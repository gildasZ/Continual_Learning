# %% [markdown]
# # *__Working on BTCUSD predictions with GRU model(DynEx_CLoRA)__*

# %% [markdown]
# ## __Check first before starting__

# %%
import os

# Change the working directory to the project root
Working_directory = os.path.normpath("C:/Users/james/OneDrive/文件/Continual_Learning")
# Working_directory = os.path.normpath("/mnt/mydisk/Continual_Learning")
os.chdir(Working_directory)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: C:\Users\james\OneDrive\文件\Continual_Learning

# %% [markdown]
# ## __All imports__

# %%
# Operating system and file management
import os
import shutil
import contextlib
import traceback
import gc
import glob, copy

# Jupyter notebook widgets and display
import ipywidgets as widgets
from IPython.display import display

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Plotting and visualization
import matplotlib.pyplot as plt
from mpl_interactions import zoom_factory, panhandler

# Machine learning and preprocessing
from sklearn.model_selection import train_test_split
import pickle
from ta import trend, momentum, volatility, volume

# Mathematical and scientific computing
import math
from scipy.ndimage import gaussian_filter1d

# Type hinting
from typing import Callable, Tuple

# Deep learning with PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## __All functions (For data processing)__

# %%
def ensure_folder(folder_path: str) -> None:
    """Ensure the given folder exists, create it if not."""
    os.makedirs(folder_path, exist_ok=True)

def plot_with_matplotlib(data: pd.DataFrame, 
                         title: str, 
                         interactive: bool = False, 
                         save_path: str = None, 
                         show_plot: bool = True, 
                         save_matplotlib_object: str = None) -> None:
    """
    Plot time-series data using Matplotlib with optional trend-based coloring.

    Args:
        - data (pd.DataFrame): Data containing a 'close' column (required).
        - title (str): Plot title.
        - interactive (bool): Enable zoom & pan if True.
        - save_path (str, optional): Path to save the figure.
        - show_plot (bool): Whether to display the plot.
        - save_matplotlib_object (str, optional): Path to save the Matplotlib object.

    Returns:
        - None: Displays or saves the plot as specified.
    """
    # Check if 'close' column exists
    if 'close' not in data.columns:
        raise ValueError("DataFrame must contain a 'close' column.")

    # Set default color from Matplotlib cycle
    default_blue = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
    
    # Define colors for different trends
    trend_colors = {
        0: 'black',
        1: 'yellow',
        2: 'red',
        3: 'green',
        4: default_blue
    }

    # Create figure and axis for plotting
    fig, ax = plt.subplots(figsize=(12, 6))

    # Plot with trend-based coloring if 'trend' column exists
    if 'trend' in data.columns:
        legend_added = set()
        prev_idx = data.index[0]
        for idx, row in data.iterrows():
            if idx != prev_idx:
                trend_key = int(row['trend'])
                label = f'Trend {trend_key}' if trend_key not in legend_added else None
                ax.plot([prev_idx, idx], 
                        [data.loc[prev_idx, 'close'], row['close']],
                        color=trend_colors[trend_key], 
                        linestyle='-', 
                        linewidth=1,
                        label=label)
                legend_added.add(trend_key)
            prev_idx = idx
        ax.set_title(f"{title} (Connected, Colored by Trend)")
    else:
        # Plot default line if no 'trend' column
        ax.plot(data.index, data['close'], label='Closing Price', linestyle='-', marker='o', 
                markersize=2, linewidth=1, color=default_blue, markerfacecolor='green', markeredgecolor='black')
        ax.set_title(title)
    
    # Set axis labels and add legend/grid
    ax.set_xlabel('Date')
    ax.set_ylabel('Closing Price (USD)')
    ax.legend()
    ax.grid()
    
    # Enable interactive features if requested
    if interactive:
        zoom_factory(ax)
        panhandler(fig)

    # Save the plot if a path is provided
    if save_path:
        fig.tight_layout()
        fig.savefig(save_path, dpi=300, bbox_inches='tight')

    # Save the Matplotlib object if requested
    if save_matplotlib_object:
        with open(save_matplotlib_object, 'wb') as f:
            pickle.dump(fig, f)

    # Display the plot if requested
    if show_plot:
        plt.show()

def load_and_show_pickle(pickle_file_path: str):
    """
    Load a pickled Matplotlib figure object and display it.

    Args:
        - pickle_file_path (str): Path to the pickled Matplotlib figure file.

    Returns:
        - None: Displays the loaded figure.
    """
    # Load and display the pickled figure
    try:
        with open(pickle_file_path, "rb") as f:
            loaded_fig = pickle.load(f)

        print(f"Figure successfully loaded and displayed from: {pickle_file_path}")
        plt.show(block=True)

    except FileNotFoundError:
        print(f"Error: File not found at {pickle_file_path}.")
    except Exception as e:
        print(f"Error loading the pickled figure: {e}")

def save_to_csv(df: pd.DataFrame, file_path: str) -> None:
    """
    Save DataFrame to CSV.
    """
    df.to_csv(file_path)
    print(f"\nSuccessfully saved data with moving average to CSV: \n\t{file_path}\n")

def read_csv_file(file_path: str, preview_rows: int = 5, 
                  days_towards_end: int = None, 
                  days_from_start: int = None, description: str = ""):
    """
    Reads a CSV file and returns a pandas DataFrame filtered by date range.

    Args:
        - file_path (str): The path to the CSV file.
        - preview_rows (int): Number of rows to preview (default is 5).
        - days_towards_end (int, optional): Number of days from the most recent date.
        - days_from_start (int, optional): Number of days from the oldest date of filtered data.
        - description (str): A brief description of the dataset.
                           Explanation:
                           - To retrieve data from the **end**: Use `days_towards_end`.
                           - To retrieve data from the **start of the filtered range**: Use `days_from_start`.
                           - To retrieve data from the **middle**: Use both:
                             For example, if `days_towards_end=100` and `days_from_start=50`,
                             the function will first filter the last 100 days of the dataset,
                             and then filter the first 50 days from this range.
                             This results in data between the last 100th and the last 50th day.

    Returns:
        - pd.DataFrame: The loaded and filtered data from the CSV file.
    """
    try:
        if description:
            print(f"\nDescription: {description}")
        print(f"\nFile path: {file_path}")
        
        # Read the CSV file
        data = pd.read_csv(file_path, parse_dates=['date'], index_col='date')
        
        # Filter by days towards the end
        if days_towards_end is not None:
            # Get the most recent date in the dataset
            last_date = data.index.max()
            end_cutoff_date = last_date - pd.Timedelta(days=days_towards_end)
            data = data[data.index >= end_cutoff_date]
            print(f"\nRetrieving data from the past {days_towards_end} days (from {end_cutoff_date.date()} onwards):")
        
        # Filter by days from the start (from the filtered data)
        if days_from_start is not None:
            # Get the earliest date in the filtered dataset
            first_date = data.index.min()
            start_cutoff_date = first_date + pd.Timedelta(days=days_from_start)
            data = data[data.index <= start_cutoff_date]
            print(f"\nRetrieving the first {days_from_start} days from the filtered data (up to {start_cutoff_date.date()}):")

        if preview_rows:
            # Print a preview of the data
            print(f"\nPreview of the first {preview_rows} rows:")
            display(data.head(preview_rows))
            print()

            print(f"\nPreview of the last {preview_rows} rows:")
            display(data.tail(preview_rows))
            print()

        return data
    
    except FileNotFoundError:
        print("Error: File not found.")
    except pd.errors.EmptyDataError:
        print("Error: The file is empty.")
    except pd.errors.ParserError:
        print("Error: File parsing failed.")
    except Exception as e:
        print(f"Unexpected error: {e}")

def downsample_minute_data(data: pd.DataFrame, n: int) -> pd.DataFrame:
    """
    Downsample minute data into N-minute intervals by retaining every Nth row.

    Args:
        - data (pd.DataFrame): The original DataFrame with a datetime index.
        - n (int): The number of minutes for the downsampling interval.

    Returns:
        - pd.DataFrame: Downsampled DataFrame.
    """
    print("\n========---> Downsampling the data! \n")
    data = data.copy()

    # Ensure index is a DatetimeIndex
    if not isinstance(data.index, pd.DatetimeIndex):
        try:
            data.index = pd.to_datetime(data.index)
        except Exception as e:
            raise ValueError("DataFrame index conversion to DatetimeIndex failed.") from e

    # Downsample by selecting rows where minute % N == 0
    return data[data.index.minute % n == 0]

def calculate_log_returns_all_columns(data: pd.DataFrame, exclude_columns: list = [], dropna: bool = True) -> pd.DataFrame:
    """
    Calculate log returns for all numeric columns in a pandas DataFrame,
    excluding specified columns, and removing excluded columns from the returned DataFrame.

    Args:
        - data (pd.DataFrame): Input DataFrame containing numeric data.
        - exclude_columns (list): List of columns to exclude from log return calculations and the result.
        - dropna (bool): Whether to drop rows with NaN values resulting from the calculation.

    Returns:
        - pd.DataFrame: DataFrame with log returns for numeric columns, excluding specified columns.
    """
    # Copy data and remove excluded columns
    data = data.copy().drop(columns=exclude_columns)
    
    # Select numeric columns for transformation
    columns_to_transform = data.select_dtypes(include=[np.number]).columns
    print(f"columns_to_transform = \n{columns_to_transform}, \nlen(columns_to_transform) = {len(columns_to_transform)}")

    # Calculate log returns for each numeric column
    for col in columns_to_transform:
        if (data[col] <= 0).any():
            raise ValueError(f"Column '{col}' contains non-positive values. Log returns require strictly positive values.")
        data[col] = np.log(data[col] / data[col].shift(1))

    # Return data with or without NaN rows based on dropna
    return data.dropna() if dropna else data

def created_sequences_2(data: pd.DataFrame, sequence_length: int = 60, sliding_interval: int = 60) -> list:
    """
    Divide the dataset into sequences based on the sequence_length.
    Each sequence must fully cover the window size.

    Args:
    - data (pd.DataFrame): The input DataFrame.
    - sequence_length (int): The window size for sequences.

    Returns:
    - sequences (list): A list of sequences (as DataFrames).
    """
    sequences = []
    
    # Iterate over the data with a sliding window to create sequences
    for i in range(0, len(data) - sequence_length + 1, sliding_interval):
        # Extract a sequence of specified length from the DataFrame
        seq = data.iloc[i:i + sequence_length].copy()
        sequences.append(seq)

    return sequences

def gaussian_smoothing(data: pd.DataFrame, sigma=2) -> pd.DataFrame:
    """
    Applies Gaussian smoothing to numeric columns in a DataFrame.

    Args:
        - data (pd.DataFrame): Input DataFrame.
        - sigma (float): Standard deviation for the Gaussian kernel (default is 2).

    Returns:
        - pd.DataFrame: Smoothed DataFrame with sorted index.
    """
    # Sort data by index in ascending order and create a copy
    data = data.sort_index(ascending=True).copy()
    
    # Apply Gaussian smoothing to numeric columns
    for column in data.columns:
        if pd.api.types.is_numeric_dtype(data[column]):
            data[column] = gaussian_filter1d(data[column].values, sigma=sigma)
    
    return data

def detect_trends_4(
    dataframe: pd.DataFrame, 
    column: str = 'close', 
    lower_threshold: float = 0.001, 
    upper_threshold: float = 0.02,
    reverse_steps: int = 7,
    trends_to_keep: set = {0, 1, 2, 3, 4}  # Default keeps all trends
) -> pd.DataFrame:
    """
    Detects trends based on log return data provided in a specified column and categorizes them into different strength levels.

    This function analyzes time-series data by evaluating cumulative trends in log return values provided in the input DataFrame. 
    It uses three dictionaries (`dic1`, `dic2`, `dic3`) to track different phases of trends, handles multi-step reversals, and 
    classifies trends dynamically based on cumulative product thresholds and specified thresholds for trend strengths.

    Args:
        - dataframe (pd.DataFrame): Input DataFrame with log return data.
        - column (str): Column name for log returns (default is 'close').
        - lower_threshold (float): Threshold for moderate trends (default is 0.001).
        - upper_threshold (float): Threshold for strong trends (default is 0.02).
        - reverse_steps (int): Steps to confirm trend reversal (default is 7).
        - trends_to_keep (set): Trends to retain, others set to 0 (default is {0, 1, 2, 3, 4}).

    Returns:
        pd.DataFrame: DataFrame with 'trend' column:
                        - 0: No trend
                        - 1: Moderate negative trend
                        - 2: Very strong negative trend
                        - 3: Moderate positive trend
                        - 4: Very strong positive trend
                      Any trends not included in `trends_to_keep` will be reset to 0.

    Function Details:
    1. **Input Assumption**:
    - The input DataFrame already contains log return data in the specified column (`column`).

    2. **Trend Tracking**:
    - Uses dictionaries to monitor trends:
        - `dic1`: Tracks the first phase of the trend.
        - `dic2`: Tracks the second phase if a reversal occurs.
        - `dic3`: Tracks the third phase if another reversal occurs.

    3. **Cumulative Product**:
    - Calculates the cumulative product of `(1 + log_return)` from the specified column to evaluate the strength of trends.

    4. **Reversal Handling**:
    - If a trend reversal persists beyond `reverse_steps`, labels are assigned based on the cumulative product tracked in `dic1`.
    - Subsequent reversals are merged or labeled independently if conditions are met.

    5. **Label Assignment**:
    - Labels are dynamically assigned based on cumulative product thresholds for positive and negative trends:
        - Positive trends are categorized as moderate (3) or strong (4).
        - Negative trends are categorized as moderate (1) or strong (2).

    6. **Trend Filtering**:
    - After detecting trends, only those specified in `trends_to_keep` remain unchanged.
    - Any trend category not included in `trends_to_keep` is reset to 0 (No Trend).

    7. **Edge Cases**:
    - Properly handles scenarios where data points are insufficient for trend analysis or when trend phases overlap, ensuring all data points are labeled.
    """
    # Copy to avoid modifying the original DataFrame
    df = dataframe.copy()
    df['trend'] = None  # Default value 

    dic1, dic2, dic3 = None, None, None # Initialize trend tracking dictionaries
    
    def assign_label(dictio_, lower_threshold, upper_threshold):
        cumulative = dictio_['cumulative']
        if cumulative > (1 + upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 4  # Very strong positive
        elif (1 + lower_threshold) < cumulative <= (1 + upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 3  # Moderate positive
        elif (1 - upper_threshold) < cumulative <= (1 - lower_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 1  # Moderate negative
        elif cumulative <= (1 - upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 2  # Very strong negative
        else:
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 0  # No trend
    
    # Process each log return to detect trends
    for idx, log_ret in enumerate(df[column]):
        sign = 1 if log_ret > 0 else -1

        if dic1 is None:  # Initialize dic1
            dic1 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue

        last_sign = dic1['last_sign']
        if sign == last_sign and dic2 is None:  # Continue same trend
            dic1['ids'].append(idx)
            dic1['last_sign'] = sign
            dic1['cumulative'] *= (1 + log_ret)
            continue

        # 1st Reversal occuring
        if dic2 is None:  # Start dic2
            dic2 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue

        last_sign = dic2['last_sign']
        if sign == last_sign and dic3 is None:  # Continue same trend
            dic2['ids'].append(idx)
            dic2['last_sign'] = sign
            dic2['cumulative'] *= (1 + log_ret)
            if len(dic2['ids']) == reverse_steps:
                assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                dic1, dic2 = dic2, None
            continue

        # 2nd Reversal occuring
        if dic3 is None:  # Start dic3
            dic3 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue

        last_sign = dic3['last_sign']
        if sign == last_sign: # Continue same trend, there is no dic4 to check if is None
            dic3['ids'].append(idx)
            dic3['last_sign'] = sign
            dic3['cumulative'] *= (1 + log_ret)
            dic_prod = dic2['cumulative'] * dic3['cumulative']
            if (sign == 1 and dic_prod > 1) or (sign == -1 and dic_prod < 1):
                dic1['ids'] += dic2['ids'] + dic3['ids']
                dic1['last_sign'] = dic3['last_sign']
                dic1['cumulative'] *= dic2['cumulative'] * dic3['cumulative']
                dic2, dic3 = None, None
                continue

            if len(dic3['ids']) == reverse_steps:      
                assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                assign_label(dic2, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                dic1, dic2, dic3 = dic3, None, None
            continue
            
        # 3rd Reversal occuring
        assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
        dic1, dic2, dic3 = dic2, dic3, {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}

    # Assign remaining labels
    if dic1:
        assign_label(dic1, lower_threshold, upper_threshold)
    if dic2:
        assign_label(dic2, lower_threshold, upper_threshold)
    if dic3:
        assign_label(dic3, lower_threshold, upper_threshold)
    
    # Apply filtering: Keep only selected trends, set others to 0
    df['trend'] = df['trend'].where(df['trend'].isin(trends_to_keep), 0)

    return df

def split_X_y(sequences: list[pd.DataFrame], 
              target_column: str = 'trend',
              detect_trends_function: Callable[[pd.DataFrame, str, float, float, int, set], pd.DataFrame] = detect_trends_4, 
              column: str = 'close', 
              lower_threshold: float = 0.0009, 
              upper_threshold: float = 0.015,
              reverse_steps: int = 7,
              trends_to_keep: set = {0, 1, 2, 3, 4}) -> Tuple[np.ndarray, np.ndarray]:
    """
    Process sequences to generate features (X) and labels (y) with trend detection.

    Args:
        - sequences (list[pd.DataFrame]): List of DataFrame sequences.
        - target_column (str): Column name for labels (default is 'trend').
        - detect_trends_function (Callable): Trend detection function (default is detect_trends_4).
        - column (str): Column for trend detection (default is 'close').
        - lower_threshold (float): Lower threshold for trends (default is 0.0009).
        - upper_threshold (float): Upper threshold for trends (default is 0.015).
        - reverse_steps (int): Steps for trend reversal (default is 7).
        - trends_to_keep (set): Trends to retain (default is {0, 1, 2, 3, 4}).

    Returns:
        - Tuple[np.ndarray, np.ndarray]: X (features), y (labels) as NumPy arrays.
    """
    # Initialize lists for features and labels
    X, y = [], []
    
    # Process each sequence
    for seq in sequences:
        # Apply trend detection
        seq = detect_trends_function(seq, column, lower_threshold, upper_threshold, reverse_steps, trends_to_keep)
        
        # Extract features and labels
        X.append(seq.drop(columns=[target_column]).values)
        y.append(seq[target_column].values)
    
    # Convert to NumPy arrays
    return np.array(X), np.array(y)

def process_and_return_splits(
    with_indicators_file_path: str,
    downsampled_data_minutes: int,
    exclude_columns: list[str],
    lower_threshold: float,
    upper_threshold: float,
    reverse_steps: int,
    sequence_length: int,
    sliding_interval: int,
    trends_to_keep: set = {0, 1, 2, 3, 4}  # Default keeps all trends
) -> tuple[
    list[list[float]],  # X_train: List of sequences, each containing a list of features
    list[list[int]],    # y_train: List of sequences, each containing a list of labels
    list[list[float]],  # X_val: List of sequences, each containing a list of features
    list[list[int]],    # y_val: List of sequences, each containing a list of labels
    list[list[float]],  # X_test: List of sequences, each containing a list of features
    list[list[int]]     # y_test: List of sequences, each containing a list of labels
]:
    """
    Processes time-series data from a CSV file and prepares it for machine learning.

    This function performs the following steps:
        1. Reads data from the specified CSV file and sorts it by date in descending order.
        2. Optionally downsamples the data to a lower frequency (e.g., 5-minute intervals).
        3. Applies Gaussian smoothing to reduce noise in the data.
        4. Calculates log returns for all numeric columns, excluding specified columns.
        5. Detects trends based on defined thresholds (`lower_threshold`, `upper_threshold`, and `reverse_steps`).
        6. Filters trends to keep only those specified in `trends_to_keep`, setting others to 0 (No Trend).
        7. Converts the processed data into sequences of a fixed length (`sequence_length`) with a sliding interval.
        8. Splits the sequences into training (80%), validation (10%), and test (10%) sets.
        9. Further splits the sequences into features (`X`) and labels (`y`) for supervised learning.

    Args:
        - with_indicators_file_path (str): Path to the CSV file with time-series data.
        - downsampled_data_minutes (int): Frequency for downsampling (e.g., 1 for no downsampling).
        - exclude_columns (list[str]): Columns to exclude from log return calculations.
        - lower_threshold (float): Lower threshold for trend detection.
        - upper_threshold (float): Upper threshold for trend detection.
        - reverse_steps (int): Steps for reversing trends in trend detection.
        - sequence_length (int): Length of sequences to create.
        - sliding_interval (int): Interval for sliding the window.
        - trends_to_keep (set): Trends to retain, others set to 0 (default is {0, 1, 2, 3, 4}).

    Returns:
        - tuple: X_train, y_train, X_val, y_val, X_test, y_test as lists of sequences.
    """
    def check_missing_timestamps(data: pd.DataFrame, stage: str):
        """
        Checks for missing timestamps and prints diagnostic info.
        """
        missing_timestamps = pd.date_range(
            start=data.index.min(),
            end=data.index.max(),
            freq='1min',  # Checking 1-minute frequency
            tz=data.index.tz,
        ).difference(data.index)

        print(f"\n{stage} - Missing timestamps: \n{missing_timestamps}")

        if not missing_timestamps.empty:
            for timestamp in missing_timestamps[:5]:  # Show only first 5 missing timestamps
                print(f"\nMissing timestamp: {timestamp}")

                before = data[data.index < timestamp].tail(5)  # 5 data points before
                after = data[data.index > timestamp].head(5)  # 5 data points after

                print("\nData before missing timestamp:")
                display(before) if not before.empty else print("No data available before.")

                print("\nData after missing timestamp:")
                display(after) if not after.empty else print("No data available after.")

    print("\n======== Processing Time-Series Data ========")

    # Step 1: Read & Sort Data
    data = read_csv_file(with_indicators_file_path, preview_rows=0).sort_index(ascending=False)

    # Step 2: Downsample Data
    if downsampled_data_minutes != 1:
        print("\n---> Downsampling Data")
        data = downsample_minute_data(data, downsampled_data_minutes)

    check_missing_timestamps(data, "Data Retrieved")

    # Step 3: Gaussian Smoothing
    data = gaussian_smoothing(data, sigma=7)
    check_missing_timestamps(data, "Gaussian Smoothed Data")

    # Step 4: Compute Log Returns
    data = calculate_log_returns_all_columns(data, exclude_columns=exclude_columns)
    check_missing_timestamps(data, "Log Returns Computed")

    # Step 5: Create Sequences
    sequences = created_sequences_2(data, sequence_length, sliding_interval)

    # Step 6: Train / Validation / Test Split
    train_size = int(len(sequences) * 0.8)
    val_size = int(len(sequences) * 0.1)

    train_sequences = sequences[:train_size]
    val_sequences = sequences[train_size:train_size + val_size]
    test_sequences = sequences[train_size + val_size:]

    print(f"\nNumber of sequences:\n"
          f"  - Total sequences: {len(sequences)}\n"
          f"  - Train: {len(train_sequences)}\n"
          f"  - Validation: {len(val_sequences)}\n"
          f"  - Test: {len(test_sequences)}\n")

    # Step 7: Convert Sequences to X, y
    def split_and_format_data(sequences):
        X, y = split_X_y(
            sequences, target_column='trend',
            detect_trends_function=detect_trends_4,
            column='close', lower_threshold=lower_threshold,
            upper_threshold=upper_threshold, reverse_steps=reverse_steps,
            trends_to_keep=trends_to_keep
        )
        return np.array(X), np.array(y)

    X_train, y_train = split_and_format_data(train_sequences)
    X_val, y_val = split_and_format_data(val_sequences)
    X_test, y_test = split_and_format_data(test_sequences)

    # Step 8: Data Integrity Check (Ensuring Proper Types)
    def check_data_types(X: np.ndarray, y: np.ndarray, label: str):
        """
        Checks if all values in X are float and y are integer.
        """
        unexpected_X = [(i, j, k, type(v)) for i, seq in enumerate(X)
                        for j, row in enumerate(seq)
                        for k, v in enumerate(row) if not isinstance(v, (float, np.float32))]
        unexpected_y = [(i, j, type(v)) for i, seq in enumerate(y)
                        for j, v in enumerate(seq) if not isinstance(v, (int, np.int64))]

        if unexpected_X:
            print(f"\n⚠️ Unexpected type in {label} X:")
            for i, j, k, t in unexpected_X[:5]:  # Show first 5 errors
                print(f"  Sequence {i}, Row {j}, Feature {k}: {t}")

        if unexpected_y:
            print(f"\n⚠️ Unexpected type in {label} y:")
            for i, j, t in unexpected_y[:5]:  # Show first 5 errors
                print(f"  Sequence {i}, Label {j}: {t}")

    check_data_types(X_train, y_train, "Train")
    check_data_types(X_val, y_val, "Validation")
    check_data_types(X_test, y_test, "Test")

    # Step 9: Convert y types if needed
    def convert_dtype(y: np.ndarray):
        return np.array(y, dtype=np.int64) if isinstance(y, np.ndarray) and y.dtype == np.object_ else y

    y_train, y_val, y_test = map(convert_dtype, [y_train, y_val, y_test])

    # Get feature info
    Number_features = X_train.shape[-1]
    close_col_index = data.columns.get_loc('close')
    
    print(f"\nFeature Info:\n  - close_col_index = {close_col_index}\n  - Number_features = {Number_features}")

    return X_train, y_train, X_val, y_val, X_test, y_test, Number_features

def print_class_distribution(y, var_name: str) -> None:
    """
    Prints the class distribution of a label array.

    Args:
        y: Tensor, array, or list of class labels.
        var_name: Name of the variable (for display).
    """
    if isinstance(y, torch.Tensor):
        y = y.cpu().numpy()
    flattened = np.array(y).flatten()

    unique_classes, counts = np.unique(flattened, return_counts=True)
    total = counts.sum()

    header = f"Class Distribution for '{var_name}':"
    line_parts = [
        f"Class {int(c):<3} Percent: {(count / total) * 100:>6.2f}%"
        for c, count in zip(unique_classes, counts)
    ]
    print(header.ljust(40) + " || ".join(line_parts))

# %% [markdown]
# ## __All (Initial) parameters__

# %%
ticker = 'BTC-USD'
downsampled_data_minutes = 1 # No downsampling

# Step 0 (Again): Identify parameters for trend settings of the loaded data with 1,000 data points
lower_threshold = 0.0009 # 較小的價格變動門檻，代表 輕微的趨勢變化 也可能被識別為趨勢。
upper_threshold = 0.015  # 較大的價格變動門檻，當變動超過這個值，才會標記為強趨勢。
reverse_steps = 13       # 趨勢反轉的步數門檻，當價格變動連續 13 次反向時，才認為趨勢改變。

# Features not to be included in the analysis
exclude_columns= ['MACD', 'MACD_signal', 'ROC_10', 'OBV', 'AD_Line']

# Step 3, under ### Correlation Analysis
# Compute correlations with the 'trend' column
# corr = data_trends.corr()
# trend_corr = corr['trend'].sort_values(ascending=False)
strongly_correlated = ['close', 'open', 'SMA_5', 'high', 'low', 'EMA_10', 'SMA_10'] # Strongly correlated (correlation > 0.6)
moderately_correlated = ['BB_middle', 'BB_lower', 'BB_upper', 'RSI_14']             # Moderately correlated (correlation between 0.3 and 0.6)
weakly_correlated = ['SMA_50', 'volume', 'BBW', 'ATR_14']                           # Weakly correlated or negligible (correlation <~ 0.3)

# Add the weakly_correlated and moderately_correlated features to exclude_columns.
exclude_columns += weakly_correlated + moderately_correlated

sequence_length = 1000
sliding_interval = 60

# %% [markdown]
# ## __Check GPU, CUDA, Pytorch__

# %% [markdown]
# ### GPU Details

# %%
# !nvidia-smi
# Out:
# Mon Apr 21 01:12:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   45C    P5             18W /  200W |    1655MiB /  12282MiB |     24%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     54768    C+G   ...al\Discord\app-1.0.9188\Discord.exe      N/A      |
# |    0   N/A  N/A     67352    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     83936    C+G   ...US\ArmouryDevice\asus_framework.exe      N/A      |
# |    0   N/A  N/A     85988    C+G   ...ata\Local\LINE\bin\current\LINE.exe      N/A      |
# |    0   N/A  N/A     90496    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A    103372    C+G   ... Stream\106.0.4.0\GoogleDriveFS.exe      N/A      |
# |    0   N/A  N/A    120292    C+G   ...ta\Local\Programs\Notion\Notion.exe      N/A      |
# |    0   N/A  N/A    123408    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A    125500    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A    126332    C+G   ...\cef\cef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A    131424    C+G   ...ograms\cron-web\Notion Calendar.exe      N/A      |
# |    0   N/A  N/A    135136    C+G   ...1.0_x64__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A    140496    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A    141588    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A    142900    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A    146092    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A    165780    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### CUDA Details

# %%
def check_gpu_config():
    """
    Check GPU availability and display detailed configuration information.
    """
    # Check if GPU is available
    gpu_available = torch.cuda.is_available()
    
    # Print header
    print("=" * 50)
    print("GPU Configuration Check".center(50))
    print("=" * 50)
    
    # Basic GPU availability
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'GPU Available':<25}: {'Yes' if gpu_available else 'No'}")
    
    # If GPU is available, print detailed info
    if gpu_available:
        print("-" * 50)
        print("GPU Details".center(50))
        print("-" * 50)
        
        # Device info
        print(f"{'Device Name':<25}: {torch.cuda.get_device_name(0)}")
        print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")
        print(f"{'Current Device Index':<25}: {torch.cuda.current_device()}")
        
        # Compute capability and CUDA cores
        props = torch.cuda.get_device_properties(0)
        print(f"{'Compute Capability':<25}: {props.major}.{props.minor}")
        print(f"{'Total CUDA Cores':<25}: {props.multi_processor_count * 128}")  # Approx. 128 cores per SM
        
        # Memory info
        total_memory = props.total_memory / (1024 ** 3)  # Convert to GB
        memory_allocated = torch.cuda.memory_allocated(0) / (1024 ** 3)
        memory_reserved = torch.cuda.memory_reserved(0) / (1024 ** 3)
        print(f"{'Total Memory (GB)':<25}: {total_memory:.2f}")
        print(f"{'Allocated Memory (GB)':<25}: {memory_allocated:.2f}")
        print(f"{'Reserved Memory (GB)':<25}: {memory_reserved:.2f}")
    else:
        print("-" * 50)
        print("No GPU detected. Running on CPU.".center(50))
        print("-" * 50)
    
    print("=" * 50)

if __name__ == "__main__":
    check_gpu_config()
# Out:
# ==================================================
#              GPU Configuration Check
# ==================================================
# PyTorch Version          : 2.4.1+cu124
# GPU Available            : Yes
# --------------------------------------------------
#                    GPU Details
# --------------------------------------------------
# Device Name              : NVIDIA GeForce RTX 4070
# Number of GPUs           : 1
# Current Device Index     : 0
# Compute Capability       : 8.9
# Total CUDA Cores         : 5888
# Total Memory (GB)        : 11.99
# Allocated Memory (GB)    : 0.00
# Reserved Memory (GB)     : 0.00
# ==================================================

# %% [markdown]
# ### PyTorch Details

# %%
def print_torch_config():
    """Print PyTorch and CUDA configuration in a formatted manner."""
    print("=" * 50)
    print("PyTorch Configuration".center(50))
    print("=" * 50)
    
    # Basic PyTorch and CUDA info
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'CUDA Compiled Version':<25}: {torch.version.cuda}")
    print(f"{'CUDA Available':<25}: {'Yes' if torch.cuda.is_available() else 'No'}")
    print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")

    # GPU details if available
    if torch.cuda.is_available():
        print(f"{'GPU Name':<25}: {torch.cuda.get_device_name(0)}")

    print("-" * 50)
    
    # Seed setting
    torch.manual_seed(42)
    print(f"{'Random Seed':<25}: 42 (Seeding successful!)")
    
    print("=" * 50)

if __name__ == "__main__":
    print_torch_config()
# Out:
# ==================================================
#               PyTorch Configuration
# ==================================================
# PyTorch Version          : 2.4.1+cu124
# CUDA Compiled Version    : 12.4
# CUDA Available           : Yes
# Number of GPUs           : 1
# GPU Name                 : NVIDIA GeForce RTX 4070
# --------------------------------------------------
# Random Seed              : 42 (Seeding successful!)
# ==================================================

# %% [markdown]
# ## __Build the GRU Model__

# %% [markdown]
# ### Standard LoRA

# %%
class LoRA(nn.Module):
    def __init__(self, linear_layer: nn.Linear, rank: int):
        """
        LoRA module applied to a specified linear layer.

        Args:
            linear_layer (nn.Linear): The linear layer to adapt (e.g., attention_fc or fc).
            rank (int): The rank of the LoRA adjustment matrices (e.g., 8).
        """
        super(LoRA, self).__init__()
        self.linear = linear_layer  # 保留對 linear_layer 的引用
        self.rank = rank
        
        # Get input and output dimensions from the linear layer
        in_features, out_features = linear_layer.weight.shape
        
        # Create LoRA matrices A and B
        self.A = nn.Parameter(torch.zeros(in_features, rank))  # Shape: (in_features, rank)
        self.B = nn.Parameter(torch.zeros(rank, out_features))  # Shape: (rank, out_features)
        
        # Initialize A with normal distribution, B with zeros
        nn.init.normal_(self.A, mean=0, std=1)
        nn.init.zeros_(self.B)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Forward pass with LoRA adjustment applied to the linear layer.

        Args:
            x (torch.Tensor): Input tensor.

        Returns:
            torch.Tensor: Output tensor with LoRA-adapted weights.
        """
        lora_delta = self.A @ self.B
        adapted_weight = self.linear.weight + lora_delta
        return nn.functional.linear(x, adapted_weight, self.linear.bias)
    
    def parameters(self, recurse=True):
        """
        Override parameters() to return only LoRA-specific parameters (A and B).

        Args:
            recurse (bool): Ignored, included for compatibility with nn.Module.

        Returns:
            list: List of LoRA parameters (self.A and self.B).
        """
        return [self.A, self.B]

class BiGRUWithAttention_LoRA(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout=0.0, lora_rank=8):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lora_rank = lora_rank
        
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True,
                          bidirectional=True, dropout=dropout if num_layers > 1 else 0)
        
        self.attention_fc = nn.Linear(hidden_size * 2, hidden_size * 2)
        self.lora_adapter = None  # 從 Period 2 開始才初始化
        self.fc = nn.Linear(hidden_size * 2, output_size)
        self.dropout = nn.Dropout(dropout)
        self.init_weights()
    
    def init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0)
    
    def init_lora(self):
        """在 Period 2 初始化一次 LoRA，之後都不再變動"""
        if self.lora_adapter is None:
            self.lora_adapter = LoRA(self.attention_fc, self.lora_rank).to(next(self.parameters()).device)
            print("Initialized LoRA adapter")

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers * 2, batch_size, self.hidden_size, device=x.device)
        out, _ = self.gru(x, h0)

        if self.lora_adapter:
            attn_out = self.lora_adapter(out)
        else:
            attn_out = self.attention_fc(out)

        attn_weights = torch.tanh(attn_out)
        out = attn_weights * out
        out = self.dropout(out)
        out = self.fc(out)
        return out

    def get_trainable_parameters(self):
        params = []
        names = []

        if self.lora_adapter:
            lora_params = list(self.lora_adapter.parameters())
            params += lora_params
            names += ['lora_adapter.' + name for name, _ in self.lora_adapter.named_parameters()]

        fc_params = list(self.fc.parameters())
        params += fc_params
        names += ['fc.' + name for name, _ in self.fc.named_parameters()]

        print(f"🧠 Trainable parameters: {len(params)} total")
        for name in names:
            print(f"  ✅ {name}")
        
        return params

# %% [markdown]
# ## __Training and validation function__

# %% [markdown]
# ### Analytical Function

# %%
def compute_classwise_accuracy(student_logits_flat, y_batch, class_correct, class_total):
    """
    Computes per-class accuracy by accumulating correct and total samples for each class using vectorized operations.
    
    Args:
        student_logits_flat (torch.Tensor): Model predictions (logits) in shape [batch_size * seq_len, output_size]
        y_batch (torch.Tensor): True labels in shape [batch_size * seq_len]
        class_correct (dict): Dictionary to store correct predictions per class
        class_total (dict): Dictionary to store total samples per class
    """
    # Ensure inputs are on the same device
    if student_logits_flat.device != y_batch.device:
        raise ValueError("student_logits_flat and y_batch must be on the same device")

    # Convert logits to predicted class indices
    predictions = torch.argmax(student_logits_flat, dim=-1)  # Shape: [batch_size * seq_len]

    # Compute correct predictions mask
    correct_mask = (predictions == y_batch)  # Shape: [batch_size * seq_len], boolean

    # Get unique labels in this batch
    unique_labels = torch.unique(y_batch)

    # Update class_total and class_correct using vectorized operations
    for label in unique_labels:
        label = label.item()  # Convert tensor to scalar
        if label not in class_total:
            class_total[label] = 0
            class_correct[label] = 0
        
        # Count total samples for this label
        label_mask = (y_batch == label)
        class_total[label] += label_mask.sum().item()
        
        # Count correct predictions for this label
        class_correct[label] += (label_mask & correct_mask).sum().item()

# %% [markdown]
# ### Training and validation function

# %%
def train_lora_baseline(model, output_size, criterion, optimizer,
                        X_train, y_train, X_val, y_val, scheduler=None,
                        num_epochs=10, batch_size=64, model_saving_folder=None,
                        model_name=None, stop_signal_file=None):
    print("\n🚀 'train_lora_baseline' started.")

    # Prepare saving folder
    if model_saving_folder:
        if os.path.exists(model_saving_folder):
            shutil.rmtree(model_saving_folder)
            print(f"✅ Removed existing folder: {model_saving_folder}")
        os.makedirs(model_saving_folder, exist_ok=True)

    model_name = model_name or 'model'
    model_saving_folder = model_saving_folder or './saved_models'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    # Tensor to device
    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    print("\n✅ Data Overview:")
    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")

    best_results = []
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        class_correct, class_total = {}, {}

        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\n🛑 Stop signal detected. Exiting training loop.")
            break

        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch).view(-1, output_size)
            y_batch = y_batch.view(-1)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * X_batch.size(0)
            compute_classwise_accuracy(outputs, y_batch, class_correct, class_total)

        train_loss = epoch_loss / len(train_loader.dataset)
        train_acc = {int(c): f"{(class_correct[c] / class_total[c]) * 100:.2f}%" if class_total[c] > 0 else "0.00%"
                     for c in sorted(class_total.keys())}

        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        val_class_correct, val_class_total = {}, {}
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                outputs = model(X_batch).view(-1, output_size)
                y_batch = y_batch.view(-1)
                val_loss += criterion(outputs, y_batch).item() * X_batch.size(0)
                predictions = torch.argmax(outputs, dim=-1)
                val_correct += (predictions == y_batch).sum().item()
                val_total += y_batch.size(0)
                compute_classwise_accuracy(outputs, y_batch, val_class_correct, val_class_total)

        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / val_total
        val_acc_cls = {int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%"
                       for c in sorted(val_class_total.keys())}

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, Train-Class-Acc: {train_acc},")
        print(f"Val Loss: {val_loss:.6f}, Val Acc: {val_acc * 100:.2f}%, Val-Class-Acc: {val_acc_cls}, LR: {optimizer.param_groups[0]['lr']:.6f}")

        model_path = os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        current = {
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_accuracy': val_acc,
            'train_classwise_accuracy': train_acc,
            'val_classwise_accuracy': val_acc_cls,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'learning_rate': optimizer.param_groups[0]['lr'],
            'model_path': model_path
        }

        if len(best_results) < 5 or val_acc > best_results[-1]['val_accuracy']:
            if len(best_results) == 5:
                to_remove = best_results.pop()
                if os.path.exists(to_remove['model_path']):
                    os.remove(to_remove['model_path'])
                    print(f"🗑 Removed: {to_remove['model_path']}")
            best_results.append(current)
            best_results.sort(key=lambda x: (x['val_accuracy'], x['epoch']), reverse=True)
            torch.save(current, model_path)
            print(f"✅ Saved model: {model_path}")

        if scheduler: scheduler.step(val_loss)

    if best_results:
        best = best_results[0]
        best_model_path = os.path.join(model_saving_folder, f"{model_name}_best.pth")
        torch.save(best, best_model_path)
        print(f"\n🏆 Best model saved as: {best_model_path} (Val Accuracy: {best['val_accuracy'] * 100:.2f}%)")

    final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
    torch.save(current, final_model_path)
    print(f"\n📌 Final model saved as: {final_model_path}")

    print("\n🎯 Top 5 Best Models:")
    for res in best_results:
        print(f"Epoch {res['epoch']}, Train Loss: {res['train_loss']:.6f}, Train-Acc: {res['train_classwise_accuracy']},\n"
              f"Val Loss: {res['val_loss']:.6f}, Val Acc: {res['val_accuracy']*100:.2f}%, Val-Acc: {res['val_classwise_accuracy']},"
              f" Model Path: {res['model_path']}")

    del X_train, y_train, X_val, y_val, train_loader, val_loader
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# ## __Setup before training__

# %% [markdown]
# ### Define list_period_files_full_path

# %%
def setup_file_paths(pair='BTCUSD', base_dir='Data', days=190):
    """
    Set up file paths for cryptocurrency data across multiple periods.

    Args:
        pair (str): Trading pair (e.g., 'BTCUSD').
        base_dir (str): Base directory for data storage (default 'Data').
        days (int): Number of days for each period (default 190).

    Returns:
        tuple: (base_folder_path, with_indicators_file_path, list_period_files_full_path)
    """
    # Define base file name and folder structure
    file_name = f"Polygon_{pair}_4Y_1min"
    base_folder_path = os.path.normpath(os.path.join(base_dir, file_name))
    
    # Check if folder exists
    if not os.path.isdir(base_folder_path):
        raise FileNotFoundError(f"Directory '{base_folder_path}' does not exist.")

    # Define file path with indicators for Period 1
    with_indicators_file_path = os.path.normpath(
        os.path.join(base_folder_path, f"_{file_name}_{days}_days_with_indicators.csv")
    )

    # Define file paths for all periods
    list_period_files_full_path = [
        # Period 1
        with_indicators_file_path,
        # Period 2: 2020-11-11 to 2021-05-20
        os.path.normpath(os.path.join(
            base_folder_path, f"{file_name}_{days}_days__2020-11-11__2021-05-20__with_indicators.csv"
        )),
        # Period 3: 2021-05-20 to 2021-11-26
        os.path.normpath(os.path.join(
            base_folder_path, f"{file_name}_{days}_days__2021-05-20__2021-11-26__with_indicators.csv"
        )),
        # Period 4: 2021-11-26 to 2022-06-04
        os.path.normpath(os.path.join(
            base_folder_path, f"{file_name}_{days}_days__2021-11-26__2022-06-04__with_indicators.csv"
        )),
        # Period 5: 2022-06-04 to 2022-12-11
        os.path.normpath(os.path.join(
            base_folder_path, f"{file_name}_{days}_days__2022-06-04__2022-12-11__with_indicators.csv"
        )),
    ]

    return base_folder_path, with_indicators_file_path, list_period_files_full_path

def print_folder_contents(folder_path):
    """Print all files in the specified folder."""
    print("\n📂 Folder Contents:")
    for file in os.listdir(folder_path):
        print(f"Found file: {file}")

if __name__ == "__main__":
    # Set up paths
    base_folder_path, with_indicators_file_path, list_period_files_full_path = setup_file_paths()

    # Print results
    print("=" * 70)
    print("File Path Configuration".center(70))
    print("=" * 70)
    
    print(f"{'Base Folder Path':<25}: {base_folder_path}")
    print(f"{'Period 1 File Path':<25}: {with_indicators_file_path}")
    print("-" * 70)
    
    print("List of Period Files:")
    for i, path in enumerate(list_period_files_full_path, 1):
        print(f"{'Period ' + str(i):<25}: {path}")
    
    print("=" * 70)

    # Print folder contents
    print_folder_contents(base_folder_path)
# Out:
# ======================================================================
#                        File Path Configuration
# ======================================================================
# Base Folder Path         : Data\Polygon_BTCUSD_4Y_1min
# Period 1 File Path       : Data\Polygon_BTCUSD_4Y_1min\_Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv
# ----------------------------------------------------------------------
# List of Period Files:
# Period 1                 : Data\Polygon_BTCUSD_4Y_1min\_Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv
# Period 2                 : Data\Polygon_BTCUSD_4Y_1min\Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20__with_indicators.csv
# Period 3                 : Data\Polygon_BTCUSD_4Y_1min\Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26__with_indicators.csv
# Period 4                 : Data\Polygon_BTCUSD_4Y_1min\Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04__with_indicators.csv
# Period 5                 : Data\Polygon_BTCUSD_4Y_1min\Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11__with_indicators.csv
# ======================================================================
#
# 📂 Folder Contents:
# Found file: Polygon_BTCUSD_4Y_1min.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_525_days.png
# Found file: _Polygon_BTCUSD_4Y_1min_190_days.png
# Found file: _Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv

# %% [markdown]
# ### __All periods data__
# 'trend': Categorized trend values based on the detected phases:
# - 0: No trend
# - 1: Moderate negative trend
# - 2: Very strong negative trend
# - 3: Moderate positive trend
# - 4: Very strong positive trend

# %% [markdown]
# ## __Train the Model__

# %% [markdown]
# ---
# ### Period 1 (num_layers = 4, lora_r=4)
# + ##### BiGRUWithAttention_LoRA
# + ##### Training and saving in *'Standard_LoRA/Rank_4_Period_1/1st_try'*
# #### __Val Accuracy: 98.36%__
# #### __Val-Class-Acc: {0: '98.54%', 1: '98.09%'}__

# %%
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[0], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

print_class_distribution(y_train, "y_train")
print_class_distribution(y_val, "y_val")
print_class_distribution(y_test, "y_test")
# Out:
# Number_features = 7
# unique_classes = [0 1]
# num_classes = 2
# Class Distribution for 'y_train':       Class 0   Percent:  63.08% || Class 1   Percent:  36.92%
# Class Distribution for 'y_val':         Class 0   Percent:  60.61% || Class 1   Percent:  39.39%
# Class Distribution for 'y_test':        Class 0   Percent:  58.04% || Class 1   Percent:  41.96%

# %%
# ==== Model Hyperparameters ====
input_size = Number_features
hidden_size = 64
output_size = num_classes   # = 2 for Period 1
num_layers = 4
dropout = 0.0
lora_r = 4
num_epochs = 1000
batch_size = 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ==== Paths ====
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))
model_saving_folder = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_1/1st_try"
))
ensure_folder(model_saving_folder)

# ==== Model (no LoRA initialized in Period 1) ====
model = BiGRUWithAttention_LoRA(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    num_layers=num_layers,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

# ==== 判斷是 Period 1 還是 Period 2+ ====
is_period_1 = True  # ⬅️ 你在實驗程式可以明確設定

# ==== Optimizer and Training ====
criterion = nn.CrossEntropyLoss()

if is_period_1:
    optimizer = optim.Adam(model.parameters(), lr=0.0001)  # 訓練所有參數
else:
    model.init_lora()  # Period 2+ 才加
    optimizer = optim.Adam(model.get_trainable_parameters(), lr=0.0001)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

train_lora_baseline(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    scheduler=scheduler,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name='BiGRUWithAttention',
    stop_signal_file=stop_signal_file
)

# ==== Summary ====
print(f"\n✅ Training Complete. Final model: \n{model}")
print(f"unique_classes = {unique_classes}, num_classes = {num_classes}")

# ==== Clean up ====
del X_train, y_train, X_val, y_val, X_test, y_test, Number_features, unique_classes, num_classes
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🚀 'train_lora_baseline' started.
# ✅ Removed existing folder: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try
#
# ✅ Data Overview:
# X_train: torch.Size([3634, 1000, 7]), y_train: torch.Size([3634, 1000])
# X_val: torch.Size([454, 1000, 7]), y_val: torch.Size([454, 1000])
# Epoch 1/2000, Train Loss: 0.680050, Train-Class-Acc: {0: '98.34%', 1: '1.61%'},
# Val Loss: 0.671339, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_1.pth
# Epoch 2/2000, Train Loss: 0.659055, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.671710, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_2.pth
# Epoch 3/2000, Train Loss: 0.658948, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.671231, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_3.pth
# Epoch 4/2000, Train Loss: 0.658847, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.671008, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_4.pth
# Epoch 5/2000, Train Loss: 0.658730, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.672388, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_5.pth
# Epoch 6/2000, Train Loss: 0.658731, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.670203, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 7/2000, Train Loss: 0.658674, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.673508, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 8/2000, Train Loss: 0.658395, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.670917, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 9/2000, Train Loss: 0.658279, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.672330, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 10/2000, Train Loss: 0.657976, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.671352, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 11/2000, Train Loss: 0.657826, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.669336, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 12/2000, Train Loss: 0.657385, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.668832, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 13/2000, Train Loss: 0.656366, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.666827, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 14/2000, Train Loss: 0.653809, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.667417, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 15/2000, Train Loss: 0.646126, Train-Class-Acc: {0: '100.00%', 1: '0.00%'},
# Val Loss: 0.625778, Val Acc: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100
# Epoch 16/2000, Train Loss: 0.633663, Train-Class-Acc: {0: '99.54%', 1: '0.01%'},
# Val Loss: 0.666352, Val Acc: 70.53%, Val-Class-Acc: {0: '99.39%', 1: '26.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_16.pth
# Epoch 17/2000, Train Loss: 0.600832, Train-Class-Acc: {0: '99.87%', 1: '0.76%'},
# Val Loss: 0.550236, Val Acc: 60.74%, Val-Class-Acc: {0: '99.51%', 1: '1.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_17.pth
# Epoch 18/2000, Train Loss: 0.612890, Train-Class-Acc: {0: '96.29%', 1: '5.54%'},
# Val Loss: 0.586637, Val Acc: 61.25%, Val-Class-Acc: {0: '98.91%', 1: '3.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_18.pth
# Epoch 19/2000, Train Loss: 0.561924, Train-Class-Acc: {0: '99.56%', 1: '2.17%'},
# Val Loss: 0.501523, Val Acc: 62.82%, Val-Class-Acc: {0: '99.17%', 1: '6.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_19.pth
# Epoch 20/2000, Train Loss: 0.533040, Train-Class-Acc: {0: '95.59%', 1: '13.81%'},
# Val Loss: 0.870865, Val Acc: 57.54%, Val-Class-Acc: {0: '94.87%', 1: '0.10%'}, LR: 0.000100
# Epoch 21/2000, Train Loss: 0.563568, Train-Class-Acc: {0: '94.07%', 1: '12.52%'},
# Val Loss: 0.458377, Val Acc: 67.25%, Val-Class-Acc: {0: '99.27%', 1: '17.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_21.pth
# Epoch 22/2000, Train Loss: 0.443753, Train-Class-Acc: {0: '99.29%', 1: '25.45%'},
# Val Loss: 0.410644, Val Acc: 73.71%, Val-Class-Acc: {0: '99.38%', 1: '34.22%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_22.pth
# Epoch 23/2000, Train Loss: 0.441419, Train-Class-Acc: {0: '97.98%', 1: '39.63%'},
# Val Loss: 0.415522, Val Acc: 73.43%, Val-Class-Acc: {0: '99.34%', 1: '33.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_23.pth
# Epoch 24/2000, Train Loss: 0.434559, Train-Class-Acc: {0: '95.15%', 1: '44.88%'},
# Val Loss: 0.454509, Val Acc: 82.13%, Val-Class-Acc: {0: '86.32%', 1: '75.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_24.pth
# Epoch 25/2000, Train Loss: 0.408835, Train-Class-Acc: {0: '97.51%', 1: '53.37%'},
# Val Loss: 0.357587, Val Acc: 84.90%, Val-Class-Acc: {0: '98.35%', 1: '64.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_25.pth
# Epoch 26/2000, Train Loss: 0.408297, Train-Class-Acc: {0: '87.21%', 1: '73.35%'},
# Val Loss: 0.305877, Val Acc: 89.45%, Val-Class-Acc: {0: '95.33%', 1: '80.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_26.pth
# Epoch 27/2000, Train Loss: 0.335314, Train-Class-Acc: {0: '88.64%', 1: '80.95%'},
# Val Loss: 0.252826, Val Acc: 90.20%, Val-Class-Acc: {0: '94.94%', 1: '82.91%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_27.pth
# Epoch 28/2000, Train Loss: 0.305269, Train-Class-Acc: {0: '88.60%', 1: '84.55%'},
# Val Loss: 0.232614, Val Acc: 90.73%, Val-Class-Acc: {0: '94.54%', 1: '84.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_28.pth
# Epoch 29/2000, Train Loss: 0.284752, Train-Class-Acc: {0: '89.28%', 1: '85.42%'},
# Val Loss: 0.264412, Val Acc: 88.14%, Val-Class-Acc: {0: '81.51%', 1: '98.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_29.pth
# Epoch 30/2000, Train Loss: 0.259884, Train-Class-Acc: {0: '90.21%', 1: '86.70%'},
# Val Loss: 0.195505, Val Acc: 92.39%, Val-Class-Acc: {0: '93.27%', 1: '91.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_30.pth
# Epoch 31/2000, Train Loss: 0.294221, Train-Class-Acc: {0: '88.18%', 1: '85.68%'},
# Val Loss: 0.206695, Val Acc: 92.01%, Val-Class-Acc: {0: '89.72%', 1: '95.55%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_31.pth
# Epoch 32/2000, Train Loss: 0.241135, Train-Class-Acc: {0: '91.14%', 1: '87.89%'},
# Val Loss: 0.188371, Val Acc: 92.73%, Val-Class-Acc: {0: '94.21%', 1: '90.45%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_32.pth
# Epoch 33/2000, Train Loss: 0.225567, Train-Class-Acc: {0: '91.45%', 1: '89.50%'},
# Val Loss: 0.252777, Val Acc: 89.86%, Val-Class-Acc: {0: '96.30%', 1: '79.95%'}, LR: 0.000100
# Epoch 34/2000, Train Loss: 0.311884, Train-Class-Acc: {0: '88.11%', 1: '85.04%'},
# Val Loss: 0.210268, Val Acc: 91.75%, Val-Class-Acc: {0: '88.59%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_34.pth
# Epoch 35/2000, Train Loss: 0.215747, Train-Class-Acc: {0: '92.47%', 1: '89.31%'},
# Val Loss: 0.174428, Val Acc: 93.06%, Val-Class-Acc: {0: '91.54%', 1: '95.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_35.pth
# Epoch 36/2000, Train Loss: 0.240959, Train-Class-Acc: {0: '90.87%', 1: '88.50%'},
# Val Loss: 0.170688, Val Acc: 93.48%, Val-Class-Acc: {0: '92.98%', 1: '94.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_36.pth
# Epoch 37/2000, Train Loss: 0.201446, Train-Class-Acc: {0: '92.70%', 1: '90.67%'},
# Val Loss: 0.164145, Val Acc: 93.77%, Val-Class-Acc: {0: '95.18%', 1: '91.59%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_37.pth
# Epoch 38/2000, Train Loss: 0.289088, Train-Class-Acc: {0: '89.59%', 1: '86.79%'},
# Val Loss: 0.182259, Val Acc: 92.90%, Val-Class-Acc: {0: '94.83%', 1: '89.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_38.pth
# Epoch 39/2000, Train Loss: 0.194021, Train-Class-Acc: {0: '93.21%', 1: '91.01%'},
# Val Loss: 0.159815, Val Acc: 94.02%, Val-Class-Acc: {0: '95.15%', 1: '92.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_39.pth
# Epoch 40/2000, Train Loss: 0.358175, Train-Class-Acc: {0: '85.71%', 1: '85.86%'},
# Val Loss: 0.200651, Val Acc: 92.01%, Val-Class-Acc: {0: '95.23%', 1: '87.06%'}, LR: 0.000100
# Epoch 41/2000, Train Loss: 0.222273, Train-Class-Acc: {0: '93.02%', 1: '88.07%'},
# Val Loss: 0.169271, Val Acc: 93.85%, Val-Class-Acc: {0: '94.29%', 1: '93.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_41.pth
# Epoch 42/2000, Train Loss: 0.194438, Train-Class-Acc: {0: '93.28%', 1: '90.77%'},
# Val Loss: 0.176054, Val Acc: 92.87%, Val-Class-Acc: {0: '89.72%', 1: '97.72%'}, LR: 0.000100
# Epoch 43/2000, Train Loss: 0.224855, Train-Class-Acc: {0: '91.63%', 1: '89.63%'},
# Val Loss: 0.173882, Val Acc: 92.95%, Val-Class-Acc: {0: '89.95%', 1: '97.55%'}, LR: 0.000100
# Epoch 44/2000, Train Loss: 0.214853, Train-Class-Acc: {0: '92.16%', 1: '89.73%'},
# Val Loss: 0.208802, Val Acc: 91.00%, Val-Class-Acc: {0: '86.05%', 1: '98.63%'}, LR: 0.000100
# Epoch 45/2000, Train Loss: 0.183483, Train-Class-Acc: {0: '93.24%', 1: '91.87%'},
# Val Loss: 0.145314, Val Acc: 94.68%, Val-Class-Acc: {0: '94.49%', 1: '94.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_45.pth
# Epoch 46/2000, Train Loss: 0.190979, Train-Class-Acc: {0: '92.92%', 1: '91.42%'},
# Val Loss: 0.157884, Val Acc: 93.58%, Val-Class-Acc: {0: '91.36%', 1: '97.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_46.pth
# Epoch 47/2000, Train Loss: 0.180177, Train-Class-Acc: {0: '93.32%', 1: '91.84%'},
# Val Loss: 0.158881, Val Acc: 93.85%, Val-Class-Acc: {0: '96.84%', 1: '89.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_47.pth
# Epoch 48/2000, Train Loss: 0.243436, Train-Class-Acc: {0: '91.23%', 1: '89.01%'},
# Val Loss: 0.146297, Val Acc: 94.70%, Val-Class-Acc: {0: '94.43%', 1: '95.11%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_48.pth
# Epoch 49/2000, Train Loss: 0.185905, Train-Class-Acc: {0: '93.18%', 1: '91.59%'},
# Val Loss: 0.162292, Val Acc: 93.68%, Val-Class-Acc: {0: '96.90%', 1: '88.72%'}, LR: 0.000100
# Epoch 50/2000, Train Loss: 0.170574, Train-Class-Acc: {0: '93.80%', 1: '92.38%'},
# Val Loss: 0.142143, Val Acc: 94.73%, Val-Class-Acc: {0: '96.46%', 1: '92.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_50.pth
# Epoch 51/2000, Train Loss: 0.161743, Train-Class-Acc: {0: '94.08%', 1: '92.73%'},
# Val Loss: 0.133357, Val Acc: 94.78%, Val-Class-Acc: {0: '94.24%', 1: '95.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_51.pth
# Epoch 52/2000, Train Loss: 0.198418, Train-Class-Acc: {0: '92.60%', 1: '91.20%'},
# Val Loss: 0.135310, Val Acc: 94.76%, Val-Class-Acc: {0: '93.94%', 1: '96.02%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_52.pth
# Epoch 53/2000, Train Loss: 0.168474, Train-Class-Acc: {0: '93.84%', 1: '92.28%'},
# Val Loss: 0.131456, Val Acc: 95.17%, Val-Class-Acc: {0: '96.07%', 1: '93.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_53.pth
# Epoch 54/2000, Train Loss: 0.238069, Train-Class-Acc: {0: '91.46%', 1: '89.19%'},
# Val Loss: 0.140634, Val Acc: 94.99%, Val-Class-Acc: {0: '96.05%', 1: '93.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_54.pth
# Epoch 55/2000, Train Loss: 0.161268, Train-Class-Acc: {0: '94.20%', 1: '92.72%'},
# Val Loss: 0.133602, Val Acc: 95.18%, Val-Class-Acc: {0: '96.56%', 1: '93.06%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_50.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_55.pth
# Epoch 56/2000, Train Loss: 0.160992, Train-Class-Acc: {0: '94.29%', 1: '92.48%'},
# Val Loss: 0.130491, Val Acc: 94.78%, Val-Class-Acc: {0: '93.79%', 1: '96.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_52.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_56.pth
# Epoch 57/2000, Train Loss: 0.177639, Train-Class-Acc: {0: '93.52%', 1: '91.87%'},
# Val Loss: 0.160476, Val Acc: 93.02%, Val-Class-Acc: {0: '89.66%', 1: '98.19%'}, LR: 0.000100
# Epoch 58/2000, Train Loss: 0.202755, Train-Class-Acc: {0: '92.76%', 1: '90.42%'},
# Val Loss: 0.177791, Val Acc: 91.99%, Val-Class-Acc: {0: '87.69%', 1: '98.61%'}, LR: 0.000100
# Epoch 59/2000, Train Loss: 0.173879, Train-Class-Acc: {0: '93.61%', 1: '92.03%'},
# Val Loss: 0.135054, Val Acc: 94.61%, Val-Class-Acc: {0: '93.16%', 1: '96.83%'}, LR: 0.000100
# Epoch 60/2000, Train Loss: 0.147389, Train-Class-Acc: {0: '94.84%', 1: '93.23%'},
# Val Loss: 0.120998, Val Acc: 95.67%, Val-Class-Acc: {0: '96.13%', 1: '94.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_60.pth
# Epoch 61/2000, Train Loss: 0.204266, Train-Class-Acc: {0: '92.64%', 1: '90.89%'},
# Val Loss: 0.124652, Val Acc: 95.48%, Val-Class-Acc: {0: '96.06%', 1: '94.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_61.pth
# Epoch 62/2000, Train Loss: 0.154421, Train-Class-Acc: {0: '94.62%', 1: '92.76%'},
# Val Loss: 0.121027, Val Acc: 95.74%, Val-Class-Acc: {0: '96.59%', 1: '94.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_54.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_62.pth
# Epoch 63/2000, Train Loss: 0.160754, Train-Class-Acc: {0: '94.37%', 1: '92.50%'},
# Val Loss: 0.143885, Val Acc: 94.54%, Val-Class-Acc: {0: '97.50%', 1: '89.99%'}, LR: 0.000100
# Epoch 64/2000, Train Loss: 0.200088, Train-Class-Acc: {0: '93.17%', 1: '90.81%'},
# Val Loss: 0.172032, Val Acc: 93.15%, Val-Class-Acc: {0: '97.80%', 1: '86.01%'}, LR: 0.000100
# Epoch 65/2000, Train Loss: 0.197859, Train-Class-Acc: {0: '92.86%', 1: '90.56%'},
# Val Loss: 0.128055, Val Acc: 95.66%, Val-Class-Acc: {0: '96.75%', 1: '93.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_65.pth
# Epoch 66/2000, Train Loss: 0.149058, Train-Class-Acc: {0: '95.02%', 1: '92.92%'},
# Val Loss: 0.116699, Val Acc: 95.74%, Val-Class-Acc: {0: '96.36%', 1: '94.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_66.pth
# Epoch 67/2000, Train Loss: 0.136642, Train-Class-Acc: {0: '95.41%', 1: '93.57%'},
# Val Loss: 0.115118, Val Acc: 95.42%, Val-Class-Acc: {0: '94.94%', 1: '96.16%'}, LR: 0.000100
# Epoch 68/2000, Train Loss: 0.136593, Train-Class-Acc: {0: '95.36%', 1: '93.56%'},
# Val Loss: 0.114566, Val Acc: 95.41%, Val-Class-Acc: {0: '94.70%', 1: '96.51%'}, LR: 0.000100
# Epoch 69/2000, Train Loss: 0.166308, Train-Class-Acc: {0: '94.34%', 1: '92.08%'},
# Val Loss: 0.111144, Val Acc: 95.89%, Val-Class-Acc: {0: '96.30%', 1: '95.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_69.pth
# Epoch 70/2000, Train Loss: 0.257769, Train-Class-Acc: {0: '92.90%', 1: '89.40%'},
# Val Loss: 0.811972, Val Acc: 69.65%, Val-Class-Acc: {0: '53.09%', 1: '95.13%'}, LR: 0.000100
# Epoch 71/2000, Train Loss: 0.401235, Train-Class-Acc: {0: '83.42%', 1: '83.89%'},
# Val Loss: 0.168981, Val Acc: 94.21%, Val-Class-Acc: {0: '97.24%', 1: '89.55%'}, LR: 0.000100
# Epoch 72/2000, Train Loss: 0.160179, Train-Class-Acc: {0: '95.56%', 1: '92.21%'},
# Val Loss: 0.118556, Val Acc: 95.93%, Val-Class-Acc: {0: '96.78%', 1: '94.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_65.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_72.pth
# Epoch 73/2000, Train Loss: 0.141659, Train-Class-Acc: {0: '95.66%', 1: '92.92%'},
# Val Loss: 0.108571, Val Acc: 96.04%, Val-Class-Acc: {0: '96.22%', 1: '95.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_60.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_73.pth
# Epoch 74/2000, Train Loss: 0.138072, Train-Class-Acc: {0: '95.45%', 1: '93.30%'},
# Val Loss: 0.117407, Val Acc: 95.61%, Val-Class-Acc: {0: '97.74%', 1: '92.33%'}, LR: 0.000100
# Epoch 75/2000, Train Loss: 0.152661, Train-Class-Acc: {0: '94.90%', 1: '92.50%'},
# Val Loss: 0.128413, Val Acc: 94.99%, Val-Class-Acc: {0: '97.89%', 1: '90.53%'}, LR: 0.000100
# Epoch 76/2000, Train Loss: 0.135651, Train-Class-Acc: {0: '95.64%', 1: '93.40%'},
# Val Loss: 0.115601, Val Acc: 95.82%, Val-Class-Acc: {0: '97.63%', 1: '93.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_76.pth
# Epoch 77/2000, Train Loss: 0.172414, Train-Class-Acc: {0: '94.20%', 1: '91.47%'},
# Val Loss: 0.106985, Val Acc: 96.04%, Val-Class-Acc: {0: '96.44%', 1: '95.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_77.pth
# Epoch 78/2000, Train Loss: 0.152543, Train-Class-Acc: {0: '95.16%', 1: '92.22%'},
# Val Loss: 0.126977, Val Acc: 94.39%, Val-Class-Acc: {0: '92.51%', 1: '97.27%'}, LR: 0.000100
# Epoch 79/2000, Train Loss: 0.169129, Train-Class-Acc: {0: '94.36%', 1: '91.46%'},
# Val Loss: 0.129932, Val Acc: 94.92%, Val-Class-Acc: {0: '97.97%', 1: '90.23%'}, LR: 0.000100
# Epoch 80/2000, Train Loss: 0.149598, Train-Class-Acc: {0: '95.25%', 1: '92.26%'},
# Val Loss: 0.113591, Val Acc: 95.25%, Val-Class-Acc: {0: '94.03%', 1: '97.11%'}, LR: 0.000100
# Epoch 81/2000, Train Loss: 0.132959, Train-Class-Acc: {0: '95.68%', 1: '93.50%'},
# Val Loss: 0.102711, Val Acc: 96.25%, Val-Class-Acc: {0: '97.31%', 1: '94.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_81.pth
# Epoch 82/2000, Train Loss: 0.140742, Train-Class-Acc: {0: '95.44%', 1: '93.04%'},
# Val Loss: 0.129713, Val Acc: 94.79%, Val-Class-Acc: {0: '98.12%', 1: '89.67%'}, LR: 0.000100
# Epoch 83/2000, Train Loss: 0.144681, Train-Class-Acc: {0: '95.42%', 1: '92.54%'},
# Val Loss: 0.100762, Val Acc: 96.37%, Val-Class-Acc: {0: '97.49%', 1: '94.64%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_69.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_83.pth
# Epoch 84/2000, Train Loss: 0.145372, Train-Class-Acc: {0: '95.46%', 1: '92.50%'},
# Val Loss: 0.102045, Val Acc: 96.34%, Val-Class-Acc: {0: '97.59%', 1: '94.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_84.pth
# Epoch 85/2000, Train Loss: 0.129473, Train-Class-Acc: {0: '95.85%', 1: '93.58%'},
# Val Loss: 0.246085, Val Acc: 90.83%, Val-Class-Acc: {0: '98.66%', 1: '78.78%'}, LR: 0.000100
# Epoch 86/2000, Train Loss: 0.216222, Train-Class-Acc: {0: '93.33%', 1: '88.40%'},
# Val Loss: 0.130950, Val Acc: 94.28%, Val-Class-Acc: {0: '92.24%', 1: '97.41%'}, LR: 0.000100
# Epoch 87/2000, Train Loss: 0.135766, Train-Class-Acc: {0: '95.86%', 1: '93.20%'},
# Val Loss: 0.103530, Val Acc: 96.32%, Val-Class-Acc: {0: '97.82%', 1: '94.02%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_73.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_87.pth
# Epoch 88/2000, Train Loss: 0.124396, Train-Class-Acc: {0: '96.20%', 1: '93.60%'},
# Val Loss: 0.098094, Val Acc: 96.43%, Val-Class-Acc: {0: '97.75%', 1: '94.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_77.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_88.pth
# Epoch 89/2000, Train Loss: 0.131450, Train-Class-Acc: {0: '96.02%', 1: '93.06%'},
# Val Loss: 0.106342, Val Acc: 95.24%, Val-Class-Acc: {0: '94.26%', 1: '96.75%'}, LR: 0.000100
# Epoch 90/2000, Train Loss: 0.126944, Train-Class-Acc: {0: '96.05%', 1: '93.54%'},
# Val Loss: 0.111417, Val Acc: 94.95%, Val-Class-Acc: {0: '93.53%', 1: '97.14%'}, LR: 0.000100
# Epoch 91/2000, Train Loss: 0.149931, Train-Class-Acc: {0: '95.22%', 1: '92.19%'},
# Val Loss: 0.100874, Val Acc: 95.78%, Val-Class-Acc: {0: '95.20%', 1: '96.67%'}, LR: 0.000100
# Epoch 92/2000, Train Loss: 0.156683, Train-Class-Acc: {0: '95.50%', 1: '91.79%'},
# Val Loss: 0.096395, Val Acc: 96.28%, Val-Class-Acc: {0: '96.30%', 1: '96.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_92.pth
# Epoch 93/2000, Train Loss: 0.131538, Train-Class-Acc: {0: '96.05%', 1: '93.11%'},
# Val Loss: 0.096656, Val Acc: 96.36%, Val-Class-Acc: {0: '97.94%', 1: '93.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_92.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_93.pth
# Epoch 94/2000, Train Loss: 0.118717, Train-Class-Acc: {0: '96.37%', 1: '93.87%'},
# Val Loss: 0.092751, Val Acc: 96.18%, Val-Class-Acc: {0: '96.13%', 1: '96.27%'}, LR: 0.000100
# Epoch 95/2000, Train Loss: 0.130331, Train-Class-Acc: {0: '96.07%', 1: '93.04%'},
# Val Loss: 0.094202, Val Acc: 96.47%, Val-Class-Acc: {0: '97.92%', 1: '94.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_87.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_95.pth
# Epoch 96/2000, Train Loss: 0.116074, Train-Class-Acc: {0: '96.49%', 1: '93.95%'},
# Val Loss: 0.101063, Val Acc: 95.62%, Val-Class-Acc: {0: '94.57%', 1: '97.24%'}, LR: 0.000100
# Epoch 97/2000, Train Loss: 0.118186, Train-Class-Acc: {0: '96.39%', 1: '93.93%'},
# Val Loss: 0.095466, Val Acc: 95.94%, Val-Class-Acc: {0: '95.29%', 1: '96.95%'}, LR: 0.000100
# Epoch 98/2000, Train Loss: 0.218549, Train-Class-Acc: {0: '93.70%', 1: '88.53%'},
# Val Loss: 0.108935, Val Acc: 96.01%, Val-Class-Acc: {0: '95.43%', 1: '96.92%'}, LR: 0.000100
# Epoch 99/2000, Train Loss: 0.128923, Train-Class-Acc: {0: '96.27%', 1: '93.23%'},
# Val Loss: 0.096657, Val Acc: 96.47%, Val-Class-Acc: {0: '98.04%', 1: '94.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_84.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_99.pth
# Epoch 100/2000, Train Loss: 0.124315, Train-Class-Acc: {0: '96.31%', 1: '93.28%'},
# Val Loss: 0.086776, Val Acc: 96.87%, Val-Class-Acc: {0: '97.56%', 1: '95.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_93.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_100.pth
# Epoch 101/2000, Train Loss: 0.116193, Train-Class-Acc: {0: '96.55%', 1: '93.80%'},
# Val Loss: 0.086443, Val Acc: 96.82%, Val-Class-Acc: {0: '97.95%', 1: '95.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_101.pth
# Epoch 102/2000, Train Loss: 0.161580, Train-Class-Acc: {0: '95.46%', 1: '90.89%'},
# Val Loss: 0.108144, Val Acc: 95.84%, Val-Class-Acc: {0: '98.41%', 1: '91.89%'}, LR: 0.000100
# Epoch 103/2000, Train Loss: 0.140677, Train-Class-Acc: {0: '95.74%', 1: '92.32%'},
# Val Loss: 0.091616, Val Acc: 96.67%, Val-Class-Acc: {0: '98.26%', 1: '94.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_88.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_103.pth
# Epoch 104/2000, Train Loss: 0.123465, Train-Class-Acc: {0: '96.40%', 1: '93.33%'},
# Val Loss: 0.106095, Val Acc: 95.74%, Val-Class-Acc: {0: '98.54%', 1: '91.43%'}, LR: 0.000100
# Epoch 105/2000, Train Loss: 0.117330, Train-Class-Acc: {0: '96.55%', 1: '93.69%'},
# Val Loss: 0.084348, Val Acc: 96.76%, Val-Class-Acc: {0: '97.21%', 1: '96.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_95.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_105.pth
# Epoch 106/2000, Train Loss: 0.115466, Train-Class-Acc: {0: '96.54%', 1: '93.80%'},
# Val Loss: 0.114541, Val Acc: 95.06%, Val-Class-Acc: {0: '93.11%', 1: '98.07%'}, LR: 0.000100
# Epoch 107/2000, Train Loss: 0.119445, Train-Class-Acc: {0: '96.44%', 1: '93.68%'},
# Val Loss: 0.085489, Val Acc: 96.67%, Val-Class-Acc: {0: '96.60%', 1: '96.78%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_99.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_107.pth
# Epoch 108/2000, Train Loss: 0.118685, Train-Class-Acc: {0: '96.45%', 1: '93.59%'},
# Val Loss: 0.119292, Val Acc: 95.13%, Val-Class-Acc: {0: '98.78%', 1: '89.50%'}, LR: 0.000100
# Epoch 109/2000, Train Loss: 0.120685, Train-Class-Acc: {0: '96.47%', 1: '93.41%'},
# Val Loss: 0.081841, Val Acc: 97.05%, Val-Class-Acc: {0: '97.65%', 1: '96.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_107.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_109.pth
# Epoch 110/2000, Train Loss: 0.123911, Train-Class-Acc: {0: '96.28%', 1: '93.14%'},
# Val Loss: 0.095574, Val Acc: 95.88%, Val-Class-Acc: {0: '95.08%', 1: '97.11%'}, LR: 0.000100
# Epoch 111/2000, Train Loss: 0.113842, Train-Class-Acc: {0: '96.52%', 1: '93.92%'},
# Val Loss: 0.200894, Val Acc: 92.20%, Val-Class-Acc: {0: '98.89%', 1: '81.91%'}, LR: 0.000100
# Epoch 112/2000, Train Loss: 0.129777, Train-Class-Acc: {0: '96.26%', 1: '92.76%'},
# Val Loss: 0.083100, Val Acc: 97.01%, Val-Class-Acc: {0: '97.88%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_103.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_112.pth
# Epoch 113/2000, Train Loss: 0.111944, Train-Class-Acc: {0: '96.60%', 1: '93.98%'},
# Val Loss: 0.094984, Val Acc: 96.34%, Val-Class-Acc: {0: '98.50%', 1: '93.01%'}, LR: 0.000100
# Epoch 114/2000, Train Loss: 0.115865, Train-Class-Acc: {0: '96.61%', 1: '93.60%'},
# Val Loss: 0.180087, Val Acc: 92.76%, Val-Class-Acc: {0: '98.93%', 1: '83.25%'}, LR: 0.000100
# Epoch 115/2000, Train Loss: 0.152295, Train-Class-Acc: {0: '95.83%', 1: '91.46%'},
# Val Loss: 0.083123, Val Acc: 96.88%, Val-Class-Acc: {0: '97.29%', 1: '96.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_105.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_115.pth
# Epoch 116/2000, Train Loss: 0.110988, Train-Class-Acc: {0: '96.74%', 1: '93.76%'},
# Val Loss: 0.083417, Val Acc: 96.89%, Val-Class-Acc: {0: '98.38%', 1: '94.59%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_101.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_116.pth
# Epoch 117/2000, Train Loss: 0.143778, Train-Class-Acc: {0: '95.89%', 1: '92.30%'},
# Val Loss: 0.154677, Val Acc: 93.41%, Val-Class-Acc: {0: '98.89%', 1: '84.97%'}, LR: 0.000100
# Epoch 118/2000, Train Loss: 0.172784, Train-Class-Acc: {0: '95.50%', 1: '89.01%'},
# Val Loss: 0.094625, Val Acc: 96.24%, Val-Class-Acc: {0: '95.29%', 1: '97.70%'}, LR: 0.000100
# Epoch 119/2000, Train Loss: 0.111772, Train-Class-Acc: {0: '96.76%', 1: '93.90%'},
# Val Loss: 0.079915, Val Acc: 97.10%, Val-Class-Acc: {0: '97.79%', 1: '96.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_100.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_119.pth
# Epoch 120/2000, Train Loss: 0.097679, Train-Class-Acc: {0: '97.12%', 1: '94.85%'},
# Val Loss: 0.082908, Val Acc: 96.92%, Val-Class-Acc: {0: '98.57%', 1: '94.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_115.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_120.pth
# Epoch 121/2000, Train Loss: 0.104514, Train-Class-Acc: {0: '96.92%', 1: '94.14%'},
# Val Loss: 0.081113, Val Acc: 96.80%, Val-Class-Acc: {0: '96.76%', 1: '96.85%'}, LR: 0.000100
# Epoch 122/2000, Train Loss: 0.114961, Train-Class-Acc: {0: '96.63%', 1: '93.53%'},
# Val Loss: 0.080308, Val Acc: 96.96%, Val-Class-Acc: {0: '96.86%', 1: '97.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_116.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_122.pth
# Epoch 123/2000, Train Loss: 0.110067, Train-Class-Acc: {0: '96.66%', 1: '94.03%'},
# Val Loss: 0.083757, Val Acc: 96.61%, Val-Class-Acc: {0: '96.29%', 1: '97.11%'}, LR: 0.000100
# Epoch 124/2000, Train Loss: 0.095358, Train-Class-Acc: {0: '97.18%', 1: '94.73%'},
# Val Loss: 0.079366, Val Acc: 96.90%, Val-Class-Acc: {0: '97.08%', 1: '96.62%'}, LR: 0.000100
# Epoch 125/2000, Train Loss: 0.160466, Train-Class-Acc: {0: '95.49%', 1: '90.67%'},
# Val Loss: 0.089848, Val Acc: 96.82%, Val-Class-Acc: {0: '98.36%', 1: '94.45%'}, LR: 0.000100
# Epoch 126/2000, Train Loss: 0.102431, Train-Class-Acc: {0: '97.08%', 1: '94.41%'},
# Val Loss: 0.087003, Val Acc: 96.42%, Val-Class-Acc: {0: '95.89%', 1: '97.22%'}, LR: 0.000100
# Epoch 127/2000, Train Loss: 0.108635, Train-Class-Acc: {0: '96.74%', 1: '93.98%'},
# Val Loss: 0.077951, Val Acc: 97.09%, Val-Class-Acc: {0: '97.30%', 1: '96.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_120.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_127.pth
# Epoch 128/2000, Train Loss: 0.099631, Train-Class-Acc: {0: '97.09%', 1: '94.41%'},
# Val Loss: 0.078466, Val Acc: 97.03%, Val-Class-Acc: {0: '97.16%', 1: '96.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_122.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_128.pth
# Epoch 129/2000, Train Loss: 0.127927, Train-Class-Acc: {0: '96.32%', 1: '92.76%'},
# Val Loss: 0.101726, Val Acc: 95.55%, Val-Class-Acc: {0: '94.07%', 1: '97.83%'}, LR: 0.000100
# Epoch 130/2000, Train Loss: 0.095128, Train-Class-Acc: {0: '97.21%', 1: '94.94%'},
# Val Loss: 0.079589, Val Acc: 96.82%, Val-Class-Acc: {0: '96.71%', 1: '96.99%'}, LR: 0.000100
# Epoch 131/2000, Train Loss: 0.128806, Train-Class-Acc: {0: '96.35%', 1: '92.82%'},
# Val Loss: 0.084164, Val Acc: 97.06%, Val-Class-Acc: {0: '98.15%', 1: '95.39%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_112.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_131.pth
# Epoch 132/2000, Train Loss: 0.123128, Train-Class-Acc: {0: '96.52%', 1: '92.62%'},
# Val Loss: 0.107747, Val Acc: 95.83%, Val-Class-Acc: {0: '98.74%', 1: '91.35%'}, LR: 0.000100
# Epoch 133/2000, Train Loss: 0.103093, Train-Class-Acc: {0: '97.02%', 1: '94.18%'},
# Val Loss: 0.076286, Val Acc: 97.10%, Val-Class-Acc: {0: '97.43%', 1: '96.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_128.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_133.pth
# Epoch 134/2000, Train Loss: 0.097103, Train-Class-Acc: {0: '97.16%', 1: '94.53%'},
# Val Loss: 0.088903, Val Acc: 96.86%, Val-Class-Acc: {0: '98.34%', 1: '94.60%'}, LR: 0.000100
# Epoch 135/2000, Train Loss: 0.101915, Train-Class-Acc: {0: '96.96%', 1: '94.21%'},
# Val Loss: 0.077334, Val Acc: 97.13%, Val-Class-Acc: {0: '97.99%', 1: '95.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_109.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_135.pth
# Epoch 136/2000, Train Loss: 0.095708, Train-Class-Acc: {0: '97.15%', 1: '94.68%'},
# Val Loss: 0.076891, Val Acc: 97.21%, Val-Class-Acc: {0: '97.94%', 1: '96.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_131.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_136.pth
# Epoch 137/2000, Train Loss: 0.118912, Train-Class-Acc: {0: '96.53%', 1: '92.93%'},
# Val Loss: 0.099888, Val Acc: 95.64%, Val-Class-Acc: {0: '93.99%', 1: '98.19%'}, LR: 0.000100
# Epoch 138/2000, Train Loss: 0.102732, Train-Class-Acc: {0: '96.85%', 1: '94.14%'},
# Val Loss: 0.078416, Val Acc: 97.16%, Val-Class-Acc: {0: '98.20%', 1: '95.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_127.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_138.pth
# Epoch 139/2000, Train Loss: 0.123475, Train-Class-Acc: {0: '96.44%', 1: '92.52%'},
# Val Loss: 0.082572, Val Acc: 97.14%, Val-Class-Acc: {0: '98.29%', 1: '95.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_133.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_139.pth
# Epoch 140/2000, Train Loss: 0.095474, Train-Class-Acc: {0: '97.29%', 1: '94.63%'},
# Val Loss: 0.076675, Val Acc: 97.15%, Val-Class-Acc: {0: '97.12%', 1: '97.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_119.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_140.pth
# Epoch 141/2000, Train Loss: 0.093857, Train-Class-Acc: {0: '97.28%', 1: '94.70%'},
# Val Loss: 0.076374, Val Acc: 97.16%, Val-Class-Acc: {0: '97.25%', 1: '97.01%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_135.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_141.pth
# Epoch 142/2000, Train Loss: 0.109409, Train-Class-Acc: {0: '96.84%', 1: '93.90%'},
# Val Loss: 0.094378, Val Acc: 95.93%, Val-Class-Acc: {0: '94.56%', 1: '98.04%'}, LR: 0.000100
# Epoch 143/2000, Train Loss: 0.099509, Train-Class-Acc: {0: '97.02%', 1: '94.34%'},
# Val Loss: 0.078453, Val Acc: 97.26%, Val-Class-Acc: {0: '98.11%', 1: '95.97%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_139.pth
# ...
# Val Loss: 0.071057, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1275/2000, Train Loss: 0.016862, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071014, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1276/2000, Train Loss: 0.016889, Train-Class-Acc: {0: '99.49%', 1: '99.13%'},
# Val Loss: 0.071510, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1277/2000, Train Loss: 0.016881, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071815, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.59%'}, LR: 0.000000
# Epoch 1278/2000, Train Loss: 0.016854, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071005, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1279/2000, Train Loss: 0.016856, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071711, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.62%'}, LR: 0.000000
# Epoch 1280/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071270, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1281/2000, Train Loss: 0.016866, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071473, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1282/2000, Train Loss: 0.016875, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071490, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1283/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.072121, Val Acc: 98.26%, Val-Class-Acc: {0: '98.71%', 1: '97.58%'}, LR: 0.000000
# Epoch 1284/2000, Train Loss: 0.016861, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071093, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1285/2000, Train Loss: 0.016858, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071472, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1286/2000, Train Loss: 0.016872, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071802, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.59%'}, LR: 0.000000
# Epoch 1287/2000, Train Loss: 0.016852, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.070870, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.66%'}, LR: 0.000000
# Epoch 1288/2000, Train Loss: 0.016860, Train-Class-Acc: {0: '99.49%', 1: '99.14%'},
# Val Loss: 0.072027, Val Acc: 98.26%, Val-Class-Acc: {0: '98.71%', 1: '97.58%'}, LR: 0.000000
# Epoch 1289/2000, Train Loss: 0.016857, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071785, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.61%'}, LR: 0.000000
# Epoch 1290/2000, Train Loss: 0.016872, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.070913, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.66%'}, LR: 0.000000
# Epoch 1291/2000, Train Loss: 0.016866, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.070731, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.66%'}, LR: 0.000000
# Epoch 1292/2000, Train Loss: 0.016855, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071431, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1293/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071472, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1294/2000, Train Loss: 0.016847, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071819, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.61%'}, LR: 0.000000
# Epoch 1295/2000, Train Loss: 0.016855, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071034, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1296/2000, Train Loss: 0.016862, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.070928, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.65%'}, LR: 0.000000
# Epoch 1297/2000, Train Loss: 0.016848, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071495, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1298/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071252, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1299/2000, Train Loss: 0.016853, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071760, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.62%'}, LR: 0.000000
# Epoch 1300/2000, Train Loss: 0.016867, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071733, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.62%'}, LR: 0.000000
# Epoch 1301/2000, Train Loss: 0.016862, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071608, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1302/2000, Train Loss: 0.016857, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071163, Val Acc: 98.28%, Val-Class-Acc: {0: '98.69%', 1: '97.64%'}, LR: 0.000000
# Epoch 1303/2000, Train Loss: 0.016853, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.070538, Val Acc: 98.30%, Val-Class-Acc: {0: '98.70%', 1: '97.69%'}, LR: 0.000000
# Epoch 1304/2000, Train Loss: 0.016853, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071366, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1305/2000, Train Loss: 0.016843, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071010, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1306/2000, Train Loss: 0.016855, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.072019, Val Acc: 98.26%, Val-Class-Acc: {0: '98.71%', 1: '97.58%'}, LR: 0.000000
# Epoch 1307/2000, Train Loss: 0.016860, Train-Class-Acc: {0: '99.51%', 1: '99.10%'},
# Val Loss: 0.071101, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1308/2000, Train Loss: 0.016879, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071515, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1309/2000, Train Loss: 0.016870, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071203, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1310/2000, Train Loss: 0.016852, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.070540, Val Acc: 98.30%, Val-Class-Acc: {0: '98.70%', 1: '97.69%'}, LR: 0.000000
# Epoch 1311/2000, Train Loss: 0.016893, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071186, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1312/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.070783, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.66%'}, LR: 0.000000
# Epoch 1313/2000, Train Loss: 0.016846, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071393, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1314/2000, Train Loss: 0.016849, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071800, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.60%'}, LR: 0.000000
# Epoch 1315/2000, Train Loss: 0.016863, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071452, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1316/2000, Train Loss: 0.016848, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071618, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1317/2000, Train Loss: 0.016845, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071870, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.59%'}, LR: 0.000000
# Epoch 1318/2000, Train Loss: 0.016868, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071619, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1319/2000, Train Loss: 0.016866, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071582, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1320/2000, Train Loss: 0.016842, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071562, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1321/2000, Train Loss: 0.016839, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071308, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1322/2000, Train Loss: 0.016854, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071792, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.61%'}, LR: 0.000000
# Epoch 1323/2000, Train Loss: 0.016844, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.070903, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.66%'}, LR: 0.000000
# Epoch 1324/2000, Train Loss: 0.016852, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071323, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1325/2000, Train Loss: 0.016859, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071316, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1326/2000, Train Loss: 0.016839, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071062, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1327/2000, Train Loss: 0.016889, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071196, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1328/2000, Train Loss: 0.016845, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071113, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1329/2000, Train Loss: 0.016844, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071890, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.59%'}, LR: 0.000000
# Epoch 1330/2000, Train Loss: 0.016847, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071017, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.65%'}, LR: 0.000000
# Epoch 1331/2000, Train Loss: 0.016840, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071951, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.59%'}, LR: 0.000000
# Epoch 1332/2000, Train Loss: 0.016845, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071234, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1333/2000, Train Loss: 0.016865, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071104, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1334/2000, Train Loss: 0.016846, Train-Class-Acc: {0: '99.49%', 1: '99.14%'},
# Val Loss: 0.071774, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.62%'}, LR: 0.000000
# Epoch 1335/2000, Train Loss: 0.016868, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071040, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1336/2000, Train Loss: 0.016834, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071594, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1337/2000, Train Loss: 0.016853, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.070956, Val Acc: 98.29%, Val-Class-Acc: {0: '98.70%', 1: '97.65%'}, LR: 0.000000
# Epoch 1338/2000, Train Loss: 0.016844, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.070968, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.65%'}, LR: 0.000000
# Epoch 1339/2000, Train Loss: 0.016840, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.072124, Val Acc: 98.26%, Val-Class-Acc: {0: '98.71%', 1: '97.58%'}, LR: 0.000000
# Epoch 1340/2000, Train Loss: 0.016836, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.070567, Val Acc: 98.30%, Val-Class-Acc: {0: '98.70%', 1: '97.69%'}, LR: 0.000000
# Epoch 1341/2000, Train Loss: 0.016871, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071163, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1342/2000, Train Loss: 0.016848, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071694, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.62%'}, LR: 0.000000
# Epoch 1343/2000, Train Loss: 0.016833, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071296, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1344/2000, Train Loss: 0.016850, Train-Class-Acc: {0: '99.50%', 1: '99.12%'},
# Val Loss: 0.071158, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1345/2000, Train Loss: 0.016846, Train-Class-Acc: {0: '99.51%', 1: '99.11%'},
# Val Loss: 0.071577, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1346/2000, Train Loss: 0.016834, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071319, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.63%'}, LR: 0.000000
# Epoch 1347/2000, Train Loss: 0.016828, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.071256, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1348/2000, Train Loss: 0.016834, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071834, Val Acc: 98.27%, Val-Class-Acc: {0: '98.70%', 1: '97.61%'}, LR: 0.000000
# Epoch 1349/2000, Train Loss: 0.016834, Train-Class-Acc: {0: '99.51%', 1: '99.12%'},
# Val Loss: 0.070982, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.65%'}, LR: 0.000000
# Epoch 1350/2000, Train Loss: 0.016842, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071069, Val Acc: 98.28%, Val-Class-Acc: {0: '98.70%', 1: '97.64%'}, LR: 0.000000
# Epoch 1351/2000, Train Loss: 0.016864, Train-Class-Acc: {0: '99.50%', 1: '99.13%'},
# Val Loss: 0.071997, Val Acc: 98.26%, Val-Class-Acc: {0: '98.71%', 1: '97.58%'}, LR: 0.000000
#
# 🛑 Stop signal detected. Exiting training loop.
#
# 🏆 Best model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_best.pth (Val Accuracy: 98.36%)
#
# 📌 Final model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 559, Train Loss: 0.021934, Train-Acc: {0: '99.32%', 1: '98.77%'},
# Val Loss: 0.063427, Val Acc: 98.36%, Val-Acc: {0: '98.54%', 1: '98.09%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_559.pth
# Epoch 480, Train Loss: 0.021243, Train-Acc: {0: '99.37%', 1: '98.85%'},
# Val Loss: 0.060799, Val Acc: 98.36%, Val-Acc: {0: '98.58%', 1: '98.03%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_480.pth
# Epoch 590, Train Loss: 0.019052, Train-Acc: {0: '99.44%', 1: '98.98%'},
# Val Loss: 0.064551, Val Acc: 98.35%, Val-Acc: {0: '98.62%', 1: '97.93%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_590.pth
# Epoch 360, Train Loss: 0.049394, Train-Acc: {0: '98.57%', 1: '97.11%'},
# Val Loss: 0.051781, Val Acc: 98.35%, Val-Acc: {0: '98.43%', 1: '98.23%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_360.pth
# Epoch 381, Train Loss: 0.027973, Train-Acc: {0: '99.20%', 1: '98.38%'},
# Val Loss: 0.054268, Val Acc: 98.35%, Val-Acc: {0: '98.40%', 1: '98.27%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_1\1st_try\BiGRUWithAttention_epoch_381.pth
#
# ✅ Training Complete. Final model:
# BiGRUWithAttention_LoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
# unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ---
# ### Period 2 (num_layers = 4, lora_r=4)
# + ##### BiGRUWithAttention_LoRA
# + ##### Training and saving in *'Standard_LoRA/Rank_4_Period_2/1st_try'*
# #### __Val Accuracy: 96.43%__
# #### __Val-Class-Acc: {0: '98.93%', 1: '95.63%', 2: '87.04%'}__

# %%
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[1],  # Period 2
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2}
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

print_class_distribution(y_train, "y_train")
print_class_distribution(y_val, "y_val")
print_class_distribution(y_test, "y_test")
# Out:
# Number_features = 7
# unique_classes = [0 1 2]
# num_classes = 3
# Class Distribution for 'y_train':       Class 0   Percent:  53.41% || Class 1   Percent:  36.03% || Class 2   Percent:  10.55%
# Class Distribution for 'y_val':         Class 0   Percent:  52.72% || Class 1   Percent:  36.38% || Class 2   Percent:  10.90%
# Class Distribution for 'y_test':        Class 0   Percent:  49.11% || Class 1   Percent:  32.27% || Class 2   Percent:  18.62%

# %%
# ==== Model Hyperparameters ====
input_size = Number_features
hidden_size = 64
output_size = num_classes
num_layers = 4
dropout = 0.0
lora_r = 4
num_epochs = 1000
batch_size = 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ==== Paths ====
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))
model_saving_folder = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_2/1st_try"
))
ensure_folder(model_saving_folder)

# ==== Load previous model (Period 1) ====
previous_model_path = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_1/1st_try", "BiGRUWithAttention_best.pth"
))
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# ==== Initialize new model ====
model = BiGRUWithAttention_LoRA(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    num_layers=num_layers,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

# ==== Load GRU & attention_fc (excluding FC and LoRA) ====
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc.") and not k.startswith("lora_adapter.")
}, strict=False)

# ==== Initialize LoRA for the first time ====
model.init_lora()

# ==== Check if previous model had LoRA weights ====
has_lora = any(k.startswith("lora_adapter.") for k in previous_state_dict.keys())
if has_lora:
    model.lora_adapter.load_state_dict({
        k.replace("lora_adapter.", ""): v
        for k, v in previous_state_dict.items() if k.startswith("lora_adapter.")
    })
    print("✅ LoRA weights loaded from previous model.")
else:
    print("⚠️ Previous model has no LoRA. Using newly initialized LoRA.")

# ==== Training Setup ====
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.get_trainable_parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

train_lora_baseline(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    scheduler=scheduler,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name='BiGRUWithAttention',
    stop_signal_file=stop_signal_file
)

# ==== Summary ====
print(f"\n✅ Training Complete. Final model: \n{model}")
print(f"unique_classes = {unique_classes}, num_classes = {num_classes}")

# ==== Clean up ====
del X_train, y_train, X_val, y_val, X_test, y_test, Number_features, unique_classes, num_classes
gc.collect()
torch.cuda.empty_cache()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_169508\24227835.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# Initialized LoRA adapter
# ⚠️ Previous model has no LoRA. Using newly initialized LoRA.
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc.weight
#   ✅ fc.bias
#
# 🚀 'train_lora_baseline' started.
# ✅ Removed existing folder: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try
#
# ✅ Data Overview:
# X_train: torch.Size([3634, 1000, 7]), y_train: torch.Size([3634, 1000])
# X_val: torch.Size([454, 1000, 7]), y_val: torch.Size([454, 1000])
# Epoch 1/1000, Train Loss: 1.545942, Train-Class-Acc: {0: '23.23%', 1: '18.26%', 2: '24.33%'},
# Val Loss: 1.133397, Val Acc: 34.64%, Val-Class-Acc: {0: '46.37%', 1: '23.99%', 2: '13.46%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.888692, Train-Class-Acc: {0: '80.58%', 1: '37.86%', 2: '13.03%'},
# Val Loss: 0.756252, Val Acc: 68.48%, Val-Class-Acc: {0: '89.47%', 1: '56.17%', 2: '8.10%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.654603, Train-Class-Acc: {0: '91.16%', 1: '72.40%', 2: '9.03%'},
# Val Loss: 0.601206, Val Acc: 78.02%, Val-Class-Acc: {0: '92.83%', 1: '77.87%', 2: '6.91%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.536440, Train-Class-Acc: {0: '93.34%', 1: '85.55%', 2: '11.85%'},
# Val Loss: 0.503030, Val Acc: 83.27%, Val-Class-Acc: {0: '95.22%', 1: '86.97%', 2: '13.15%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.456702, Train-Class-Acc: {0: '94.94%', 1: '91.48%', 2: '22.27%'},
# Val Loss: 0.432606, Val Acc: 87.78%, Val-Class-Acc: {0: '96.55%', 1: '91.81%', 2: '31.91%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.398117, Train-Class-Acc: {0: '95.86%', 1: '93.93%', 2: '33.74%'},
# Val Loss: 0.379623, Val Acc: 90.08%, Val-Class-Acc: {0: '97.28%', 1: '93.67%', 2: '43.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.353348, Train-Class-Acc: {0: '96.39%', 1: '94.81%', 2: '42.59%'},
# Val Loss: 0.338671, Val Acc: 91.05%, Val-Class-Acc: {0: '97.64%', 1: '93.90%', 2: '49.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.318118, Train-Class-Acc: {0: '96.72%', 1: '95.20%', 2: '49.53%'},
# Val Loss: 0.306394, Val Acc: 91.93%, Val-Class-Acc: {0: '97.96%', 1: '94.09%', 2: '55.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.289779, Train-Class-Acc: {0: '96.97%', 1: '95.27%', 2: '55.85%'},
# Val Loss: 0.280296, Val Acc: 92.67%, Val-Class-Acc: {0: '98.16%', 1: '94.05%', 2: '61.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.266517, Train-Class-Acc: {0: '97.17%', 1: '95.31%', 2: '60.88%'},
# Val Loss: 0.258990, Val Acc: 93.32%, Val-Class-Acc: {0: '98.40%', 1: '94.13%', 2: '66.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.247155, Train-Class-Acc: {0: '97.31%', 1: '95.36%', 2: '64.92%'},
# Val Loss: 0.241307, Val Acc: 93.83%, Val-Class-Acc: {0: '98.52%', 1: '94.05%', 2: '70.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.230840, Train-Class-Acc: {0: '97.46%', 1: '95.36%', 2: '68.44%'},
# Val Loss: 0.226469, Val Acc: 94.11%, Val-Class-Acc: {0: '98.59%', 1: '94.04%', 2: '72.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.216968, Train-Class-Acc: {0: '97.59%', 1: '95.33%', 2: '71.16%'},
# Val Loss: 0.213887, Val Acc: 94.38%, Val-Class-Acc: {0: '98.65%', 1: '94.10%', 2: '74.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.205054, Train-Class-Acc: {0: '97.70%', 1: '95.33%', 2: '73.23%'},
# Val Loss: 0.203178, Val Acc: 94.52%, Val-Class-Acc: {0: '98.68%', 1: '94.11%', 2: '75.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.194762, Train-Class-Acc: {0: '97.78%', 1: '95.33%', 2: '75.04%'},
# Val Loss: 0.193981, Val Acc: 94.73%, Val-Class-Acc: {0: '98.72%', 1: '94.20%', 2: '77.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.185807, Train-Class-Acc: {0: '97.85%', 1: '95.32%', 2: '76.58%'},
# Val Loss: 0.186020, Val Acc: 94.85%, Val-Class-Acc: {0: '98.77%', 1: '94.28%', 2: '77.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.177969, Train-Class-Acc: {0: '97.91%', 1: '95.34%', 2: '77.75%'},
# Val Loss: 0.179084, Val Acc: 94.98%, Val-Class-Acc: {0: '98.82%', 1: '94.35%', 2: '78.51%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.171066, Train-Class-Acc: {0: '97.97%', 1: '95.34%', 2: '78.58%'},
# Val Loss: 0.173016, Val Acc: 95.06%, Val-Class-Acc: {0: '98.86%', 1: '94.39%', 2: '78.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.164962, Train-Class-Acc: {0: '98.03%', 1: '95.32%', 2: '79.42%'},
# Val Loss: 0.167669, Val Acc: 95.14%, Val-Class-Acc: {0: '98.88%', 1: '94.49%', 2: '79.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.159521, Train-Class-Acc: {0: '98.06%', 1: '95.37%', 2: '79.92%'},
# Val Loss: 0.162919, Val Acc: 95.22%, Val-Class-Acc: {0: '98.88%', 1: '94.59%', 2: '79.59%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.154659, Train-Class-Acc: {0: '98.10%', 1: '95.38%', 2: '80.60%'},
# Val Loss: 0.158708, Val Acc: 95.28%, Val-Class-Acc: {0: '98.92%', 1: '94.62%', 2: '79.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.150296, Train-Class-Acc: {0: '98.12%', 1: '95.39%', 2: '81.16%'},
# Val Loss: 0.154944, Val Acc: 95.34%, Val-Class-Acc: {0: '98.93%', 1: '94.66%', 2: '80.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.146370, Train-Class-Acc: {0: '98.16%', 1: '95.40%', 2: '81.65%'},
# Val Loss: 0.151561, Val Acc: 95.40%, Val-Class-Acc: {0: '98.94%', 1: '94.73%', 2: '80.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.142815, Train-Class-Acc: {0: '98.19%', 1: '95.44%', 2: '82.03%'},
# Val Loss: 0.148508, Val Acc: 95.47%, Val-Class-Acc: {0: '98.94%', 1: '94.80%', 2: '80.91%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.139595, Train-Class-Acc: {0: '98.23%', 1: '95.44%', 2: '82.48%'},
# Val Loss: 0.145720, Val Acc: 95.53%, Val-Class-Acc: {0: '98.95%', 1: '94.84%', 2: '81.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.136644, Train-Class-Acc: {0: '98.25%', 1: '95.50%', 2: '82.69%'},
# Val Loss: 0.143202, Val Acc: 95.55%, Val-Class-Acc: {0: '98.94%', 1: '94.90%', 2: '81.39%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.133955, Train-Class-Acc: {0: '98.27%', 1: '95.53%', 2: '83.06%'},
# Val Loss: 0.140899, Val Acc: 95.59%, Val-Class-Acc: {0: '98.95%', 1: '94.92%', 2: '81.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.131489, Train-Class-Acc: {0: '98.30%', 1: '95.53%', 2: '83.49%'},
# Val Loss: 0.138784, Val Acc: 95.64%, Val-Class-Acc: {0: '98.96%', 1: '94.97%', 2: '81.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.129219, Train-Class-Acc: {0: '98.32%', 1: '95.53%', 2: '83.97%'},
# Val Loss: 0.136817, Val Acc: 95.67%, Val-Class-Acc: {0: '98.95%', 1: '95.03%', 2: '81.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.127115, Train-Class-Acc: {0: '98.31%', 1: '95.58%', 2: '84.12%'},
# Val Loss: 0.135014, Val Acc: 95.71%, Val-Class-Acc: {0: '98.95%', 1: '95.05%', 2: '82.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.125172, Train-Class-Acc: {0: '98.34%', 1: '95.58%', 2: '84.35%'},
# Val Loss: 0.133339, Val Acc: 95.77%, Val-Class-Acc: {0: '98.96%', 1: '95.10%', 2: '82.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.123357, Train-Class-Acc: {0: '98.36%', 1: '95.57%', 2: '84.73%'},
# Val Loss: 0.131748, Val Acc: 95.79%, Val-Class-Acc: {0: '98.96%', 1: '95.16%', 2: '82.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.121669, Train-Class-Acc: {0: '98.36%', 1: '95.62%', 2: '84.81%'},
# Val Loss: 0.130286, Val Acc: 95.81%, Val-Class-Acc: {0: '98.96%', 1: '95.18%', 2: '82.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.120088, Train-Class-Acc: {0: '98.38%', 1: '95.60%', 2: '85.08%'},
# Val Loss: 0.128882, Val Acc: 95.83%, Val-Class-Acc: {0: '98.96%', 1: '95.20%', 2: '82.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.118605, Train-Class-Acc: {0: '98.37%', 1: '95.64%', 2: '85.20%'},
# Val Loss: 0.127594, Val Acc: 95.86%, Val-Class-Acc: {0: '98.98%', 1: '95.19%', 2: '82.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.117212, Train-Class-Acc: {0: '98.40%', 1: '95.61%', 2: '85.44%'},
# Val Loss: 0.126327, Val Acc: 95.87%, Val-Class-Acc: {0: '98.97%', 1: '95.22%', 2: '83.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.115890, Train-Class-Acc: {0: '98.40%', 1: '95.64%', 2: '85.52%'},
# Val Loss: 0.125163, Val Acc: 95.88%, Val-Class-Acc: {0: '98.99%', 1: '95.20%', 2: '83.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.114653, Train-Class-Acc: {0: '98.40%', 1: '95.66%', 2: '85.61%'},
# Val Loss: 0.124032, Val Acc: 95.87%, Val-Class-Acc: {0: '98.99%', 1: '95.15%', 2: '83.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.113460, Train-Class-Acc: {0: '98.42%', 1: '95.65%', 2: '85.78%'},
# Val Loss: 0.122959, Val Acc: 95.88%, Val-Class-Acc: {0: '98.98%', 1: '95.16%', 2: '83.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.112342, Train-Class-Acc: {0: '98.42%', 1: '95.66%', 2: '85.85%'},
# Val Loss: 0.121933, Val Acc: 95.88%, Val-Class-Acc: {0: '98.98%', 1: '95.13%', 2: '83.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.111268, Train-Class-Acc: {0: '98.43%', 1: '95.63%', 2: '86.20%'},
# Val Loss: 0.120933, Val Acc: 95.90%, Val-Class-Acc: {0: '98.98%', 1: '95.15%', 2: '83.47%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_41.pth
# Epoch 42/1000, Train Loss: 0.110243, Train-Class-Acc: {0: '98.43%', 1: '95.68%', 2: '86.14%'},
# Val Loss: 0.119964, Val Acc: 95.91%, Val-Class-Acc: {0: '98.99%', 1: '95.18%', 2: '83.51%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.109254, Train-Class-Acc: {0: '98.43%', 1: '95.68%', 2: '86.32%'},
# Val Loss: 0.119066, Val Acc: 95.93%, Val-Class-Acc: {0: '98.99%', 1: '95.22%', 2: '83.55%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.108314, Train-Class-Acc: {0: '98.45%', 1: '95.66%', 2: '86.45%'},
# Val Loss: 0.118186, Val Acc: 95.94%, Val-Class-Acc: {0: '99.00%', 1: '95.22%', 2: '83.59%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.107414, Train-Class-Acc: {0: '98.45%', 1: '95.69%', 2: '86.54%'},
# Val Loss: 0.117323, Val Acc: 95.95%, Val-Class-Acc: {0: '99.00%', 1: '95.20%', 2: '83.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.106547, Train-Class-Acc: {0: '98.46%', 1: '95.70%', 2: '86.57%'},
# Val Loss: 0.116518, Val Acc: 95.96%, Val-Class-Acc: {0: '99.01%', 1: '95.22%', 2: '83.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.105700, Train-Class-Acc: {0: '98.46%', 1: '95.70%', 2: '86.76%'},
# Val Loss: 0.115734, Val Acc: 95.97%, Val-Class-Acc: {0: '99.00%', 1: '95.24%', 2: '83.75%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.104892, Train-Class-Acc: {0: '98.47%', 1: '95.68%', 2: '86.93%'},
# Val Loss: 0.114943, Val Acc: 95.97%, Val-Class-Acc: {0: '99.01%', 1: '95.20%', 2: '83.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.104107, Train-Class-Acc: {0: '98.46%', 1: '95.71%', 2: '87.00%'},
# Val Loss: 0.114187, Val Acc: 95.98%, Val-Class-Acc: {0: '99.00%', 1: '95.21%', 2: '83.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.103356, Train-Class-Acc: {0: '98.47%', 1: '95.73%', 2: '86.97%'},
# Val Loss: 0.113492, Val Acc: 95.98%, Val-Class-Acc: {0: '99.01%', 1: '95.19%', 2: '83.91%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_50.pth
# Epoch 51/1000, Train Loss: 0.102633, Train-Class-Acc: {0: '98.47%', 1: '95.72%', 2: '87.13%'},
# Val Loss: 0.112795, Val Acc: 96.00%, Val-Class-Acc: {0: '99.01%', 1: '95.25%', 2: '83.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.101927, Train-Class-Acc: {0: '98.47%', 1: '95.73%', 2: '87.21%'},
# Val Loss: 0.112119, Val Acc: 96.00%, Val-Class-Acc: {0: '99.01%', 1: '95.23%', 2: '84.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.101241, Train-Class-Acc: {0: '98.49%', 1: '95.71%', 2: '87.35%'},
# Val Loss: 0.111427, Val Acc: 96.00%, Val-Class-Acc: {0: '99.01%', 1: '95.20%', 2: '84.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.100570, Train-Class-Acc: {0: '98.49%', 1: '95.72%', 2: '87.42%'},
# Val Loss: 0.110840, Val Acc: 96.02%, Val-Class-Acc: {0: '99.01%', 1: '95.27%', 2: '84.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_54.pth
# Epoch 55/1000, Train Loss: 0.099944, Train-Class-Acc: {0: '98.50%', 1: '95.74%', 2: '87.45%'},
# Val Loss: 0.110189, Val Acc: 96.03%, Val-Class-Acc: {0: '99.01%', 1: '95.25%', 2: '84.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_50.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.099315, Train-Class-Acc: {0: '98.49%', 1: '95.75%', 2: '87.54%'},
# Val Loss: 0.109644, Val Acc: 96.03%, Val-Class-Acc: {0: '99.00%', 1: '95.28%', 2: '84.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.098697, Train-Class-Acc: {0: '98.50%', 1: '95.76%', 2: '87.50%'},
# Val Loss: 0.109013, Val Acc: 96.03%, Val-Class-Acc: {0: '99.01%', 1: '95.24%', 2: '84.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.098116, Train-Class-Acc: {0: '98.50%', 1: '95.74%', 2: '87.77%'},
# Val Loss: 0.108434, Val Acc: 96.05%, Val-Class-Acc: {0: '99.00%', 1: '95.30%', 2: '84.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_52.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_58.pth
# Epoch 59/1000, Train Loss: 0.097534, Train-Class-Acc: {0: '98.50%', 1: '95.74%', 2: '87.87%'},
# Val Loss: 0.107973, Val Acc: 96.06%, Val-Class-Acc: {0: '99.00%', 1: '95.32%', 2: '84.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_54.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_59.pth
# Epoch 60/1000, Train Loss: 0.096987, Train-Class-Acc: {0: '98.50%', 1: '95.80%', 2: '87.77%'},
# Val Loss: 0.107383, Val Acc: 96.05%, Val-Class-Acc: {0: '99.02%', 1: '95.21%', 2: '84.45%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_60.pth
# Epoch 61/1000, Train Loss: 0.096440, Train-Class-Acc: {0: '98.51%', 1: '95.76%', 2: '88.03%'},
# Val Loss: 0.106909, Val Acc: 96.07%, Val-Class-Acc: {0: '99.01%', 1: '95.29%', 2: '84.41%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.095919, Train-Class-Acc: {0: '98.51%', 1: '95.77%', 2: '88.14%'},
# Val Loss: 0.106513, Val Acc: 96.08%, Val-Class-Acc: {0: '98.98%', 1: '95.38%', 2: '84.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.095400, Train-Class-Acc: {0: '98.51%', 1: '95.79%', 2: '88.24%'},
# Val Loss: 0.106007, Val Acc: 96.09%, Val-Class-Acc: {0: '99.00%', 1: '95.37%', 2: '84.41%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_60.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_63.pth
# Epoch 64/1000, Train Loss: 0.094909, Train-Class-Acc: {0: '98.51%', 1: '95.84%', 2: '88.14%'},
# Val Loss: 0.105484, Val Acc: 96.11%, Val-Class-Acc: {0: '99.01%', 1: '95.35%', 2: '84.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_58.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_64.pth
# Epoch 65/1000, Train Loss: 0.094412, Train-Class-Acc: {0: '98.51%', 1: '95.82%', 2: '88.49%'},
# Val Loss: 0.105020, Val Acc: 96.13%, Val-Class-Acc: {0: '99.02%', 1: '95.33%', 2: '84.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_59.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_65.pth
# Epoch 66/1000, Train Loss: 0.093933, Train-Class-Acc: {0: '98.52%', 1: '95.83%', 2: '88.51%'},
# Val Loss: 0.104563, Val Acc: 96.14%, Val-Class-Acc: {0: '99.01%', 1: '95.33%', 2: '84.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.093462, Train-Class-Acc: {0: '98.51%', 1: '95.86%', 2: '88.59%'},
# Val Loss: 0.104055, Val Acc: 96.15%, Val-Class-Acc: {0: '99.02%', 1: '95.32%', 2: '85.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_67.pth
# Epoch 68/1000, Train Loss: 0.093023, Train-Class-Acc: {0: '98.52%', 1: '95.85%', 2: '88.65%'},
# Val Loss: 0.103599, Val Acc: 96.14%, Val-Class-Acc: {0: '99.00%', 1: '95.27%', 2: '85.15%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_63.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_68.pth
# Epoch 69/1000, Train Loss: 0.092557, Train-Class-Acc: {0: '98.51%', 1: '95.86%', 2: '88.83%'},
# Val Loss: 0.103350, Val Acc: 96.16%, Val-Class-Acc: {0: '98.99%', 1: '95.37%', 2: '85.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_64.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_69.pth
# Epoch 70/1000, Train Loss: 0.092122, Train-Class-Acc: {0: '98.52%', 1: '95.89%', 2: '88.83%'},
# Val Loss: 0.103012, Val Acc: 96.14%, Val-Class-Acc: {0: '99.00%', 1: '95.31%', 2: '85.13%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_65.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_70.pth
# Epoch 71/1000, Train Loss: 0.091692, Train-Class-Acc: {0: '98.52%', 1: '95.88%', 2: '89.01%'},
# Val Loss: 0.102493, Val Acc: 96.18%, Val-Class-Acc: {0: '98.99%', 1: '95.37%', 2: '85.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_68.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_71.pth
# Epoch 72/1000, Train Loss: 0.091270, Train-Class-Acc: {0: '98.52%', 1: '95.90%', 2: '89.05%'},
# Val Loss: 0.102244, Val Acc: 96.19%, Val-Class-Acc: {0: '98.99%', 1: '95.43%', 2: '85.25%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_70.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.090862, Train-Class-Acc: {0: '98.52%', 1: '95.90%', 2: '89.21%'},
# Val Loss: 0.102009, Val Acc: 96.21%, Val-Class-Acc: {0: '98.99%', 1: '95.46%', 2: '85.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_73.pth
# Epoch 74/1000, Train Loss: 0.090458, Train-Class-Acc: {0: '98.52%', 1: '95.93%', 2: '89.26%'},
# Val Loss: 0.101481, Val Acc: 96.22%, Val-Class-Acc: {0: '98.98%', 1: '95.43%', 2: '85.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_67.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_74.pth
# Epoch 75/1000, Train Loss: 0.090064, Train-Class-Acc: {0: '98.53%', 1: '95.90%', 2: '89.49%'},
# Val Loss: 0.101667, Val Acc: 96.21%, Val-Class-Acc: {0: '98.98%', 1: '95.48%', 2: '85.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_69.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_75.pth
# Epoch 76/1000, Train Loss: 0.089703, Train-Class-Acc: {0: '98.53%', 1: '95.93%', 2: '89.55%'},
# Val Loss: 0.101316, Val Acc: 96.23%, Val-Class-Acc: {0: '98.98%', 1: '95.52%', 2: '85.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_71.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.089317, Train-Class-Acc: {0: '98.53%', 1: '95.95%', 2: '89.66%'},
# Val Loss: 0.101127, Val Acc: 96.23%, Val-Class-Acc: {0: '98.98%', 1: '95.51%', 2: '85.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_77.pth
# Epoch 78/1000, Train Loss: 0.088945, Train-Class-Acc: {0: '98.55%', 1: '95.98%', 2: '89.59%'},
# Val Loss: 0.100415, Val Acc: 96.26%, Val-Class-Acc: {0: '98.98%', 1: '95.48%', 2: '85.72%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_73.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_78.pth
# Epoch 79/1000, Train Loss: 0.088574, Train-Class-Acc: {0: '98.54%', 1: '95.99%', 2: '89.77%'},
# Val Loss: 0.099986, Val Acc: 96.27%, Val-Class-Acc: {0: '98.99%', 1: '95.44%', 2: '85.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_75.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_79.pth
# Epoch 80/1000, Train Loss: 0.088234, Train-Class-Acc: {0: '98.54%', 1: '95.99%', 2: '89.91%'},
# Val Loss: 0.099582, Val Acc: 96.25%, Val-Class-Acc: {0: '99.00%', 1: '95.33%', 2: '86.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_74.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_80.pth
# Epoch 81/1000, Train Loss: 0.087871, Train-Class-Acc: {0: '98.54%', 1: '96.01%', 2: '89.92%'},
# Val Loss: 0.099804, Val Acc: 96.26%, Val-Class-Acc: {0: '98.99%', 1: '95.48%', 2: '85.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.087538, Train-Class-Acc: {0: '98.55%', 1: '96.00%', 2: '90.04%'},
# Val Loss: 0.099128, Val Acc: 96.29%, Val-Class-Acc: {0: '99.00%', 1: '95.46%', 2: '85.96%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_77.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_82.pth
# Epoch 83/1000, Train Loss: 0.087190, Train-Class-Acc: {0: '98.54%', 1: '96.04%', 2: '90.09%'},
# Val Loss: 0.098984, Val Acc: 96.26%, Val-Class-Acc: {0: '99.00%', 1: '95.38%', 2: '85.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_80.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.086890, Train-Class-Acc: {0: '98.56%', 1: '96.00%', 2: '90.20%'},
# Val Loss: 0.099173, Val Acc: 96.29%, Val-Class-Acc: {0: '99.00%', 1: '95.52%', 2: '85.76%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_84.pth
# Epoch 85/1000, Train Loss: 0.086576, Train-Class-Acc: {0: '98.55%', 1: '96.05%', 2: '90.17%'},
# Val Loss: 0.098354, Val Acc: 96.29%, Val-Class-Acc: {0: '99.00%', 1: '95.46%', 2: '86.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_78.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_85.pth
# Epoch 86/1000, Train Loss: 0.086198, Train-Class-Acc: {0: '98.55%', 1: '96.07%', 2: '90.21%'},
# Val Loss: 0.097859, Val Acc: 96.26%, Val-Class-Acc: {0: '98.99%', 1: '95.37%', 2: '86.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_86.pth
# Epoch 87/1000, Train Loss: 0.085904, Train-Class-Acc: {0: '98.55%', 1: '96.06%', 2: '90.48%'},
# Val Loss: 0.098076, Val Acc: 96.31%, Val-Class-Acc: {0: '98.99%', 1: '95.51%', 2: '86.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_86.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_87.pth
# Epoch 88/1000, Train Loss: 0.085598, Train-Class-Acc: {0: '98.56%', 1: '96.09%', 2: '90.28%'},
# Val Loss: 0.097702, Val Acc: 96.31%, Val-Class-Acc: {0: '98.98%', 1: '95.51%', 2: '86.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_79.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_88.pth
# Epoch 89/1000, Train Loss: 0.085311, Train-Class-Acc: {0: '98.55%', 1: '96.06%', 2: '90.60%'},
# Val Loss: 0.097836, Val Acc: 96.28%, Val-Class-Acc: {0: '99.00%', 1: '95.44%', 2: '85.95%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.084999, Train-Class-Acc: {0: '98.57%', 1: '96.10%', 2: '90.39%'},
# Val Loss: 0.097288, Val Acc: 96.33%, Val-Class-Acc: {0: '98.97%', 1: '95.55%', 2: '86.13%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_84.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_90.pth
# Epoch 91/1000, Train Loss: 0.084705, Train-Class-Acc: {0: '98.55%', 1: '96.12%', 2: '90.58%'},
# Val Loss: 0.096903, Val Acc: 96.30%, Val-Class-Acc: {0: '98.97%', 1: '95.47%', 2: '86.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_82.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_91.pth
# Epoch 92/1000, Train Loss: 0.084413, Train-Class-Acc: {0: '98.56%', 1: '96.10%', 2: '90.75%'},
# Val Loss: 0.097111, Val Acc: 96.29%, Val-Class-Acc: {0: '98.99%', 1: '95.47%', 2: '85.99%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.084141, Train-Class-Acc: {0: '98.57%', 1: '96.11%', 2: '90.66%'},
# Val Loss: 0.096579, Val Acc: 96.31%, Val-Class-Acc: {0: '98.98%', 1: '95.51%', 2: '86.08%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_85.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_93.pth
# Epoch 94/1000, Train Loss: 0.083858, Train-Class-Acc: {0: '98.57%', 1: '96.15%', 2: '90.66%'},
# Val Loss: 0.096308, Val Acc: 96.31%, Val-Class-Acc: {0: '98.98%', 1: '95.51%', 2: '86.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_91.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_94.pth
# Epoch 95/1000, Train Loss: 0.083586, Train-Class-Acc: {0: '98.56%', 1: '96.13%', 2: '90.90%'},
# Val Loss: 0.096161, Val Acc: 96.30%, Val-Class-Acc: {0: '98.99%', 1: '95.49%', 2: '86.05%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.083333, Train-Class-Acc: {0: '98.57%', 1: '96.16%', 2: '90.79%'},
# Val Loss: 0.096234, Val Acc: 96.29%, Val-Class-Acc: {0: '98.97%', 1: '95.55%', 2: '85.81%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.083052, Train-Class-Acc: {0: '98.57%', 1: '96.19%', 2: '90.82%'},
# Val Loss: 0.095683, Val Acc: 96.31%, Val-Class-Acc: {0: '98.97%', 1: '95.52%', 2: '86.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_88.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_97.pth
# Epoch 98/1000, Train Loss: 0.082806, Train-Class-Acc: {0: '98.57%', 1: '96.15%', 2: '91.07%'},
# Val Loss: 0.095656, Val Acc: 96.30%, Val-Class-Acc: {0: '98.98%', 1: '95.51%', 2: '85.98%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.082563, Train-Class-Acc: {0: '98.57%', 1: '96.18%', 2: '90.97%'},
# Val Loss: 0.095310, Val Acc: 96.30%, Val-Class-Acc: {0: '98.99%', 1: '95.52%', 2: '85.93%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.082308, Train-Class-Acc: {0: '98.57%', 1: '96.20%', 2: '91.11%'},
# Val Loss: 0.095423, Val Acc: 96.28%, Val-Class-Acc: {0: '98.99%', 1: '95.54%', 2: '85.68%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.082041, Train-Class-Acc: {0: '98.58%', 1: '96.21%', 2: '91.06%'},
# Val Loss: 0.094922, Val Acc: 96.31%, Val-Class-Acc: {0: '98.97%', 1: '95.52%', 2: '86.04%'}, LR: 0.000100
# ...
# Epoch 772/1000, Train Loss: 0.063678, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090708, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 773/1000, Train Loss: 0.063678, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 774/1000, Train Loss: 0.063678, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 775/1000, Train Loss: 0.063678, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 776/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090708, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 777/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 778/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 779/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090709, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 780/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 781/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 782/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 783/1000, Train Loss: 0.063677, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 784/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 785/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 786/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 787/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 788/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 789/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 790/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 791/1000, Train Loss: 0.063676, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 792/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 793/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 794/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090709, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.35%'}, LR: 0.000000
# Epoch 795/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090714, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 796/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 797/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 798/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 799/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 800/1000, Train Loss: 0.063675, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 801/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 802/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090714, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 803/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 804/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090715, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 805/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 806/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 807/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 808/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 809/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 810/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 811/1000, Train Loss: 0.063674, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090709, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.35%'}, LR: 0.000000
# Epoch 812/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 813/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090714, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 814/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 815/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090715, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 816/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.35%'}, LR: 0.000000
# Epoch 817/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 818/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090710, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 819/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 820/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 821/1000, Train Loss: 0.063673, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 822/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 823/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 824/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090714, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 825/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 826/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 827/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090711, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.33%'}, LR: 0.000000
# Epoch 828/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 829/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 830/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.51%', 2: '86.34%'}, LR: 0.000000
# Epoch 831/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 832/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 833/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 834/1000, Train Loss: 0.063672, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 835/1000, Train Loss: 0.063671, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.89%'},
# Val Loss: 0.090711, Val Acc: 96.33%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.35%'}, LR: 0.000000
# Epoch 836/1000, Train Loss: 0.063671, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 837/1000, Train Loss: 0.063671, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090712, Val Acc: 96.33%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
# Epoch 838/1000, Train Loss: 0.063671, Train-Class-Acc: {0: '98.81%', 1: '96.80%', 2: '93.88%'},
# Val Loss: 0.090713, Val Acc: 96.32%, Val-Class-Acc: {0: '98.95%', 1: '95.52%', 2: '86.33%'}, LR: 0.000000
#
# 🛑 Stop signal detected. Exiting training loop.
#
# 🏆 Best model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_best.pth (Val Accuracy: 96.43%)
#
# 📌 Final model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 202, Train Loss: 0.068063, Train-Acc: {0: '98.77%', 1: '96.62%', 2: '93.04%'},
# Val Loss: 0.088448, Val Acc: 96.43%, Val-Acc: {0: '98.93%', 1: '95.63%', 2: '87.04%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_202.pth
# Epoch 209, Train Loss: 0.067698, Train-Acc: {0: '98.78%', 1: '96.65%', 2: '93.07%'},
# Val Loss: 0.088352, Val Acc: 96.43%, Val-Acc: {0: '98.96%', 1: '95.53%', 2: '87.22%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_209.pth
# Epoch 203, Train Loss: 0.068009, Train-Acc: {0: '98.77%', 1: '96.57%', 2: '93.15%'},
# Val Loss: 0.088495, Val Acc: 96.43%, Val-Acc: {0: '98.95%', 1: '95.60%', 2: '87.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_203.pth
# Epoch 200, Train Loss: 0.068179, Train-Acc: {0: '98.76%', 1: '96.62%', 2: '93.04%'},
# Val Loss: 0.088784, Val Acc: 96.43%, Val-Acc: {0: '98.97%', 1: '95.64%', 2: '86.78%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_200.pth
# Epoch 213, Train Loss: 0.067495, Train-Acc: {0: '98.77%', 1: '96.64%', 2: '93.20%'},
# Val Loss: 0.088964, Val Acc: 96.42%, Val-Acc: {0: '98.95%', 1: '95.66%', 2: '86.73%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_2\1st_try\BiGRUWithAttention_epoch_213.pth
#
# ✅ Training Complete. Final model:
# BiGRUWithAttention_LoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=3, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3 (num_layers = 4, lora_r=4)
# + ##### BiGRUWithAttention_LoRA
# + ##### Training and saving in *'Standard_LoRA/Rank_4_Period_3/1st_try'*
# #### __Val Accuracy: 91.14%__
# #### __Val-Class-Acc: {0: '50.14%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}__

# %%
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[2],  # Period 3
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2, 3}
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

print_class_distribution(y_train, "y_train")
print_class_distribution(y_val, "y_val")
print_class_distribution(y_test, "y_test")
# Out:
# Number_features = 7
# unique_classes = [0 1 2 3]
# num_classes = 4
# Class Distribution for 'y_train':       Class 0   Percent:  13.79% || Class 1   Percent:  37.59% || Class 2   Percent:   8.89% || Class 3   Percent:  39.73%
# Class Distribution for 'y_val':         Class 0   Percent:  10.26% || Class 1   Percent:  46.19% || Class 2   Percent:   4.21% || Class 3   Percent:  39.34%
# Class Distribution for 'y_test':        Class 0   Percent:  10.30% || Class 1   Percent:  43.50% || Class 2   Percent:   8.50% || Class 3   Percent:  37.70%

# %%
# ==== Model Hyperparameters ====
input_size = Number_features
hidden_size = 64
output_size = num_classes
num_layers = 4
dropout = 0.0
lora_r = 4
num_epochs = 1000
batch_size = 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ==== Paths ====
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))
model_saving_folder = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_3/1st_try"
))
ensure_folder(model_saving_folder)

# ==== Load previous model (Period 2) ====
previous_model_path = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_2/1st_try", "BiGRUWithAttention_best.pth"
))
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# ==== Initialize model and LoRA ====
model = BiGRUWithAttention_LoRA(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    num_layers=num_layers,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

model.init_lora()

# ==== Load GRU + attention_fc + LoRA weights ====
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc.")
}, strict=False)

print("✅ Model loaded (GRU, attention_fc, and LoRA). FC layer reinitialized.")

# ==== Training Setup ====
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.get_trainable_parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

train_lora_baseline(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    scheduler=scheduler,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name='BiGRUWithAttention',
    stop_signal_file=stop_signal_file
)

print(f"\n✅ Training Complete. Final model: \n{model}")
print(f"unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, X_test, y_test, Number_features, unique_classes, num_classes
gc.collect()
torch.cuda.empty_cache()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_169508\1940402688.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# Initialized LoRA adapter
# ✅ Model loaded (GRU, attention_fc, and LoRA). FC layer reinitialized.
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc.weight
#   ✅ fc.bias
#
# 🚀 'train_lora_baseline' started.
# ✅ Removed existing folder: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try
#
# ✅ Data Overview:
# X_train: torch.Size([3634, 1000, 7]), y_train: torch.Size([3634, 1000])
# X_val: torch.Size([454, 1000, 7]), y_val: torch.Size([454, 1000])
# Epoch 1/1000, Train Loss: 1.754825, Train-Class-Acc: {0: '32.53%', 1: '30.57%', 2: '5.05%', 3: '4.25%'},
# Val Loss: 1.523233, Val Acc: 26.73%, Val-Class-Acc: {0: '40.22%', 1: '43.29%', 2: '3.95%', 3: '6.20%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_1.pth
# Epoch 2/1000, Train Loss: 1.353650, Train-Class-Acc: {0: '42.10%', 1: '51.93%', 2: '6.78%', 3: '9.06%'},
# Val Loss: 1.182346, Val Acc: 37.69%, Val-Class-Acc: {0: '40.49%', 1: '59.45%', 2: '9.48%', 3: '14.42%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_2.pth
# Epoch 3/1000, Train Loss: 1.080095, Train-Class-Acc: {0: '27.28%', 1: '68.39%', 2: '14.35%', 3: '47.45%'},
# Val Loss: 0.952296, Val Acc: 67.94%, Val-Class-Acc: {0: '15.13%', 1: '74.34%', 2: '16.98%', 3: '79.66%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.901796, Train-Class-Acc: {0: '8.82%', 1: '80.90%', 2: '25.90%', 3: '84.49%'},
# Val Loss: 0.799881, Val Acc: 76.35%, Val-Class-Acc: {0: '9.71%', 1: '83.19%', 2: '31.04%', 3: '90.54%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.782326, Train-Class-Acc: {0: '5.79%', 1: '88.83%', 2: '40.21%', 3: '92.31%'},
# Val Loss: 0.694611, Val Acc: 81.09%, Val-Class-Acc: {0: '7.27%', 1: '88.90%', 2: '42.59%', 3: '95.30%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.697538, Train-Class-Acc: {0: '4.67%', 1: '92.89%', 2: '51.99%', 3: '94.79%'},
# Val Loss: 0.619152, Val Acc: 83.12%, Val-Class-Acc: {0: '6.62%', 1: '91.74%', 2: '54.10%', 3: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.635601, Train-Class-Acc: {0: '4.62%', 1: '94.28%', 2: '60.71%', 3: '95.47%'},
# Val Loss: 0.562947, Val Acc: 84.35%, Val-Class-Acc: {0: '7.05%', 1: '93.26%', 2: '61.64%', 3: '96.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.589247, Train-Class-Acc: {0: '5.34%', 1: '94.72%', 2: '66.55%', 3: '95.88%'},
# Val Loss: 0.520466, Val Acc: 85.24%, Val-Class-Acc: {0: '8.71%', 1: '94.01%', 2: '68.38%', 3: '96.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.553818, Train-Class-Acc: {0: '6.25%', 1: '94.96%', 2: '70.31%', 3: '96.25%'},
# Val Loss: 0.486431, Val Acc: 85.90%, Val-Class-Acc: {0: '10.17%', 1: '94.45%', 2: '72.17%', 3: '97.08%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.526170, Train-Class-Acc: {0: '7.46%', 1: '95.02%', 2: '73.23%', 3: '96.58%'},
# Val Loss: 0.460702, Val Acc: 86.44%, Val-Class-Acc: {0: '11.83%', 1: '94.79%', 2: '74.31%', 3: '97.39%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.504348, Train-Class-Acc: {0: '8.56%', 1: '95.09%', 2: '75.15%', 3: '96.80%'},
# Val Loss: 0.439290, Val Acc: 86.79%, Val-Class-Acc: {0: '13.26%', 1: '95.03%', 2: '75.66%', 3: '97.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.486685, Train-Class-Acc: {0: '9.71%', 1: '95.18%', 2: '76.37%', 3: '96.92%'},
# Val Loss: 0.421491, Val Acc: 87.08%, Val-Class-Acc: {0: '14.70%', 1: '95.30%', 2: '76.57%', 3: '97.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.472145, Train-Class-Acc: {0: '10.47%', 1: '95.21%', 2: '77.74%', 3: '97.04%'},
# Val Loss: 0.407283, Val Acc: 87.26%, Val-Class-Acc: {0: '15.48%', 1: '95.46%', 2: '77.39%', 3: '97.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.459914, Train-Class-Acc: {0: '11.20%', 1: '95.23%', 2: '78.78%', 3: '97.11%'},
# Val Loss: 0.394868, Val Acc: 87.46%, Val-Class-Acc: {0: '16.04%', 1: '95.71%', 2: '77.82%', 3: '97.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.449468, Train-Class-Acc: {0: '11.83%', 1: '95.33%', 2: '79.39%', 3: '97.11%'},
# Val Loss: 0.384167, Val Acc: 87.69%, Val-Class-Acc: {0: '16.88%', 1: '95.96%', 2: '78.54%', 3: '97.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.440428, Train-Class-Acc: {0: '12.38%', 1: '95.38%', 2: '80.03%', 3: '97.12%'},
# Val Loss: 0.374804, Val Acc: 87.88%, Val-Class-Acc: {0: '17.99%', 1: '96.11%', 2: '78.85%', 3: '97.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.432509, Train-Class-Acc: {0: '12.90%', 1: '95.50%', 2: '80.34%', 3: '97.11%'},
# Val Loss: 0.366769, Val Acc: 88.07%, Val-Class-Acc: {0: '18.69%', 1: '96.30%', 2: '79.65%', 3: '97.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.425502, Train-Class-Acc: {0: '13.37%', 1: '95.58%', 2: '80.93%', 3: '97.09%'},
# Val Loss: 0.359482, Val Acc: 88.20%, Val-Class-Acc: {0: '19.30%', 1: '96.38%', 2: '80.47%', 3: '97.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.419258, Train-Class-Acc: {0: '13.75%', 1: '95.59%', 2: '81.59%', 3: '97.10%'},
# Val Loss: 0.352677, Val Acc: 88.33%, Val-Class-Acc: {0: '19.65%', 1: '96.55%', 2: '80.86%', 3: '97.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.413643, Train-Class-Acc: {0: '14.06%', 1: '95.73%', 2: '81.76%', 3: '97.09%'},
# Val Loss: 0.346560, Val Acc: 88.42%, Val-Class-Acc: {0: '20.13%', 1: '96.70%', 2: '80.75%', 3: '97.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.408545, Train-Class-Acc: {0: '14.37%', 1: '95.75%', 2: '82.35%', 3: '97.11%'},
# Val Loss: 0.341599, Val Acc: 88.53%, Val-Class-Acc: {0: '20.75%', 1: '96.82%', 2: '81.02%', 3: '97.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.403893, Train-Class-Acc: {0: '14.65%', 1: '95.85%', 2: '82.45%', 3: '97.11%'},
# Val Loss: 0.337072, Val Acc: 88.75%, Val-Class-Acc: {0: '22.16%', 1: '96.94%', 2: '81.41%', 3: '97.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.399633, Train-Class-Acc: {0: '15.15%', 1: '95.88%', 2: '82.98%', 3: '97.09%'},
# Val Loss: 0.332984, Val Acc: 88.90%, Val-Class-Acc: {0: '23.18%', 1: '97.04%', 2: '81.47%', 3: '97.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.395698, Train-Class-Acc: {0: '15.91%', 1: '96.01%', 2: '82.88%', 3: '97.05%'},
# Val Loss: 0.328083, Val Acc: 88.95%, Val-Class-Acc: {0: '23.31%', 1: '97.08%', 2: '81.92%', 3: '97.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.392019, Train-Class-Acc: {0: '16.17%', 1: '95.99%', 2: '83.49%', 3: '97.05%'},
# Val Loss: 0.324083, Val Acc: 89.10%, Val-Class-Acc: {0: '24.03%', 1: '97.24%', 2: '81.66%', 3: '97.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.388569, Train-Class-Acc: {0: '17.16%', 1: '96.09%', 2: '83.52%', 3: '96.97%'},
# Val Loss: 0.320623, Val Acc: 89.13%, Val-Class-Acc: {0: '24.24%', 1: '97.24%', 2: '82.22%', 3: '97.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.385410, Train-Class-Acc: {0: '17.73%', 1: '96.12%', 2: '83.87%', 3: '96.95%'},
# Val Loss: 0.317869, Val Acc: 89.27%, Val-Class-Acc: {0: '25.57%', 1: '97.30%', 2: '82.39%', 3: '97.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.382380, Train-Class-Acc: {0: '18.59%', 1: '96.15%', 2: '84.22%', 3: '96.90%'},
# Val Loss: 0.314104, Val Acc: 89.35%, Val-Class-Acc: {0: '25.74%', 1: '97.39%', 2: '82.63%', 3: '97.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.379528, Train-Class-Acc: {0: '19.69%', 1: '96.22%', 2: '84.42%', 3: '96.82%'},
# Val Loss: 0.311273, Val Acc: 89.45%, Val-Class-Acc: {0: '26.75%', 1: '97.47%', 2: '82.69%', 3: '97.11%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.376832, Train-Class-Acc: {0: '20.31%', 1: '96.28%', 2: '84.67%', 3: '96.81%'},
# Val Loss: 0.308916, Val Acc: 89.51%, Val-Class-Acc: {0: '27.36%', 1: '97.46%', 2: '83.20%', 3: '97.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.374215, Train-Class-Acc: {0: '21.73%', 1: '96.37%', 2: '84.74%', 3: '96.69%'},
# Val Loss: 0.306663, Val Acc: 89.57%, Val-Class-Acc: {0: '27.97%', 1: '97.52%', 2: '83.43%', 3: '96.97%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.371668, Train-Class-Acc: {0: '23.16%', 1: '96.33%', 2: '85.43%', 3: '96.56%'},
# Val Loss: 0.304167, Val Acc: 89.68%, Val-Class-Acc: {0: '29.28%', 1: '97.57%', 2: '83.59%', 3: '96.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.369260, Train-Class-Acc: {0: '25.42%', 1: '96.39%', 2: '85.63%', 3: '96.21%'},
# Val Loss: 0.301994, Val Acc: 89.75%, Val-Class-Acc: {0: '30.61%', 1: '97.61%', 2: '84.12%', 3: '96.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.366825, Train-Class-Acc: {0: '25.88%', 1: '96.49%', 2: '85.58%', 3: '96.23%'},
# Val Loss: 0.298821, Val Acc: 89.79%, Val-Class-Acc: {0: '30.69%', 1: '97.66%', 2: '84.10%', 3: '96.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.364696, Train-Class-Acc: {0: '27.34%', 1: '96.52%', 2: '85.83%', 3: '95.96%'},
# Val Loss: 0.297319, Val Acc: 89.80%, Val-Class-Acc: {0: '32.08%', 1: '97.70%', 2: '84.23%', 3: '96.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.362574, Train-Class-Acc: {0: '28.47%', 1: '96.52%', 2: '86.06%', 3: '95.72%'},
# Val Loss: 0.293659, Val Acc: 89.83%, Val-Class-Acc: {0: '31.16%', 1: '97.80%', 2: '83.94%', 3: '96.41%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.360616, Train-Class-Acc: {0: '28.11%', 1: '96.60%', 2: '86.07%', 3: '95.86%'},
# Val Loss: 0.293430, Val Acc: 89.84%, Val-Class-Acc: {0: '33.28%', 1: '97.79%', 2: '84.52%', 3: '95.83%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.358896, Train-Class-Acc: {0: '29.48%', 1: '96.63%', 2: '86.24%', 3: '95.52%'},
# Val Loss: 0.290879, Val Acc: 89.91%, Val-Class-Acc: {0: '33.07%', 1: '97.86%', 2: '84.65%', 3: '95.97%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.357195, Train-Class-Acc: {0: '29.48%', 1: '96.68%', 2: '86.22%', 3: '95.56%'},
# Val Loss: 0.289334, Val Acc: 89.96%, Val-Class-Acc: {0: '33.58%', 1: '97.87%', 2: '85.14%', 3: '95.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.355530, Train-Class-Acc: {0: '30.05%', 1: '96.75%', 2: '86.27%', 3: '95.45%'},
# Val Loss: 0.287099, Val Acc: 90.01%, Val-Class-Acc: {0: '33.08%', 1: '97.85%', 2: '85.91%', 3: '96.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.354007, Train-Class-Acc: {0: '29.87%', 1: '96.74%', 2: '86.52%', 3: '95.52%'},
# Val Loss: 0.286283, Val Acc: 90.00%, Val-Class-Acc: {0: '34.19%', 1: '97.89%', 2: '85.68%', 3: '95.76%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_41.pth
# Epoch 42/1000, Train Loss: 0.352537, Train-Class-Acc: {0: '30.55%', 1: '96.75%', 2: '86.69%', 3: '95.38%'},
# Val Loss: 0.283412, Val Acc: 90.06%, Val-Class-Acc: {0: '33.19%', 1: '97.93%', 2: '85.36%', 3: '96.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.351103, Train-Class-Acc: {0: '30.74%', 1: '96.76%', 2: '86.85%', 3: '95.34%'},
# Val Loss: 0.283471, Val Acc: 90.04%, Val-Class-Acc: {0: '34.58%', 1: '97.89%', 2: '86.42%', 3: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.349767, Train-Class-Acc: {0: '31.09%', 1: '96.76%', 2: '86.99%', 3: '95.27%'},
# Val Loss: 0.281055, Val Acc: 90.10%, Val-Class-Acc: {0: '33.95%', 1: '97.92%', 2: '86.03%', 3: '95.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.348513, Train-Class-Acc: {0: '31.36%', 1: '96.80%', 2: '86.94%', 3: '95.23%'},
# Val Loss: 0.279780, Val Acc: 90.09%, Val-Class-Acc: {0: '34.03%', 1: '97.93%', 2: '86.13%', 3: '95.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.347259, Train-Class-Acc: {0: '31.34%', 1: '96.81%', 2: '87.00%', 3: '95.27%'},
# Val Loss: 0.279230, Val Acc: 90.07%, Val-Class-Acc: {0: '34.59%', 1: '97.87%', 2: '86.93%', 3: '95.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.346070, Train-Class-Acc: {0: '31.81%', 1: '96.80%', 2: '87.17%', 3: '95.16%'},
# Val Loss: 0.279113, Val Acc: 90.04%, Val-Class-Acc: {0: '35.39%', 1: '97.85%', 2: '87.07%', 3: '95.45%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.344937, Train-Class-Acc: {0: '31.82%', 1: '96.82%', 2: '87.21%', 3: '95.20%'},
# Val Loss: 0.277454, Val Acc: 90.08%, Val-Class-Acc: {0: '35.18%', 1: '97.89%', 2: '87.30%', 3: '95.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.343820, Train-Class-Acc: {0: '32.29%', 1: '96.81%', 2: '87.46%', 3: '95.06%'},
# Val Loss: 0.276141, Val Acc: 90.11%, Val-Class-Acc: {0: '35.23%', 1: '97.91%', 2: '87.43%', 3: '95.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.342748, Train-Class-Acc: {0: '32.10%', 1: '96.85%', 2: '87.40%', 3: '95.15%'},
# Val Loss: 0.275639, Val Acc: 90.08%, Val-Class-Acc: {0: '35.49%', 1: '97.84%', 2: '87.71%', 3: '95.47%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_50.pth
# Epoch 51/1000, Train Loss: 0.341771, Train-Class-Acc: {0: '32.66%', 1: '96.80%', 2: '87.80%', 3: '95.01%'},
# Val Loss: 0.274700, Val Acc: 90.10%, Val-Class-Acc: {0: '35.83%', 1: '97.82%', 2: '87.80%', 3: '95.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.340792, Train-Class-Acc: {0: '32.43%', 1: '96.85%', 2: '87.65%', 3: '95.12%'},
# Val Loss: 0.273898, Val Acc: 90.08%, Val-Class-Acc: {0: '35.82%', 1: '97.77%', 2: '88.28%', 3: '95.38%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.339821, Train-Class-Acc: {0: '33.11%', 1: '96.85%', 2: '87.83%', 3: '94.92%'},
# Val Loss: 0.273303, Val Acc: 90.05%, Val-Class-Acc: {0: '36.19%', 1: '97.89%', 2: '88.08%', 3: '95.11%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.338833, Train-Class-Acc: {0: '33.19%', 1: '96.89%', 2: '87.80%', 3: '94.94%'},
# Val Loss: 0.272433, Val Acc: 90.03%, Val-Class-Acc: {0: '36.16%', 1: '97.81%', 2: '88.35%', 3: '95.11%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.337911, Train-Class-Acc: {0: '33.03%', 1: '96.83%', 2: '88.25%', 3: '95.02%'},
# Val Loss: 0.270523, Val Acc: 90.16%, Val-Class-Acc: {0: '35.88%', 1: '98.03%', 2: '87.82%', 3: '95.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_50.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.336991, Train-Class-Acc: {0: '33.35%', 1: '96.91%', 2: '88.01%', 3: '94.94%'},
# Val Loss: 0.270282, Val Acc: 90.09%, Val-Class-Acc: {0: '36.05%', 1: '97.85%', 2: '89.00%', 3: '95.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.336263, Train-Class-Acc: {0: '33.42%', 1: '96.83%', 2: '88.56%', 3: '94.92%'},
# Val Loss: 0.268248, Val Acc: 90.22%, Val-Class-Acc: {0: '35.74%', 1: '98.05%', 2: '88.03%', 3: '95.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.335319, Train-Class-Acc: {0: '33.73%', 1: '96.95%', 2: '88.10%', 3: '94.86%'},
# Val Loss: 0.268418, Val Acc: 90.10%, Val-Class-Acc: {0: '36.11%', 1: '97.86%', 2: '89.04%', 3: '95.18%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.334553, Train-Class-Acc: {0: '33.93%', 1: '96.89%', 2: '88.60%', 3: '94.81%'},
# Val Loss: 0.266524, Val Acc: 90.23%, Val-Class-Acc: {0: '35.69%', 1: '98.05%', 2: '88.16%', 3: '95.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_59.pth
# Epoch 60/1000, Train Loss: 0.333757, Train-Class-Acc: {0: '33.69%', 1: '96.90%', 2: '88.55%', 3: '94.94%'},
# Val Loss: 0.266384, Val Acc: 90.14%, Val-Class-Acc: {0: '35.91%', 1: '97.94%', 2: '88.97%', 3: '95.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_60.pth
# Epoch 61/1000, Train Loss: 0.332970, Train-Class-Acc: {0: '34.06%', 1: '96.93%', 2: '88.58%', 3: '94.81%'},
# Val Loss: 0.267189, Val Acc: 90.03%, Val-Class-Acc: {0: '37.02%', 1: '97.89%', 2: '89.10%', 3: '94.73%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.332194, Train-Class-Acc: {0: '34.00%', 1: '96.92%', 2: '88.80%', 3: '94.88%'},
# Val Loss: 0.265198, Val Acc: 90.09%, Val-Class-Acc: {0: '36.03%', 1: '97.86%', 2: '89.21%', 3: '95.16%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.331514, Train-Class-Acc: {0: '34.37%', 1: '96.92%', 2: '88.86%', 3: '94.75%'},
# Val Loss: 0.265260, Val Acc: 90.06%, Val-Class-Acc: {0: '36.72%', 1: '97.90%', 2: '89.38%', 3: '94.86%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.330819, Train-Class-Acc: {0: '34.36%', 1: '96.89%', 2: '89.04%', 3: '94.80%'},
# Val Loss: 0.263229, Val Acc: 90.17%, Val-Class-Acc: {0: '35.88%', 1: '97.87%', 2: '89.65%', 3: '95.34%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_64.pth
# Epoch 65/1000, Train Loss: 0.330159, Train-Class-Acc: {0: '34.38%', 1: '96.95%', 2: '88.90%', 3: '94.79%'},
# Val Loss: 0.264337, Val Acc: 90.05%, Val-Class-Acc: {0: '37.00%', 1: '97.93%', 2: '89.64%', 3: '94.67%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.329475, Train-Class-Acc: {0: '34.61%', 1: '96.89%', 2: '89.27%', 3: '94.74%'},
# Val Loss: 0.263376, Val Acc: 90.07%, Val-Class-Acc: {0: '37.16%', 1: '97.95%', 2: '89.48%', 3: '94.68%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.328768, Train-Class-Acc: {0: '34.87%', 1: '96.93%', 2: '89.16%', 3: '94.66%'},
# Val Loss: 0.262106, Val Acc: 90.11%, Val-Class-Acc: {0: '36.69%', 1: '97.90%', 2: '89.74%', 3: '94.94%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.328217, Train-Class-Acc: {0: '34.35%', 1: '96.93%', 2: '89.25%', 3: '94.85%'},
# Val Loss: 0.260912, Val Acc: 90.15%, Val-Class-Acc: {0: '36.18%', 1: '97.84%', 2: '90.00%', 3: '95.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_60.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_68.pth
# Epoch 69/1000, Train Loss: 0.327488, Train-Class-Acc: {0: '34.99%', 1: '96.91%', 2: '89.39%', 3: '94.67%'},
# Val Loss: 0.261206, Val Acc: 90.07%, Val-Class-Acc: {0: '37.20%', 1: '97.89%', 2: '89.90%', 3: '94.71%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.326826, Train-Class-Acc: {0: '35.00%', 1: '96.94%', 2: '89.42%', 3: '94.69%'},
# Val Loss: 0.260313, Val Acc: 90.09%, Val-Class-Acc: {0: '36.88%', 1: '97.80%', 2: '90.24%', 3: '94.91%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.326232, Train-Class-Acc: {0: '34.99%', 1: '96.89%', 2: '89.68%', 3: '94.73%'},
# Val Loss: 0.260850, Val Acc: 90.06%, Val-Class-Acc: {0: '38.05%', 1: '97.94%', 2: '89.65%', 3: '94.42%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.325706, Train-Class-Acc: {0: '35.14%', 1: '96.94%', 2: '89.54%', 3: '94.69%'},
# Val Loss: 0.260283, Val Acc: 90.05%, Val-Class-Acc: {0: '37.81%', 1: '97.89%', 2: '89.99%', 3: '94.48%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.325049, Train-Class-Acc: {0: '35.34%', 1: '96.94%', 2: '89.59%', 3: '94.65%'},
# Val Loss: 0.258000, Val Acc: 90.14%, Val-Class-Acc: {0: '36.79%', 1: '97.90%', 2: '89.99%', 3: '94.96%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.324490, Train-Class-Acc: {0: '35.38%', 1: '96.94%', 2: '89.72%', 3: '94.66%'},
# Val Loss: 0.256784, Val Acc: 90.23%, Val-Class-Acc: {0: '36.79%', 1: '97.96%', 2: '89.72%', 3: '95.15%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_68.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_74.pth
# Epoch 75/1000, Train Loss: 0.323911, Train-Class-Acc: {0: '35.43%', 1: '96.95%', 2: '89.73%', 3: '94.68%'},
# Val Loss: 0.257737, Val Acc: 90.09%, Val-Class-Acc: {0: '37.47%', 1: '97.82%', 2: '90.32%', 3: '94.71%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.323422, Train-Class-Acc: {0: '35.54%', 1: '96.92%', 2: '89.93%', 3: '94.65%'},
# Val Loss: 0.255936, Val Acc: 90.22%, Val-Class-Acc: {0: '36.99%', 1: '97.94%', 2: '89.94%', 3: '95.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.322844, Train-Class-Acc: {0: '35.77%', 1: '96.94%', 2: '89.88%', 3: '94.58%'},
# Val Loss: 0.256586, Val Acc: 90.18%, Val-Class-Acc: {0: '38.27%', 1: '97.98%', 2: '89.70%', 3: '94.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_64.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_77.pth
# Epoch 78/1000, Train Loss: 0.322397, Train-Class-Acc: {0: '35.72%', 1: '96.96%', 2: '89.79%', 3: '94.62%'},
# Val Loss: 0.256574, Val Acc: 90.15%, Val-Class-Acc: {0: '38.48%', 1: '97.84%', 2: '90.55%', 3: '94.56%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.321797, Train-Class-Acc: {0: '35.81%', 1: '96.92%', 2: '89.98%', 3: '94.63%'},
# Val Loss: 0.256565, Val Acc: 90.16%, Val-Class-Acc: {0: '39.07%', 1: '97.89%', 2: '90.38%', 3: '94.37%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.321308, Train-Class-Acc: {0: '35.99%', 1: '96.94%', 2: '90.04%', 3: '94.58%'},
# Val Loss: 0.254125, Val Acc: 90.27%, Val-Class-Acc: {0: '37.72%', 1: '97.99%', 2: '89.90%', 3: '94.96%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_77.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_80.pth
# Epoch 81/1000, Train Loss: 0.320838, Train-Class-Acc: {0: '35.95%', 1: '96.96%', 2: '90.00%', 3: '94.60%'},
# Val Loss: 0.255802, Val Acc: 90.17%, Val-Class-Acc: {0: '39.46%', 1: '97.89%', 2: '90.32%', 3: '94.31%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.320410, Train-Class-Acc: {0: '35.92%', 1: '96.92%', 2: '90.22%', 3: '94.63%'},
# Val Loss: 0.253928, Val Acc: 90.28%, Val-Class-Acc: {0: '38.93%', 1: '98.07%', 2: '89.61%', 3: '94.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_82.pth
# Epoch 83/1000, Train Loss: 0.319816, Train-Class-Acc: {0: '36.22%', 1: '97.00%', 2: '89.90%', 3: '94.58%'},
# Val Loss: 0.253331, Val Acc: 90.23%, Val-Class-Acc: {0: '38.18%', 1: '97.87%', 2: '90.66%', 3: '94.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.319350, Train-Class-Acc: {0: '36.38%', 1: '96.96%', 2: '90.14%', 3: '94.56%'},
# Val Loss: 0.253776, Val Acc: 90.19%, Val-Class-Acc: {0: '38.64%', 1: '97.77%', 2: '91.01%', 3: '94.63%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.318901, Train-Class-Acc: {0: '36.49%', 1: '96.95%', 2: '90.25%', 3: '94.53%'},
# Val Loss: 0.252761, Val Acc: 90.25%, Val-Class-Acc: {0: '38.72%', 1: '97.90%', 2: '90.65%', 3: '94.66%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_59.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_85.pth
# Epoch 86/1000, Train Loss: 0.318405, Train-Class-Acc: {0: '36.46%', 1: '96.97%', 2: '90.20%', 3: '94.57%'},
# Val Loss: 0.252043, Val Acc: 90.31%, Val-Class-Acc: {0: '39.08%', 1: '98.00%', 2: '90.04%', 3: '94.66%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_86.pth
# Epoch 87/1000, Train Loss: 0.317984, Train-Class-Acc: {0: '36.65%', 1: '96.98%', 2: '90.19%', 3: '94.53%'},
# Val Loss: 0.251588, Val Acc: 90.31%, Val-Class-Acc: {0: '39.00%', 1: '97.93%', 2: '90.49%', 3: '94.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_74.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_87.pth
# Epoch 88/1000, Train Loss: 0.317549, Train-Class-Acc: {0: '36.64%', 1: '96.96%', 2: '90.30%', 3: '94.55%'},
# Val Loss: 0.250453, Val Acc: 90.34%, Val-Class-Acc: {0: '38.65%', 1: '97.97%', 2: '90.24%', 3: '94.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_85.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_88.pth
# Epoch 89/1000, Train Loss: 0.317168, Train-Class-Acc: {0: '36.84%', 1: '96.94%', 2: '90.42%', 3: '94.50%'},
# Val Loss: 0.249691, Val Acc: 90.37%, Val-Class-Acc: {0: '38.49%', 1: '97.94%', 2: '90.31%', 3: '95.01%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_80.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_89.pth
# Epoch 90/1000, Train Loss: 0.316719, Train-Class-Acc: {0: '36.64%', 1: '96.96%', 2: '90.47%', 3: '94.61%'},
# Val Loss: 0.249846, Val Acc: 90.32%, Val-Class-Acc: {0: '38.92%', 1: '98.04%', 2: '89.22%', 3: '94.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_82.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_90.pth
# Epoch 91/1000, Train Loss: 0.316204, Train-Class-Acc: {0: '37.09%', 1: '96.96%', 2: '90.44%', 3: '94.47%'},
# Val Loss: 0.249210, Val Acc: 90.34%, Val-Class-Acc: {0: '38.75%', 1: '97.95%', 2: '89.77%', 3: '94.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_87.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_91.pth
# Epoch 92/1000, Train Loss: 0.315812, Train-Class-Acc: {0: '37.09%', 1: '96.98%', 2: '90.30%', 3: '94.49%'},
# Val Loss: 0.249841, Val Acc: 90.34%, Val-Class-Acc: {0: '39.91%', 1: '97.91%', 2: '90.14%', 3: '94.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_86.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_92.pth
# Epoch 93/1000, Train Loss: 0.315436, Train-Class-Acc: {0: '37.22%', 1: '96.95%', 2: '90.59%', 3: '94.47%'},
# Val Loss: 0.250573, Val Acc: 90.27%, Val-Class-Acc: {0: '40.64%', 1: '97.87%', 2: '90.21%', 3: '94.29%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.315067, Train-Class-Acc: {0: '37.20%', 1: '96.98%', 2: '90.46%', 3: '94.50%'},
# Val Loss: 0.249703, Val Acc: 90.31%, Val-Class-Acc: {0: '40.52%', 1: '97.91%', 2: '89.81%', 3: '94.42%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.314631, Train-Class-Acc: {0: '37.43%', 1: '96.94%', 2: '90.64%', 3: '94.45%'},
# Val Loss: 0.248535, Val Acc: 90.39%, Val-Class-Acc: {0: '40.28%', 1: '97.93%', 2: '89.65%', 3: '94.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_90.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_95.pth
# Epoch 96/1000, Train Loss: 0.314261, Train-Class-Acc: {0: '37.09%', 1: '96.97%', 2: '90.56%', 3: '94.60%'},
# Val Loss: 0.250086, Val Acc: 90.26%, Val-Class-Acc: {0: '41.64%', 1: '97.92%', 2: '89.78%', 3: '94.01%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.313858, Train-Class-Acc: {0: '37.63%', 1: '96.99%', 2: '90.48%', 3: '94.42%'},
# Val Loss: 0.248433, Val Acc: 90.37%, Val-Class-Acc: {0: '40.88%', 1: '97.91%', 2: '89.77%', 3: '94.47%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_92.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_97.pth
# Epoch 98/1000, Train Loss: 0.313466, Train-Class-Acc: {0: '37.63%', 1: '96.94%', 2: '90.78%', 3: '94.44%'},
# Val Loss: 0.247379, Val Acc: 90.41%, Val-Class-Acc: {0: '40.50%', 1: '97.96%', 2: '89.49%', 3: '94.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_91.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_98.pth
# Epoch 99/1000, Train Loss: 0.313072, Train-Class-Acc: {0: '37.50%', 1: '96.99%', 2: '90.62%', 3: '94.53%'},
# Val Loss: 0.248687, Val Acc: 90.32%, Val-Class-Acc: {0: '41.75%', 1: '97.95%', 2: '89.42%', 3: '94.12%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.312746, Train-Class-Acc: {0: '37.74%', 1: '96.97%', 2: '90.65%', 3: '94.44%'},
# Val Loss: 0.245753, Val Acc: 90.48%, Val-Class-Acc: {0: '39.91%', 1: '97.97%', 2: '89.37%', 3: '94.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_88.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_100.pth
# Epoch 101/1000, Train Loss: 0.312481, Train-Class-Acc: {0: '37.56%', 1: '96.95%', 2: '90.83%', 3: '94.51%'},
# Val Loss: 0.245970, Val Acc: 90.45%, Val-Class-Acc: {0: '40.56%', 1: '97.96%', 2: '89.41%', 3: '94.76%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_97.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_101.pth
# Epoch 102/1000, Train Loss: 0.312030, Train-Class-Acc: {0: '37.75%', 1: '96.99%', 2: '90.68%', 3: '94.45%'},
# Val Loss: 0.246059, Val Acc: 90.47%, Val-Class-Acc: {0: '41.09%', 1: '98.15%', 2: '88.22%', 3: '94.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_89.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_102.pth
# Epoch 103/1000, Train Loss: 0.311683, Train-Class-Acc: {0: '37.87%', 1: '96.96%', 2: '90.82%', 3: '94.47%'},
# Val Loss: 0.245339, Val Acc: 90.50%, Val-Class-Acc: {0: '41.08%', 1: '98.06%', 2: '88.83%', 3: '94.69%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_95.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_103.pth
# Epoch 104/1000, Train Loss: 0.311349, Train-Class-Acc: {0: '37.87%', 1: '97.02%', 2: '90.59%', 3: '94.45%'},
# Val Loss: 0.246115, Val Acc: 90.41%, Val-Class-Acc: {0: '41.29%', 1: '97.83%', 2: '90.05%', 3: '94.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_98.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_104.pth
# Epoch 105/1000, Train Loss: 0.311023, Train-Class-Acc: {0: '38.06%', 1: '96.98%', 2: '90.80%', 3: '94.43%'},
# Val Loss: 0.246503, Val Acc: 90.34%, Val-Class-Acc: {0: '41.53%', 1: '97.86%', 2: '89.45%', 3: '94.33%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.310641, Train-Class-Acc: {0: '37.95%', 1: '96.97%', 2: '90.75%', 3: '94.48%'},
# Val Loss: 0.244993, Val Acc: 90.43%, Val-Class-Acc: {0: '41.05%', 1: '97.95%', 2: '89.23%', 3: '94.61%'}, LR: 0.000100
# ...
# Val Loss: 0.222145, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 945/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 946/1000, Train Loss: 0.273639, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222160, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 947/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222146, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 948/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 949/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222146, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 950/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222138, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.30%'}, LR: 0.000000
# Epoch 951/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222151, Val Acc: 91.13%, Val-Class-Acc: {0: '50.10%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 952/1000, Train Loss: 0.273638, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222149, Val Acc: 91.13%, Val-Class-Acc: {0: '50.10%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 953/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222147, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 954/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222152, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 955/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222149, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 956/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222145, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 957/1000, Train Loss: 0.273637, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222151, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 958/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222142, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 959/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222146, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 960/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222146, Val Acc: 91.13%, Val-Class-Acc: {0: '50.10%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 961/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222142, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 962/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222139, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 963/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222151, Val Acc: 91.13%, Val-Class-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_845.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_963.pth
# Epoch 964/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222141, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 965/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222149, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 966/1000, Train Loss: 0.273636, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222145, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 967/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 968/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222144, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 969/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222152, Val Acc: 91.13%, Val-Class-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_938.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_969.pth
# Epoch 970/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222142, Val Acc: 91.13%, Val-Class-Acc: {0: '50.08%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 971/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222147, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 972/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222156, Val Acc: 91.13%, Val-Class-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 973/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222137, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.30%'}, LR: 0.000000
# Epoch 974/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222146, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 975/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222148, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 976/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222141, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 977/1000, Train Loss: 0.273635, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222136, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.30%'}, LR: 0.000000
# Epoch 978/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222147, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 979/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222137, Val Acc: 91.13%, Val-Class-Acc: {0: '50.09%', 1: '97.60%', 2: '90.57%', 3: '94.30%'}, LR: 0.000000
# Epoch 980/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222141, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 981/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 982/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222148, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 983/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222147, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 984/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222144, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 985/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222147, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 986/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222138, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 987/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222142, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 988/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 989/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222144, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 990/1000, Train Loss: 0.273634, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222139, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 991/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222140, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 992/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222141, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 993/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222140, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 994/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 995/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222136, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 996/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222144, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 997/1000, Train Loss: 0.273633, Train-Class-Acc: {0: '45.85%', 1: '97.36%', 2: '92.85%', 3: '94.80%'},
# Val Loss: 0.222139, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 998/1000, Train Loss: 0.273632, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222145, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 999/1000, Train Loss: 0.273632, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222141, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
# Epoch 1000/1000, Train Loss: 0.273632, Train-Class-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222143, Val Acc: 91.13%, Val-Class-Acc: {0: '50.11%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, LR: 0.000000
#
# 🏆 Best model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_best.pth (Val Accuracy: 91.14%)
#
# 📌 Final model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 766, Train Loss: 0.273711, Train-Acc: {0: '45.88%', 1: '97.36%', 2: '92.84%', 3: '94.78%'},
# Val Loss: 0.222223, Val Acc: 91.14%, Val-Acc: {0: '50.14%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_766.pth
# Epoch 742, Train Loss: 0.273732, Train-Acc: {0: '45.87%', 1: '97.35%', 2: '92.85%', 3: '94.78%'},
# Val Loss: 0.222231, Val Acc: 91.13%, Val-Acc: {0: '50.13%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_742.pth
# Epoch 963, Train Loss: 0.273636, Train-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222151, Val Acc: 91.13%, Val-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_963.pth
# Epoch 969, Train Loss: 0.273635, Train-Acc: {0: '45.86%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222152, Val Acc: 91.13%, Val-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_969.pth
# Epoch 861, Train Loss: 0.273657, Train-Acc: {0: '45.87%', 1: '97.36%', 2: '92.85%', 3: '94.79%'},
# Val Loss: 0.222176, Val Acc: 91.13%, Val-Acc: {0: '50.12%', 1: '97.60%', 2: '90.57%', 3: '94.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_3\1st_try\BiGRUWithAttention_epoch_861.pth
#
# ✅ Training Complete. Final model:
# BiGRUWithAttention_LoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=4, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4 (num_layers = 4, lora_r=4)
# + ##### BiGRUWithAttention_LoRA
# + ##### Training and saving in *'Standard_LoRA/Rank_4_Period_4/1st_try'*
# #### __Val Accuracy: 88.21%__
# #### __Val-Class-Acc: {0: '75.26%', 1: '95.05%', 2: '92.39%', 3: '94.41%', 4: '41.75%'}__

# %%
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[3],  # Period 4
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2, 3, 4}
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

print_class_distribution(y_train, "y_train")
print_class_distribution(y_val, "y_val")
print_class_distribution(y_test, "y_test")
# Out:
# Number_features = 7
# unique_classes = [0 1 2 3 4]
# num_classes = 5
# Class Distribution for 'y_train':       Class 0   Percent:   6.47% || Class 1   Percent:  39.17% || Class 2   Percent:   7.24% || Class 3   Percent:  41.06% || Class 4   Percent:   6.06%
# Class Distribution for 'y_val':         Class 0   Percent:   5.35% || Class 1   Percent:  36.15% || Class 2   Percent:  14.78% || Class 3   Percent:  34.02% || Class 4   Percent:   9.70%
# Class Distribution for 'y_test':        Class 0   Percent:   6.63% || Class 1   Percent:  40.53% || Class 2   Percent:   5.48% || Class 3   Percent:  41.29% || Class 4   Percent:   6.08%

# %%
# ==== Model Hyperparameters ====
input_size = Number_features
hidden_size = 64
output_size = num_classes
num_layers = 4
dropout = 0.0
lora_r = 4
num_epochs = 1000
batch_size = 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ==== Paths ====
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))
model_saving_folder = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_4/1st_try"
))
ensure_folder(model_saving_folder)

# ==== Load previous model (Period 3) ====
previous_model_path = os.path.normpath(os.path.join(
    'Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Standard_LoRA/Rank_4_Period_3/1st_try", "BiGRUWithAttention_best.pth"
))
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# ==== Initialize model and LoRA ====
model = BiGRUWithAttention_LoRA(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    num_layers=num_layers,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

model.init_lora()

# ==== Load GRU + attention_fc + LoRA weights ====
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc.")
}, strict=False)

print("✅ Model loaded (GRU, attention_fc, and LoRA). FC layer reinitialized.")

# ==== Training Setup ====
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.get_trainable_parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

train_lora_baseline(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    scheduler=scheduler,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name='BiGRUWithAttention',
    stop_signal_file=stop_signal_file
)

print(f"\n✅ Training Complete. Final model: \n{model}")
print(f"unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, X_test, y_test, Number_features, unique_classes, num_classes
gc.collect()
torch.cuda.empty_cache()
# Out:
# Initialized LoRA adapter
# ✅ Model loaded (GRU, attention_fc, and LoRA). FC layer reinitialized.
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc.weight
#   ✅ fc.bias
#
# 🚀 'train_lora_baseline' started.
# ✅ Removed existing folder: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try
#
# ✅ Data Overview:
# X_train: torch.Size([3634, 1000, 7]), y_train: torch.Size([3634, 1000])
# X_val: torch.Size([454, 1000, 7]), y_val: torch.Size([454, 1000])
# C:\Users\james\AppData\Local\Temp\ipykernel_169508\1350849705.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 1.441725, Train-Class-Acc: {0: '21.80%', 1: '17.00%', 2: '1.15%', 3: '56.43%', 4: '3.46%'},
# Val Loss: 1.389300, Val Acc: 41.29%, Val-Class-Acc: {0: '24.16%', 1: '42.66%', 2: '1.81%', 3: '70.32%', 4: '3.98%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_1.pth
# Epoch 2/1000, Train Loss: 1.138782, Train-Class-Acc: {0: '16.44%', 1: '60.53%', 2: '0.86%', 3: '76.20%', 4: '2.91%'},
# Val Loss: 1.189568, Val Acc: 56.24%, Val-Class-Acc: {0: '18.15%', 1: '74.60%', 2: '1.48%', 3: '81.57%', 4: '3.47%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.955387, Train-Class-Acc: {0: '13.49%', 1: '80.63%', 2: '0.89%', 3: '84.97%', 4: '1.92%'},
# Val Loss: 1.042064, Val Acc: 62.33%, Val-Class-Acc: {0: '15.63%', 1: '86.88%', 2: '1.73%', 3: '86.96%', 4: '2.54%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.829823, Train-Class-Acc: {0: '13.05%', 1: '91.70%', 2: '1.36%', 3: '89.32%', 4: '1.20%'},
# Val Loss: 0.933379, Val Acc: 66.11%, Val-Class-Acc: {0: '15.49%', 1: '94.69%', 2: '3.55%', 3: '89.22%', 4: '1.81%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.744885, Train-Class-Acc: {0: '13.89%', 1: '96.45%', 2: '4.82%', 3: '91.33%', 4: '0.92%'},
# Val Loss: 0.855193, Val Acc: 68.14%, Val-Class-Acc: {0: '15.34%', 1: '96.78%', 2: '9.10%', 3: '90.62%', 4: '1.63%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.683473, Train-Class-Acc: {0: '14.49%', 1: '97.31%', 2: '14.20%', 3: '92.64%', 4: '0.74%'},
# Val Loss: 0.790483, Val Acc: 70.43%, Val-Class-Acc: {0: '15.69%', 1: '97.13%', 2: '20.86%', 3: '91.90%', 4: '1.34%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.635508, Train-Class-Acc: {0: '15.54%', 1: '97.68%', 2: '27.13%', 3: '93.63%', 4: '0.62%'},
# Val Loss: 0.739066, Val Acc: 73.19%, Val-Class-Acc: {0: '16.64%', 1: '96.79%', 2: '37.73%', 3: '92.96%', 4: '1.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.596658, Train-Class-Acc: {0: '17.44%', 1: '97.83%', 2: '39.78%', 3: '94.44%', 4: '0.50%'},
# Val Loss: 0.694511, Val Acc: 75.55%, Val-Class-Acc: {0: '19.89%', 1: '96.56%', 2: '51.45%', 3: '93.72%', 4: '0.97%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.564568, Train-Class-Acc: {0: '20.94%', 1: '97.84%', 2: '48.93%', 3: '95.05%', 4: '0.43%'},
# Val Loss: 0.658811, Val Acc: 77.07%, Val-Class-Acc: {0: '23.69%', 1: '96.37%', 2: '59.58%', 3: '94.26%', 4: '0.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.537835, Train-Class-Acc: {0: '26.88%', 1: '97.77%', 2: '55.98%', 3: '95.39%', 4: '0.32%'},
# Val Loss: 0.627696, Val Acc: 78.60%, Val-Class-Acc: {0: '29.83%', 1: '96.19%', 2: '67.34%', 3: '94.67%', 4: '0.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.515324, Train-Class-Acc: {0: '32.10%', 1: '97.76%', 2: '60.48%', 3: '95.61%', 4: '0.28%'},
# Val Loss: 0.601751, Val Acc: 79.42%, Val-Class-Acc: {0: '33.14%', 1: '96.13%', 2: '71.65%', 3: '94.81%', 4: '0.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.496206, Train-Class-Acc: {0: '35.61%', 1: '97.74%', 2: '63.78%', 3: '95.77%', 4: '0.25%'},
# Val Loss: 0.579879, Val Acc: 80.04%, Val-Class-Acc: {0: '36.19%', 1: '96.11%', 2: '74.43%', 3: '95.01%', 4: '0.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.479837, Train-Class-Acc: {0: '38.21%', 1: '97.65%', 2: '67.28%', 3: '95.87%', 4: '0.21%'},
# Val Loss: 0.560980, Val Acc: 80.55%, Val-Class-Acc: {0: '38.57%', 1: '96.08%', 2: '76.81%', 3: '95.17%', 4: '0.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.465670, Train-Class-Acc: {0: '40.28%', 1: '97.57%', 2: '69.63%', 3: '95.93%', 4: '0.19%'},
# Val Loss: 0.544635, Val Acc: 80.93%, Val-Class-Acc: {0: '40.33%', 1: '95.99%', 2: '78.54%', 3: '95.34%', 4: '0.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.453329, Train-Class-Acc: {0: '41.66%', 1: '97.53%', 2: '71.44%', 3: '96.01%', 4: '0.17%'},
# Val Loss: 0.529645, Val Acc: 81.24%, Val-Class-Acc: {0: '40.61%', 1: '95.96%', 2: '80.40%', 3: '95.46%', 4: '0.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.442510, Train-Class-Acc: {0: '42.68%', 1: '97.48%', 2: '73.30%', 3: '96.09%', 4: '0.15%'},
# Val Loss: 0.516172, Val Acc: 81.50%, Val-Class-Acc: {0: '41.06%', 1: '95.88%', 2: '82.01%', 3: '95.53%', 4: '0.22%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.432914, Train-Class-Acc: {0: '43.64%', 1: '97.46%', 2: '74.45%', 3: '96.15%', 4: '0.17%'},
# Val Loss: 0.506152, Val Acc: 81.73%, Val-Class-Acc: {0: '41.42%', 1: '95.89%', 2: '83.16%', 3: '95.65%', 4: '0.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.424354, Train-Class-Acc: {0: '44.25%', 1: '97.41%', 2: '75.66%', 3: '96.22%', 4: '0.35%'},
# Val Loss: 0.496649, Val Acc: 81.95%, Val-Class-Acc: {0: '41.48%', 1: '95.83%', 2: '84.38%', 3: '95.73%', 4: '0.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.416639, Train-Class-Acc: {0: '45.22%', 1: '97.38%', 2: '76.49%', 3: '96.24%', 4: '0.50%'},
# Val Loss: 0.486682, Val Acc: 82.18%, Val-Class-Acc: {0: '41.96%', 1: '95.78%', 2: '85.25%', 3: '95.79%', 4: '1.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.409693, Train-Class-Acc: {0: '45.75%', 1: '97.35%', 2: '77.27%', 3: '96.27%', 4: '1.31%'},
# Val Loss: 0.478412, Val Acc: 82.39%, Val-Class-Acc: {0: '42.72%', 1: '95.74%', 2: '85.83%', 3: '95.75%', 4: '2.45%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.403399, Train-Class-Acc: {0: '46.05%', 1: '97.29%', 2: '78.37%', 3: '96.28%', 4: '3.12%'},
# Val Loss: 0.473037, Val Acc: 82.50%, Val-Class-Acc: {0: '42.93%', 1: '95.73%', 2: '86.28%', 3: '95.82%', 4: '2.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.397680, Train-Class-Acc: {0: '46.58%', 1: '97.27%', 2: '78.84%', 3: '96.28%', 4: '4.11%'},
# Val Loss: 0.465519, Val Acc: 82.73%, Val-Class-Acc: {0: '43.25%', 1: '95.69%', 2: '86.71%', 3: '95.85%', 4: '4.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.392326, Train-Class-Acc: {0: '47.03%', 1: '97.25%', 2: '79.28%', 3: '96.26%', 4: '5.50%'},
# Val Loss: 0.458483, Val Acc: 82.99%, Val-Class-Acc: {0: '43.61%', 1: '95.61%', 2: '87.31%', 3: '95.84%', 4: '5.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.387501, Train-Class-Acc: {0: '47.36%', 1: '97.21%', 2: '79.88%', 3: '96.25%', 4: '7.16%'},
# Val Loss: 0.453983, Val Acc: 83.10%, Val-Class-Acc: {0: '44.20%', 1: '95.60%', 2: '87.69%', 3: '95.88%', 4: '6.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.382994, Train-Class-Acc: {0: '47.76%', 1: '97.18%', 2: '80.27%', 3: '96.24%', 4: '8.04%'},
# Val Loss: 0.448027, Val Acc: 83.28%, Val-Class-Acc: {0: '44.76%', 1: '95.44%', 2: '88.20%', 3: '95.88%', 4: '7.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.378799, Train-Class-Acc: {0: '48.30%', 1: '97.14%', 2: '80.65%', 3: '96.19%', 4: '9.88%'},
# Val Loss: 0.442537, Val Acc: 83.49%, Val-Class-Acc: {0: '45.60%', 1: '95.43%', 2: '88.61%', 3: '95.82%', 4: '8.87%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.374911, Train-Class-Acc: {0: '48.56%', 1: '97.13%', 2: '80.92%', 3: '96.17%', 4: '11.78%'},
# Val Loss: 0.438606, Val Acc: 83.62%, Val-Class-Acc: {0: '45.90%', 1: '95.40%', 2: '88.87%', 3: '95.87%', 4: '9.60%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.371260, Train-Class-Acc: {0: '48.95%', 1: '97.09%', 2: '81.21%', 3: '96.07%', 4: '13.44%'},
# Val Loss: 0.434725, Val Acc: 83.71%, Val-Class-Acc: {0: '46.74%', 1: '95.37%', 2: '89.10%', 3: '95.79%', 4: '10.11%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.367822, Train-Class-Acc: {0: '49.30%', 1: '97.06%', 2: '81.61%', 3: '96.06%', 4: '14.14%'},
# Val Loss: 0.431436, Val Acc: 83.83%, Val-Class-Acc: {0: '47.29%', 1: '95.35%', 2: '89.28%', 3: '95.82%', 4: '10.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.364584, Train-Class-Acc: {0: '49.75%', 1: '97.07%', 2: '81.68%', 3: '96.03%', 4: '15.05%'},
# Val Loss: 0.427240, Val Acc: 83.99%, Val-Class-Acc: {0: '47.96%', 1: '95.33%', 2: '89.44%', 3: '95.69%', 4: '12.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.361518, Train-Class-Acc: {0: '50.25%', 1: '97.04%', 2: '82.04%', 3: '96.02%', 4: '15.64%'},
# Val Loss: 0.422553, Val Acc: 84.24%, Val-Class-Acc: {0: '48.43%', 1: '95.30%', 2: '89.60%', 3: '95.52%', 4: '15.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.358585, Train-Class-Acc: {0: '50.75%', 1: '97.02%', 2: '82.28%', 3: '95.95%', 4: '16.57%'},
# Val Loss: 0.420445, Val Acc: 84.29%, Val-Class-Acc: {0: '48.97%', 1: '95.29%', 2: '89.79%', 3: '95.57%', 4: '14.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.355865, Train-Class-Acc: {0: '50.96%', 1: '96.97%', 2: '82.61%', 3: '95.90%', 4: '17.31%'},
# Val Loss: 0.418375, Val Acc: 84.34%, Val-Class-Acc: {0: '49.88%', 1: '95.30%', 2: '89.79%', 3: '95.63%', 4: '14.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.353224, Train-Class-Acc: {0: '51.34%', 1: '97.02%', 2: '82.51%', 3: '95.99%', 4: '17.03%'},
# Val Loss: 0.414562, Val Acc: 84.51%, Val-Class-Acc: {0: '50.19%', 1: '95.27%', 2: '89.98%', 3: '95.40%', 4: '16.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.350627, Train-Class-Acc: {0: '51.97%', 1: '96.99%', 2: '82.91%', 3: '95.90%', 4: '17.82%'},
# Val Loss: 0.410365, Val Acc: 84.70%, Val-Class-Acc: {0: '50.61%', 1: '95.23%', 2: '90.17%', 3: '95.20%', 4: '19.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.348334, Train-Class-Acc: {0: '52.13%', 1: '96.96%', 2: '83.15%', 3: '95.87%', 4: '18.53%'},
# Val Loss: 0.407863, Val Acc: 84.76%, Val-Class-Acc: {0: '51.03%', 1: '95.23%', 2: '90.27%', 3: '95.23%', 4: '19.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.345883, Train-Class-Acc: {0: '52.45%', 1: '96.92%', 2: '83.46%', 3: '95.95%', 4: '18.34%'},
# Val Loss: 0.406651, Val Acc: 84.75%, Val-Class-Acc: {0: '51.53%', 1: '95.26%', 2: '90.28%', 3: '95.41%', 4: '18.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.343662, Train-Class-Acc: {0: '52.98%', 1: '96.99%', 2: '83.29%', 3: '95.88%', 4: '18.91%'},
# Val Loss: 0.404802, Val Acc: 84.78%, Val-Class-Acc: {0: '51.83%', 1: '95.25%', 2: '90.36%', 3: '95.45%', 4: '18.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.341504, Train-Class-Acc: {0: '53.22%', 1: '96.96%', 2: '83.58%', 3: '95.84%', 4: '19.76%'},
# Val Loss: 0.403196, Val Acc: 84.82%, Val-Class-Acc: {0: '52.02%', 1: '95.21%', 2: '90.60%', 3: '95.50%', 4: '17.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.339481, Train-Class-Acc: {0: '53.69%', 1: '96.94%', 2: '83.77%', 3: '95.95%', 4: '19.14%'},
# Val Loss: 0.398788, Val Acc: 84.99%, Val-Class-Acc: {0: '52.29%', 1: '95.21%', 2: '90.66%', 3: '95.21%', 4: '20.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.337407, Train-Class-Acc: {0: '54.23%', 1: '96.96%', 2: '83.80%', 3: '95.92%', 4: '19.56%'},
# Val Loss: 0.395554, Val Acc: 85.06%, Val-Class-Acc: {0: '52.78%', 1: '95.18%', 2: '90.72%', 3: '94.83%', 4: '22.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_41.pth
# Epoch 42/1000, Train Loss: 0.335479, Train-Class-Acc: {0: '54.40%', 1: '96.92%', 2: '84.14%', 3: '95.94%', 4: '19.87%'},
# Val Loss: 0.393929, Val Acc: 85.19%, Val-Class-Acc: {0: '53.46%', 1: '95.20%', 2: '90.94%', 3: '94.67%', 4: '23.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.333589, Train-Class-Acc: {0: '55.24%', 1: '96.96%', 2: '84.09%', 3: '95.83%', 4: '20.40%'},
# Val Loss: 0.393073, Val Acc: 85.10%, Val-Class-Acc: {0: '53.68%', 1: '95.22%', 2: '90.82%', 3: '95.24%', 4: '20.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.331751, Train-Class-Acc: {0: '55.33%', 1: '96.91%', 2: '84.32%', 3: '95.87%', 4: '20.45%'},
# Val Loss: 0.391110, Val Acc: 85.23%, Val-Class-Acc: {0: '54.38%', 1: '95.24%', 2: '91.09%', 3: '94.97%', 4: '21.84%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.329991, Train-Class-Acc: {0: '55.81%', 1: '96.94%', 2: '84.39%', 3: '95.91%', 4: '20.17%'},
# Val Loss: 0.389433, Val Acc: 85.23%, Val-Class-Acc: {0: '55.07%', 1: '95.25%', 2: '90.99%', 3: '95.07%', 4: '21.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.328269, Train-Class-Acc: {0: '56.09%', 1: '96.95%', 2: '84.34%', 3: '95.88%', 4: '20.60%'},
# Val Loss: 0.387000, Val Acc: 85.36%, Val-Class-Acc: {0: '55.40%', 1: '95.18%', 2: '91.30%', 3: '94.76%', 4: '23.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.326652, Train-Class-Acc: {0: '56.64%', 1: '96.95%', 2: '84.42%', 3: '95.82%', 4: '20.81%'},
# Val Loss: 0.384717, Val Acc: 85.48%, Val-Class-Acc: {0: '55.76%', 1: '95.14%', 2: '91.44%', 3: '94.57%', 4: '24.94%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.324968, Train-Class-Acc: {0: '56.93%', 1: '96.89%', 2: '84.80%', 3: '95.90%', 4: '20.67%'},
# Val Loss: 0.382598, Val Acc: 85.54%, Val-Class-Acc: {0: '56.07%', 1: '95.16%', 2: '91.43%', 3: '94.57%', 4: '25.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.323446, Train-Class-Acc: {0: '57.25%', 1: '96.86%', 2: '85.00%', 3: '95.73%', 4: '21.69%'},
# Val Loss: 0.384807, Val Acc: 85.30%, Val-Class-Acc: {0: '57.24%', 1: '95.22%', 2: '91.26%', 3: '95.35%', 4: '19.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.321967, Train-Class-Acc: {0: '57.64%', 1: '96.91%', 2: '84.98%', 3: '95.90%', 4: '20.68%'},
# Val Loss: 0.379491, Val Acc: 85.55%, Val-Class-Acc: {0: '56.73%', 1: '95.18%', 2: '91.27%', 3: '94.74%', 4: '24.64%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_50.pth
# Epoch 51/1000, Train Loss: 0.320415, Train-Class-Acc: {0: '57.79%', 1: '96.98%', 2: '84.76%', 3: '95.81%', 4: '21.48%'},
# Val Loss: 0.377833, Val Acc: 85.69%, Val-Class-Acc: {0: '57.65%', 1: '95.14%', 2: '91.55%', 3: '94.59%', 4: '25.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.318980, Train-Class-Acc: {0: '58.23%', 1: '96.85%', 2: '85.37%', 3: '95.84%', 4: '21.34%'},
# Val Loss: 0.376872, Val Acc: 85.67%, Val-Class-Acc: {0: '58.26%', 1: '95.16%', 2: '91.39%', 3: '94.81%', 4: '24.66%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.317521, Train-Class-Acc: {0: '58.76%', 1: '96.93%', 2: '85.13%', 3: '95.79%', 4: '21.61%'},
# Val Loss: 0.374726, Val Acc: 85.77%, Val-Class-Acc: {0: '58.53%', 1: '95.09%', 2: '91.61%', 3: '94.66%', 4: '25.97%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.316201, Train-Class-Acc: {0: '58.80%', 1: '96.84%', 2: '85.58%', 3: '95.82%', 4: '21.68%'},
# Val Loss: 0.373722, Val Acc: 85.78%, Val-Class-Acc: {0: '59.16%', 1: '95.14%', 2: '91.48%', 3: '94.77%', 4: '25.35%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_54.pth
# Epoch 55/1000, Train Loss: 0.314885, Train-Class-Acc: {0: '59.40%', 1: '96.92%', 2: '85.36%', 3: '95.80%', 4: '21.78%'},
# Val Loss: 0.375258, Val Acc: 85.61%, Val-Class-Acc: {0: '59.43%', 1: '95.16%', 2: '91.51%', 3: '95.29%', 4: '21.60%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_50.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.313645, Train-Class-Acc: {0: '59.79%', 1: '96.88%', 2: '85.50%', 3: '95.81%', 4: '21.73%'},
# Val Loss: 0.372519, Val Acc: 85.79%, Val-Class-Acc: {0: '59.73%', 1: '95.15%', 2: '91.65%', 3: '94.96%', 4: '24.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.312360, Train-Class-Acc: {0: '59.92%', 1: '96.88%', 2: '85.61%', 3: '95.82%', 4: '21.82%'},
# Val Loss: 0.369379, Val Acc: 85.88%, Val-Class-Acc: {0: '60.08%', 1: '95.12%', 2: '91.59%', 3: '94.56%', 4: '26.55%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_52.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.311078, Train-Class-Acc: {0: '60.25%', 1: '96.87%', 2: '85.77%', 3: '95.78%', 4: '22.21%'},
# Val Loss: 0.370317, Val Acc: 85.78%, Val-Class-Acc: {0: '60.58%', 1: '95.14%', 2: '91.40%', 3: '95.15%', 4: '23.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_58.pth
# Epoch 59/1000, Train Loss: 0.309943, Train-Class-Acc: {0: '60.50%', 1: '96.91%', 2: '85.65%', 3: '95.83%', 4: '22.03%'},
# Val Loss: 0.366731, Val Acc: 86.02%, Val-Class-Acc: {0: '60.70%', 1: '95.04%', 2: '91.94%', 3: '94.57%', 4: '27.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_59.pth
# Epoch 60/1000, Train Loss: 0.308763, Train-Class-Acc: {0: '60.89%', 1: '96.90%', 2: '85.76%', 3: '95.81%', 4: '22.16%'},
# Val Loss: 0.367685, Val Acc: 85.97%, Val-Class-Acc: {0: '61.53%', 1: '95.03%', 2: '92.02%', 3: '94.75%', 4: '25.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_54.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_60.pth
# Epoch 61/1000, Train Loss: 0.307656, Train-Class-Acc: {0: '61.41%', 1: '96.86%', 2: '85.93%', 3: '95.77%', 4: '22.38%'},
# Val Loss: 0.367092, Val Acc: 85.85%, Val-Class-Acc: {0: '61.47%', 1: '95.07%', 2: '91.53%', 3: '95.04%', 4: '24.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_58.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.306582, Train-Class-Acc: {0: '61.22%', 1: '96.88%', 2: '86.00%', 3: '95.81%', 4: '22.43%'},
# Val Loss: 0.364988, Val Acc: 85.96%, Val-Class-Acc: {0: '61.79%', 1: '95.08%', 2: '91.58%', 3: '94.86%', 4: '25.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.305465, Train-Class-Acc: {0: '61.89%', 1: '96.88%', 2: '86.10%', 3: '95.78%', 4: '22.43%'},
# Val Loss: 0.362767, Val Acc: 86.07%, Val-Class-Acc: {0: '62.21%', 1: '95.11%', 2: '91.55%', 3: '94.62%', 4: '27.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_63.pth
# Epoch 64/1000, Train Loss: 0.304406, Train-Class-Acc: {0: '62.18%', 1: '96.86%', 2: '86.20%', 3: '95.79%', 4: '22.58%'},
# Val Loss: 0.362430, Val Acc: 86.05%, Val-Class-Acc: {0: '62.80%', 1: '95.07%', 2: '91.64%', 3: '94.84%', 4: '25.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_64.pth
# Epoch 65/1000, Train Loss: 0.303459, Train-Class-Acc: {0: '62.16%', 1: '96.90%', 2: '86.19%', 3: '95.86%', 4: '22.38%'},
# Val Loss: 0.362128, Val Acc: 86.08%, Val-Class-Acc: {0: '63.07%', 1: '95.07%', 2: '91.67%', 3: '94.90%', 4: '25.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_65.pth
# Epoch 66/1000, Train Loss: 0.302483, Train-Class-Acc: {0: '62.81%', 1: '96.89%', 2: '86.18%', 3: '95.78%', 4: '22.71%'},
# Val Loss: 0.360420, Val Acc: 86.12%, Val-Class-Acc: {0: '63.17%', 1: '95.01%', 2: '91.92%', 3: '94.87%', 4: '26.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_60.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.301485, Train-Class-Acc: {0: '62.63%', 1: '96.86%', 2: '86.43%', 3: '95.82%', 4: '22.88%'},
# Val Loss: 0.358004, Val Acc: 86.26%, Val-Class-Acc: {0: '63.61%', 1: '95.06%', 2: '91.81%', 3: '94.50%', 4: '28.65%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_59.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_67.pth
# Epoch 68/1000, Train Loss: 0.300525, Train-Class-Acc: {0: '63.42%', 1: '96.90%', 2: '86.28%', 3: '95.84%', 4: '22.66%'},
# Val Loss: 0.356250, Val Acc: 86.31%, Val-Class-Acc: {0: '63.21%', 1: '95.06%', 2: '91.85%', 3: '94.38%', 4: '29.69%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_64.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_68.pth
# Epoch 69/1000, Train Loss: 0.299669, Train-Class-Acc: {0: '63.38%', 1: '96.89%', 2: '86.39%', 3: '95.76%', 4: '23.26%'},
# Val Loss: 0.356253, Val Acc: 86.32%, Val-Class-Acc: {0: '63.30%', 1: '95.01%', 2: '92.13%', 3: '94.57%', 4: '28.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_63.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_69.pth
# Epoch 70/1000, Train Loss: 0.298887, Train-Class-Acc: {0: '63.42%', 1: '96.89%', 2: '86.59%', 3: '95.87%', 4: '22.96%'},
# Val Loss: 0.355308, Val Acc: 86.35%, Val-Class-Acc: {0: '64.02%', 1: '95.04%', 2: '91.98%', 3: '94.48%', 4: '29.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_65.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_70.pth
# Epoch 71/1000, Train Loss: 0.297780, Train-Class-Acc: {0: '63.99%', 1: '96.89%', 2: '86.72%', 3: '95.73%', 4: '23.51%'},
# Val Loss: 0.357630, Val Acc: 86.13%, Val-Class-Acc: {0: '64.28%', 1: '95.05%', 2: '91.84%', 3: '95.15%', 4: '24.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_71.pth
# Epoch 72/1000, Train Loss: 0.297030, Train-Class-Acc: {0: '63.94%', 1: '96.92%', 2: '86.56%', 3: '95.87%', 4: '22.94%'},
# Val Loss: 0.355565, Val Acc: 86.31%, Val-Class-Acc: {0: '64.54%', 1: '95.03%', 2: '92.16%', 3: '94.80%', 4: '27.15%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_71.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.296128, Train-Class-Acc: {0: '64.34%', 1: '96.87%', 2: '86.87%', 3: '95.84%', 4: '23.24%'},
# Val Loss: 0.354867, Val Acc: 86.29%, Val-Class-Acc: {0: '64.68%', 1: '95.06%', 2: '91.91%', 3: '95.00%', 4: '26.45%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_67.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_73.pth
# Epoch 74/1000, Train Loss: 0.295375, Train-Class-Acc: {0: '64.54%', 1: '96.87%', 2: '86.94%', 3: '95.83%', 4: '23.40%'},
# Val Loss: 0.352225, Val Acc: 86.41%, Val-Class-Acc: {0: '64.46%', 1: '95.05%', 2: '92.07%', 3: '94.56%', 4: '29.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_73.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_74.pth
# Epoch 75/1000, Train Loss: 0.294491, Train-Class-Acc: {0: '64.54%', 1: '96.92%', 2: '86.78%', 3: '95.82%', 4: '23.56%'},
# Val Loss: 0.352317, Val Acc: 86.36%, Val-Class-Acc: {0: '64.94%', 1: '95.05%', 2: '91.95%', 3: '94.88%', 4: '27.40%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_68.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_75.pth
# Epoch 76/1000, Train Loss: 0.293782, Train-Class-Acc: {0: '64.80%', 1: '96.90%', 2: '86.88%', 3: '95.82%', 4: '23.59%'},
# Val Loss: 0.351426, Val Acc: 86.42%, Val-Class-Acc: {0: '65.06%', 1: '95.03%', 2: '92.20%', 3: '94.70%', 4: '28.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.293041, Train-Class-Acc: {0: '65.05%', 1: '96.89%', 2: '87.02%', 3: '95.79%', 4: '23.72%'},
# Val Loss: 0.352604, Val Acc: 86.35%, Val-Class-Acc: {0: '65.38%', 1: '95.01%', 2: '92.24%', 3: '95.11%', 4: '25.96%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_69.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_77.pth
# Epoch 78/1000, Train Loss: 0.292531, Train-Class-Acc: {0: '65.15%', 1: '96.91%', 2: '86.96%', 3: '95.84%', 4: '23.39%'},
# Val Loss: 0.348464, Val Acc: 86.58%, Val-Class-Acc: {0: '65.29%', 1: '95.03%', 2: '92.42%', 3: '94.32%', 4: '30.82%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_70.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_78.pth
# Epoch 79/1000, Train Loss: 0.291516, Train-Class-Acc: {0: '65.37%', 1: '96.85%', 2: '87.37%', 3: '95.87%', 4: '23.49%'},
# Val Loss: 0.348113, Val Acc: 86.49%, Val-Class-Acc: {0: '65.58%', 1: '95.07%', 2: '91.97%', 3: '94.38%', 4: '30.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_77.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_79.pth
# Epoch 80/1000, Train Loss: 0.290828, Train-Class-Acc: {0: '65.45%', 1: '96.93%', 2: '86.97%', 3: '95.81%', 4: '23.80%'},
# Val Loss: 0.347780, Val Acc: 86.52%, Val-Class-Acc: {0: '65.77%', 1: '95.07%', 2: '92.07%', 3: '94.46%', 4: '29.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_75.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_80.pth
# Epoch 81/1000, Train Loss: 0.290164, Train-Class-Acc: {0: '65.69%', 1: '96.92%', 2: '87.12%', 3: '95.85%', 4: '23.68%'},
# Val Loss: 0.347090, Val Acc: 86.55%, Val-Class-Acc: {0: '65.95%', 1: '95.04%', 2: '92.32%', 3: '94.36%', 4: '30.11%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_74.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.289419, Train-Class-Acc: {0: '65.93%', 1: '96.89%', 2: '87.38%', 3: '95.79%', 4: '24.04%'},
# Val Loss: 0.348384, Val Acc: 86.40%, Val-Class-Acc: {0: '66.05%', 1: '95.07%', 2: '91.63%', 3: '94.90%', 4: '27.52%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.288825, Train-Class-Acc: {0: '65.97%', 1: '96.87%', 2: '87.48%', 3: '95.79%', 4: '24.23%'},
# Val Loss: 0.348422, Val Acc: 86.45%, Val-Class-Acc: {0: '66.44%', 1: '95.07%', 2: '91.90%', 3: '94.97%', 4: '27.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.288201, Train-Class-Acc: {0: '66.20%', 1: '96.93%', 2: '87.36%', 3: '95.87%', 4: '23.56%'},
# Val Loss: 0.348747, Val Acc: 86.45%, Val-Class-Acc: {0: '66.74%', 1: '95.04%', 2: '92.06%', 3: '95.17%', 4: '26.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_84.pth
# Epoch 85/1000, Train Loss: 0.287611, Train-Class-Acc: {0: '66.37%', 1: '96.91%', 2: '87.44%', 3: '95.81%', 4: '24.02%'},
# Val Loss: 0.345909, Val Acc: 86.53%, Val-Class-Acc: {0: '66.66%', 1: '95.05%', 2: '91.99%', 3: '94.76%', 4: '28.60%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_84.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_85.pth
# Epoch 86/1000, Train Loss: 0.286862, Train-Class-Acc: {0: '66.49%', 1: '96.95%', 2: '87.24%', 3: '95.79%', 4: '24.22%'},
# Val Loss: 0.345563, Val Acc: 86.58%, Val-Class-Acc: {0: '67.10%', 1: '95.03%', 2: '92.28%', 3: '94.80%', 4: '28.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_79.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_86.pth
# Epoch 87/1000, Train Loss: 0.286349, Train-Class-Acc: {0: '66.73%', 1: '96.90%', 2: '87.63%', 3: '95.79%', 4: '24.16%'},
# Val Loss: 0.346693, Val Acc: 86.54%, Val-Class-Acc: {0: '66.98%', 1: '95.02%', 2: '92.28%', 3: '95.11%', 4: '26.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_80.pth
# ✅ Saved model: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_87.pth
# Epoch 88/1000, Train Loss: 0.285745, Train-Class-Acc: {0: '66.91%', 1: '96.90%', 2: '87.65%', 3: '95.83%', 4: '23.99%'},
# Val Loss: 0.343152, Val Acc: 86.67%, Val-Class-Acc: {0: '67.15%', 1: '95.04%', 2: '92.12%', 3: '94.62%', 4: '30.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_85.pth
# ...
# Val Loss: 0.313301, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 949/1000, Train Loss: 0.241843, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.06%'},
# Val Loss: 0.313295, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.03%'}, LR: 0.000000
# Epoch 950/1000, Train Loss: 0.241843, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.06%'},
# Val Loss: 0.313303, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 951/1000, Train Loss: 0.241843, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.06%'},
# Val Loss: 0.313303, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 952/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 953/1000, Train Loss: 0.241843, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313313, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 954/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313315, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 955/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.03%'},
# Val Loss: 0.313312, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 956/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313307, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 957/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313307, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 958/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.06%'},
# Val Loss: 0.313304, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 959/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313306, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 960/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313312, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 961/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313305, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 962/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313308, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 963/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 964/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313301, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 965/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313316, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 966/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313308, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 967/1000, Train Loss: 0.241842, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.03%'},
# Val Loss: 0.313317, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 968/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.03%'},
# Val Loss: 0.313314, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 969/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313310, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 970/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313313, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 971/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313308, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 972/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313311, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 973/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313316, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 974/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 975/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313301, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 976/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313316, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 977/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313312, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 978/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313315, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 979/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313313, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 980/1000, Train Loss: 0.241841, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313312, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 981/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 982/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313311, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 983/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313312, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 984/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313303, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.55%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 985/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313311, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 986/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313307, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 987/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313310, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.55%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 988/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313306, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 989/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313311, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 990/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313315, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.31%', 4: '38.00%'}, LR: 0.000000
# Epoch 991/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313303, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 992/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313306, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 993/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 994/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313313, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 995/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 996/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.03%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 997/1000, Train Loss: 0.241840, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.60%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 998/1000, Train Loss: 0.241839, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.04%'},
# Val Loss: 0.313309, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.56%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 999/1000, Train Loss: 0.241839, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313305, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.55%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
# Epoch 1000/1000, Train Loss: 0.241839, Train-Class-Acc: {0: '76.47%', 1: '97.25%', 2: '90.59%', 3: '95.79%', 4: '30.05%'},
# Val Loss: 0.313311, Val Acc: 88.03%, Val-Class-Acc: {0: '76.77%', 1: '94.84%', 2: '91.55%', 3: '95.30%', 4: '38.00%'}, LR: 0.000000
#
# 🏆 Best model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_best.pth (Val Accuracy: 88.21%)
#
# 📌 Final model saved as: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 252, Train Loss: 0.249542, Train-Acc: {0: '75.13%', 1: '97.12%', 2: '90.18%', 3: '95.80%', 4: '28.93%'},
# Val Loss: 0.312897, Val Acc: 88.21%, Val-Acc: {0: '75.26%', 1: '95.05%', 2: '92.39%', 3: '94.41%', 4: '41.75%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_252.pth
# Epoch 290, Train Loss: 0.247225, Train-Acc: {0: '75.76%', 1: '97.13%', 2: '90.36%', 3: '95.76%', 4: '29.28%'},
# Val Loss: 0.312478, Val Acc: 88.19%, Val-Acc: {0: '75.50%', 1: '95.02%', 2: '92.05%', 3: '94.69%', 4: '41.10%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_290.pth
# Epoch 264, Train Loss: 0.248745, Train-Acc: {0: '75.47%', 1: '97.16%', 2: '89.94%', 3: '95.76%', 4: '29.16%'},
# Val Loss: 0.313175, Val Acc: 88.19%, Val-Acc: {0: '75.54%', 1: '95.06%', 2: '92.21%', 3: '94.63%', 4: '40.87%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_264.pth
# Epoch 291, Train Loss: 0.247190, Train-Acc: {0: '75.73%', 1: '97.16%', 2: '90.27%', 3: '95.78%', 4: '29.17%'},
# Val Loss: 0.312400, Val Acc: 88.19%, Val-Acc: {0: '75.42%', 1: '95.07%', 2: '91.99%', 3: '94.79%', 4: '40.70%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_291.pth
# Epoch 273, Train Loss: 0.248194, Train-Acc: {0: '75.48%', 1: '97.17%', 2: '90.05%', 3: '95.74%', 4: '29.40%'},
# Val Loss: 0.312173, Val Acc: 88.18%, Val-Acc: {0: '75.38%', 1: '94.94%', 2: '92.26%', 3: '94.34%', 4: '42.29%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Standard_LoRA\Rank_4_Period_4\1st_try\BiGRUWithAttention_epoch_273.pth
#
# ✅ Training Complete. Final model:
# BiGRUWithAttention_LoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=5, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# unique_classes = [0 1 2 3 4], num_classes = 5

# %% [markdown]
# ---
#
# ## 📊 Summary: Standard LoRA (BiGRUWithAttention + LoRA)
# ### (`LoRA_CL_Classif_Bi_Dir_GRU_Model_ver2.ipynb`)
#
# | Period | Model & Config                                                                                     | Validation Accuracy | Class-wise Accuracy                                                        |
# |--------|----------------------------------------------------------------------------------------------------|---------------------|-----------------------------------------------------------------------------|
# | 1      | `BiGRUWithAttention_LoRA`<br>(num_layers=4, lora_r=4)<br>saved in `'Standard_LoRA/Rank_4_Period_1/1st_try'` | **98.36%**          | {0: 98.54%, 1: 98.09%}                                                     |
# | 2      | `BiGRUWithAttention_LoRA`<br>(num_layers=4, lora_r=4)<br>saved in `'Standard_LoRA/Rank_4_Period_2/1st_try'` | **96.43%**          | {0: 98.93%, 1: 95.63%, 2: 87.04%}                                          |
# | 3      | `BiGRUWithAttention_LoRA`<br>(num_layers=4, lora_r=4)<br>saved in `'Standard_LoRA/Rank_4_Period_3/1st_try'` | **91.14%**          | {0: 50.14%, 1: 97.60%, 2: 90.57%, 3: 94.29%}                               |
# | 4      | `BiGRUWithAttention_LoRA`<br>(num_layers=4, lora_r=4)<br>saved in `'Standard_LoRA/Rank_4_Period_4/1st_try'` | **88.21%**          | {0: 75.26%, 1: 95.05%, 2: 92.39%, 3: 94.41%, 4: 41.75%}                    |
#
# ---
