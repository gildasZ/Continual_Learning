# %% [markdown]
# # *__Working on BTCUSD predictions with GRU model.__*

# %% [markdown]
# ## *__Check first before starting__*

# %%
# Do 'pipenv install ipykernel' if you get error.
print("Kernel is working correctly!")
# Out:
# Kernel is working correctly!

# %%
import os

# Change the working directory to the project root
# Working_directory = os.path.normpath("C:/Users/gilda/OneDrive/Documents/_NYCU/MASTER_S_studies/Master\'s Thesis/LABORATORY/_Global_Pytorch/Continual_Learning")
Working_directory = os.path.normpath("C:/Users/james/OneDrive/文件/Continual_Learning")
os.chdir(Working_directory)
print(f"Working directory: {os.getcwd()}")  # Prints the current working directory
# Out:
# Working directory: C:\Users\james\OneDrive\文件\Continual_Learning

# %% [markdown]
# ## **__All imports__**

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_interactions import zoom_factory, panhandler
from sklearn.model_selection import train_test_split
import pickle
from ta import trend, momentum, volatility, volume
import math
from scipy.ndimage import gaussian_filter1d
from typing import Callable, Tuple
import shutil
import contextlib
import traceback
import gc
import glob, copy
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## __**All functions (For data processing)**__

# %%
def ensure_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

def plot_with_matplotlib(data: pd.DataFrame, 
                         title: str, 
                         interactive: bool = False, 
                         save_path: str = None, 
                         show_plot: bool = True, 
                         save_matplotlib_object: str = None) -> None:
    """
    Plot data using Matplotlib, with optional interactivity using mpl-interactions.
    
    Parameters:
    - data (pd.DataFrame): The data to plot, must contain 'close' column.
    - title (str): The title of the plot.
    - interactive (bool): If True, enables interactive zoom and pan.
    - save_path (Optional[str]): If provided, saves the plot to this path.
    - show_plot (bool): If True, displays the plot. If False, skips display.
    - save_matplotlib_object (Optional[str]): If provided, saves the Matplotlib figure object to this file path.
    """
    if not all(col in data.columns for col in ['close']):
        raise ValueError("The input DataFrame must contain 'close' column.")

    # Use the default Matplotlib color cycle for the line
    default_blue = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
    print(f"Default blue: {default_blue}")

    # Explicit colors for trends
    trend_colors = {
        0: 'black',
        1: 'yellow',
        2: 'red',
        3: 'green',
        4: default_blue #'purple',
    }
    # unique_trends = [0, -25, -15, 15, 25]
    # colormap = plt.cm.get_cmap('tab10', len(unique_trends))  # Choose 'tab10' or 'Set1' for distinct colors
    # trend_colors = {trend: colormap(i) for i, trend in enumerate(unique_trends)}

    fig, ax = plt.subplots(figsize=(12, 6))

    # Plot data as a single connected line, colored by trend
    if 'trend' in data.columns:
        legend_added = set() # Track which trends have already been added to the legend
        prev_idx = data.index[0]
        for idx, row in data.iterrows():
            if idx != prev_idx:
                trend_key = int(row['trend'])  # Convert trend value to int for lookup
                label = f'Trend {trend_key}' if trend_key not in legend_added else None
                ax.plot([prev_idx, idx], 
                        [data.loc[prev_idx, 'close'], row['close']],
                        color=trend_colors[trend_key], 
                        linestyle='-', 
                        # marker='o', 
                        linewidth=1,
                        label=label  # Add label only if it's not in the legend
                )
                legend_added.add(trend_key)  # Mark this trend as added to the legend
            prev_idx = idx

        ax.set_title(f"{title} (Connected, Colored by Trend)")
    else:
        # Default plot if no trend column exists
        ax.plot(data.index, data['close'], label='Closing Price', linestyle='-', marker='o', 
                markersize=2, linewidth=1, color=default_blue, markerfacecolor='green', markeredgecolor='black')
        ax.set_title(title)
    
    ax.set_xlabel('Date')
    ax.set_ylabel('Closing Price (USD)')
    
    # Add a legend manually for trends
    # for trend, color in trend_colors.items():
    #     ax.plot([], [], color=color, label=f'Trend {trend}')
    ax.legend()
    ax.grid()
    
    # Enable interactivity if requested
    if interactive:
        zoom_factory(ax)  # Enable zoom with mouse wheel
        panhandler(fig)   # Enable panning with left-click
        print("Interactive mode enabled. Use mouse wheel to zoom and left click to pan.")

    # Save the plot if a path is provided
    if save_path:
        fig.tight_layout()  # Ensures the layout is clean
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to: {save_path}")

    # Save the Matplotlib figure object
    if save_matplotlib_object:
        with open(save_matplotlib_object, 'wb') as f:
            pickle.dump(fig, f)
        print(f"Matplotlib figure object saved to: {save_matplotlib_object}")

    if show_plot:
        plt.show()
    else:
        print("Plot display skipped.")

def load_and_show_pickle(pickle_file_path: str):
    """
    Load a pickled Matplotlib figure object and display it with optional interactivity.

    Parameters:
    - pickle_file_path (str): Path to the pickled Matplotlib figure file.

    Returns:
    - None
    """
    try:
        # Open the pickle file and load the figure
        with open(pickle_file_path, "rb") as f:
            loaded_fig = pickle.load(f)

        print(f"Figure successfully loaded and displayed from: {pickle_file_path}")

        # Use plt.show() to allow interactivity
        plt.show(block=True)

    except FileNotFoundError:
        print(f"Error: File not found at {pickle_file_path}. Please check the path.")
    except Exception as e:
        print(f"Error loading the pickled figure: {e}")

def save_to_csv(df: pd.DataFrame, file_path: str):
    """
    Save a DataFrame to a CSV file.

    Parameters:
        df (pd.DataFrame): The DataFrame containing the data to be saved.
        file_path (str): The file path (including the file name) to save the CSV.

    Returns:
        None
    """
    df.to_csv(file_path)
    # df_to_save = df.copy()
    # df_to_save["date"] = df_to_save.index.strftime('%Y-%m-%d %H:%M:%S')  # Add formatted index as a column
    
    # Save the DataFrame to CSV
    # df_to_save.to_csv(file_path)
    print(f"\nSuccessfully saved data with moving average to CSV: \n\t{file_path}\n")

def read_csv_file(file_path: str, preview_rows: int = 5, 
                  days_towards_end: int = None, 
                  days_from_start: int = None, description: str = ""):
    """
    Reads a CSV file and returns a pandas DataFrame filtered by date range.

    Args:
        file_path (str): The path to the CSV file.
        preview_rows (int): Number of rows to preview (default is 5).
        days_towards_end (int, optional): Number of days from the most recent date to retrieve data.
        days_from_start (int, optional): Number of days from the oldest date of the filtered data to retrieve data.
        description (str): A brief description of the dataset being loaded.
                           Explanation:
                           - To retrieve data from the **end**: Use `days_towards_end`.
                           - To retrieve data from the **start of the filtered range**: Use `days_from_start`.
                           - To retrieve data from the **middle**: Use both:
                             For example, if `days_towards_end=100` and `days_from_start=50`,
                             the function will first filter the last 100 days of the dataset,
                             and then filter the first 50 days from this range.
                             This results in data between the last 100th and the last 50th day.

    Returns:
        DataFrame: The loaded and filtered data from the CSV file.
    """
    try:
        if description:
            print(f"\nDescription: {description}")
        print(f"\nFile path: {file_path}")
        
        # Read the CSV file
        data = pd.read_csv(file_path, parse_dates=['date'], index_col='date')
        
        # Filter by days towards the end
        if days_towards_end is not None:
            last_date = data.index.max()  # Get the most recent date in the dataset
            end_cutoff_date = last_date - pd.Timedelta(days=days_towards_end)
            data = data[data.index >= end_cutoff_date]
            print(f"\nRetrieving data from the past {days_towards_end} days (from {end_cutoff_date.date()} onwards):")
        
        # Filter by days from the start (from the filtered data)
        if days_from_start is not None:
            first_date = data.index.min()  # Get the earliest date in the filtered dataset
            start_cutoff_date = first_date + pd.Timedelta(days=days_from_start)
            data = data[data.index <= start_cutoff_date]
            print(f"\nRetrieving the first {days_from_start} days from the filtered data (up to {start_cutoff_date.date()}):")

        if preview_rows:
            # Print a preview of the data
            print(f"\nPreview of the first {preview_rows} rows:")
            # print(data.head(preview_rows), '\n')
            display(data.head(preview_rows))
            print()

            print(f"\nPreview of the last {preview_rows} rows:")
            # print(data.tail(preview_rows), '\n')
            display(data.tail(preview_rows))
            print()

        return data
    except FileNotFoundError:
        print("Error: File not found. Please check the file path.")
    except pd.errors.EmptyDataError:
        print("Error: The file is empty.")
    except pd.errors.ParserError:
        print("Error: The file could not be parsed. Please check the file format.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

def downsample_minute_data(data: pd.DataFrame, n: int) -> pd.DataFrame:
    """
    Downsample minute data into N-minute intervals by retaining every Nth row.

    Parameters:
        data (pd.DataFrame): The original DataFrame with a datetime index.
        n (int): The number of minutes for the downsampling interval.

    Returns:
        pd.DataFrame: Downsampled DataFrame.
    """
    print("\n========---> Downsampling the data! \n")
    data = data.copy()
    # Ensure the index is a DatetimeIndex
    if not isinstance(data.index, pd.DatetimeIndex):
        try:
            data.index = pd.to_datetime(data.index)  # Convert to DatetimeIndex
        except Exception as e:
            raise ValueError("The DataFrame index could not be converted to DatetimeIndex.") from e

    # Filter rows where the minute index modulo N is 0
    downsampled_data = data[data.index.minute % n == 0]

    return downsampled_data

def calculate_log_returns_all_columns(data: pd.DataFrame, exclude_columns: list = [], dropna: bool = True) -> pd.DataFrame:
    """
    Calculate log returns for all numeric columns in a pandas DataFrame,
    excluding specified columns, and removing excluded columns from the returned DataFrame.

    Args:
        data (pd.DataFrame): Input DataFrame containing numeric data.
        exclude_columns (list): List of columns to exclude from log return calculations and the result.
        dropna (bool): Whether to drop rows with NaN values resulting from the calculation.

    Returns:
        pd.DataFrame: DataFrame with log returns for numeric columns,
                      excluding specified columns.
    """
    data = data.copy().drop(columns=exclude_columns)
    columns_to_transform = data.select_dtypes(include=[np.number]).columns
    print(f"columns_to_transform = \n{columns_to_transform}, \nlen(columns_to_transform) = {len(columns_to_transform)}")

    for col in columns_to_transform:
        # Ensure no negative or zero values
        if (data[col] <= 0).any():
            raise ValueError(f"Column '{col}' contains non-positive values. Log returns require strictly positive values.")
        data[col] = np.log(data[col] / data[col].shift(1))

    # Optionally drop rows with NaN values
    return data.dropna() if dropna else data

def created_sequences_2(data: pd.DataFrame, sequence_length: int = 60, sliding_interval: int = 60) -> list:
    """
    Divide the dataset into sequences based on the sequence_length.
    Each sequence must fully cover the window size.

    Args:
    - data (pd.DataFrame): The input DataFrame.
    - sequence_length (int): The window size for sequences.

    Returns:
    - sequences (list): A list of sequences (as DataFrames).
    """
    sequences = []
    for i in range(0, len(data) - sequence_length + 1, sliding_interval):
        # print(f"Processing sequence starting at index: {i}")
        seq = data.iloc[i:i + sequence_length].copy()
        sequences.append(seq)
    # print(f"Total sequences created: {len(sequences)}")
    return sequences

def gaussian_smoothing(data: pd.DataFrame, sigma=2) -> pd.DataFrame:
    """
    Applies Gaussian smoothing to numeric columns in a DataFrame and ensures the index is sorted in ascending order.

    Args:
        data (pd.DataFrame): Input DataFrame.
        sigma (float): Standard deviation for the Gaussian kernel. Defaults to 2.

    Returns:
        pd.DataFrame: A DataFrame with smoothed numeric columns and sorted index.
    """
    # Sort the DataFrame by index in ascending order
    data = data.sort_index(ascending=True).copy()
    for column in data.columns:
        if pd.api.types.is_numeric_dtype(data[column]):  # Only apply to numeric columns
            data[column] = gaussian_filter1d(data[column].values, sigma=sigma)
    return data

def detect_trends_4(
    dataframe: pd.DataFrame, 
    column: str = 'close', 
    lower_threshold: float = 0.001, 
    upper_threshold: float = 0.02,
    reverse_steps: int = 7,
    trends_to_keep: set = {0, 1, 2, 3, 4}  # Default keeps all trends
) -> pd.DataFrame:
    """
    Detects trends based on log return data provided in a specified column and categorizes them into different strength levels.

    This function analyzes time-series data by evaluating cumulative trends in log return values provided in the input DataFrame. 
    It uses three dictionaries (`dic1`, `dic2`, `dic3`) to track different phases of trends, handles multi-step reversals, and 
    classifies trends dynamically based on cumulative product thresholds and specified thresholds for trend strengths.

    Args:
        dataframe (pd.DataFrame): Input DataFrame containing log return data.
        column (str): Column name containing log return values. Defaults to 'close'.
        lower_threshold (float): Threshold for categorizing moderate trends. Defaults to 0.001.
        upper_threshold (float): Threshold for categorizing strong trends. Defaults to 0.02.
        reverse_steps (int): Number of consecutive steps to confirm a trend reversal. Defaults to 7.
        trends_to_keep (set): A set of trend categories to retain; others will be set to 0 (No Trend). Defaults to keeping all trends {0, 1, 2, 3, 4}.

    Returns:
        pd.DataFrame: A DataFrame with an added column:
                    - 'trend': Categorized trend values based on the detected phases:
                        - 0: No trend
                        - 1: Moderate negative trend
                        - 2: Very strong negative trend
                        - 3: Moderate positive trend
                        - 4: Very strong positive trend
                      Any trends not included in `trends_to_keep` will be reset to 0.

    Function Details:
    1. **Input Assumption**:
    - The input DataFrame already contains log return data in the specified column (`column`).

    2. **Trend Tracking**:
    - Uses dictionaries to monitor trends:
        - `dic1`: Tracks the first phase of the trend.
        - `dic2`: Tracks the second phase if a reversal occurs.
        - `dic3`: Tracks the third phase if another reversal occurs.

    3. **Cumulative Product**:
    - Calculates the cumulative product of `(1 + log_return)` from the specified column to evaluate the strength of trends.

    4. **Reversal Handling**:
    - If a trend reversal persists beyond `reverse_steps`, labels are assigned based on the cumulative product tracked in `dic1`.
    - Subsequent reversals are merged or labeled independently if conditions are met.

    5. **Label Assignment**:
    - Labels are dynamically assigned based on cumulative product thresholds for positive and negative trends:
        - Positive trends are categorized as moderate (3) or strong (4).
        - Negative trends are categorized as moderate (1) or strong (2).

    6. **Trend Filtering**:
    - After detecting trends, only those specified in `trends_to_keep` remain unchanged.
    - Any trend category not included in `trends_to_keep` is reset to 0 (No Trend).

    7. **Edge Cases**:
    - Properly handles scenarios where data points are insufficient for trend analysis or when trend phases overlap, ensuring all data points are labeled.
    """
    # Copy to avoid modifying the original DataFrame
    df = dataframe.copy()
    df['trend'] = None  # Default value 
    
    # print("\n#-------------------- Working on 'trend' patterns -----------------------#")
    dic1, dic2, dic3 = None, None, None # Initialize trend tracking dictionaries
    # dic1 = None # {'ids': [], 'last_sign': None, 'cumulative': 1.0}
    
    def assign_label(dictio_, lower_threshold, upper_threshold):
        cumulative = dictio_['cumulative']
        # print(f"cumulative = {cumulative}")
        if cumulative > (1 + upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 4  # Very strong positive
        elif (1 + lower_threshold) < cumulative <= (1 + upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 3  # Moderate positive
        elif (1 - upper_threshold) < cumulative <= (1 - lower_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 1  # Moderate negative
        elif cumulative <= (1 - upper_threshold):
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 2  # Very strong negative
        else:
            df.iloc[dictio_['ids'], df.columns.get_loc('trend')] = 0  # No trend
    
    #----------------------- For Loop -----------------------#
    for idx, log_ret in enumerate(df[column]):
        sign = 1 if log_ret > 0 else -1

        if dic1 is None:  # Initialize dic1
            # print(f"\nThis one time condition 'if loop' is running \n")
            dic1 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue
        last_sign = dic1['last_sign']
        if sign == last_sign and dic2 is None:  # Continue same trend
            dic1['ids'].append(idx)
            dic1['last_sign'] = sign
            dic1['cumulative'] *= (1 + log_ret)
            continue

        # 1st Reversal occuring
        if dic2 is None:  # Start dic2
            dic2 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue
        last_sign = dic2['last_sign']
        if sign == last_sign and dic3 is None:  # Continue same trend
            dic2['ids'].append(idx)
            dic2['last_sign'] = sign
            dic2['cumulative'] *= (1 + log_ret)
            if len(dic2['ids']) == reverse_steps:
                assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                # print(f"dic1['cumulative'] = {dic1['cumulative']}, and dic1['ids'] = {dic1['ids']}")
                dic1 = dic2
                dic2 = None
                # print(f"dic1 after trend reversal persisted and dic1 = dic2 = \n{dic1}")
                # print(f"dic2 after being reset: {dic2}\n")
            continue

        # 2nd Reversal occuring
        if dic3 is None:  # Start dic3
            dic3 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
            continue
        last_sign = dic3['last_sign']
        if sign == last_sign: # Continue same trend, there is no dic4 to check if is None
            dic3['ids'].append(idx)
            dic3['last_sign'] = sign
            dic3['cumulative'] *= (1 + log_ret)
            dic_prod = dic2['cumulative'] * dic3['cumulative']
            # if (sign == 1 and dic1['cumulative'] * dic_prod > dic1['cumulative']) or (sign == -1 and dic1['cumulative'] * dic_prod < dic1['cumulative'])):
            if (sign == 1 and dic_prod > 1) or (sign == -1 and dic_prod < 1): # More beautiful
                # Merge dic1, dic2, and dic3
                dic1['ids'] += dic2['ids'] + dic3['ids']
                dic1['last_sign'] = dic3['last_sign']
                dic1['cumulative'] *= dic2['cumulative'] * dic3['cumulative']
                dic2, dic3 = None, None
                continue

            if len(dic3['ids']) == reverse_steps:      
                assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                assign_label(dic2, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
                dic1 = dic3
                dic2, dic3 = None, None
                # print(f"dic2 after 2nd trend reversal didn't catch up fast enough, and now \ndic1 = dic3 = {dic1}")
                # print(f"dic3 and dic2 after being reset: {dic3}\n")
            continue
            
        # 3rd Reversal occuring
        assign_label(dic1, lower_threshold, upper_threshold) # Assign labels in the 'trend' column for ids of dic1
        # Reassign values
        dic1 = dic2
        dic2 = dic3
        dic3 = {'ids': [idx], 'last_sign': sign, 'cumulative': (1 + log_ret)}
        # print(f"There was a 3rd trend reversal, and now \ndic1 = dic2 = {dic1}, \ndic2 = dic3 = {dic2}")
        # print(f"dic3 after being reset: {dic3}\n")

    # Assign remaining labels
    if dic1:
        assign_label(dic1, lower_threshold, upper_threshold)
    if dic2:
        assign_label(dic2, lower_threshold, upper_threshold)
    if dic3:
        assign_label(dic3, lower_threshold, upper_threshold)
    # print("\n#-------------------- Returning 'trend' patterns ------------------------#")
    
    # Apply filtering: Keep only selected trends, set others to 0
    df['trend'] = df['trend'].apply(lambda x: x if x in trends_to_keep else 0)

    return df

def split_X_y(sequences: list[pd.DataFrame], 
              target_column: str = 'trend',
              detect_trends_function: Callable[[pd.DataFrame, str, float, float, int, set], pd.DataFrame] = detect_trends_4, 
              column: str = 'close', 
              lower_threshold: float = 0.0009, 
              upper_threshold: float = 0.015,
              reverse_steps: int = 7,
              trends_to_keep: set = {0, 1, 2, 3, 4}) -> Tuple[np.ndarray, np.ndarray]:
    """
    Process sequences to generate features (X) and labels (y) while applying trend detection.

    Args:
    - sequences (list of pd.DataFrame): List of DataFrame sequences.
    - lower_threshold (float): Lower threshold for trend detection.
    - upper_threshold (float): Upper threshold for trend detection.
    - reverse_steps (int): Steps to reverse trends in the sequence.
    - target_column (str): Column name to use as the label (default: 'trend').
    - detect_trends_function (Callable): Function for detecting trends, defaults to `detect_trends_4`.
    - trends_to_keep (set): A set of trend categories to retain; others will be set to 0 (No Trend).

    Returns:
    - X (np.ndarray): Features array of shape (num_sequences, sequence_length, num_features).
    - y (np.ndarray): Labels array of shape (num_sequences,).
    """
    X = []
    y = []
    # count = 0
    for seq in sequences:
        # Apply trend detection on the sequence
        seq = detect_trends_function(seq, column=column, 
                                     lower_threshold=lower_threshold, 
                                     upper_threshold=upper_threshold, 
                                     reverse_steps=reverse_steps,
                                     trends_to_keep=trends_to_keep)
        # if count == 0:
        #     count = 1
        #     print(f"\nseq.head()")
        #     display(seq.head())
        #     print()
        # Extract features (X) and labels (y)
        X.append(seq.drop(columns=[target_column]).values)  # All but the target column
        y.append(seq[target_column].values)  # Target column as labels
        
    # return np.array(X, dtype=np.float32), np.array(y, dtype=np.int64)
    return np.array(X), np.array(y)

def process_and_return_splits(
    with_indicators_file_path: str,
    downsampled_data_minutes: int,
    exclude_columns: list[str],
    lower_threshold: float,
    upper_threshold: float,
    reverse_steps: int,
    sequence_length: int,
    sliding_interval: int,
    trends_to_keep: set = {0, 1, 2, 3, 4}  # Default keeps all trends
) -> tuple[
    list[list[float]],  # X_train: List of sequences, each containing a list of features
    list[list[int]],    # y_train: List of sequences, each containing a list of labels
    list[list[float]],  # X_val: List of sequences, each containing a list of features
    list[list[int]],    # y_val: List of sequences, each containing a list of labels
    list[list[float]],  # X_test: List of sequences, each containing a list of features
    list[list[int]]     # y_test: List of sequences, each containing a list of labels
]:
    """
    Processes time-series data from a CSV file and prepares it for machine learning.

    This function performs the following steps:
        1. Reads data from the specified CSV file and sorts it by date in descending order.
        2. Optionally downsamples the data to a lower frequency (e.g., 5-minute intervals).
        3. Applies Gaussian smoothing to reduce noise in the data.
        4. Calculates log returns for all numeric columns, excluding specified columns.
        5. Detects trends based on defined thresholds (`lower_threshold`, `upper_threshold`, and `reverse_steps`).
        6. Filters trends to keep only those specified in `trends_to_keep`, setting others to 0 (No Trend).
        7. Converts the processed data into sequences of a fixed length (`sequence_length`) with a sliding interval.
        8. Splits the sequences into training (80%), validation (10%), and test (10%) sets.
        9. Further splits the sequences into features (`X`) and labels (`y`) for supervised learning.

    Args:
        with_indicators_file_path (str): Path to the CSV file containing the time-series data.
        downsampled_data_minutes (int): Frequency for downsampling the data (e.g., 1 for no downsampling).
        exclude_columns (list[str]): List of column names to exclude from log return calculations.
        lower_threshold (float): Lower threshold for trend detection.
        upper_threshold (float): Upper threshold for trend detection.
        reverse_steps (int): Number of steps for reversing trends in trend detection.
        sequence_length (int): Length of sequences to create from the data.
        sliding_interval (int): Interval for sliding the window when creating sequences.
        trends_to_keep (set): A set of trend categories to retain; others will be set to 0 (No Trend). Defaults to keeping all trends {0, 1, 2, 3, 4}.

    Returns:
        tuple[list[list[float]], list[list[int]], list[list[float]], list[list[int]], list[list[float]], list[list[int]]]:
            A tuple containing:
            - X_train (list[list[float]]): Input sequences for training.
            - y_train (list[list[int]]): Target sequences for training.
            - X_val (list[list[float]]): Input sequences for validation.
            - y_val (list[list[int]]): Target sequences for validation.
            - X_test (list[list[float]]): Input sequences for testing.
            - y_test (list[list[int]]): Target sequences for testing.

    Example:
        X_train, y_train, X_val, y_val, X_test, y_test = process_and_return_splits(
            with_indicators_file_path="data.csv",
            downsampled_data_minutes=5,
            exclude_columns=["volume"],
            lower_threshold=-0.05,
            upper_threshold=0.05,
            reverse_steps=3,
            sequence_length=50,
            sliding_interval=5,
            trends_to_keep={1, 2, 3, 4}  # Only keep categorized trends, set others to 0
        )
    """

    data_retrieved = read_csv_file(with_indicators_file_path, preview_rows=0) # 190 days of data
    data_retrieved = data_retrieved.sort_index(ascending=False)

    #---------------------------------------------------------------------------------------
    if downsampled_data_minutes != 1:
        print("Downsampling the data! \n")
        data_retrieved = downsample_minute_data(data_retrieved, downsampled_data_minutes)
    #---------------------------------------------------------------------------------------

    # Get missing timestamps
    missing_timestamps = pd.date_range(
        start=data_retrieved.index.min(), # Returns smallest/earliest/oldest date
        end=data_retrieved.index.max(),
        freq='1min',  # Use 'min' for a frequency of 1 minute, '30s' for a frequency of 30 seconds
        tz=data_retrieved.index.tz,
    ).difference(data_retrieved.index)
    print(f"\ndata_retrieved - Missing timestamps time: \n{missing_timestamps}") 

    data_gaussian = gaussian_smoothing(data_retrieved, sigma=7)

    # Get missing timestamps
    missing_timestamps = pd.date_range(
        start=data_gaussian.index.min(), # Returns smallest/earliest/oldest date
        end=data_gaussian.index.max(),
        freq='1min',  # Use 'min' for a frequency of 1 minute, '30s' for a frequency of 30 seconds
        tz=data_gaussian.index.tz,
    ).difference(data_gaussian.index)
    print(f"\ndata_gaussian - Missing timestamps time: \n{missing_timestamps}\n")

    data_log_return = calculate_log_returns_all_columns(data_gaussian, exclude_columns=exclude_columns)

    # Get missing timestamps
    missing_timestamps = pd.date_range(
        start=data_log_return.index.min(), # Returns smallest/earliest/oldest date
        end=data_log_return.index.max(),
        freq='1min',  # Use 'min' for a frequency of 1 minute, '30s' for a frequency of 30 seconds
        tz=data_log_return.index.tz,
    ).difference(data_log_return.index)
    print(f"\ndata_log_return - Missing timestamps time: \n{missing_timestamps}\n") 

    # Check if there are missing timestamps
    if missing_timestamps.empty:
        print("No missing timestamps.")
    else:
        for timestamp in missing_timestamps:
            print(f"\nMissing timestamp: {timestamp}")
            
            # Create a placeholder for the missing timestamp
            if timestamp not in data_log_return.index:
                print('Missing')
            
            # Get data before and after the missing timestamp
            before_data = data_log_return[data_log_return.index < timestamp].tail(5)  # 5 data points before
            after_data = data_log_return[data_log_return.index > timestamp].head(5)  # 5 data points after
            
            # Display surrounding data
            if not before_data.empty:
                print("\nData before:")
                print(before_data)
            else:
                print("\nNo data available before the missing timestamp.")
            
            if not after_data.empty:
                print("\nData after:")
                print(after_data)
            else:
                print("\nNo data available after the missing timestamp.")

    sequences = created_sequences_2(data_log_return, sequence_length, sliding_interval)

    # Split sequences into training, validation, and test sets
    train_size = int(len(sequences) * 0.8)
    val_size = int(len(sequences) * 0.1)

    train_sequences = sequences[:train_size]
    val_sequences = sequences[train_size:train_size + val_size]
    test_sequences = sequences[train_size + val_size:]

    print(f"""
    Number of sequences:
        - sequences[0].shape: {sequences[0].shape}
        - Total sequences: {len(sequences)}
        - Train sequences: {len(train_sequences)}
        - Validation sequences: {len(val_sequences)}
        - Test sequences: {len(test_sequences)}
    """)

    # Process train, validation, and test sets
    X_train, y_train = split_X_y(train_sequences, 
                                target_column='trend',
                                detect_trends_function = detect_trends_4,
                                column= 'close',
                                lower_threshold=lower_threshold, 
                                upper_threshold=upper_threshold, 
                                reverse_steps=reverse_steps,
                                trends_to_keep=trends_to_keep)

    X_val, y_val = split_X_y(val_sequences, 
                            target_column='trend',
                            detect_trends_function = detect_trends_4,
                            column= 'close',
                            lower_threshold=lower_threshold, 
                            upper_threshold=upper_threshold, 
                            reverse_steps=reverse_steps,
                            trends_to_keep=trends_to_keep)

    X_test, y_test = split_X_y(test_sequences, 
                            target_column='trend',
                            detect_trends_function = detect_trends_4,
                            column= 'close',
                            lower_threshold=lower_threshold, 
                            upper_threshold=upper_threshold, 
                            reverse_steps=reverse_steps,
                            trends_to_keep=trends_to_keep)

    # Checking X arrays
    for idx, seq in enumerate(X_train):  # Loop through sequences
        for sub_idx, feature_set in enumerate(seq):  # Loop through data points
            for feature_idx, feature in enumerate(feature_set):  # Loop through features
                if not isinstance(feature, (float, np.float32)):  # Check each feature
                    print(f"Unexpected type in X_train at sequence {idx}, data point {sub_idx}, feature {feature_idx}: {type(feature)}")

    # Checking y arrays
    for idx, seq in enumerate(y_train):  # Loop through sequences
        for sub_idx, label in enumerate(seq):  # Loop through data points (labels)
            if not isinstance(label, (int, np.int64)):  # Check each label
                print(f"Unexpected type in y_train at sequence {idx}, data point {sub_idx}: {type(label)}")

    # Checking X arrays
    for idx, seq in enumerate(X_val):  # Loop through sequences
        for sub_idx, feature_set in enumerate(seq):  # Loop through data points
            for feature_idx, feature in enumerate(feature_set):  # Loop through features
                if not isinstance(feature, (float, np.float32)):  # Check each feature
                    print(f"Unexpected type in X_val at sequence {idx}, data point {sub_idx}, feature {feature_idx}: {type(feature)}")
    # Checking y arrays
    for idx, seq in enumerate(y_val):  # Loop through sequences
        for sub_idx, label in enumerate(seq):  # Loop through data points (labels)
            if not isinstance(label, (int, np.int64)):  # Check each label
                print(f"Unexpected type in y_val at sequence {idx}, data point {sub_idx}: {type(label)}")

    # Checking X arrays
    for idx, seq in enumerate(X_test):  # Loop through sequences
        for sub_idx, feature_set in enumerate(seq):  # Loop through data points
            for feature_idx, feature in enumerate(feature_set):  # Loop through features
                if not isinstance(feature, (float, np.float32)):  # Check each feature
                    print(f"Unexpected type in X_test at sequence {idx}, data point {sub_idx}, feature {feature_idx}: {type(feature)}")
    # Checking y arrays
    for idx, seq in enumerate(y_test):  # Loop through sequences
        for sub_idx, label in enumerate(seq):  # Loop through data points (labels)
            if not isinstance(label, (int, np.int64)):  # Check each label
                print(f"Unexpected type in y_test at sequence {idx}, data point {sub_idx}: {type(label)}")

    if isinstance(y_train, np.ndarray) and y_train.dtype == np.object_:
        # Convert to numeric if needed
        y_train = np.array(y_train, dtype=np.int64)

    if isinstance(y_val, np.ndarray) and y_val.dtype == np.object_:
        # Convert to numeric if needed
        y_val = np.array(y_val, dtype=np.int64)

    if isinstance(y_test, np.ndarray) and y_test.dtype == np.object_:
        # Convert to numeric if needed
        y_test = np.array(y_test, dtype=np.int64)

    close_col_index = data_log_return.columns.get_loc('close') # 'date' is set as index so doesnt count as a column
    Number_features = X_train.shape[-1]
    print(f"close_col_index = {close_col_index}")
    print(f"Number_features = {Number_features}")

    return X_train, y_train, X_val, y_val, X_test, y_test, Number_features

def print_class_distribution(y, var_name: str) -> None:
    """
    Prints the class distribution of a label array.

    Args:
        y: Tensor, array, or list of class labels.
        var_name: Name of the variable (for display).
    """
    if isinstance(y, torch.Tensor):
        y = y.cpu().numpy()
    flattened = np.array(y).flatten()

    unique_classes, counts = np.unique(flattened, return_counts=True)
    total = counts.sum()

    header = f"Class Distribution for '{var_name}':"
    line_parts = [
        f"Class {int(c):<3} Percent: {(count / total) * 100:>6.2f}%"
        for c, count in zip(unique_classes, counts)
    ]
    print(header.ljust(40) + " || ".join(line_parts))

# %% [markdown]
# ## All(Initial) parameters here

# %%
ticker = 'BTC-USD'
downsampled_data_minutes = 1

# Step 0 (Again): Identify parameters for trend settings of the loaded data with 1,000 data points
lower_threshold = 0.0009 
upper_threshold = 0.015
reverse_steps = 13


exclude_columns= ['MACD', 'MACD_signal', 'ROC_10', 'OBV', 'AD_Line']
# exclude_columns= []#['open', 'high', 'low', 'MACD', 'MACD_signal', 'BB_middle', 'ROC_10', 'OBV', 'AD_Line']

# Step 3, under ### Correlation Analysis
# Compute correlations with the 'trend' column
# corr = data_trends.corr()
# trend_corr = corr['trend'].sort_values(ascending=False)
strongly_correlated = ['close', 'open', 'SMA_5', 'high', 'low', 'EMA_10', 'SMA_10'] # Strongly correlated (correlation > 0.6)
moderately_correlated = ['BB_middle', 'BB_lower', 'BB_upper', 'RSI_14'] # Moderately correlated (correlation between 0.3 and 0.6)
weakly_correlated = ['SMA_50', 'volume', 'BBW', 'ATR_14'] # Weakly correlated or negligible (correlation <~ 0.3)

exclude_columns += weakly_correlated + moderately_correlated
# print(exclude_columns)


sequence_length = 1000
sliding_interval = 60

# %% [markdown]
# ## **_Build the GRU Model_**

# %% [markdown]
# ### GPU details

# %%
# If not in Jupyter Notebook
# import subprocess
# result = subprocess.run(["nvidia-smi"], capture_output=True, text=True)
# print(result.stdout)

# !nvidia-smi
# Out:
# Sun Apr 20 21:00:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8             10W /  200W |    4389MiB /  12282MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     18500    C+G   ...43.0_x64__zpdnekdrzrea0\Spotify.exe      N/A      |
# |    0   N/A  N/A     54768    C+G   ...al\Discord\app-1.0.9188\Discord.exe      N/A      |
# |    0   N/A  N/A     67352    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     81344      C   ...s\Medical_AI_LoRA_py3.12\python.exe      N/A      |
# |    0   N/A  N/A     83936    C+G   ...US\ArmouryDevice\asus_framework.exe      N/A      |
# |    0   N/A  N/A     85988    C+G   ...ata\Local\LINE\bin\current\LINE.exe      N/A      |
# |    0   N/A  N/A     90496    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A    103372    C+G   ... Stream\106.0.4.0\GoogleDriveFS.exe      N/A      |
# |    0   N/A  N/A    119500    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A    120292    C+G   ...ta\Local\Programs\Notion\Notion.exe      N/A      |
# |    0   N/A  N/A    123408    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A    125500    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A    126332    C+G   ...\cef\cef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A    131424    C+G   ...ograms\cron-web\Notion Calendar.exe      N/A      |
# |    0   N/A  N/A    135136    C+G   ...1.0_x64__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A    136672    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A    141588    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A    142900    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A    145764    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A    146092    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A    149096      C   ...s\Medical_AI_LoRA_py3.12\python.exe      N/A      |
# |    0   N/A  N/A    150348    C+G   ...t Office\root\Office16\POWERPNT.EXE      N/A      |
# |    0   N/A  N/A    151976      C   ...s\Medical_AI_LoRA_py3.12\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Torch and CUDA check

# %%
# Check if GPU is available
gpu_available = torch.cuda.is_available()

print("torch.cuda.is_available()", gpu_available)

# If GPU is available, print additional information
if gpu_available:
    print("\nGPU Device Name:", torch.cuda.get_device_name(0))
    print("Number of GPUs:", torch.cuda.device_count())
    print("Total CUDA Cores:", torch.cuda.get_device_properties(0).multi_processor_count * 128)  # NVIDIA GPUs often have 128 cores/SM
    print("Current GPU Device:", torch.cuda.current_device())
else:
    print("No GPU detected.")
# Out:
# torch.cuda.is_available() True
#
# GPU Device Name: NVIDIA GeForce RTX 4070
# Number of GPUs: 1
# Total CUDA Cores: 5888
# Current GPU Device: 0

# %% [markdown]
# ### Model building

# %% [markdown]
# #### Bi-Directional GRU with Attention

# %%
class BiGRUWithAttention(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, num_layers: int, dropout: float = 0.0):
        super(BiGRUWithAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        # Bi-Directional GRU Layer
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=dropout)
        # Attention layer
        self.attention_fc = nn.Linear(hidden_size * 2, hidden_size * 2)  # Hidden size * 2 for bi-directional
        # Fully connected layer for classification
        self.fc = nn.Linear(hidden_size * 2, output_size)
        self.dropout = nn.Dropout(dropout)  # Apply dropout before the fully connected layer
        self.init_weights()

    def init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)  # Xavier initialization for weights
            elif 'bias' in name:
                nn.init.constant_(param, 0)  # Zero initialization for biases

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)  # Bi-directional: num_layers * 2
        # Bi-Directional GRU forward pass
        out, _ = self.gru(x, h0)  # Shape: (batch_size, seq_length, hidden_size * 2)

        # Attention mechanism
        attn_weights = torch.tanh(self.attention_fc(out))  # Shape: (batch_size, seq_length, hidden_size * 2)
        out = attn_weights * out  # Element-wise attention application
        out = self.dropout(out)  # Apply dropout

        # Fully connected layer (applied at each time step)
        out = self.fc(out)  # Shape: (batch_size, seq_length, output_size)
        return out

# %% [markdown]
# #### New Architecture with LoRA

# %%
# --- LoRA Layer ---
class LoRALinear(nn.Module):
    def __init__(self, in_features, out_features, r=4):
        """
        in_features: Input features
        out_features: Output features (number of classes for classification)
        r: Rank of the low-rank update matrices
        """
        super(LoRALinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        # Original linear layer (frozen during incremental training)
        self.linear = nn.Linear(in_features, out_features)
        for param in self.linear.parameters():
            param.requires_grad = False
        # Low-rank adaptation parameters
        self.r = r
        self.A = nn.Parameter(torch.randn(r, in_features) * 0.01)
        self.B = nn.Parameter(torch.randn(out_features, r) * 0.01)
    
    def forward(self, x):
        # Compute the LoRA update: W' = W + (B @ A)
        lora_update = F.linear(x, self.B @ self.A)
        orig_output = self.linear(x)
        return orig_output + lora_update

# --- New Model Architecture ---
class BiGRUWithAttentionLoRA(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, num_layers: int, dropout: float = 0.0, lora_r: int = 4):
        super(BiGRUWithAttentionLoRA, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Bi-directional GRU layer
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=dropout)
        # Attention layer
        self.attention_fc = nn.Linear(hidden_size * 2, hidden_size * 2)
        # Fully connected layer replaced by a LoRA adapted linear layer
        self.fc = LoRALinear(hidden_size * 2, output_size, r=lora_r)
        self.dropout = nn.Dropout(dropout)
        self.init_weights()
    
    def init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name and 'linear' in name:
                nn.init.xavier_uniform_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Initialize hidden state for bi-directional GRU: (num_layers * 2, batch, hidden_size)
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)  # Shape: [batch, seq_len, hidden_size*2]
        # Apply attention mechanism
        attn_weights = torch.tanh(self.attention_fc(out))
        out = attn_weights * out  # Element-wise multiplication
        out = self.dropout(out)
        # Final prediction for each time step
        out = self.fc(out)  # Shape: [batch, seq_len, output_size]
        return out

# %% [markdown]
# ## Step 6: Train the Model

# %% [markdown]
# ### Training and validation function

# %%
# Training and validation function for Period 1.
def train_and_validate(model, output_size, criterion, optimizer, 
                       X_train, y_train, X_val, y_val, scheduler, 
                       use_scheduler=None, num_epochs=10, batch_size=64, 
                       model_saving_folder=None, model_name=None, stop_signal_file=None):
    print("'train_and_validate' function started. \n")
    # Ensure model saving folder exists (deleting existing first if there is one)
    if model_saving_folder and os.path.exists(model_saving_folder):
        # os.rmdir(model_saving_folder) # Only works on empty folders 
        shutil.rmtree(model_saving_folder) # Safely remove all contents
        if not os.path.exists(model_saving_folder):
            print(f"Existing folder has been removed : {model_saving_folder}\n")
    if model_saving_folder and not os.path.exists(model_saving_folder):
        os.makedirs(model_saving_folder)
        
    if not model_saving_folder:
        model_saving_folder = './saved_models'
    if not model_name:
        model_name = 'model'

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    # Convert data to tensors # Returns a copy, original is safe
    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)  # (seqs, seq_len, features)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)    # (seqs, seq_len)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    # Create TensorDatasets
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    print("y_train:")
    print(type(y_train))
    print(y_train.dtype)
    print(y_train.shape)
    print("X_train:")
    print(type(X_train))
    print(X_train.dtype)
    print(X_train.shape)
    print("\ny_val:")
    print(type(y_val))
    print(y_val.dtype)
    print(y_val.shape)
    print("X_val:")
    print(type(X_val))
    print(X_val.dtype)
    print(X_val.shape)

    # Debug prints for TensorDataset and DataLoader
    print("\nDataset Lengths:")
    print(f"Train Dataset Length: {len(train_dataset)}")
    print(f"Validation Dataset Length: {len(val_dataset)}")

    print("\nDataLoader Batch Sizes:")
    print(f"Number of Batches in Train DataLoader: {len(train_loader)}")
    print(f"Number of Batches in Validation DataLoader: {len(val_loader)}")

    # Additional details for y_train, y_val, and y_test
    print("\ny_train Unique Values and Stats:")
    print(f"Unique values in y_train: {y_train.unique()}")
    print(f"y_train Min: {y_train.min()}, Max: {y_train.max()}")

    print("\ny_val Unique Values and Stats:")
    print(f"Unique values in y_val: {y_val.unique()}")
    print(f"y_val Min: {y_val.min()}, Max: {y_val.max()}")

    # Device check
    print("\nDevice Info:")
    print(f"X_train Device: {X_train.device}")
    print(f"y_train Device: {y_train.device}")
    print(f"X_val Device: {X_val.device}")
    print(f"y_val Device: {y_val.device}\n")

    # Calculate number of batches
    # num_batches = (len(X_train) + batch_size - 1) // batch_size

    global best_results  # Ensure we can modify the external variable if defined outside.
    best_results = []    # Start empty each training run
    model.train()

    for epoch in range(num_epochs):
        epoch_loss = 0
        class_correct = {}  # Dictionary to store correct predictions per class
        class_total = {}  # Dictionary to store total samples per class
        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\nStop signal detected. Exiting training loop safely.\n")
            break
        model.train()
        i=0
        for X_batch, y_batch in train_loader:
            # Reset gradients before forward pass
            optimizer.zero_grad()  # Best practice

            # Forward pass
            outputs = model(X_batch)
            outputs = outputs.view(-1, output_size)
            y_batch = y_batch.view(-1)

            if epoch == 1 and i < 3:
                i += 1
                print(f"\nUnique target values: {y_batch.unique()}")
                print(f"Target dtype: {y_batch.dtype}")
                print(f"Min target: {y_batch.min()}, Max target: {y_batch.max()}")
                print("Unique classes in y_train:", y_train.unique())
                print(f"Unique classes in y_val: {y_val.unique()}\n")
            
            # Compute loss
            loss = criterion(outputs, y_batch)

            # Compute class-wise accuracy (Accumulates values in dict)
            compute_classwise_accuracy(outputs, y_batch, class_correct, class_total)

            # Backward pass and optimization
            # No longer reset gradients here: optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item() * X_batch.size(0)  # Scale back to total loss
            
        train_loss = epoch_loss / len(train_loader.dataset)

        # Compute per-class training accuracy
        # train_classwise_accuracy = {int(c): (class_correct[c] / class_total[c]) * 100 if class_total[c] > 0 else 0 
        #                            for c in sorted(class_total.keys())}
        train_classwise_accuracy = {int(c): f"{(class_correct[c] / class_total[c]) * 100:.2f}%" if class_total[c] > 0 else "0.00%" 
                                    for c in sorted(class_total.keys())}
        
        # Perform validation at the end of each epoch
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        val_class_correct = {}
        val_class_total = {}
        with torch.no_grad():
            for X_val_batch, y_val_batch in val_loader:
                val_outputs = model(X_val_batch).view(-1, output_size)
                val_labels = y_val_batch.view(-1)
                val_loss += criterion(val_outputs, val_labels).item() * X_val_batch.size(0)  # Scale to total loss
                val_predictions = torch.argmax(val_outputs, dim=-1)
                val_correct += (val_predictions == val_labels).sum().item()
                val_total += val_labels.size(0)
                # Compute per-class validation accuracy
                compute_classwise_accuracy(val_outputs, val_labels, val_class_correct, val_class_total)
        val_loss /= len(val_loader.dataset)
        val_accuracy = val_correct / val_total

        # Compute per-class validation accuracy
        # val_classwise_accuracy = {int(c): (val_class_correct[c] / val_class_total[c]) * 100 if val_class_total[c] > 0 else 0 
        #                          for c in sorted(val_class_total.keys())}
        val_classwise_accuracy = {int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%" 
                                  for c in sorted(val_class_total.keys())}

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train Loss: {train_loss:.9f}, "
              f"Train-Class-Acc: {train_classwise_accuracy}, "
              f"Val Loss: {val_loss:.9f}, "
              f"Val Accuracy: {val_accuracy * 100:.2f}%, "
              f"Val-Class-Acc: {val_classwise_accuracy}, "
              f"LR: {optimizer.param_groups[0]['lr']:.9f}")

        # Save current model and update best results if applicable
        current_epoch_info = {
            "epoch": epoch+1,
            "train_loss": train_loss,
            "train_classwise_accuracy": train_classwise_accuracy,
            "val_loss": val_loss,
            "val_accuracy": val_accuracy,
            "val_classwise_accuracy": val_classwise_accuracy,
            'learning_rate': optimizer.param_groups[0]['lr'], # Optimizer state
            "model_path": os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        }

        # Insert this epoch if we have fewer than 5 results
        # or if it beats the lowest of the top 5
        if len(best_results) < 5 or val_accuracy > best_results[-1]["val_accuracy"]:
            if len(best_results) == 5:
                # Remove the worst model from the list, the last (lowest accuracy)
                worst = best_results.pop() 
                if os.path.exists(worst["model_path"]):
                    os.remove(worst["model_path"])
                    print(f"Removed old model with accuracy {worst['val_accuracy']*100:.2f}%, and file was at {worst['model_path']}")
            # Just insert and sort by val_accuracy descending
            best_results.append(current_epoch_info) 
            best_results.sort(key=lambda x: x["val_accuracy"], reverse=True)
            torch.save({ # Save this model
                'epoch': epoch+1,  # Save the current epoch
                'train_loss': train_loss,
                'val_loss': val_loss,
                'model_state_dict': model.state_dict(),  # Model weights
                'optimizer_state_dict': optimizer.state_dict(),  # Optimizer state
                'learning_rate': optimizer.param_groups[0]['lr'] # Optimizer state
            }, current_epoch_info["model_path"])
            print(f"Model saved after epoch {epoch+1} to {current_epoch_info['model_path']} \n")

        if use_scheduler == True:
            # Scheduler step should follow after considering the results (placed after otallher losses)
            scheduler.step(val_loss)


    # Save the final model
    if current_epoch_info:
        final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
        torch.save({ # Save this model
            'epoch': epoch+1,  # Save the current epoch
            'train_loss': train_loss,
            'val_loss': val_loss,
            'model_state_dict': model.state_dict(),  # Model weights
            'optimizer_state_dict': optimizer.state_dict(),  # Optimizer state
            'learning_rate': optimizer.param_groups[0]['lr'] # Optimizer state
        }, final_model_path)
        print(f"\nFinal model saved to {final_model_path}")

    print("\nTraining complete. \n\nTop 5 Models Sorted by Validation Accuracy: ")
    for res in best_results:        
        print(f"Epoch {res['epoch']}/{num_epochs}, "
              f"Train Loss: {res['train_loss']:.9f}, "
              f"Train-Class-Acc: {train_classwise_accuracy}, " 
              f"Val Loss: {res['val_loss']:.9f}, "
              f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
              f"Val-Class-Acc: {val_classwise_accuracy}, "
              f"Model Path: {res['model_path']}")
    print('\n')
    
    del X_train, y_train, X_val, y_val, train_dataset, val_dataset, train_loader, val_loader
    torch.cuda.empty_cache()

    # Load the checkpoint
    # checkpoint = torch.load("path/to/model_checkpoint.pth")
    # # Restore model state
    # model.load_state_dict(checkpoint['model_state_dict'])
    # # Restore optimizer state
    # optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    # # Restore scheduler state (if used)
    # scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    # # Restore epoch and other metadata
    # start_epoch = checkpoint['epoch'] + 1  # Resume from the next epoch
    # loss = checkpoint['loss']  # Optional
    # print(f"Checkpoint loaded. Resuming from epoch {start_epoch}")


def compute_classwise_accuracy(student_logits_flat, y_batch, class_correct, class_total):
    """
    Computes per-class accuracy by accumulating correct and total samples for each class.
    
    student_logits_flat: Model predictions (logits) in shape [batch_size * seq_len, output_size]
    y_batch: True labels in shape [batch_size * seq_len]
    class_correct: Dictionary to store correct predictions per class
    class_total: Dictionary to store total samples per class
    """
    # Convert logits to predicted class indices
    predictions = torch.argmax(student_logits_flat, dim=-1)  # Shape: [batch_size * seq_len]

    # Loop through batch elements to track correct/total per class
    for label, pred in zip(y_batch.cpu().numpy(), predictions.cpu().numpy()):
        if label not in class_total:
            class_total[label] = 0
            class_correct[label] = 0
        class_total[label] += 1
        if label == pred:
            class_correct[label] += 1


# Training and validation function for Period 2 and beyond 
def train_and_validate_lora(student_model, teacher_model, stable_classes, output_size, criterion, optimizer, 
                            X_train, y_train, X_val, y_val, scheduler, 
                            use_scheduler=None, num_epochs=10, batch_size=64, alpha=0.5,
                            model_saving_folder=None, model_name=None, stop_signal_file=None):
    """
    student_model: The new LoRA-based student model (with output size 3).
    teacher_model: Frozen teacher model from period 1 (with output size 2).
    criterion: CrossEntropyLoss function.
    optimizer: Optimizer for student model.
    X_train, y_train, X_val, y_val: Training/validation data (as NumPy arrays or similar).
    num_epochs: Number of epochs to train.
    batch_size: Batch size for DataLoader.
    alpha: Weighting factor for distillation loss (alpha * distill_loss + (1-alpha) * ce_loss).
    """
    print("'train_and_validate' function started. \n")
    # Ensure model saving folder exists (deleting existing first if there is one)
    if model_saving_folder and os.path.exists(model_saving_folder):
        # os.rmdir(model_saving_folder) # Only works on empty folders 
        shutil.rmtree(model_saving_folder) # Safely remove all contents
        if not os.path.exists(model_saving_folder):
            print(f"Existing folder has been removed : {model_saving_folder}\n")
    if model_saving_folder and not os.path.exists(model_saving_folder):
        os.makedirs(model_saving_folder)
        
    if not model_saving_folder:
        model_saving_folder = './saved_models'
    if not model_name:
        model_name = 'model'

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    student_model.to(device)
    teacher_model.to(device)

    # Convert data to tensors # Returns a copy, original is safe
    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)  # (seqs, seq_len, features)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)    # (seqs, seq_len)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    # Create TensorDatasets
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    print("y_train:")
    print(type(y_train))
    print(y_train.dtype)
    print(y_train.shape)
    print("X_train:")
    print(type(X_train))
    print(X_train.dtype)
    print(X_train.shape)
    print("\ny_val:")
    print(type(y_val))
    print(y_val.dtype)
    print(y_val.shape)
    print("X_val:")
    print(type(X_val))
    print(X_val.dtype)
    print(X_val.shape)

    # Debug prints for TensorDataset and DataLoader
    print("\nDataset Lengths:")
    print(f"Train Dataset Length: {len(train_dataset)}")
    print(f"Validation Dataset Length: {len(val_dataset)}")

    print("\nDataLoader Batch Sizes:")
    print(f"Number of Batches in Train DataLoader: {len(train_loader)}")
    print(f"Number of Batches in Validation DataLoader: {len(val_loader)}")

    # Additional details for y_train, y_val, and y_test
    print("\ny_train Unique Values and Stats:")
    print(f"Unique values in y_train: {y_train.unique()}")
    print(f"y_train Min: {y_train.min()}, Max: {y_train.max()}")

    print("\ny_val Unique Values and Stats:")
    print(f"Unique values in y_val: {y_val.unique()}")
    print(f"y_val Min: {y_val.min()}, Max: {y_val.max()}")

    # Device check
    print("\nDevice Info:")
    print(f"X_train Device: {X_train.device}")
    print(f"y_train Device: {y_train.device}")
    print(f"X_val Device: {X_val.device}")
    print(f"y_val Device: {y_val.device}\n")

    # Calculate number of batches
    # num_batches = (len(X_train) + batch_size - 1) // batch_size

    global best_results  # Ensure we can modify the external variable if defined outside.
    best_results = []    # Start empty each training run

    teacher_model.eval()  # Ensure teacher is frozen
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        class_correct = {}  # Dictionary to store correct predictions per class
        class_total = {}  # Dictionary to store total samples per class
        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\nStop signal detected. Exiting training loop safely.\n")
            break
        student_model.train()
        i=0
        for X_batch, y_batch in train_loader:
            # Reset gradients before forward pass
            optimizer.zero_grad()  # Best practice

            # Forward pass: student model produces logits for output_size classes.
            student_logits = student_model(X_batch)  # Shape: [batch, seq_len, output_size]
            
            # Reshape for CE loss computation.
            student_logits_flat = student_logits.view(-1, output_size)
            y_batch = y_batch.view(-1)

            # Compute Cross-Entropy loss
            ce_loss = criterion(student_logits_flat, y_batch)

            # Compute class-wise accuracy (Accumulates values in dict)
            compute_classwise_accuracy(student_logits_flat, y_batch, class_correct, class_total)

            if epoch == 1 and i < 3:
                i += 1
                print(f"\nUnique target values: {y_batch.unique()}")
                print(f"Target dtype: {y_batch.dtype}")
                print(f"Min target: {y_batch.min()}, Max target: {y_batch.max()}")
                print("Unique classes in y_train:", y_train.unique())
                print(f"Unique classes in y_val: {y_val.unique()}\n")

            # Knowledge Distillation:
            # Forward pass through teacher (pre-trained on previous period data).
            with torch.no_grad():
                teacher_logits = teacher_model(X_batch)  # Shape: [batch, seq_len, teacher_output_size]
            # Use stable_classes (a list of indices) to extract the relevant logits.
            # We distill only the stable classes (class 1 if teacher is from period 1).
            # Teacher's class index 1 corresponds to student's class index 1.
            # It's safer to use index_select to ensure the operation works on GPU.
            stable_indices = torch.tensor(stable_classes, device=teacher_logits.device)
            teacher_stable = teacher_logits.index_select(dim=2, index=stable_indices)
            student_stable = student_logits.index_select(dim=2, index=stable_indices)

            # Compute the distillation loss over the selected stable classes.
            distill_loss = F.mse_loss(student_stable, teacher_stable)
            
            # Total loss: balance between cross-entropy and distillation loss.
            total_loss = alpha * distill_loss + (1 - alpha) * ce_loss
            total_loss.backward()
            optimizer.step()
            epoch_loss += total_loss.item() * X_batch.size(0)
            
        train_loss = epoch_loss / len(train_loader.dataset)

        # Compute per-class training accuracy
        # train_classwise_accuracy = {int(c): (class_correct[c] / class_total[c]) * 100 if class_total[c] > 0 else 0 
        #                            for c in sorted(class_total.keys())}
        train_classwise_accuracy = {int(c): f"{(class_correct[c] / class_total[c]) * 100:.2f}%" if class_total[c] > 0 else "0.00%" 
                                    for c in sorted(class_total.keys())}

        # Perform validation at the end of each epoch (only CE loss and accuracy)
        student_model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        val_class_correct = {}
        val_class_total = {}
        with torch.no_grad():
            for X_val_batch, y_val_batch in val_loader:
                val_outputs = student_model(X_val_batch).view(-1, output_size)
                val_labels = y_val_batch.view(-1)
                val_loss += criterion(val_outputs, val_labels).item() * X_val_batch.size(0)  # Scale to total loss
                val_predictions = torch.argmax(val_outputs, dim=-1)
                val_correct += (val_predictions == val_labels).sum().item()
                val_total += val_labels.size(0)
                # Compute per-class validation accuracy
                compute_classwise_accuracy(val_outputs, val_labels, val_class_correct, val_class_total)
        val_loss /= len(val_loader.dataset)
        val_accuracy = val_correct / val_total

        # Compute per-class validation accuracy
        # val_classwise_accuracy = {int(c): (val_class_correct[c] / val_class_total[c]) * 100 if val_class_total[c] > 0 else 0 
        #                          for c in sorted(val_class_total.keys())}
        val_classwise_accuracy = {int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%" 
                                  for c in sorted(val_class_total.keys())}

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train Loss: {train_loss:.9f}, "
              f"Train-Class-Acc: {train_classwise_accuracy}, "
              f"Val Loss: {val_loss:.9f}, "
              f"Val Accuracy: {val_accuracy * 100:.2f}%, "
              f"Val-Class-Acc: {val_classwise_accuracy}, "
              f"LR: {optimizer.param_groups[0]['lr']:.9f}")

        # Save current model and update best results if applicable
        current_epoch_info = {
            "epoch": epoch+1,
            "train_loss": train_loss,
            "train_classwise_accuracy": train_classwise_accuracy,
            "val_loss": val_loss,
            "val_accuracy": val_accuracy,
            "val_classwise_accuracy": val_classwise_accuracy,
            'learning_rate': optimizer.param_groups[0]['lr'], # Optimizer state
            "model_path": os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        }

        # Insert this epoch if we have fewer than 5 results
        # or if it beats the lowest of the top 5
        if len(best_results) < 5 or val_accuracy > best_results[-1]["val_accuracy"]:
            if len(best_results) == 5:
                # Remove the worst model from the list, the last (lowest accuracy)
                worst = best_results.pop() 
                if os.path.exists(worst["model_path"]):
                    os.remove(worst["model_path"])
                    print(f"Removed old model with accuracy {worst['val_accuracy']*100:.2f}%, and file was at {worst['model_path']}")
            # Just insert and sort by val_accuracy descending
            best_results.append(current_epoch_info) 
            best_results.sort(key=lambda x: x["val_accuracy"], reverse=True)
            torch.save({ # Save this model
                'epoch': epoch+1,  # Save the current epoch
                'train_loss': train_loss,
                'val_loss': val_loss,
                'model_state_dict': student_model.state_dict(),  # Model weights
                'optimizer_state_dict': optimizer.state_dict(),  # Optimizer state
                'learning_rate': optimizer.param_groups[0]['lr'] # Optimizer state
            }, current_epoch_info["model_path"])
            print(f"Model saved after epoch {epoch+1} to {current_epoch_info['model_path']} \n")

        if use_scheduler == True:
            # Scheduler step should follow after considering the results (placed after otallher losses)
            scheduler.step(val_loss)

    # Save the final model
    if current_epoch_info:
        final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
        torch.save({ # Save this model
            'epoch': epoch+1,  # Save the current epoch
            'train_loss': train_loss,
            'val_loss': val_loss,
            'model_state_dict': student_model.state_dict(),  # Model weights
            'optimizer_state_dict': optimizer.state_dict(),  # Optimizer state
            'learning_rate': optimizer.param_groups[0]['lr'] # Optimizer state
        }, final_model_path)
        print(f"\nFinal model saved to {final_model_path}")

    print("\nTraining complete. \n\nTop 5 Models Sorted by Validation Accuracy: ")
    for res in best_results:        
        print(f"Epoch {res['epoch']}/{num_epochs}, "
              f"Train Loss: {res['train_loss']:.9f}, "
              f"Train-Class-Acc: {train_classwise_accuracy}, " 
              f"Val Loss: {res['val_loss']:.9f}, "
              f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
              f"Val-Class-Acc: {val_classwise_accuracy}, "
              f"Model Path: {res['model_path']}")
    print('\n')
    
    del X_train, y_train, X_val, y_val, train_dataset, val_dataset, train_loader, val_loader
    torch.cuda.empty_cache()

# %% [markdown]
# ### Set parameters and initialize model

# %%
print("PyTorch compiled CUDA version:", torch.version.cuda)
# Out:
# PyTorch compiled CUDA version: 12.4

# %%
print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
print("Num GPUs:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))

torch.manual_seed(42)
print("Seeding successful!")
# Out:
# PyTorch Version: 2.4.1+cu124
# CUDA Available: True
# Num GPUs: 1
# GPU Name: NVIDIA GeForce RTX 4070
# Seeding successful!

# %% [markdown]
# ### list_period_files_full_path

# %%
pair = 'BTCUSD'
file_name = f'Polygon_{pair}_4Y_1min'  # File name for saving data
# BASE_FOLDER_PATH = f"{Working_directory}/Data/{file_name}"
BASE_FOLDER_PATH = f"Data/{file_name}"
# folder_path=f'{BASE_FOLDER_PATH}/polygon_io/12_USD_Crypto_Pairs/{file_name}'
folder_path=f'{BASE_FOLDER_PATH}'
if not os.path.isdir(folder_path):
    raise FileNotFoundError(f"Directory '{folder_path}' does not exist.")
file_path=f'{folder_path}/{file_name}.csv'
number_days = 190
with_indicators_file_path = os.path.normpath(f'{folder_path}/_{file_name}_{number_days}_days_with_indicators.csv')

# LABORATORY\_Global_Pytorch\Continual_Learning\Data\Polygon_BTCUSD_4Y_1min

list_period_files_full_path = [
    # Period 1
    with_indicators_file_path,
    # Period 2
    os.path.normpath(f"{folder_path}/Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20__with_indicators.csv"),
    # Period 3
    os.path.normpath(f"{folder_path}/Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26__with_indicators.csv"),
    # Period 4
    os.path.normpath(f"{folder_path}/Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04__with_indicators.csv"),
    # Period 5
    os.path.normpath(f"{folder_path}/Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11__with_indicators.csv")
]

with_indicators_file_path
# Out:
# 'Data\\Polygon_BTCUSD_4Y_1min\\_Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv'

# %%
for file in os.listdir(folder_path):
    print(f"Found file: {file}")

# Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv
# Out:
# Found file: Polygon_BTCUSD_4Y_1min.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2020-11-11__2021-05-20__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-05-20__2021-11-26__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2021-11-26__2022-06-04__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11.png
# Found file: Polygon_BTCUSD_4Y_1min_190_days__2022-06-04__2022-12-11__with_indicators.csv
# Found file: Polygon_BTCUSD_4Y_1min_525_days.png
# Found file: _Polygon_BTCUSD_4Y_1min_190_days.png
# Found file: _Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv

# %%
X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
    with_indicators_file_path = list_period_files_full_path[0],
    downsampled_data_minutes = downsampled_data_minutes,
    exclude_columns = exclude_columns,
    lower_threshold = lower_threshold,
    upper_threshold = upper_threshold,
    reverse_steps = reverse_steps,
    sequence_length = sequence_length,
    sliding_interval = sliding_interval,
    trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
)

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, X_test, y_test, Number_features
del unique_classes, num_classes
# Out:
# File path: Data\Polygon_BTCUSD_4Y_1min\_Polygon_BTCUSD_4Y_1min_190_days_with_indicators.csv
#
# data_retrieved - Missing timestamps time:
# DatetimeIndex([], dtype='datetime64[ns, UTC]', freq='min')
#
# data_gaussian - Missing timestamps time:
# DatetimeIndex([], dtype='datetime64[ns, UTC]', freq='min')
#
# columns_to_transform =
# Index(['open', 'high', 'low', 'close', 'SMA_5', 'SMA_10', 'EMA_10'], dtype='object'),
# len(columns_to_transform) = 7
#
# data_log_return - Missing timestamps time:
# DatetimeIndex([], dtype='datetime64[ns, UTC]', freq='min')
#
# No missing timestamps.
#
#     Number of sequences:
#         - sequences[0].shape: (1000, 7)
#         - Total sequences: 4543
#         - Train sequences: 3634
#         - Validation sequences: 454
#         - Test sequences: 455
#
# close_col_index = 3
# Number_features = 7
# unique_classes = [0 1 2 3 4]
# num_classes = 5

# %% [markdown]
# ### __*All periods data*__

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""

# Initialize empty lists to combine validation elements
# X_train_all = []
# y_train_all = []
# X_val_all = []
# y_val_all = []
# X_test_all = []
# y_test_all = []

# for path_ in list_period_files_full_path:
#     with contextlib.redirect_stdout(open(os.devnull, 'w')):
#         X_train_, y_train_, X_val_, y_val_, X_test_, y_test_, Number_features = process_and_return_splits(
#             with_indicators_file_path = path_,
#             downsampled_data_minutes = downsampled_data_minutes,
#             exclude_columns = exclude_columns,
#             lower_threshold = lower_threshold,
#             upper_threshold = upper_threshold,
#             reverse_steps = reverse_steps,
#             sequence_length = sequence_length,
#             sliding_interval = sliding_interval,
#             trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
#         )
#     # Combine validation elements
#     X_train_all.extend(X_train_)
#     y_train_all.extend(y_train_)
#     X_val_all.extend(X_val_)
#     y_val_all.extend(y_val_)
#     X_test_all.extend(X_test_)
#     y_test_all.extend(y_test_)
#     # Delete unused variables to save memory
#     del X_train_, y_train_, X_val_, y_val_, X_test_, y_test_

# X_train_all = np.array(X_train_all)
# y_train_all = np.array(y_train_all)
# X_val_all = np.array(X_val_all)
# y_val_all = np.array(y_val_all)
# X_test_all = np.array(X_test_all)
# y_test_all = np.array(y_test_all)


# with contextlib.redirect_stdout(open(os.devnull, 'w')):
#     X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
#         with_indicators_file_path = list_period_files_full_path[0],
#         downsampled_data_minutes = downsampled_data_minutes,
#         exclude_columns = exclude_columns,
#         lower_threshold = lower_threshold,
#         upper_threshold = upper_threshold,
#         reverse_steps = reverse_steps,
#         sequence_length = sequence_length,
#         sliding_interval = sliding_interval,
#         trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
#         # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
#     )
    
# print(f"\nNumber_features = {Number_features}")

# unique_classes = np.unique(y_val)
# num_classes = len(unique_classes)
# print(f"unique_classes = {unique_classes}")
# print(f"num_classes = {num_classes}")
# Out:
# "\n- 'trend': Categorized trend values based on the detected phases:\n    - 0: No trend\n    - 1: Moderate negative trend\n    - 2: Very strong negative trend\n    - 3: Moderate positive trend\n    - 4: Very strong positive trend\n"

# %% [markdown]
# ### Period 1 --> Training and saving in __*'1st_try'*__ (BiGRUWithAttention, num_layers = 4) ---> Val acc = 98.35 %
# ### Val-Class-Acc: {0: '98.63%', 1: '97.92%'}

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[0], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1]
# num_classes = 2

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttention' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttention(input_size, hidden_size, output_size, num_layers).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1], device='cuda:0')
# y_train Min: 0, Max: 1
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1], device='cuda:0')
# y_val Min: 0, Max: 1
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 0.681195149, Train-Class-Acc: {0: '98.48%', 1: '1.57%'}, Val Loss: 0.670978806, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1.pth
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 0.659097561, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.671626767, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 0.658912126, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.672343892, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 0.658798798, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.670798046, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 0.658789793, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.670712810, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 0.658633200, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.670821638, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 7/2000, Train Loss: 0.658653052, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.672454676, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 8/2000, Train Loss: 0.658567325, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.671255033, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 9/2000, Train Loss: 0.658194496, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.670800413, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 10/2000, Train Loss: 0.658025196, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.669505533, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 11/2000, Train Loss: 0.657949901, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.670813681, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 12/2000, Train Loss: 0.657441564, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.672089164, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 13/2000, Train Loss: 0.656437984, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.669727216, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 14/2000, Train Loss: 0.653848377, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.664403139, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 15/2000, Train Loss: 0.646628344, Train-Class-Acc: {0: '100.00%', 1: '0.00%'}, Val Loss: 0.609726766, Val Accuracy: 60.61%, Val-Class-Acc: {0: '100.00%', 1: '0.00%'}, LR: 0.000100000
# Epoch 16/2000, Train Loss: 0.614362940, Train-Class-Acc: {0: '99.91%', 1: '1.19%'}, Val Loss: 0.600788087, Val Accuracy: 67.63%, Val-Class-Acc: {0: '99.67%', 1: '18.34%'}, LR: 0.000100000
# Removed old model with accuracy 60.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_5.pth
# Model saved after epoch 16 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_16.pth
#
# Epoch 17/2000, Train Loss: 0.621365933, Train-Class-Acc: {0: '96.15%', 1: '7.03%'}, Val Loss: 0.818046801, Val Accuracy: 59.62%, Val-Class-Acc: {0: '98.27%', 1: '0.15%'}, LR: 0.000100000
# Epoch 18/2000, Train Loss: 0.608454279, Train-Class-Acc: {0: '96.24%', 1: '3.97%'}, Val Loss: 0.562103030, Val Accuracy: 60.73%, Val-Class-Acc: {0: '99.43%', 1: '1.19%'}, LR: 0.000100000
# Removed old model with accuracy 60.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_4.pth
# Model saved after epoch 18 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_18.pth
#
# Epoch 19/2000, Train Loss: 0.514641512, Train-Class-Acc: {0: '99.48%', 1: '8.85%'}, Val Loss: 0.566889348, Val Accuracy: 68.41%, Val-Class-Acc: {0: '76.29%', 1: '56.30%'}, LR: 0.000100000
# Removed old model with accuracy 60.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_3.pth
# Model saved after epoch 19 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_19.pth
#
# Epoch 20/2000, Train Loss: 0.644582497, Train-Class-Acc: {0: '82.75%', 1: '18.11%'}, Val Loss: 0.504615842, Val Accuracy: 64.25%, Val-Class-Acc: {0: '98.39%', 1: '11.73%'}, LR: 0.000100000
# Removed old model with accuracy 60.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_2.pth
# Model saved after epoch 20 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_20.pth
#
# Epoch 21/2000, Train Loss: 0.492967396, Train-Class-Acc: {0: '97.49%', 1: '27.76%'}, Val Loss: 0.487886070, Val Accuracy: 68.63%, Val-Class-Acc: {0: '99.16%', 1: '21.65%'}, LR: 0.000100000
# Removed old model with accuracy 60.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1.pth
# Model saved after epoch 21 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_21.pth
#
# Epoch 22/2000, Train Loss: 0.452352457, Train-Class-Acc: {0: '96.95%', 1: '43.08%'}, Val Loss: 0.487116188, Val Accuracy: 79.81%, Val-Class-Acc: {0: '78.69%', 1: '81.53%'}, LR: 0.000100000
# Removed old model with accuracy 60.73%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_18.pth
# Model saved after epoch 22 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_22.pth
#
# Epoch 23/2000, Train Loss: 0.434873998, Train-Class-Acc: {0: '95.18%', 1: '58.11%'}, Val Loss: 0.390466562, Val Accuracy: 88.28%, Val-Class-Acc: {0: '88.55%', 1: '87.86%'}, LR: 0.000100000
# Removed old model with accuracy 64.25%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_20.pth
# Model saved after epoch 23 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_23.pth
#
# Epoch 24/2000, Train Loss: 0.371178092, Train-Class-Acc: {0: '91.24%', 1: '74.65%'}, Val Loss: 0.405491732, Val Accuracy: 80.64%, Val-Class-Acc: {0: '97.23%', 1: '55.13%'}, LR: 0.000100000
# Removed old model with accuracy 67.63%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_16.pth
# Model saved after epoch 24 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_24.pth
#
# Epoch 25/2000, Train Loss: 0.310568025, Train-Class-Acc: {0: '90.22%', 1: '80.46%'}, Val Loss: 0.291351317, Val Accuracy: 86.98%, Val-Class-Acc: {0: '96.50%', 1: '72.34%'}, LR: 0.000100000
# Removed old model with accuracy 68.41%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_19.pth
# Model saved after epoch 25 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_25.pth
#
# Epoch 26/2000, Train Loss: 0.297321178, Train-Class-Acc: {0: '90.23%', 1: '81.70%'}, Val Loss: 0.448748425, Val Accuracy: 81.14%, Val-Class-Acc: {0: '97.49%', 1: '55.99%'}, LR: 0.000100000
# Removed old model with accuracy 68.63%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_21.pth
# Model saved after epoch 26 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_26.pth
#
# Epoch 27/2000, Train Loss: 0.303039434, Train-Class-Acc: {0: '90.36%', 1: '81.03%'}, Val Loss: 0.213425552, Val Accuracy: 91.43%, Val-Class-Acc: {0: '93.11%', 1: '88.84%'}, LR: 0.000100000
# Removed old model with accuracy 79.81%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_22.pth
# Model saved after epoch 27 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_27.pth
#
# Epoch 28/2000, Train Loss: 0.272568219, Train-Class-Acc: {0: '90.89%', 1: '83.61%'}, Val Loss: 0.222415951, Val Accuracy: 90.64%, Val-Class-Acc: {0: '88.26%', 1: '94.29%'}, LR: 0.000100000
# Removed old model with accuracy 80.64%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_24.pth
# Model saved after epoch 28 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_28.pth
#
# Epoch 29/2000, Train Loss: 0.264326659, Train-Class-Acc: {0: '91.15%', 1: '83.98%'}, Val Loss: 0.203569631, Val Accuracy: 91.66%, Val-Class-Acc: {0: '93.73%', 1: '88.48%'}, LR: 0.000100000
# Removed old model with accuracy 81.14%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_26.pth
# Model saved after epoch 29 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_29.pth
#
# Epoch 30/2000, Train Loss: 0.244300543, Train-Class-Acc: {0: '91.83%', 1: '85.53%'}, Val Loss: 0.197122880, Val Accuracy: 91.94%, Val-Class-Acc: {0: '93.34%', 1: '89.79%'}, LR: 0.000100000
# Removed old model with accuracy 86.98%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_25.pth
# Model saved after epoch 30 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_30.pth
#
# Epoch 31/2000, Train Loss: 0.257247911, Train-Class-Acc: {0: '91.15%', 1: '84.93%'}, Val Loss: 0.209243174, Val Accuracy: 91.30%, Val-Class-Acc: {0: '95.55%', 1: '84.75%'}, LR: 0.000100000
# Removed old model with accuracy 88.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_23.pth
# Model saved after epoch 31 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_31.pth
#
# Epoch 32/2000, Train Loss: 0.238245306, Train-Class-Acc: {0: '91.86%', 1: '86.02%'}, Val Loss: 0.228018277, Val Accuracy: 90.47%, Val-Class-Acc: {0: '96.41%', 1: '81.33%'}, LR: 0.000100000
# Epoch 33/2000, Train Loss: 0.264013958, Train-Class-Acc: {0: '90.89%', 1: '84.62%'}, Val Loss: 0.233804809, Val Accuracy: 90.09%, Val-Class-Acc: {0: '85.87%', 1: '96.59%'}, LR: 0.000100000
# Epoch 34/2000, Train Loss: 0.243011474, Train-Class-Acc: {0: '91.73%', 1: '85.68%'}, Val Loss: 0.187668636, Val Accuracy: 92.43%, Val-Class-Acc: {0: '93.27%', 1: '91.13%'}, LR: 0.000100000
# Removed old model with accuracy 90.64%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_28.pth
# Model saved after epoch 34 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_34.pth
#
# Epoch 35/2000, Train Loss: 0.236420788, Train-Class-Acc: {0: '91.81%', 1: '86.48%'}, Val Loss: 0.184720213, Val Accuracy: 92.62%, Val-Class-Acc: {0: '93.76%', 1: '90.85%'}, LR: 0.000100000
# Removed old model with accuracy 91.30%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_31.pth
# Model saved after epoch 35 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_35.pth
#
# Epoch 36/2000, Train Loss: 0.217609777, Train-Class-Acc: {0: '92.67%', 1: '87.48%'}, Val Loss: 0.191684678, Val Accuracy: 92.00%, Val-Class-Acc: {0: '90.19%', 1: '94.78%'}, LR: 0.000100000
# Removed old model with accuracy 91.43%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_27.pth
# Model saved after epoch 36 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_36.pth
#
# Epoch 37/2000, Train Loss: 0.284277942, Train-Class-Acc: {0: '90.44%', 1: '84.33%'}, Val Loss: 0.286707052, Val Accuracy: 87.34%, Val-Class-Acc: {0: '97.40%', 1: '71.85%'}, LR: 0.000100000
# Epoch 38/2000, Train Loss: 0.265898370, Train-Class-Acc: {0: '91.60%', 1: '83.21%'}, Val Loss: 0.187562795, Val Accuracy: 92.62%, Val-Class-Acc: {0: '94.24%', 1: '90.11%'}, LR: 0.000100000
# Removed old model with accuracy 91.66%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_29.pth
# Model saved after epoch 38 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_38.pth
#
# Epoch 39/2000, Train Loss: 0.210585040, Train-Class-Acc: {0: '92.97%', 1: '88.04%'}, Val Loss: 0.180045803, Val Accuracy: 92.94%, Val-Class-Acc: {0: '95.34%', 1: '89.24%'}, LR: 0.000100000
# Removed old model with accuracy 91.94%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_30.pth
# Model saved after epoch 39 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_39.pth
#
# Epoch 40/2000, Train Loss: 0.238094420, Train-Class-Acc: {0: '91.87%', 1: '86.75%'}, Val Loss: 0.178726288, Val Accuracy: 93.09%, Val-Class-Acc: {0: '95.35%', 1: '89.62%'}, LR: 0.000100000
# Removed old model with accuracy 92.00%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_36.pth
# Model saved after epoch 40 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_40.pth
#
# Epoch 41/2000, Train Loss: 0.207275141, Train-Class-Acc: {0: '93.05%', 1: '88.52%'}, Val Loss: 0.175347696, Val Accuracy: 93.12%, Val-Class-Acc: {0: '92.19%', 1: '94.54%'}, LR: 0.000100000
# Removed old model with accuracy 92.43%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_34.pth
# Model saved after epoch 41 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_41.pth
#
# Epoch 42/2000, Train Loss: 0.209914956, Train-Class-Acc: {0: '92.97%', 1: '88.55%'}, Val Loss: 0.225025468, Val Accuracy: 90.83%, Val-Class-Acc: {0: '86.54%', 1: '97.41%'}, LR: 0.000100000
# Epoch 43/2000, Train Loss: 0.220341593, Train-Class-Acc: {0: '92.36%', 1: '88.49%'}, Val Loss: 0.167316595, Val Accuracy: 93.70%, Val-Class-Acc: {0: '95.53%', 1: '90.88%'}, LR: 0.000100000
# Removed old model with accuracy 92.62%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_35.pth
# Model saved after epoch 43 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_43.pth
#
# Epoch 44/2000, Train Loss: 0.269007935, Train-Class-Acc: {0: '91.00%', 1: '85.73%'}, Val Loss: 0.174062059, Val Accuracy: 93.47%, Val-Class-Acc: {0: '94.09%', 1: '92.52%'}, LR: 0.000100000
# Removed old model with accuracy 92.62%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_38.pth
# Model saved after epoch 44 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_44.pth
#
# Epoch 45/2000, Train Loss: 0.197333827, Train-Class-Acc: {0: '93.40%', 1: '89.67%'}, Val Loss: 0.164271003, Val Accuracy: 93.83%, Val-Class-Acc: {0: '95.41%', 1: '91.41%'}, LR: 0.000100000
# Removed old model with accuracy 92.94%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_39.pth
# Model saved after epoch 45 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_45.pth
#
# Epoch 46/2000, Train Loss: 0.189310658, Train-Class-Acc: {0: '93.72%', 1: '90.13%'}, Val Loss: 0.191949290, Val Accuracy: 92.42%, Val-Class-Acc: {0: '97.29%', 1: '84.93%'}, LR: 0.000100000
# Epoch 47/2000, Train Loss: 0.271163867, Train-Class-Acc: {0: '90.86%', 1: '85.76%'}, Val Loss: 0.169589889, Val Accuracy: 93.54%, Val-Class-Acc: {0: '92.72%', 1: '94.79%'}, LR: 0.000100000
# Removed old model with accuracy 93.09%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_40.pth
# Model saved after epoch 47 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_47.pth
#
# Epoch 48/2000, Train Loss: 0.194548183, Train-Class-Acc: {0: '93.36%', 1: '90.04%'}, Val Loss: 0.159067444, Val Accuracy: 94.13%, Val-Class-Acc: {0: '95.43%', 1: '92.14%'}, LR: 0.000100000
# Removed old model with accuracy 93.12%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_41.pth
# Model saved after epoch 48 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_48.pth
#
# Epoch 49/2000, Train Loss: 0.180990097, Train-Class-Acc: {0: '94.09%', 1: '90.59%'}, Val Loss: 0.168373258, Val Accuracy: 93.31%, Val-Class-Acc: {0: '91.55%', 1: '96.01%'}, LR: 0.000100000
# Epoch 50/2000, Train Loss: 0.239504298, Train-Class-Acc: {0: '92.20%', 1: '88.41%'}, Val Loss: 0.383417705, Val Accuracy: 83.95%, Val-Class-Acc: {0: '74.85%', 1: '97.95%'}, LR: 0.000100000
# Epoch 51/2000, Train Loss: 0.288683205, Train-Class-Acc: {0: '89.87%', 1: '85.09%'}, Val Loss: 0.169444337, Val Accuracy: 93.85%, Val-Class-Acc: {0: '93.69%', 1: '94.11%'}, LR: 0.000100000
# Removed old model with accuracy 93.47%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_44.pth
# Model saved after epoch 51 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_51.pth
#
# Epoch 52/2000, Train Loss: 0.191881882, Train-Class-Acc: {0: '93.61%', 1: '90.22%'}, Val Loss: 0.175076038, Val Accuracy: 93.17%, Val-Class-Acc: {0: '97.07%', 1: '87.17%'}, LR: 0.000100000
# Epoch 53/2000, Train Loss: 0.185404059, Train-Class-Acc: {0: '93.90%', 1: '90.42%'}, Val Loss: 0.152652687, Val Accuracy: 94.45%, Val-Class-Acc: {0: '96.07%', 1: '91.97%'}, LR: 0.000100000
# Removed old model with accuracy 93.54%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_47.pth
# Model saved after epoch 53 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_53.pth
#
# Epoch 54/2000, Train Loss: 0.191675974, Train-Class-Acc: {0: '93.59%', 1: '90.16%'}, Val Loss: 0.174494223, Val Accuracy: 92.84%, Val-Class-Acc: {0: '90.00%', 1: '97.20%'}, LR: 0.000100000
# Epoch 55/2000, Train Loss: 0.193448262, Train-Class-Acc: {0: '93.27%', 1: '90.34%'}, Val Loss: 0.145541254, Val Accuracy: 94.62%, Val-Class-Acc: {0: '95.35%', 1: '93.51%'}, LR: 0.000100000
# Removed old model with accuracy 93.70%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_43.pth
# Model saved after epoch 55 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_55.pth
#
# Epoch 56/2000, Train Loss: 0.182504379, Train-Class-Acc: {0: '93.71%', 1: '90.91%'}, Val Loss: 0.146615895, Val Accuracy: 94.62%, Val-Class-Acc: {0: '96.20%', 1: '92.19%'}, LR: 0.000100000
# Removed old model with accuracy 93.83%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_45.pth
# Model saved after epoch 56 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_56.pth
#
# Epoch 57/2000, Train Loss: 0.179727800, Train-Class-Acc: {0: '93.88%', 1: '91.00%'}, Val Loss: 0.143332199, Val Accuracy: 94.74%, Val-Class-Acc: {0: '96.10%', 1: '92.65%'}, LR: 0.000100000
# Removed old model with accuracy 93.85%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_51.pth
# Model saved after epoch 57 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_57.pth
#
# Epoch 58/2000, Train Loss: 0.172354028, Train-Class-Acc: {0: '94.11%', 1: '91.44%'}, Val Loss: 0.188774437, Val Accuracy: 92.26%, Val-Class-Acc: {0: '88.50%', 1: '98.06%'}, LR: 0.000100000
# Epoch 59/2000, Train Loss: 0.170791950, Train-Class-Acc: {0: '93.99%', 1: '91.76%'}, Val Loss: 0.150424770, Val Accuracy: 94.05%, Val-Class-Acc: {0: '92.23%', 1: '96.85%'}, LR: 0.000100000
# Epoch 60/2000, Train Loss: 0.237950610, Train-Class-Acc: {0: '92.22%', 1: '88.79%'}, Val Loss: 0.141766477, Val Accuracy: 94.74%, Val-Class-Acc: {0: '95.23%', 1: '93.99%'}, LR: 0.000100000
# Removed old model with accuracy 94.13%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_48.pth
# Model saved after epoch 60 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_60.pth
#
# Epoch 61/2000, Train Loss: 0.159865226, Train-Class-Acc: {0: '94.46%', 1: '92.36%'}, Val Loss: 0.134701482, Val Accuracy: 95.03%, Val-Class-Acc: {0: '95.34%', 1: '94.57%'}, LR: 0.000100000
# Removed old model with accuracy 94.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_53.pth
# Model saved after epoch 61 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_61.pth
#
# Epoch 62/2000, Train Loss: 0.154645165, Train-Class-Acc: {0: '94.79%', 1: '92.43%'}, Val Loss: 0.131383347, Val Accuracy: 95.01%, Val-Class-Acc: {0: '94.71%', 1: '95.47%'}, LR: 0.000100000
# Removed old model with accuracy 94.62%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_56.pth
# Model saved after epoch 62 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_62.pth
#
# Epoch 63/2000, Train Loss: 0.173537951, Train-Class-Acc: {0: '93.96%', 1: '91.48%'}, Val Loss: 0.141241268, Val Accuracy: 94.84%, Val-Class-Acc: {0: '97.09%', 1: '91.38%'}, LR: 0.000100000
# Removed old model with accuracy 94.62%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_55.pth
# Model saved after epoch 63 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_63.pth
#
# Epoch 64/2000, Train Loss: 0.190194924, Train-Class-Acc: {0: '93.68%', 1: '90.57%'}, Val Loss: 0.258897337, Val Accuracy: 89.44%, Val-Class-Acc: {0: '83.42%', 1: '98.72%'}, LR: 0.000100000
# Epoch 65/2000, Train Loss: 0.203301990, Train-Class-Acc: {0: '92.82%', 1: '90.43%'}, Val Loss: 0.209081068, Val Accuracy: 91.74%, Val-Class-Acc: {0: '97.77%', 1: '82.46%'}, LR: 0.000100000
# Epoch 66/2000, Train Loss: 0.181119686, Train-Class-Acc: {0: '93.89%', 1: '90.84%'}, Val Loss: 0.131768431, Val Accuracy: 95.32%, Val-Class-Acc: {0: '96.18%', 1: '93.99%'}, LR: 0.000100000
# Removed old model with accuracy 94.74%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_57.pth
# Model saved after epoch 66 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_66.pth
#
# Epoch 67/2000, Train Loss: 0.147911904, Train-Class-Acc: {0: '95.05%', 1: '92.76%'}, Val Loss: 0.125778688, Val Accuracy: 95.44%, Val-Class-Acc: {0: '96.16%', 1: '94.33%'}, LR: 0.000100000
# Removed old model with accuracy 94.74%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_60.pth
# Model saved after epoch 67 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_67.pth
#
# Epoch 68/2000, Train Loss: 0.163452386, Train-Class-Acc: {0: '94.38%', 1: '91.96%'}, Val Loss: 0.126433608, Val Accuracy: 95.37%, Val-Class-Acc: {0: '96.67%', 1: '93.38%'}, LR: 0.000100000
# Removed old model with accuracy 94.84%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_63.pth
# Model saved after epoch 68 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_68.pth
#
# Epoch 69/2000, Train Loss: 0.194460999, Train-Class-Acc: {0: '93.52%', 1: '90.41%'}, Val Loss: 0.124454915, Val Accuracy: 95.45%, Val-Class-Acc: {0: '95.45%', 1: '95.46%'}, LR: 0.000100000
# Removed old model with accuracy 95.01%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_62.pth
# Model saved after epoch 69 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_69.pth
#
# Epoch 70/2000, Train Loss: 0.157647210, Train-Class-Acc: {0: '94.58%', 1: '92.27%'}, Val Loss: 0.173349854, Val Accuracy: 93.19%, Val-Class-Acc: {0: '97.90%', 1: '85.95%'}, LR: 0.000100000
# Epoch 71/2000, Train Loss: 0.165655796, Train-Class-Acc: {0: '94.52%', 1: '91.55%'}, Val Loss: 0.147469963, Val Accuracy: 93.61%, Val-Class-Acc: {0: '90.84%', 1: '97.86%'}, LR: 0.000100000
# Epoch 72/2000, Train Loss: 0.175070485, Train-Class-Acc: {0: '93.98%', 1: '91.34%'}, Val Loss: 0.121973638, Val Accuracy: 95.63%, Val-Class-Acc: {0: '95.71%', 1: '95.51%'}, LR: 0.000100000
# Removed old model with accuracy 95.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_61.pth
# Model saved after epoch 72 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_72.pth
#
# Epoch 73/2000, Train Loss: 0.157884207, Train-Class-Acc: {0: '94.75%', 1: '92.25%'}, Val Loss: 0.123220193, Val Accuracy: 95.59%, Val-Class-Acc: {0: '96.92%', 1: '93.55%'}, LR: 0.000100000
# Removed old model with accuracy 95.32%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_66.pth
# Model saved after epoch 73 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_73.pth
#
# Epoch 74/2000, Train Loss: 0.153984929, Train-Class-Acc: {0: '94.80%', 1: '92.21%'}, Val Loss: 0.123427186, Val Accuracy: 95.10%, Val-Class-Acc: {0: '94.22%', 1: '96.47%'}, LR: 0.000100000
# Epoch 75/2000, Train Loss: 0.143387006, Train-Class-Acc: {0: '95.23%', 1: '92.87%'}, Val Loss: 0.121025656, Val Accuracy: 95.23%, Val-Class-Acc: {0: '94.34%', 1: '96.59%'}, LR: 0.000100000
# Epoch 76/2000, Train Loss: 0.154501641, Train-Class-Acc: {0: '94.79%', 1: '92.39%'}, Val Loss: 0.120860538, Val Accuracy: 95.84%, Val-Class-Acc: {0: '97.26%', 1: '93.66%'}, LR: 0.000100000
# Removed old model with accuracy 95.37%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_68.pth
# Model saved after epoch 76 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_76.pth
#
# Epoch 77/2000, Train Loss: 0.177526387, Train-Class-Acc: {0: '94.19%', 1: '91.00%'}, Val Loss: 0.120238038, Val Accuracy: 95.40%, Val-Class-Acc: {0: '94.61%', 1: '96.60%'}, LR: 0.000100000
# Epoch 78/2000, Train Loss: 0.151011696, Train-Class-Acc: {0: '94.87%', 1: '92.53%'}, Val Loss: 0.115001696, Val Accuracy: 95.91%, Val-Class-Acc: {0: '96.26%', 1: '95.36%'}, LR: 0.000100000
# Removed old model with accuracy 95.44%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_67.pth
# Model saved after epoch 78 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_78.pth
#
# Epoch 79/2000, Train Loss: 0.146998496, Train-Class-Acc: {0: '95.08%', 1: '92.72%'}, Val Loss: 0.117006985, Val Accuracy: 95.97%, Val-Class-Acc: {0: '97.17%', 1: '94.12%'}, LR: 0.000100000
# Removed old model with accuracy 95.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_69.pth
# Model saved after epoch 79 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_79.pth
#
# Epoch 80/2000, Train Loss: 0.166473881, Train-Class-Acc: {0: '94.47%', 1: '91.58%'}, Val Loss: 0.121073520, Val Accuracy: 95.82%, Val-Class-Acc: {0: '97.41%', 1: '93.38%'}, LR: 0.000100000
# Removed old model with accuracy 95.59%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_73.pth
# Model saved after epoch 80 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_80.pth
#
# Epoch 81/2000, Train Loss: 0.180372988, Train-Class-Acc: {0: '94.05%', 1: '90.99%'}, Val Loss: 0.117820070, Val Accuracy: 95.66%, Val-Class-Acc: {0: '95.09%', 1: '96.54%'}, LR: 0.000100000
# Removed old model with accuracy 95.63%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_72.pth
# Model saved after epoch 81 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_81.pth
#
# Epoch 82/2000, Train Loss: 0.136017267, Train-Class-Acc: {0: '95.53%', 1: '93.26%'}, Val Loss: 0.112264929, Val Accuracy: 95.95%, Val-Class-Acc: {0: '96.70%', 1: '94.79%'}, LR: 0.000100000
# Removed old model with accuracy 95.66%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_81.pth
# Model saved after epoch 82 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_82.pth
#
# Epoch 83/2000, Train Loss: 0.134139806, Train-Class-Acc: {0: '95.54%', 1: '93.37%'}, Val Loss: 0.113917039, Val Accuracy: 96.05%, Val-Class-Acc: {0: '97.42%', 1: '93.94%'}, LR: 0.000100000
# Removed old model with accuracy 95.82%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_80.pth
# Model saved after epoch 83 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_83.pth
#
# Epoch 84/2000, Train Loss: 0.138436239, Train-Class-Acc: {0: '95.49%', 1: '93.05%'}, Val Loss: 0.121511291, Val Accuracy: 95.07%, Val-Class-Acc: {0: '93.45%', 1: '97.56%'}, LR: 0.000100000
# Epoch 85/2000, Train Loss: 0.150480056, Train-Class-Acc: {0: '95.06%', 1: '92.50%'}, Val Loss: 0.117400858, Val Accuracy: 95.24%, Val-Class-Acc: {0: '93.97%', 1: '97.21%'}, LR: 0.000100000
# Epoch 86/2000, Train Loss: 0.143843655, Train-Class-Acc: {0: '95.16%', 1: '93.13%'}, Val Loss: 0.154823640, Val Accuracy: 94.02%, Val-Class-Acc: {0: '98.19%', 1: '87.60%'}, LR: 0.000100000
# Epoch 87/2000, Train Loss: 0.150312609, Train-Class-Acc: {0: '95.07%', 1: '92.42%'}, Val Loss: 0.113921904, Val Accuracy: 96.11%, Val-Class-Acc: {0: '97.55%', 1: '93.90%'}, LR: 0.000100000
# Removed old model with accuracy 95.84%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_76.pth
# Model saved after epoch 87 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_87.pth
#
# Epoch 88/2000, Train Loss: 0.144246975, Train-Class-Acc: {0: '95.26%', 1: '92.84%'}, Val Loss: 0.109122780, Val Accuracy: 96.28%, Val-Class-Acc: {0: '97.39%', 1: '94.58%'}, LR: 0.000100000
# Removed old model with accuracy 95.91%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_78.pth
# Model saved after epoch 88 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_88.pth
#
# Epoch 89/2000, Train Loss: 0.126816295, Train-Class-Acc: {0: '95.99%', 1: '93.59%'}, Val Loss: 0.105997992, Val Accuracy: 96.31%, Val-Class-Acc: {0: '97.25%', 1: '94.87%'}, LR: 0.000100000
# Removed old model with accuracy 95.95%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_82.pth
# Model saved after epoch 89 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_89.pth
#
# Epoch 90/2000, Train Loss: 0.123937161, Train-Class-Acc: {0: '95.95%', 1: '93.82%'}, Val Loss: 0.103911697, Val Accuracy: 96.35%, Val-Class-Acc: {0: '97.29%', 1: '94.89%'}, LR: 0.000100000
# Removed old model with accuracy 95.97%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_79.pth
# Model saved after epoch 90 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_90.pth
#
# Epoch 91/2000, Train Loss: 0.152954501, Train-Class-Acc: {0: '95.01%', 1: '92.45%'}, Val Loss: 0.121286404, Val Accuracy: 95.68%, Val-Class-Acc: {0: '97.99%', 1: '92.12%'}, LR: 0.000100000
# Epoch 92/2000, Train Loss: 0.146488075, Train-Class-Acc: {0: '95.23%', 1: '92.71%'}, Val Loss: 0.104046205, Val Accuracy: 96.32%, Val-Class-Acc: {0: '97.27%', 1: '94.85%'}, LR: 0.000100000
# Removed old model with accuracy 96.05%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_83.pth
# Model saved after epoch 92 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_92.pth
#
# Epoch 93/2000, Train Loss: 0.159179425, Train-Class-Acc: {0: '95.10%', 1: '92.18%'}, Val Loss: 0.283403634, Val Accuracy: 90.39%, Val-Class-Acc: {0: '98.62%', 1: '77.74%'}, LR: 0.000100000
# Epoch 94/2000, Train Loss: 0.149372776, Train-Class-Acc: {0: '95.31%', 1: '92.62%'}, Val Loss: 0.103143373, Val Accuracy: 96.16%, Val-Class-Acc: {0: '95.94%', 1: '96.50%'}, LR: 0.000100000
# Removed old model with accuracy 96.11%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_87.pth
# Model saved after epoch 94 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_94.pth
#
# Epoch 95/2000, Train Loss: 0.122739561, Train-Class-Acc: {0: '96.11%', 1: '93.88%'}, Val Loss: 0.102191381, Val Accuracy: 96.28%, Val-Class-Acc: {0: '97.69%', 1: '94.11%'}, LR: 0.000100000
# Removed old model with accuracy 96.16%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_94.pth
# Model saved after epoch 95 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_95.pth
#
# Epoch 96/2000, Train Loss: 0.156978270, Train-Class-Acc: {0: '95.19%', 1: '92.02%'}, Val Loss: 0.110926700, Val Accuracy: 96.21%, Val-Class-Acc: {0: '97.76%', 1: '93.83%'}, LR: 0.000100000
# Epoch 97/2000, Train Loss: 0.131073938, Train-Class-Acc: {0: '95.83%', 1: '93.39%'}, Val Loss: 0.098015525, Val Accuracy: 96.52%, Val-Class-Acc: {0: '97.35%', 1: '95.25%'}, LR: 0.000100000
# Removed old model with accuracy 96.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_88.pth
# Model saved after epoch 97 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_97.pth
#
# Epoch 98/2000, Train Loss: 0.149925058, Train-Class-Acc: {0: '95.16%', 1: '92.24%'}, Val Loss: 0.118984561, Val Accuracy: 95.57%, Val-Class-Acc: {0: '98.15%', 1: '91.62%'}, LR: 0.000100000
# Epoch 99/2000, Train Loss: 0.144172386, Train-Class-Acc: {0: '95.34%', 1: '92.64%'}, Val Loss: 0.097035566, Val Accuracy: 96.36%, Val-Class-Acc: {0: '96.74%', 1: '95.78%'}, LR: 0.000100000
# Removed old model with accuracy 96.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_95.pth
# Model saved after epoch 99 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_99.pth
#
# Epoch 100/2000, Train Loss: 0.121749277, Train-Class-Acc: {0: '96.24%', 1: '93.82%'}, Val Loss: 0.097131094, Val Accuracy: 96.08%, Val-Class-Acc: {0: '95.71%', 1: '96.63%'}, LR: 0.000100000
# Epoch 101/2000, Train Loss: 0.134576448, Train-Class-Acc: {0: '95.76%', 1: '93.07%'}, Val Loss: 0.134582030, Val Accuracy: 94.68%, Val-Class-Acc: {0: '98.42%', 1: '88.92%'}, LR: 0.000100000
# Epoch 102/2000, Train Loss: 0.124843962, Train-Class-Acc: {0: '95.98%', 1: '93.68%'}, Val Loss: 0.092496755, Val Accuracy: 96.43%, Val-Class-Acc: {0: '96.63%', 1: '96.12%'}, LR: 0.000100000
# Removed old model with accuracy 96.31%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_89.pth
# Model saved after epoch 102 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_102.pth
#
# Epoch 103/2000, Train Loss: 0.123462454, Train-Class-Acc: {0: '96.13%', 1: '93.58%'}, Val Loss: 0.094427314, Val Accuracy: 96.54%, Val-Class-Acc: {0: '97.86%', 1: '94.50%'}, LR: 0.000100000
# Removed old model with accuracy 96.32%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_92.pth
# Model saved after epoch 103 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_103.pth
#
# Epoch 104/2000, Train Loss: 0.123945792, Train-Class-Acc: {0: '96.21%', 1: '93.41%'}, Val Loss: 0.110973300, Val Accuracy: 95.26%, Val-Class-Acc: {0: '93.59%', 1: '97.82%'}, LR: 0.000100000
# Epoch 105/2000, Train Loss: 0.161886060, Train-Class-Acc: {0: '95.06%', 1: '91.70%'}, Val Loss: 0.193722893, Val Accuracy: 91.92%, Val-Class-Acc: {0: '87.70%', 1: '98.42%'}, LR: 0.000100000
# Epoch 106/2000, Train Loss: 0.158545844, Train-Class-Acc: {0: '95.01%', 1: '91.82%'}, Val Loss: 0.094559179, Val Accuracy: 96.42%, Val-Class-Acc: {0: '96.92%', 1: '95.66%'}, LR: 0.000100000
# Removed old model with accuracy 96.35%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_90.pth
# Model saved after epoch 106 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_106.pth
#
# Epoch 107/2000, Train Loss: 0.122570972, Train-Class-Acc: {0: '96.27%', 1: '93.58%'}, Val Loss: 0.091741258, Val Accuracy: 96.45%, Val-Class-Acc: {0: '96.61%', 1: '96.21%'}, LR: 0.000100000
# Removed old model with accuracy 96.36%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_99.pth
# Model saved after epoch 107 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_107.pth
#
# Epoch 108/2000, Train Loss: 0.113395356, Train-Class-Acc: {0: '96.55%', 1: '94.03%'}, Val Loss: 0.090406168, Val Accuracy: 96.65%, Val-Class-Acc: {0: '97.68%', 1: '95.06%'}, LR: 0.000100000
# Removed old model with accuracy 96.42%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_106.pth
# Model saved after epoch 108 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_108.pth
#
# Epoch 109/2000, Train Loss: 0.109516177, Train-Class-Acc: {0: '96.59%', 1: '94.18%'}, Val Loss: 0.104533318, Val Accuracy: 96.19%, Val-Class-Acc: {0: '98.26%', 1: '92.99%'}, LR: 0.000100000
# Epoch 110/2000, Train Loss: 0.153492452, Train-Class-Acc: {0: '95.30%', 1: '92.14%'}, Val Loss: 0.095393957, Val Accuracy: 96.08%, Val-Class-Acc: {0: '95.77%', 1: '96.55%'}, LR: 0.000100000
# Epoch 111/2000, Train Loss: 0.134057596, Train-Class-Acc: {0: '95.98%', 1: '92.67%'}, Val Loss: 0.107392398, Val Accuracy: 95.43%, Val-Class-Acc: {0: '93.99%', 1: '97.63%'}, LR: 0.000100000
# Epoch 112/2000, Train Loss: 0.129674346, Train-Class-Acc: {0: '95.98%', 1: '93.15%'}, Val Loss: 0.097738005, Val Accuracy: 96.52%, Val-Class-Acc: {0: '98.14%', 1: '94.03%'}, LR: 0.000100000
# Removed old model with accuracy 96.43%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_102.pth
# Model saved after epoch 112 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_112.pth
#
# Epoch 113/2000, Train Loss: 0.130827964, Train-Class-Acc: {0: '95.97%', 1: '92.91%'}, Val Loss: 0.114971380, Val Accuracy: 95.08%, Val-Class-Acc: {0: '93.05%', 1: '98.21%'}, LR: 0.000100000
# Epoch 114/2000, Train Loss: 0.144948766, Train-Class-Acc: {0: '95.58%', 1: '92.11%'}, Val Loss: 0.122780781, Val Accuracy: 95.31%, Val-Class-Acc: {0: '98.44%', 1: '90.50%'}, LR: 0.000100000
# Epoch 115/2000, Train Loss: 0.112787297, Train-Class-Acc: {0: '96.62%', 1: '94.01%'}, Val Loss: 0.093391408, Val Accuracy: 96.33%, Val-Class-Acc: {0: '96.04%', 1: '96.77%'}, LR: 0.000100000
# Epoch 116/2000, Train Loss: 0.118139402, Train-Class-Acc: {0: '96.44%', 1: '93.52%'}, Val Loss: 0.091634164, Val Accuracy: 96.44%, Val-Class-Acc: {0: '96.36%', 1: '96.55%'}, LR: 0.000100000
# Epoch 117/2000, Train Loss: 0.112407224, Train-Class-Acc: {0: '96.61%', 1: '93.92%'}, Val Loss: 0.129460866, Val Accuracy: 94.81%, Val-Class-Acc: {0: '98.70%', 1: '88.82%'}, LR: 0.000100000
# Epoch 118/2000, Train Loss: 0.141852518, Train-Class-Acc: {0: '95.67%', 1: '92.14%'}, Val Loss: 0.090822550, Val Accuracy: 96.54%, Val-Class-Acc: {0: '96.82%', 1: '96.10%'}, LR: 0.000100000
# Removed old model with accuracy 96.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_107.pth
# Model saved after epoch 118 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_118.pth
#
# Epoch 119/2000, Train Loss: 0.112210670, Train-Class-Acc: {0: '96.54%', 1: '93.92%'}, Val Loss: 0.089933257, Val Accuracy: 96.81%, Val-Class-Acc: {0: '97.95%', 1: '95.07%'}, LR: 0.000100000
# Removed old model with accuracy 96.52%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_112.pth
# Model saved after epoch 119 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_119.pth
#
# Epoch 120/2000, Train Loss: 0.122302354, Train-Class-Acc: {0: '96.38%', 1: '93.31%'}, Val Loss: 0.089868240, Val Accuracy: 96.85%, Val-Class-Acc: {0: '98.04%', 1: '95.02%'}, LR: 0.000100000
# Removed old model with accuracy 96.52%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_97.pth
# Model saved after epoch 120 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_120.pth
#
# Epoch 121/2000, Train Loss: 0.121599930, Train-Class-Acc: {0: '96.42%', 1: '93.27%'}, Val Loss: 0.089847712, Val Accuracy: 96.70%, Val-Class-Acc: {0: '97.18%', 1: '95.95%'}, LR: 0.000100000
# Removed old model with accuracy 96.54%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_103.pth
# Model saved after epoch 121 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_121.pth
#
# Epoch 122/2000, Train Loss: 0.109592803, Train-Class-Acc: {0: '96.80%', 1: '94.02%'}, Val Loss: 0.093202491, Val Accuracy: 96.27%, Val-Class-Acc: {0: '96.02%', 1: '96.64%'}, LR: 0.000100000
# Epoch 123/2000, Train Loss: 0.125448972, Train-Class-Acc: {0: '96.28%', 1: '93.17%'}, Val Loss: 0.094200093, Val Accuracy: 96.51%, Val-Class-Acc: {0: '98.25%', 1: '93.82%'}, LR: 0.000100000
# ...
# Epoch 1951/2000, Train Loss: 0.003421246, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.088236614, Val Accuracy: 98.19%, Val-Class-Acc: {0: '98.38%', 1: '97.90%'}, LR: 0.000100000
# Epoch 1952/2000, Train Loss: 0.039496821, Train-Class-Acc: {0: '99.16%', 1: '98.68%'}, Val Loss: 0.085044271, Val Accuracy: 97.81%, Val-Class-Acc: {0: '97.95%', 1: '97.58%'}, LR: 0.000100000
# Epoch 1953/2000, Train Loss: 0.018693213, Train-Class-Acc: {0: '99.47%', 1: '99.02%'}, Val Loss: 0.081994369, Val Accuracy: 98.12%, Val-Class-Acc: {0: '98.19%', 1: '98.02%'}, LR: 0.000100000
# Epoch 1954/2000, Train Loss: 0.004547807, Train-Class-Acc: {0: '99.91%', 1: '99.84%'}, Val Loss: 0.080950578, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.31%', 1: '97.93%'}, LR: 0.000100000
# Epoch 1955/2000, Train Loss: 0.003950452, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.083737226, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.40%', 1: '97.79%'}, LR: 0.000100000
# Epoch 1956/2000, Train Loss: 0.003885966, Train-Class-Acc: {0: '99.91%', 1: '99.86%'}, Val Loss: 0.082728039, Val Accuracy: 98.21%, Val-Class-Acc: {0: '98.46%', 1: '97.83%'}, LR: 0.000100000
# Removed old model with accuracy 98.20%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1948.pth
# Model saved after epoch 1956 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1956.pth
#
# Epoch 1957/2000, Train Loss: 0.003659829, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.085804068, Val Accuracy: 98.18%, Val-Class-Acc: {0: '98.27%', 1: '98.04%'}, LR: 0.000100000
# Epoch 1958/2000, Train Loss: 0.003594912, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.085503785, Val Accuracy: 98.21%, Val-Class-Acc: {0: '98.36%', 1: '97.98%'}, LR: 0.000100000
# Removed old model with accuracy 98.20%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1946.pth
# Model saved after epoch 1958 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1958.pth
#
# Epoch 1959/2000, Train Loss: 0.003402913, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.088015170, Val Accuracy: 98.17%, Val-Class-Acc: {0: '98.45%', 1: '97.74%'}, LR: 0.000100000
# Epoch 1960/2000, Train Loss: 0.003411842, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.087600321, Val Accuracy: 98.18%, Val-Class-Acc: {0: '98.32%', 1: '97.97%'}, LR: 0.000100000
# Epoch 1961/2000, Train Loss: 0.003268393, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.086987355, Val Accuracy: 98.19%, Val-Class-Acc: {0: '98.26%', 1: '98.07%'}, LR: 0.000100000
# Epoch 1962/2000, Train Loss: 0.003303142, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.089010904, Val Accuracy: 98.18%, Val-Class-Acc: {0: '98.44%', 1: '97.79%'}, LR: 0.000100000
# Epoch 1963/2000, Train Loss: 0.003260236, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.090017784, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.27%', 1: '97.99%'}, LR: 0.000100000
# Epoch 1964/2000, Train Loss: 0.003195771, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.090069781, Val Accuracy: 98.18%, Val-Class-Acc: {0: '98.41%', 1: '97.83%'}, LR: 0.000100000
# Epoch 1965/2000, Train Loss: 0.003108997, Train-Class-Acc: {0: '99.93%', 1: '99.88%'}, Val Loss: 0.089669649, Val Accuracy: 98.21%, Val-Class-Acc: {0: '98.41%', 1: '97.90%'}, LR: 0.000100000
# Removed old model with accuracy 98.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1958.pth
# Model saved after epoch 1965 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1965.pth
#
# Epoch 1966/2000, Train Loss: 0.003125474, Train-Class-Acc: {0: '99.93%', 1: '99.88%'}, Val Loss: 0.089094632, Val Accuracy: 98.18%, Val-Class-Acc: {0: '98.30%', 1: '98.00%'}, LR: 0.000100000
# Epoch 1967/2000, Train Loss: 0.003146560, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.092499538, Val Accuracy: 98.14%, Val-Class-Acc: {0: '98.31%', 1: '97.89%'}, LR: 0.000100000
# Epoch 1968/2000, Train Loss: 0.003150639, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.092979635, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.39%', 1: '97.79%'}, LR: 0.000100000
# Epoch 1969/2000, Train Loss: 0.003063393, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.091742312, Val Accuracy: 98.08%, Val-Class-Acc: {0: '98.01%', 1: '98.19%'}, LR: 0.000100000
# Epoch 1970/2000, Train Loss: 0.003244234, Train-Class-Acc: {0: '99.91%', 1: '99.87%'}, Val Loss: 0.094147975, Val Accuracy: 98.15%, Val-Class-Acc: {0: '98.41%', 1: '97.75%'}, LR: 0.000100000
# Epoch 1971/2000, Train Loss: 0.003174248, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.092360388, Val Accuracy: 98.12%, Val-Class-Acc: {0: '98.17%', 1: '98.06%'}, LR: 0.000100000
# Epoch 1972/2000, Train Loss: 0.003139892, Train-Class-Acc: {0: '99.91%', 1: '99.87%'}, Val Loss: 0.093409933, Val Accuracy: 98.20%, Val-Class-Acc: {0: '98.30%', 1: '98.06%'}, LR: 0.000100000
# Epoch 1973/2000, Train Loss: 0.002974381, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.094097353, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.50%', 1: '97.65%'}, LR: 0.000100000
# Epoch 1974/2000, Train Loss: 0.003050450, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.094338371, Val Accuracy: 98.17%, Val-Class-Acc: {0: '98.46%', 1: '97.73%'}, LR: 0.000100000
# Epoch 1975/2000, Train Loss: 0.003111813, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.098878148, Val Accuracy: 98.02%, Val-Class-Acc: {0: '98.60%', 1: '97.13%'}, LR: 0.000100000
# Epoch 1976/2000, Train Loss: 0.002959768, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.099001271, Val Accuracy: 98.10%, Val-Class-Acc: {0: '98.37%', 1: '97.70%'}, LR: 0.000100000
# Epoch 1977/2000, Train Loss: 0.002998354, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.096772097, Val Accuracy: 98.16%, Val-Class-Acc: {0: '98.49%', 1: '97.65%'}, LR: 0.000100000
# Epoch 1978/2000, Train Loss: 0.003077346, Train-Class-Acc: {0: '99.91%', 1: '99.87%'}, Val Loss: 0.095969462, Val Accuracy: 98.19%, Val-Class-Acc: {0: '98.35%', 1: '97.95%'}, LR: 0.000100000
# Epoch 1979/2000, Train Loss: 0.003239141, Train-Class-Acc: {0: '99.91%', 1: '99.86%'}, Val Loss: 0.096345583, Val Accuracy: 98.19%, Val-Class-Acc: {0: '98.51%', 1: '97.71%'}, LR: 0.000100000
# Epoch 1980/2000, Train Loss: 0.387779785, Train-Class-Acc: {0: '92.36%', 1: '87.45%'}, Val Loss: 0.107538989, Val Accuracy: 96.30%, Val-Class-Acc: {0: '98.55%', 1: '92.85%'}, LR: 0.000100000
# Epoch 1981/2000, Train Loss: 0.039038325, Train-Class-Acc: {0: '99.16%', 1: '98.02%'}, Val Loss: 0.066574477, Val Accuracy: 98.17%, Val-Class-Acc: {0: '98.31%', 1: '97.94%'}, LR: 0.000100000
# Epoch 1982/2000, Train Loss: 0.011185855, Train-Class-Acc: {0: '99.84%', 1: '99.64%'}, Val Loss: 0.074445779, Val Accuracy: 98.22%, Val-Class-Acc: {0: '98.45%', 1: '97.87%'}, LR: 0.000100000
# Removed old model with accuracy 98.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1965.pth
# Model saved after epoch 1982 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1982.pth
#
# Epoch 1983/2000, Train Loss: 0.007233458, Train-Class-Acc: {0: '99.89%', 1: '99.77%'}, Val Loss: 0.076435258, Val Accuracy: 98.30%, Val-Class-Acc: {0: '98.59%', 1: '97.86%'}, LR: 0.000100000
# Removed old model with accuracy 98.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1615.pth
# Model saved after epoch 1983 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1983.pth
#
# Epoch 1984/2000, Train Loss: 0.005902283, Train-Class-Acc: {0: '99.90%', 1: '99.80%'}, Val Loss: 0.078133123, Val Accuracy: 98.32%, Val-Class-Acc: {0: '98.60%', 1: '97.88%'}, LR: 0.000100000
# Removed old model with accuracy 98.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1956.pth
# Model saved after epoch 1984 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1984.pth
#
# Epoch 1985/2000, Train Loss: 0.006586034, Train-Class-Acc: {0: '99.84%', 1: '99.75%'}, Val Loss: 0.087338613, Val Accuracy: 97.97%, Val-Class-Acc: {0: '98.78%', 1: '96.74%'}, LR: 0.000100000
# Epoch 1986/2000, Train Loss: 0.005705502, Train-Class-Acc: {0: '99.87%', 1: '99.77%'}, Val Loss: 0.079556592, Val Accuracy: 98.35%, Val-Class-Acc: {0: '98.67%', 1: '97.86%'}, LR: 0.000100000
# Removed old model with accuracy 98.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_401.pth
# Model saved after epoch 1986 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1986.pth
#
# Epoch 1987/2000, Train Loss: 0.004282389, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}, Val Loss: 0.080810791, Val Accuracy: 98.35%, Val-Class-Acc: {0: '98.63%', 1: '97.92%'}, LR: 0.000100000
# Removed old model with accuracy 98.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1982.pth
# Model saved after epoch 1987 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1987.pth
#
# Epoch 1988/2000, Train Loss: 0.004980465, Train-Class-Acc: {0: '99.88%', 1: '99.81%'}, Val Loss: 0.081019753, Val Accuracy: 98.21%, Val-Class-Acc: {0: '98.15%', 1: '98.30%'}, LR: 0.000100000
# Epoch 1989/2000, Train Loss: 0.004127318, Train-Class-Acc: {0: '99.91%', 1: '99.85%'}, Val Loss: 0.081761440, Val Accuracy: 98.33%, Val-Class-Acc: {0: '98.57%', 1: '97.96%'}, LR: 0.000100000
# Removed old model with accuracy 98.30%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1983.pth
# Model saved after epoch 1989 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1989.pth
#
# Epoch 1990/2000, Train Loss: 0.004119948, Train-Class-Acc: {0: '99.90%', 1: '99.84%'}, Val Loss: 0.083815012, Val Accuracy: 98.26%, Val-Class-Acc: {0: '98.40%', 1: '98.05%'}, LR: 0.000100000
# Epoch 1991/2000, Train Loss: 0.003699951, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.085908542, Val Accuracy: 98.31%, Val-Class-Acc: {0: '98.68%', 1: '97.74%'}, LR: 0.000100000
# Epoch 1992/2000, Train Loss: 0.003551026, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.084037083, Val Accuracy: 98.28%, Val-Class-Acc: {0: '98.42%', 1: '98.05%'}, LR: 0.000100000
# Epoch 1993/2000, Train Loss: 0.003481898, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.084002547, Val Accuracy: 98.27%, Val-Class-Acc: {0: '98.40%', 1: '98.08%'}, LR: 0.000100000
# Epoch 1994/2000, Train Loss: 0.003473318, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.085947424, Val Accuracy: 98.29%, Val-Class-Acc: {0: '98.53%', 1: '97.91%'}, LR: 0.000100000
# Epoch 1995/2000, Train Loss: 0.003464602, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.084821461, Val Accuracy: 98.31%, Val-Class-Acc: {0: '98.53%', 1: '97.98%'}, LR: 0.000100000
# Epoch 1996/2000, Train Loss: 0.003391660, Train-Class-Acc: {0: '99.92%', 1: '99.88%'}, Val Loss: 0.088281523, Val Accuracy: 98.28%, Val-Class-Acc: {0: '98.74%', 1: '97.58%'}, LR: 0.000100000
# Epoch 1997/2000, Train Loss: 0.003329088, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.090527261, Val Accuracy: 98.19%, Val-Class-Acc: {0: '98.77%', 1: '97.31%'}, LR: 0.000100000
# Epoch 1998/2000, Train Loss: 0.003344848, Train-Class-Acc: {0: '99.92%', 1: '99.87%'}, Val Loss: 0.087991502, Val Accuracy: 98.30%, Val-Class-Acc: {0: '98.59%', 1: '97.84%'}, LR: 0.000100000
# Epoch 1999/2000, Train Loss: 0.003456159, Train-Class-Acc: {0: '99.91%', 1: '99.86%'}, Val Loss: 0.088306877, Val Accuracy: 98.33%, Val-Class-Acc: {0: '98.72%', 1: '97.73%'}, LR: 0.000100000
# Removed old model with accuracy 98.32%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1984.pth
# Model saved after epoch 1999 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1999.pth
#
# Epoch 2000/2000, Train Loss: 0.069607688, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.076768133, Val Accuracy: 97.98%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, LR: 0.000100000
#
# Final model saved to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_final.pth
#
# Training complete.
#
# Top 5 Models Sorted by Validation Accuracy:
# Epoch 1987/2000, Train Loss: 0.004282389, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.080810791, Val Accuracy: 98.35%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1987.pth
# Epoch 1986/2000, Train Loss: 0.005705502, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.079556592, Val Accuracy: 98.35%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1986.pth
# Epoch 1550/2000, Train Loss: 0.008332113, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.064474121, Val Accuracy: 98.33%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1550.pth
# Epoch 1989/2000, Train Loss: 0.004127318, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.081761440, Val Accuracy: 98.33%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1989.pth
# Epoch 1999/2000, Train Loss: 0.003456159, Train-Class-Acc: {0: '98.36%', 1: '97.80%'}, Val Loss: 0.088306877, Val Accuracy: 98.33%, Val-Class-Acc: {0: '98.10%', 1: '97.81%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1999.pth
#
#
# Epoch 1987/2000, Train Loss: 0.0043, Val Loss: 0.0808, Val Accuracy: 98.35%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1987.pth
# Epoch 1986/2000, Train Loss: 0.0057, Val Loss: 0.0796, Val Accuracy: 98.35%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1986.pth
# Epoch 1550/2000, Train Loss: 0.0083, Val Loss: 0.0645, Val Accuracy: 98.33%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1550.pth
# Epoch 1989/2000, Train Loss: 0.0041, Val Loss: 0.0818, Val Accuracy: 98.33%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1989.pth
# Epoch 1999/2000, Train Loss: 0.0035, Val Loss: 0.0883, Val Accuracy: 98.33%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_1\1st_try\BiGRUWithAttention_epoch_1999.pth
#
# class_gru_model:
# BiGRUWithAttention(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1]
# num_classes = 2

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import os
import glob
import copy

def compute_classwise_accuracy(student_logits_flat, y_batch, class_correct, class_total):
    predictions = torch.argmax(student_logits_flat, dim=-1)
    correct_mask = (predictions == y_batch)
    unique_labels = torch.unique(y_batch)

    for label in unique_labels:
        label = label.item()
        if label not in class_total:
            class_total[label] = 0
            class_correct[label] = 0
        label_mask = (y_batch == label)
        class_total[label] += label_mask.sum().item()
        class_correct[label] += (label_mask & correct_mask).sum().item()

def add_val_class_acc(model_copy, output_size, criterion, X_val, y_val, file_path, model_checkpoint, batch_size=64):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model_copy.to(device)
    model_copy.eval()

    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)
    val_dataset = TensorDataset(X_val, y_val)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    val_loss = 0.0
    val_correct = 0
    val_total = 0
    val_class_correct = {}
    val_class_total = {}

    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            val_outputs = model_copy(X_val_batch).view(-1, output_size)
            val_labels = y_val_batch.view(-1)
            val_loss += criterion(val_outputs, val_labels).item() * X_val_batch.size(0)
            val_predictions = torch.argmax(val_outputs, dim=-1)
            val_correct += (val_predictions == val_labels).sum().item()
            val_total += val_labels.size(0)
            compute_classwise_accuracy(val_outputs, val_labels, val_class_correct, val_class_total)

    val_accuracy = val_correct / val_total
    val_classwise_accuracy = {
        int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%"
        for c in sorted(val_class_total.keys())
    }

    model_checkpoint.update({
        "val_accuracy": val_accuracy,
        "Val-Class-Acc": val_classwise_accuracy
    })
    torch.save(model_checkpoint, file_path)
    print(f"✅ Updated: {os.path.basename(file_path)} | Acc: {val_accuracy:.4f} | Saved to: {file_path}")

def show_val_accuracy_from_checkpoints(model_folder):
    import torch
    import glob
    import os

    ckpt_paths = sorted(glob.glob(os.path.join(model_folder, "*.pth")))

    print(f"\n📝 Summary of val_accuracy and Val-Class-Acc:")
    for path in ckpt_paths:
        checkpoint = torch.load(path, map_location="cpu")
        filename = os.path.basename(path)

        val_acc = checkpoint.get("val_accuracy", None)
        val_class_acc = checkpoint.get("Val-Class-Acc", None)

        if val_acc is not None and val_class_acc is not None:
            print(f"{filename}: val_accuracy = {val_acc:.4f}, Val-Class-Acc: {val_class_acc}")
        else:
            print(f"{filename}: ❌ val_accuracy or Val-Class-Acc not found")

# %%
# Reconstruct model with same config
model_template = BiGRUWithAttention(
    input_size=Number_features,
    hidden_size=64,
    output_size=num_classes,
    num_layers=4
)

# Prepare validation data
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)
criterion = nn.CrossEntropyLoss()

# Your model folder
model_folder = 'Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try'
ckpt_paths = sorted(glob.glob(os.path.join(model_folder, "*.pth")))

# Loop through and update each model
for file_path in ckpt_paths:
    model_copy = copy.deepcopy(model_template).to(device)
    checkpoint = torch.load(file_path, map_location=device)
    model_copy.load_state_dict(checkpoint['model_state_dict'])

    add_val_class_acc(
        model_copy=model_copy,
        output_size=num_classes,
        criterion=criterion,
        X_val=X_val_tensor,
        y_val=y_val_tensor,
        file_path=file_path,
        model_checkpoint=checkpoint,
        batch_size=64
    )

show_val_accuracy_from_checkpoints(
    "Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try"
)
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_149096\3997419134.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_path, map_location=device)
# C:\Users\james\AppData\Local\Temp\ipykernel_149096\2472753690.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
# C:\Users\james\AppData\Local\Temp\ipykernel_149096\2472753690.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val, dtype=torch.long).to(device)
# ✅ Updated: BiGRUWithAttention_epoch_1550.pth | Acc: 0.9833 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_epoch_1550.pth
# ✅ Updated: BiGRUWithAttention_epoch_1986.pth | Acc: 0.9835 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_epoch_1986.pth
# ✅ Updated: BiGRUWithAttention_epoch_1987.pth | Acc: 0.9835 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_epoch_1987.pth
# ✅ Updated: BiGRUWithAttention_epoch_1989.pth | Acc: 0.9833 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_epoch_1989.pth
# ✅ Updated: BiGRUWithAttention_epoch_1999.pth | Acc: 0.9833 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_epoch_1999.pth
# ✅ Updated: BiGRUWithAttention_final.pth | Acc: 0.9798 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/1st_try\BiGRUWithAttention_final.pth
#
# 📝 Summary of val_accuracy and Val-Class-Acc:
# BiGRUWithAttention_epoch_1550.pth: val_accuracy = 0.9833, Val-Class-Acc = {0: '98.50%', 1: '98.08%'}
# BiGRUWithAttention_epoch_1986.pth: val_accuracy = 0.9835, Val-Class-Acc = {0: '98.67%', 1: '97.86%'}
# BiGRUWithAttention_epoch_1987.pth: val_accuracy = 0.9835, Val-Class-Acc = {0: '98.63%', 1: '97.92%'}
# BiGRUWithAttention_epoch_1989.pth: val_accuracy = 0.9833, Val-Class-Acc = {0: '98.57%', 1: '97.96%'}
# BiGRUWithAttention_epoch_1999.pth: val_accuracy = 0.9833, Val-Class-Acc = {0: '98.72%', 1: '97.73%'}
# BiGRUWithAttention_final.pth: val_accuracy = 0.9798, Val-Class-Acc = {0: '98.10%', 1: '97.81%'}
# C:\Users\james\AppData\Local\Temp\ipykernel_149096\2472753690.py:66: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")

# %% [markdown]
# ### Period 1 --> Training and saving in __*'2nd_try'*__ (BiGRUWithAttention, num_layers = 3) ---> Val acc = 98.31 %

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[0], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 3  # Number of GRU layers
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttention' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/2nd_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttention(input_size, hidden_size, output_size, num_layers).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1], device='cuda:0')
# y_train Min: 0, Max: 1
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1], device='cuda:0')
# y_val Min: 0, Max: 1
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 0.010724814, Val Loss: 0.011819029, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_1.pth
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 0.010339666, Val Loss: 0.011771941, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 0.010337460, Val Loss: 0.011761453, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 0.010333836, Val Loss: 0.011767223, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 0.010333769, Val Loss: 0.011770000, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 0.010330688, Val Loss: 0.011766681, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 7/2000, Train Loss: 0.010330320, Val Loss: 0.011756237, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 8/2000, Train Loss: 0.010332275, Val Loss: 0.011772879, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 9/2000, Train Loss: 0.010327020, Val Loss: 0.011751898, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 10/2000, Train Loss: 0.010327381, Val Loss: 0.011763328, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 11/2000, Train Loss: 0.010323909, Val Loss: 0.011753893, Val Accuracy: 60.61%, LR: 0.000100000
Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\2nd_try\BiGRUWithAttention_epoch_1576.pth
#
# class_gru_model:
# BiGRUWithAttention(
#   (gru): GRU(7, 64, num_layers=3, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1]
# num_classes = 2

# %% [markdown]
# ### Period 1 --> Training and saving in __*'3rd_try'*__ (BiGRUWithAttentionLoRA, num_layers = 4, lora_r=4) ---> Val acc = 98.50 %

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[0], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1]
# num_classes = 2

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
dropout = 0.0
lora_r = 4 # Rank of the low-rank update matrices
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttentionLoRA' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/3rd_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttentionLoRA(input_size, hidden_size, output_size, num_layers, dropout, lora_r).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1], device='cuda:0')
# y_train Min: 0, Max: 1
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1], device='cuda:0')
# y_val Min: 0, Max: 1
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 0.010701247, Val Loss: 0.011859514, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1.pth
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 0.010341127, Val Loss: 0.011767494, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 0.010334799, Val Loss: 0.011764389, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 0.010333897, Val Loss: 0.011783907, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 0.010336850, Val Loss: 0.011759262, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch
# Epoch 1995/2000, Train Loss: 0.000075399, Val Loss: 0.001391693, Val Accuracy: 98.28%, LR: 0.000100000
# Epoch 1996/2000, Train Loss: 0.000071547, Val Loss: 0.001453116, Val Accuracy: 98.14%, LR: 0.000100000
# Epoch 1997/2000, Train Loss: 0.000074455, Val Loss: 0.001479488, Val Accuracy: 98.17%, LR: 0.000100000
# Epoch 1998/2000, Train Loss: 0.000069826, Val Loss: 0.001472816, Val Accuracy: 98.27%, LR: 0.000100000
# Epoch 1999/2000, Train Loss: 0.000069430, Val Loss: 0.001458687, Val Accuracy: 98.34%, LR: 0.000100000
# Epoch 2000/2000, Train Loss: 0.000066466, Val Loss: 0.001496513, Val Accuracy: 98.24%, LR: 0.000100000
#
# Final model saved to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_final.pth
#
# Training complete.
#
# Top 5 Models Sorted by Validation Accuracy:
# Epoch 1943/2000, Train Loss: 0.000220914, Val Loss: 0.001079956, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1943.pth
# Epoch 1252/2000, Train Loss: 0.000730280, Val Loss: 0.000982695, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1252.pth
# Epoch 875/2000, Train Loss: 0.000289137, Val Loss: 0.000921160, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_875.pth
# Epoch 651/2000, Train Loss: 0.000906659, Val Loss: 0.001459916, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_651.pth
# Epoch 1583/2000, Train Loss: 0.000247374, Val Loss: 0.000951950, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1583.pth
#
#
# Epoch 1943/2000, Train Loss: 0.0002, Val Loss: 0.0011, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1943.pth
# Epoch 1252/2000, Train Loss: 0.0007, Val Loss: 0.0010, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1252.pth
# Epoch 875/2000, Train Loss: 0.0003, Val Loss: 0.0009, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_875.pth
# Epoch 651/2000, Train Loss: 0.0009, Val Loss: 0.0015, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_651.pth
# Epoch 1583/2000, Train Loss: 0.0002, Val Loss: 0.0010, Val Accuracy: 98.50%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\3rd_try\BiGRUWithAttentionLoRA_epoch_1583.pth
#
# class_gru_model:
# BiGRUWithAttentionLoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): LoRALinear(
#     (linear): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1]
# num_classes = 2

# %% [markdown]
# ### Period 1 --> Training and saving in __*'4th_try'*__ (BiGRUWithAttentionLoRA, num_layers = 4, lora_r=8) ---> Val acc = 98.50 %

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[0], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1]
# num_classes = 2

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
dropout = 0.0
lora_r = 8 # Rank of the low-rank update matrices
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttentionLoRA' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_1/4th_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttentionLoRA(input_size, hidden_size, output_size, num_layers, dropout, lora_r).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1], device='cuda:0')
# y_train Min: 0, Max: 1
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1], device='cuda:0')
# y_val Min: 0, Max: 1
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 0.684206644, Val Loss: 0.672887361, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_1.pth
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
#
# Unique target values: tensor([0, 1], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 1
# Unique classes in y_train: tensor([0, 1], device='cuda:0')
# Unique classes in y_val: tensor([0, 1], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 0.659332213, Val Loss: 0.672203205, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 0.658970441, Val Loss: 0.673207546, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 0.658980706, Val Loss: 0.671704585, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 0.658883410, Val Loss: 0.672691967, Val Accuracy: 60.61%, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 0.658813260, Val Loss: 0.672620780, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 7/2000, Train Loss: 0.658687456, Val Loss: 0.671941326, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 8/2000, Train Loss: 0.658571564, Val Loss: 0.671010163, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 9/2000, Train Loss: 0.658562150, Val Loss: 0.671055225, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 10/2000, Train Loss: 0.658608773, Val Loss: 0.671446003, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 11/2000, Train Loss: 0.658463253, Val Loss: 0.671050210, Val Accuracy: 60.61%, LR: 0.000100000
# Epoch 12/2000, Train Loss: 0.658125669, Val Loss: 0.669897506, Val Accuracy: 60.61%, LR: 0.000100000
Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Period_1\4th_try\BiGRUWithAttentionLoRA_epoch_1998.pth
#
# class_gru_model:
# BiGRUWithAttentionLoRA(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): LoRALinear(
#     (linear): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1]
# num_classes = 2

# %% [markdown]
# ### Period 2 --> Training and saving in __*'1st_try'*__ (BiGRUWithAttention, num_layers = 4) ---> Val acc = 98.15 %
# ### Val-Class-Acc: {0: '99.46%', 1: '98.44%', 2: '90.81%'}

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[1], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1 2]
# num_classes = 3

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttention' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttention(input_size, hidden_size, output_size, num_layers).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1, 2], device='cuda:0')
# y_train Min: 0, Max: 2
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1, 2], device='cuda:0')
# y_val Min: 0, Max: 2
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 1.059442620, Train-Class-Acc: {0: '99.71%', 1: '0.35%', 2: '0.04%'}, Val Loss: 0.962022782, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_1.pth
#
#
# Unique target values: tensor([0, 1, 2], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 2
# Unique classes in y_train: tensor([0, 1, 2], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 2
# Unique classes in y_train: tensor([0, 1, 2], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 2
# Unique classes in y_train: tensor([0, 1, 2], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 0.941471050, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.948308579, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 0.940016479, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.947201740, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 0.939430882, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.946333438, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 0.938705929, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.945754153, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 0.938139927, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.945057886, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Epoch 7/2000, Train Loss: 0.937114480, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.944348399, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Epoch 8/2000, Train Loss: 0.935619384, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.945016407, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Epoch 9/2000, Train Loss: 0.932754088, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.939795483, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Epoch 10/2000, Train Loss: 0.923443705, Train-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, Val Loss: 0.921590817, Val Accuracy: 52.72%, Val-Class-Acc: {0: '100.00%', 1: '0.00%', 2: '0.00%'}, LR: 0.000100000
# Epoch 11/2000, Train Loss: 0.827924562, Train-Class-Acc: {0: '99.98%', 1: '2.72%', 2: '0.01%'}, Val Loss: 0.709184159, Val Accuracy: 58.73%, Val-Class-Acc: {0: '99.93%', 1: '16.64%', 2: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 52.72%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_5.pth
# Model saved after epoch 11 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_11.pth
#
# Epoch 12/2000, Train Loss: 0.652048642, Train-Class-Acc: {0: '98.51%', 1: '42.86%', 2: '0.15%'}, Val Loss: 0.579198338, Val Accuracy: 80.63%, Val-Class-Acc: {0: '96.72%', 1: '81.39%', 2: '0.29%'}, LR: 0.000100000
# Removed old model with accuracy 52.72%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_4.pth
# Model saved after epoch 12 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_12.pth
#
# Epoch 13/2000, Train Loss: 0.529077957, Train-Class-Acc: {0: '91.31%', 1: '79.38%', 2: '12.94%'}, Val Loss: 0.481214821, Val Accuracy: 81.41%, Val-Class-Acc: {0: '98.18%', 1: '73.94%', 2: '25.25%'}, LR: 0.000100000
# Removed old model with accuracy 52.72%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_3.pth
# Model saved after epoch 13 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_13.pth
#
# Epoch 14/2000, Train Loss: 0.407232673, Train-Class-Acc: {0: '91.41%', 1: '83.54%', 2: '47.94%'}, Val Loss: 0.359000814, Val Accuracy: 86.44%, Val-Class-Acc: {0: '93.61%', 1: '89.28%', 2: '42.34%'}, LR: 0.000100000
# Removed old model with accuracy 52.72%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_2.pth
# Model saved after epoch 14 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_14.pth
#
# Epoch 15/2000, Train Loss: 0.347429134, Train-Class-Acc: {0: '93.29%', 1: '85.46%', 2: '51.28%'}, Val Loss: 0.323600252, Val Accuracy: 87.46%, Val-Class-Acc: {0: '94.96%', 1: '90.00%', 2: '42.77%'}, LR: 0.000100000
# Removed old model with accuracy 52.72%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_1.pth
# Model saved after epoch 15 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_15.pth
#
# Epoch 16/2000, Train Loss: 0.310391180, Train-Class-Acc: {0: '94.00%', 1: '87.48%', 2: '53.63%'}, Val Loss: 0.303389223, Val Accuracy: 87.83%, Val-Class-Acc: {0: '97.40%', 1: '87.62%', 2: '42.29%'}, LR: 0.000100000
# Removed old model with accuracy 58.73%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_11.pth
# Model saved after epoch 16 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_16.pth
#
# Epoch 17/2000, Train Loss: 0.279176082, Train-Class-Acc: {0: '94.19%', 1: '88.93%', 2: '59.34%'}, Val Loss: 0.320347456, Val Accuracy: 86.09%, Val-Class-Acc: {0: '85.26%', 1: '93.98%', 2: '63.75%'}, LR: 0.000100000
# Removed old model with accuracy 80.63%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_12.pth
# Model saved after epoch 17 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_17.pth
#
# Epoch 18/2000, Train Loss: 0.259924942, Train-Class-Acc: {0: '93.90%', 1: '89.39%', 2: '67.18%'}, Val Loss: 0.236061273, Val Accuracy: 90.89%, Val-Class-Acc: {0: '97.73%', 1: '90.97%', 2: '57.55%'}, LR: 0.000100000
# Removed old model with accuracy 81.41%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_13.pth
# Model saved after epoch 18 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_18.pth
#
# Epoch 19/2000, Train Loss: 0.221425370, Train-Class-Acc: {0: '94.85%', 1: '90.69%', 2: '75.14%'}, Val Loss: 0.199994686, Val Accuracy: 92.68%, Val-Class-Acc: {0: '96.70%', 1: '93.22%', 2: '71.46%'}, LR: 0.000100000
# Removed old model with accuracy 86.09%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_17.pth
# Model saved after epoch 19 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_19.pth
#
# Epoch 20/2000, Train Loss: 0.197619614, Train-Class-Acc: {0: '95.32%', 1: '91.26%', 2: '80.08%'}, Val Loss: 0.183715757, Val Accuracy: 93.23%, Val-Class-Acc: {0: '95.97%', 1: '93.53%', 2: '78.92%'}, LR: 0.000100000
# Removed old model with accuracy 86.44%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_14.pth
# Model saved after epoch 20 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_20.pth
#
# Epoch 21/2000, Train Loss: 0.178016859, Train-Class-Acc: {0: '95.86%', 1: '91.78%', 2: '83.51%'}, Val Loss: 0.216957857, Val Accuracy: 91.88%, Val-Class-Acc: {0: '99.17%', 1: '88.43%', 2: '68.17%'}, LR: 0.000100000
# Removed old model with accuracy 87.46%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_15.pth
# Model saved after epoch 21 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_21.pth
#
# Epoch 22/2000, Train Loss: 0.179706674, Train-Class-Acc: {0: '95.74%', 1: '91.35%', 2: '84.65%'}, Val Loss: 0.175689178, Val Accuracy: 93.23%, Val-Class-Acc: {0: '98.29%', 1: '91.73%', 2: '73.79%'}, LR: 0.000100000
# Removed old model with accuracy 87.83%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_16.pth
# Model saved after epoch 22 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_22.pth
#
# Epoch 23/2000, Train Loss: 0.156919691, Train-Class-Acc: {0: '96.44%', 1: '92.51%', 2: '86.31%'}, Val Loss: 0.186028457, Val Accuracy: 92.93%, Val-Class-Acc: {0: '99.00%', 1: '90.65%', 2: '71.22%'}, LR: 0.000100000
# Removed old model with accuracy 90.89%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_18.pth
# Model saved after epoch 23 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_23.pth
#
# Epoch 24/2000, Train Loss: 0.156402396, Train-Class-Acc: {0: '96.39%', 1: '92.41%', 2: '87.04%'}, Val Loss: 0.181052082, Val Accuracy: 93.12%, Val-Class-Acc: {0: '98.91%', 1: '91.27%', 2: '71.25%'}, LR: 0.000100000
# Removed old model with accuracy 91.88%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_21.pth
# Model saved after epoch 24 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_24.pth
#
# Epoch 25/2000, Train Loss: 0.146437419, Train-Class-Acc: {0: '96.62%', 1: '92.90%', 2: '87.72%'}, Val Loss: 0.178341288, Val Accuracy: 93.24%, Val-Class-Acc: {0: '99.02%', 1: '91.39%', 2: '71.48%'}, LR: 0.000100000
# Removed old model with accuracy 92.68%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_19.pth
# Model saved after epoch 25 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_25.pth
#
# Epoch 26/2000, Train Loss: 0.156027387, Train-Class-Acc: {0: '96.25%', 1: '92.26%', 2: '87.82%'}, Val Loss: 0.151040223, Val Accuracy: 94.22%, Val-Class-Acc: {0: '95.53%', 1: '95.67%', 2: '83.04%'}, LR: 0.000100000
# Removed old model with accuracy 92.93%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_23.pth
# Model saved after epoch 26 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_26.pth
#
# Epoch 27/2000, Train Loss: 0.151991740, Train-Class-Acc: {0: '96.34%', 1: '92.72%', 2: '87.87%'}, Val Loss: 0.153150305, Val Accuracy: 93.97%, Val-Class-Acc: {0: '95.05%', 1: '93.25%', 2: '91.14%'}, LR: 0.000100000
# Removed old model with accuracy 93.12%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_24.pth
# Model saved after epoch 27 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_27.pth
#
# Epoch 28/2000, Train Loss: 0.146892045, Train-Class-Acc: {0: '96.51%', 1: '92.78%', 2: '89.24%'}, Val Loss: 0.162737023, Val Accuracy: 93.67%, Val-Class-Acc: {0: '98.93%', 1: '92.37%', 2: '72.58%'}, LR: 0.000100000
# Removed old model with accuracy 93.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_20.pth
# Model saved after epoch 28 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_28.pth
#
# Epoch 29/2000, Train Loss: 0.135434725, Train-Class-Acc: {0: '96.82%', 1: '93.51%', 2: '89.56%'}, Val Loss: 0.158168970, Val Accuracy: 93.85%, Val-Class-Acc: {0: '98.87%', 1: '92.62%', 2: '73.63%'}, LR: 0.000100000
# Removed old model with accuracy 93.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_22.pth
# Model saved after epoch 29 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_29.pth
#
# Epoch 30/2000, Train Loss: 0.146080121, Train-Class-Acc: {0: '96.57%', 1: '92.91%', 2: '89.44%'}, Val Loss: 0.143820853, Val Accuracy: 94.17%, Val-Class-Acc: {0: '97.84%', 1: '95.06%', 2: '73.45%'}, LR: 0.000100000
# Removed old model with accuracy 93.24%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_25.pth
# Model saved after epoch 30 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_30.pth
#
# Epoch 31/2000, Train Loss: 0.128523357, Train-Class-Acc: {0: '97.02%', 1: '93.88%', 2: '89.97%'}, Val Loss: 0.130738205, Val Accuracy: 95.11%, Val-Class-Acc: {0: '96.92%', 1: '95.48%', 2: '85.14%'}, LR: 0.000100000
# Removed old model with accuracy 93.67%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_28.pth
# Model saved after epoch 31 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_31.pth
#
# Epoch 32/2000, Train Loss: 0.123264118, Train-Class-Acc: {0: '97.14%', 1: '94.11%', 2: '90.85%'}, Val Loss: 0.129756706, Val Accuracy: 95.25%, Val-Class-Acc: {0: '97.93%', 1: '94.73%', 2: '84.01%'}, LR: 0.000100000
# Removed old model with accuracy 93.85%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_29.pth
# Model saved after epoch 32 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_32.pth
#
# Epoch 33/2000, Train Loss: 0.125644414, Train-Class-Acc: {0: '97.06%', 1: '93.98%', 2: '90.87%'}, Val Loss: 0.167160794, Val Accuracy: 93.42%, Val-Class-Acc: {0: '99.16%', 1: '92.18%', 2: '69.83%'}, LR: 0.000100000
# Epoch 34/2000, Train Loss: 0.127893204, Train-Class-Acc: {0: '96.98%', 1: '93.89%', 2: '90.79%'}, Val Loss: 0.180781006, Val Accuracy: 92.85%, Val-Class-Acc: {0: '91.65%', 1: '93.57%', 2: '96.24%'}, LR: 0.000100000
# Epoch 35/2000, Train Loss: 0.130932678, Train-Class-Acc: {0: '96.82%', 1: '93.72%', 2: '90.57%'}, Val Loss: 0.124030075, Val Accuracy: 95.45%, Val-Class-Acc: {0: '96.53%', 1: '95.85%', 2: '88.87%'}, LR: 0.000100000
# Removed old model with accuracy 93.97%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_27.pth
# Model saved after epoch 35 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_35.pth
#
# Epoch 36/2000, Train Loss: 0.139276226, Train-Class-Acc: {0: '96.60%', 1: '93.43%', 2: '90.65%'}, Val Loss: 0.122820147, Val Accuracy: 95.55%, Val-Class-Acc: {0: '97.24%', 1: '95.82%', 2: '86.51%'}, LR: 0.000100000
# Removed old model with accuracy 94.17%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_30.pth
# Model saved after epoch 36 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_36.pth
#
# Epoch 37/2000, Train Loss: 0.121288546, Train-Class-Acc: {0: '97.11%', 1: '94.23%', 2: '91.41%'}, Val Loss: 0.132641260, Val Accuracy: 95.07%, Val-Class-Acc: {0: '98.83%', 1: '93.40%', 2: '82.50%'}, LR: 0.000100000
# Removed old model with accuracy 94.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_26.pth
# Model saved after epoch 37 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_37.pth
#
# Epoch 38/2000, Train Loss: 0.116257641, Train-Class-Acc: {0: '97.22%', 1: '94.52%', 2: '91.79%'}, Val Loss: 0.140919066, Val Accuracy: 94.44%, Val-Class-Acc: {0: '98.99%', 1: '93.18%', 2: '76.65%'}, LR: 0.000100000
# Epoch 39/2000, Train Loss: 0.126024786, Train-Class-Acc: {0: '96.86%', 1: '94.04%', 2: '91.11%'}, Val Loss: 0.139473171, Val Accuracy: 94.43%, Val-Class-Acc: {0: '98.96%', 1: '93.64%', 2: '75.16%'}, LR: 0.000100000
# Epoch 40/2000, Train Loss: 0.116220807, Train-Class-Acc: {0: '97.20%', 1: '94.48%', 2: '91.94%'}, Val Loss: 0.144774929, Val Accuracy: 94.21%, Val-Class-Acc: {0: '99.09%', 1: '92.94%', 2: '74.87%'}, LR: 0.000100000
# Epoch 41/2000, Train Loss: 0.114742957, Train-Class-Acc: {0: '97.16%', 1: '94.69%', 2: '91.98%'}, Val Loss: 0.113499164, Val Accuracy: 96.02%, Val-Class-Acc: {0: '98.00%', 1: '95.67%', 2: '87.63%'}, LR: 0.000100000
# Removed old model with accuracy 95.07%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_37.pth
# Model saved after epoch 41 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_41.pth
#
# Epoch 42/2000, Train Loss: 0.131461691, Train-Class-Acc: {0: '96.70%', 1: '93.92%', 2: '91.35%'}, Val Loss: 0.118001937, Val Accuracy: 95.78%, Val-Class-Acc: {0: '97.93%', 1: '95.59%', 2: '85.96%'}, LR: 0.000100000
# Removed old model with accuracy 95.11%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_31.pth
# Model saved after epoch 42 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_42.pth
#
# Epoch 43/2000, Train Loss: 0.110492931, Train-Class-Acc: {0: '97.33%', 1: '94.80%', 2: '92.54%'}, Val Loss: 0.139907802, Val Accuracy: 94.57%, Val-Class-Acc: {0: '99.15%', 1: '92.68%', 2: '78.77%'}, LR: 0.000100000
# Epoch 44/2000, Train Loss: 0.114806696, Train-Class-Acc: {0: '97.15%', 1: '94.61%', 2: '91.99%'}, Val Loss: 0.109623987, Val Accuracy: 96.00%, Val-Class-Acc: {0: '96.72%', 1: '96.48%', 2: '90.94%'}, LR: 0.000100000
# Removed old model with accuracy 95.25%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_32.pth
# Model saved after epoch 44 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_44.pth
#
# Epoch 45/2000, Train Loss: 0.109038744, Train-Class-Acc: {0: '97.26%', 1: '94.97%', 2: '92.68%'}, Val Loss: 0.167118880, Val Accuracy: 93.61%, Val-Class-Acc: {0: '99.46%', 1: '91.38%', 2: '72.77%'}, LR: 0.000100000
# Epoch 46/2000, Train Loss: 0.108380100, Train-Class-Acc: {0: '97.28%', 1: '95.03%', 2: '92.74%'}, Val Loss: 0.150385736, Val Accuracy: 93.89%, Val-Class-Acc: {0: '99.17%', 1: '92.97%', 2: '71.39%'}, LR: 0.000100000
# Epoch 47/2000, Train Loss: 0.106964835, Train-Class-Acc: {0: '97.31%', 1: '95.04%', 2: '92.76%'}, Val Loss: 0.200410151, Val Accuracy: 92.65%, Val-Class-Acc: {0: '99.60%', 1: '89.71%', 2: '68.82%'}, LR: 0.000100000
# Epoch 48/2000, Train Loss: 0.131078099, Train-Class-Acc: {0: '96.65%', 1: '93.93%', 2: '91.54%'}, Val Loss: 0.108244819, Val Accuracy: 96.04%, Val-Class-Acc: {0: '97.83%', 1: '96.55%', 2: '85.68%'}, LR: 0.000100000
# Removed old model with accuracy 95.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_35.pth
# Model saved after epoch 48 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_48.pth
#
# Epoch 49/2000, Train Loss: 0.104429716, Train-Class-Acc: {0: '97.39%', 1: '95.21%', 2: '92.85%'}, Val Loss: 0.114818094, Val Accuracy: 95.81%, Val-Class-Acc: {0: '95.31%', 1: '97.18%', 2: '93.64%'}, LR: 0.000100000
# Removed old model with accuracy 95.55%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_36.pth
# Model saved after epoch 49 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_49.pth
#
# Epoch 50/2000, Train Loss: 0.117066936, Train-Class-Acc: {0: '96.98%', 1: '94.52%', 2: '92.07%'}, Val Loss: 0.103295244, Val Accuracy: 96.21%, Val-Class-Acc: {0: '97.27%', 1: '96.91%', 2: '88.76%'}, LR: 0.000100000
# Removed old model with accuracy 95.78%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_42.pth
# Model saved after epoch 50 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_50.pth
#
# Epoch 51/2000, Train Loss: 0.100481361, Train-Class-Acc: {0: '97.44%', 1: '95.45%', 2: '93.44%'}, Val Loss: 0.126155947, Val Accuracy: 95.06%, Val-Class-Acc: {0: '99.11%', 1: '93.23%', 2: '81.58%'}, LR: 0.000100000
# Epoch 52/2000, Train Loss: 0.106634379, Train-Class-Acc: {0: '97.23%', 1: '95.13%', 2: '92.98%'}, Val Loss: 0.102113643, Val Accuracy: 96.38%, Val-Class-Acc: {0: '98.14%', 1: '96.20%', 2: '88.44%'}, LR: 0.000100000
# Removed old model with accuracy 95.81%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_49.pth
# Model saved after epoch 52 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_52.pth
#
# Epoch 53/2000, Train Loss: 0.113511584, Train-Class-Acc: {0: '97.00%', 1: '94.76%', 2: '92.60%'}, Val Loss: 0.105652499, Val Accuracy: 96.16%, Val-Class-Acc: {0: '98.47%', 1: '95.60%', 2: '86.86%'}, LR: 0.000100000
# Removed old model with accuracy 96.00%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_44.pth
# Model saved after epoch 53 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_53.pth
#
# Epoch 54/2000, Train Loss: 0.105487643, Train-Class-Acc: {0: '97.26%', 1: '95.11%', 2: '93.27%'}, Val Loss: 0.109723289, Val Accuracy: 95.58%, Val-Class-Acc: {0: '98.25%', 1: '96.35%', 2: '80.11%'}, LR: 0.000100000
# Epoch 55/2000, Train Loss: 0.104729795, Train-Class-Acc: {0: '97.23%', 1: '95.19%', 2: '93.15%'}, Val Loss: 0.097535632, Val Accuracy: 96.64%, Val-Class-Acc: {0: '97.38%', 1: '96.99%', 2: '91.85%'}, LR: 0.000100000
# Removed old model with accuracy 96.02%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_41.pth
# Model saved after epoch 55 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_55.pth
#
# Epoch 56/2000, Train Loss: 0.116357068, Train-Class-Acc: {0: '96.88%', 1: '94.56%', 2: '92.50%'}, Val Loss: 0.265857205, Val Accuracy: 91.27%, Val-Class-Acc: {0: '99.80%', 1: '86.52%', 2: '65.80%'}, LR: 0.000100000
# Epoch 57/2000, Train Loss: 0.120103405, Train-Class-Acc: {0: '96.90%', 1: '94.42%', 2: '92.53%'}, Val Loss: 0.105788107, Val Accuracy: 96.02%, Val-Class-Acc: {0: '98.60%', 1: '95.62%', 2: '84.85%'}, LR: 0.000100000
# Epoch 58/2000, Train Loss: 0.100285570, Train-Class-Acc: {0: '97.34%', 1: '95.50%', 2: '93.29%'}, Val Loss: 0.119833582, Val Accuracy: 95.07%, Val-Class-Acc: {0: '99.05%', 1: '94.28%', 2: '78.40%'}, LR: 0.000100000
# Epoch 59/2000, Train Loss: 0.094758653, Train-Class-Acc: {0: '97.55%', 1: '95.72%', 2: '93.89%'}, Val Loss: 0.097696665, Val Accuracy: 96.40%, Val-Class-Acc: {0: '98.03%', 1: '96.92%', 2: '86.84%'}, LR: 0.000100000
# Removed old model with accuracy 96.04%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_48.pth
# Model saved after epoch 59 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_59.pth
#
# Epoch 60/2000, Train Loss: 0.111101843, Train-Class-Acc: {0: '97.03%', 1: '94.79%', 2: '93.23%'}, Val Loss: 0.098934616, Val Accuracy: 96.58%, Val-Class-Acc: {0: '96.33%', 1: '97.45%', 2: '94.86%'}, LR: 0.000100000
# Removed old model with accuracy 96.16%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_53.pth
# Model saved after epoch 60 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_60.pth
#
# Epoch 61/2000, Train Loss: 0.097414128, Train-Class-Acc: {0: '97.42%', 1: '95.64%', 2: '93.82%'}, Val Loss: 0.113682592, Val Accuracy: 95.94%, Val-Class-Acc: {0: '94.64%', 1: '97.34%', 2: '97.52%'}, LR: 0.000100000
# Epoch 62/2000, Train Loss: 0.099514567, Train-Class-Acc: {0: '97.32%', 1: '95.51%', 2: '93.45%'}, Val Loss: 0.094616276, Val Accuracy: 96.60%, Val-Class-Acc: {0: '98.17%', 1: '96.67%', 2: '88.79%'}, LR: 0.000100000
# Removed old model with accuracy 96.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_50.pth
# Model saved after epoch 62 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_62.pth
#
# Epoch 63/2000, Train Loss: 0.092389181, Train-Class-Acc: {0: '97.57%', 1: '95.84%', 2: '94.08%'}, Val Loss: 0.094610959, Val Accuracy: 96.68%, Val-Class-Acc: {0: '96.48%', 1: '97.53%', 2: '94.82%'}, LR: 0.000100000
# Removed old model with accuracy 96.38%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_52.pth
# Model saved after epoch 63 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_63.pth
#
# Epoch 64/2000, Train Loss: 0.145179397, Train-Class-Acc: {0: '96.01%', 1: '93.50%', 2: '91.46%'}, Val Loss: 0.250059778, Val Accuracy: 91.48%, Val-Class-Acc: {0: '99.84%', 1: '86.80%', 2: '66.65%'}, LR: 0.000100000
# Epoch 65/2000, Train Loss: 0.102348146, Train-Class-Acc: {0: '97.40%', 1: '95.25%', 2: '93.54%'}, Val Loss: 0.092394287, Val Accuracy: 96.89%, Val-Class-Acc: {0: '97.82%', 1: '97.05%', 2: '91.81%'}, LR: 0.000100000
# Removed old model with accuracy 96.40%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_59.pth
# Model saved after epoch 65 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_65.pth
#
# Epoch 66/2000, Train Loss: 0.092191829, Train-Class-Acc: {0: '97.52%', 1: '95.95%', 2: '94.35%'}, Val Loss: 0.112200494, Val Accuracy: 95.37%, Val-Class-Acc: {0: '99.11%', 1: '93.97%', 2: '81.97%'}, LR: 0.000100000
# Epoch 67/2000, Train Loss: 0.095143382, Train-Class-Acc: {0: '97.41%', 1: '95.66%', 2: '94.16%'}, Val Loss: 0.102998235, Val Accuracy: 95.86%, Val-Class-Acc: {0: '98.58%', 1: '96.27%', 2: '81.30%'}, LR: 0.000100000
# Epoch 68/2000, Train Loss: 0.089343366, Train-Class-Acc: {0: '97.58%', 1: '96.11%', 2: '94.43%'}, Val Loss: 0.103382713, Val Accuracy: 95.82%, Val-Class-Acc: {0: '98.91%', 1: '95.00%', 2: '83.63%'}, LR: 0.000100000
# Epoch 69/2000, Train Loss: 0.091725886, Train-Class-Acc: {0: '97.50%', 1: '95.88%', 2: '94.38%'}, Val Loss: 0.091998499, Val Accuracy: 96.59%, Val-Class-Acc: {0: '96.51%', 1: '97.01%', 2: '95.59%'}, LR: 0.000100000
# Removed old model with accuracy 96.58%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_60.pth
# Model saved after epoch 69 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_69.pth
#
# Epoch 70/2000, Train Loss: 0.090098795, Train-Class-Acc: {0: '97.53%', 1: '95.95%', 2: '94.52%'}, Val Loss: 0.090584266, Val Accuracy: 96.58%, Val-Class-Acc: {0: '98.04%', 1: '97.31%', 2: '87.07%'}, LR: 0.000100000
# Epoch 71/2000, Train Loss: 0.089251624, Train-Class-Acc: {0: '97.55%', 1: '96.10%', 2: '94.54%'}, Val Loss: 0.107665258, Val Accuracy: 96.01%, Val-Class-Acc: {0: '94.92%', 1: '96.91%', 2: '98.24%'}, LR: 0.000100000
# Epoch 72/2000, Train Loss: 0.098244248, Train-Class-Acc: {0: '97.29%', 1: '95.46%', 2: '94.07%'}, Val Loss: 0.090033387, Val Accuracy: 96.60%, Val-Class-Acc: {0: '98.08%', 1: '97.33%', 2: '87.00%'}, LR: 0.000100000
# Removed old model with accuracy 96.59%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_69.pth
# Model saved after epoch 72 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_72.pth
#
# Epoch 73/2000, Train Loss: 0.091612024, Train-Class-Acc: {0: '97.48%', 1: '95.89%', 2: '94.45%'}, Val Loss: 0.086268422, Val Accuracy: 96.94%, Val-Class-Acc: {0: '97.90%', 1: '97.40%', 2: '90.76%'}, LR: 0.000100000
# Removed old model with accuracy 96.60%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_72.pth
# Model saved after epoch 73 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_73.pth
#
# Epoch 74/2000, Train Loss: 0.087837594, Train-Class-Acc: {0: '97.56%', 1: '96.15%', 2: '94.74%'}, Val Loss: 0.085617564, Val Accuracy: 97.09%, Val-Class-Acc: {0: '98.21%', 1: '97.12%', 2: '91.59%'}, LR: 0.000100000
# Removed old model with accuracy 96.60%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_62.pth
# Model saved after epoch 74 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_74.pth
#
# Epoch 75/2000, Train Loss: 0.090096929, Train-Class-Acc: {0: '97.54%', 1: '95.93%', 2: '94.61%'}, Val Loss: 0.085484329, Val Accuracy: 97.01%, Val-Class-Acc: {0: '98.02%', 1: '97.56%', 2: '90.25%'}, LR: 0.000100000
# Removed old model with accuracy 96.64%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_55.pth
# Model saved after epoch 75 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_75.pth
#
# Epoch 76/2000, Train Loss: 0.090328706, Train-Class-Acc: {0: '97.52%', 1: '95.99%', 2: '94.44%'}, Val Loss: 0.092990445, Val Accuracy: 96.22%, Val-Class-Acc: {0: '98.52%', 1: '96.67%', 2: '83.59%'}, LR: 0.000100000
# Epoch 77/2000, Train Loss: 0.091171227, Train-Class-Acc: {0: '97.45%', 1: '95.97%', 2: '94.61%'}, Val Loss: 0.141538716, Val Accuracy: 94.36%, Val-Class-Acc: {0: '99.49%', 1: '92.65%', 2: '75.19%'}, LR: 0.000100000
# Epoch 78/2000, Train Loss: 0.088310368, Train-Class-Acc: {0: '97.59%', 1: '96.05%', 2: '94.75%'}, Val Loss: 0.083718318, Val Accuracy: 97.11%, Val-Class-Acc: {0: '97.37%', 1: '97.84%', 2: '93.42%'}, LR: 0.000100000
# Removed old model with accuracy 96.68%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_63.pth
# Model saved after epoch 78 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_78.pth
#
# Epoch 79/2000, Train Loss: 0.087091311, Train-Class-Acc: {0: '97.60%', 1: '96.07%', 2: '94.85%'}, Val Loss: 0.099389401, Val Accuracy: 96.29%, Val-Class-Acc: {0: '95.38%', 1: '97.02%', 2: '98.25%'}, LR: 0.000100000
# Epoch 80/2000, Train Loss: 0.092450722, Train-Class-Acc: {0: '97.41%', 1: '95.88%', 2: '94.51%'}, Val Loss: 0.088796153, Val Accuracy: 96.83%, Val-Class-Acc: {0: '96.26%', 1: '98.33%', 2: '94.56%'}, LR: 0.000100000
# Epoch 81/2000, Train Loss: 0.098684861, Train-Class-Acc: {0: '97.13%', 1: '95.54%', 2: '94.15%'}, Val Loss: 0.087848070, Val Accuracy: 96.63%, Val-Class-Acc: {0: '97.87%', 1: '97.79%', 2: '86.79%'}, LR: 0.000100000
# Epoch 82/2000, Train Loss: 0.081885856, Train-Class-Acc: {0: '97.75%', 1: '96.45%', 2: '95.28%'}, Val Loss: 0.083257716, Val Accuracy: 96.93%, Val-Class-Acc: {0: '97.72%', 1: '97.89%', 2: '89.90%'}, LR: 0.000100000
# Removed old model with accuracy 96.89%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_65.pth
# Model saved after epoch 82 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_82.pth
#
# Epoch 83/2000, Train Loss: 0.089886124, Train-Class-Acc: {0: '97.44%', 1: '95.99%', 2: '94.51%'}, Val Loss: 0.106597413, Val Accuracy: 95.33%, Val-Class-Acc: {0: '99.18%', 1: '94.58%', 2: '79.17%'}, LR: 0.000100000
# Epoch 84/2000, Train Loss: 0.087369935, Train-Class-Acc: {0: '97.58%', 1: '96.10%', 2: '94.82%'}, Val Loss: 0.085330395, Val Accuracy: 96.71%, Val-Class-Acc: {0: '98.25%', 1: '97.34%', 2: '87.17%'}, LR: 0.000100000
# Epoch 85/2000, Train Loss: 0.081789285, Train-Class-Acc: {0: '97.72%', 1: '96.43%', 2: '95.32%'}, Val Loss: 0.089558546, Val Accuracy: 96.44%, Val-Class-Acc: {0: '98.73%', 1: '96.62%', 2: '84.82%'}, LR: 0.000100000
# Epoch 86/2000, Train Loss: 0.085711898, Train-Class-Acc: {0: '97.57%', 1: '96.23%', 2: '94.96%'}, Val Loss: 0.078927010, Val Accuracy: 97.24%, Val-Class-Acc: {0: '97.97%', 1: '97.82%', 2: '91.72%'}, LR: 0.000100000
# Removed old model with accuracy 96.93%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_82.pth
# Model saved after epoch 86 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_86.pth
#
# Epoch 87/2000, Train Loss: 0.083417835, Train-Class-Acc: {0: '97.64%', 1: '96.38%', 2: '95.12%'}, Val Loss: 0.080215241, Val Accuracy: 97.05%, Val-Class-Acc: {0: '98.46%', 1: '97.11%', 2: '90.02%'}, LR: 0.000100000
# Removed old model with accuracy 96.94%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_73.pth
# Model saved after epoch 87 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_87.pth
#
# Epoch 88/2000, Train Loss: 0.107020820, Train-Class-Acc: {0: '97.03%', 1: '95.11%', 2: '93.52%'}, Val Loss: 0.099173256, Val Accuracy: 95.79%, Val-Class-Acc: {0: '98.49%', 1: '97.29%', 2: '77.73%'}, LR: 0.000100000
# Epoch 89/2000, Train Loss: 0.088493414, Train-Class-Acc: {0: '97.51%', 1: '95.99%', 2: '94.87%'}, Val Loss: 0.129929575, Val Accuracy: 94.42%, Val-Class-Acc: {0: '99.45%', 1: '93.41%', 2: '73.51%'}, LR: 0.000100000
# Epoch 90/2000, Train Loss: 0.082174711, Train-Class-Acc: {0: '97.71%', 1: '96.42%', 2: '95.13%'}, Val Loss: 0.080841213, Val Accuracy: 96.96%, Val-Class-Acc: {0: '98.17%', 1: '97.67%', 2: '88.73%'}, LR: 0.000100000
# Epoch 91/2000, Train Loss: 0.078282603, Train-Class-Acc: {0: '97.80%', 1: '96.59%', 2: '95.54%'}, Val Loss: 0.086154613, Val Accuracy: 96.97%, Val-Class-Acc: {0: '96.19%', 1: '97.78%', 2: '98.02%'}, LR: 0.000100000
# Epoch 92/2000, Train Loss: 0.077221269, Train-Class-Acc: {0: '97.81%', 1: '96.66%', 2: '95.55%'}, Val Loss: 0.088719663, Val Accuracy: 96.15%, Val-Class-Acc: {0: '98.65%', 1: '96.91%', 2: '81.45%'}, LR: 0.000100000
# Epoch 93/2000, Train Loss: 0.078863688, Train-Class-Acc: {0: '97.76%', 1: '96.59%', 2: '95.37%'}, Val Loss: 0.078644990, Val Accuracy: 97.00%, Val-Class-Acc: {0: '98.64%', 1: '96.91%', 2: '89.36%'}, LR: 0.000100000
# Epoch 94/2000, Train Loss: 0.079540851, Train-Class-Acc: {0: '97.69%', 1: '96.53%', 2: '95.66%'}, Val Loss: 0.117640470, Val Accuracy: 94.92%, Val-Class-Acc: {0: '99.51%', 1: '93.39%', 2: '77.78%'}, LR: 0.000100000
# Epoch 95/2000, Train Loss: 0.086060193, Train-Class-Acc: {0: '97.58%', 1: '96.05%', 2: '94.97%'}, Val Loss: 0.087704666, Val Accuracy: 96.90%, Val-Class-Acc: {0: '95.92%', 1: '98.26%', 2: '97.07%'}, LR: 0.000100000
# Epoch 96/2000, Train Loss: 0.079345561, Train-Class-Acc: {0: '97.72%', 1: '96.54%', 2: '95.39%'}, Val Loss: 0.089496292, Val Accuracy: 96.20%, Val-Class-Acc: {0: '98.98%', 1: '95.87%', 2: '83.86%'}, LR: 0.000100000
# Epoch 97/2000, Train Loss: 0.086675575, Train-Class-Acc: {0: '97.56%', 1: '96.17%', 2: '94.96%'}, Val Loss: 0.096190485, Val Accuracy: 96.28%, Val-Class-Acc: {0: '95.37%', 1: '96.92%', 2: '98.58%'}, LR: 0.000100000
# Epoch 98/2000, Train Loss: 0.078773294, Train-Class-Acc: {0: '97.78%', 1: '96.49%', 2: '95.46%'}, Val Loss: 0.075509436, Val Accuracy: 97.46%, Val-Class-Acc: {0: '97.70%', 1: '98.29%', 2: '93.49%'}, LR: 0.000100000
# Removed old model with accuracy 97.01%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_75.pth
# Model saved after epoch 98 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_98.pth
#
# Epoch 99/2000, Train Loss: 0.088949462, Train-Class-Acc: {0: '97.40%', 1: '95.89%', 2: '94.92%'}, Val Loss: 0.100128851, Val Accuracy: 95.71%, Val-Class-Acc: {0: '99.05%', 1: '96.00%', 2: '78.54%'}, LR: 0.000100000
# Epoch 100/2000, Train Loss: 0.077432981, Train-Class-Acc: {0: '97.76%', 1: '96.57%', 2: '95.75%'}, Val Loss: 0.074672491, Val Accuracy: 97.34%, Val-Class-Acc: {0: '97.85%', 1: '98.16%', 2: '92.13%'}, LR: 0.000100000
# Removed old model with accuracy 97.05%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_87.pth
# Model saved after epoch 100 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_100.pth
#
# Epoch 101/2000, Train Loss: 0.083974308, Train-Class-Acc: {0: '97.54%', 1: '96.22%', 2: '95.21%'}, Val Loss: 0.107622367, Val Accuracy: 95.27%, Val-Class-Acc: {0: '99.29%', 1: '94.55%', 2: '78.22%'}, LR: 0.000100000
# Epoch 102/2000, Train Loss: 0.073780660, Train-Class-Acc: {0: '97.90%', 1: '96.70%', 2: '96.11%'}, Val Loss: 0.092863503, Val Accuracy: 95.82%, Val-Class-Acc: {0: '98.98%', 1: '95.99%', 2: '79.98%'}, LR: 0.000100000
# Epoch 103/2000, Train Loss: 0.075184484, Train-Class-Acc: {0: '97.85%', 1: '96.64%', 2: '95.84%'}, Val Loss: 0.072497356, Val Accuracy: 97.71%, Val-Class-Acc: {0: '97.78%', 1: '98.03%', 2: '96.31%'}, LR: 0.000100000
# Removed old model with accuracy 97.09%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_74.pth
# Model saved after epoch 103 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_103.pth
#
# Epoch 104/2000, Train Loss: 0.078786810, Train-Class-Acc: {0: '97.71%', 1: '96.45%', 2: '95.63%'}, Val Loss: 0.074844497, Val Accuracy: 97.22%, Val-Class-Acc: {0: '97.85%', 1: '98.31%', 2: '90.53%'}, LR: 0.000100000
# Removed old model with accuracy 97.11%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_78.pth
# Model saved after epoch 104 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_104.pth
#
# Epoch 105/2000, Train Loss: 0.073097440, Train-Class-Acc: {0: '97.86%', 1: '96.80%', 2: '95.95%'}, Val Loss: 0.074326904, Val Accuracy: 96.96%, Val-Class-Acc: {0: '98.05%', 1: '98.11%', 2: '87.86%'}, LR: 0.000100000
# Epoch 106/2000, Train Loss: 0.078949893, Train-Class-Acc: {0: '97.71%', 1: '96.46%', 2: '95.80%'}, Val Loss: 0.070867989, Val Accuracy: 97.67%, Val-Class-Acc: {0: '98.04%', 1: '97.67%', 2: '95.94%'}, LR: 0.000100000
# Removed old model with accuracy 97.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_104.pth
# Model saved after epoch 106 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_106.pth
#
# Epoch 107/2000, Train Loss: 0.081956803, Train-Class-Acc: {0: '97.57%', 1: '96.35%', 2: '95.57%'}, Val Loss: 0.123256969, Val Accuracy: 94.80%, Val-Class-Acc: {0: '99.61%', 1: '92.77%', 2: '78.34%'}, LR: 0.000100000
# Epoch 108/2000, Train Loss: 0.105524804, Train-Class-Acc: {0: '97.01%', 1: '95.08%', 2: '94.05%'}, Val Loss: 0.086842769, Val Accuracy: 96.23%, Val-Class-Acc: {0: '97.05%', 1: '98.62%', 2: '84.33%'}, LR: 0.000100000
# Epoch 109/2000, Train Loss: 0.089333131, Train-Class-Acc: {0: '97.44%', 1: '95.71%', 2: '94.87%'}, Val Loss: 0.082556575, Val Accuracy: 96.92%, Val-Class-Acc: {0: '96.90%', 1: '98.07%', 2: '93.18%'}, LR: 0.000100000
# Epoch 110/2000, Train Loss: 0.077396928, Train-Class-Acc: {0: '97.73%', 1: '96.50%', 2: '96.10%'}, Val Loss: 0.079317611, Val Accuracy: 96.67%, Val-Class-Acc: {0: '98.27%', 1: '97.98%', 2: '84.53%'}, LR: 0.000100000
# Epoch 111/2000, Train Loss: 0.068340907, Train-Class-Acc: {0: '98.05%', 1: '97.12%', 2: '96.52%'}, Val Loss: 0.074901512, Val Accuracy: 97.09%, Val-Class-Acc: {0: '97.74%', 1: '98.45%', 2: '89.38%'}, LR: 0.000100000
# Epoch 112/2000, Train Loss: 0.070052756, Train-Class-Acc: {0: '97.95%', 1: '96.93%', 2: '96.42%'}, Val Loss: 0.094929806, Val Accuracy: 95.72%, Val-Class-Acc: {0: '99.22%', 1: '95.29%', 2: '80.19%'}, LR: 0.000100000
# Epoch 113/2000, Train Loss: 0.071231611, Train-Class-Acc: {0: '97.94%', 1: '96.72%', 2: '96.24%'}, Val Loss: 0.074380065, Val Accuracy: 96.88%, Val-Class-Acc: {0: '97.87%', 1: '98.37%', 2: '87.14%'}, LR: 0.000100000
# Epoch 114/2000, Train Loss: 0.072866704, Train-Class-Acc: {0: '97.81%', 1: '96.69%', 2: '96.05%'}, Val Loss: 0.072808651, Val Accuracy: 97.28%, Val-Class-Acc: {0: '97.74%', 1: '98.28%', 2: '91.70%'}, LR: 0.000100000
# Removed old model with accuracy 97.24%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_86.pth
# Model saved after epoch 114 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_114.pth
#
# Epoch 115/2000, Train Loss: 0.071624251, Train-Class-Acc: {0: '97.88%', 1: '96.73%', 2: '96.28%'}, Val Loss: 0.109697711, Val Accuracy: 95.31%, Val-Class-Acc: {0: '99.44%', 1: '94.12%', 2: '79.30%'}, LR: 0.000100000
# Epoch 116/2000, Train Loss: 0.072804510, Train-Class-Acc: {0: '97.83%', 1: '96.63%', 2: '96.22%'}, Val Loss: 0.103575544, Val Accuracy: 95.38%, Val-Class-Acc: {0: '99.34%', 1: '94.75%', 2: '78.28%'}, LR: 0.000100000
# Epoch 117/2000, Train Loss: 0.069967641, Train-Class-Acc: {0: '97.93%', 1: '96.87%', 2: '96.40%'}, Val Loss: 0.077740958, Val Accuracy: 96.82%, Val-Class-Acc: {0: '97.06%', 1: '98.33%', 2: '90.61%'}, LR: 0.000100000
# Epoch 118/2000, Train Loss: 0.082677889, Train-Class-Acc: {0: '97.54%', 1: '96.23%', 2: '95.67%'}, Val Loss: 0.079144387, Val Accuracy: 96.50%, Val-Class-Acc: {0: '98.75%', 1: '97.31%', 2: '82.93%'}, LR: 0.000100000
# Epoch 119/2000, Train Loss: 0.070339901, Train-Class-Acc: {0: '97.91%', 1: '96.78%', 2: '96.54%'}, Val Loss: 0.082152281, Val Accuracy: 96.29%, Val-Class-Acc: {0: '98.92%', 1: '96.81%', 2: '81.84%'}, LR: 0.000100000
# Epoch 120/2000, Train Loss: 0.070734288, Train-Class-Acc: {0: '97.88%', 1: '96.84%', 2: '96.45%'}, Val Loss: 0.147623513, Val Accuracy: 94.48%, Val-Class-Acc: {0: '99.66%', 1: '92.90%', 2: '74.64%'}, LR: 0.000100000
# Epoch 121/2000, Train Loss: 0.110258566, Train-Class-Acc: {0: '96.88%', 1: '94.93%', 2: '93.80%'}, Val Loss: 0.085148806, Val Accuracy: 96.64%, Val-Class-Acc: {0: '96.38%', 1: '97.46%', 2: '95.15%'}, LR: 0.000100000
# Epoch 122/2000, Train Loss: 0.074167183, Train-Class-Acc: {0: '97.77%', 1: '96.53%', 2: '96.28%'}, Val Loss: 0.082735635, Val Accuracy: 96.35%, Val-Class-Acc: {0: '98.52%', 1: '97.63%', 2: '81.56%'}, LR: 0.000100000
# Epoch 123/2000, Train Loss: 0.074565880, Train-Class-Acc: {0: '97.78%', 1: '96.57%', 2: '96.17%'}, Val Loss: 0.117735880, Val Accuracy: 95.19%, Val-Class-Acc: {0: '99.49%', 1: '94.45%', 2: '76.94%'}, LR: 0.000100000
# Epoch 124/2000, Train Loss: 0.066444867, Train-Class-Acc: {0: '98.05%', 1: '97.02%', 2: '96.70%'}, Val Loss: 0.100834501, Val Accuracy: 95.56%, Val-Class-Acc: {0: '99.25%', 1: '95.45%', 2: '78.04%'}, LR: 0.000100000
# Epoch 125/2000, Train Loss: 0.075632280, Train-Class-Acc: {0: '97.70%', 1: '96.43%', 2: '96.15%'}, Val Loss: 0.077329343, Val Accuracy: 96.59%, Val-Class-Acc: {0: '98.23%', 1: '98.22%', 2: '83.25%'}, LR: 0.000100000
# Epoch 126/2000, Train Loss: 0.065354407, Train-Class-Acc: {0: '98.06%', 1: '97.07%', 2: '96.85%'}, Val Loss: 0.095705470, Val Accuracy: 95.85%, Val-Class-Acc: {0: '99.14%', 1: '96.14%', 2: '79.02%'}, LR: 0.000100000
# Epoch 127/2000, Train Loss: 0.064765408, Train-Class-Acc: {0: '98.06%', 1: '97.09%', 2: '96.87%'}, Val Loss: 0.069860766, Val Accuracy: 97.17%, Val-Class-Acc: {0: '98.09%', 1: '97.98%', 2: '89.99%'}, LR: 0.000100000
# Epoch 128/2000, Train Loss: 0.066123993, Train-Class-Acc: {0: '97.99%', 1: '97.01%', 2: '96.66%'}, Val Loss: 0.121297423, Val Accuracy: 95.15%, Val-Class-Acc: {0: '99.57%', 1: '94.12%', 2: '77.20%'}, LR: 0.000100000
# Epoch 129/2000, Train Loss: 0.062208334, Train-Class-Acc: {0: '98.12%', 1: '97.24%', 2: '97.14%'}, Val Loss: 0.088652696, Val Accuracy: 96.04%, Val-Class-Acc: {0: '99.13%', 1: '96.21%', 2: '80.54%'}, LR: 0.000100000
# Epoch 130/2000, Train Loss: 0.067149162, Train-Class-Acc: {0: '97.94%', 1: '96.87%', 2: '97.05%'}, Val Loss: 0.119795179, Val Accuracy: 95.23%, Val-Class-Acc: {0: '99.47%', 1: '94.72%', 2: '76.46%'}, LR: 0.000100000
# ...
# Epoch 1943/2000, Train Loss: 0.001642910, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '99.99%'}, Val Loss: 0.147940386, Val Accuracy: 97.59%, Val-Class-Acc: {0: '99.72%', 1: '98.30%', 2: '84.90%'}, LR: 0.000100000
# Epoch 1944/2000, Train Loss: 0.001538993, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.146389901, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.68%', 1: '98.53%', 2: '84.88%'}, LR: 0.000100000
# Epoch 1945/2000, Train Loss: 0.001413244, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.145784942, Val Accuracy: 97.66%, Val-Class-Acc: {0: '99.62%', 1: '98.55%', 2: '85.19%'}, LR: 0.000100000
# Epoch 1946/2000, Train Loss: 0.001475707, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.145219148, Val Accuracy: 97.67%, Val-Class-Acc: {0: '99.65%', 1: '98.52%', 2: '85.26%'}, LR: 0.000100000
# Epoch 1947/2000, Train Loss: 0.001388488, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.147221378, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.70%', 1: '98.41%', 2: '85.07%'}, LR: 0.000100000
# Epoch 1948/2000, Train Loss: 0.001414232, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.144420314, Val Accuracy: 97.66%, Val-Class-Acc: {0: '99.58%', 1: '98.51%', 2: '85.56%'}, LR: 0.000100000
# Epoch 1949/2000, Train Loss: 0.001517251, Train-Class-Acc: {0: '99.96%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.146196396, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.53%', 1: '98.65%', 2: '85.24%'}, LR: 0.000100000
# Epoch 1950/2000, Train Loss: 0.001399928, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.146554162, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.66%', 1: '98.45%', 2: '85.26%'}, LR: 0.000100000
# Epoch 1951/2000, Train Loss: 0.001434529, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.147075741, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.69%', 1: '98.38%', 2: '85.33%'}, LR: 0.000100000
# Epoch 1952/2000, Train Loss: 0.001370501, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.155220967, Val Accuracy: 97.49%, Val-Class-Acc: {0: '99.75%', 1: '98.03%', 2: '84.77%'}, LR: 0.000100000
# Epoch 1953/2000, Train Loss: 0.002124175, Train-Class-Acc: {0: '99.93%', 1: '99.90%', 2: '99.99%'}, Val Loss: 0.165115253, Val Accuracy: 97.33%, Val-Class-Acc: {0: '99.77%', 1: '97.75%', 2: '84.11%'}, LR: 0.000100000
# Epoch 1954/2000, Train Loss: 0.002789518, Train-Class-Acc: {0: '99.90%', 1: '99.86%', 2: '99.99%'}, Val Loss: 0.158484187, Val Accuracy: 97.54%, Val-Class-Acc: {0: '99.73%', 1: '98.35%', 2: '84.28%'}, LR: 0.000100000
# Epoch 1955/2000, Train Loss: 0.001563538, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '100.00%'}, Val Loss: 0.147927974, Val Accuracy: 97.62%, Val-Class-Acc: {0: '99.60%', 1: '98.43%', 2: '85.36%'}, LR: 0.000100000
# Epoch 1956/2000, Train Loss: 0.001498758, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '100.00%'}, Val Loss: 0.147840241, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.53%', 1: '98.58%', 2: '85.33%'}, LR: 0.000100000
# Epoch 1957/2000, Train Loss: 0.042624798, Train-Class-Acc: {0: '99.39%', 1: '98.98%', 2: '99.22%'}, Val Loss: 0.513545655, Val Accuracy: 92.97%, Val-Class-Acc: {0: '99.99%', 1: '88.36%', 2: '74.45%'}, LR: 0.000100000
# Epoch 1958/2000, Train Loss: 0.056229674, Train-Class-Acc: {0: '98.82%', 1: '98.08%', 2: '98.66%'}, Val Loss: 0.164988069, Val Accuracy: 97.03%, Val-Class-Acc: {0: '99.74%', 1: '96.93%', 2: '84.26%'}, LR: 0.000100000
# Epoch 1959/2000, Train Loss: 0.003760516, Train-Class-Acc: {0: '99.93%', 1: '99.86%', 2: '99.98%'}, Val Loss: 0.151502415, Val Accuracy: 97.60%, Val-Class-Acc: {0: '99.63%', 1: '98.49%', 2: '84.77%'}, LR: 0.000100000
# Epoch 1960/2000, Train Loss: 0.002377176, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '99.99%'}, Val Loss: 0.148474177, Val Accuracy: 97.69%, Val-Class-Acc: {0: '99.57%', 1: '98.77%', 2: '85.03%'}, LR: 0.000100000
# Epoch 1961/2000, Train Loss: 0.002082168, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.147668736, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.69%', 1: '98.45%', 2: '85.08%'}, LR: 0.000100000
# Epoch 1962/2000, Train Loss: 0.001894839, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.147127936, Val Accuracy: 97.61%, Val-Class-Acc: {0: '99.71%', 1: '98.34%', 2: '85.04%'}, LR: 0.000100000
# Epoch 1963/2000, Train Loss: 0.001837030, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.146329954, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.67%', 1: '98.46%', 2: '85.07%'}, LR: 0.000100000
# Epoch 1964/2000, Train Loss: 0.001686558, Train-Class-Acc: {0: '99.98%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.143815756, Val Accuracy: 97.68%, Val-Class-Acc: {0: '99.52%', 1: '98.66%', 2: '85.51%'}, LR: 0.000100000
# Epoch 1965/2000, Train Loss: 0.001637529, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.144546216, Val Accuracy: 97.63%, Val-Class-Acc: {0: '99.68%', 1: '98.29%', 2: '85.46%'}, LR: 0.000100000
# Epoch 1966/2000, Train Loss: 0.001564106, Train-Class-Acc: {0: '99.98%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.145646382, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.69%', 1: '98.45%', 2: '85.09%'}, LR: 0.000100000
# Epoch 1967/2000, Train Loss: 0.001560387, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.145841587, Val Accuracy: 97.58%, Val-Class-Acc: {0: '99.71%', 1: '98.21%', 2: '85.19%'}, LR: 0.000100000
# Epoch 1968/2000, Train Loss: 0.001617575, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.145089192, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.63%', 1: '98.54%', 2: '85.08%'}, LR: 0.000100000
# Epoch 1969/2000, Train Loss: 0.001599314, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.144422602, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.53%', 1: '98.59%', 2: '85.38%'}, LR: 0.000100000
# Epoch 1970/2000, Train Loss: 0.001593821, Train-Class-Acc: {0: '99.96%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.144350351, Val Accuracy: 97.66%, Val-Class-Acc: {0: '99.63%', 1: '98.53%', 2: '85.26%'}, LR: 0.000100000
# Epoch 1971/2000, Train Loss: 0.001553355, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.144190693, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.57%', 1: '98.50%', 2: '85.44%'}, LR: 0.000100000
# Epoch 1972/2000, Train Loss: 0.001463933, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.144144132, Val Accuracy: 97.68%, Val-Class-Acc: {0: '99.60%', 1: '98.58%', 2: '85.34%'}, LR: 0.000100000
# Epoch 1973/2000, Train Loss: 0.001442657, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.150201957, Val Accuracy: 97.49%, Val-Class-Acc: {0: '99.75%', 1: '97.92%', 2: '85.07%'}, LR: 0.000100000
# Epoch 1974/2000, Train Loss: 0.001523704, Train-Class-Acc: {0: '99.96%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.148592128, Val Accuracy: 97.57%, Val-Class-Acc: {0: '99.72%', 1: '98.24%', 2: '84.93%'}, LR: 0.000100000
# Epoch 1975/2000, Train Loss: 0.001448398, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.145024548, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.58%', 1: '98.49%', 2: '85.41%'}, LR: 0.000100000
# Epoch 1976/2000, Train Loss: 0.001636962, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '99.99%'}, Val Loss: 0.144783359, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.56%', 1: '98.53%', 2: '85.45%'}, LR: 0.000100000
# Epoch 1977/2000, Train Loss: 0.001538839, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '100.00%'}, Val Loss: 0.145364143, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.52%', 1: '98.59%', 2: '85.40%'}, LR: 0.000100000
# Epoch 1978/2000, Train Loss: 0.001414312, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.148039408, Val Accuracy: 97.61%, Val-Class-Acc: {0: '99.70%', 1: '98.33%', 2: '85.08%'}, LR: 0.000100000
# Epoch 1979/2000, Train Loss: 0.001706375, Train-Class-Acc: {0: '99.95%', 1: '99.93%', 2: '99.99%'}, Val Loss: 0.145347977, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.34%', 1: '98.81%', 2: '85.62%'}, LR: 0.000100000
# Epoch 1980/2000, Train Loss: 0.001869324, Train-Class-Acc: {0: '99.94%', 1: '99.92%', 2: '99.99%'}, Val Loss: 0.148353715, Val Accuracy: 97.62%, Val-Class-Acc: {0: '99.66%', 1: '98.43%', 2: '85.08%'}, LR: 0.000100000
# Epoch 1981/2000, Train Loss: 0.001371054, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.146411326, Val Accuracy: 97.62%, Val-Class-Acc: {0: '99.60%', 1: '98.42%', 2: '85.40%'}, LR: 0.000100000
# Epoch 1982/2000, Train Loss: 0.001496129, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '100.00%'}, Val Loss: 0.147401933, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.54%', 1: '98.63%', 2: '85.18%'}, LR: 0.000100000
# Epoch 1983/2000, Train Loss: 0.001395635, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.145334579, Val Accuracy: 97.65%, Val-Class-Acc: {0: '99.50%', 1: '98.60%', 2: '85.52%'}, LR: 0.000100000
# Epoch 1984/2000, Train Loss: 0.001545728, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '100.00%'}, Val Loss: 0.145216529, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.52%', 1: '98.44%', 2: '85.87%'}, LR: 0.000100000
# Epoch 1985/2000, Train Loss: 0.001406289, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.147807604, Val Accuracy: 97.63%, Val-Class-Acc: {0: '99.62%', 1: '98.43%', 2: '85.37%'}, LR: 0.000100000
# Epoch 1986/2000, Train Loss: 0.001656480, Train-Class-Acc: {0: '99.95%', 1: '99.93%', 2: '99.99%'}, Val Loss: 0.145877968, Val Accuracy: 97.58%, Val-Class-Acc: {0: '99.52%', 1: '98.38%', 2: '85.56%'}, LR: 0.000100000
# Epoch 1987/2000, Train Loss: 0.002766879, Train-Class-Acc: {0: '99.91%', 1: '99.88%', 2: '99.98%'}, Val Loss: 0.148824128, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.57%', 1: '98.58%', 2: '85.20%'}, LR: 0.000100000
# Epoch 1988/2000, Train Loss: 0.055623909, Train-Class-Acc: {0: '99.12%', 1: '98.61%', 2: '99.22%'}, Val Loss: 0.204783970, Val Accuracy: 96.37%, Val-Class-Acc: {0: '97.29%', 1: '97.94%', 2: '86.70%'}, LR: 0.000100000
# Epoch 1989/2000, Train Loss: 0.015355221, Train-Class-Acc: {0: '99.52%', 1: '99.36%', 2: '99.82%'}, Val Loss: 0.156708721, Val Accuracy: 97.48%, Val-Class-Acc: {0: '99.65%', 1: '98.30%', 2: '84.29%'}, LR: 0.000100000
# Epoch 1990/2000, Train Loss: 0.002439290, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '99.99%'}, Val Loss: 0.148534480, Val Accuracy: 97.69%, Val-Class-Acc: {0: '99.63%', 1: '98.57%', 2: '85.36%'}, LR: 0.000100000
# Epoch 1991/2000, Train Loss: 0.002038234, Train-Class-Acc: {0: '99.96%', 1: '99.94%', 2: '99.99%'}, Val Loss: 0.147305051, Val Accuracy: 97.71%, Val-Class-Acc: {0: '99.59%', 1: '98.72%', 2: '85.33%'}, LR: 0.000100000
# Epoch 1992/2000, Train Loss: 0.001823593, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '99.99%'}, Val Loss: 0.145970776, Val Accuracy: 97.69%, Val-Class-Acc: {0: '99.63%', 1: '98.50%', 2: '85.54%'}, LR: 0.000100000
# Epoch 1993/2000, Train Loss: 0.001671434, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.148577413, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.70%', 1: '98.43%', 2: '85.01%'}, LR: 0.000100000
# Epoch 1994/2000, Train Loss: 0.001578218, Train-Class-Acc: {0: '99.98%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.146837600, Val Accuracy: 97.62%, Val-Class-Acc: {0: '99.70%', 1: '98.25%', 2: '85.40%'}, LR: 0.000100000
# Epoch 1995/2000, Train Loss: 0.001542927, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '99.99%'}, Val Loss: 0.145136000, Val Accuracy: 97.67%, Val-Class-Acc: {0: '99.50%', 1: '98.62%', 2: '85.61%'}, LR: 0.000100000
# Epoch 1996/2000, Train Loss: 0.001531921, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.147389449, Val Accuracy: 97.60%, Val-Class-Acc: {0: '99.70%', 1: '98.21%', 2: '85.36%'}, LR: 0.000100000
# Epoch 1997/2000, Train Loss: 0.001460010, Train-Class-Acc: {0: '99.98%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.146281899, Val Accuracy: 97.66%, Val-Class-Acc: {0: '99.62%', 1: '98.50%', 2: '85.35%'}, LR: 0.000100000
# Epoch 1998/2000, Train Loss: 0.001460664, Train-Class-Acc: {0: '99.97%', 1: '99.96%', 2: '100.00%'}, Val Loss: 0.147046546, Val Accuracy: 97.64%, Val-Class-Acc: {0: '99.56%', 1: '98.51%', 2: '85.41%'}, LR: 0.000100000
# Epoch 1999/2000, Train Loss: 0.001501781, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.145917034, Val Accuracy: 97.63%, Val-Class-Acc: {0: '99.62%', 1: '98.37%', 2: '85.54%'}, LR: 0.000100000
# Epoch 2000/2000, Train Loss: 0.001474843, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.147689775, Val Accuracy: 97.61%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, LR: 0.000100000
#
# Final model saved to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_final.pth
#
# Training complete.
#
# Top 5 Models Sorted by Validation Accuracy:
# Epoch 677/2000, Train Loss: 0.008700504, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.102096845, Val Accuracy: 98.15%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_677.pth
# Epoch 730/2000, Train Loss: 0.007741663, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.102018280, Val Accuracy: 98.14%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_730.pth
# Epoch 665/2000, Train Loss: 0.009235143, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.102920321, Val Accuracy: 98.14%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_665.pth
# Epoch 648/2000, Train Loss: 0.010347092, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.099304967, Val Accuracy: 98.13%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_648.pth
# Epoch 688/2000, Train Loss: 0.009375544, Train-Class-Acc: {0: '99.97%', 1: '99.95%', 2: '100.00%'}, Val Loss: 0.102140184, Val Accuracy: 98.13%, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_688.pth
#
#
# Epoch 677/2000, Train Loss: 0.0087, Val Loss: 0.1021, Val Accuracy: 98.15%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_677.pth
# Epoch 730/2000, Train Loss: 0.0077, Val Loss: 0.1020, Val Accuracy: 98.14%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_730.pth
# Epoch 665/2000, Train Loss: 0.0092, Val Loss: 0.1029, Val Accuracy: 98.14%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_665.pth
# Epoch 648/2000, Train Loss: 0.0103, Val Loss: 0.0993, Val Accuracy: 98.13%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_648.pth
# Epoch 688/2000, Train Loss: 0.0094, Val Loss: 0.1021, Val Accuracy: 98.13%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_2\1st_try\BiGRUWithAttention_epoch_688.pth
#
# class_gru_model:
# BiGRUWithAttention(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=3, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1 2]
# num_classes = 3

# %%
# === Post-training Evaluation: Update .pth with val accuracy and class-wise accuracy for Baseline Period 2 ===

# Rebuild evaluation model
model_template = BiGRUWithAttention(
    input_size=Number_features,
    hidden_size=64,
    output_size=num_classes,
    num_layers=4
)

# Prepare validation data
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)
criterion = nn.CrossEntropyLoss()

# Your model folder
model_folder = 'Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try'
ckpt_paths = sorted(glob.glob(os.path.join(model_folder, "*.pth")))

# Loop through and update each model
for file_path in ckpt_paths:
    model_copy = copy.deepcopy(model_template).to(device)
    checkpoint = torch.load(file_path, map_location=device)
    model_copy.load_state_dict(checkpoint['model_state_dict'])

    add_val_class_acc(
        model_copy=model_copy,
        output_size=num_classes,
        criterion=criterion,
        X_val=X_val_tensor,
        y_val=y_val_tensor,
        file_path=file_path,
        model_checkpoint=checkpoint,
        batch_size=64
    )

# 顯示 summary
show_val_accuracy_from_checkpoints(model_folder)
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\447304183.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_path, map_location=device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val, dtype=torch.long).to(device)
# ✅ Updated: BiGRUWithAttention_epoch_648.pth | Acc: 0.9813 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_epoch_648.pth
# ✅ Updated: BiGRUWithAttention_epoch_665.pth | Acc: 0.9814 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_epoch_665.pth
# ✅ Updated: BiGRUWithAttention_epoch_677.pth | Acc: 0.9815 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_epoch_677.pth
# ✅ Updated: BiGRUWithAttention_epoch_688.pth | Acc: 0.9813 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_epoch_688.pth
# ✅ Updated: BiGRUWithAttention_epoch_730.pth | Acc: 0.9814 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_epoch_730.pth
# ✅ Updated: BiGRUWithAttention_final.pth | Acc: 0.9761 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_2/1st_try\BiGRUWithAttention_final.pth
#
# 📝 Summary of val_accuracy and Val-Class-Acc:
# BiGRUWithAttention_epoch_648.pth: val_accuracy = 0.9813, Val-Class-Acc: {0: '99.31%', 1: '98.50%', 2: '91.22%'}
# BiGRUWithAttention_epoch_665.pth: val_accuracy = 0.9814, Val-Class-Acc: {0: '99.53%', 1: '98.34%', 2: '90.76%'}
# BiGRUWithAttention_epoch_677.pth: val_accuracy = 0.9815, Val-Class-Acc: {0: '99.46%', 1: '98.44%', 2: '90.81%'}
# BiGRUWithAttention_epoch_688.pth: val_accuracy = 0.9813, Val-Class-Acc: {0: '99.18%', 1: '98.58%', 2: '91.55%'}
# BiGRUWithAttention_epoch_730.pth: val_accuracy = 0.9814, Val-Class-Acc: {0: '99.43%', 1: '98.59%', 2: '90.45%'}
# BiGRUWithAttention_final.pth: val_accuracy = 0.9761, Val-Class-Acc: {0: '99.67%', 1: '98.26%', 2: '85.41%'}
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:66: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")

# %% [markdown]
# ### Period 3 --> Training and saving in __*'1st_try'*__ (BiGRUWithAttention, num_layers = 4) ---> Val acc = 97.81 %
# ### Val-Class-Acc: {0: '92.45%', 1: '98.51%', 2: '93.73%', 3: '98.82%'}

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[2], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2, 3}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1 2 3]
# num_classes = 4

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttention' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttention(input_size, hidden_size, output_size, num_layers).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1, 2, 3], device='cuda:0')
# y_train Min: 0, Max: 3
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1, 2, 3], device='cuda:0')
# y_val Min: 0, Max: 3
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 1.345557159, Train-Class-Acc: {0: '0.17%', 1: '99.61%', 2: '0.09%', 3: '0.14%'}, Val Loss: 1.095414100, Val Accuracy: 46.17%, Val-Class-Acc: {0: '0.00%', 1: '99.76%', 2: '0.00%', 3: '0.22%'}, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1.pth
#
#
# Unique target values: tensor([0, 1, 2, 3], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 3
# Unique classes in y_train: tensor([0, 1, 2, 3], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2, 3], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 3
# Unique classes in y_train: tensor([0, 1, 2, 3], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2, 3], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 3
# Unique classes in y_train: tensor([0, 1, 2, 3], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 1.224206815, Train-Class-Acc: {0: '0.00%', 1: '3.76%', 2: '0.00%', 3: '96.22%'}, Val Loss: 1.124143968, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.27%', 2: '0.00%', 3: '99.69%'}, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 1.222984248, Train-Class-Acc: {0: '0.00%', 1: '0.32%', 2: '0.00%', 3: '99.69%'}, Val Loss: 1.120164655, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.27%', 2: '0.00%', 3: '99.69%'}, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 1.223169359, Train-Class-Acc: {0: '0.00%', 1: '0.25%', 2: '0.00%', 3: '99.75%'}, Val Loss: 1.116855689, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.13%', 2: '0.00%', 3: '99.85%'}, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 1.222845225, Train-Class-Acc: {0: '0.00%', 1: '0.25%', 2: '0.00%', 3: '99.75%'}, Val Loss: 1.125156532, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.34%', 2: '0.00%', 3: '99.61%'}, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 1.222975055, Train-Class-Acc: {0: '0.00%', 1: '0.19%', 2: '0.00%', 3: '99.82%'}, Val Loss: 1.120425199, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.01%', 2: '0.00%', 3: '100.00%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_4.pth
# Model saved after epoch 6 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_6.pth
#
# Epoch 7/2000, Train Loss: 1.222780994, Train-Class-Acc: {0: '0.00%', 1: '0.19%', 2: '0.00%', 3: '99.82%'}, Val Loss: 1.116864651, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.07%', 2: '0.00%', 3: '99.92%'}, LR: 0.000100000
# Epoch 8/2000, Train Loss: 1.222619367, Train-Class-Acc: {0: '0.00%', 1: '0.16%', 2: '0.00%', 3: '99.84%'}, Val Loss: 1.112654904, Val Accuracy: 39.35%, Val-Class-Acc: {0: '0.00%', 1: '0.13%', 2: '0.00%', 3: '99.88%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_6.pth
# Model saved after epoch 8 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_8.pth
#
# Epoch 9/2000, Train Loss: 1.222578839, Train-Class-Acc: {0: '0.00%', 1: '0.15%', 2: '0.00%', 3: '99.87%'}, Val Loss: 1.123187387, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.13%', 2: '0.00%', 3: '99.85%'}, LR: 0.000100000
# Epoch 10/2000, Train Loss: 1.222463370, Train-Class-Acc: {0: '0.00%', 1: '0.17%', 2: '0.00%', 3: '99.85%'}, Val Loss: 1.114745451, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.27%', 2: '0.00%', 3: '99.69%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_3.pth
# Model saved after epoch 10 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_10.pth
#
# Epoch 11/2000, Train Loss: 1.222105872, Train-Class-Acc: {0: '0.00%', 1: '0.16%', 2: '0.00%', 3: '99.86%'}, Val Loss: 1.117585789, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.20%', 2: '0.00%', 3: '99.77%'}, LR: 0.000100000
# Epoch 12/2000, Train Loss: 1.221669936, Train-Class-Acc: {0: '0.00%', 1: '0.19%', 2: '0.00%', 3: '99.82%'}, Val Loss: 1.115004972, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.14%', 2: '0.00%', 3: '99.85%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_2.pth
# Model saved after epoch 12 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_12.pth
#
# Epoch 13/2000, Train Loss: 1.221054709, Train-Class-Acc: {0: '0.00%', 1: '0.24%', 2: '0.00%', 3: '99.79%'}, Val Loss: 1.123959758, Val Accuracy: 39.34%, Val-Class-Acc: {0: '0.00%', 1: '0.20%', 2: '0.00%', 3: '99.78%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_10.pth
# Model saved after epoch 13 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_13.pth
#
# Epoch 14/2000, Train Loss: 1.219717741, Train-Class-Acc: {0: '0.00%', 1: '5.07%', 2: '0.00%', 3: '97.47%'}, Val Loss: 1.116164899, Val Accuracy: 39.35%, Val-Class-Acc: {0: '0.00%', 1: '0.20%', 2: '0.00%', 3: '99.81%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_13.pth
# Model saved after epoch 14 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_14.pth
#
# Epoch 15/2000, Train Loss: 1.209649688, Train-Class-Acc: {0: '0.00%', 1: '12.16%', 2: '0.00%', 3: '97.58%'}, Val Loss: 1.086884329, Val Accuracy: 77.20%, Val-Class-Acc: {0: '0.00%', 1: '84.77%', 2: '0.00%', 3: '96.70%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_12.pth
# Model saved after epoch 15 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_15.pth
#
# Epoch 16/2000, Train Loss: 1.083277859, Train-Class-Acc: {0: '0.44%', 1: '65.28%', 2: '0.04%', 3: '71.25%'}, Val Loss: 0.926093555, Val Accuracy: 54.04%, Val-Class-Acc: {0: '3.51%', 1: '31.24%', 2: '0.00%', 3: '99.78%'}, LR: 0.000100000
# Removed old model with accuracy 39.34%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_5.pth
# Model saved after epoch 16 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_16.pth
#
# Epoch 17/2000, Train Loss: 0.850692552, Train-Class-Acc: {0: '15.45%', 1: '79.11%', 2: '16.72%', 3: '84.16%'}, Val Loss: 0.709017814, Val Accuracy: 72.45%, Val-Class-Acc: {0: '14.53%', 1: '67.57%', 2: '25.19%', 3: '98.35%'}, LR: 0.000100000
# Removed old model with accuracy 39.35%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_8.pth
# Model saved after epoch 17 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_17.pth
#
# Epoch 18/2000, Train Loss: 0.697840612, Train-Class-Acc: {0: '21.88%', 1: '84.17%', 2: '40.17%', 3: '89.32%'}, Val Loss: 0.546878714, Val Accuracy: 82.76%, Val-Class-Acc: {0: '13.95%', 1: '93.40%', 2: '38.83%', 3: '92.91%'}, LR: 0.000100000
# Removed old model with accuracy 39.35%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_14.pth
# Model saved after epoch 18 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_18.pth
#
# Epoch 19/2000, Train Loss: 0.616825788, Train-Class-Acc: {0: '23.97%', 1: '87.29%', 2: '47.33%', 3: '91.31%'}, Val Loss: 0.485767427, Val Accuracy: 84.23%, Val-Class-Acc: {0: '18.50%', 1: '94.01%', 2: '48.45%', 3: '93.71%'}, LR: 0.000100000
# Removed old model with accuracy 46.17%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1.pth
# Model saved after epoch 19 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_19.pth
#
# Epoch 20/2000, Train Loss: 0.537878596, Train-Class-Acc: {0: '28.45%', 1: '90.14%', 2: '55.50%', 3: '92.97%'}, Val Loss: 0.444599396, Val Accuracy: 84.89%, Val-Class-Acc: {0: '20.53%', 1: '94.18%', 2: '67.66%', 3: '92.62%'}, LR: 0.000100000
# Removed old model with accuracy 54.04%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_16.pth
# Model saved after epoch 20 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_20.pth
#
# Epoch 21/2000, Train Loss: 0.494323406, Train-Class-Acc: {0: '32.53%', 1: '90.75%', 2: '62.12%', 3: '92.78%'}, Val Loss: 0.406289845, Val Accuracy: 85.96%, Val-Class-Acc: {0: '21.26%', 1: '96.29%', 2: '70.53%', 3: '92.37%'}, LR: 0.000100000
# Removed old model with accuracy 72.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_17.pth
# Model saved after epoch 21 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_21.pth
#
# Epoch 22/2000, Train Loss: 0.461895138, Train-Class-Acc: {0: '34.90%', 1: '91.48%', 2: '67.10%', 3: '92.75%'}, Val Loss: 0.377555699, Val Accuracy: 86.60%, Val-Class-Acc: {0: '27.07%', 1: '93.72%', 2: '70.27%', 3: '95.51%'}, LR: 0.000100000
# Removed old model with accuracy 77.20%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_15.pth
# Model saved after epoch 22 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_22.pth
#
# Epoch 23/2000, Train Loss: 0.447776002, Train-Class-Acc: {0: '37.12%', 1: '91.38%', 2: '69.76%', 3: '92.28%'}, Val Loss: 0.492717053, Val Accuracy: 81.31%, Val-Class-Acc: {0: '18.21%', 1: '92.88%', 2: '88.18%', 3: '83.45%'}, LR: 0.000100000
# Epoch 24/2000, Train Loss: 0.434844644, Train-Class-Acc: {0: '37.44%', 1: '91.72%', 2: '72.91%', 3: '92.39%'}, Val Loss: 0.344159233, Val Accuracy: 87.63%, Val-Class-Acc: {0: '26.30%', 1: '95.25%', 2: '82.27%', 3: '95.27%'}, LR: 0.000100000
# Removed old model with accuracy 82.76%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_18.pth
# Model saved after epoch 24 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_24.pth
#
# Epoch 25/2000, Train Loss: 0.425597657, Train-Class-Acc: {0: '39.66%', 1: '91.57%', 2: '74.83%', 3: '92.01%'}, Val Loss: 0.349420398, Val Accuracy: 87.23%, Val-Class-Acc: {0: '29.70%', 1: '92.77%', 2: '79.12%', 3: '96.61%'}, LR: 0.000100000
# Removed old model with accuracy 84.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_19.pth
# Model saved after epoch 25 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_25.pth
#
# Epoch 26/2000, Train Loss: 0.388507033, Train-Class-Acc: {0: '41.42%', 1: '92.67%', 2: '79.30%', 3: '92.87%'}, Val Loss: 0.320537778, Val Accuracy: 88.27%, Val-Class-Acc: {0: '29.18%', 1: '95.54%', 2: '87.99%', 3: '95.18%'}, LR: 0.000100000
# Removed old model with accuracy 84.89%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_20.pth
# Model saved after epoch 26 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_26.pth
#
# Epoch 27/2000, Train Loss: 0.387242926, Train-Class-Acc: {0: '42.82%', 1: '92.31%', 2: '80.27%', 3: '92.60%'}, Val Loss: 0.326797243, Val Accuracy: 87.98%, Val-Class-Acc: {0: '33.54%', 1: '93.25%', 2: '81.56%', 3: '96.67%'}, LR: 0.000100000
# Removed old model with accuracy 85.96%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_21.pth
# Model saved after epoch 27 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_27.pth
#
# Epoch 28/2000, Train Loss: 0.380127387, Train-Class-Acc: {0: '44.10%', 1: '92.42%', 2: '80.40%', 3: '92.61%'}, Val Loss: 0.351313761, Val Accuracy: 87.13%, Val-Class-Acc: {0: '40.95%', 1: '90.34%', 2: '78.23%', 3: '96.35%'}, LR: 0.000100000
# Removed old model with accuracy 86.60%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_22.pth
# Model saved after epoch 28 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_28.pth
#
# Epoch 29/2000, Train Loss: 0.360643609, Train-Class-Acc: {0: '45.69%', 1: '92.91%', 2: '82.72%', 3: '92.97%'}, Val Loss: 0.298463259, Val Accuracy: 88.93%, Val-Class-Acc: {0: '35.19%', 1: '94.77%', 2: '87.90%', 3: '96.19%'}, LR: 0.000100000
# Removed old model with accuracy 87.13%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_28.pth
# Model saved after epoch 29 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_29.pth
#
# Epoch 30/2000, Train Loss: 0.343142560, Train-Class-Acc: {0: '47.01%', 1: '93.51%', 2: '84.11%', 3: '93.37%'}, Val Loss: 0.299729227, Val Accuracy: 88.46%, Val-Class-Acc: {0: '33.31%', 1: '96.15%', 2: '92.77%', 3: '93.36%'}, LR: 0.000100000
# Removed old model with accuracy 87.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_25.pth
# Model saved after epoch 30 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_30.pth
#
# Epoch 31/2000, Train Loss: 0.339598605, Train-Class-Acc: {0: '48.29%', 1: '93.54%', 2: '84.39%', 3: '93.21%'}, Val Loss: 0.282932694, Val Accuracy: 89.54%, Val-Class-Acc: {0: '41.78%', 1: '94.96%', 2: '86.99%', 3: '95.92%'}, LR: 0.000100000
# Removed old model with accuracy 87.63%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_24.pth
# Model saved after epoch 31 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_31.pth
#
# Epoch 32/2000, Train Loss: 0.343975250, Train-Class-Acc: {0: '49.62%', 1: '93.26%', 2: '84.01%', 3: '92.85%'}, Val Loss: 0.274887066, Val Accuracy: 89.23%, Val-Class-Acc: {0: '36.52%', 1: '95.86%', 2: '92.61%', 3: '94.83%'}, LR: 0.000100000
# Removed old model with accuracy 87.98%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_27.pth
# Model saved after epoch 32 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_32.pth
#
# Epoch 33/2000, Train Loss: 0.323109485, Train-Class-Acc: {0: '50.19%', 1: '93.91%', 2: '85.73%', 3: '93.57%'}, Val Loss: 0.274542640, Val Accuracy: 89.95%, Val-Class-Acc: {0: '45.26%', 1: '94.94%', 2: '82.44%', 3: '96.55%'}, LR: 0.000100000
# Removed old model with accuracy 88.27%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_26.pth
# Model saved after epoch 33 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_33.pth
#
# Epoch 34/2000, Train Loss: 0.333475994, Train-Class-Acc: {0: '51.51%', 1: '93.42%', 2: '85.04%', 3: '93.12%'}, Val Loss: 0.291301161, Val Accuracy: 89.47%, Val-Class-Acc: {0: '46.09%', 1: '93.69%', 2: '78.80%', 3: '96.96%'}, LR: 0.000100000
# Removed old model with accuracy 88.46%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_30.pth
# Model saved after epoch 34 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_34.pth
#
# Epoch 35/2000, Train Loss: 0.315585098, Train-Class-Acc: {0: '52.67%', 1: '93.97%', 2: '86.05%', 3: '93.57%'}, Val Loss: 0.287144755, Val Accuracy: 89.57%, Val-Class-Acc: {0: '48.04%', 1: '93.70%', 2: '77.86%', 3: '96.79%'}, LR: 0.000100000
# Removed old model with accuracy 88.93%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_29.pth
# Model saved after epoch 35 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_35.pth
#
# Epoch 36/2000, Train Loss: 0.289213915, Train-Class-Acc: {0: '54.53%', 1: '94.84%', 2: '87.33%', 3: '94.13%'}, Val Loss: 0.258047064, Val Accuracy: 89.68%, Val-Class-Acc: {0: '39.04%', 1: '96.31%', 2: '93.88%', 3: '94.65%'}, LR: 0.000100000
# Removed old model with accuracy 89.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_32.pth
# Model saved after epoch 36 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_36.pth
#
# Epoch 37/2000, Train Loss: 0.288807032, Train-Class-Acc: {0: '55.87%', 1: '94.61%', 2: '87.74%', 3: '94.06%'}, Val Loss: 0.236679826, Val Accuracy: 90.73%, Val-Class-Acc: {0: '45.74%', 1: '96.46%', 2: '93.51%', 3: '95.45%'}, LR: 0.000100000
# Removed old model with accuracy 89.47%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_34.pth
# Model saved after epoch 37 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_37.pth
#
# Epoch 38/2000, Train Loss: 0.271975706, Train-Class-Acc: {0: '57.93%', 1: '95.08%', 2: '88.41%', 3: '94.39%'}, Val Loss: 0.257403790, Val Accuracy: 89.78%, Val-Class-Acc: {0: '44.13%', 1: '95.71%', 2: '95.34%', 3: '94.12%'}, LR: 0.000100000
# Removed old model with accuracy 89.54%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_31.pth
# Model saved after epoch 38 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_38.pth
#
# Epoch 39/2000, Train Loss: 0.274771791, Train-Class-Acc: {0: '59.36%', 1: '94.76%', 2: '88.17%', 3: '94.20%'}, Val Loss: 0.238035700, Val Accuracy: 91.18%, Val-Class-Acc: {0: '56.42%', 1: '94.88%', 2: '85.05%', 3: '96.56%'}, LR: 0.000100000
# Removed old model with accuracy 89.57%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_35.pth
# Model saved after epoch 39 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_39.pth
#
# Epoch 40/2000, Train Loss: 0.270003807, Train-Class-Acc: {0: '60.49%', 1: '94.76%', 2: '88.60%', 3: '94.30%'}, Val Loss: 0.272105929, Val Accuracy: 89.13%, Val-Class-Acc: {0: '43.26%', 1: '95.76%', 2: '98.07%', 3: '92.36%'}, LR: 0.000100000
# Epoch 41/2000, Train Loss: 0.264937079, Train-Class-Acc: {0: '61.41%', 1: '94.79%', 2: '88.84%', 3: '94.37%'}, Val Loss: 0.212070322, Val Accuracy: 92.03%, Val-Class-Acc: {0: '58.89%', 1: '95.87%', 2: '92.79%', 3: '96.08%'}, LR: 0.000100000
# Removed old model with accuracy 89.68%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_36.pth
# Model saved after epoch 41 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_41.pth
#
# Epoch 42/2000, Train Loss: 0.268739599, Train-Class-Acc: {0: '62.55%', 1: '94.39%', 2: '88.47%', 3: '94.13%'}, Val Loss: 0.244061281, Val Accuracy: 90.28%, Val-Class-Acc: {0: '47.94%', 1: '95.75%', 2: '97.39%', 3: '94.13%'}, LR: 0.000100000
# Removed old model with accuracy 89.78%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_38.pth
# Model saved after epoch 42 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_42.pth
#
# Epoch 43/2000, Train Loss: 0.258928505, Train-Class-Acc: {0: '63.52%', 1: '94.77%', 2: '88.90%', 3: '94.35%'}, Val Loss: 0.288461312, Val Accuracy: 88.70%, Val-Class-Acc: {0: '44.89%', 1: '95.03%', 2: '99.34%', 3: '91.54%'}, LR: 0.000100000
# Epoch 44/2000, Train Loss: 0.246609256, Train-Class-Acc: {0: '65.61%', 1: '94.99%', 2: '90.40%', 3: '94.60%'}, Val Loss: 0.263594073, Val Accuracy: 89.67%, Val-Class-Acc: {0: '59.73%', 1: '91.39%', 2: '75.76%', 3: '96.96%'}, LR: 0.000100000
# Epoch 45/2000, Train Loss: 0.260388748, Train-Class-Acc: {0: '64.84%', 1: '94.45%', 2: '89.28%', 3: '94.10%'}, Val Loss: 0.209527975, Val Accuracy: 92.21%, Val-Class-Acc: {0: '64.96%', 1: '95.13%', 2: '89.76%', 3: '96.16%'}, LR: 0.000100000
# Removed old model with accuracy 89.95%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_33.pth
# Model saved after epoch 45 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_45.pth
#
# Epoch 46/2000, Train Loss: 0.233815086, Train-Class-Acc: {0: '67.47%', 1: '95.19%', 2: '90.01%', 3: '94.97%'}, Val Loss: 0.208006615, Val Accuracy: 92.23%, Val-Class-Acc: {0: '68.31%', 1: '94.75%', 2: '86.70%', 3: '96.11%'}, LR: 0.000100000
# Removed old model with accuracy 90.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_42.pth
# Model saved after epoch 46 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_46.pth
#
# Epoch 47/2000, Train Loss: 0.231140243, Train-Class-Acc: {0: '68.74%', 1: '95.14%', 2: '90.30%', 3: '94.71%'}, Val Loss: 0.191622972, Val Accuracy: 92.71%, Val-Class-Acc: {0: '63.92%', 1: '96.37%', 2: '96.13%', 3: '95.56%'}, LR: 0.000100000
# Removed old model with accuracy 90.73%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_37.pth
# Model saved after epoch 47 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_47.pth
#
# Epoch 48/2000, Train Loss: 0.225921916, Train-Class-Acc: {0: '69.38%', 1: '95.18%', 2: '90.59%', 3: '94.92%'}, Val Loss: 0.200966324, Val Accuracy: 92.32%, Val-Class-Acc: {0: '63.51%', 1: '95.86%', 2: '98.50%', 3: '95.02%'}, LR: 0.000100000
# Removed old model with accuracy 91.18%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_39.pth
# Model saved after epoch 48 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_48.pth
#
# Epoch 49/2000, Train Loss: 0.229871442, Train-Class-Acc: {0: '70.00%', 1: '94.90%', 2: '90.61%', 3: '94.61%'}, Val Loss: 0.183641123, Val Accuracy: 93.03%, Val-Class-Acc: {0: '66.44%', 1: '96.54%', 2: '96.04%', 3: '95.52%'}, LR: 0.000100000
# Removed old model with accuracy 92.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_41.pth
# Model saved after epoch 49 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_49.pth
#
# Epoch 50/2000, Train Loss: 0.233397627, Train-Class-Acc: {0: '69.72%', 1: '94.68%', 2: '89.99%', 3: '94.56%'}, Val Loss: 0.183225908, Val Accuracy: 93.01%, Val-Class-Acc: {0: '71.41%', 1: '95.57%', 2: '93.98%', 3: '95.52%'}, LR: 0.000100000
# Removed old model with accuracy 92.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_45.pth
# Model saved after epoch 50 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_50.pth
#
# Epoch 51/2000, Train Loss: 0.225536108, Train-Class-Acc: {0: '71.24%', 1: '94.85%', 2: '91.08%', 3: '94.57%'}, Val Loss: 0.172906316, Val Accuracy: 93.75%, Val-Class-Acc: {0: '69.71%', 1: '96.53%', 2: '92.30%', 3: '96.92%'}, LR: 0.000100000
# Removed old model with accuracy 92.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_46.pth
# Model saved after epoch 51 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_51.pth
#
# Epoch 52/2000, Train Loss: 0.215810923, Train-Class-Acc: {0: '71.94%', 1: '95.20%', 2: '90.79%', 3: '94.94%'}, Val Loss: 0.175998097, Val Accuracy: 93.36%, Val-Class-Acc: {0: '74.22%', 1: '95.92%', 2: '96.65%', 3: '95.00%'}, LR: 0.000100000
# Removed old model with accuracy 92.32%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_48.pth
# Model saved after epoch 52 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_52.pth
#
# Epoch 53/2000, Train Loss: 0.224700721, Train-Class-Acc: {0: '71.74%', 1: '94.68%', 2: '90.78%', 3: '94.56%'}, Val Loss: 0.175279841, Val Accuracy: 93.27%, Val-Class-Acc: {0: '73.62%', 1: '95.61%', 2: '95.95%', 3: '95.36%'}, LR: 0.000100000
# Removed old model with accuracy 92.71%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_47.pth
# Model saved after epoch 53 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_53.pth
#
# Epoch 54/2000, Train Loss: 0.208485675, Train-Class-Acc: {0: '73.33%', 1: '95.20%', 2: '91.49%', 3: '95.07%'}, Val Loss: 0.180403810, Val Accuracy: 93.10%, Val-Class-Acc: {0: '72.94%', 1: '94.76%', 2: '93.42%', 3: '96.38%'}, LR: 0.000100000
# Removed old model with accuracy 93.01%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_50.pth
# Model saved after epoch 54 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_54.pth
#
# Epoch 55/2000, Train Loss: 0.220691982, Train-Class-Acc: {0: '72.82%', 1: '94.65%', 2: '91.09%', 3: '94.65%'}, Val Loss: 0.293127030, Val Accuracy: 88.49%, Val-Class-Acc: {0: '52.77%', 1: '94.29%', 2: '99.50%', 3: '89.83%'}, LR: 0.000100000
# Epoch 56/2000, Train Loss: 0.216806980, Train-Class-Acc: {0: '73.16%', 1: '94.88%', 2: '90.90%', 3: '94.69%'}, Val Loss: 0.179051255, Val Accuracy: 93.08%, Val-Class-Acc: {0: '74.39%', 1: '94.55%', 2: '94.30%', 3: '96.10%'}, LR: 0.000100000
# Removed old model with accuracy 93.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_49.pth
# Model saved after epoch 56 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_56.pth
#
# Epoch 57/2000, Train Loss: 0.207705557, Train-Class-Acc: {0: '74.16%', 1: '94.93%', 2: '91.79%', 3: '94.99%'}, Val Loss: 0.179709368, Val Accuracy: 92.98%, Val-Class-Acc: {0: '74.54%', 1: '94.54%', 2: '90.21%', 3: '96.26%'}, LR: 0.000100000
# Epoch 58/2000, Train Loss: 0.208943388, Train-Class-Acc: {0: '74.23%', 1: '95.03%', 2: '91.47%', 3: '94.88%'}, Val Loss: 0.168330438, Val Accuracy: 93.75%, Val-Class-Acc: {0: '75.77%', 1: '95.17%', 2: '92.66%', 3: '96.90%'}, LR: 0.000100000
# Removed old model with accuracy 93.08%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_56.pth
# Model saved after epoch 58 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_58.pth
#
# Epoch 59/2000, Train Loss: 0.213213326, Train-Class-Acc: {0: '73.61%', 1: '94.75%', 2: '90.98%', 3: '94.76%'}, Val Loss: 0.176299367, Val Accuracy: 93.35%, Val-Class-Acc: {0: '74.74%', 1: '95.72%', 2: '98.64%', 3: '94.85%'}, LR: 0.000100000
# Removed old model with accuracy 93.10%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_54.pth
# Model saved after epoch 59 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_59.pth
#
# Epoch 60/2000, Train Loss: 0.193338026, Train-Class-Acc: {0: '76.25%', 1: '95.43%', 2: '92.66%', 3: '95.32%'}, Val Loss: 0.161234787, Val Accuracy: 93.77%, Val-Class-Acc: {0: '72.59%', 1: '96.03%', 2: '97.69%', 3: '96.23%'}, LR: 0.000100000
# Removed old model with accuracy 93.27%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_53.pth
# Model saved after epoch 60 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_60.pth
#
# Epoch 61/2000, Train Loss: 0.197515863, Train-Class-Acc: {0: '75.61%', 1: '95.23%', 2: '92.44%', 3: '95.26%'}, Val Loss: 0.156146751, Val Accuracy: 94.28%, Val-Class-Acc: {0: '76.90%', 1: '96.21%', 2: '94.44%', 3: '96.53%'}, LR: 0.000100000
# Removed old model with accuracy 93.35%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_59.pth
# Model saved after epoch 61 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_61.pth
#
# Epoch 62/2000, Train Loss: 0.194637165, Train-Class-Acc: {0: '75.93%', 1: '95.31%', 2: '92.48%', 3: '95.28%'}, Val Loss: 0.170236530, Val Accuracy: 93.38%, Val-Class-Acc: {0: '77.39%', 1: '94.80%', 2: '89.47%', 3: '96.30%'}, LR: 0.000100000
# Removed old model with accuracy 93.36%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_52.pth
# Model saved after epoch 62 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_62.pth
#
# Epoch 63/2000, Train Loss: 0.201241234, Train-Class-Acc: {0: '75.93%', 1: '95.04%', 2: '91.89%', 3: '94.96%'}, Val Loss: 0.154337130, Val Accuracy: 94.28%, Val-Class-Acc: {0: '77.46%', 1: '96.11%', 2: '95.17%', 3: '96.43%'}, LR: 0.000100000
# Removed old model with accuracy 93.38%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_62.pth
# Model saved after epoch 63 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_63.pth
#
# Epoch 64/2000, Train Loss: 0.194095543, Train-Class-Acc: {0: '76.38%', 1: '95.26%', 2: '92.43%', 3: '95.23%'}, Val Loss: 0.183627604, Val Accuracy: 92.50%, Val-Class-Acc: {0: '75.69%', 1: '93.24%', 2: '85.30%', 3: '96.78%'}, LR: 0.000100000
# Epoch 65/2000, Train Loss: 0.201571015, Train-Class-Acc: {0: '76.11%', 1: '94.91%', 2: '91.96%', 3: '95.04%'}, Val Loss: 0.160752799, Val Accuracy: 94.06%, Val-Class-Acc: {0: '77.88%', 1: '95.02%', 2: '94.44%', 3: '97.11%'}, LR: 0.000100000
# Removed old model with accuracy 93.75%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_51.pth
# Model saved after epoch 65 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_65.pth
#
# Epoch 66/2000, Train Loss: 0.185521352, Train-Class-Acc: {0: '77.68%', 1: '95.44%', 2: '92.78%', 3: '95.55%'}, Val Loss: 0.163109752, Val Accuracy: 93.65%, Val-Class-Acc: {0: '71.50%', 1: '96.82%', 2: '98.23%', 3: '95.21%'}, LR: 0.000100000
# Epoch 67/2000, Train Loss: 0.213627955, Train-Class-Acc: {0: '75.16%', 1: '94.70%', 2: '91.15%', 3: '94.61%'}, Val Loss: 0.155258722, Val Accuracy: 94.11%, Val-Class-Acc: {0: '78.07%', 1: '95.52%', 2: '95.51%', 3: '96.50%'}, LR: 0.000100000
# Removed old model with accuracy 93.75%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_58.pth
# Model saved after epoch 67 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_67.pth
#
# Epoch 68/2000, Train Loss: 0.188977713, Train-Class-Acc: {0: '77.19%', 1: '95.29%', 2: '92.53%', 3: '95.39%'}, Val Loss: 0.158686049, Val Accuracy: 94.03%, Val-Class-Acc: {0: '77.14%', 1: '94.91%', 2: '94.35%', 3: '97.36%'}, LR: 0.000100000
# Removed old model with accuracy 93.77%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_60.pth
# Model saved after epoch 68 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_68.pth
#
# Epoch 69/2000, Train Loss: 0.183843573, Train-Class-Acc: {0: '77.99%', 1: '95.54%', 2: '93.04%', 3: '95.55%'}, Val Loss: 0.174497807, Val Accuracy: 93.28%, Val-Class-Acc: {0: '73.61%', 1: '96.07%', 2: '98.81%', 3: '94.53%'}, LR: 0.000100000
# Epoch 70/2000, Train Loss: 0.190298079, Train-Class-Acc: {0: '77.37%', 1: '95.27%', 2: '92.84%', 3: '95.27%'}, Val Loss: 0.217721964, Val Accuracy: 90.99%, Val-Class-Acc: {0: '74.04%', 1: '90.67%', 2: '78.79%', 3: '97.09%'}, LR: 0.000100000
# Epoch 71/2000, Train Loss: 0.191322892, Train-Class-Acc: {0: '77.38%', 1: '95.19%', 2: '92.52%', 3: '95.30%'}, Val Loss: 0.151745101, Val Accuracy: 94.16%, Val-Class-Acc: {0: '77.18%', 1: '96.02%', 2: '98.23%', 3: '95.97%'}, LR: 0.000100000
# Removed old model with accuracy 94.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_68.pth
# Model saved after epoch 71 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_71.pth
#
# Epoch 72/2000, Train Loss: 0.189373538, Train-Class-Acc: {0: '77.62%', 1: '95.26%', 2: '92.66%', 3: '95.32%'}, Val Loss: 0.148592048, Val Accuracy: 94.29%, Val-Class-Acc: {0: '76.73%', 1: '96.06%', 2: '98.29%', 3: '96.37%'}, LR: 0.000100000
# Removed old model with accuracy 94.06%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_65.pth
# Model saved after epoch 72 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_72.pth
#
# Epoch 73/2000, Train Loss: 0.211909422, Train-Class-Acc: {0: '75.78%', 1: '94.61%', 2: '91.52%', 3: '94.56%'}, Val Loss: 0.155751835, Val Accuracy: 93.93%, Val-Class-Acc: {0: '74.71%', 1: '95.88%', 2: '98.52%', 3: '96.17%'}, LR: 0.000100000
# Epoch 74/2000, Train Loss: 0.182092600, Train-Class-Acc: {0: '78.40%', 1: '95.50%', 2: '93.19%', 3: '95.57%'}, Val Loss: 0.145878774, Val Accuracy: 94.46%, Val-Class-Acc: {0: '78.49%', 1: '95.76%', 2: '97.90%', 3: '96.74%'}, LR: 0.000100000
# Removed old model with accuracy 94.11%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_67.pth
# Model saved after epoch 74 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_74.pth
#
# Epoch 75/2000, Train Loss: 0.193232806, Train-Class-Acc: {0: '77.44%', 1: '95.17%', 2: '92.74%', 3: '95.15%'}, Val Loss: 0.160831340, Val Accuracy: 93.74%, Val-Class-Acc: {0: '79.56%', 1: '94.68%', 2: '92.89%', 3: '96.43%'}, LR: 0.000100000
# Epoch 76/2000, Train Loss: 0.182810503, Train-Class-Acc: {0: '78.31%', 1: '95.48%', 2: '93.14%', 3: '95.49%'}, Val Loss: 0.152123624, Val Accuracy: 94.10%, Val-Class-Acc: {0: '76.09%', 1: '96.43%', 2: '98.41%', 3: '95.61%'}, LR: 0.000100000
# Epoch 77/2000, Train Loss: 0.174566413, Train-Class-Acc: {0: '79.46%', 1: '95.80%', 2: '93.68%', 3: '95.75%'}, Val Loss: 0.146229999, Val Accuracy: 94.53%, Val-Class-Acc: {0: '79.63%', 1: '95.70%', 2: '96.92%', 3: '96.80%'}, LR: 0.000100000
# Removed old model with accuracy 94.16%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_71.pth
# Model saved after epoch 77 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_77.pth
#
# Epoch 78/2000, Train Loss: 0.191718478, Train-Class-Acc: {0: '77.99%', 1: '95.08%', 2: '92.49%', 3: '95.22%'}, Val Loss: 0.221839138, Val Accuracy: 91.30%, Val-Class-Acc: {0: '62.71%', 1: '96.34%', 2: '99.26%', 3: '91.99%'}, LR: 0.000100000
# Epoch 79/2000, Train Loss: 0.184660338, Train-Class-Acc: {0: '78.18%', 1: '95.43%', 2: '93.00%', 3: '95.37%'}, Val Loss: 0.156175136, Val Accuracy: 94.07%, Val-Class-Acc: {0: '80.13%', 1: '94.47%', 2: '94.09%', 3: '97.23%'}, LR: 0.000100000
# Epoch 80/2000, Train Loss: 0.175641124, Train-Class-Acc: {0: '79.52%', 1: '95.67%', 2: '93.50%', 3: '95.70%'}, Val Loss: 0.177694099, Val Accuracy: 92.98%, Val-Class-Acc: {0: '70.63%', 1: '96.42%', 2: '98.89%', 3: '94.15%'}, LR: 0.000100000
# Epoch 81/2000, Train Loss: 0.184756619, Train-Class-Acc: {0: '78.46%', 1: '95.40%', 2: '93.01%', 3: '95.41%'}, Val Loss: 0.141472898, Val Accuracy: 94.79%, Val-Class-Acc: {0: '80.07%', 1: '96.21%', 2: '97.53%', 3: '96.65%'}, LR: 0.000100000
# Removed old model with accuracy 94.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_61.pth
# Model saved after epoch 81 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_81.pth
#
# Epoch 82/2000, Train Loss: 0.173028412, Train-Class-Acc: {0: '80.04%', 1: '95.70%', 2: '93.70%', 3: '95.77%'}, Val Loss: 0.179818571, Val Accuracy: 92.76%, Val-Class-Acc: {0: '66.92%', 1: '97.20%', 2: '98.49%', 3: '93.67%'}, LR: 0.000100000
# Epoch 83/2000, Train Loss: 0.174429158, Train-Class-Acc: {0: '79.81%', 1: '95.73%', 2: '93.43%', 3: '95.68%'}, Val Loss: 0.166603929, Val Accuracy: 93.37%, Val-Class-Acc: {0: '71.35%', 1: '96.26%', 2: '98.84%', 3: '95.13%'}, LR: 0.000100000
# Epoch 84/2000, Train Loss: 0.173539962, Train-Class-Acc: {0: '79.77%', 1: '95.65%', 2: '93.77%', 3: '95.64%'}, Val Loss: 0.142962899, Val Accuracy: 94.83%, Val-Class-Acc: {0: '79.37%', 1: '95.52%', 2: '93.91%', 3: '98.15%'}, LR: 0.000100000
# Removed old model with accuracy 94.28%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_63.pth
# Model saved after epoch 84 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_84.pth
#
# Epoch 85/2000, Train Loss: 0.170747984, Train-Class-Acc: {0: '80.21%', 1: '95.79%', 2: '93.48%', 3: '95.84%'}, Val Loss: 0.137689030, Val Accuracy: 94.95%, Val-Class-Acc: {0: '79.21%', 1: '95.98%', 2: '97.39%', 3: '97.57%'}, LR: 0.000100000
# Removed old model with accuracy 94.29%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_72.pth
# Model saved after epoch 85 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_85.pth
#
# Epoch 86/2000, Train Loss: 0.176133010, Train-Class-Acc: {0: '80.02%', 1: '95.53%', 2: '93.66%', 3: '95.61%'}, Val Loss: 0.137622535, Val Accuracy: 94.94%, Val-Class-Acc: {0: '80.39%', 1: '96.24%', 2: '94.55%', 3: '97.24%'}, LR: 0.000100000
# Removed old model with accuracy 94.46%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_74.pth
# Model saved after epoch 86 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_86.pth
#
# Epoch 87/2000, Train Loss: 0.174800880, Train-Class-Acc: {0: '79.96%', 1: '95.72%', 2: '93.60%', 3: '95.65%'}, Val Loss: 0.140200884, Val Accuracy: 94.87%, Val-Class-Acc: {0: '81.27%', 1: '95.75%', 2: '95.14%', 3: '97.35%'}, LR: 0.000100000
# Removed old model with accuracy 94.53%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_77.pth
# Model saved after epoch 87 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_87.pth
#
# Epoch 88/2000, Train Loss: 0.172632177, Train-Class-Acc: {0: '80.16%', 1: '95.65%', 2: '93.65%', 3: '95.76%'}, Val Loss: 0.153743338, Val Accuracy: 93.95%, Val-Class-Acc: {0: '75.24%', 1: '96.66%', 2: '98.61%', 3: '95.16%'}, LR: 0.000100000
# Epoch 89/2000, Train Loss: 0.179712919, Train-Class-Acc: {0: '79.69%', 1: '95.49%', 2: '93.15%', 3: '95.52%'}, Val Loss: 0.139006289, Val Accuracy: 94.73%, Val-Class-Acc: {0: '78.82%', 1: '96.55%', 2: '98.41%', 3: '96.33%'}, LR: 0.000100000
# Epoch 90/2000, Train Loss: 0.185085119, Train-Class-Acc: {0: '78.81%', 1: '95.33%', 2: '93.15%', 3: '95.37%'}, Val Loss: 0.263551936, Val Accuracy: 89.62%, Val-Class-Acc: {0: '71.36%', 1: '88.14%', 2: '73.94%', 3: '97.79%'}, LR: 0.000100000
# Epoch 91/2000, Train Loss: 0.178310095, Train-Class-Acc: {0: '79.72%', 1: '95.49%', 2: '93.23%', 3: '95.49%'}, Val Loss: 0.153576499, Val Accuracy: 94.08%, Val-Class-Acc: {0: '73.68%', 1: '97.40%', 2: '98.36%', 3: '95.05%'}, LR: 0.000100000
# Epoch 92/2000, Train Loss: 0.183627178, Train-Class-Acc: {0: '78.98%', 1: '95.38%', 2: '92.95%', 3: '95.34%'}, Val Loss: 0.138405907, Val Accuracy: 94.77%, Val-Class-Acc: {0: '78.51%', 1: '96.36%', 2: '98.57%', 3: '96.75%'}, LR: 0.000100000
# Epoch 93/2000, Train Loss: 0.170302904, Train-Class-Acc: {0: '80.52%', 1: '95.68%', 2: '93.79%', 3: '95.78%'}, Val Loss: 0.148140293, Val Accuracy: 94.27%, Val-Class-Acc: {0: '76.61%', 1: '96.43%', 2: '98.68%', 3: '95.88%'}, LR: 0.000100000
# Epoch 94/2000, Train Loss: 0.163617851, Train-Class-Acc: {0: '81.07%', 1: '96.02%', 2: '94.00%', 3: '96.03%'}, Val Loss: 0.146774210, Val Accuracy: 94.20%, Val-Class-Acc: {0: '77.35%', 1: '96.17%', 2: '98.87%', 3: '95.78%'}, LR: 0.000100000
# Epoch 95/2000, Train Loss: 0.162670585, Train-Class-Acc: {0: '81.35%', 1: '96.00%', 2: '94.30%', 3: '95.96%'}, Val Loss: 0.133271069, Val Accuracy: 95.21%, Val-Class-Acc: {0: '81.31%', 1: '96.11%', 2: '98.23%', 3: '97.45%'}, LR: 0.000100000
# Removed old model with accuracy 94.79%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_81.pth
# Model saved after epoch 95 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_95.pth
#
# Epoch 96/2000, Train Loss: 0.161617531, Train-Class-Acc: {0: '81.47%', 1: '96.05%', 2: '94.31%', 3: '96.00%'}, Val Loss: 0.142866243, Val Accuracy: 94.73%, Val-Class-Acc: {0: '80.81%', 1: '95.06%', 2: '94.80%', 3: '97.96%'}, LR: 0.000100000
# Epoch 97/2000, Train Loss: 0.175865704, Train-Class-Acc: {0: '80.16%', 1: '95.55%', 2: '93.40%', 3: '95.53%'}, Val Loss: 0.138120503, Val Accuracy: 95.04%, Val-Class-Acc: {0: '81.29%', 1: '95.67%', 2: '93.67%', 3: '98.05%'}, LR: 0.000100000
# Removed old model with accuracy 94.83%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_84.pth
# Model saved after epoch 97 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_97.pth
#
# Epoch 98/2000, Train Loss: 0.167538556, Train-Class-Acc: {0: '80.80%', 1: '95.89%', 2: '93.91%', 3: '95.83%'}, Val Loss: 0.128576883, Val Accuracy: 95.40%, Val-Class-Acc: {0: '80.63%', 1: '97.00%', 2: '97.86%', 3: '97.11%'}, LR: 0.000100000
# Removed old model with accuracy 94.87%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_87.pth
# Model saved after epoch 98 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_98.pth
#
# Epoch 99/2000, Train Loss: 0.162851380, Train-Class-Acc: {0: '81.22%', 1: '96.09%', 2: '94.29%', 3: '95.86%'}, Val Loss: 0.135044375, Val Accuracy: 95.23%, Val-Class-Acc: {0: '81.40%', 1: '95.58%', 2: '96.95%', 3: '98.23%'}, LR: 0.000100000
# Removed old model with accuracy 94.94%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_86.pth
# Model saved after epoch 99 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_99.pth
#
# Epoch 100/2000, Train Loss: 0.161513847, Train-Class-Acc: {0: '81.69%', 1: '95.99%', 2: '94.44%', 3: '95.98%'}, Val Loss: 0.133973200, Val Accuracy: 95.10%, Val-Class-Acc: {0: '79.98%', 1: '96.80%', 2: '98.29%', 3: '96.71%'}, LR: 0.000100000
# Removed old model with accuracy 94.95%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_85.pth
# Model saved after epoch 100 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_100.pth
#
# ...
# Epoch 1950/2000, Train Loss: 0.003471526, Train-Class-Acc: {0: '99.81%', 1: '99.90%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.143366089, Val Accuracy: 97.66%, Val-Class-Acc: {0: '90.53%', 1: '98.72%', 2: '92.46%', 3: '98.84%'}, LR: 0.000100000
# Epoch 1951/2000, Train Loss: 0.003453347, Train-Class-Acc: {0: '99.81%', 1: '99.90%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.146863376, Val Accuracy: 97.59%, Val-Class-Acc: {0: '89.70%', 1: '98.65%', 2: '91.95%', 3: '99.01%'}, LR: 0.000100000
# Epoch 1952/2000, Train Loss: 0.003810895, Train-Class-Acc: {0: '99.77%', 1: '99.88%', 2: '99.99%', 3: '99.90%'}, Val Loss: 0.151926869, Val Accuracy: 97.42%, Val-Class-Acc: {0: '90.83%', 1: '98.24%', 2: '90.12%', 3: '98.97%'}, LR: 0.000100000
# Epoch 1953/2000, Train Loss: 0.109521883, Train-Class-Acc: {0: '95.74%', 1: '98.48%', 2: '97.98%', 3: '98.36%'}, Val Loss: 0.177032804, Val Accuracy: 96.89%, Val-Class-Acc: {0: '86.05%', 1: '98.15%', 2: '93.69%', 3: '98.57%'}, LR: 0.000100000
# Epoch 1954/2000, Train Loss: 0.005094122, Train-Class-Acc: {0: '99.66%', 1: '99.87%', 2: '99.96%', 3: '99.88%'}, Val Loss: 0.144421127, Val Accuracy: 97.17%, Val-Class-Acc: {0: '88.72%', 1: '98.27%', 2: '91.41%', 3: '98.69%'}, LR: 0.000100000
# Epoch 1955/2000, Train Loss: 0.003785554, Train-Class-Acc: {0: '99.81%', 1: '99.91%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.145382528, Val Accuracy: 97.15%, Val-Class-Acc: {0: '88.24%', 1: '98.27%', 2: '91.52%', 3: '98.76%'}, LR: 0.000100000
# Epoch 1956/2000, Train Loss: 0.003618031, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.144842266, Val Accuracy: 97.25%, Val-Class-Acc: {0: '88.24%', 1: '98.46%', 2: '92.11%', 3: '98.73%'}, LR: 0.000100000
# Epoch 1957/2000, Train Loss: 0.003517673, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.144931788, Val Accuracy: 97.27%, Val-Class-Acc: {0: '88.13%', 1: '98.49%', 2: '92.04%', 3: '98.78%'}, LR: 0.000100000
# Epoch 1958/2000, Train Loss: 0.003510794, Train-Class-Acc: {0: '99.82%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.147465253, Val Accuracy: 97.19%, Val-Class-Acc: {0: '89.13%', 1: '98.17%', 2: '90.60%', 3: '98.85%'}, LR: 0.000100000
# Epoch 1959/2000, Train Loss: 0.003522712, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.143710257, Val Accuracy: 97.32%, Val-Class-Acc: {0: '89.04%', 1: '98.42%', 2: '91.69%', 3: '98.79%'}, LR: 0.000100000
# Epoch 1960/2000, Train Loss: 0.003418389, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.142405589, Val Accuracy: 97.33%, Val-Class-Acc: {0: '89.27%', 1: '98.40%', 2: '91.86%', 3: '98.75%'}, LR: 0.000100000
# Epoch 1961/2000, Train Loss: 0.003403088, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.143430820, Val Accuracy: 97.40%, Val-Class-Acc: {0: '89.16%', 1: '98.51%', 2: '91.57%', 3: '98.88%'}, LR: 0.000100000
# Epoch 1962/2000, Train Loss: 0.003373187, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.143718431, Val Accuracy: 97.38%, Val-Class-Acc: {0: '89.55%', 1: '98.41%', 2: '91.18%', 3: '98.86%'}, LR: 0.000100000
# Epoch 1963/2000, Train Loss: 0.003376512, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.144456030, Val Accuracy: 97.38%, Val-Class-Acc: {0: '89.17%', 1: '98.45%', 2: '91.26%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1964/2000, Train Loss: 0.003568207, Train-Class-Acc: {0: '99.80%', 1: '99.90%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.145067446, Val Accuracy: 97.39%, Val-Class-Acc: {0: '88.99%', 1: '98.56%', 2: '92.14%', 3: '98.78%'}, LR: 0.000100000
# Epoch 1965/2000, Train Loss: 0.003432874, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.142508370, Val Accuracy: 97.40%, Val-Class-Acc: {0: '88.80%', 1: '98.61%', 2: '92.90%', 3: '98.71%'}, LR: 0.000100000
# Epoch 1966/2000, Train Loss: 0.003341701, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.142071201, Val Accuracy: 97.43%, Val-Class-Acc: {0: '89.43%', 1: '98.55%', 2: '91.37%', 3: '98.87%'}, LR: 0.000100000
# Epoch 1967/2000, Train Loss: 0.003343729, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.145367774, Val Accuracy: 97.35%, Val-Class-Acc: {0: '89.60%', 1: '98.30%', 2: '91.40%', 3: '98.90%'}, LR: 0.000100000
# Epoch 1968/2000, Train Loss: 0.003460966, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.147422662, Val Accuracy: 97.33%, Val-Class-Acc: {0: '89.50%', 1: '98.29%', 2: '91.10%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1969/2000, Train Loss: 0.003351498, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.146025679, Val Accuracy: 97.32%, Val-Class-Acc: {0: '88.03%', 1: '98.63%', 2: '92.98%', 3: '98.68%'}, LR: 0.000100000
# Epoch 1970/2000, Train Loss: 0.003761730, Train-Class-Acc: {0: '99.79%', 1: '99.89%', 2: '99.99%', 3: '99.90%'}, Val Loss: 0.143374209, Val Accuracy: 97.44%, Val-Class-Acc: {0: '88.68%', 1: '98.68%', 2: '92.65%', 3: '98.79%'}, LR: 0.000100000
# Epoch 1971/2000, Train Loss: 0.003366986, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.141417304, Val Accuracy: 97.50%, Val-Class-Acc: {0: '89.82%', 1: '98.63%', 2: '92.35%', 3: '98.74%'}, LR: 0.000100000
# Epoch 1972/2000, Train Loss: 0.003310169, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.140946765, Val Accuracy: 97.54%, Val-Class-Acc: {0: '90.00%', 1: '98.59%', 2: '91.68%', 3: '98.90%'}, LR: 0.000100000
# Epoch 1973/2000, Train Loss: 0.003289342, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.140825346, Val Accuracy: 97.51%, Val-Class-Acc: {0: '88.67%', 1: '98.81%', 2: '93.26%', 3: '98.73%'}, LR: 0.000100000
# Epoch 1974/2000, Train Loss: 0.003322791, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.139643467, Val Accuracy: 97.42%, Val-Class-Acc: {0: '88.81%', 1: '98.67%', 2: '93.88%', 3: '98.56%'}, LR: 0.000100000
# Epoch 1975/2000, Train Loss: 0.004751946, Train-Class-Acc: {0: '99.71%', 1: '99.85%', 2: '99.98%', 3: '99.86%'}, Val Loss: 0.148441054, Val Accuracy: 97.36%, Val-Class-Acc: {0: '88.70%', 1: '98.39%', 2: '91.46%', 3: '99.04%'}, LR: 0.000100000
# Epoch 1976/2000, Train Loss: 0.003394682, Train-Class-Acc: {0: '99.81%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.141054880, Val Accuracy: 97.50%, Val-Class-Acc: {0: '89.56%', 1: '98.50%', 2: '92.85%', 3: '98.89%'}, LR: 0.000100000
# Epoch 1977/2000, Train Loss: 0.003443112, Train-Class-Acc: {0: '99.81%', 1: '99.91%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.143682003, Val Accuracy: 97.53%, Val-Class-Acc: {0: '89.69%', 1: '98.61%', 2: '92.07%', 3: '98.90%'}, LR: 0.000100000
# Epoch 1978/2000, Train Loss: 0.003289881, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.141899368, Val Accuracy: 97.56%, Val-Class-Acc: {0: '90.33%', 1: '98.56%', 2: '91.83%', 3: '98.89%'}, LR: 0.000100000
# Epoch 1979/2000, Train Loss: 0.003230192, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.144532641, Val Accuracy: 97.37%, Val-Class-Acc: {0: '88.18%', 1: '98.71%', 2: '92.91%', 3: '98.67%'}, LR: 0.000100000
# Epoch 1980/2000, Train Loss: 0.003309613, Train-Class-Acc: {0: '99.81%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.144064878, Val Accuracy: 97.46%, Val-Class-Acc: {0: '88.49%', 1: '98.89%', 2: '93.40%', 3: '98.56%'}, LR: 0.000100000
# Epoch 1981/2000, Train Loss: 0.003445410, Train-Class-Acc: {0: '99.81%', 1: '99.90%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.145637303, Val Accuracy: 97.45%, Val-Class-Acc: {0: '88.23%', 1: '98.88%', 2: '93.36%', 3: '98.61%'}, LR: 0.000100000
# Epoch 1982/2000, Train Loss: 0.060176532, Train-Class-Acc: {0: '97.15%', 1: '99.02%', 2: '99.38%', 3: '98.99%'}, Val Loss: 0.142268260, Val Accuracy: 97.02%, Val-Class-Acc: {0: '89.16%', 1: '97.65%', 2: '90.39%', 3: '99.03%'}, LR: 0.000100000
# Epoch 1983/2000, Train Loss: 0.003892686, Train-Class-Acc: {0: '99.77%', 1: '99.90%', 2: '99.99%', 3: '99.91%'}, Val Loss: 0.139051727, Val Accuracy: 97.29%, Val-Class-Acc: {0: '89.00%', 1: '98.30%', 2: '91.67%', 3: '98.87%'}, LR: 0.000100000
# Epoch 1984/2000, Train Loss: 0.003511458, Train-Class-Acc: {0: '99.81%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.137663769, Val Accuracy: 97.48%, Val-Class-Acc: {0: '89.23%', 1: '98.56%', 2: '93.13%', 3: '98.82%'}, LR: 0.000100000
# Epoch 1985/2000, Train Loss: 0.003407590, Train-Class-Acc: {0: '99.82%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.140911450, Val Accuracy: 97.40%, Val-Class-Acc: {0: '89.60%', 1: '98.40%', 2: '91.11%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1986/2000, Train Loss: 0.003398033, Train-Class-Acc: {0: '99.82%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.138539819, Val Accuracy: 97.49%, Val-Class-Acc: {0: '89.32%', 1: '98.63%', 2: '92.28%', 3: '98.83%'}, LR: 0.000100000
# Epoch 1987/2000, Train Loss: 0.003295255, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.138951452, Val Accuracy: 97.54%, Val-Class-Acc: {0: '89.03%', 1: '98.76%', 2: '92.73%', 3: '98.85%'}, LR: 0.000100000
# Epoch 1988/2000, Train Loss: 0.003379998, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.137378973, Val Accuracy: 97.55%, Val-Class-Acc: {0: '89.29%', 1: '98.73%', 2: '94.09%', 3: '98.69%'}, LR: 0.000100000
# Epoch 1989/2000, Train Loss: 0.003268252, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.148837612, Val Accuracy: 97.34%, Val-Class-Acc: {0: '89.81%', 1: '98.27%', 2: '89.90%', 3: '99.02%'}, LR: 0.000100000
# Epoch 1990/2000, Train Loss: 0.003259936, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.93%'}, Val Loss: 0.140335224, Val Accuracy: 97.50%, Val-Class-Acc: {0: '89.58%', 1: '98.66%', 2: '92.50%', 3: '98.73%'}, LR: 0.000100000
# Epoch 1991/2000, Train Loss: 0.003243206, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.93%'}, Val Loss: 0.142120495, Val Accuracy: 97.52%, Val-Class-Acc: {0: '90.02%', 1: '98.64%', 2: '90.46%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1992/2000, Train Loss: 0.003326531, Train-Class-Acc: {0: '99.82%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.141493947, Val Accuracy: 97.48%, Val-Class-Acc: {0: '88.60%', 1: '98.83%', 2: '93.36%', 3: '98.64%'}, LR: 0.000100000
# Epoch 1993/2000, Train Loss: 0.003256924, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.142205336, Val Accuracy: 97.47%, Val-Class-Acc: {0: '90.40%', 1: '98.32%', 2: '91.56%', 3: '98.95%'}, LR: 0.000100000
# Epoch 1994/2000, Train Loss: 0.003218158, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.93%'}, Val Loss: 0.142534600, Val Accuracy: 97.60%, Val-Class-Acc: {0: '89.68%', 1: '98.79%', 2: '91.70%', 3: '98.89%'}, LR: 0.000100000
# Epoch 1995/2000, Train Loss: 0.003370107, Train-Class-Acc: {0: '99.81%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.138858332, Val Accuracy: 97.57%, Val-Class-Acc: {0: '89.77%', 1: '98.64%', 2: '92.14%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1996/2000, Train Loss: 0.003155343, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.93%'}, Val Loss: 0.144318919, Val Accuracy: 97.53%, Val-Class-Acc: {0: '90.31%', 1: '98.50%', 2: '90.80%', 3: '99.00%'}, LR: 0.000100000
# Epoch 1997/2000, Train Loss: 0.003185957, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.93%'}, Val Loss: 0.141477651, Val Accuracy: 97.61%, Val-Class-Acc: {0: '90.29%', 1: '98.79%', 2: '91.84%', 3: '98.75%'}, LR: 0.000100000
# Epoch 1998/2000, Train Loss: 0.003209298, Train-Class-Acc: {0: '99.83%', 1: '99.92%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.143708109, Val Accuracy: 97.53%, Val-Class-Acc: {0: '89.90%', 1: '98.51%', 2: '92.42%', 3: '98.92%'}, LR: 0.000100000
# Epoch 1999/2000, Train Loss: 0.003660005, Train-Class-Acc: {0: '99.78%', 1: '99.89%', 2: '99.99%', 3: '99.90%'}, Val Loss: 0.152067777, Val Accuracy: 97.33%, Val-Class-Acc: {0: '89.82%', 1: '98.28%', 2: '90.68%', 3: '98.88%'}, LR: 0.000100000
# Epoch 2000/2000, Train Loss: 0.003226089, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.147879877, Val Accuracy: 97.50%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, LR: 0.000100000
#
# Final model saved to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_final.pth
#
# Training complete.
#
# Top 5 Models Sorted by Validation Accuracy:
# Epoch 1740/2000, Train Loss: 0.005721287, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.118269217, Val Accuracy: 97.81%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1740.pth
# Epoch 1933/2000, Train Loss: 0.003549516, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.133131425, Val Accuracy: 97.74%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1933.pth
# Epoch 1942/2000, Train Loss: 0.003437383, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.139303269, Val Accuracy: 97.74%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1942.pth
# Epoch 1774/2000, Train Loss: 0.004196457, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.131851874, Val Accuracy: 97.74%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1774.pth
# Epoch 1742/2000, Train Loss: 0.004255317, Train-Class-Acc: {0: '99.83%', 1: '99.91%', 2: '99.99%', 3: '99.92%'}, Val Loss: 0.124466503, Val Accuracy: 97.70%, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1742.pth
#
#
# Epoch 1740/2000, Train Loss: 0.0057, Val Loss: 0.1183, Val Accuracy: 97.81%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1740.pth
# Epoch 1933/2000, Train Loss: 0.0035, Val Loss: 0.1331, Val Accuracy: 97.74%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1933.pth
# Epoch 1942/2000, Train Loss: 0.0034, Val Loss: 0.1393, Val Accuracy: 97.74%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1942.pth
# Epoch 1774/2000, Train Loss: 0.0042, Val Loss: 0.1319, Val Accuracy: 97.74%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1774.pth
# Epoch 1742/2000, Train Loss: 0.0043, Val Loss: 0.1245, Val Accuracy: 97.70%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_3\1st_try\BiGRUWithAttention_epoch_1742.pth
#
# class_gru_model:
# BiGRUWithAttention(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=4, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1 2 3]
# num_classes = 4

# %%
# === Post-training Evaluation: Update .pth with val accuracy and class-wise accuracy for Baseline Period 3 ===

# Rebuild evaluation model
model_template = BiGRUWithAttention(
    input_size=Number_features,
    hidden_size=64,
    output_size=num_classes,
    num_layers=4
)

# Prepare validation data
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)
criterion = nn.CrossEntropyLoss()

# Your model folder
model_folder = 'Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try'
ckpt_paths = sorted(glob.glob(os.path.join(model_folder, "*.pth")))

# Loop through and update each model
for file_path in ckpt_paths:
    model_copy = copy.deepcopy(model_template).to(device)
    checkpoint = torch.load(file_path, map_location=device)
    model_copy.load_state_dict(checkpoint['model_state_dict'])

    add_val_class_acc(
        model_copy=model_copy,
        output_size=num_classes,
        criterion=criterion,
        X_val=X_val_tensor,
        y_val=y_val_tensor,
        file_path=file_path,
        model_checkpoint=checkpoint,
        batch_size=64
    )

# 顯示 summary
show_val_accuracy_from_checkpoints(model_folder)
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\3163461864.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_path, map_location=device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val, dtype=torch.long).to(device)
# ✅ Updated: BiGRUWithAttention_epoch_1740.pth | Acc: 0.9781 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_epoch_1740.pth
# ✅ Updated: BiGRUWithAttention_epoch_1742.pth | Acc: 0.9770 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_epoch_1742.pth
# ✅ Updated: BiGRUWithAttention_epoch_1774.pth | Acc: 0.9774 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_epoch_1774.pth
# ✅ Updated: BiGRUWithAttention_epoch_1933.pth | Acc: 0.9774 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_epoch_1933.pth
# ✅ Updated: BiGRUWithAttention_epoch_1942.pth | Acc: 0.9774 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_epoch_1942.pth
# ✅ Updated: BiGRUWithAttention_final.pth | Acc: 0.9750 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_3/1st_try\BiGRUWithAttention_final.pth
#
# 📝 Summary of val_accuracy and Val-Class-Acc:
# BiGRUWithAttention_epoch_1740.pth: val_accuracy = 0.9781, Val-Class-Acc: {0: '92.45%', 1: '98.51%', 2: '93.73%', 3: '98.82%'}
# BiGRUWithAttention_epoch_1742.pth: val_accuracy = 0.9770, Val-Class-Acc: {0: '89.69%', 1: '98.87%', 2: '95.24%', 3: '98.68%'}
# BiGRUWithAttention_epoch_1774.pth: val_accuracy = 0.9774, Val-Class-Acc: {0: '91.43%', 1: '98.70%', 2: '92.79%', 3: '98.78%'}
# BiGRUWithAttention_epoch_1933.pth: val_accuracy = 0.9774, Val-Class-Acc: {0: '90.89%', 1: '98.90%', 2: '92.88%', 3: '98.69%'}
# BiGRUWithAttention_epoch_1942.pth: val_accuracy = 0.9774, Val-Class-Acc: {0: '91.01%', 1: '98.87%', 2: '91.62%', 3: '98.82%'}
# BiGRUWithAttention_final.pth: val_accuracy = 0.9750, Val-Class-Acc: {0: '89.70%', 1: '98.57%', 2: '90.83%', 3: '99.00%'}
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:66: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")

# %% [markdown]
# ### Period 4 --> Training and saving in __*'1st_try'*__ (BiGRUWithAttention, num_layers = 4) ---> Val acc = 96.89 %
# ### Val-Class-Acc: {0: '89.55%', 1: '98.16%', 2: '90.90%', 3: '98.64%', 4: '99.18%'}

# %%
"""
- 'trend': Categorized trend values based on the detected phases:
    - 0: No trend
    - 1: Moderate negative trend
    - 2: Very strong negative trend
    - 3: Moderate positive trend
    - 4: Very strong positive trend
"""
with contextlib.redirect_stdout(open(os.devnull, 'w')):
    X_train, y_train, X_val, y_val, X_test, y_test, Number_features = process_and_return_splits(
        with_indicators_file_path = list_period_files_full_path[3], # Change 
        downsampled_data_minutes = downsampled_data_minutes,
        exclude_columns = exclude_columns,
        lower_threshold = lower_threshold,
        upper_threshold = upper_threshold,
        reverse_steps = reverse_steps,
        sequence_length = sequence_length,
        sliding_interval = sliding_interval,
        trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends : {0, 1, 2, 3, 4}
        # trends_to_keep = {0, 1, 2, 3, 4}  # Default keeps all trends
    )

print(f"\nNumber_features = {Number_features}")

unique_classes = np.unique(y_val)
num_classes = len(unique_classes)
print(f"unique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# Out:
# Number_features = 7
# unique_classes = [0 1 2 3 4]
# num_classes = 5

# %%
# Model parameters
input_size = Number_features  # Number of features
hidden_size = 64  # Number of GRU units
output_size = num_classes # Must be dynamic, up to 5  # Number of trend classes (0, 15, 25, -15, -25)
num_layers = 4  # Number of GRU layers
num_epochs= 2000 # Number of epochs/ go through entire data
batch_size= 64 # How many sequences passed at once to the model
model_name = 'BiGRUWithAttention' # Name of the model to use for saving
best_results = [] # Initialize this outside the training function or at the beginning of training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Define a global stop signal
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'Classif_Bi_Dir_GRU_Model/stop_training.txt'))  # Create this file to stop training
model_saving_folder = os.path.normpath(os.path.join('Class_Incremental_CL', "Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try"))
ensure_folder(model_saving_folder)

# Instantiate the model
class_gru_model = BiGRUWithAttention(input_size, hidden_size, output_size, num_layers).to(device)

# Define the loss function, optimizer and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(class_gru_model.parameters(), lr=0.0001) # lr=0.00005
# optimizer = optim.Adam(class_gru_model.parameters(), lr=0.001, weight_decay=1e-5)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=10)

# train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train_all, y_train_all, X_val_all, y_val_all, scheduler, 
train_and_validate(class_gru_model, output_size, criterion, optimizer, X_train, y_train, X_val, y_val, scheduler, 
                   False, num_epochs, batch_size, model_saving_folder, model_name, stop_signal_file)

for res in best_results:        
    print(f"Epoch {res['epoch']}/{num_epochs}, "
            f"Train Loss: {res['train_loss']:.4f}, " 
            f"Val Loss: {res['val_loss']:.4f}, "
            f"Val Accuracy: {res['val_accuracy'] * 100:.2f}%, "
            f"Model Path: {res['model_path']}")      
print(f"\nclass_gru_model: \n{class_gru_model}")

print(f"\nunique_classes = {unique_classes}")
print(f"num_classes = {num_classes}")
# del unique_classes, num_classes
for var in ["X_train", "y_train", "X_val", "y_val", "X_test", "y_test", "Number_features", "unique_classes", "num_classes"]:
    if var in locals():
        del locals()[var]
# Out:
# 'train_and_validate' function started.
#
# Existing folder has been removed : Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try
#
# y_train:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([3634, 1000])
# X_train:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([3634, 1000, 7])
#
# y_val:
# <class 'torch.Tensor'>
# torch.int64
# torch.Size([454, 1000])
# X_val:
# <class 'torch.Tensor'>
# torch.float32
# torch.Size([454, 1000, 7])
#
# Dataset Lengths:
# Train Dataset Length: 3634
# Validation Dataset Length: 454
#
# DataLoader Batch Sizes:
# Number of Batches in Train DataLoader: 57
# Number of Batches in Validation DataLoader: 8
#
# y_train Unique Values and Stats:
# Unique values in y_train: tensor([0, 1, 2, 3, 4], device='cuda:0')
# y_train Min: 0, Max: 4
#
# y_val Unique Values and Stats:
# Unique values in y_val: tensor([0, 1, 2, 3, 4], device='cuda:0')
# y_val Min: 0, Max: 4
#
# Device Info:
# X_train Device: cuda:0
# y_train Device: cuda:0
# X_val Device: cuda:0
# y_val Device: cuda:0
#
# Epoch 1/2000, Train Loss: 1.542230139, Train-Class-Acc: {0: '0.09%', 1: '98.74%', 2: '0.00%', 3: '0.30%', 4: '1.23%'}, Val Loss: 1.492349962, Val Accuracy: 36.12%, Val-Class-Acc: {0: '0.00%', 1: '99.13%', 2: '0.00%', 3: '0.84%', 4: '0.00%'}, LR: 0.000100000
# Model saved after epoch 1 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1.pth
#
#
# Unique target values: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 4
# Unique classes in y_train: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3, 4], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 4
# Unique classes in y_train: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3, 4], device='cuda:0')
#
#
# Unique target values: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Target dtype: torch.int64
# Min target: 0, Max target: 4
# Unique classes in y_train: tensor([0, 1, 2, 3, 4], device='cuda:0')
# Unique classes in y_val: tensor([0, 1, 2, 3, 4], device='cuda:0')
#
# Epoch 2/2000, Train Loss: 1.274216829, Train-Class-Acc: {0: '0.00%', 1: '2.35%', 2: '0.00%', 3: '97.71%', 4: '0.00%'}, Val Loss: 1.447354310, Val Accuracy: 34.02%, Val-Class-Acc: {0: '0.00%', 1: '0.57%', 2: '0.00%', 3: '99.40%', 4: '0.00%'}, LR: 0.000100000
# Model saved after epoch 2 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_2.pth
#
# Epoch 3/2000, Train Loss: 1.269339203, Train-Class-Acc: {0: '0.00%', 1: '0.64%', 2: '0.00%', 3: '99.39%', 4: '0.00%'}, Val Loss: 1.453597586, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.40%', 2: '0.00%', 3: '99.59%', 4: '0.00%'}, LR: 0.000100000
# Model saved after epoch 3 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_3.pth
#
# Epoch 4/2000, Train Loss: 1.269220944, Train-Class-Acc: {0: '0.00%', 1: '0.55%', 2: '0.00%', 3: '99.47%', 4: '0.00%'}, Val Loss: 1.438008981, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.40%', 2: '0.00%', 3: '99.59%', 4: '0.00%'}, LR: 0.000100000
# Model saved after epoch 4 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_4.pth
#
# Epoch 5/2000, Train Loss: 1.269277873, Train-Class-Acc: {0: '0.00%', 1: '0.48%', 2: '0.00%', 3: '99.54%', 4: '0.00%'}, Val Loss: 1.445359314, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.60%', 2: '0.00%', 3: '99.40%', 4: '0.00%'}, LR: 0.000100000
# Model saved after epoch 5 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_5.pth
#
# Epoch 6/2000, Train Loss: 1.269321445, Train-Class-Acc: {0: '0.00%', 1: '0.51%', 2: '0.00%', 3: '99.51%', 4: '0.00%'}, Val Loss: 1.451679609, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.40%', 2: '0.00%', 3: '99.59%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.02%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_2.pth
# Model saved after epoch 6 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_6.pth
#
# Epoch 7/2000, Train Loss: 1.269351263, Train-Class-Acc: {0: '0.00%', 1: '0.46%', 2: '0.00%', 3: '99.57%', 4: '0.00%'}, Val Loss: 1.449060901, Val Accuracy: 34.04%, Val-Class-Acc: {0: '0.00%', 1: '0.36%', 2: '0.00%', 3: '99.67%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_6.pth
# Model saved after epoch 7 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_7.pth
#
# Epoch 8/2000, Train Loss: 1.269168756, Train-Class-Acc: {0: '0.00%', 1: '0.43%', 2: '0.00%', 3: '99.58%', 4: '0.00%'}, Val Loss: 1.446565299, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.40%', 2: '0.00%', 3: '99.59%', 4: '0.00%'}, LR: 0.000100000
# Epoch 9/2000, Train Loss: 1.268980965, Train-Class-Acc: {0: '0.00%', 1: '0.41%', 2: '0.00%', 3: '99.61%', 4: '0.00%'}, Val Loss: 1.438855464, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.32%', 2: '0.00%', 3: '99.67%', 4: '0.00%'}, LR: 0.000100000
# Epoch 10/2000, Train Loss: 1.269259902, Train-Class-Acc: {0: '0.00%', 1: '7.17%', 2: '0.00%', 3: '92.72%', 4: '0.00%'}, Val Loss: 1.448572821, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.40%', 2: '0.00%', 3: '99.59%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_4.pth
# Model saved after epoch 10 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_10.pth
#
# Epoch 11/2000, Train Loss: 1.268726284, Train-Class-Acc: {0: '0.00%', 1: '2.71%', 2: '0.00%', 3: '99.56%', 4: '0.00%'}, Val Loss: 1.446597400, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.32%', 2: '0.00%', 3: '99.68%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_3.pth
# Model saved after epoch 11 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_11.pth
#
# Epoch 12/2000, Train Loss: 1.268650299, Train-Class-Acc: {0: '0.00%', 1: '0.33%', 2: '0.00%', 3: '99.68%', 4: '0.00%'}, Val Loss: 1.450529747, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.32%', 2: '0.00%', 3: '99.67%', 4: '0.00%'}, LR: 0.000100000
# Epoch 13/2000, Train Loss: 1.268970205, Train-Class-Acc: {0: '0.00%', 1: '4.63%', 2: '0.00%', 3: '96.45%', 4: '0.00%'}, Val Loss: 1.457497339, Val Accuracy: 34.04%, Val-Class-Acc: {0: '0.00%', 1: '0.36%', 2: '0.00%', 3: '99.67%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_11.pth
# Model saved after epoch 13 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_13.pth
#
# Epoch 14/2000, Train Loss: 1.268683097, Train-Class-Acc: {0: '0.00%', 1: '0.30%', 2: '0.00%', 3: '99.72%', 4: '0.00%'}, Val Loss: 1.443439368, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.32%', 2: '0.00%', 3: '99.67%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_10.pth
# Model saved after epoch 14 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_14.pth
#
# Epoch 15/2000, Train Loss: 1.268317907, Train-Class-Acc: {0: '0.00%', 1: '10.20%', 2: '0.00%', 3: '90.70%', 4: '0.00%'}, Val Loss: 1.442222943, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.24%', 2: '0.00%', 3: '99.76%', 4: '0.00%'}, LR: 0.000100000
# Epoch 16/2000, Train Loss: 1.267963376, Train-Class-Acc: {0: '0.00%', 1: '1.44%', 2: '0.00%', 3: '99.75%', 4: '0.00%'}, Val Loss: 1.452913206, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.24%', 2: '0.00%', 3: '99.76%', 4: '0.00%'}, LR: 0.000100000
# Epoch 17/2000, Train Loss: 1.267651268, Train-Class-Acc: {0: '0.00%', 1: '0.78%', 2: '0.00%', 3: '99.76%', 4: '0.00%'}, Val Loss: 1.436998303, Val Accuracy: 34.03%, Val-Class-Acc: {0: '0.00%', 1: '0.24%', 2: '0.00%', 3: '99.76%', 4: '0.00%'}, LR: 0.000100000
# Epoch 18/2000, Train Loss: 1.266814193, Train-Class-Acc: {0: '0.00%', 1: '19.47%', 2: '0.00%', 3: '84.74%', 4: '0.00%'}, Val Loss: 1.444256556, Val Accuracy: 34.13%, Val-Class-Acc: {0: '0.00%', 1: '0.51%', 2: '0.00%', 3: '99.76%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_14.pth
# Model saved after epoch 18 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_18.pth
#
# Epoch 19/2000, Train Loss: 1.265073915, Train-Class-Acc: {0: '0.00%', 1: '23.08%', 2: '0.00%', 3: '89.03%', 4: '0.00%'}, Val Loss: 1.441012393, Val Accuracy: 34.39%, Val-Class-Acc: {0: '0.00%', 1: '1.25%', 2: '0.00%', 3: '99.77%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.03%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_5.pth
# Model saved after epoch 19 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_19.pth
#
# Epoch 20/2000, Train Loss: 1.256432019, Train-Class-Acc: {0: '0.00%', 1: '38.74%', 2: '0.00%', 3: '86.14%', 4: '0.00%'}, Val Loss: 1.412817026, Val Accuracy: 56.54%, Val-Class-Acc: {0: '0.00%', 1: '65.06%', 2: '0.00%', 3: '97.05%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.04%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_7.pth
# Model saved after epoch 20 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_20.pth
#
# Epoch 21/2000, Train Loss: 1.180888980, Train-Class-Acc: {0: '0.00%', 1: '62.62%', 2: '0.00%', 3: '76.98%', 4: '0.00%'}, Val Loss: 1.271964648, Val Accuracy: 51.89%, Val-Class-Acc: {0: '0.00%', 1: '52.11%', 2: '0.00%', 3: '97.15%', 4: '0.00%'}, LR: 0.000100000
# Removed old model with accuracy 34.04%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_13.pth
# Model saved after epoch 21 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_21.pth
#
# Epoch 22/2000, Train Loss: 0.981275313, Train-Class-Acc: {0: '0.00%', 1: '76.99%', 2: '0.21%', 3: '79.29%', 4: '1.44%'}, Val Loss: 0.874408173, Val Accuracy: 64.73%, Val-Class-Acc: {0: '0.00%', 1: '95.76%', 2: '5.12%', 3: '81.79%', 4: '15.76%'}, LR: 0.000100000
# Removed old model with accuracy 34.13%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_18.pth
# Model saved after epoch 22 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_22.pth
#
# Epoch 23/2000, Train Loss: 0.759730291, Train-Class-Acc: {0: '0.00%', 1: '86.78%', 2: '14.16%', 3: '87.96%', 4: '17.43%'}, Val Loss: 0.748743608, Val Accuracy: 71.21%, Val-Class-Acc: {0: '0.00%', 1: '85.53%', 2: '29.03%', 3: '95.61%', 4: '35.87%'}, LR: 0.000100000
# Removed old model with accuracy 34.39%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_19.pth
# Model saved after epoch 23 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_23.pth
#
# Epoch 24/2000, Train Loss: 0.644223204, Train-Class-Acc: {0: '0.00%', 1: '90.36%', 2: '30.58%', 3: '91.48%', 4: '24.73%'}, Val Loss: 0.644074217, Val Accuracy: 76.22%, Val-Class-Acc: {0: '0.00%', 1: '92.65%', 2: '50.71%', 3: '90.74%', 4: '45.03%'}, LR: 0.000100000
# Removed old model with accuracy 36.12%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1.pth
# Model saved after epoch 24 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_24.pth
#
# Epoch 25/2000, Train Loss: 0.585384772, Train-Class-Acc: {0: '0.00%', 1: '91.08%', 2: '43.07%', 3: '92.22%', 4: '31.58%'}, Val Loss: 0.604307152, Val Accuracy: 78.00%, Val-Class-Acc: {0: '0.00%', 1: '93.42%', 2: '62.83%', 3: '89.58%', 4: '46.00%'}, LR: 0.000100000
# Removed old model with accuracy 51.89%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_21.pth
# Model saved after epoch 25 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_25.pth
#
# Epoch 26/2000, Train Loss: 0.529156522, Train-Class-Acc: {0: '0.00%', 1: '92.13%', 2: '51.58%', 3: '93.05%', 4: '37.69%'}, Val Loss: 0.569385410, Val Accuracy: 78.91%, Val-Class-Acc: {0: '0.00%', 1: '93.91%', 2: '66.11%', 3: '89.37%', 4: '49.30%'}, LR: 0.000100000
# Removed old model with accuracy 56.54%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_20.pth
# Model saved after epoch 26 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_26.pth
#
# Epoch 27/2000, Train Loss: 0.502789354, Train-Class-Acc: {0: '0.01%', 1: '92.09%', 2: '57.02%', 3: '92.93%', 4: '43.83%'}, Val Loss: 0.530340893, Val Accuracy: 79.88%, Val-Class-Acc: {0: '0.01%', 1: '93.95%', 2: '67.70%', 3: '90.50%', 4: '52.89%'}, LR: 0.000100000
# Removed old model with accuracy 64.73%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_22.pth
# Model saved after epoch 27 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_27.pth
#
# Epoch 28/2000, Train Loss: 0.473005460, Train-Class-Acc: {0: '0.03%', 1: '92.47%', 2: '61.33%', 3: '93.28%', 4: '47.93%'}, Val Loss: 0.491916300, Val Accuracy: 81.11%, Val-Class-Acc: {0: '0.04%', 1: '91.99%', 2: '67.46%', 3: '93.27%', 4: '63.50%'}, LR: 0.000100000
# Removed old model with accuracy 71.21%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_23.pth
# Model saved after epoch 28 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_28.pth
#
# Epoch 29/2000, Train Loss: 0.443180744, Train-Class-Acc: {0: '0.10%', 1: '92.83%', 2: '64.70%', 3: '93.61%', 4: '53.12%'}, Val Loss: 0.467000957, Val Accuracy: 81.91%, Val-Class-Acc: {0: '0.15%', 1: '92.95%', 2: '72.00%', 3: '92.96%', 4: '62.19%'}, LR: 0.000100000
# Removed old model with accuracy 76.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_24.pth
# Model saved after epoch 29 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_29.pth
#
# Epoch 30/2000, Train Loss: 0.435575765, Train-Class-Acc: {0: '0.21%', 1: '92.81%', 2: '66.22%', 3: '93.44%', 4: '56.71%'}, Val Loss: 0.456114111, Val Accuracy: 82.16%, Val-Class-Acc: {0: '0.28%', 1: '93.43%', 2: '74.35%', 3: '92.77%', 4: '60.01%'}, LR: 0.000100000
# Removed old model with accuracy 78.00%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_25.pth
# Model saved after epoch 30 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_30.pth
#
# Epoch 31/2000, Train Loss: 0.424303003, Train-Class-Acc: {0: '0.35%', 1: '92.73%', 2: '68.95%', 3: '93.43%', 4: '58.59%'}, Val Loss: 0.439632655, Val Accuracy: 82.89%, Val-Class-Acc: {0: '0.52%', 1: '93.37%', 2: '71.49%', 3: '93.46%', 4: '69.54%'}, LR: 0.000100000
# Removed old model with accuracy 78.91%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_26.pth
# Model saved after epoch 31 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_31.pth
#
# Epoch 32/2000, Train Loss: 0.412865850, Train-Class-Acc: {0: '0.65%', 1: '92.81%', 2: '70.86%', 3: '93.47%', 4: '61.04%'}, Val Loss: 0.465782358, Val Accuracy: 81.64%, Val-Class-Acc: {0: '1.12%', 1: '89.79%', 2: '66.76%', 3: '94.07%', 4: '74.82%'}, LR: 0.000100000
# Removed old model with accuracy 79.88%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_27.pth
# Model saved after epoch 32 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_32.pth
#
# Epoch 33/2000, Train Loss: 0.398164033, Train-Class-Acc: {0: '0.79%', 1: '93.13%', 2: '72.10%', 3: '93.68%', 4: '63.83%'}, Val Loss: 0.411249246, Val Accuracy: 83.84%, Val-Class-Acc: {0: '1.49%', 1: '92.52%', 2: '75.93%', 3: '93.72%', 4: '74.27%'}, LR: 0.000100000
# Removed old model with accuracy 81.11%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_28.pth
# Model saved after epoch 33 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_33.pth
#
# Epoch 34/2000, Train Loss: 0.388496677, Train-Class-Acc: {0: '2.39%', 1: '93.03%', 2: '74.89%', 3: '93.65%', 4: '65.50%'}, Val Loss: 0.429497830, Val Accuracy: 83.24%, Val-Class-Acc: {0: '2.53%', 1: '90.57%', 2: '72.86%', 3: '94.24%', 4: '77.67%'}, LR: 0.000100000
# Removed old model with accuracy 81.64%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_32.pth
# Model saved after epoch 34 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_34.pth
#
# Epoch 35/2000, Train Loss: 0.378991544, Train-Class-Acc: {0: '4.84%', 1: '93.04%', 2: '76.09%', 3: '93.67%', 4: '67.06%'}, Val Loss: 0.384558581, Val Accuracy: 85.22%, Val-Class-Acc: {0: '4.13%', 1: '93.77%', 2: '83.95%', 3: '93.21%', 4: '72.02%'}, LR: 0.000100000
# Removed old model with accuracy 81.91%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_29.pth
# Model saved after epoch 35 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_35.pth
#
# Epoch 36/2000, Train Loss: 0.353826508, Train-Class-Acc: {0: '7.62%', 1: '93.75%', 2: '78.45%', 3: '93.94%', 4: '69.82%'}, Val Loss: 0.370607155, Val Accuracy: 85.85%, Val-Class-Acc: {0: '14.19%', 1: '92.33%', 2: '80.53%', 3: '94.57%', 4: '78.78%'}, LR: 0.000100000
# Removed old model with accuracy 82.16%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_30.pth
# Model saved after epoch 36 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_36.pth
#
# Epoch 37/2000, Train Loss: 0.351453505, Train-Class-Acc: {0: '11.79%', 1: '93.24%', 2: '79.87%', 3: '93.69%', 4: '71.75%'}, Val Loss: 0.396850219, Val Accuracy: 84.76%, Val-Class-Acc: {0: '9.93%', 1: '93.85%', 2: '89.18%', 3: '89.28%', 4: '69.63%'}, LR: 0.000100000
# Removed old model with accuracy 82.89%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_31.pth
# Model saved after epoch 37 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_37.pth
#
# Epoch 38/2000, Train Loss: 0.357952802, Train-Class-Acc: {0: '12.05%', 1: '93.10%', 2: '80.21%', 3: '93.36%', 4: '71.71%'}, Val Loss: 0.337072036, Val Accuracy: 87.33%, Val-Class-Acc: {0: '14.99%', 1: '93.39%', 2: '87.61%', 3: '94.47%', 4: '79.18%'}, LR: 0.000100000
# Removed old model with accuracy 83.24%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_34.pth
# Model saved after epoch 38 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_38.pth
#
# Epoch 39/2000, Train Loss: 0.354504459, Train-Class-Acc: {0: '13.12%', 1: '92.81%', 2: '81.05%', 3: '93.25%', 4: '73.42%'}, Val Loss: 0.381363509, Val Accuracy: 85.61%, Val-Class-Acc: {0: '10.45%', 1: '93.35%', 2: '92.58%', 3: '88.91%', 4: '76.01%'}, LR: 0.000100000
# Removed old model with accuracy 83.84%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_33.pth
# Model saved after epoch 39 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_39.pth
#
# Epoch 40/2000, Train Loss: 0.317875154, Train-Class-Acc: {0: '18.02%', 1: '93.94%', 2: '83.36%', 3: '93.95%', 4: '76.16%'}, Val Loss: 0.322914285, Val Accuracy: 87.88%, Val-Class-Acc: {0: '25.53%', 1: '91.89%', 2: '86.14%', 3: '94.55%', 4: '86.59%'}, LR: 0.000100000
# Removed old model with accuracy 84.76%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_37.pth
# Model saved after epoch 40 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_40.pth
#
# Epoch 41/2000, Train Loss: 0.309949568, Train-Class-Acc: {0: '23.15%', 1: '93.62%', 2: '84.43%', 3: '93.90%', 4: '77.23%'}, Val Loss: 0.326485682, Val Accuracy: 87.46%, Val-Class-Acc: {0: '27.56%', 1: '91.29%', 2: '82.34%', 3: '94.85%', 4: '88.12%'}, LR: 0.000100000
# Removed old model with accuracy 85.22%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_35.pth
# Model saved after epoch 41 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_41.pth
#
# Epoch 42/2000, Train Loss: 0.310736744, Train-Class-Acc: {0: '25.15%', 1: '93.57%', 2: '84.59%', 3: '93.68%', 4: '77.57%'}, Val Loss: 0.397896763, Val Accuracy: 84.58%, Val-Class-Acc: {0: '20.74%', 1: '86.07%', 2: '78.28%', 3: '92.70%', 4: '95.33%'}, LR: 0.000100000
# Epoch 43/2000, Train Loss: 0.301235976, Train-Class-Acc: {0: '27.86%', 1: '93.71%', 2: '85.84%', 3: '93.90%', 4: '78.55%'}, Val Loss: 0.285344577, Val Accuracy: 89.60%, Val-Class-Acc: {0: '39.89%', 1: '94.23%', 2: '89.15%', 3: '94.22%', 4: '84.22%'}, LR: 0.000100000
# Removed old model with accuracy 85.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_39.pth
# Model saved after epoch 43 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_43.pth
#
# Epoch 44/2000, Train Loss: 0.279677416, Train-Class-Acc: {0: '33.39%', 1: '94.16%', 2: '86.91%', 3: '94.28%', 4: '79.88%'}, Val Loss: 0.275416674, Val Accuracy: 89.91%, Val-Class-Acc: {0: '39.56%', 1: '94.21%', 2: '90.90%', 3: '93.89%', 4: '86.23%'}, LR: 0.000100000
# Removed old model with accuracy 85.85%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_36.pth
# Model saved after epoch 44 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_44.pth
#
# Epoch 45/2000, Train Loss: 0.280929370, Train-Class-Acc: {0: '35.71%', 1: '93.95%', 2: '87.09%', 3: '94.11%', 4: '80.62%'}, Val Loss: 0.367507429, Val Accuracy: 85.81%, Val-Class-Acc: {0: '15.87%', 1: '92.27%', 2: '97.07%', 3: '87.18%', 4: '78.34%'}, LR: 0.000100000
# Epoch 46/2000, Train Loss: 0.291192634, Train-Class-Acc: {0: '35.83%', 1: '93.49%', 2: '86.45%', 3: '93.68%', 4: '79.84%'}, Val Loss: 0.261915584, Val Accuracy: 90.54%, Val-Class-Acc: {0: '49.64%', 1: '93.81%', 2: '89.42%', 3: '94.04%', 4: '90.32%'}, LR: 0.000100000
# Removed old model with accuracy 87.33%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_38.pth
# Model saved after epoch 46 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_46.pth
#
# Epoch 47/2000, Train Loss: 0.275547812, Train-Class-Acc: {0: '38.72%', 1: '93.90%', 2: '86.91%', 3: '94.22%', 4: '81.04%'}, Val Loss: 0.251790172, Val Accuracy: 90.95%, Val-Class-Acc: {0: '51.02%', 1: '93.94%', 2: '90.73%', 3: '94.54%', 4: '89.61%'}, LR: 0.000100000
# Removed old model with accuracy 87.46%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_41.pth
# Model saved after epoch 47 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_47.pth
#
# Epoch 48/2000, Train Loss: 0.273202398, Train-Class-Acc: {0: '40.68%', 1: '93.77%', 2: '87.30%', 3: '93.99%', 4: '81.66%'}, Val Loss: 0.266857607, Val Accuracy: 90.05%, Val-Class-Acc: {0: '43.07%', 1: '94.51%', 2: '92.83%', 3: '92.07%', 4: '87.98%'}, LR: 0.000100000
# Removed old model with accuracy 87.88%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_40.pth
# Model saved after epoch 48 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_48.pth
#
# Epoch 49/2000, Train Loss: 0.267316758, Train-Class-Acc: {0: '43.02%', 1: '93.89%', 2: '87.56%', 3: '94.08%', 4: '82.07%'}, Val Loss: 0.244642623, Val Accuracy: 90.96%, Val-Class-Acc: {0: '52.06%', 1: '95.14%', 2: '88.91%', 3: '93.91%', 4: '89.58%'}, LR: 0.000100000
# Removed old model with accuracy 89.60%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_43.pth
# Model saved after epoch 49 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_49.pth
#
# Epoch 50/2000, Train Loss: 0.248884381, Train-Class-Acc: {0: '46.49%', 1: '94.45%', 2: '88.49%', 3: '94.55%', 4: '83.03%'}, Val Loss: 0.258607092, Val Accuracy: 90.35%, Val-Class-Acc: {0: '55.70%', 1: '91.20%', 2: '86.63%', 3: '95.20%', 4: '94.91%'}, LR: 0.000100000
# Removed old model with accuracy 89.91%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_44.pth
# Model saved after epoch 50 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_50.pth
#
# Epoch 51/2000, Train Loss: 0.244688994, Train-Class-Acc: {0: '48.46%', 1: '94.35%', 2: '88.85%', 3: '94.66%', 4: '83.31%'}, Val Loss: 0.247252802, Val Accuracy: 90.71%, Val-Class-Acc: {0: '50.75%', 1: '94.29%', 2: '93.08%', 3: '93.17%', 4: '87.14%'}, LR: 0.000100000
# Removed old model with accuracy 90.05%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_48.pth
# Model saved after epoch 51 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_51.pth
#
# Epoch 52/2000, Train Loss: 0.260869806, Train-Class-Acc: {0: '46.80%', 1: '93.82%', 2: '87.60%', 3: '93.93%', 4: '82.97%'}, Val Loss: 0.251025392, Val Accuracy: 90.60%, Val-Class-Acc: {0: '56.39%', 1: '91.48%', 2: '87.06%', 3: '94.84%', 4: '96.70%'}, LR: 0.000100000
# Removed old model with accuracy 90.35%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_50.pth
# Model saved after epoch 52 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_52.pth
#
# Epoch 53/2000, Train Loss: 0.250391489, Train-Class-Acc: {0: '49.58%', 1: '94.02%', 2: '88.24%', 3: '94.15%', 4: '83.81%'}, Val Loss: 0.233905340, Val Accuracy: 91.31%, Val-Class-Acc: {0: '55.60%', 1: '95.01%', 2: '91.45%', 3: '93.60%', 4: '88.93%'}, LR: 0.000100000
# Removed old model with accuracy 90.54%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_46.pth
# Model saved after epoch 53 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_53.pth
#
# Epoch 54/2000, Train Loss: 0.249994968, Train-Class-Acc: {0: '49.44%', 1: '93.90%', 2: '88.68%', 3: '94.20%', 4: '83.13%'}, Val Loss: 0.246270582, Val Accuracy: 90.83%, Val-Class-Acc: {0: '57.72%', 1: '91.73%', 2: '86.54%', 3: '95.32%', 4: '96.56%'}, LR: 0.000100000
# Removed old model with accuracy 90.60%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_52.pth
# Model saved after epoch 54 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_54.pth
#
# Epoch 55/2000, Train Loss: 0.232236260, Train-Class-Acc: {0: '52.81%', 1: '94.50%', 2: '89.34%', 3: '94.72%', 4: '84.37%'}, Val Loss: 0.225461386, Val Accuracy: 91.68%, Val-Class-Acc: {0: '64.52%', 1: '93.56%', 2: '88.10%', 3: '94.10%', 4: '96.65%'}, LR: 0.000100000
# Removed old model with accuracy 90.71%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_51.pth
# Model saved after epoch 55 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_55.pth
#
# Epoch 56/2000, Train Loss: 0.230918442, Train-Class-Acc: {0: '53.26%', 1: '94.48%', 2: '89.53%', 3: '94.52%', 4: '85.83%'}, Val Loss: 0.216422999, Val Accuracy: 91.87%, Val-Class-Acc: {0: '61.26%', 1: '94.42%', 2: '91.62%', 3: '94.23%', 4: '91.39%'}, LR: 0.000100000
# Removed old model with accuracy 90.83%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_54.pth
# Model saved after epoch 56 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_56.pth
#
# Epoch 57/2000, Train Loss: 0.220882921, Train-Class-Acc: {0: '55.82%', 1: '94.76%', 2: '89.90%', 3: '94.87%', 4: '85.43%'}, Val Loss: 0.211364312, Val Accuracy: 92.08%, Val-Class-Acc: {0: '64.93%', 1: '93.03%', 2: '91.53%', 3: '94.54%', 4: '95.75%'}, LR: 0.000100000
# Removed old model with accuracy 90.95%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_47.pth
# Model saved after epoch 57 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_57.pth
#
# Epoch 58/2000, Train Loss: 0.247852181, Train-Class-Acc: {0: '51.28%', 1: '93.77%', 2: '89.30%', 3: '94.03%', 4: '85.46%'}, Val Loss: 0.260231406, Val Accuracy: 90.31%, Val-Class-Acc: {0: '59.28%', 1: '90.72%', 2: '83.79%', 3: '95.49%', 4: '97.63%'}, LR: 0.000100000
# Epoch 59/2000, Train Loss: 0.246259359, Train-Class-Acc: {0: '52.16%', 1: '93.81%', 2: '88.65%', 3: '94.17%', 4: '83.95%'}, Val Loss: 0.240065312, Val Accuracy: 90.83%, Val-Class-Acc: {0: '51.58%', 1: '94.23%', 2: '95.36%', 3: '92.14%', 4: '88.37%'}, LR: 0.000100000
# Epoch 60/2000, Train Loss: 0.224183976, Train-Class-Acc: {0: '55.75%', 1: '94.59%', 2: '89.45%', 3: '94.71%', 4: '85.82%'}, Val Loss: 0.208772563, Val Accuracy: 92.09%, Val-Class-Acc: {0: '63.85%', 1: '94.58%', 2: '91.11%', 3: '93.77%', 4: '93.96%'}, LR: 0.000100000
# Removed old model with accuracy 90.96%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_49.pth
# Model saved after epoch 60 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_60.pth
#
# Epoch 61/2000, Train Loss: 0.212133620, Train-Class-Acc: {0: '57.75%', 1: '94.80%', 2: '90.63%', 3: '95.00%', 4: '87.01%'}, Val Loss: 0.217511968, Val Accuracy: 91.80%, Val-Class-Acc: {0: '59.50%', 1: '94.14%', 2: '94.27%', 3: '93.50%', 4: '91.13%'}, LR: 0.000100000
# Removed old model with accuracy 91.31%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_53.pth
# Model saved after epoch 61 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_61.pth
#
# Epoch 62/2000, Train Loss: 0.215422097, Train-Class-Acc: {0: '57.32%', 1: '94.66%', 2: '90.43%', 3: '94.80%', 4: '87.03%'}, Val Loss: 0.204983969, Val Accuracy: 92.07%, Val-Class-Acc: {0: '64.93%', 1: '94.35%', 2: '91.77%', 3: '93.80%', 4: '92.92%'}, LR: 0.000100000
# Removed old model with accuracy 91.68%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_55.pth
# Model saved after epoch 62 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_62.pth
#
# Epoch 63/2000, Train Loss: 0.213932494, Train-Class-Acc: {0: '58.08%', 1: '94.72%', 2: '90.66%', 3: '94.86%', 4: '86.69%'}, Val Loss: 0.250356829, Val Accuracy: 90.03%, Val-Class-Acc: {0: '48.04%', 1: '92.55%', 2: '97.20%', 3: '91.07%', 4: '89.25%'}, LR: 0.000100000
# Epoch 64/2000, Train Loss: 0.230634282, Train-Class-Acc: {0: '55.36%', 1: '94.23%', 2: '90.01%', 3: '94.26%', 4: '85.68%'}, Val Loss: 0.222893003, Val Accuracy: 91.48%, Val-Class-Acc: {0: '64.42%', 1: '92.16%', 2: '87.78%', 3: '94.69%', 4: '98.31%'}, LR: 0.000100000
# Epoch 65/2000, Train Loss: 0.206214838, Train-Class-Acc: {0: '59.25%', 1: '94.95%', 2: '90.89%', 3: '95.08%', 4: '87.13%'}, Val Loss: 0.204025332, Val Accuracy: 92.45%, Val-Class-Acc: {0: '70.04%', 1: '93.73%', 2: '88.75%', 3: '95.02%', 4: '96.71%'}, LR: 0.000100000
# Removed old model with accuracy 91.80%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_61.pth
# Model saved after epoch 65 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_65.pth
#
# Epoch 66/2000, Train Loss: 0.217500390, Train-Class-Acc: {0: '57.95%', 1: '94.51%', 2: '90.23%', 3: '94.57%', 4: '87.06%'}, Val Loss: 0.201542793, Val Accuracy: 92.41%, Val-Class-Acc: {0: '70.86%', 1: '93.70%', 2: '89.49%', 3: '94.74%', 4: '95.82%'}, LR: 0.000100000
# Removed old model with accuracy 91.87%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_56.pth
# Model saved after epoch 66 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_66.pth
#
# Epoch 67/2000, Train Loss: 0.202915619, Train-Class-Acc: {0: '59.79%', 1: '94.92%', 2: '91.32%', 3: '95.14%', 4: '88.03%'}, Val Loss: 0.196502935, Val Accuracy: 92.61%, Val-Class-Acc: {0: '70.96%', 1: '94.24%', 2: '89.85%', 3: '94.74%', 4: '95.14%'}, LR: 0.000100000
# Removed old model with accuracy 92.07%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_62.pth
# Model saved after epoch 67 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_67.pth
#
# Epoch 68/2000, Train Loss: 0.204699690, Train-Class-Acc: {0: '60.58%', 1: '94.85%', 2: '90.71%', 3: '94.98%', 4: '87.81%'}, Val Loss: 0.208448363, Val Accuracy: 92.23%, Val-Class-Acc: {0: '68.78%', 1: '93.52%', 2: '88.03%', 3: '94.68%', 4: '98.22%'}, LR: 0.000100000
# Removed old model with accuracy 92.08%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_57.pth
# Model saved after epoch 68 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_68.pth
#
# Epoch 69/2000, Train Loss: 0.203034653, Train-Class-Acc: {0: '60.30%', 1: '94.89%', 2: '90.92%', 3: '95.03%', 4: '87.58%'}, Val Loss: 0.194410534, Val Accuracy: 92.69%, Val-Class-Acc: {0: '69.75%', 1: '94.74%', 2: '90.73%', 3: '94.77%', 4: '93.46%'}, LR: 0.000100000
# Removed old model with accuracy 92.09%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_60.pth
# Model saved after epoch 69 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_69.pth
#
# Epoch 70/2000, Train Loss: 0.251197778, Train-Class-Acc: {0: '54.14%', 1: '93.54%', 2: '89.33%', 3: '93.77%', 4: '85.47%'}, Val Loss: 0.305985925, Val Accuracy: 88.58%, Val-Class-Acc: {0: '56.01%', 1: '88.86%', 2: '80.28%', 3: '94.08%', 4: '98.81%'}, LR: 0.000100000
# Epoch 71/2000, Train Loss: 0.225521034, Train-Class-Acc: {0: '57.07%', 1: '94.26%', 2: '89.47%', 3: '94.46%', 4: '85.59%'}, Val Loss: 0.205553766, Val Accuracy: 92.23%, Val-Class-Acc: {0: '70.16%', 1: '93.33%', 2: '88.82%', 3: '94.29%', 4: '98.25%'}, LR: 0.000100000
# Epoch 72/2000, Train Loss: 0.198939884, Train-Class-Acc: {0: '61.01%', 1: '94.98%', 2: '91.42%', 3: '95.13%', 4: '88.28%'}, Val Loss: 0.203536908, Val Accuracy: 92.52%, Val-Class-Acc: {0: '70.82%', 1: '94.17%', 2: '87.75%', 3: '94.65%', 4: '98.17%'}, LR: 0.000100000
# Removed old model with accuracy 92.23%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_68.pth
# Model saved after epoch 72 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_72.pth
#
# Epoch 73/2000, Train Loss: 0.197224316, Train-Class-Acc: {0: '61.62%', 1: '95.03%', 2: '91.30%', 3: '95.23%', 4: '88.31%'}, Val Loss: 0.205217742, Val Accuracy: 92.31%, Val-Class-Acc: {0: '69.87%', 1: '93.84%', 2: '87.77%', 3: '94.44%', 4: '98.47%'}, LR: 0.000100000
# Epoch 74/2000, Train Loss: 0.195988175, Train-Class-Acc: {0: '61.67%', 1: '95.08%', 2: '91.48%', 3: '95.15%', 4: '88.62%'}, Val Loss: 0.224856986, Val Accuracy: 91.33%, Val-Class-Acc: {0: '54.51%', 1: '94.45%', 2: '95.57%', 3: '92.27%', 4: '90.24%'}, LR: 0.000100000
# Epoch 75/2000, Train Loss: 0.202755774, Train-Class-Acc: {0: '60.42%', 1: '94.80%', 2: '90.93%', 3: '95.02%', 4: '88.16%'}, Val Loss: 0.209371303, Val Accuracy: 92.15%, Val-Class-Acc: {0: '69.16%', 1: '92.77%', 2: '88.38%', 3: '94.94%', 4: '98.52%'}, LR: 0.000100000
# Epoch 76/2000, Train Loss: 0.198186498, Train-Class-Acc: {0: '61.94%', 1: '95.02%', 2: '90.95%', 3: '95.08%', 4: '88.06%'}, Val Loss: 0.187467123, Val Accuracy: 93.02%, Val-Class-Acc: {0: '72.57%', 1: '94.50%', 2: '90.18%', 3: '94.83%', 4: '96.74%'}, LR: 0.000100000
# Removed old model with accuracy 92.41%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_66.pth
# Model saved after epoch 76 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_76.pth
#
# Epoch 77/2000, Train Loss: 0.199641099, Train-Class-Acc: {0: '61.20%', 1: '94.94%', 2: '91.27%', 3: '94.97%', 4: '88.24%'}, Val Loss: 0.195163350, Val Accuracy: 92.73%, Val-Class-Acc: {0: '72.81%', 1: '93.95%', 2: '89.25%', 3: '94.46%', 4: '98.40%'}, LR: 0.000100000
# Removed old model with accuracy 92.45%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_65.pth
# Model saved after epoch 77 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_77.pth
#
# Epoch 78/2000, Train Loss: 0.206269054, Train-Class-Acc: {0: '60.65%', 1: '94.63%', 2: '90.66%', 3: '94.84%', 4: '88.07%'}, Val Loss: 0.188090862, Val Accuracy: 92.75%, Val-Class-Acc: {0: '69.24%', 1: '94.04%', 2: '92.21%', 3: '93.75%', 4: '98.23%'}, LR: 0.000100000
# Removed old model with accuracy 92.52%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_72.pth
# Model saved after epoch 78 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_78.pth
#
# Epoch 79/2000, Train Loss: 0.193442927, Train-Class-Acc: {0: '62.67%', 1: '95.05%', 2: '91.67%', 3: '95.14%', 4: '88.75%'}, Val Loss: 0.188442092, Val Accuracy: 92.65%, Val-Class-Acc: {0: '67.95%', 1: '94.16%', 2: '93.42%', 3: '93.55%', 4: '96.29%'}, LR: 0.000100000
# Removed old model with accuracy 92.61%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_67.pth
# Model saved after epoch 79 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_79.pth
#
# Epoch 80/2000, Train Loss: 0.196498828, Train-Class-Acc: {0: '62.07%', 1: '94.99%', 2: '91.82%', 3: '95.01%', 4: '88.83%'}, Val Loss: 0.257161841, Val Accuracy: 90.50%, Val-Class-Acc: {0: '62.09%', 1: '90.31%', 2: '84.11%', 3: '95.58%', 4: '98.88%'}, LR: 0.000100000
# Epoch 81/2000, Train Loss: 0.196253158, Train-Class-Acc: {0: '62.05%', 1: '94.91%', 2: '91.41%', 3: '95.09%', 4: '88.96%'}, Val Loss: 0.196433441, Val Accuracy: 92.43%, Val-Class-Acc: {0: '65.56%', 1: '95.52%', 2: '91.92%', 3: '93.58%', 4: '92.52%'}, LR: 0.000100000
# Epoch 82/2000, Train Loss: 0.190032825, Train-Class-Acc: {0: '63.39%', 1: '95.19%', 2: '92.00%', 3: '95.19%', 4: '89.09%'}, Val Loss: 0.184225056, Val Accuracy: 93.14%, Val-Class-Acc: {0: '73.42%', 1: '94.49%', 2: '90.30%', 3: '94.81%', 4: '97.43%'}, LR: 0.000100000
# Removed old model with accuracy 92.65%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_79.pth
# Model saved after epoch 82 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_82.pth
#
# Epoch 83/2000, Train Loss: 0.218426537, Train-Class-Acc: {0: '59.14%', 1: '94.39%', 2: '90.17%', 3: '94.54%', 4: '87.54%'}, Val Loss: 0.200037318, Val Accuracy: 92.45%, Val-Class-Acc: {0: '66.79%', 1: '95.69%', 2: '92.07%', 3: '93.63%', 4: '90.99%'}, LR: 0.000100000
# Epoch 84/2000, Train Loss: 0.190026363, Train-Class-Acc: {0: '63.17%', 1: '95.14%', 2: '92.05%', 3: '95.19%', 4: '88.80%'}, Val Loss: 0.188666926, Val Accuracy: 93.27%, Val-Class-Acc: {0: '74.46%', 1: '94.75%', 2: '88.99%', 3: '95.17%', 4: '97.95%'}, LR: 0.000100000
# Removed old model with accuracy 92.69%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_69.pth
# Model saved after epoch 84 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_84.pth
#
# Epoch 85/2000, Train Loss: 0.186794352, Train-Class-Acc: {0: '64.19%', 1: '95.20%', 2: '91.91%', 3: '95.28%', 4: '89.10%'}, Val Loss: 0.194562522, Val Accuracy: 92.30%, Val-Class-Acc: {0: '65.07%', 1: '94.53%', 2: '94.13%', 3: '93.33%', 4: '92.67%'}, LR: 0.000100000
# Epoch 86/2000, Train Loss: 0.186909296, Train-Class-Acc: {0: '64.00%', 1: '95.26%', 2: '91.93%', 3: '95.25%', 4: '89.31%'}, Val Loss: 0.182852549, Val Accuracy: 92.83%, Val-Class-Acc: {0: '70.49%', 1: '94.63%', 2: '92.51%', 3: '94.02%', 4: '94.74%'}, LR: 0.000100000
# Removed old model with accuracy 92.73%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_77.pth
# Model saved after epoch 86 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_86.pth
#
# Epoch 87/2000, Train Loss: 0.184076840, Train-Class-Acc: {0: '64.37%', 1: '95.23%', 2: '92.41%', 3: '95.34%', 4: '89.80%'}, Val Loss: 0.190462331, Val Accuracy: 93.20%, Val-Class-Acc: {0: '74.51%', 1: '94.41%', 2: '89.19%', 3: '95.12%', 4: '98.40%'}, LR: 0.000100000
# Removed old model with accuracy 92.75%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_78.pth
# Model saved after epoch 87 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_87.pth
#
# Epoch 88/2000, Train Loss: 0.184855705, Train-Class-Acc: {0: '64.25%', 1: '95.27%', 2: '91.86%', 3: '95.31%', 4: '89.73%'}, Val Loss: 0.199376197, Val Accuracy: 92.16%, Val-Class-Acc: {0: '61.93%', 1: '94.78%', 2: '94.46%', 3: '93.22%', 4: '91.84%'}, LR: 0.000100000
# Epoch 89/2000, Train Loss: 0.187888177, Train-Class-Acc: {0: '64.17%', 1: '95.13%', 2: '91.77%', 3: '95.19%', 4: '89.27%'}, Val Loss: 0.194534367, Val Accuracy: 92.71%, Val-Class-Acc: {0: '67.30%', 1: '96.02%', 2: '91.65%', 3: '94.35%', 4: '90.26%'}, LR: 0.000100000
# Epoch 90/2000, Train Loss: 0.190975668, Train-Class-Acc: {0: '63.41%', 1: '95.06%', 2: '91.76%', 3: '95.19%', 4: '88.44%'}, Val Loss: 0.180056286, Val Accuracy: 93.40%, Val-Class-Acc: {0: '75.96%', 1: '94.46%', 2: '90.38%', 3: '95.20%', 4: '97.37%'}, LR: 0.000100000
# Removed old model with accuracy 92.83%, and file was at Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_86.pth
# Model saved after epoch 90 to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_90.pth
#
# Epoch 91/2000, Train Loss: 0.183546653, Train-Class-Acc: {0: '64.75%', 1: '95.29%', 2: '92.03%', 3: '95.35%', 4: '90.03%'}, Val Loss: 0.188640240, Val Accuracy: 92.70%, Val-Class-Acc: {0: '67.91%', 1: '95.71%', 2: '91.89%', 3: '93.66%', 4: '93.03%'}, LR: 0.000100000
# Epoch 92/2000, Train Loss: 0.188672886, Train-Class-Acc: {0: '63.76%', 1: '95.13%', 2: '91.92%', 3: '95.12%', 4: '89.14%'}, Val Loss: 0.190033514, Val Accuracy: 92.81%, Val-Class-Acc: {0: '73.57%', 1: '93.35%', 2: '89.64%', 3: '94.97%', 4: '98.66%'}, LR: 0.000100000
# Epoch 93/2000, Train Loss: 0.208245419, Train-Class-Acc: {0: '61.48%', 1: '94.61%', 2: '91.09%', 3: '94.71%', 4: '88.47%'}, Val Loss: 0.180655668, Val Accuracy: 92.96%, Val-Class-Acc: {0: '70.81%', 1: '94.30%', 2: '94.28%', 3: '93.95%', 4: '94.75%'}, LR: 0.000100000
# Epoch 94/2000, Train Loss: 0.172917373, Train-Class-Acc: {0: '66.95%', 1: '95.56%', 2: '92.80%', 3: '95.68%', 4: '89.79%'}, Val Loss: 0.183534139, Val Accuracy: 92.76%, Val-Class-Acc: {0: '68.23%', 1: '95.04%', 2: '92.81%', 3: '93.68%', 4: '94.42%'}, LR: 0.000100000
# Epoch 95/2000, Train Loss: 0.222327435, Train-Class-Acc: {0: '59.31%', 1: '94.31%', 2: '90.54%', 3: '94.19%', 4: '88.38%'}, Val Loss: 0.249718289, Val Accuracy: 90.63%, Val-Class-Acc: {0: '63.55%', 1: '89.96%', 2: '86.08%', 3: '95.17%', 4: '99.08%'}, LR: 0.000100000
# ...
# Epoch 1955/2000, Train Loss: 0.004110784, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.177393933, Val Accuracy: 96.63%, Val-Class-Acc: {0: '88.89%', 1: '97.38%', 2: '90.88%', 3: '99.02%', 4: '98.44%'}, LR: 0.000100000
# Epoch 1956/2000, Train Loss: 0.004163807, Train-Class-Acc: {0: '99.49%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.177661777, Val Accuracy: 96.64%, Val-Class-Acc: {0: '88.61%', 1: '97.26%', 2: '91.17%', 3: '99.02%', 4: '98.73%'}, LR: 0.000100000
# Epoch 1957/2000, Train Loss: 0.004539601, Train-Class-Acc: {0: '99.43%', 1: '99.86%', 2: '99.99%', 3: '99.87%', 4: '99.99%'}, Val Loss: 0.191330158, Val Accuracy: 96.52%, Val-Class-Acc: {0: '88.85%', 1: '96.99%', 2: '90.43%', 3: '99.18%', 4: '98.98%'}, LR: 0.000100000
# Epoch 1958/2000, Train Loss: 0.004851183, Train-Class-Acc: {0: '99.33%', 1: '99.86%', 2: '99.99%', 3: '99.85%', 4: '99.98%'}, Val Loss: 0.183005460, Val Accuracy: 96.63%, Val-Class-Acc: {0: '88.50%', 1: '97.26%', 2: '91.02%', 3: '99.07%', 4: '98.79%'}, LR: 0.000100000
# Epoch 1959/2000, Train Loss: 0.004309028, Train-Class-Acc: {0: '99.43%', 1: '99.88%', 2: '99.99%', 3: '99.88%', 4: '99.99%'}, Val Loss: 0.176466072, Val Accuracy: 96.65%, Val-Class-Acc: {0: '88.31%', 1: '97.21%', 2: '91.38%', 3: '99.10%', 4: '98.63%'}, LR: 0.000100000
# Epoch 1960/2000, Train Loss: 0.004238407, Train-Class-Acc: {0: '99.43%', 1: '99.88%', 2: '99.98%', 3: '99.89%', 4: '99.98%'}, Val Loss: 0.178252668, Val Accuracy: 96.66%, Val-Class-Acc: {0: '88.42%', 1: '97.48%', 2: '91.14%', 3: '98.96%', 4: '98.49%'}, LR: 0.000100000
# Epoch 1961/2000, Train Loss: 0.004080778, Train-Class-Acc: {0: '99.48%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.187131553, Val Accuracy: 96.57%, Val-Class-Acc: {0: '88.42%', 1: '97.39%', 2: '90.32%', 3: '99.08%', 4: '98.77%'}, LR: 0.000100000
# Epoch 1962/2000, Train Loss: 0.004116327, Train-Class-Acc: {0: '99.50%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.171967529, Val Accuracy: 96.66%, Val-Class-Acc: {0: '88.20%', 1: '97.72%', 2: '91.83%', 3: '98.59%', 4: '97.96%'}, LR: 0.000100000
# Epoch 1963/2000, Train Loss: 0.004427337, Train-Class-Acc: {0: '99.39%', 1: '99.87%', 2: '99.99%', 3: '99.87%', 4: '99.99%'}, Val Loss: 0.177285293, Val Accuracy: 96.66%, Val-Class-Acc: {0: '88.60%', 1: '97.37%', 2: '91.09%', 3: '99.05%', 4: '98.60%'}, LR: 0.000100000
# Epoch 1964/2000, Train Loss: 0.004296808, Train-Class-Acc: {0: '99.43%', 1: '99.88%', 2: '99.99%', 3: '99.88%', 4: '99.97%'}, Val Loss: 0.184058916, Val Accuracy: 96.58%, Val-Class-Acc: {0: '88.74%', 1: '97.54%', 2: '90.39%', 3: '99.04%', 4: '98.16%'}, LR: 0.000100000
# Epoch 1965/2000, Train Loss: 0.124257145, Train-Class-Acc: {0: '93.45%', 1: '98.45%', 2: '98.19%', 3: '98.73%', 4: '98.57%'}, Val Loss: 0.343904030, Val Accuracy: 93.98%, Val-Class-Acc: {0: '79.79%', 1: '95.34%', 2: '96.90%', 3: '93.54%', 4: '93.88%'}, LR: 0.000100000
# Epoch 1966/2000, Train Loss: 0.074194868, Train-Class-Acc: {0: '90.46%', 1: '98.53%', 2: '98.86%', 3: '98.48%', 4: '99.08%'}, Val Loss: 0.187345777, Val Accuracy: 96.07%, Val-Class-Acc: {0: '86.65%', 1: '97.41%', 2: '89.86%', 3: '98.25%', 4: '98.06%'}, LR: 0.000100000
# Epoch 1967/2000, Train Loss: 0.007740895, Train-Class-Acc: {0: '98.83%', 1: '99.79%', 2: '99.94%', 3: '99.79%', 4: '99.90%'}, Val Loss: 0.168387480, Val Accuracy: 96.28%, Val-Class-Acc: {0: '87.28%', 1: '97.16%', 2: '90.86%', 3: '98.75%', 4: '97.53%'}, LR: 0.000100000
# Epoch 1968/2000, Train Loss: 0.005472899, Train-Class-Acc: {0: '99.32%', 1: '99.86%', 2: '99.98%', 3: '99.87%', 4: '99.98%'}, Val Loss: 0.176675002, Val Accuracy: 96.24%, Val-Class-Acc: {0: '87.32%', 1: '97.18%', 2: '90.06%', 3: '98.84%', 4: '97.94%'}, LR: 0.000100000
# Epoch 1969/2000, Train Loss: 0.005022383, Train-Class-Acc: {0: '99.42%', 1: '99.87%', 2: '99.98%', 3: '99.88%', 4: '99.99%'}, Val Loss: 0.175729946, Val Accuracy: 96.31%, Val-Class-Acc: {0: '87.60%', 1: '97.10%', 2: '90.52%', 3: '98.88%', 4: '98.00%'}, LR: 0.000100000
# Epoch 1970/2000, Train Loss: 0.004786980, Train-Class-Acc: {0: '99.46%', 1: '99.87%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.174351232, Val Accuracy: 96.34%, Val-Class-Acc: {0: '87.87%', 1: '97.31%', 2: '90.42%', 3: '98.81%', 4: '97.80%'}, LR: 0.000100000
# Epoch 1971/2000, Train Loss: 0.004653938, Train-Class-Acc: {0: '99.48%', 1: '99.87%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.168971447, Val Accuracy: 96.37%, Val-Class-Acc: {0: '87.37%', 1: '97.21%', 2: '90.94%', 3: '98.81%', 4: '97.99%'}, LR: 0.000100000
# Epoch 1972/2000, Train Loss: 0.004555977, Train-Class-Acc: {0: '99.48%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.174853485, Val Accuracy: 96.34%, Val-Class-Acc: {0: '87.62%', 1: '97.01%', 2: '90.65%', 3: '98.92%', 4: '98.34%'}, LR: 0.000100000
# Epoch 1973/2000, Train Loss: 0.004472207, Train-Class-Acc: {0: '99.49%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.171336473, Val Accuracy: 96.41%, Val-Class-Acc: {0: '88.23%', 1: '97.14%', 2: '90.73%', 3: '98.91%', 4: '98.12%'}, LR: 0.000100000
# Epoch 1974/2000, Train Loss: 0.004380926, Train-Class-Acc: {0: '99.50%', 1: '99.88%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.171439266, Val Accuracy: 96.43%, Val-Class-Acc: {0: '88.04%', 1: '97.27%', 2: '90.66%', 3: '98.90%', 4: '98.02%'}, LR: 0.000100000
# Epoch 1975/2000, Train Loss: 0.004327831, Train-Class-Acc: {0: '99.52%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.169103862, Val Accuracy: 96.42%, Val-Class-Acc: {0: '87.60%', 1: '97.24%', 2: '90.80%', 3: '98.91%', 4: '98.09%'}, LR: 0.000100000
# Epoch 1976/2000, Train Loss: 0.004396903, Train-Class-Acc: {0: '99.46%', 1: '99.88%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.163026438, Val Accuracy: 96.50%, Val-Class-Acc: {0: '88.09%', 1: '97.50%', 2: '91.20%', 3: '98.66%', 4: '97.93%'}, LR: 0.000100000
# Epoch 1977/2000, Train Loss: 0.004292384, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.172191579, Val Accuracy: 96.46%, Val-Class-Acc: {0: '88.10%', 1: '97.14%', 2: '90.85%', 3: '98.95%', 4: '98.34%'}, LR: 0.000100000
# Epoch 1978/2000, Train Loss: 0.004209577, Train-Class-Acc: {0: '99.51%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.174238231, Val Accuracy: 96.45%, Val-Class-Acc: {0: '87.89%', 1: '97.29%', 2: '90.64%', 3: '98.94%', 4: '98.19%'}, LR: 0.000100000
# Epoch 1979/2000, Train Loss: 0.004159761, Train-Class-Acc: {0: '99.53%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.170672062, Val Accuracy: 96.49%, Val-Class-Acc: {0: '88.24%', 1: '97.29%', 2: '90.84%', 3: '98.92%', 4: '98.17%'}, LR: 0.000100000
# Epoch 1980/2000, Train Loss: 0.004144604, Train-Class-Acc: {0: '99.53%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.172543442, Val Accuracy: 96.50%, Val-Class-Acc: {0: '88.21%', 1: '97.32%', 2: '90.71%', 3: '98.91%', 4: '98.33%'}, LR: 0.000100000
# Epoch 1981/2000, Train Loss: 0.004113383, Train-Class-Acc: {0: '99.54%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.174819101, Val Accuracy: 96.48%, Val-Class-Acc: {0: '87.94%', 1: '97.27%', 2: '90.64%', 3: '98.99%', 4: '98.39%'}, LR: 0.000100000
# Epoch 1982/2000, Train Loss: 0.004164473, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.170725889, Val Accuracy: 96.51%, Val-Class-Acc: {0: '87.90%', 1: '97.21%', 2: '91.05%', 3: '98.93%', 4: '98.49%'}, LR: 0.000100000
# Epoch 1983/2000, Train Loss: 0.004064877, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.172068038, Val Accuracy: 96.52%, Val-Class-Acc: {0: '88.23%', 1: '97.41%', 2: '90.78%', 3: '98.91%', 4: '98.18%'}, LR: 0.000100000
# Epoch 1984/2000, Train Loss: 0.004172662, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.169133420, Val Accuracy: 96.55%, Val-Class-Acc: {0: '88.25%', 1: '97.47%', 2: '91.02%', 3: '98.84%', 4: '98.12%'}, LR: 0.000100000
# Epoch 1985/2000, Train Loss: 0.004076790, Train-Class-Acc: {0: '99.51%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.172930763, Val Accuracy: 96.54%, Val-Class-Acc: {0: '88.40%', 1: '97.25%', 2: '90.94%', 3: '98.96%', 4: '98.40%'}, LR: 0.000100000
# Epoch 1986/2000, Train Loss: 0.004067148, Train-Class-Acc: {0: '99.53%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.167410339, Val Accuracy: 96.58%, Val-Class-Acc: {0: '88.16%', 1: '97.43%', 2: '91.35%', 3: '98.82%', 4: '98.16%'}, LR: 0.000100000
# Epoch 1987/2000, Train Loss: 0.004073526, Train-Class-Acc: {0: '99.51%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.171314846, Val Accuracy: 96.57%, Val-Class-Acc: {0: '88.07%', 1: '97.31%', 2: '91.11%', 3: '98.95%', 4: '98.45%'}, LR: 0.000100000
# Epoch 1988/2000, Train Loss: 0.004002898, Train-Class-Acc: {0: '99.51%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.172047678, Val Accuracy: 96.54%, Val-Class-Acc: {0: '88.35%', 1: '97.26%', 2: '91.01%', 3: '98.93%', 4: '98.42%'}, LR: 0.000100000
# Epoch 1989/2000, Train Loss: 0.004009760, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.174426907, Val Accuracy: 96.56%, Val-Class-Acc: {0: '88.35%', 1: '97.30%', 2: '90.78%', 3: '99.02%', 4: '98.52%'}, LR: 0.000100000
# Epoch 1990/2000, Train Loss: 0.004024898, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.176395344, Val Accuracy: 96.55%, Val-Class-Acc: {0: '88.38%', 1: '97.29%', 2: '90.78%', 3: '99.01%', 4: '98.44%'}, LR: 0.000100000
# Epoch 1991/2000, Train Loss: 0.003991419, Train-Class-Acc: {0: '99.51%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.170077652, Val Accuracy: 96.61%, Val-Class-Acc: {0: '88.48%', 1: '97.49%', 2: '91.18%', 3: '98.87%', 4: '98.10%'}, LR: 0.000100000
# Epoch 1992/2000, Train Loss: 0.003993344, Train-Class-Acc: {0: '99.54%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.176833762, Val Accuracy: 96.58%, Val-Class-Acc: {0: '88.54%', 1: '97.46%', 2: '90.70%', 3: '98.93%', 4: '98.43%'}, LR: 0.000100000
# Epoch 1993/2000, Train Loss: 0.004030743, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.178607156, Val Accuracy: 96.56%, Val-Class-Acc: {0: '88.50%', 1: '97.39%', 2: '90.63%', 3: '98.97%', 4: '98.49%'}, LR: 0.000100000
# Epoch 1994/2000, Train Loss: 0.004099007, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.180395611, Val Accuracy: 96.59%, Val-Class-Acc: {0: '88.59%', 1: '97.49%', 2: '90.55%', 3: '98.98%', 4: '98.47%'}, LR: 0.000100000
# Epoch 1995/2000, Train Loss: 0.003935636, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.174364990, Val Accuracy: 96.59%, Val-Class-Acc: {0: '88.20%', 1: '97.27%', 2: '91.09%', 3: '98.94%', 4: '98.77%'}, LR: 0.000100000
# Epoch 1996/2000, Train Loss: 0.004068612, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.89%', 4: '99.99%'}, Val Loss: 0.178281165, Val Accuracy: 96.57%, Val-Class-Acc: {0: '88.14%', 1: '97.33%', 2: '90.86%', 3: '99.08%', 4: '98.32%'}, LR: 0.000100000
# Epoch 1997/2000, Train Loss: 0.004388106, Train-Class-Acc: {0: '99.43%', 1: '99.87%', 2: '99.99%', 3: '99.88%', 4: '99.98%'}, Val Loss: 0.180754264, Val Accuracy: 96.54%, Val-Class-Acc: {0: '88.19%', 1: '97.28%', 2: '90.81%', 3: '99.01%', 4: '98.45%'}, LR: 0.000100000
# Epoch 1998/2000, Train Loss: 0.003964227, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.177281795, Val Accuracy: 96.61%, Val-Class-Acc: {0: '88.65%', 1: '97.59%', 2: '90.68%', 3: '98.95%', 4: '98.15%'}, LR: 0.000100000
# Epoch 1999/2000, Train Loss: 0.003893745, Train-Class-Acc: {0: '99.52%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.175154814, Val Accuracy: 96.59%, Val-Class-Acc: {0: '88.33%', 1: '97.30%', 2: '91.23%', 3: '98.96%', 4: '98.38%'}, LR: 0.000100000
# Epoch 2000/2000, Train Loss: 0.003970615, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.176755074, Val Accuracy: 96.64%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, LR: 0.000100000
#
# Final model saved to Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_final.pth
#
# Training complete.
#
# Top 5 Models Sorted by Validation Accuracy:
# Epoch 1014/2000, Train Loss: 0.012935260, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.157351914, Val Accuracy: 96.89%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1014.pth
# Epoch 1705/2000, Train Loss: 0.005373254, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.152444242, Val Accuracy: 96.88%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1705.pth
# Epoch 1017/2000, Train Loss: 0.012442351, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.158692006, Val Accuracy: 96.87%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1017.pth
# Epoch 1019/2000, Train Loss: 0.012586767, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.156663019, Val Accuracy: 96.87%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1019.pth
# Epoch 1619/2000, Train Loss: 0.005769815, Train-Class-Acc: {0: '99.49%', 1: '99.89%', 2: '99.99%', 3: '99.90%', 4: '99.99%'}, Val Loss: 0.156142720, Val Accuracy: 96.87%, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1619.pth
#
#
# Epoch 1014/2000, Train Loss: 0.0129, Val Loss: 0.1574, Val Accuracy: 96.89%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1014.pth
# Epoch 1705/2000, Train Loss: 0.0054, Val Loss: 0.1524, Val Accuracy: 96.88%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1705.pth
# Epoch 1017/2000, Train Loss: 0.0124, Val Loss: 0.1587, Val Accuracy: 96.87%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1017.pth
# Epoch 1019/2000, Train Loss: 0.0126, Val Loss: 0.1567, Val Accuracy: 96.87%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1019.pth
# Epoch 1619/2000, Train Loss: 0.0058, Val Loss: 0.1561, Val Accuracy: 96.87%, Model Path: Class_Incremental_CL\Classif_Bi_Dir_GRU_Model\Trained_models\Baseline\Period_4\1st_try\BiGRUWithAttention_epoch_1619.pth
#
# class_gru_model:
# BiGRUWithAttention(
#   (gru): GRU(7, 64, num_layers=4, batch_first=True, bidirectional=True)
#   (attention_fc): Linear(in_features=128, out_features=128, bias=True)
#   (fc): Linear(in_features=128, out_features=5, bias=True)
#   (dropout): Dropout(p=0.0, inplace=False)
# )
#
# unique_classes = [0 1 2 3 4]
# num_classes = 5

# %%
# === Post-training Evaluation: Update .pth with val accuracy and class-wise accuracy for Baseline Period 4 ===

# Rebuild evaluation model
model_template = BiGRUWithAttention(
    input_size=Number_features,
    hidden_size=64,
    output_size=num_classes,
    num_layers=4
)

# Prepare validation data
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)
criterion = nn.CrossEntropyLoss()

# Your model folder
model_folder = 'Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try'
ckpt_paths = sorted(glob.glob(os.path.join(model_folder, "*.pth")))

# Loop through and update each model
for file_path in ckpt_paths:
    model_copy = copy.deepcopy(model_template).to(device)
    checkpoint = torch.load(file_path, map_location=device)
    model_copy.load_state_dict(checkpoint['model_state_dict'])

    add_val_class_acc(
        model_copy=model_copy,
        output_size=num_classes,
        criterion=criterion,
        X_val=X_val_tensor,
        y_val=y_val_tensor,
        file_path=file_path,
        model_checkpoint=checkpoint,
        batch_size=64
    )

# 顯示 summary
show_val_accuracy_from_checkpoints(model_folder)
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\2472624244.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_path, map_location=device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val, dtype=torch.long).to(device)
# ✅ Updated: BiGRUWithAttention_epoch_1014.pth | Acc: 0.9689 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_epoch_1014.pth
# ✅ Updated: BiGRUWithAttention_epoch_1017.pth | Acc: 0.9687 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_epoch_1017.pth
# ✅ Updated: BiGRUWithAttention_epoch_1019.pth | Acc: 0.9687 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_epoch_1019.pth
# ✅ Updated: BiGRUWithAttention_epoch_1619.pth | Acc: 0.9687 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_epoch_1619.pth
# ✅ Updated: BiGRUWithAttention_epoch_1705.pth | Acc: 0.9688 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_epoch_1705.pth
# ✅ Updated: BiGRUWithAttention_final.pth | Acc: 0.9664 | Saved to: Class_Incremental_CL/Classif_Bi_Dir_GRU_Model/Trained_models/Baseline/Period_4/1st_try\BiGRUWithAttention_final.pth
#
# 📝 Summary of val_accuracy and Val-Class-Acc:
# BiGRUWithAttention_epoch_1014.pth: val_accuracy = 0.9689, Val-Class-Acc: {0: '89.55%', 1: '98.16%', 2: '90.90%', 3: '98.64%', 4: '99.18%'}
# BiGRUWithAttention_epoch_1017.pth: val_accuracy = 0.9687, Val-Class-Acc: {0: '89.96%', 1: '97.95%', 2: '90.92%', 3: '98.78%', 4: '99.06%'}
# BiGRUWithAttention_epoch_1019.pth: val_accuracy = 0.9687, Val-Class-Acc: {0: '89.96%', 1: '97.94%', 2: '91.03%', 3: '98.76%', 4: '98.95%'}
# BiGRUWithAttention_epoch_1619.pth: val_accuracy = 0.9687, Val-Class-Acc: {0: '89.19%', 1: '97.56%', 2: '91.65%', 3: '99.07%', 4: '98.76%'}
# BiGRUWithAttention_epoch_1705.pth: val_accuracy = 0.9688, Val-Class-Acc: {0: '88.53%', 1: '97.63%', 2: '91.81%', 3: '99.05%', 4: '98.80%'}
# BiGRUWithAttention_final.pth: val_accuracy = 0.9664, Val-Class-Acc: {0: '88.88%', 1: '97.59%', 2: '90.79%', 3: '98.90%', 4: '98.39%'}
# C:\Users\james\AppData\Local\Temp\ipykernel_157796\1933887850.py:66: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")

# %% [markdown]
# ---
#
# ## 📊 Summary: Baseline Continual Learning
# ### (`Baseline_CL_Classif_Bi_Dir_GRU_Model.ipynb`)
#
# | Period | Model & Config                                                          | Validation Accuracy | Class-wise Accuracy                                                  |
# |--------|-------------------------------------------------------------------------|---------------------|-----------------------------------------------------------------------|
# | 1      | `BiGRUWithAttention`<br>(num_layers=4)<br>saved in `'1st_try'`         | **98.35%**          | {0: 98.63%, 1: 97.92%}                                               |
# | 2      | `BiGRUWithAttention`<br>(num_layers=4)<br>saved in `'1st_try'`         | **98.15%**          | {0: 99.46%, 1: 98.44%, 2: 90.81%}                                    |
# | 3      | `BiGRUWithAttention`<br>(num_layers=4)<br>saved in `'1st_try'`         | **97.81%**          | {0: 92.45%, 1: 98.51%, 2: 93.73%, 3: 98.82%}                         |
# | 4      | `BiGRUWithAttention`<br>(num_layers=4)<br>saved in `'1st_try'`         | **96.89%**          | {0: 89.55%, 1: 98.16%, 2: 90.90%, 3: 98.64%, 4: 99.18%}              |
#
# ---
