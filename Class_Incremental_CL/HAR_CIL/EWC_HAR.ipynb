# %% [markdown]
# ## __Check first before starting__

# %%
import os

# Change the working directory to the project root
# Working_directory = os.path.normpath("C:/Users/james/OneDrive/文件/Continual_Learning")
Working_directory = os.path.normpath("/mnt/mydisk/Continual_Learning_JL/Continual_Learning/")
os.chdir(Working_directory)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /mnt/mydisk/Continual_Learning_JL/Continual_Learning

# %% [markdown]
# ## __All imports__

# %%
# Operating system and file management
import os
import shutil
import contextlib
import traceback
import gc
import glob, copy
from collections import defaultdict
import subprocess
import time
import re

# Jupyter notebook widgets and display
import ipywidgets as widgets
from IPython.display import display

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Plotting and visualization
import matplotlib.pyplot as plt
from mpl_interactions import zoom_factory, panhandler

# Machine learning and preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pickle
from ta import trend, momentum, volatility, volume

# Mathematical and scientific computing
import math
from scipy.ndimage import gaussian_filter1d

# Type hinting
from typing import Callable, Tuple

# Deep learning with PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## __Dataset Setup & Preprocessing__

# %% [markdown]
# ### 📥 Step 1 — Set dataset path and load features & labels
# We will load the 561-dimensional features and original activity labels for both training and testing.

# %%
# Set working directory manually before running this cell if needed
BASE_DIR = "Class_Incremental_CL/HAR_CIL/har_dataset"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
TEST_DIR = os.path.join(BASE_DIR, "test")

# 活動對應（原始標籤）
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# Load feature and label data
X_train = np.loadtxt(os.path.join(TRAIN_DIR, "X_train.txt"))
y_train = np.loadtxt(os.path.join(TRAIN_DIR, "y_train.txt")).astype(int)
X_test = np.loadtxt(os.path.join(TEST_DIR, "X_test.txt"))
y_test = np.loadtxt(os.path.join(TEST_DIR, "y_test.txt")).astype(int)

print("Train shape:", X_train.shape, y_train.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (7352, 561) (7352,)
# Test shape: (2947, 561) (2947,)

# %% [markdown]
# ### 🧩 Step 2 — Define period label groups and final class remapping
# We will predefine the class mappings for each period to ensure consistency across the experiment.

# %%
# Period-to-original-label mapping
period_label_map = {
    1: [4, 5],           # SITTING, STANDING
    2: [4, 5, 1, 2, 3],  # + WALKING variants (merged)
    3: [4, 5, 1, 2, 3, 6],  # + LAYING
    4: [4, 5, 1, 2, 3, 6]   # same classes, but with walking variants separated
}

# Consistent label remapping across all periods (final label index)
final_class_map = {
    "SITTING": 0,
    "STANDING": 1,
    "WALKING": 2,
    "LAYING": 3,
    "WALKING_UPSTAIRS": 4,
    "WALKING_DOWNSTAIRS": 5
}

# Reverse mapping for readability
label_name_from_id = {v: k for k, v in final_class_map.items()}
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# %% [markdown]
# ### 🧪 Step 3 — Filter and remap datasets for each period
# We will build training and testing splits for each period using consistent class indices.

# %%
def map_label(label, period):
    name = activity_label_map[label]
    if period < 4:
        if name.startswith("WALKING"):
            return final_class_map["WALKING"]
        else:
            return final_class_map[name]
    else:
        return final_class_map[name]

def get_period_dataset(X, y, period):
    allowed_labels = period_label_map[period]
    mask = np.isin(y, allowed_labels)
    Xp = X[mask]
    yp = np.array([map_label(label, period) for label in y[mask]])
    return Xp, yp

# %% [markdown]
# ### 📊 Step 4 — Print artistic class distribution for each period
# We show each period's label map and class statistics to confirm correctness.

# %%
def print_class_distribution(y, var_name: str, label_map: dict) -> None:
    y = np.array(y).flatten()
    unique, counts = np.unique(y, return_counts=True)
    total = counts.sum()
    print(f"\n📦 Class Distribution for {var_name}")
    for i, c in zip(unique, counts):
        print(f"  ├─ Label {i:<2} ({label_map[i]:<20}) → {c:>5} samples ({(c/total)*100:>5.2f}%)")

# %%
period_datasets = {}

for period in range(1, 5):
    Xp_train, yp_train = get_period_dataset(X_train, y_train, period)
    Xp_test, yp_test = get_period_dataset(X_test, y_test, period)

    period_datasets[period] = {
        "train": (Xp_train, yp_train),
        "test": (Xp_test, yp_test)
    }

    print_class_distribution(yp_train, f"Period {period} (Train)", label_name_from_id)
    print_class_distribution(yp_test, f"Period {period} (Test)", label_name_from_id)
# Out:
# 📦 Class Distribution for Period 1 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (48.35%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (51.65%)
#
# 📦 Class Distribution for Period 1 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (48.00%)
#   ├─ Label 1  (STANDING            ) →   532 samples (52.00%)
#
# 📦 Class Distribution for Period 2 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (21.63%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (23.11%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (55.26%)
#
# 📦 Class Distribution for Period 2 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (20.37%)
#   ├─ Label 1  (STANDING            ) →   532 samples (22.07%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (57.55%)
#
# 📦 Class Distribution for Period 3 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (44.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#
# 📦 Class Distribution for Period 3 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (47.06%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#
# 📦 Class Distribution for Period 4 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  1226 samples (16.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →  1073 samples (14.59%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   986 samples (13.41%)
#
# 📦 Class Distribution for Period 4 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →   496 samples (16.83%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →   471 samples (15.98%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   420 samples (14.25%)

# %% [markdown]
# ## __Check GPU, CUDA, Pytorch__

# %% [markdown]
# ### GPU Details

# %%
# !nvidia-smi
# Out:
# Wed Apr 23 13:54:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.15              Driver Version: 570.86.15      CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:2A:00.0 Off |                  Off |
# | 54%   80C    P2            298W /  300W |   23769MiB /  49140MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:3D:00.0 Off |                  Off |
# | 53%   70C    P2             85W /  300W |   15987MiB /  49140MiB |      7%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               Off |   00000000:AB:00.0 Off |                  Off |
# | 30%   33C    P3             24W /  300W |      15MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    0   N/A  N/A         3953719      C   python                                19778MiB |
# |    1   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    1   N/A  N/A         4062997      C   ...conda3/envs/dmytro/bin/python      15964MiB |
# |    2   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### CUDA Details

# %%
def check_gpu_config():
    """
    Check GPU availability and display detailed configuration information.
    """
    # Check if GPU is available
    gpu_available = torch.cuda.is_available()
    
    # Print header
    print("=" * 50)
    print("GPU Configuration Check".center(50))
    print("=" * 50)
    
    # Basic GPU availability
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'GPU Available':<25}: {'Yes' if gpu_available else 'No'}")
    
    # If GPU is available, print detailed info
    if gpu_available:
        print("-" * 50)
        print("GPU Details".center(50))
        print("-" * 50)
        
        # Device info
        print(f"{'Device Name':<25}: {torch.cuda.get_device_name(0)}")
        print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")
        print(f"{'Current Device Index':<25}: {torch.cuda.current_device()}")
        
        # Compute capability and CUDA cores
        props = torch.cuda.get_device_properties(0)
        print(f"{'Compute Capability':<25}: {props.major}.{props.minor}")
        print(f"{'Total CUDA Cores':<25}: {props.multi_processor_count * 128}")  # Approx. 128 cores per SM
        
        # Memory info
        total_memory = props.total_memory / (1024 ** 3)  # Convert to GB
        memory_allocated = torch.cuda.memory_allocated(0) / (1024 ** 3)
        memory_reserved = torch.cuda.memory_reserved(0) / (1024 ** 3)
        print(f"{'Total Memory (GB)':<25}: {total_memory:.2f}")
        print(f"{'Allocated Memory (GB)':<25}: {memory_allocated:.2f}")
        print(f"{'Reserved Memory (GB)':<25}: {memory_reserved:.2f}")
    else:
        print("-" * 50)
        print("No GPU detected. Running on CPU.".center(50))
        print("-" * 50)
    
    print("=" * 50)

if __name__ == "__main__":
    check_gpu_config()
# Out:
# ==================================================
#              GPU Configuration Check
# ==================================================
# PyTorch Version          : 2.5.1
# GPU Available            : Yes
# --------------------------------------------------
#                    GPU Details
# --------------------------------------------------
# Device Name              : NVIDIA RTX A6000
# Number of GPUs           : 3
# Current Device Index     : 0
# Compute Capability       : 8.6
# Total CUDA Cores         : 10752
# Total Memory (GB)        : 47.41
# Allocated Memory (GB)    : 0.00
# Reserved Memory (GB)     : 0.00
# ==================================================

# %% [markdown]
# ### PyTorch Details

# %%
def print_torch_config():
    """Print PyTorch and CUDA configuration in a formatted manner."""
    print("=" * 50)
    print("PyTorch Configuration".center(50))
    print("=" * 50)
    
    # Basic PyTorch and CUDA info
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'CUDA Compiled Version':<25}: {torch.version.cuda}")
    print(f"{'CUDA Available':<25}: {'Yes' if torch.cuda.is_available() else 'No'}")
    print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")

    # GPU details if available
    if torch.cuda.is_available():
        print(f"{'GPU Name':<25}: {torch.cuda.get_device_name(0)}")

    print("-" * 50)
    
    # Seed setting
    torch.manual_seed(42)
    print(f"{'Random Seed':<25}: 42 (Seeding successful!)")
    
    print("=" * 50)

if __name__ == "__main__":
    print_torch_config()
# Out:
# ==================================================
#               PyTorch Configuration
# ==================================================
# PyTorch Version          : 2.5.1
# CUDA Compiled Version    : 12.1
# CUDA Available           : Yes
# Number of GPUs           : 3
# GPU Name                 : NVIDIA RTX A6000
# --------------------------------------------------
# Random Seed              : 42 (Seeding successful!)
# ==================================================

# %% [markdown]
# ## __⚙️ GPU Selection — Auto-select the least loaded GPU__
# This code automatically scans available GPUs and selects the one with the lowest current memory usage.

# %%
def auto_select_cuda_device(verbose=True):
    """
    Automatically selects the CUDA GPU with the least memory usage.
    Falls back to CPU if no GPU is available.
    """
    if not torch.cuda.is_available():
        print("🚫 No CUDA GPU available. Using CPU.")
        return torch.device("cpu")

    try:
        # Run nvidia-smi to get memory usage of each GPU
        smi_output = subprocess.check_output(
            ['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader'],
            encoding='utf-8'
        )
        memory_used = [int(x) for x in smi_output.strip().split('\n')]
        best_gpu = int(np.argmin(memory_used))

        if verbose:
            print("🎯 Automatically selected GPU:")
            print(f"    - CUDA Device ID : {best_gpu}")
            print(f"    - Memory Used    : {memory_used[best_gpu]} MiB")
            print(f"    - Device Name    : {torch.cuda.get_device_name(best_gpu)}")
        return torch.device(f"cuda:{best_gpu}")
    except Exception as e:
        print(f"⚠️ Failed to auto-detect GPU. Falling back to cuda:0. ({e})")
        return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Execute and assign
device = auto_select_cuda_device()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 18 MiB
#     - Device Name    : NVIDIA RTX A6000

# %% [markdown]
# ## __MLP Model__

# %% [markdown]
# ### HAR_MLP_v1

# %%
class HAR_MLP_v1(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, dropout: float = 0.2):
        super(HAR_MLP_v1, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### HAR_MLP_v2

# %%
class HAR_MLP_v2(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, dropout: float = 0.2):
        super(HAR_MLP_v2, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.fc3 = nn.Linear(hidden_size, output_size)
        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.dropout2(x)

        x = self.fc3(x)
        return x

# %% [markdown]
# ## __EWC Class Definition__

# %%
class EWC:
    def __init__(self, fisher: dict, params: dict):
        self.fisher = {k: v.cpu() for k, v in fisher.items()}
        self.params = {k: v.cpu() for k, v in params.items()}

    @staticmethod
    def compute_fisher_and_params(model, dataloader, criterion, device, sample_size=None):
        model.train()
        fisher = {n: torch.zeros_like(p, device=device) for n, p in model.named_parameters() if p.requires_grad}
        params = {n: p.clone().detach().cpu() for n, p in model.named_parameters() if p.requires_grad}

        total_samples = 0
        for i, (x, y) in enumerate(dataloader):
            if sample_size and total_samples >= sample_size:
                break
            x, y = x.to(device), y.to(device)
            model.zero_grad()
            outputs = model(x)
            # 可視模型輸出是否需展平而選擇加上 outputs.view(-1, ...)
            loss = criterion(outputs, y)
            loss.backward()
            for n, p in model.named_parameters():
                if p.grad is not None:
                    fisher[n] += (p.grad ** 2) * x.size(0)
            total_samples += x.size(0)

        fisher = {n: f / total_samples for n, f in fisher.items()}
        return {n: f.cpu() for n, f in fisher.items()}, params

    def penalty(self, model):
        loss = 0.0
        for n, p in model.named_parameters():
            if n in self.fisher:
                _loss = self.fisher[n].to(p.device) * (p - self.params[n].to(p.device)) ** 2
                loss += _loss.sum()
        return loss

# %% [markdown]
# ## __Training Function with EWC__

# %%
def compute_classwise_accuracy(preds, targets, class_correct, class_total):
    """
    Computes per-class accuracy statistics from raw logits and ground truth.
    """
    preds = torch.argmax(preds, dim=-1)
    correct_mask = (preds == targets)
    for label in torch.unique(targets):
        label = label.item()
        label_mask = (targets == label)
        class_total[label] = class_total.get(label, 0) + label_mask.sum().item()
        class_correct[label] = class_correct.get(label, 0) + (correct_mask & label_mask).sum().item()

# %%
def compute_fwt_har(previous_model, init_model, X_val, y_val, known_classes, batch_size=64):
    """
    FWT computation for HAR-style inputs (tabular MLP, not sequence).
    X_val: shape [N, F]
    y_val: shape [N]
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    previous_model.to(device).eval()
    init_model.to(device).eval()

    # 只選擇 known_classes
    mask = np.isin(y_val, known_classes)
    X_known = X_val[mask]
    y_known = y_val[mask]

    if len(y_known) == 0:
        print(f"⚠️ No validation samples for known classes {known_classes}.")
        return None, None, None

    print(f"📋 Total samples for known classes {known_classes}: {len(y_known)}")

    dataset = TensorDataset(
        torch.tensor(X_known, dtype=torch.float32),
        torch.tensor(y_known, dtype=torch.long)
    )
    loader = DataLoader(dataset, batch_size=batch_size)

    correct_prev, correct_init, total = 0, 0, 0

    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)

            out_prev = previous_model(xb)
            out_init = init_model(xb)

            preds_prev = torch.argmax(out_prev, dim=-1)
            preds_init = torch.argmax(out_init, dim=-1)

            correct_prev += (preds_prev == yb).sum().item()
            correct_init += (preds_init == yb).sum().item()
            total += yb.size(0)

    acc_prev = correct_prev / total
    acc_init = correct_init / total
    fwt_value = acc_prev - acc_init

    print(f"\n### 🔍 FWT Debug Info (HAR):")
    print(f"- Total evaluated samples: {total}")
    print(f"- Correct (PrevModel): {correct_prev} / {total} → Acc = {acc_prev:.4f}")
    print(f"- Correct (InitModel): {correct_init} / {total} → Acc = {acc_init:.4f}")
    print(f"- FWT = Acc_prev - Acc_init = {fwt_value:.4f}")

    return fwt_value, acc_prev, acc_init

# %%
def print_model_info(model):
    total_params = sum(p.numel() for p in model.parameters())
    param_size_bytes = total_params * 4  # 假設 float32，每個參數佔 4 bytes
    param_size_MB = param_size_bytes / (1024**2)

    print(f"- Total Parameters: {total_params}")
    print(f"- Model Size (float32): {param_size_MB:.2f} MB")

# %%
def train_with_ewc(model, output_size, criterion, optimizer,
                   X_train, y_train, X_val, y_val,
                   scheduler=None, num_epochs=10, batch_size=64,
                   model_saving_folder=None, model_name=None,
                   stop_signal_file=None, ewc=None, lambda_ewc=0.4, device=auto_select_cuda_device()):

    print("\n🚀 'train_with_ewc' started.")
    model_name = model_name or 'model'
    model_saving_folder = model_saving_folder or './saved_models'
    
    if model_saving_folder:
        if os.path.exists(model_saving_folder):
            shutil.rmtree(model_saving_folder)
            print(f"✅ Removed existing folder: {model_saving_folder}")
        os.makedirs(model_saving_folder, exist_ok=True)

    device = device
    model.to(device)

    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    print("\n✅ Data Overview:")
    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")

    # Start timer
    start_time = time.time()

    best_results = []
    for epoch in range(num_epochs):
        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\n🛑 Stop signal detected. Exiting training loop.")
            break

        model.train()
        epoch_loss = 0.0
        class_correct, class_total = {}, {}

        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch).view(-1, output_size)
            y_batch = y_batch.view(-1)
            loss = criterion(outputs, y_batch)
            if ewc is not None:
                loss += (lambda_ewc / 2) * ewc.penalty(model)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * X_batch.size(0)
            compute_classwise_accuracy(outputs, y_batch, class_correct, class_total)

        train_loss = epoch_loss / len(train_loader.dataset)
        train_acc = {int(c): f"{(class_correct[c] / class_total[c]) * 100:.2f}%" if class_total[c] > 0 else "0.00%" for c in sorted(class_total.keys())}

        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        val_class_correct, val_class_total = {}, {}
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                outputs = model(X_batch).view(-1, output_size)
                y_batch = y_batch.view(-1)
                val_loss += criterion(outputs, y_batch).item() * X_batch.size(0)
                predictions = torch.argmax(outputs, dim=-1)
                val_correct += (predictions == y_batch).sum().item()
                val_total += y_batch.size(0)
                compute_classwise_accuracy(outputs, y_batch, val_class_correct, val_class_total)

        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / val_total
        val_acc_cls = {int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%" for c in sorted(val_class_total.keys())}

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, Train-Class-Acc: {train_acc},")
        print(f"Val Loss: {val_loss:.6f}, Val Acc: {val_acc * 100:.2f}%, Val-Class-Acc: {val_acc_cls}, LR: {optimizer.param_groups[0]['lr']:.6f}")

        model_path = os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        current = {
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_accuracy': val_acc,
            'train_classwise_accuracy': train_acc,
            'val_classwise_accuracy': val_acc_cls,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'learning_rate': optimizer.param_groups[0]['lr'],
            'model_path': model_path
        }

        if len(best_results) < 5 or val_acc > best_results[-1]['val_accuracy']:
            if len(best_results) == 5:
                to_remove = best_results.pop()
                if os.path.exists(to_remove['model_path']):
                    os.remove(to_remove['model_path'])
                    print(f"🗑 Removed: {to_remove['model_path']}")
            best_results.append(current)
            best_results.sort(key=lambda x: (x['val_accuracy'], x['epoch']), reverse=True)
            torch.save(current, model_path)
            print(f"✅ Saved model: {model_path}")

        if scheduler: scheduler.step(val_loss)

    # End timer and report
    elapsed_time = time.time() - start_time
    print(f"\n⏳ Total training time: {elapsed_time:.2f} seconds")
    
    if best_results:
        best = best_results[0]
        best_model_path = os.path.join(model_saving_folder, f"{model_name}_best.pth")
        torch.save(best, best_model_path)
        print(f"\n🏆 Best model saved as: {best_model_path} (Val Accuracy: {best['val_accuracy'] * 100:.2f}%)")

    final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
    torch.save(current, final_model_path)
    print(f"\n📌 Final model saved as: {final_model_path}")

    print("\n🎯 Top 5 Best Models:")
    for res in best_results:
        print(f"Epoch {res['epoch']}, Train Loss: {res['train_loss']:.6f}, Train-Acc: {res['train_classwise_accuracy']},\n"
              f"Val Loss: {res['val_loss']:.6f}, Val Acc: {res['val_accuracy']*100:.2f}%, Val-Acc: {res['val_classwise_accuracy']},"
              f" Model Path: {res['model_path']}")

    # === Markdown summary for best result ===
    best_model = max(best_results, key=lambda x: x['val_accuracy'])

    # Extract period number from folder path
    match = re.search(r'Period_(\d+)', model_saving_folder)
    period_label = match.group(1) if match else "?"
    model_name_str = model.__class__.__name__

    best_md_summary = f"""
    ---
### Period {period_label}
+ ##### Total training time: {elapsed_time:.2f} seconds
+ ##### Model: {model_name_str}
+ ##### Training and saving in *'{model_saving_folder}'*
+ ##### Best Epoch: {best_model['epoch']}
#### __Val Accuracy: {best_model['val_accuracy'] * 100:.2f}%__
#### __Val-Class-Acc: {best_model['val_classwise_accuracy']}__
    """
    print(best_md_summary.strip())

    del X_train, y_train, X_val, y_val, train_loader, val_loader
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 18 MiB
#     - Device Name    : NVIDIA RTX A6000

# %% [markdown]
# ## __📋 Label Mapping (HAR Activities)__
#
# | Label ID | Activity Name       |
# |----------|---------------------|
# |    0     | SITTING             |
# |    1     | STANDING            |
# |    2     | WALKING             |
# |    3     | LAYING              |
# |    4     | WALKING_UPSTAIRS    |
# |    5     | WALKING_DOWNSTAIRS  |

# %% [markdown]
# ## __Common Parameters__

# %%
batch_size    = 64
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'HAR_CIL/stop_training.txt'))

# %% [markdown]
# ## __HAR_MLP_v1 Training__

# %% [markdown]
# ---
# ### Period 1
# + ##### Total training time: 79.13 seconds
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1'*
# + ##### Best Epoch: 965
# #### __Val Accuracy: 94.62%__
# #### __Val-Class-Acc: {0: '91.04%', 1: '97.93%'}__

# %%
# ================================
# 📌 Period 1 Configuration
# ================================
period = 1

# Load processed dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]   # use test set for validation

# Auto-select the best CUDA device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 0.0  # EWC disabled for Period 1
ewc_state     = None

# Model saving path
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_1")
os.makedirs(model_saving_folder, exist_ok=True)

# Initialize model, criterion, optimizer
model     = HAR_MLP_v1(input_size=input_size, hidden_size=hidden_size, output_size=output_size, dropout=dropout).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train the model
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================

# Unique class summary
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Clean up memory to prepare for next period
del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 11269 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
# Epoch 1/1000, Train Loss: 0.735055, Train-Class-Acc: {0: '53.34%', 1: '59.24%'},
# Val Loss: 0.566365, Val Acc: 80.84%, Val-Class-Acc: {0: '87.78%', 1: '74.44%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.585920, Train-Class-Acc: {0: '66.10%', 1: '71.91%'},
# Val Loss: 0.511184, Val Acc: 77.13%, Val-Class-Acc: {0: '56.01%', 1: '96.62%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.521991, Train-Class-Acc: {0: '71.93%', 1: '78.38%'},
# Val Loss: 0.459979, Val Acc: 82.50%, Val-Class-Acc: {0: '67.82%', 1: '96.05%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.474686, Train-Class-Acc: {0: '75.89%', 1: '82.97%'},
# Val Loss: 0.421508, Val Acc: 87.49%, Val-Class-Acc: {0: '81.26%', 1: '93.23%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.429074, Train-Class-Acc: {0: '78.46%', 1: '87.19%'},
# Val Loss: 0.390711, Val Acc: 87.98%, Val-Class-Acc: {0: '84.32%', 1: '91.35%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.409596, Train-Class-Acc: {0: '79.78%', 1: '85.30%'},
# Val Loss: 0.372874, Val Acc: 88.56%, Val-Class-Acc: {0: '83.91%', 1: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.383453, Train-Class-Acc: {0: '80.87%', 1: '88.50%'},
# Val Loss: 0.384285, Val Acc: 82.70%, Val-Class-Acc: {0: '67.21%', 1: '96.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.367641, Train-Class-Acc: {0: '82.35%', 1: '89.01%'},
# Val Loss: 0.341951, Val Acc: 88.66%, Val-Class-Acc: {0: '83.10%', 1: '93.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.345725, Train-Class-Acc: {0: '83.51%', 1: '89.30%'},
# Val Loss: 0.321719, Val Acc: 89.15%, Val-Class-Acc: {0: '88.39%', 1: '89.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.331492, Train-Class-Acc: {0: '83.51%', 1: '90.39%'},
# Val Loss: 0.312172, Val Acc: 89.15%, Val-Class-Acc: {0: '85.74%', 1: '92.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.319392, Train-Class-Acc: {0: '85.46%', 1: '91.12%'},
# Val Loss: 0.325918, Val Acc: 86.31%, Val-Class-Acc: {0: '76.17%', 1: '95.68%'}, LR: 0.000100
# Epoch 12/1000, Train Loss: 0.305392, Train-Class-Acc: {0: '86.08%', 1: '90.76%'},
# Val Loss: 0.305490, Val Acc: 87.19%, Val-Class-Acc: {0: '78.82%', 1: '94.92%'}, LR: 0.000100
# Epoch 13/1000, Train Loss: 0.295488, Train-Class-Acc: {0: '85.61%', 1: '91.85%'},
# Val Loss: 0.287038, Val Acc: 91.30%, Val-Class-Acc: {0: '95.93%', 1: '87.03%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.289822, Train-Class-Acc: {0: '87.09%', 1: '91.12%'},
# Val Loss: 0.307942, Val Acc: 86.31%, Val-Class-Acc: {0: '75.56%', 1: '96.24%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.277262, Train-Class-Acc: {0: '86.94%', 1: '91.34%'},
# Val Loss: 0.281922, Val Acc: 87.98%, Val-Class-Acc: {0: '80.04%', 1: '95.30%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.262594, Train-Class-Acc: {0: '89.04%', 1: '92.29%'},
# Val Loss: 0.257191, Val Acc: 90.81%, Val-Class-Acc: {0: '88.39%', 1: '93.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.257476, Train-Class-Acc: {0: '89.27%', 1: '91.70%'},
# Val Loss: 0.263673, Val Acc: 89.44%, Val-Class-Acc: {0: '84.11%', 1: '94.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.253658, Train-Class-Acc: {0: '88.80%', 1: '92.36%'},
# Val Loss: 0.244841, Val Acc: 91.79%, Val-Class-Acc: {0: '91.65%', 1: '91.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.246660, Train-Class-Acc: {0: '89.35%', 1: '91.99%'},
# Val Loss: 0.244015, Val Acc: 91.10%, Val-Class-Acc: {0: '88.80%', 1: '93.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.239074, Train-Class-Acc: {0: '89.27%', 1: '92.29%'},
# Val Loss: 0.253096, Val Acc: 89.44%, Val-Class-Acc: {0: '83.91%', 1: '94.55%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.228031, Train-Class-Acc: {0: '89.27%', 1: '93.38%'},
# Val Loss: 0.234933, Val Acc: 91.59%, Val-Class-Acc: {0: '89.82%', 1: '93.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.225821, Train-Class-Acc: {0: '89.74%', 1: '93.09%'},
# Val Loss: 0.228983, Val Acc: 92.18%, Val-Class-Acc: {0: '93.69%', 1: '90.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.228197, Train-Class-Acc: {0: '90.59%', 1: '92.36%'},
# Val Loss: 0.249442, Val Acc: 89.74%, Val-Class-Acc: {0: '83.10%', 1: '95.86%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.221270, Train-Class-Acc: {0: '91.14%', 1: '93.23%'},
# Val Loss: 0.256621, Val Acc: 88.86%, Val-Class-Acc: {0: '80.24%', 1: '96.80%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.223294, Train-Class-Acc: {0: '89.66%', 1: '93.09%'},
# Val Loss: 0.218425, Val Acc: 92.18%, Val-Class-Acc: {0: '92.87%', 1: '91.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.204070, Train-Class-Acc: {0: '92.07%', 1: '92.14%'},
# Val Loss: 0.222064, Val Acc: 91.50%, Val-Class-Acc: {0: '88.80%', 1: '93.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.204295, Train-Class-Acc: {0: '91.14%', 1: '93.60%'},
# Val Loss: 0.213258, Val Acc: 92.38%, Val-Class-Acc: {0: '92.06%', 1: '92.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.208119, Train-Class-Acc: {0: '90.67%', 1: '93.23%'},
# Val Loss: 0.212688, Val Acc: 92.47%, Val-Class-Acc: {0: '91.45%', 1: '93.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.195575, Train-Class-Acc: {0: '92.53%', 1: '92.87%'},
# Val Loss: 0.217382, Val Acc: 91.20%, Val-Class-Acc: {0: '87.98%', 1: '94.17%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.194306, Train-Class-Acc: {0: '91.91%', 1: '94.61%'},
# Val Loss: 0.208828, Val Acc: 92.28%, Val-Class-Acc: {0: '90.84%', 1: '93.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.190998, Train-Class-Acc: {0: '92.30%', 1: '93.09%'},
# Val Loss: 0.215137, Val Acc: 91.59%, Val-Class-Acc: {0: '87.98%', 1: '94.92%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.186237, Train-Class-Acc: {0: '92.85%', 1: '93.96%'},
# Val Loss: 0.207661, Val Acc: 92.08%, Val-Class-Acc: {0: '90.02%', 1: '93.98%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.188498, Train-Class-Acc: {0: '92.61%', 1: '94.03%'},
# Val Loss: 0.222545, Val Acc: 91.10%, Val-Class-Acc: {0: '86.15%', 1: '95.68%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.175648, Train-Class-Acc: {0: '92.77%', 1: '93.81%'},
# Val Loss: 0.202831, Val Acc: 92.08%, Val-Class-Acc: {0: '90.02%', 1: '93.98%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.173446, Train-Class-Acc: {0: '92.92%', 1: '94.40%'},
# Val Loss: 0.199068, Val Acc: 92.67%, Val-Class-Acc: {0: '91.45%', 1: '93.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.171383, Train-Class-Acc: {0: '93.39%', 1: '94.03%'},
# Val Loss: 0.196792, Val Acc: 92.96%, Val-Class-Acc: {0: '93.08%', 1: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.170217, Train-Class-Acc: {0: '93.62%', 1: '93.96%'},
# Val Loss: 0.210154, Val Acc: 91.89%, Val-Class-Acc: {0: '87.98%', 1: '95.49%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.169864, Train-Class-Acc: {0: '93.00%', 1: '94.18%'},
# Val Loss: 0.213235, Val Acc: 91.50%, Val-Class-Acc: {0: '86.76%', 1: '95.86%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.168549, Train-Class-Acc: {0: '93.00%', 1: '94.32%'},
# Val Loss: 0.225098, Val Acc: 91.10%, Val-Class-Acc: {0: '84.93%', 1: '96.80%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.161498, Train-Class-Acc: {0: '93.70%', 1: '94.25%'},
# Val Loss: 0.201955, Val Acc: 92.08%, Val-Class-Acc: {0: '89.00%', 1: '94.92%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.155173, Train-Class-Acc: {0: '94.01%', 1: '94.10%'},
# Val Loss: 0.220941, Val Acc: 91.20%, Val-Class-Acc: {0: '85.34%', 1: '96.62%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.160741, Train-Class-Acc: {0: '92.77%', 1: '94.98%'},
# Val Loss: 0.191921, Val Acc: 93.06%, Val-Class-Acc: {0: '93.48%', 1: '92.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.157845, Train-Class-Acc: {0: '94.01%', 1: '94.76%'},
# Val Loss: 0.193561, Val Acc: 92.57%, Val-Class-Acc: {0: '90.63%', 1: '94.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.150466, Train-Class-Acc: {0: '93.70%', 1: '95.12%'},
# Val Loss: 0.218357, Val Acc: 91.20%, Val-Class-Acc: {0: '85.34%', 1: '96.62%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.152625, Train-Class-Acc: {0: '93.78%', 1: '94.54%'},
# Val Loss: 0.190249, Val Acc: 92.86%, Val-Class-Acc: {0: '92.06%', 1: '93.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.151789, Train-Class-Acc: {0: '94.63%', 1: '94.32%'},
# Val Loss: 0.195553, Val Acc: 92.38%, Val-Class-Acc: {0: '89.61%', 1: '94.92%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.148282, Train-Class-Acc: {0: '93.55%', 1: '94.91%'},
# Val Loss: 0.200646, Val Acc: 92.57%, Val-Class-Acc: {0: '89.00%', 1: '95.86%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.151129, Train-Class-Acc: {0: '94.25%', 1: '94.69%'},
# Val Loss: 0.201471, Val Acc: 92.67%, Val-Class-Acc: {0: '88.59%', 1: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.144774, Train-Class-Acc: {0: '94.25%', 1: '95.20%'},
# Val Loss: 0.200344, Val Acc: 92.47%, Val-Class-Acc: {0: '89.00%', 1: '95.68%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.144580, Train-Class-Acc: {0: '93.93%', 1: '94.18%'},
# Val Loss: 0.191821, Val Acc: 92.47%, Val-Class-Acc: {0: '90.22%', 1: '94.55%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.141048, Train-Class-Acc: {0: '94.25%', 1: '94.91%'},
# Val Loss: 0.196215, Val Acc: 92.67%, Val-Class-Acc: {0: '89.82%', 1: '95.30%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.138056, Train-Class-Acc: {0: '94.56%', 1: '95.27%'},
# Val Loss: 0.217120, Val Acc: 91.40%, Val-Class-Acc: {0: '85.74%', 1: '96.62%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.142223, Train-Class-Acc: {0: '94.48%', 1: '94.69%'},
# Val Loss: 0.211681, Val Acc: 91.69%, Val-Class-Acc: {0: '86.35%', 1: '96.62%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.140046, Train-Class-Acc: {0: '94.40%', 1: '95.34%'},
# Val Loss: 0.192511, Val Acc: 92.38%, Val-Class-Acc: {0: '90.22%', 1: '94.36%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.135015, Train-Class-Acc: {0: '95.18%', 1: '95.63%'},
# Val Loss: 0.216399, Val Acc: 91.50%, Val-Class-Acc: {0: '85.95%', 1: '96.62%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.138917, Train-Class-Acc: {0: '94.32%', 1: '95.71%'},
# Val Loss: 0.202138, Val Acc: 92.96%, Val-Class-Acc: {0: '89.00%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.136890, Train-Class-Acc: {0: '95.26%', 1: '94.47%'},
# Val Loss: 0.196453, Val Acc: 92.77%, Val-Class-Acc: {0: '89.61%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.131134, Train-Class-Acc: {0: '94.87%', 1: '95.34%'},
# Val Loss: 0.202251, Val Acc: 92.57%, Val-Class-Acc: {0: '88.39%', 1: '96.43%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.125244, Train-Class-Acc: {0: '95.10%', 1: '95.27%'},
# Val Loss: 0.199076, Val Acc: 92.86%, Val-Class-Acc: {0: '89.00%', 1: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_59.pth
# Epoch 60/1000, Train Loss: 0.128496, Train-Class-Acc: {0: '94.87%', 1: '95.41%'},
# Val Loss: 0.190085, Val Acc: 92.67%, Val-Class-Acc: {0: '91.04%', 1: '94.17%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.129940, Train-Class-Acc: {0: '95.49%', 1: '95.12%'},
# Val Loss: 0.205838, Val Acc: 92.28%, Val-Class-Acc: {0: '87.58%', 1: '96.62%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.127307, Train-Class-Acc: {0: '95.10%', 1: '95.56%'},
# Val Loss: 0.213833, Val Acc: 91.59%, Val-Class-Acc: {0: '86.15%', 1: '96.62%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.122274, Train-Class-Acc: {0: '95.18%', 1: '95.85%'},
# Val Loss: 0.194094, Val Acc: 92.86%, Val-Class-Acc: {0: '89.82%', 1: '95.68%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.129832, Train-Class-Acc: {0: '95.41%', 1: '95.92%'},
# Val Loss: 0.188854, Val Acc: 92.96%, Val-Class-Acc: {0: '92.26%', 1: '93.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_64.pth
# Epoch 65/1000, Train Loss: 0.122919, Train-Class-Acc: {0: '94.40%', 1: '95.85%'},
# Val Loss: 0.193831, Val Acc: 92.86%, Val-Class-Acc: {0: '90.63%', 1: '94.92%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.118227, Train-Class-Acc: {0: '95.88%', 1: '95.85%'},
# Val Loss: 0.204613, Val Acc: 92.47%, Val-Class-Acc: {0: '87.98%', 1: '96.62%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.120594, Train-Class-Acc: {0: '95.26%', 1: '95.56%'},
# Val Loss: 0.214714, Val Acc: 91.69%, Val-Class-Acc: {0: '86.35%', 1: '96.62%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.118112, Train-Class-Acc: {0: '95.57%', 1: '95.78%'},
# Val Loss: 0.217310, Val Acc: 91.59%, Val-Class-Acc: {0: '85.95%', 1: '96.80%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.120328, Train-Class-Acc: {0: '95.41%', 1: '95.85%'},
# Val Loss: 0.197420, Val Acc: 92.57%, Val-Class-Acc: {0: '89.41%', 1: '95.49%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.122549, Train-Class-Acc: {0: '95.18%', 1: '95.78%'},
# Val Loss: 0.214997, Val Acc: 91.98%, Val-Class-Acc: {0: '86.76%', 1: '96.80%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.123309, Train-Class-Acc: {0: '95.26%', 1: '95.49%'},
# Val Loss: 0.194233, Val Acc: 92.67%, Val-Class-Acc: {0: '91.04%', 1: '94.17%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.114824, Train-Class-Acc: {0: '95.49%', 1: '95.63%'},
# Val Loss: 0.212729, Val Acc: 91.89%, Val-Class-Acc: {0: '86.76%', 1: '96.62%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.115038, Train-Class-Acc: {0: '95.65%', 1: '96.22%'},
# Val Loss: 0.203189, Val Acc: 92.47%, Val-Class-Acc: {0: '88.59%', 1: '96.05%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.115139, Train-Class-Acc: {0: '95.65%', 1: '95.92%'},
# Val Loss: 0.195093, Val Acc: 92.57%, Val-Class-Acc: {0: '90.43%', 1: '94.55%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.112680, Train-Class-Acc: {0: '96.58%', 1: '95.85%'},
# Val Loss: 0.200162, Val Acc: 92.57%, Val-Class-Acc: {0: '89.21%', 1: '95.68%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.109442, Train-Class-Acc: {0: '95.65%', 1: '96.43%'},
# Val Loss: 0.195287, Val Acc: 92.96%, Val-Class-Acc: {0: '93.28%', 1: '92.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_59.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.108230, Train-Class-Acc: {0: '96.35%', 1: '96.22%'},
# Val Loss: 0.195494, Val Acc: 92.57%, Val-Class-Acc: {0: '90.84%', 1: '94.17%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.112094, Train-Class-Acc: {0: '95.88%', 1: '96.22%'},
# Val Loss: 0.207270, Val Acc: 92.28%, Val-Class-Acc: {0: '87.58%', 1: '96.62%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.108248, Train-Class-Acc: {0: '96.19%', 1: '96.43%'},
# Val Loss: 0.198262, Val Acc: 92.86%, Val-Class-Acc: {0: '90.22%', 1: '95.30%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.106886, Train-Class-Acc: {0: '96.03%', 1: '96.43%'},
# Val Loss: 0.240797, Val Acc: 91.50%, Val-Class-Acc: {0: '84.73%', 1: '97.74%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.106446, Train-Class-Acc: {0: '95.72%', 1: '96.51%'},
# Val Loss: 0.226864, Val Acc: 91.59%, Val-Class-Acc: {0: '85.74%', 1: '96.99%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.109813, Train-Class-Acc: {0: '95.57%', 1: '96.65%'},
# Val Loss: 0.205759, Val Acc: 92.38%, Val-Class-Acc: {0: '89.21%', 1: '95.30%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.111689, Train-Class-Acc: {0: '95.80%', 1: '95.71%'},
# Val Loss: 0.197404, Val Acc: 93.06%, Val-Class-Acc: {0: '92.67%', 1: '93.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.107379, Train-Class-Acc: {0: '96.66%', 1: '96.14%'},
# Val Loss: 0.198148, Val Acc: 92.86%, Val-Class-Acc: {0: '92.46%', 1: '93.23%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.104325, Train-Class-Acc: {0: '96.19%', 1: '96.65%'},
# Val Loss: 0.208121, Val Acc: 92.18%, Val-Class-Acc: {0: '87.98%', 1: '96.05%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.105922, Train-Class-Acc: {0: '96.35%', 1: '96.07%'},
# Val Loss: 0.207037, Val Acc: 92.38%, Val-Class-Acc: {0: '88.59%', 1: '95.86%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.113497, Train-Class-Acc: {0: '95.49%', 1: '96.00%'},
# Val Loss: 0.196075, Val Acc: 92.47%, Val-Class-Acc: {0: '90.63%', 1: '94.17%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.103006, Train-Class-Acc: {0: '96.42%', 1: '96.51%'},
# Val Loss: 0.197358, Val Acc: 92.86%, Val-Class-Acc: {0: '91.65%', 1: '93.98%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.109516, Train-Class-Acc: {0: '96.03%', 1: '96.36%'},
# Val Loss: 0.228498, Val Acc: 91.69%, Val-Class-Acc: {0: '85.95%', 1: '96.99%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.103544, Train-Class-Acc: {0: '96.50%', 1: '96.22%'},
# Val Loss: 0.204107, Val Acc: 92.67%, Val-Class-Acc: {0: '89.41%', 1: '95.68%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.096518, Train-Class-Acc: {0: '96.42%', 1: '96.43%'},
# Val Loss: 0.213272, Val Acc: 91.98%, Val-Class-Acc: {0: '87.17%', 1: '96.43%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.096142, Train-Class-Acc: {0: '96.73%', 1: '96.80%'},
# Val Loss: 0.215947, Val Acc: 91.79%, Val-Class-Acc: {0: '86.97%', 1: '96.24%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.098635, Train-Class-Acc: {0: '96.19%', 1: '96.80%'},
# Val Loss: 0.214602, Val Acc: 92.18%, Val-Class-Acc: {0: '87.78%', 1: '96.24%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.098286, Train-Class-Acc: {0: '96.11%', 1: '97.02%'},
# Val Loss: 0.235679, Val Acc: 91.59%, Val-Class-Acc: {0: '85.13%', 1: '97.56%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.098757, Train-Class-Acc: {0: '96.42%', 1: '96.29%'},
# Val Loss: 0.218838, Val Acc: 91.79%, Val-Class-Acc: {0: '86.56%', 1: '96.62%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.095144, Train-Class-Acc: {0: '96.73%', 1: '97.31%'},
# Val Loss: 0.213850, Val Acc: 92.18%, Val-Class-Acc: {0: '87.98%', 1: '96.05%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.096854, Train-Class-Acc: {0: '96.81%', 1: '96.94%'},
# Val Loss: 0.227903, Val Acc: 91.69%, Val-Class-Acc: {0: '85.95%', 1: '96.99%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.095532, Train-Class-Acc: {0: '96.19%', 1: '97.31%'},
# Val Loss: 0.202701, Val Acc: 92.86%, Val-Class-Acc: {0: '92.67%', 1: '93.05%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.101273, Train-Class-Acc: {0: '96.58%', 1: '96.00%'},
# Val Loss: 0.217303, Val Acc: 91.98%, Val-Class-Acc: {0: '87.17%', 1: '96.43%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.096110, Train-Class-Acc: {0: '96.11%', 1: '97.02%'},
# Val Loss: 0.218435, Val Acc: 91.98%, Val-Class-Acc: {0: '87.17%', 1: '96.43%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.090159, Train-Class-Acc: {0: '96.89%', 1: '97.16%'},
# Val Loss: 0.219314, Val Acc: 91.98%, Val-Class-Acc: {0: '87.17%', 1: '96.43%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.097532, Train-Class-Acc: {0: '96.42%', 1: '96.58%'},
# Val Loss: 0.206957, Val Acc: 92.67%, Val-Class-Acc: {0: '90.43%', 1: '94.74%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.103028, Train-Class-Acc: {0: '95.80%', 1: '96.65%'},
# Val Loss: 0.221481, Val Acc: 91.89%, Val-Class-Acc: {0: '86.97%', 1: '96.43%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.093843, Train-Class-Acc: {0: '97.05%', 1: '96.65%'},
# Val Loss: 0.211130, Val Acc: 92.77%, Val-Class-Acc: {0: '89.41%', 1: '95.86%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.091493, Train-Class-Acc: {0: '96.73%', 1: '96.94%'},
# Val Loss: 0.226261, Val Acc: 91.89%, Val-Class-Acc: {0: '86.15%', 1: '97.18%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.086312, Train-Class-Acc: {0: '97.20%', 1: '96.94%'},
# Val Loss: 0.209440, Val Acc: 92.67%, Val-Class-Acc: {0: '90.02%', 1: '95.11%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.090085, Train-Class-Acc: {0: '96.66%', 1: '96.80%'},
# Val Loss: 0.217105, Val Acc: 92.08%, Val-Class-Acc: {0: '87.98%', 1: '95.86%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.087959, Train-Class-Acc: {0: '97.20%', 1: '97.38%'},
# Val Loss: 0.228835, Val Acc: 91.89%, Val-Class-Acc: {0: '86.76%', 1: '96.62%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.090171, Train-Class-Acc: {0: '96.42%', 1: '96.87%'},
# Val Loss: 0.221098, Val Acc: 92.08%, Val-Class-Acc: {0: '87.37%', 1: '96.43%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.085204, Train-Class-Acc: {0: '97.28%', 1: '97.23%'},
# Val Loss: 0.239510, Val Acc: 91.79%, Val-Class-Acc: {0: '85.54%', 1: '97.56%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.091423, Train-Class-Acc: {0: '96.58%', 1: '96.65%'},
# Val Loss: 0.252436, Val Acc: 91.30%, Val-Class-Acc: {0: '84.11%', 1: '97.93%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.089955, Train-Class-Acc: {0: '96.81%', 1: '97.38%'},
# Val Loss: 0.276888, Val Acc: 90.13%, Val-Class-Acc: {0: '81.47%', 1: '98.12%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.090029, Train-Class-Acc: {0: '96.35%', 1: '97.09%'},
# Val Loss: 0.205696, Val Acc: 92.77%, Val-Class-Acc: {0: '90.63%', 1: '94.74%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.086132, Train-Class-Acc: {0: '96.73%', 1: '97.31%'},
# Val Loss: 0.257101, Val Acc: 91.10%, Val-Class-Acc: {0: '84.11%', 1: '97.56%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.087316, Train-Class-Acc: {0: '97.05%', 1: '97.02%'},
# Val Loss: 0.233045, Val Acc: 92.08%, Val-Class-Acc: {0: '86.15%', 1: '97.56%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.084488, Train-Class-Acc: {0: '96.81%', 1: '97.31%'},
# Val Loss: 0.212329, Val Acc: 92.57%, Val-Class-Acc: {0: '89.21%', 1: '95.68%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.089613, Train-Class-Acc: {0: '96.97%', 1: '97.02%'},
# Val Loss: 0.214231, Val Acc: 92.77%, Val-Class-Acc: {0: '89.61%', 1: '95.68%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.083051, Train-Class-Acc: {0: '97.12%', 1: '97.45%'},
# Val Loss: 0.211959, Val Acc: 92.77%, Val-Class-Acc: {0: '90.43%', 1: '94.92%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.084582, Train-Class-Acc: {0: '97.05%', 1: '96.94%'},
# Val Loss: 0.224507, Val Acc: 92.28%, Val-Class-Acc: {0: '87.58%', 1: '96.62%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.083863, Train-Class-Acc: {0: '96.89%', 1: '96.87%'},
# Val Loss: 0.215184, Val Acc: 92.77%, Val-Class-Acc: {0: '89.61%', 1: '95.68%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.081097, Train-Class-Acc: {0: '97.20%', 1: '97.38%'},
# Val Loss: 0.231608, Val Acc: 92.18%, Val-Class-Acc: {0: '86.97%', 1: '96.99%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.081364, Train-Class-Acc: {0: '96.50%', 1: '97.53%'},
# Val Loss: 0.217836, Val Acc: 92.57%, Val-Class-Acc: {0: '89.21%', 1: '95.68%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.081560, Train-Class-Acc: {0: '97.05%', 1: '97.31%'},
# Val Loss: 0.216727, Val Acc: 92.67%, Val-Class-Acc: {0: '89.21%', 1: '95.86%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.080418, Train-Class-Acc: {0: '97.05%', 1: '97.53%'},
# Val Loss: 0.211918, Val Acc: 92.67%, Val-Class-Acc: {0: '90.22%', 1: '94.92%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.078592, Train-Class-Acc: {0: '97.28%', 1: '97.45%'},
# Val Loss: 0.228171, Val Acc: 92.08%, Val-Class-Acc: {0: '86.76%', 1: '96.99%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.079113, Train-Class-Acc: {0: '97.36%', 1: '97.53%'},
# Val Loss: 0.222895, Val Acc: 92.47%, Val-Class-Acc: {0: '87.98%', 1: '96.62%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.082134, Train-Class-Acc: {0: '96.97%', 1: '96.87%'},
# Val Loss: 0.220805, Val Acc: 92.67%, Val-Class-Acc: {0: '88.80%', 1: '96.24%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.079654, Train-Class-Acc: {0: '96.89%', 1: '97.38%'},
# Val Loss: 0.226537, Val Acc: 92.18%, Val-Class-Acc: {0: '87.37%', 1: '96.62%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.074800, Train-Class-Acc: {0: '97.20%', 1: '97.67%'},
# Val Loss: 0.240018, Val Acc: 92.18%, Val-Class-Acc: {0: '86.35%', 1: '97.56%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.077109, Train-Class-Acc: {0: '97.12%', 1: '97.89%'},
# Val Loss: 0.209116, Val Acc: 92.96%, Val-Class-Acc: {0: '90.84%', 1: '94.92%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.078319, Train-Class-Acc: {0: '96.89%', 1: '97.45%'},
# Val Loss: 0.219594, Val Acc: 92.86%, Val-Class-Acc: {0: '89.61%', 1: '95.86%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.077041, Train-Class-Acc: {0: '97.43%', 1: '97.23%'},
# Val Loss: 0.242198, Val Acc: 91.98%, Val-Class-Acc: {0: '86.15%', 1: '97.37%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.074939, Train-Class-Acc: {0: '97.59%', 1: '97.60%'},
# Val Loss: 0.228721, Val Acc: 92.38%, Val-Class-Acc: {0: '86.97%', 1: '97.37%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.077010, Train-Class-Acc: {0: '97.20%', 1: '97.53%'},
# Val Loss: 0.209793, Val Acc: 92.86%, Val-Class-Acc: {0: '90.22%', 1: '95.30%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.076300, Train-Class-Acc: {0: '97.43%', 1: '97.53%'},
# Val Loss: 0.219782, Val Acc: 92.86%, Val-Class-Acc: {0: '89.61%', 1: '95.86%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.081196, Train-Class-Acc: {0: '97.28%', 1: '97.31%'},
# Val Loss: 0.237608, Val Acc: 92.18%, Val-Class-Acc: {0: '86.56%', 1: '97.37%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.075461, Train-Class-Acc: {0: '97.12%', 1: '97.89%'},
# Val Loss: 0.221720, Val Acc: 92.86%, Val-Class-Acc: {0: '89.82%', 1: '95.68%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.078035, Train-Class-Acc: {0: '97.36%', 1: '97.09%'},
# Val Loss: 0.235483, Val Acc: 92.18%, Val-Class-Acc: {0: '86.56%', 1: '97.37%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.074547, Train-Class-Acc: {0: '97.43%', 1: '97.74%'},
# Val Loss: 0.230705, Val Acc: 92.47%, Val-Class-Acc: {0: '87.17%', 1: '97.37%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.076874, Train-Class-Acc: {0: '97.67%', 1: '97.23%'},
# Val Loss: 0.258624, Val Acc: 91.40%, Val-Class-Acc: {0: '84.52%', 1: '97.74%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.074361, Train-Class-Acc: {0: '97.20%', 1: '97.96%'},
# Val Loss: 0.211771, Val Acc: 92.86%, Val-Class-Acc: {0: '90.02%', 1: '95.49%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.079581, Train-Class-Acc: {0: '96.81%', 1: '97.23%'},
# Val Loss: 0.220348, Val Acc: 92.96%, Val-Class-Acc: {0: '88.80%', 1: '96.80%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.073824, Train-Class-Acc: {0: '97.28%', 1: '97.60%'},
# Val Loss: 0.232863, Val Acc: 92.28%, Val-Class-Acc: {0: '86.76%', 1: '97.37%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.072482, Train-Class-Acc: {0: '97.43%', 1: '97.82%'},
# Val Loss: 0.217261, Val Acc: 92.57%, Val-Class-Acc: {0: '89.41%', 1: '95.49%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.072067, Train-Class-Acc: {0: '97.98%', 1: '97.45%'},
# Val Loss: 0.244860, Val Acc: 92.18%, Val-Class-Acc: {0: '86.35%', 1: '97.56%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.071402, Train-Class-Acc: {0: '97.51%', 1: '98.11%'},
# Val Loss: 0.242727, Val Acc: 92.08%, Val-Class-Acc: {0: '86.35%', 1: '97.37%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.073955, Train-Class-Acc: {0: '97.59%', 1: '97.45%'},
# Val Loss: 0.300118, Val Acc: 89.83%, Val-Class-Acc: {0: '80.86%', 1: '98.12%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.074447, Train-Class-Acc: {0: '97.20%', 1: '97.67%'},
# Val Loss: 0.211428, Val Acc: 92.96%, Val-Class-Acc: {0: '90.43%', 1: '95.30%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.071444, Train-Class-Acc: {0: '97.59%', 1: '97.45%'},
# Val Loss: 0.263359, Val Acc: 91.20%, Val-Class-Acc: {0: '84.11%', 1: '97.74%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.073218, Train-Class-Acc: {0: '97.28%', 1: '98.25%'},
# Val Loss: 0.242560, Val Acc: 91.98%, Val-Class-Acc: {0: '85.95%', 1: '97.56%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.068590, Train-Class-Acc: {0: '97.82%', 1: '97.74%'},
# Val Loss: 0.226067, Val Acc: 92.86%, Val-Class-Acc: {0: '88.39%', 1: '96.99%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.071201, Train-Class-Acc: {0: '97.36%', 1: '97.89%'},
# Val Loss: 0.214610, Val Acc: 92.67%, Val-Class-Acc: {0: '89.41%', 1: '95.68%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.068600, Train-Class-Acc: {0: '97.82%', 1: '97.96%'},
# Val Loss: 0.229824, Val Acc: 92.57%, Val-Class-Acc: {0: '87.58%', 1: '97.18%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.065457, Train-Class-Acc: {0: '98.29%', 1: '98.18%'},
# Val Loss: 0.239632, Val Acc: 92.08%, Val-Class-Acc: {0: '86.35%', 1: '97.37%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.069771, Train-Class-Acc: {0: '97.36%', 1: '98.03%'},
# Val Loss: 0.216671, Val Acc: 92.67%, Val-Class-Acc: {0: '89.82%', 1: '95.30%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.066090, Train-Class-Acc: {0: '98.21%', 1: '98.03%'},
# Val Loss: 0.219172, Val Acc: 93.06%, Val-Class-Acc: {0: '89.41%', 1: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_156.pth
# Epoch 157/1000, Train Loss: 0.065681, Train-Class-Acc: {0: '97.74%', 1: '97.67%'},
# Val Loss: 0.218471, Val Acc: 93.06%, Val-Class-Acc: {0: '89.61%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_64.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_157.pth
# Epoch 158/1000, Train Loss: 0.066265, Train-Class-Acc: {0: '97.67%', 1: '97.74%'},
# Val Loss: 0.220675, Val Acc: 92.96%, Val-Class-Acc: {0: '89.41%', 1: '96.24%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.063347, Train-Class-Acc: {0: '98.06%', 1: '97.96%'},
# Val Loss: 0.222764, Val Acc: 92.67%, Val-Class-Acc: {0: '88.80%', 1: '96.24%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.066833, Train-Class-Acc: {0: '97.90%', 1: '97.60%'},
# Val Loss: 0.208261, Val Acc: 92.86%, Val-Class-Acc: {0: '90.43%', 1: '95.11%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.067224, Train-Class-Acc: {0: '97.90%', 1: '97.89%'},
# Val Loss: 0.215726, Val Acc: 92.77%, Val-Class-Acc: {0: '89.61%', 1: '95.68%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.064169, Train-Class-Acc: {0: '97.36%', 1: '98.33%'},
# Val Loss: 0.224338, Val Acc: 92.86%, Val-Class-Acc: {0: '88.80%', 1: '96.62%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.066382, Train-Class-Acc: {0: '97.90%', 1: '97.74%'},
# Val Loss: 0.215909, Val Acc: 92.67%, Val-Class-Acc: {0: '89.41%', 1: '95.68%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.065859, Train-Class-Acc: {0: '98.06%', 1: '97.89%'},
# Val Loss: 0.242120, Val Acc: 92.18%, Val-Class-Acc: {0: '86.35%', 1: '97.56%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.063048, Train-Class-Acc: {0: '97.90%', 1: '98.03%'},
# Val Loss: 0.221695, Val Acc: 93.16%, Val-Class-Acc: {0: '89.41%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_165.pth
# Epoch 166/1000, Train Loss: 0.067106, Train-Class-Acc: {0: '97.90%', 1: '97.74%'},
# Val Loss: 0.223375, Val Acc: 93.26%, Val-Class-Acc: {0: '89.41%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_166.pth
# Epoch 167/1000, Train Loss: 0.068980, Train-Class-Acc: {0: '97.43%', 1: '97.96%'},
# Val Loss: 0.222015, Val Acc: 92.96%, Val-Class-Acc: {0: '89.41%', 1: '96.24%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.062582, Train-Class-Acc: {0: '98.13%', 1: '98.25%'},
# Val Loss: 0.208416, Val Acc: 92.57%, Val-Class-Acc: {0: '90.84%', 1: '94.17%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.063495, Train-Class-Acc: {0: '98.13%', 1: '98.18%'},
# Val Loss: 0.221216, Val Acc: 93.16%, Val-Class-Acc: {0: '89.41%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_169.pth
# Epoch 170/1000, Train Loss: 0.062710, Train-Class-Acc: {0: '97.90%', 1: '97.89%'},
# Val Loss: 0.206065, Val Acc: 92.86%, Val-Class-Acc: {0: '91.85%', 1: '93.80%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.059412, Train-Class-Acc: {0: '98.44%', 1: '98.33%'},
# Val Loss: 0.242427, Val Acc: 92.38%, Val-Class-Acc: {0: '86.56%', 1: '97.74%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.061342, Train-Class-Acc: {0: '97.82%', 1: '98.33%'},
# Val Loss: 0.218203, Val Acc: 93.06%, Val-Class-Acc: {0: '89.00%', 1: '96.80%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.056522, Train-Class-Acc: {0: '98.44%', 1: '98.54%'},
# Val Loss: 0.225762, Val Acc: 93.16%, Val-Class-Acc: {0: '89.21%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_156.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_173.pth
# Epoch 174/1000, Train Loss: 0.062510, Train-Class-Acc: {0: '98.29%', 1: '98.03%'},
# Val Loss: 0.234396, Val Acc: 92.47%, Val-Class-Acc: {0: '87.17%', 1: '97.37%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.058497, Train-Class-Acc: {0: '97.98%', 1: '97.89%'},
# Val Loss: 0.222699, Val Acc: 92.86%, Val-Class-Acc: {0: '88.80%', 1: '96.62%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.055372, Train-Class-Acc: {0: '98.60%', 1: '98.47%'},
# Val Loss: 0.218362, Val Acc: 93.06%, Val-Class-Acc: {0: '89.82%', 1: '96.05%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.056456, Train-Class-Acc: {0: '98.37%', 1: '98.54%'},
# Val Loss: 0.238808, Val Acc: 92.57%, Val-Class-Acc: {0: '86.97%', 1: '97.74%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.059093, Train-Class-Acc: {0: '98.13%', 1: '98.25%'},
# Val Loss: 0.232788, Val Acc: 92.77%, Val-Class-Acc: {0: '87.37%', 1: '97.74%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.055783, Train-Class-Acc: {0: '98.29%', 1: '98.11%'},
# Val Loss: 0.230006, Val Acc: 93.16%, Val-Class-Acc: {0: '89.41%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_157.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_179.pth
# Epoch 180/1000, Train Loss: 0.058784, Train-Class-Acc: {0: '98.13%', 1: '97.96%'},
# Val Loss: 0.222348, Val Acc: 92.96%, Val-Class-Acc: {0: '88.80%', 1: '96.80%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.054534, Train-Class-Acc: {0: '98.37%', 1: '98.40%'},
# Val Loss: 0.213443, Val Acc: 92.77%, Val-Class-Acc: {0: '89.82%', 1: '95.49%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.055132, Train-Class-Acc: {0: '98.21%', 1: '98.18%'},
# Val Loss: 0.262338, Val Acc: 91.50%, Val-Class-Acc: {0: '84.52%', 1: '97.93%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.057311, Train-Class-Acc: {0: '97.51%', 1: '98.47%'},
# Val Loss: 0.209816, Val Acc: 92.77%, Val-Class-Acc: {0: '90.02%', 1: '95.30%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.055331, Train-Class-Acc: {0: '98.37%', 1: '98.18%'},
# Val Loss: 0.247095, Val Acc: 91.89%, Val-Class-Acc: {0: '85.54%', 1: '97.74%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.055183, Train-Class-Acc: {0: '98.06%', 1: '98.25%'},
# Val Loss: 0.241179, Val Acc: 92.47%, Val-Class-Acc: {0: '87.17%', 1: '97.37%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.052637, Train-Class-Acc: {0: '98.29%', 1: '98.25%'},
# Val Loss: 0.232862, Val Acc: 92.67%, Val-Class-Acc: {0: '87.37%', 1: '97.56%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.054942, Train-Class-Acc: {0: '98.29%', 1: '98.54%'},
# Val Loss: 0.223800, Val Acc: 92.86%, Val-Class-Acc: {0: '88.80%', 1: '96.62%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.054179, Train-Class-Acc: {0: '98.44%', 1: '98.40%'},
# Val Loss: 0.242745, Val Acc: 92.77%, Val-Class-Acc: {0: '87.58%', 1: '97.56%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.052829, Train-Class-Acc: {0: '98.68%', 1: '98.18%'},
# Val Loss: 0.245694, Val Acc: 92.47%, Val-Class-Acc: {0: '86.76%', 1: '97.74%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.053507, Train-Class-Acc: {0: '98.44%', 1: '98.11%'},
# Val Loss: 0.256697, Val Acc: 91.98%, Val-Class-Acc: {0: '85.74%', 1: '97.74%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.057695, Train-Class-Acc: {0: '98.13%', 1: '98.33%'},
# Val Loss: 0.213189, Val Acc: 92.67%, Val-Class-Acc: {0: '89.82%', 1: '95.30%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.051472, Train-Class-Acc: {0: '98.37%', 1: '98.62%'},
# Val Loss: 0.245812, Val Acc: 92.77%, Val-Class-Acc: {0: '87.37%', 1: '97.74%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.054677, Train-Class-Acc: {0: '97.90%', 1: '98.54%'},
# Val Loss: 0.237576, Val Acc: 92.86%, Val-Class-Acc: {0: '87.78%', 1: '97.56%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.049096, Train-Class-Acc: {0: '98.68%', 1: '98.40%'},
# Val Loss: 0.214007, Val Acc: 92.77%, Val-Class-Acc: {0: '89.61%', 1: '95.68%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.049351, Train-Class-Acc: {0: '98.91%', 1: '98.62%'},
# Val Loss: 0.224282, Val Acc: 93.16%, Val-Class-Acc: {0: '89.21%', 1: '96.80%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.050232, Train-Class-Acc: {0: '98.91%', 1: '98.91%'},
# Val Loss: 0.256938, Val Acc: 92.38%, Val-Class-Acc: {0: '86.56%', 1: '97.74%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.048703, Train-Class-Acc: {0: '98.68%', 1: '98.62%'},
# Val Loss: 0.220538, Val Acc: 92.77%, Val-Class-Acc: {0: '88.59%', 1: '96.62%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.049993, Train-Class-Acc: {0: '98.37%', 1: '98.54%'},
# Val Loss: 0.247348, Val Acc: 92.67%, Val-Class-Acc: {0: '87.17%', 1: '97.74%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.049013, Train-Class-Acc: {0: '98.44%', 1: '98.47%'},
# Val Loss: 0.213365, Val Acc: 93.26%, Val-Class-Acc: {0: '90.43%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_165.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_199.pth
# Epoch 200/1000, Train Loss: 0.049990, Train-Class-Acc: {0: '98.21%', 1: '98.33%'},
# Val Loss: 0.236212, Val Acc: 92.96%, Val-Class-Acc: {0: '87.78%', 1: '97.74%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.046171, Train-Class-Acc: {0: '98.83%', 1: '98.84%'},
# Val Loss: 0.221611, Val Acc: 93.06%, Val-Class-Acc: {0: '89.41%', 1: '96.43%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.049708, Train-Class-Acc: {0: '98.68%', 1: '98.25%'},
# Val Loss: 0.221333, Val Acc: 92.96%, Val-Class-Acc: {0: '89.21%', 1: '96.43%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.047853, Train-Class-Acc: {0: '98.83%', 1: '98.47%'},
# Val Loss: 0.238646, Val Acc: 92.86%, Val-Class-Acc: {0: '87.58%', 1: '97.74%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.055591, Train-Class-Acc: {0: '97.98%', 1: '98.11%'},
# Val Loss: 0.236854, Val Acc: 92.86%, Val-Class-Acc: {0: '88.19%', 1: '97.18%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.046852, Train-Class-Acc: {0: '98.60%', 1: '98.62%'},
# Val Loss: 0.220225, Val Acc: 92.86%, Val-Class-Acc: {0: '89.21%', 1: '96.24%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.045834, Train-Class-Acc: {0: '98.83%', 1: '98.47%'},
# Val Loss: 0.241844, Val Acc: 92.57%, Val-Class-Acc: {0: '87.37%', 1: '97.37%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.045418, Train-Class-Acc: {0: '98.29%', 1: '98.54%'},
# Val Loss: 0.223852, Val Acc: 93.06%, Val-Class-Acc: {0: '89.41%', 1: '96.43%'}, LR: 0.000100
# Epoch 208/1000, Train Loss: 0.044633, Train-Class-Acc: {0: '98.76%', 1: '98.62%'},
# Val Loss: 0.259609, Val Acc: 92.08%, Val-Class-Acc: {0: '85.95%', 1: '97.74%'}, LR: 0.000100
# Epoch 209/1000, Train Loss: 0.046717, Train-Class-Acc: {0: '98.44%', 1: '98.62%'},
# Val Loss: 0.212502, Val Acc: 93.06%, Val-Class-Acc: {0: '90.02%', 1: '95.86%'}, LR: 0.000100
# Epoch 210/1000, Train Loss: 0.043003, Train-Class-Acc: {0: '99.30%', 1: '98.98%'},
# Val Loss: 0.216443, Val Acc: 93.16%, Val-Class-Acc: {0: '90.02%', 1: '96.05%'}, LR: 0.000100
# Epoch 211/1000, Train Loss: 0.045056, Train-Class-Acc: {0: '98.60%', 1: '98.47%'},
# Val Loss: 0.245834, Val Acc: 92.77%, Val-Class-Acc: {0: '87.37%', 1: '97.74%'}, LR: 0.000100
# Epoch 212/1000, Train Loss: 0.046849, Train-Class-Acc: {0: '98.60%', 1: '98.62%'},
# Val Loss: 0.237134, Val Acc: 93.16%, Val-Class-Acc: {0: '88.19%', 1: '97.74%'}, LR: 0.000100
# Epoch 213/1000, Train Loss: 0.043858, Train-Class-Acc: {0: '98.91%', 1: '98.54%'},
# Val Loss: 0.233091, Val Acc: 93.16%, Val-Class-Acc: {0: '88.59%', 1: '97.37%'}, LR: 0.000100
# Epoch 214/1000, Train Loss: 0.043174, Train-Class-Acc: {0: '99.30%', 1: '99.05%'},
# Val Loss: 0.215276, Val Acc: 93.16%, Val-Class-Acc: {0: '89.82%', 1: '96.24%'}, LR: 0.000100
# Epoch 215/1000, Train Loss: 0.042098, Train-Class-Acc: {0: '98.99%', 1: '98.98%'},
# Val Loss: 0.234224, Val Acc: 93.06%, Val-Class-Acc: {0: '88.59%', 1: '97.18%'}, LR: 0.000100
# Epoch 216/1000, Train Loss: 0.044695, Train-Class-Acc: {0: '98.99%', 1: '98.33%'},
# Val Loss: 0.214534, Val Acc: 93.26%, Val-Class-Acc: {0: '90.22%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_169.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_216.pth
# Epoch 217/1000, Train Loss: 0.041916, Train-Class-Acc: {0: '98.91%', 1: '98.76%'},
# Val Loss: 0.231609, Val Acc: 93.16%, Val-Class-Acc: {0: '88.59%', 1: '97.37%'}, LR: 0.000100
# Epoch 218/1000, Train Loss: 0.044119, Train-Class-Acc: {0: '98.68%', 1: '98.54%'},
# Val Loss: 0.243381, Val Acc: 92.86%, Val-Class-Acc: {0: '87.58%', 1: '97.74%'}, LR: 0.000100
# Epoch 219/1000, Train Loss: 0.042772, Train-Class-Acc: {0: '98.68%', 1: '99.13%'},
# Val Loss: 0.236050, Val Acc: 93.06%, Val-Class-Acc: {0: '87.98%', 1: '97.74%'}, LR: 0.000100
# Epoch 220/1000, Train Loss: 0.040995, Train-Class-Acc: {0: '99.14%', 1: '98.62%'},
# Val Loss: 0.254550, Val Acc: 92.38%, Val-Class-Acc: {0: '86.56%', 1: '97.74%'}, LR: 0.000100
# Epoch 221/1000, Train Loss: 0.039868, Train-Class-Acc: {0: '99.14%', 1: '98.76%'},
# Val Loss: 0.245848, Val Acc: 92.86%, Val-Class-Acc: {0: '87.58%', 1: '97.74%'}, LR: 0.000100
# Epoch 222/1000, Train Loss: 0.041598, Train-Class-Acc: {0: '98.83%', 1: '98.69%'},
# Val Loss: 0.213206, Val Acc: 93.16%, Val-Class-Acc: {0: '90.63%', 1: '95.49%'}, LR: 0.000100
# Epoch 223/1000, Train Loss: 0.038933, Train-Class-Acc: {0: '99.38%', 1: '98.69%'},
# Val Loss: 0.221742, Val Acc: 93.16%, Val-Class-Acc: {0: '89.82%', 1: '96.24%'}, LR: 0.000100
# Epoch 224/1000, Train Loss: 0.040318, Train-Class-Acc: {0: '98.99%', 1: '98.69%'},
# Val Loss: 0.235855, Val Acc: 93.16%, Val-Class-Acc: {0: '88.80%', 1: '97.18%'}, LR: 0.000100
# Epoch 225/1000, Train Loss: 0.037616, Train-Class-Acc: {0: '99.30%', 1: '98.76%'},
# Val Loss: 0.211353, Val Acc: 93.26%, Val-Class-Acc: {0: '90.84%', 1: '95.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_173.pth
# ...
# Epoch 924/1000, Train Loss: 0.000731, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.388138, Val Acc: 94.23%, Val-Class-Acc: {0: '91.24%', 1: '96.99%'}, LR: 0.000100
# Epoch 925/1000, Train Loss: 0.000728, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.413896, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 926/1000, Train Loss: 0.001168, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.427112, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 927/1000, Train Loss: 0.000832, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.430712, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 928/1000, Train Loss: 0.000937, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.371434, Val Acc: 94.13%, Val-Class-Acc: {0: '91.24%', 1: '96.80%'}, LR: 0.000100
# Epoch 929/1000, Train Loss: 0.000529, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.378520, Val Acc: 94.23%, Val-Class-Acc: {0: '91.24%', 1: '96.99%'}, LR: 0.000100
# Epoch 930/1000, Train Loss: 0.000707, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.384790, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# Epoch 931/1000, Train Loss: 0.000521, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.405466, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '97.74%'}, LR: 0.000100
# Epoch 932/1000, Train Loss: 0.000433, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.423156, Val Acc: 94.33%, Val-Class-Acc: {0: '90.22%', 1: '98.12%'}, LR: 0.000100
# Epoch 933/1000, Train Loss: 0.000285, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.425960, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 934/1000, Train Loss: 0.000612, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.375098, Val Acc: 94.04%, Val-Class-Acc: {0: '91.04%', 1: '96.80%'}, LR: 0.000100
# Epoch 935/1000, Train Loss: 0.001147, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.498118, Val Acc: 92.67%, Val-Class-Acc: {0: '86.56%', 1: '98.31%'}, LR: 0.000100
# Epoch 936/1000, Train Loss: 0.001595, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.427890, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.002503, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.404125, Val Acc: 93.94%, Val-Class-Acc: {0: '90.43%', 1: '97.18%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.013394, Train-Class-Acc: {0: '99.22%', 1: '99.49%'},
# Val Loss: 0.375915, Val Acc: 93.84%, Val-Class-Acc: {0: '89.82%', 1: '97.56%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.003328, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.384397, Val Acc: 94.04%, Val-Class-Acc: {0: '90.22%', 1: '97.56%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.002061, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.384569, Val Acc: 94.23%, Val-Class-Acc: {0: '90.63%', 1: '97.56%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.000690, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.379423, Val Acc: 94.53%, Val-Class-Acc: {0: '91.65%', 1: '97.18%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.000834, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.406618, Val Acc: 94.23%, Val-Class-Acc: {0: '90.43%', 1: '97.74%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.000898, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.437015, Val Acc: 93.45%, Val-Class-Acc: {0: '88.59%', 1: '97.93%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.000733, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.397340, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '97.18%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.000496, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.406666, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.001237, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.492667, Val Acc: 92.67%, Val-Class-Acc: {0: '86.35%', 1: '98.50%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.001417, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.403046, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.000628, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.409181, Val Acc: 94.53%, Val-Class-Acc: {0: '90.84%', 1: '97.93%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.001047, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.410101, Val Acc: 94.13%, Val-Class-Acc: {0: '90.43%', 1: '97.56%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.000947, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.407401, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '97.74%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.000733, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.397091, Val Acc: 94.04%, Val-Class-Acc: {0: '91.24%', 1: '96.62%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.000508, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.442591, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.000413, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.410021, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.001725, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.381661, Val Acc: 93.94%, Val-Class-Acc: {0: '90.63%', 1: '96.99%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.000667, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.406735, Val Acc: 94.23%, Val-Class-Acc: {0: '90.43%', 1: '97.74%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.000507, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.400833, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.000577, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.407360, Val Acc: 94.23%, Val-Class-Acc: {0: '90.84%', 1: '97.37%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.000588, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.394295, Val Acc: 93.94%, Val-Class-Acc: {0: '91.04%', 1: '96.62%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.000656, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.430964, Val Acc: 94.04%, Val-Class-Acc: {0: '89.61%', 1: '98.12%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.000536, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.407583, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '97.74%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.000741, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.452170, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.000414, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.440818, Val Acc: 93.84%, Val-Class-Acc: {0: '89.21%', 1: '98.12%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.000635, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.440224, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.000797, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.458087, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.000576, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.412686, Val Acc: 94.62%, Val-Class-Acc: {0: '91.04%', 1: '97.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_654.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_965.pth
# Epoch 966/1000, Train Loss: 0.002126, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.400637, Val Acc: 93.84%, Val-Class-Acc: {0: '89.41%', 1: '97.93%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.000592, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.405707, Val Acc: 94.04%, Val-Class-Acc: {0: '90.43%', 1: '97.37%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.000422, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.403514, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.000569, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.420504, Val Acc: 94.04%, Val-Class-Acc: {0: '89.82%', 1: '97.93%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.000372, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.402615, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.000734, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.427728, Val Acc: 93.84%, Val-Class-Acc: {0: '89.21%', 1: '98.12%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.000480, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.410552, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '97.74%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.000602, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.444132, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.000533, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.406316, Val Acc: 94.13%, Val-Class-Acc: {0: '90.84%', 1: '97.18%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.000291, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.429673, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.000336, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.418191, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.000444, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.425872, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.000438, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.452127, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.000512, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.403900, Val Acc: 94.53%, Val-Class-Acc: {0: '91.24%', 1: '97.56%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.000997, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.404354, Val Acc: 93.94%, Val-Class-Acc: {0: '90.63%', 1: '96.99%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.000825, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.413181, Val Acc: 93.84%, Val-Class-Acc: {0: '89.82%', 1: '97.56%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.000406, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.444397, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.000362, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.435760, Val Acc: 93.94%, Val-Class-Acc: {0: '89.82%', 1: '97.74%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.000335, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.441783, Val Acc: 94.04%, Val-Class-Acc: {0: '89.82%', 1: '97.93%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.000292, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.442323, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.000638, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.394824, Val Acc: 94.23%, Val-Class-Acc: {0: '90.63%', 1: '97.56%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.001177, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.469079, Val Acc: 93.65%, Val-Class-Acc: {0: '88.80%', 1: '98.12%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.000716, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.440997, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.000679, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.432123, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.000624, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.406499, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.001646, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.461982, Val Acc: 92.86%, Val-Class-Acc: {0: '87.17%', 1: '98.12%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.001217, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.384499, Val Acc: 94.04%, Val-Class-Acc: {0: '91.65%', 1: '96.24%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.001316, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.347487, Val Acc: 93.84%, Val-Class-Acc: {0: '91.85%', 1: '95.68%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.000869, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.424504, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.000409, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.424127, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.000433, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.421190, Val Acc: 94.13%, Val-Class-Acc: {0: '90.22%', 1: '97.74%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.000575, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.425691, Val Acc: 94.13%, Val-Class-Acc: {0: '90.63%', 1: '97.37%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.000601, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.417018, Val Acc: 94.43%, Val-Class-Acc: {0: '90.43%', 1: '98.12%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.000409, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.416133, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.000440, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.490800, Val Acc: 92.96%, Val-Class-Acc: {0: '87.17%', 1: '98.31%'}, LR: 0.000100
#
# ⏳ Total training time: 79.13 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_best.pth (Val Accuracy: 94.62%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 965, Train Loss: 0.000576, Train-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.412686, Val Acc: 94.62%, Val-Acc: {0: '91.04%', 1: '97.93%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_965.pth
# Epoch 880, Train Loss: 0.000657, Train-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.387258, Val Acc: 94.62%, Val-Acc: {0: '91.04%', 1: '97.93%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_880.pth
# Epoch 804, Train Loss: 0.000888, Train-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.389568, Val Acc: 94.62%, Val-Acc: {0: '91.04%', 1: '97.93%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_804.pth
# Epoch 621, Train Loss: 0.001468, Train-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.335178, Val Acc: 94.62%, Val-Acc: {0: '91.04%', 1: '97.93%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_621.pth
# Epoch 685, Train Loss: 0.002208, Train-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.354538, Val Acc: 94.53%, Val-Acc: {0: '90.84%', 1: '97.93%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1/HAR_MLP_epoch_685.pth
# ---
# ### Period 1
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_1'*
# + ##### Best Epoch: 965
# #### __Val Accuracy: 94.62%__
# #### __Val-Class-Acc: {0: '91.04%', 1: '97.93%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v1(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ---
# ### Period 2
# + ##### Total training time: 243.23 seconds
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2'*
# + ##### Best Epoch: 935
# #### __Val Accuracy: 97.72%__
# #### __Val-Class-Acc: {0: '90.22%', 1: '98.68%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 2 Configuration
# ================================
period = 2

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_2")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 1 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_1", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v1(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher Information Matrix (based on Period 1 training data)
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[1]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[1]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer (new for Period 2)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Memory cleanup
del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 27486 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# /tmp/ipykernel_3491776/1503672125.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.403891, Train-Class-Acc: {0: '82.35%', 1: '72.42%', 2: '96.23%'},
# Val Loss: 0.166479, Val Acc: 96.60%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.144973, Train-Class-Acc: {0: '90.44%', 1: '93.96%', 2: '99.97%'},
# Val Loss: 0.125727, Val Acc: 96.97%, Val-Class-Acc: {0: '87.37%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.109035, Train-Class-Acc: {0: '93.78%', 1: '95.34%', 2: '99.97%'},
# Val Loss: 0.112250, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.094232, Train-Class-Acc: {0: '94.87%', 1: '95.92%', 2: '99.94%'},
# Val Loss: 0.101696, Val Acc: 97.18%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.085195, Train-Class-Acc: {0: '95.65%', 1: '96.36%', 2: '100.00%'},
# Val Loss: 0.098359, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.079284, Train-Class-Acc: {0: '94.63%', 1: '96.87%', 2: '100.00%'},
# Val Loss: 0.091515, Val Acc: 97.22%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.074304, Train-Class-Acc: {0: '95.10%', 1: '96.29%', 2: '100.00%'},
# Val Loss: 0.087472, Val Acc: 97.30%, Val-Class-Acc: {0: '90.43%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.068314, Train-Class-Acc: {0: '96.35%', 1: '96.87%', 2: '100.00%'},
# Val Loss: 0.089251, Val Acc: 96.97%, Val-Class-Acc: {0: '87.78%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 9/1000, Train Loss: 0.065473, Train-Class-Acc: {0: '95.88%', 1: '96.58%', 2: '100.00%'},
# Val Loss: 0.084116, Val Acc: 97.18%, Val-Class-Acc: {0: '90.22%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.061670, Train-Class-Acc: {0: '96.89%', 1: '96.94%', 2: '100.00%'},
# Val Loss: 0.087469, Val Acc: 97.05%, Val-Class-Acc: {0: '87.98%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 11/1000, Train Loss: 0.061315, Train-Class-Acc: {0: '96.03%', 1: '97.02%', 2: '100.00%'},
# Val Loss: 0.080548, Val Acc: 97.18%, Val-Class-Acc: {0: '90.22%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.058288, Train-Class-Acc: {0: '96.50%', 1: '97.23%', 2: '100.00%'},
# Val Loss: 0.077708, Val Acc: 97.34%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.056204, Train-Class-Acc: {0: '97.05%', 1: '97.45%', 2: '100.00%'},
# Val Loss: 0.077727, Val Acc: 97.18%, Val-Class-Acc: {0: '90.63%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 14/1000, Train Loss: 0.053729, Train-Class-Acc: {0: '97.12%', 1: '97.53%', 2: '100.00%'},
# Val Loss: 0.083244, Val Acc: 97.14%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.054180, Train-Class-Acc: {0: '96.81%', 1: '97.31%', 2: '100.00%'},
# Val Loss: 0.086854, Val Acc: 96.89%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.049025, Train-Class-Acc: {0: '97.59%', 1: '97.60%', 2: '100.00%'},
# Val Loss: 0.075334, Val Acc: 97.34%, Val-Class-Acc: {0: '91.65%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.049111, Train-Class-Acc: {0: '97.20%', 1: '97.60%', 2: '100.00%'},
# Val Loss: 0.076418, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.049083, Train-Class-Acc: {0: '97.51%', 1: '97.16%', 2: '100.00%'},
# Val Loss: 0.089600, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.045724, Train-Class-Acc: {0: '97.43%', 1: '97.89%', 2: '100.00%'},
# Val Loss: 0.079536, Val Acc: 97.14%, Val-Class-Acc: {0: '89.41%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.045637, Train-Class-Acc: {0: '97.90%', 1: '97.89%', 2: '100.00%'},
# Val Loss: 0.075670, Val Acc: 97.34%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.044393, Train-Class-Acc: {0: '98.13%', 1: '98.03%', 2: '100.00%'},
# Val Loss: 0.088291, Val Acc: 96.85%, Val-Class-Acc: {0: '86.35%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.044797, Train-Class-Acc: {0: '97.51%', 1: '97.67%', 2: '100.00%'},
# Val Loss: 0.077830, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.043756, Train-Class-Acc: {0: '97.74%', 1: '97.74%', 2: '100.00%'},
# Val Loss: 0.083472, Val Acc: 97.01%, Val-Class-Acc: {0: '87.37%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.041755, Train-Class-Acc: {0: '97.98%', 1: '98.18%', 2: '100.00%'},
# Val Loss: 0.076936, Val Acc: 97.43%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.042242, Train-Class-Acc: {0: '97.82%', 1: '97.96%', 2: '100.00%'},
# Val Loss: 0.072762, Val Acc: 97.26%, Val-Class-Acc: {0: '92.67%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.042028, Train-Class-Acc: {0: '98.21%', 1: '97.67%', 2: '100.00%'},
# Val Loss: 0.082441, Val Acc: 97.18%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.038564, Train-Class-Acc: {0: '97.82%', 1: '98.40%', 2: '100.00%'},
# Val Loss: 0.074368, Val Acc: 97.30%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.038679, Train-Class-Acc: {0: '98.06%', 1: '98.33%', 2: '100.00%'},
# Val Loss: 0.075004, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.037963, Train-Class-Acc: {0: '98.06%', 1: '98.33%', 2: '100.00%'},
# Val Loss: 0.074162, Val Acc: 97.30%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.039122, Train-Class-Acc: {0: '98.21%', 1: '98.03%', 2: '100.00%'},
# Val Loss: 0.084697, Val Acc: 97.05%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.037888, Train-Class-Acc: {0: '98.52%', 1: '97.89%', 2: '100.00%'},
# Val Loss: 0.074835, Val Acc: 97.47%, Val-Class-Acc: {0: '91.24%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.036564, Train-Class-Acc: {0: '98.06%', 1: '98.54%', 2: '100.00%'},
# Val Loss: 0.082133, Val Acc: 97.18%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.034400, Train-Class-Acc: {0: '98.76%', 1: '98.47%', 2: '100.00%'},
# Val Loss: 0.079307, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.035647, Train-Class-Acc: {0: '97.90%', 1: '98.33%', 2: '100.00%'},
# Val Loss: 0.074592, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.033934, Train-Class-Acc: {0: '98.37%', 1: '98.62%', 2: '100.00%'},
# Val Loss: 0.074115, Val Acc: 97.39%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.033925, Train-Class-Acc: {0: '98.44%', 1: '98.54%', 2: '100.00%'},
# Val Loss: 0.079666, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.033812, Train-Class-Acc: {0: '98.21%', 1: '98.40%', 2: '100.00%'},
# Val Loss: 0.078913, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.033245, Train-Class-Acc: {0: '98.60%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.077353, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.032737, Train-Class-Acc: {0: '98.68%', 1: '98.18%', 2: '100.00%'},
# Val Loss: 0.090374, Val Acc: 96.80%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.032007, Train-Class-Acc: {0: '98.44%', 1: '98.84%', 2: '100.00%'},
# Val Loss: 0.074164, Val Acc: 97.30%, Val-Class-Acc: {0: '91.65%', 1: '95.49%', 2: '100.00%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.030985, Train-Class-Acc: {0: '98.83%', 1: '98.69%', 2: '100.00%'},
# Val Loss: 0.093792, Val Acc: 96.80%, Val-Class-Acc: {0: '86.15%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.030997, Train-Class-Acc: {0: '98.44%', 1: '98.84%', 2: '100.00%'},
# Val Loss: 0.089912, Val Acc: 96.85%, Val-Class-Acc: {0: '86.35%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.029776, Train-Class-Acc: {0: '98.44%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.073255, Val Acc: 97.26%, Val-Class-Acc: {0: '92.06%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.030654, Train-Class-Acc: {0: '98.83%', 1: '98.47%', 2: '99.97%'},
# Val Loss: 0.077178, Val Acc: 97.22%, Val-Class-Acc: {0: '90.84%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.029971, Train-Class-Acc: {0: '98.68%', 1: '98.91%', 2: '100.00%'},
# Val Loss: 0.076561, Val Acc: 97.26%, Val-Class-Acc: {0: '91.04%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.029351, Train-Class-Acc: {0: '98.44%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.077414, Val Acc: 97.43%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.029245, Train-Class-Acc: {0: '99.07%', 1: '98.91%', 2: '99.97%'},
# Val Loss: 0.076494, Val Acc: 97.30%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.028597, Train-Class-Acc: {0: '98.60%', 1: '99.05%', 2: '100.00%'},
# Val Loss: 0.075307, Val Acc: 97.30%, Val-Class-Acc: {0: '92.46%', 1: '94.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.027269, Train-Class-Acc: {0: '99.22%', 1: '99.05%', 2: '100.00%'},
# Val Loss: 0.081959, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.026106, Train-Class-Acc: {0: '98.76%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.076792, Val Acc: 97.18%, Val-Class-Acc: {0: '91.85%', 1: '94.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.027122, Train-Class-Acc: {0: '99.14%', 1: '98.91%', 2: '100.00%'},
# Val Loss: 0.078780, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.026490, Train-Class-Acc: {0: '99.38%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.078072, Val Acc: 97.34%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.029376, Train-Class-Acc: {0: '98.21%', 1: '98.91%', 2: '100.00%'},
# Val Loss: 0.077896, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.027047, Train-Class-Acc: {0: '98.52%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.079370, Val Acc: 97.43%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.026541, Train-Class-Acc: {0: '99.14%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.082870, Val Acc: 97.43%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.025013, Train-Class-Acc: {0: '98.99%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.085470, Val Acc: 97.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.024737, Train-Class-Acc: {0: '99.38%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.077243, Val Acc: 97.26%, Val-Class-Acc: {0: '91.65%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.024791, Train-Class-Acc: {0: '99.07%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.080988, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_58.pth
# Epoch 59/1000, Train Loss: 0.024242, Train-Class-Acc: {0: '99.07%', 1: '98.98%', 2: '100.00%'},
# Val Loss: 0.077375, Val Acc: 97.30%, Val-Class-Acc: {0: '91.45%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.023763, Train-Class-Acc: {0: '99.53%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.093244, Val Acc: 96.97%, Val-Class-Acc: {0: '87.17%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.022795, Train-Class-Acc: {0: '99.30%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.079197, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.023229, Train-Class-Acc: {0: '99.46%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.082593, Val Acc: 97.51%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.024131, Train-Class-Acc: {0: '99.14%', 1: '99.05%', 2: '100.00%'},
# Val Loss: 0.083815, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.022539, Train-Class-Acc: {0: '99.38%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.104447, Val Acc: 96.27%, Val-Class-Acc: {0: '83.71%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.023170, Train-Class-Acc: {0: '99.07%', 1: '98.98%', 2: '100.00%'},
# Val Loss: 0.079925, Val Acc: 97.47%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.022316, Train-Class-Acc: {0: '99.46%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.081962, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.021083, Train-Class-Acc: {0: '99.22%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.080853, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_67.pth
# Epoch 68/1000, Train Loss: 0.024005, Train-Class-Acc: {0: '98.99%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.085591, Val Acc: 97.43%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.021199, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.091653, Val Acc: 97.18%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.021482, Train-Class-Acc: {0: '99.14%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.079234, Val Acc: 97.30%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.021063, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.092034, Val Acc: 97.10%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.021406, Train-Class-Acc: {0: '99.38%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.083847, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.021537, Train-Class-Acc: {0: '99.30%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.080752, Val Acc: 97.34%, Val-Class-Acc: {0: '91.65%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.021312, Train-Class-Acc: {0: '99.38%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.095558, Val Acc: 96.93%, Val-Class-Acc: {0: '86.97%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.021738, Train-Class-Acc: {0: '99.30%', 1: '99.05%', 2: '100.00%'},
# Val Loss: 0.086104, Val Acc: 97.39%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.021021, Train-Class-Acc: {0: '99.22%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.081127, Val Acc: 97.39%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.021373, Train-Class-Acc: {0: '99.22%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.080393, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.018953, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.091723, Val Acc: 97.18%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.019813, Train-Class-Acc: {0: '99.30%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.084135, Val Acc: 97.43%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.019765, Train-Class-Acc: {0: '99.46%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.086883, Val Acc: 97.51%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_80.pth
# Epoch 81/1000, Train Loss: 0.018693, Train-Class-Acc: {0: '99.46%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.082061, Val Acc: 97.34%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.019416, Train-Class-Acc: {0: '99.38%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.092475, Val Acc: 97.18%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.019550, Train-Class-Acc: {0: '99.38%', 1: '98.98%', 2: '100.00%'},
# Val Loss: 0.085095, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.019172, Train-Class-Acc: {0: '99.38%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.082875, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.018949, Train-Class-Acc: {0: '99.61%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.086534, Val Acc: 97.51%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.019363, Train-Class-Acc: {0: '99.22%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.088444, Val Acc: 97.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.018426, Train-Class-Acc: {0: '99.77%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.093984, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.018305, Train-Class-Acc: {0: '99.69%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.089228, Val Acc: 97.47%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.017711, Train-Class-Acc: {0: '99.69%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.099662, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.017962, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.081881, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.018530, Train-Class-Acc: {0: '99.38%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.083651, Val Acc: 97.34%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.017192, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.089346, Val Acc: 97.47%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.017717, Train-Class-Acc: {0: '99.46%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.090440, Val Acc: 97.34%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.017188, Train-Class-Acc: {0: '99.53%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.087087, Val Acc: 97.26%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.016206, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.096873, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.017919, Train-Class-Acc: {0: '99.38%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.083426, Val Acc: 97.47%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.016825, Train-Class-Acc: {0: '99.84%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.112535, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.016973, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.088689, Val Acc: 97.51%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.015709, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.094937, Val Acc: 97.30%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.016472, Train-Class-Acc: {0: '99.84%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.093338, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.015634, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.095273, Val Acc: 97.43%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.015746, Train-Class-Acc: {0: '99.61%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.096387, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.015901, Train-Class-Acc: {0: '99.53%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.097823, Val Acc: 97.22%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.015715, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.095350, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.015478, Train-Class-Acc: {0: '99.61%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.088460, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.016216, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '99.97%'},
# Val Loss: 0.089864, Val Acc: 97.34%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.015137, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.087010, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.015121, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.104320, Val Acc: 97.05%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.015890, Train-Class-Acc: {0: '99.69%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.097105, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.014953, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.094667, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.015922, Train-Class-Acc: {0: '99.61%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.091542, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.014748, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.094340, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.015222, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.104741, Val Acc: 97.01%, Val-Class-Acc: {0: '87.37%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.015906, Train-Class-Acc: {0: '99.61%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.088863, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.015241, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.096424, Val Acc: 97.30%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.014038, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.088679, Val Acc: 97.39%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.014441, Train-Class-Acc: {0: '99.92%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.090174, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.013928, Train-Class-Acc: {0: '99.38%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.099279, Val Acc: 97.22%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.014493, Train-Class-Acc: {0: '99.77%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.091598, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.013911, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.082503, Val Acc: 97.22%, Val-Class-Acc: {0: '92.87%', 1: '93.98%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.015291, Train-Class-Acc: {0: '99.77%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.091866, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.014603, Train-Class-Acc: {0: '99.92%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.086577, Val Acc: 97.30%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.013988, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.101486, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.013351, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.100847, Val Acc: 97.18%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.013591, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.097807, Val Acc: 97.43%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.013668, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.086209, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.013726, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.099693, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.013821, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.091864, Val Acc: 97.30%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.013183, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.101187, Val Acc: 97.30%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.013021, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.090955, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.012994, Train-Class-Acc: {0: '99.84%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.089282, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.012687, Train-Class-Acc: {0: '99.92%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.095796, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.013724, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.093456, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.013108, Train-Class-Acc: {0: '99.53%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.089768, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.013569, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.093172, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.011960, Train-Class-Acc: {0: '100.00%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.098574, Val Acc: 97.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.011999, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.105926, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.012909, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.101417, Val Acc: 97.22%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.012094, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.086162, Val Acc: 97.34%, Val-Class-Acc: {0: '91.45%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.012855, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.097928, Val Acc: 97.34%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.012292, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.097357, Val Acc: 97.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.013269, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.093276, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.013134, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.104067, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.012896, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.093896, Val Acc: 97.43%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.013210, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.097360, Val Acc: 97.30%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.012073, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.088735, Val Acc: 97.39%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.011962, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.098698, Val Acc: 97.51%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.012885, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.089262, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.012121, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.108887, Val Acc: 96.97%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.012260, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.092115, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.011828, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.097438, Val Acc: 97.43%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.012462, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.095909, Val Acc: 97.47%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.011415, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.105069, Val Acc: 97.10%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.011422, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.097277, Val Acc: 97.30%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.012301, Train-Class-Acc: {0: '99.92%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.103961, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.011411, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.086444, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.012342, Train-Class-Acc: {0: '99.53%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.113471, Val Acc: 96.89%, Val-Class-Acc: {0: '86.56%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.011901, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.095287, Val Acc: 97.43%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.011302, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.110098, Val Acc: 97.10%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.011845, Train-Class-Acc: {0: '100.00%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.101142, Val Acc: 97.39%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.012235, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.098639, Val Acc: 97.34%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.011102, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.097124, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.011648, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.097991, Val Acc: 97.30%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.010679, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.094895, Val Acc: 97.34%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.011631, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.094362, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.012046, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.105135, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.015001, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.107851, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.011617, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.112855, Val Acc: 97.01%, Val-Class-Acc: {0: '86.97%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.011853, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.104554, Val Acc: 97.14%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.011138, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.106369, Val Acc: 97.30%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.010942, Train-Class-Acc: {0: '99.92%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.094464, Val Acc: 97.39%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.010984, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.101092, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.010382, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.096279, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.010961, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.103048, Val Acc: 97.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.011283, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.113172, Val Acc: 96.97%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.010630, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.099903, Val Acc: 97.30%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.010247, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.105480, Val Acc: 97.34%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.010333, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.097026, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.010923, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.102042, Val Acc: 97.43%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.011688, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.097490, Val Acc: 97.43%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.011012, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.112336, Val Acc: 97.18%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.010440, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.100805, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.010614, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.104942, Val Acc: 97.18%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.011146, Train-Class-Acc: {0: '99.92%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.097899, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.011234, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.100610, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.010896, Train-Class-Acc: {0: '100.00%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.093595, Val Acc: 97.43%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.010550, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.093677, Val Acc: 97.26%, Val-Class-Acc: {0: '91.04%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.010427, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.089654, Val Acc: 97.47%, Val-Class-Acc: {0: '91.24%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.010978, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.100821, Val Acc: 97.47%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.010181, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.098351, Val Acc: 97.51%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.010351, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.106159, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.010028, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.096217, Val Acc: 97.39%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.011499, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.101512, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.010585, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.099708, Val Acc: 97.47%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.011023, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.098556, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.010119, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.100587, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.009935, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.096837, Val Acc: 97.39%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.009791, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.111106, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.010293, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.105694, Val Acc: 97.26%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.009908, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.097059, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.010070, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.103389, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.009787, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.109838, Val Acc: 97.30%, Val-Class-Acc: {0: '88.39%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.009453, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.109993, Val Acc: 97.30%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.009876, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.115884, Val Acc: 97.14%, Val-Class-Acc: {0: '87.78%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.009619, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.107837, Val Acc: 97.39%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.011189, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# ...
# Epoch 936/1000, Train Loss: 0.004518, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.131731, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.003950, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.127195, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.003769, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.119623, Val Acc: 97.22%, Val-Class-Acc: {0: '91.45%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.004044, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.136251, Val Acc: 97.43%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.004077, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.143197, Val Acc: 97.43%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.004851, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.126536, Val Acc: 97.51%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.004192, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.130475, Val Acc: 97.47%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.004463, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.138306, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.003893, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.134441, Val Acc: 97.34%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.003636, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.130425, Val Acc: 97.34%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.003789, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.126310, Val Acc: 97.39%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.004758, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.128546, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.004093, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.97%'},
# Val Loss: 0.147408, Val Acc: 97.18%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.004362, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.123280, Val Acc: 97.47%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.003773, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135164, Val Acc: 97.47%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.003718, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.136240, Val Acc: 97.55%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.004409, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.131872, Val Acc: 97.22%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.003958, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.126117, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.004415, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.129221, Val Acc: 97.26%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.005178, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.145584, Val Acc: 97.10%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.004225, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.139229, Val Acc: 97.47%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.004084, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.142786, Val Acc: 97.34%, Val-Class-Acc: {0: '89.00%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.004011, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.137168, Val Acc: 97.63%, Val-Class-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_612.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_958.pth
# Epoch 959/1000, Train Loss: 0.003778, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.121792, Val Acc: 97.30%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.004327, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.127566, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.004157, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.154483, Val Acc: 97.14%, Val-Class-Acc: {0: '87.78%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.003814, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135887, Val Acc: 97.51%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.003891, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144583, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.004976, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.136603, Val Acc: 97.51%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.003934, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.130369, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.003354, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.129562, Val Acc: 97.47%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.003670, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.134616, Val Acc: 97.43%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.004587, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.148012, Val Acc: 97.30%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.005828, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.137387, Val Acc: 97.34%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.004701, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.131482, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.003671, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.145320, Val Acc: 97.39%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.004156, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.123131, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.004086, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.151521, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.003848, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.139221, Val Acc: 97.51%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.003763, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144943, Val Acc: 97.59%, Val-Class-Acc: {0: '90.22%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_664.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_975.pth
# Epoch 976/1000, Train Loss: 0.004202, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.127985, Val Acc: 97.26%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.003575, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.152016, Val Acc: 97.26%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.004655, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.135859, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.004331, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.158825, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.003853, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.145826, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.004456, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.121243, Val Acc: 97.51%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.004000, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135508, Val Acc: 97.55%, Val-Class-Acc: {0: '90.43%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.004153, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.136647, Val Acc: 97.47%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.004293, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.127326, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.003866, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.122919, Val Acc: 97.34%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.004320, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.159950, Val Acc: 97.10%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.003645, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.150257, Val Acc: 97.22%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.004171, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.135304, Val Acc: 97.43%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.004696, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.129637, Val Acc: 97.34%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.005343, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.148081, Val Acc: 97.30%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.003746, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.146987, Val Acc: 97.39%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.003690, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.146091, Val Acc: 97.39%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.004566, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.152197, Val Acc: 97.39%, Val-Class-Acc: {0: '88.59%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.004788, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.141027, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.004487, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.133798, Val Acc: 97.34%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.003715, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.127956, Val Acc: 97.22%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.003969, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135715, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.004303, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.139927, Val Acc: 97.43%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.003781, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.130837, Val Acc: 97.18%, Val-Class-Acc: {0: '90.84%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.003741, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.141233, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 243.23 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_best.pth (Val Accuracy: 97.72%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 935, Train Loss: 0.004359, Train-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.136893, Val Acc: 97.72%, Val-Acc: {0: '90.22%', 1: '98.68%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_935.pth
# Epoch 958, Train Loss: 0.004011, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.137168, Val Acc: 97.63%, Val-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_958.pth
# Epoch 805, Train Loss: 0.004712, Train-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.128759, Val Acc: 97.63%, Val-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_805.pth
# Epoch 975, Train Loss: 0.003763, Train-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144943, Val Acc: 97.59%, Val-Acc: {0: '90.22%', 1: '98.12%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_975.pth
# Epoch 882, Train Loss: 0.004518, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.127061, Val Acc: 97.59%, Val-Acc: {0: '90.84%', 1: '97.56%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2/HAR_MLP_epoch_882.pth
# ---
# ### Period 2
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_2'*
# + ##### Best Epoch: 935
# #### __Val Accuracy: 97.72%__
# #### __Val-Class-Acc: {0: '90.22%', 1: '98.68%', 2: '100.00%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v1(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=3, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3
# + ##### Total training time: 263.91 seconds
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3'*
# + ##### Best Epoch: 871
# #### __Val Accuracy: 98.07%__
# #### __Val-Class-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}__

# %%
# ================================
# 📌 Period 3 Configuration
# ================================
period = 3

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_3")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 2 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_2", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v1(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 2 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[2]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[2]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 26557 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_3491776/1351216394.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.825303, Train-Class-Acc: {0: '46.89%', 1: '55.46%', 2: '84.35%', 3: '72.00%'},
# Val Loss: 0.244195, Val Acc: 94.06%, Val-Class-Acc: {0: '82.28%', 1: '95.30%', 2: '100.00%', 3: '88.27%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.336030, Train-Class-Acc: {0: '65.09%', 1: '82.53%', 2: '99.57%', 3: '85.50%'},
# Val Loss: 0.188144, Val Acc: 94.84%, Val-Class-Acc: {0: '84.93%', 1: '96.80%', 2: '100.00%', 3: '88.64%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.215803, Train-Class-Acc: {0: '79.63%', 1: '88.50%', 2: '99.88%', 3: '90.97%'},
# Val Loss: 0.154940, Val Acc: 95.45%, Val-Class-Acc: {0: '87.37%', 1: '96.43%', 2: '100.00%', 3: '90.13%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.166725, Train-Class-Acc: {0: '86.78%', 1: '91.70%', 2: '100.00%', 3: '93.67%'},
# Val Loss: 0.135529, Val Acc: 96.06%, Val-Class-Acc: {0: '90.43%', 1: '95.49%', 2: '100.00%', 3: '91.62%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.135778, Train-Class-Acc: {0: '88.80%', 1: '93.60%', 2: '100.00%', 3: '96.09%'},
# Val Loss: 0.124512, Val Acc: 96.10%, Val-Class-Acc: {0: '91.65%', 1: '94.55%', 2: '100.00%', 3: '91.62%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.114130, Train-Class-Acc: {0: '91.68%', 1: '94.69%', 2: '100.00%', 3: '96.87%'},
# Val Loss: 0.116988, Val Acc: 96.23%, Val-Class-Acc: {0: '88.80%', 1: '96.80%', 2: '100.00%', 3: '92.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.098504, Train-Class-Acc: {0: '92.77%', 1: '95.71%', 2: '99.97%', 3: '98.15%'},
# Val Loss: 0.104981, Val Acc: 96.64%, Val-Class-Acc: {0: '91.65%', 1: '95.30%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.091344, Train-Class-Acc: {0: '92.53%', 1: '96.65%', 2: '100.00%', 3: '98.72%'},
# Val Loss: 0.102107, Val Acc: 96.54%, Val-Class-Acc: {0: '91.04%', 1: '95.30%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.080047, Train-Class-Acc: {0: '94.71%', 1: '96.58%', 2: '100.00%', 3: '99.08%'},
# Val Loss: 0.098271, Val Acc: 96.61%, Val-Class-Acc: {0: '91.65%', 1: '95.11%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.076394, Train-Class-Acc: {0: '94.87%', 1: '96.94%', 2: '100.00%', 3: '98.72%'},
# Val Loss: 0.100016, Val Acc: 96.64%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.072264, Train-Class-Acc: {0: '95.41%', 1: '97.38%', 2: '100.00%', 3: '98.93%'},
# Val Loss: 0.098117, Val Acc: 96.67%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.068678, Train-Class-Acc: {0: '95.26%', 1: '97.23%', 2: '100.00%', 3: '99.15%'},
# Val Loss: 0.089142, Val Acc: 96.91%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 2: '100.00%', 3: '95.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.061955, Train-Class-Acc: {0: '96.42%', 1: '97.16%', 2: '100.00%', 3: '99.50%'},
# Val Loss: 0.085735, Val Acc: 96.84%, Val-Class-Acc: {0: '92.06%', 1: '94.74%', 2: '100.00%', 3: '95.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.058678, Train-Class-Acc: {0: '96.50%', 1: '97.74%', 2: '100.00%', 3: '99.29%'},
# Val Loss: 0.085584, Val Acc: 96.95%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%', 3: '95.34%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.058007, Train-Class-Acc: {0: '96.66%', 1: '97.53%', 2: '100.00%', 3: '99.50%'},
# Val Loss: 0.086464, Val Acc: 96.98%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '95.16%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.056053, Train-Class-Acc: {0: '96.58%', 1: '98.11%', 2: '100.00%', 3: '99.43%'},
# Val Loss: 0.083638, Val Acc: 96.95%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.052141, Train-Class-Acc: {0: '97.05%', 1: '98.25%', 2: '100.00%', 3: '99.50%'},
# Val Loss: 0.082171, Val Acc: 97.05%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.048018, Train-Class-Acc: {0: '97.98%', 1: '98.47%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.080236, Val Acc: 97.05%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.049043, Train-Class-Acc: {0: '96.97%', 1: '97.96%', 2: '100.00%', 3: '99.50%'},
# Val Loss: 0.084682, Val Acc: 96.98%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.047227, Train-Class-Acc: {0: '96.73%', 1: '98.33%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.075637, Val Acc: 96.95%, Val-Class-Acc: {0: '92.46%', 1: '94.55%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.045790, Train-Class-Acc: {0: '97.20%', 1: '98.33%', 2: '100.00%', 3: '99.57%'},
# Val Loss: 0.076636, Val Acc: 97.12%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%', 3: '95.72%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.041510, Train-Class-Acc: {0: '97.82%', 1: '98.33%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072813, Val Acc: 97.08%, Val-Class-Acc: {0: '91.85%', 1: '95.11%', 2: '100.00%', 3: '96.28%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.042961, Train-Class-Acc: {0: '97.82%', 1: '98.47%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.081058, Val Acc: 97.01%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%', 3: '95.72%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.040688, Train-Class-Acc: {0: '98.06%', 1: '98.40%', 2: '100.00%', 3: '99.72%'},
# Val Loss: 0.072967, Val Acc: 97.29%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.040269, Train-Class-Acc: {0: '97.51%', 1: '98.62%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.076534, Val Acc: 97.29%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%', 3: '96.46%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.037755, Train-Class-Acc: {0: '98.60%', 1: '98.84%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074545, Val Acc: 97.29%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.040140, Train-Class-Acc: {0: '98.06%', 1: '98.62%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.071493, Val Acc: 97.42%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.037000, Train-Class-Acc: {0: '98.37%', 1: '98.69%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.101284, Val Acc: 96.20%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.036888, Train-Class-Acc: {0: '97.90%', 1: '98.84%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.080162, Val Acc: 97.12%, Val-Class-Acc: {0: '89.21%', 1: '97.56%', 2: '100.00%', 3: '96.46%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.035634, Train-Class-Acc: {0: '97.90%', 1: '98.69%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075901, Val Acc: 97.35%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '96.83%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.035267, Train-Class-Acc: {0: '98.44%', 1: '98.76%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.071517, Val Acc: 97.42%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.033606, Train-Class-Acc: {0: '99.07%', 1: '98.76%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.071153, Val Acc: 97.32%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.035427, Train-Class-Acc: {0: '98.44%', 1: '98.76%', 2: '99.97%', 3: '99.86%'},
# Val Loss: 0.071812, Val Acc: 97.46%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.033333, Train-Class-Acc: {0: '98.76%', 1: '98.69%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.076851, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.93%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.032295, Train-Class-Acc: {0: '98.37%', 1: '98.54%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.089371, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '98.50%', 2: '100.00%', 3: '96.09%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.032034, Train-Class-Acc: {0: '98.76%', 1: '99.13%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.076336, Val Acc: 97.35%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%', 3: '96.83%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.031383, Train-Class-Acc: {0: '98.68%', 1: '98.69%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.076716, Val Acc: 97.29%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.030116, Train-Class-Acc: {0: '98.68%', 1: '98.84%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.081430, Val Acc: 97.18%, Val-Class-Acc: {0: '87.37%', 1: '98.50%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.030603, Train-Class-Acc: {0: '98.37%', 1: '99.13%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.073786, Val Acc: 97.18%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%', 3: '96.28%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.028987, Train-Class-Acc: {0: '98.99%', 1: '99.13%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.068904, Val Acc: 97.42%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.030307, Train-Class-Acc: {0: '98.76%', 1: '99.05%', 2: '99.97%', 3: '99.93%'},
# Val Loss: 0.080449, Val Acc: 97.25%, Val-Class-Acc: {0: '88.19%', 1: '98.50%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.028899, Train-Class-Acc: {0: '99.14%', 1: '99.13%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.068604, Val Acc: 97.25%, Val-Class-Acc: {0: '92.06%', 1: '94.55%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.029115, Train-Class-Acc: {0: '98.68%', 1: '99.05%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076500, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.028582, Train-Class-Acc: {0: '98.83%', 1: '98.91%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074573, Val Acc: 97.42%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.028056, Train-Class-Acc: {0: '98.91%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.071938, Val Acc: 97.42%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.027418, Train-Class-Acc: {0: '98.99%', 1: '99.05%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.073466, Val Acc: 97.42%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.026437, Train-Class-Acc: {0: '98.99%', 1: '99.34%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.075372, Val Acc: 97.46%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.026575, Train-Class-Acc: {0: '99.30%', 1: '99.27%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.079488, Val Acc: 97.22%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '96.28%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.026641, Train-Class-Acc: {0: '99.30%', 1: '99.05%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.068659, Val Acc: 97.42%, Val-Class-Acc: {0: '91.65%', 1: '95.86%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.025537, Train-Class-Acc: {0: '98.91%', 1: '99.34%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073458, Val Acc: 97.35%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.026143, Train-Class-Acc: {0: '99.07%', 1: '98.98%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.075780, Val Acc: 97.46%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.025140, Train-Class-Acc: {0: '99.30%', 1: '99.27%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.070092, Val Acc: 97.25%, Val-Class-Acc: {0: '91.65%', 1: '95.11%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.025642, Train-Class-Acc: {0: '99.07%', 1: '99.20%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071600, Val Acc: 97.18%, Val-Class-Acc: {0: '92.06%', 1: '94.74%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.024649, Train-Class-Acc: {0: '99.53%', 1: '99.13%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076117, Val Acc: 97.42%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.024679, Train-Class-Acc: {0: '99.22%', 1: '99.27%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071146, Val Acc: 97.56%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.022703, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.073609, Val Acc: 97.52%, Val-Class-Acc: {0: '91.45%', 1: '96.99%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.024779, Train-Class-Acc: {0: '99.30%', 1: '99.13%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.075969, Val Acc: 97.42%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.023730, Train-Class-Acc: {0: '99.46%', 1: '99.27%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073995, Val Acc: 97.46%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.023483, Train-Class-Acc: {0: '99.14%', 1: '99.20%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074614, Val Acc: 97.42%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.022972, Train-Class-Acc: {0: '99.53%', 1: '99.20%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.079163, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.022296, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080740, Val Acc: 97.18%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%', 3: '96.46%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.023364, Train-Class-Acc: {0: '99.22%', 1: '99.42%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072736, Val Acc: 97.46%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.022110, Train-Class-Acc: {0: '99.38%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.081961, Val Acc: 97.32%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.022484, Train-Class-Acc: {0: '98.99%', 1: '99.34%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.069237, Val Acc: 97.32%, Val-Class-Acc: {0: '91.65%', 1: '95.30%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.022056, Train-Class-Acc: {0: '99.38%', 1: '99.49%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.074043, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.021879, Train-Class-Acc: {0: '99.30%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080382, Val Acc: 97.22%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.022284, Train-Class-Acc: {0: '99.38%', 1: '99.27%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072948, Val Acc: 97.46%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.020730, Train-Class-Acc: {0: '99.53%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.069482, Val Acc: 97.39%, Val-Class-Acc: {0: '91.65%', 1: '95.68%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.020797, Train-Class-Acc: {0: '99.77%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074921, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.021243, Train-Class-Acc: {0: '99.30%', 1: '99.42%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073587, Val Acc: 97.52%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_70.pth
# Epoch 71/1000, Train Loss: 0.021018, Train-Class-Acc: {0: '99.46%', 1: '99.42%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072503, Val Acc: 97.32%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.021175, Train-Class-Acc: {0: '99.38%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074435, Val Acc: 97.35%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.021896, Train-Class-Acc: {0: '99.30%', 1: '99.20%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071729, Val Acc: 97.35%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.021191, Train-Class-Acc: {0: '99.14%', 1: '99.64%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072524, Val Acc: 97.35%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.019902, Train-Class-Acc: {0: '99.38%', 1: '99.78%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.069264, Val Acc: 97.29%, Val-Class-Acc: {0: '91.65%', 1: '95.11%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.020597, Train-Class-Acc: {0: '99.38%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074791, Val Acc: 97.49%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.019099, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079151, Val Acc: 97.46%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.019589, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074455, Val Acc: 97.49%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_78.pth
# Epoch 79/1000, Train Loss: 0.019536, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080396, Val Acc: 97.35%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.019159, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079525, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.02%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.019218, Train-Class-Acc: {0: '99.53%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074845, Val Acc: 97.32%, Val-Class-Acc: {0: '90.43%', 1: '96.62%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.019079, Train-Class-Acc: {0: '99.77%', 1: '99.56%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072095, Val Acc: 97.46%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.018365, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.078960, Val Acc: 97.49%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.019572, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.075624, Val Acc: 97.59%, Val-Class-Acc: {0: '90.43%', 1: '97.74%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_84.pth
# Epoch 85/1000, Train Loss: 0.017846, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076532, Val Acc: 97.49%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.017865, Train-Class-Acc: {0: '99.92%', 1: '99.20%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077514, Val Acc: 97.56%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_78.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_86.pth
# Epoch 87/1000, Train Loss: 0.019775, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.073761, Val Acc: 97.49%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.018673, Train-Class-Acc: {0: '99.38%', 1: '99.56%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073259, Val Acc: 97.49%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.018283, Train-Class-Acc: {0: '99.69%', 1: '99.42%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074742, Val Acc: 97.49%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.018351, Train-Class-Acc: {0: '99.61%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.070338, Val Acc: 97.49%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.018198, Train-Class-Acc: {0: '99.61%', 1: '99.85%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.073403, Val Acc: 97.52%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.017695, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081486, Val Acc: 97.42%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.017476, Train-Class-Acc: {0: '99.69%', 1: '99.49%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076140, Val Acc: 97.18%, Val-Class-Acc: {0: '91.45%', 1: '95.11%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.017153, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081265, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.017909, Train-Class-Acc: {0: '99.53%', 1: '99.71%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.078478, Val Acc: 97.56%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_95.pth
# Epoch 96/1000, Train Loss: 0.018301, Train-Class-Acc: {0: '99.22%', 1: '99.56%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.085722, Val Acc: 97.29%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.017526, Train-Class-Acc: {0: '99.53%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074257, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.016660, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081242, Val Acc: 97.35%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.017740, Train-Class-Acc: {0: '99.69%', 1: '99.56%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082282, Val Acc: 97.32%, Val-Class-Acc: {0: '89.00%', 1: '98.12%', 2: '100.00%', 3: '97.21%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.016501, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.086102, Val Acc: 97.35%, Val-Class-Acc: {0: '88.80%', 1: '98.31%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.016321, Train-Class-Acc: {0: '99.69%', 1: '99.56%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076025, Val Acc: 97.46%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.015998, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.070377, Val Acc: 97.49%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 2: '100.00%', 3: '98.32%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.016098, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.081616, Val Acc: 97.42%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.016466, Train-Class-Acc: {0: '99.38%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074287, Val Acc: 97.46%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.016070, Train-Class-Acc: {0: '99.61%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083515, Val Acc: 97.39%, Val-Class-Acc: {0: '88.80%', 1: '98.31%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.016468, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.068449, Val Acc: 97.29%, Val-Class-Acc: {0: '92.46%', 1: '94.17%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.016629, Train-Class-Acc: {0: '99.53%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076913, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.016207, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.083072, Val Acc: 97.32%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.016702, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.072957, Val Acc: 97.52%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.016399, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081951, Val Acc: 97.46%, Val-Class-Acc: {0: '88.80%', 1: '98.31%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.015980, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073104, Val Acc: 97.49%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.016248, Train-Class-Acc: {0: '99.46%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075634, Val Acc: 97.52%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.015726, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078709, Val Acc: 97.42%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.016305, Train-Class-Acc: {0: '99.53%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078497, Val Acc: 97.52%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.015903, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071212, Val Acc: 97.62%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%', 3: '98.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_70.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_115.pth
# Epoch 116/1000, Train Loss: 0.015641, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.078118, Val Acc: 97.69%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%', 3: '99.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_116.pth
# Epoch 117/1000, Train Loss: 0.015213, Train-Class-Acc: {0: '99.53%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081195, Val Acc: 97.32%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.015317, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073112, Val Acc: 97.76%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_86.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_118.pth
# Epoch 119/1000, Train Loss: 0.014920, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072629, Val Acc: 97.42%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.015771, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.069372, Val Acc: 97.59%, Val-Class-Acc: {0: '90.84%', 1: '95.68%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_95.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_120.pth
# Epoch 121/1000, Train Loss: 0.015290, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074379, Val Acc: 97.46%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.014653, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.085886, Val Acc: 97.46%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.014769, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078810, Val Acc: 97.42%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.014453, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.071207, Val Acc: 97.76%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_84.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_124.pth
# Epoch 125/1000, Train Loss: 0.015105, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075273, Val Acc: 97.46%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.014918, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074621, Val Acc: 97.83%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_120.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_126.pth
# Epoch 127/1000, Train Loss: 0.014469, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072131, Val Acc: 97.73%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_115.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_127.pth
# Epoch 128/1000, Train Loss: 0.014738, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081580, Val Acc: 97.42%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.014292, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076124, Val Acc: 97.76%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_116.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_129.pth
# Epoch 130/1000, Train Loss: 0.014593, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.065586, Val Acc: 97.66%, Val-Class-Acc: {0: '91.65%', 1: '95.11%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.013545, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.070048, Val Acc: 97.62%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.014547, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079426, Val Acc: 97.56%, Val-Class-Acc: {0: '90.02%', 1: '97.93%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.013557, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079785, Val Acc: 97.69%, Val-Class-Acc: {0: '90.43%', 1: '97.93%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.013961, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076977, Val Acc: 97.59%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.013696, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.074690, Val Acc: 97.79%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_127.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_135.pth
# Epoch 136/1000, Train Loss: 0.014043, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080343, Val Acc: 97.49%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.013727, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072938, Val Acc: 97.52%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.014150, Train-Class-Acc: {0: '99.53%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072899, Val Acc: 97.52%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%', 3: '98.32%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.013943, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071220, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '95.86%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.014168, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078811, Val Acc: 97.39%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.014079, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071851, Val Acc: 97.59%, Val-Class-Acc: {0: '90.84%', 1: '95.86%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.014154, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076432, Val Acc: 97.76%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.012970, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078336, Val Acc: 97.76%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.013464, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.077624, Val Acc: 97.49%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.013160, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075992, Val Acc: 97.46%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.014332, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079090, Val Acc: 97.59%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '98.51%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.014462, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.073537, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.013066, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.073129, Val Acc: 97.32%, Val-Class-Acc: {0: '91.45%', 1: '95.68%', 2: '100.00%', 3: '97.39%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.013842, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072763, Val Acc: 97.69%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.013897, Train-Class-Acc: {0: '99.53%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076398, Val Acc: 97.76%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.012973, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074380, Val Acc: 97.66%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.013496, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083071, Val Acc: 97.42%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.012841, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.071958, Val Acc: 97.69%, Val-Class-Acc: {0: '91.04%', 1: '95.86%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.012582, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080141, Val Acc: 97.46%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%', 3: '97.77%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.013292, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.088023, Val Acc: 97.46%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%', 3: '98.70%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.013563, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.068672, Val Acc: 97.79%, Val-Class-Acc: {0: '91.85%', 1: '95.68%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_118.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_156.pth
# Epoch 157/1000, Train Loss: 0.013167, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.076699, Val Acc: 97.62%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '98.51%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.012270, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.089313, Val Acc: 97.22%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 2: '100.00%', 3: '97.95%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.012691, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.075918, Val Acc: 97.59%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%', 3: '98.70%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.012934, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# ...
# Val Loss: 0.084258, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.007311, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.077297, Val Acc: 97.86%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.007593, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077260, Val Acc: 97.93%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.007599, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.074787, Val Acc: 97.86%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.007621, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082754, Val Acc: 97.93%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.007937, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.077460, Val Acc: 97.86%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.007584, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076868, Val Acc: 97.83%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.007397, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.088143, Val Acc: 97.86%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.007679, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.081061, Val Acc: 97.86%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.007737, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.093968, Val Acc: 97.66%, Val-Class-Acc: {0: '88.39%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.007616, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.087903, Val Acc: 97.62%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.007452, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078250, Val Acc: 97.69%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.008110, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075266, Val Acc: 97.90%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.007495, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082655, Val Acc: 97.90%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.007495, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082861, Val Acc: 97.90%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.007608, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079869, Val Acc: 97.86%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.007817, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.089715, Val Acc: 97.73%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.007988, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082525, Val Acc: 98.00%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.007422, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080253, Val Acc: 97.86%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.006750, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075449, Val Acc: 97.83%, Val-Class-Acc: {0: '91.65%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.007691, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075107, Val Acc: 97.90%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.007916, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.086509, Val Acc: 97.76%, Val-Class-Acc: {0: '88.39%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.007618, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.090103, Val Acc: 97.66%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.007309, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.085361, Val Acc: 97.86%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.007821, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.97%', 3: '99.93%'},
# Val Loss: 0.087309, Val Acc: 97.79%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.008063, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.093473, Val Acc: 97.66%, Val-Class-Acc: {0: '88.19%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.008343, Train-Class-Acc: {0: '99.61%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.076119, Val Acc: 97.86%, Val-Class-Acc: {0: '91.85%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.007702, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.084846, Val Acc: 97.90%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.007403, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083866, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.006834, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081064, Val Acc: 97.86%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.008340, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.087869, Val Acc: 97.79%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.008374, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.078944, Val Acc: 97.96%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.007633, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.094698, Val Acc: 97.69%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.007088, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078847, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.007538, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080327, Val Acc: 97.90%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.007635, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083582, Val Acc: 97.90%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.007978, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077716, Val Acc: 97.83%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.007809, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.077890, Val Acc: 97.79%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.007996, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077059, Val Acc: 97.90%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.007639, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080616, Val Acc: 97.86%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.008266, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.092975, Val Acc: 97.62%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.007843, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.085339, Val Acc: 97.79%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.007579, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079995, Val Acc: 97.76%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.008157, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079960, Val Acc: 97.83%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.007158, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083330, Val Acc: 97.90%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.007474, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.086483, Val Acc: 97.96%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.007267, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.076812, Val Acc: 97.83%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.006589, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.092430, Val Acc: 97.79%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.007297, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082192, Val Acc: 97.90%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.007722, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.085662, Val Acc: 97.86%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.007054, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080613, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.008272, Train-Class-Acc: {0: '99.69%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.075050, Val Acc: 97.83%, Val-Class-Acc: {0: '92.06%', 1: '95.30%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.007281, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083491, Val Acc: 97.90%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.007625, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.074108, Val Acc: 97.83%, Val-Class-Acc: {0: '92.46%', 1: '94.92%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.008262, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.091503, Val Acc: 97.66%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.008584, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072578, Val Acc: 97.79%, Val-Class-Acc: {0: '91.45%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.008160, Train-Class-Acc: {0: '99.69%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077845, Val Acc: 97.86%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.007445, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.091678, Val Acc: 97.66%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.007656, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075034, Val Acc: 97.79%, Val-Class-Acc: {0: '91.45%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 263.91 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_best.pth (Val Accuracy: 98.07%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 871, Train Loss: 0.007660, Train-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080872, Val Acc: 98.07%, Val-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_871.pth
# Epoch 868, Train Loss: 0.007414, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.083451, Val Acc: 98.03%, Val-Acc: {0: '90.43%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_868.pth
# Epoch 582, Train Loss: 0.008291, Train-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075071, Val Acc: 98.00%, Val-Acc: {0: '91.24%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_582.pth
# Epoch 578, Train Loss: 0.008782, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.070216, Val Acc: 98.00%, Val-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_578.pth
# Epoch 556, Train Loss: 0.008302, Train-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078273, Val Acc: 98.00%, Val-Acc: {0: '90.43%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3/HAR_MLP_epoch_556.pth
# ---
# ### Period 3
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_3'*
# + ##### Best Epoch: 871
# #### __Val Accuracy: 98.07%__
# #### __Val-Class-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v1(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=4, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4
# + ##### Total training time: 272.42 seconds
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4'*
# + ##### Best Epoch: 841
# #### __Val Accuracy: 96.27%__
# #### __Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '97.18%', 3: '99.81%', 4: '98.30%', 5: '93.33%'}__

# %%
# ================================
# 📌 Period 4 Configuration
# ================================
period = 4

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_4")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 3 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v1", "Period_3", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v1(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 3 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[3]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[3]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 26557 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_3491776/3642449888.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# Epoch 1/1000, Train Loss: 1.216455, Train-Class-Acc: {0: '51.09%', 1: '63.76%', 2: '43.39%', 3: '65.17%', 4: '48.65%', 5: '44.02%'},
# Val Loss: 0.638175, Val Acc: 79.95%, Val-Class-Acc: {0: '80.45%', 1: '98.12%', 2: '64.92%', 3: '88.64%', 4: '70.28%', 5: '73.81%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.593916, Train-Class-Acc: {0: '80.33%', 1: '88.86%', 2: '65.01%', 3: '90.69%', 4: '66.54%', 5: '67.34%'},
# Val Loss: 0.483212, Val Acc: 88.26%, Val-Class-Acc: {0: '88.59%', 1: '96.05%', 2: '85.28%', 3: '89.57%', 4: '94.27%', 5: '73.10%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.453118, Train-Class-Acc: {0: '86.55%', 1: '91.63%', 2: '78.06%', 3: '93.03%', 4: '76.98%', 5: '74.04%'},
# Val Loss: 0.419803, Val Acc: 88.19%, Val-Class-Acc: {0: '88.59%', 1: '96.43%', 2: '93.35%', 3: '90.32%', 4: '82.38%', 5: '75.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.373550, Train-Class-Acc: {0: '88.02%', 1: '93.52%', 2: '83.03%', 3: '94.24%', 4: '80.99%', 5: '79.01%'},
# Val Loss: 0.370150, Val Acc: 89.72%, Val-Class-Acc: {0: '89.21%', 1: '95.68%', 2: '94.96%', 3: '90.88%', 4: '88.96%', 5: '75.95%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.312858, Train-Class-Acc: {0: '90.28%', 1: '92.79%', 2: '88.01%', 3: '95.38%', 4: '85.83%', 5: '85.19%'},
# Val Loss: 0.339224, Val Acc: 90.26%, Val-Class-Acc: {0: '86.35%', 1: '97.56%', 2: '96.17%', 3: '91.06%', 4: '91.51%', 5: '76.19%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.266047, Train-Class-Acc: {0: '91.14%', 1: '94.76%', 2: '90.95%', 3: '96.16%', 4: '88.63%', 5: '87.42%'},
# Val Loss: 0.309093, Val Acc: 91.04%, Val-Class-Acc: {0: '90.43%', 1: '95.49%', 2: '97.38%', 3: '91.62%', 4: '90.23%', 5: '78.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.237348, Train-Class-Acc: {0: '92.92%', 1: '95.27%', 2: '92.33%', 3: '97.09%', 4: '89.10%', 5: '88.74%'},
# Val Loss: 0.288508, Val Acc: 91.62%, Val-Class-Acc: {0: '88.80%', 1: '96.62%', 2: '97.18%', 3: '91.62%', 4: '92.78%', 5: '80.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.207282, Train-Class-Acc: {0: '94.09%', 1: '96.14%', 2: '94.05%', 3: '98.08%', 4: '92.45%', 5: '90.37%'},
# Val Loss: 0.264589, Val Acc: 92.26%, Val-Class-Acc: {0: '88.39%', 1: '96.62%', 2: '96.77%', 3: '92.36%', 4: '94.48%', 5: '83.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.190504, Train-Class-Acc: {0: '94.56%', 1: '96.43%', 2: '94.21%', 3: '98.01%', 4: '92.73%', 5: '92.49%'},
# Val Loss: 0.242528, Val Acc: 92.81%, Val-Class-Acc: {0: '92.46%', 1: '93.61%', 2: '96.37%', 3: '92.92%', 4: '95.75%', 5: '84.52%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.176755, Train-Class-Acc: {0: '94.71%', 1: '95.71%', 2: '95.68%', 3: '98.37%', 4: '93.94%', 5: '93.10%'},
# Val Loss: 0.240175, Val Acc: 92.70%, Val-Class-Acc: {0: '91.24%', 1: '95.30%', 2: '97.58%', 3: '92.74%', 4: '92.36%', 5: '85.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.163894, Train-Class-Acc: {0: '94.79%', 1: '95.92%', 2: '95.51%', 3: '98.65%', 4: '94.59%', 5: '92.80%'},
# Val Loss: 0.241972, Val Acc: 92.37%, Val-Class-Acc: {0: '89.41%', 1: '96.62%', 2: '97.58%', 3: '92.55%', 4: '93.42%', 5: '82.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.153511, Train-Class-Acc: {0: '95.33%', 1: '96.22%', 2: '96.41%', 3: '99.00%', 4: '94.87%', 5: '94.73%'},
# Val Loss: 0.228213, Val Acc: 92.64%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '97.18%', 3: '92.74%', 4: '94.27%', 5: '84.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.145867, Train-Class-Acc: {0: '94.95%', 1: '96.58%', 2: '96.25%', 3: '99.29%', 4: '94.50%', 5: '95.13%'},
# Val Loss: 0.225012, Val Acc: 92.64%, Val-Class-Acc: {0: '90.22%', 1: '96.05%', 2: '97.38%', 3: '92.74%', 4: '92.99%', 5: '85.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.139574, Train-Class-Acc: {0: '94.87%', 1: '97.67%', 2: '96.82%', 3: '99.08%', 4: '95.53%', 5: '95.64%'},
# Val Loss: 0.205046, Val Acc: 93.35%, Val-Class-Acc: {0: '91.85%', 1: '95.11%', 2: '96.77%', 3: '93.11%', 4: '95.33%', 5: '86.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.128084, Train-Class-Acc: {0: '96.42%', 1: '97.31%', 2: '96.82%', 3: '99.22%', 4: '96.18%', 5: '96.25%'},
# Val Loss: 0.210301, Val Acc: 93.01%, Val-Class-Acc: {0: '91.85%', 1: '95.11%', 2: '97.98%', 3: '93.30%', 4: '92.14%', 5: '86.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.123313, Train-Class-Acc: {0: '96.35%', 1: '96.58%', 2: '97.88%', 3: '99.64%', 4: '96.18%', 5: '96.15%'},
# Val Loss: 0.203603, Val Acc: 93.04%, Val-Class-Acc: {0: '89.82%', 1: '96.24%', 2: '96.98%', 3: '93.30%', 4: '92.78%', 5: '88.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.120093, Train-Class-Acc: {0: '96.50%', 1: '97.23%', 2: '97.39%', 3: '99.43%', 4: '96.83%', 5: '95.84%'},
# Val Loss: 0.201744, Val Acc: 93.15%, Val-Class-Acc: {0: '89.82%', 1: '96.05%', 2: '97.18%', 3: '93.48%', 4: '93.42%', 5: '87.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.111107, Train-Class-Acc: {0: '96.81%', 1: '97.89%', 2: '97.72%', 3: '99.50%', 4: '96.27%', 5: '96.75%'},
# Val Loss: 0.200474, Val Acc: 93.08%, Val-Class-Acc: {0: '89.82%', 1: '96.05%', 2: '97.58%', 3: '93.67%', 4: '95.12%', 5: '84.76%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.106569, Train-Class-Acc: {0: '96.66%', 1: '97.38%', 2: '98.21%', 3: '99.64%', 4: '97.02%', 5: '96.45%'},
# Val Loss: 0.196608, Val Acc: 93.04%, Val-Class-Acc: {0: '89.21%', 1: '96.62%', 2: '97.18%', 3: '93.67%', 4: '92.57%', 5: '87.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.102709, Train-Class-Acc: {0: '97.12%', 1: '97.31%', 2: '98.21%', 3: '99.72%', 4: '97.48%', 5: '97.26%'},
# Val Loss: 0.198578, Val Acc: 93.21%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '97.38%', 3: '93.30%', 4: '94.48%', 5: '87.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.096971, Train-Class-Acc: {0: '97.05%', 1: '97.96%', 2: '97.96%', 3: '99.79%', 4: '97.39%', 5: '98.07%'},
# Val Loss: 0.196848, Val Acc: 92.98%, Val-Class-Acc: {0: '89.21%', 1: '96.24%', 2: '97.58%', 3: '93.48%', 4: '94.48%', 5: '85.48%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.097065, Train-Class-Acc: {0: '97.05%', 1: '98.18%', 2: '98.37%', 3: '99.72%', 4: '97.48%', 5: '97.57%'},
# Val Loss: 0.200630, Val Acc: 92.67%, Val-Class-Acc: {0: '92.46%', 1: '94.92%', 2: '97.98%', 3: '93.30%', 4: '89.60%', 5: '86.43%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.093913, Train-Class-Acc: {0: '96.73%', 1: '97.60%', 2: '98.29%', 3: '99.72%', 4: '97.76%', 5: '97.57%'},
# Val Loss: 0.185629, Val Acc: 93.42%, Val-Class-Acc: {0: '89.41%', 1: '96.24%', 2: '97.58%', 3: '94.23%', 4: '92.78%', 5: '89.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.090018, Train-Class-Acc: {0: '97.36%', 1: '98.03%', 2: '98.37%', 3: '99.72%', 4: '97.67%', 5: '98.38%'},
# Val Loss: 0.193070, Val Acc: 93.21%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '97.58%', 3: '93.48%', 4: '93.42%', 5: '87.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.085277, Train-Class-Acc: {0: '97.82%', 1: '97.96%', 2: '98.94%', 3: '99.72%', 4: '98.14%', 5: '98.17%'},
# Val Loss: 0.174404, Val Acc: 93.89%, Val-Class-Acc: {0: '90.22%', 1: '95.86%', 2: '97.18%', 3: '94.97%', 4: '95.12%', 5: '89.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.082202, Train-Class-Acc: {0: '97.12%', 1: '98.33%', 2: '98.53%', 3: '99.79%', 4: '97.95%', 5: '98.68%'},
# Val Loss: 0.173619, Val Acc: 93.99%, Val-Class-Acc: {0: '90.43%', 1: '96.05%', 2: '97.58%', 3: '95.53%', 4: '94.69%', 5: '88.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.081254, Train-Class-Acc: {0: '97.59%', 1: '98.03%', 2: '98.94%', 3: '99.57%', 4: '98.14%', 5: '98.78%'},
# Val Loss: 0.179313, Val Acc: 93.59%, Val-Class-Acc: {0: '89.82%', 1: '96.43%', 2: '97.58%', 3: '94.79%', 4: '92.99%', 5: '88.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.080319, Train-Class-Acc: {0: '97.67%', 1: '98.62%', 2: '98.69%', 3: '99.64%', 4: '98.51%', 5: '98.38%'},
# Val Loss: 0.179166, Val Acc: 93.42%, Val-Class-Acc: {0: '89.61%', 1: '96.24%', 2: '97.98%', 3: '95.53%', 4: '92.57%', 5: '87.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.079088, Train-Class-Acc: {0: '97.67%', 1: '98.18%', 2: '98.69%', 3: '99.72%', 4: '97.76%', 5: '98.38%'},
# Val Loss: 0.167115, Val Acc: 94.03%, Val-Class-Acc: {0: '92.46%', 1: '93.98%', 2: '95.36%', 3: '95.72%', 4: '92.99%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.076694, Train-Class-Acc: {0: '97.90%', 1: '98.33%', 2: '98.78%', 3: '99.72%', 4: '97.86%', 5: '98.48%'},
# Val Loss: 0.172976, Val Acc: 93.79%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '96.98%', 3: '95.34%', 4: '95.54%', 5: '87.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.076796, Train-Class-Acc: {0: '97.82%', 1: '97.67%', 2: '98.86%', 3: '99.57%', 4: '98.79%', 5: '98.48%'},
# Val Loss: 0.176308, Val Acc: 93.96%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 2: '97.78%', 3: '95.53%', 4: '94.27%', 5: '89.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.071798, Train-Class-Acc: {0: '97.59%', 1: '98.25%', 2: '99.43%', 3: '99.93%', 4: '98.04%', 5: '98.88%'},
# Val Loss: 0.167342, Val Acc: 94.16%, Val-Class-Acc: {0: '89.21%', 1: '96.62%', 2: '96.98%', 3: '95.72%', 4: '94.90%', 5: '90.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.071224, Train-Class-Acc: {0: '97.90%', 1: '98.11%', 2: '98.86%', 3: '100.00%', 4: '98.88%', 5: '98.58%'},
# Val Loss: 0.183429, Val Acc: 92.94%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '97.78%', 3: '94.41%', 4: '88.54%', 5: '90.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.068527, Train-Class-Acc: {0: '98.29%', 1: '98.76%', 2: '99.27%', 3: '99.72%', 4: '98.88%', 5: '98.78%'},
# Val Loss: 0.180493, Val Acc: 93.82%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '97.38%', 3: '94.97%', 4: '93.42%', 5: '89.52%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.067590, Train-Class-Acc: {0: '98.06%', 1: '98.47%', 2: '99.10%', 3: '99.79%', 4: '98.70%', 5: '99.19%'},
# Val Loss: 0.165021, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '96.24%', 2: '96.98%', 3: '95.72%', 4: '94.48%', 5: '90.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.066204, Train-Class-Acc: {0: '97.90%', 1: '98.40%', 2: '99.27%', 3: '100.00%', 4: '99.07%', 5: '98.48%'},
# Val Loss: 0.171060, Val Acc: 94.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '97.38%', 3: '95.16%', 4: '94.27%', 5: '90.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.066905, Train-Class-Acc: {0: '97.59%', 1: '98.69%', 2: '99.10%', 3: '99.93%', 4: '98.51%', 5: '99.09%'},
# Val Loss: 0.169974, Val Acc: 93.86%, Val-Class-Acc: {0: '89.61%', 1: '96.24%', 2: '97.58%', 3: '95.53%', 4: '93.84%', 5: '89.29%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.064688, Train-Class-Acc: {0: '98.37%', 1: '98.62%', 2: '99.02%', 3: '99.79%', 4: '98.88%', 5: '99.29%'},
# Val Loss: 0.164789, Val Acc: 93.99%, Val-Class-Acc: {0: '89.21%', 1: '96.24%', 2: '97.38%', 3: '95.90%', 4: '94.69%', 5: '89.52%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.060620, Train-Class-Acc: {0: '98.83%', 1: '98.91%', 2: '99.35%', 3: '99.72%', 4: '98.97%', 5: '99.09%'},
# Val Loss: 0.162062, Val Acc: 94.16%, Val-Class-Acc: {0: '90.43%', 1: '95.49%', 2: '97.38%', 3: '95.90%', 4: '94.90%', 5: '90.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.059881, Train-Class-Acc: {0: '97.90%', 1: '98.47%', 2: '99.76%', 3: '99.72%', 4: '99.44%', 5: '99.49%'},
# Val Loss: 0.163464, Val Acc: 94.03%, Val-Class-Acc: {0: '90.63%', 1: '95.68%', 2: '97.38%', 3: '95.90%', 4: '94.69%', 5: '88.81%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.059310, Train-Class-Acc: {0: '98.68%', 1: '98.76%', 2: '99.43%', 3: '99.93%', 4: '99.16%', 5: '98.99%'},
# Val Loss: 0.166917, Val Acc: 94.03%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '96.17%', 3: '95.90%', 4: '95.97%', 5: '88.81%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.057361, Train-Class-Acc: {0: '98.60%', 1: '98.91%', 2: '99.27%', 3: '99.72%', 4: '99.16%', 5: '99.19%'},
# Val Loss: 0.154282, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '95.49%', 2: '96.17%', 3: '95.90%', 4: '94.48%', 5: '92.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.057904, Train-Class-Acc: {0: '98.37%', 1: '98.69%', 2: '99.51%', 3: '99.86%', 4: '98.97%', 5: '99.39%'},
# Val Loss: 0.161736, Val Acc: 94.03%, Val-Class-Acc: {0: '90.43%', 1: '96.24%', 2: '97.38%', 3: '96.09%', 4: '95.33%', 5: '87.38%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.057924, Train-Class-Acc: {0: '98.60%', 1: '98.62%', 2: '99.51%', 3: '99.72%', 4: '99.07%', 5: '99.80%'},
# Val Loss: 0.161684, Val Acc: 94.23%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 2: '97.18%', 3: '96.09%', 4: '95.12%', 5: '89.52%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.058148, Train-Class-Acc: {0: '98.52%', 1: '98.62%', 2: '99.35%', 3: '99.86%', 4: '99.07%', 5: '99.09%'},
# Val Loss: 0.161875, Val Acc: 93.96%, Val-Class-Acc: {0: '89.82%', 1: '96.24%', 2: '97.78%', 3: '95.90%', 4: '90.66%', 5: '92.62%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.055112, Train-Class-Acc: {0: '98.76%', 1: '98.98%', 2: '99.43%', 3: '99.86%', 4: '99.16%', 5: '99.39%'},
# Val Loss: 0.167568, Val Acc: 94.10%, Val-Class-Acc: {0: '89.41%', 1: '96.62%', 2: '97.18%', 3: '94.97%', 4: '94.69%', 5: '90.95%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.055170, Train-Class-Acc: {0: '98.52%', 1: '98.69%', 2: '99.35%', 3: '99.93%', 4: '99.07%', 5: '98.78%'},
# Val Loss: 0.160393, Val Acc: 94.03%, Val-Class-Acc: {0: '89.82%', 1: '96.62%', 2: '97.38%', 3: '95.90%', 4: '93.42%', 5: '90.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.052895, Train-Class-Acc: {0: '98.68%', 1: '98.84%', 2: '99.67%', 3: '99.86%', 4: '98.97%', 5: '99.19%'},
# Val Loss: 0.158584, Val Acc: 94.40%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 2: '96.77%', 3: '95.72%', 4: '96.39%', 5: '90.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.051708, Train-Class-Acc: {0: '98.76%', 1: '98.98%', 2: '99.51%', 3: '99.86%', 4: '99.63%', 5: '99.29%'},
# Val Loss: 0.163676, Val Acc: 94.33%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '97.58%', 3: '95.53%', 4: '92.14%', 5: '93.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.052019, Train-Class-Acc: {0: '98.99%', 1: '98.76%', 2: '99.76%', 3: '99.79%', 4: '98.97%', 5: '99.09%'},
# Val Loss: 0.165136, Val Acc: 93.99%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '97.38%', 3: '95.72%', 4: '93.21%', 5: '90.24%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.051377, Train-Class-Acc: {0: '98.52%', 1: '98.76%', 2: '99.43%', 3: '99.86%', 4: '99.35%', 5: '99.70%'},
# Val Loss: 0.161859, Val Acc: 93.89%, Val-Class-Acc: {0: '89.82%', 1: '96.43%', 2: '97.38%', 3: '95.90%', 4: '91.30%', 5: '91.67%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.052737, Train-Class-Acc: {0: '98.29%', 1: '98.98%', 2: '99.35%', 3: '99.93%', 4: '99.35%', 5: '99.49%'},
# Val Loss: 0.167515, Val Acc: 94.06%, Val-Class-Acc: {0: '89.41%', 1: '96.99%', 2: '97.38%', 3: '95.34%', 4: '92.78%', 5: '91.67%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.049107, Train-Class-Acc: {0: '98.83%', 1: '99.27%', 2: '99.59%', 3: '99.86%', 4: '99.44%', 5: '99.19%'},
# Val Loss: 0.154792, Val Acc: 94.30%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 2: '97.38%', 3: '96.09%', 4: '92.99%', 5: '91.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.048774, Train-Class-Acc: {0: '98.99%', 1: '98.84%', 2: '99.67%', 3: '99.93%', 4: '99.53%', 5: '99.19%'},
# Val Loss: 0.158123, Val Acc: 94.23%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '97.38%', 3: '95.72%', 4: '94.06%', 5: '90.95%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.048207, Train-Class-Acc: {0: '98.68%', 1: '99.05%', 2: '99.76%', 3: '99.93%', 4: '99.25%', 5: '99.49%'},
# Val Loss: 0.156123, Val Acc: 94.47%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '97.38%', 3: '95.90%', 4: '94.90%', 5: '90.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.046799, Train-Class-Acc: {0: '98.91%', 1: '98.98%', 2: '99.76%', 3: '99.79%', 4: '99.72%', 5: '99.49%'},
# Val Loss: 0.168847, Val Acc: 94.23%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '97.18%', 3: '95.53%', 4: '95.33%', 5: '89.52%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.047523, Train-Class-Acc: {0: '99.22%', 1: '98.76%', 2: '99.76%', 3: '99.93%', 4: '99.16%', 5: '99.39%'},
# Val Loss: 0.161633, Val Acc: 94.10%, Val-Class-Acc: {0: '89.82%', 1: '96.43%', 2: '97.38%', 3: '95.72%', 4: '92.36%', 5: '92.14%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.046737, Train-Class-Acc: {0: '98.76%', 1: '98.84%', 2: '99.59%', 3: '100.00%', 4: '99.35%', 5: '99.59%'},
# Val Loss: 0.164736, Val Acc: 94.13%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 2: '97.38%', 3: '95.72%', 4: '92.14%', 5: '91.43%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.047280, Train-Class-Acc: {0: '98.60%', 1: '99.20%', 2: '99.84%', 3: '99.79%', 4: '99.44%', 5: '99.29%'},
# Val Loss: 0.157058, Val Acc: 94.30%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '97.38%', 3: '96.09%', 4: '93.21%', 5: '90.95%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.047197, Train-Class-Acc: {0: '99.22%', 1: '99.05%', 2: '99.43%', 3: '99.93%', 4: '99.72%', 5: '99.09%'},
# Val Loss: 0.159503, Val Acc: 94.23%, Val-Class-Acc: {0: '89.21%', 1: '97.37%', 2: '97.18%', 3: '95.90%', 4: '92.99%', 5: '91.90%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.045236, Train-Class-Acc: {0: '99.07%', 1: '98.98%', 2: '99.27%', 3: '99.93%', 4: '99.72%', 5: '99.59%'},
# Val Loss: 0.153471, Val Acc: 94.40%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 2: '97.38%', 3: '96.09%', 4: '92.99%', 5: '92.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.044828, Train-Class-Acc: {0: '98.99%', 1: '99.27%', 2: '99.59%', 3: '99.93%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.155227, Val Acc: 94.47%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '96.98%', 3: '95.72%', 4: '93.84%', 5: '92.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.045374, Train-Class-Acc: {0: '98.76%', 1: '99.13%', 2: '99.67%', 3: '99.93%', 4: '98.97%', 5: '99.19%'},
# Val Loss: 0.169274, Val Acc: 93.93%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '97.38%', 3: '95.90%', 4: '89.81%', 5: '93.33%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.044092, Train-Class-Acc: {0: '98.60%', 1: '99.13%', 2: '99.59%', 3: '99.79%', 4: '99.63%', 5: '99.59%'},
# Val Loss: 0.163107, Val Acc: 94.20%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '97.18%', 3: '96.09%', 4: '93.84%', 5: '90.71%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.043313, Train-Class-Acc: {0: '98.83%', 1: '98.91%', 2: '99.84%', 3: '100.00%', 4: '99.63%', 5: '99.80%'},
# Val Loss: 0.155514, Val Acc: 94.40%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '96.37%', 3: '95.90%', 4: '93.84%', 5: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_65.pth
# Epoch 66/1000, Train Loss: 0.043175, Train-Class-Acc: {0: '98.91%', 1: '99.20%', 2: '99.51%', 3: '100.00%', 4: '99.53%', 5: '99.29%'},
# Val Loss: 0.154795, Val Acc: 94.47%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '96.77%', 3: '96.09%', 4: '93.21%', 5: '92.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.041708, Train-Class-Acc: {0: '99.14%', 1: '99.49%', 2: '99.84%', 3: '100.00%', 4: '99.63%', 5: '99.59%'},
# Val Loss: 0.158340, Val Acc: 93.93%, Val-Class-Acc: {0: '91.04%', 1: '95.86%', 2: '98.19%', 3: '96.09%', 4: '91.30%', 5: '90.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.041620, Train-Class-Acc: {0: '99.07%', 1: '99.49%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.151757, Val Acc: 94.40%, Val-Class-Acc: {0: '91.04%', 1: '95.49%', 2: '97.58%', 3: '96.09%', 4: '92.57%', 5: '93.10%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.041887, Train-Class-Acc: {0: '99.07%', 1: '99.05%', 2: '99.67%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.161242, Val Acc: 93.96%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '98.19%', 3: '95.72%', 4: '90.87%', 5: '91.19%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.041961, Train-Class-Acc: {0: '99.22%', 1: '98.98%', 2: '99.43%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.154444, Val Acc: 94.13%, Val-Class-Acc: {0: '91.65%', 1: '94.92%', 2: '97.78%', 3: '95.90%', 4: '92.36%', 5: '91.43%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.039727, Train-Class-Acc: {0: '99.30%', 1: '99.34%', 2: '99.92%', 3: '99.86%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.158909, Val Acc: 94.50%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 2: '96.77%', 3: '95.72%', 4: '94.48%', 5: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_71.pth
# Epoch 72/1000, Train Loss: 0.040338, Train-Class-Acc: {0: '99.07%', 1: '98.91%', 2: '99.67%', 3: '99.93%', 4: '99.63%', 5: '99.80%'},
# Val Loss: 0.152339, Val Acc: 94.27%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '97.58%', 3: '96.09%', 4: '92.14%', 5: '91.90%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.039300, Train-Class-Acc: {0: '99.07%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '99.81%', 5: '99.49%'},
# Val Loss: 0.153700, Val Acc: 94.60%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '97.38%', 3: '95.90%', 4: '92.78%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_65.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_73.pth
# Epoch 74/1000, Train Loss: 0.038593, Train-Class-Acc: {0: '99.30%', 1: '99.49%', 2: '99.76%', 3: '99.86%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.170485, Val Acc: 93.89%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '98.99%', 3: '95.72%', 4: '90.23%', 5: '89.76%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.038043, Train-Class-Acc: {0: '99.30%', 1: '99.05%', 2: '99.59%', 3: '99.93%', 4: '99.53%', 5: '99.70%'},
# Val Loss: 0.166442, Val Acc: 93.65%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 2: '99.19%', 3: '96.09%', 4: '90.23%', 5: '88.10%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.039049, Train-Class-Acc: {0: '99.30%', 1: '99.27%', 2: '99.59%', 3: '100.00%', 4: '99.72%', 5: '99.59%'},
# Val Loss: 0.148110, Val Acc: 94.67%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '97.38%', 3: '96.09%', 4: '94.69%', 5: '91.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.037395, Train-Class-Acc: {0: '99.46%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '99.63%', 5: '99.80%'},
# Val Loss: 0.143704, Val Acc: 94.44%, Val-Class-Acc: {0: '91.45%', 1: '95.49%', 2: '97.38%', 3: '96.09%', 4: '93.84%', 5: '91.67%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.036657, Train-Class-Acc: {0: '99.22%', 1: '99.27%', 2: '99.92%', 3: '100.00%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.156860, Val Acc: 94.33%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '97.38%', 3: '95.72%', 4: '92.99%', 5: '92.14%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.036922, Train-Class-Acc: {0: '99.46%', 1: '99.05%', 2: '99.76%', 3: '99.86%', 4: '99.63%', 5: '99.80%'},
# Val Loss: 0.157121, Val Acc: 94.37%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '97.78%', 3: '96.09%', 4: '93.21%', 5: '90.95%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.036290, Train-Class-Acc: {0: '99.69%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.143279, Val Acc: 94.67%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '96.98%', 3: '96.09%', 4: '93.21%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_80.pth
# Epoch 81/1000, Train Loss: 0.037607, Train-Class-Acc: {0: '98.99%', 1: '99.27%', 2: '99.76%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.152453, Val Acc: 94.57%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '97.38%', 3: '96.09%', 4: '93.63%', 5: '91.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.036250, Train-Class-Acc: {0: '99.30%', 1: '99.49%', 2: '99.76%', 3: '99.93%', 4: '99.81%', 5: '99.49%'},
# Val Loss: 0.145576, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '95.49%', 2: '97.38%', 3: '96.09%', 4: '93.21%', 5: '92.62%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.036157, Train-Class-Acc: {0: '99.38%', 1: '99.27%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.49%'},
# Val Loss: 0.157286, Val Acc: 94.33%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '97.58%', 3: '96.09%', 4: '93.21%', 5: '91.19%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.036207, Train-Class-Acc: {0: '99.14%', 1: '99.42%', 2: '99.76%', 3: '99.93%', 4: '99.63%', 5: '99.80%'},
# Val Loss: 0.144917, Val Acc: 94.74%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '97.38%', 3: '96.09%', 4: '95.33%', 5: '91.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_71.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_84.pth
# Epoch 85/1000, Train Loss: 0.035935, Train-Class-Acc: {0: '98.91%', 1: '99.49%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.146360, Val Acc: 94.47%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 2: '97.38%', 3: '96.09%', 4: '92.78%', 5: '92.86%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.034850, Train-Class-Acc: {0: '99.38%', 1: '99.20%', 2: '99.84%', 3: '99.93%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.143458, Val Acc: 94.33%, Val-Class-Acc: {0: '91.85%', 1: '94.74%', 2: '97.38%', 3: '96.09%', 4: '92.57%', 5: '92.86%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.034732, Train-Class-Acc: {0: '99.07%', 1: '99.42%', 2: '99.76%', 3: '99.93%', 4: '99.81%', 5: '99.70%'},
# Val Loss: 0.140772, Val Acc: 94.47%, Val-Class-Acc: {0: '91.04%', 1: '95.86%', 2: '96.98%', 3: '96.09%', 4: '93.42%', 5: '92.86%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.034538, Train-Class-Acc: {0: '99.53%', 1: '99.05%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.70%'},
# Val Loss: 0.169411, Val Acc: 94.33%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '98.19%', 3: '95.72%', 4: '92.14%', 5: '93.33%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.033704, Train-Class-Acc: {0: '99.07%', 1: '99.49%', 2: '100.00%', 3: '100.00%', 4: '99.63%', 5: '99.90%'},
# Val Loss: 0.145250, Val Acc: 94.81%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '97.38%', 3: '96.09%', 4: '94.69%', 5: '92.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_89.pth
# Epoch 90/1000, Train Loss: 0.032641, Train-Class-Acc: {0: '99.14%', 1: '99.49%', 2: '99.76%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.165220, Val Acc: 94.27%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '98.39%', 3: '95.72%', 4: '92.57%', 5: '90.95%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.033483, Train-Class-Acc: {0: '99.53%', 1: '99.49%', 2: '99.84%', 3: '100.00%', 4: '99.63%', 5: '99.49%'},
# Val Loss: 0.169948, Val Acc: 93.96%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '98.19%', 3: '96.09%', 4: '90.66%', 5: '92.14%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.033862, Train-Class-Acc: {0: '99.14%', 1: '99.49%', 2: '100.00%', 3: '99.86%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.151126, Val Acc: 94.47%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '97.38%', 3: '96.09%', 4: '93.84%', 5: '91.43%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.033604, Train-Class-Acc: {0: '99.46%', 1: '99.42%', 2: '99.67%', 3: '100.00%', 4: '99.72%', 5: '99.59%'},
# Val Loss: 0.151849, Val Acc: 94.44%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '97.98%', 3: '96.09%', 4: '91.72%', 5: '92.86%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.033001, Train-Class-Acc: {0: '99.30%', 1: '99.56%', 2: '99.76%', 3: '99.93%', 4: '99.35%', 5: '99.80%'},
# Val Loss: 0.151262, Val Acc: 94.44%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '97.58%', 3: '96.09%', 4: '93.42%', 5: '91.19%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.032062, Train-Class-Acc: {0: '99.38%', 1: '99.64%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.158370, Val Acc: 94.44%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '97.58%', 3: '96.09%', 4: '93.21%', 5: '91.90%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.031385, Train-Class-Acc: {0: '99.22%', 1: '99.71%', 2: '99.84%', 3: '99.93%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.140988, Val Acc: 94.44%, Val-Class-Acc: {0: '91.04%', 1: '95.30%', 2: '97.98%', 3: '96.28%', 4: '93.42%', 5: '91.90%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.030717, Train-Class-Acc: {0: '99.46%', 1: '99.56%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.141765, Val Acc: 94.64%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '97.78%', 3: '96.09%', 4: '92.99%', 5: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_73.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_97.pth
# Epoch 98/1000, Train Loss: 0.031797, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%', 3: '99.93%', 4: '99.72%', 5: '99.59%'},
# Val Loss: 0.152966, Val Acc: 94.54%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '98.19%', 3: '96.09%', 4: '90.23%', 5: '94.76%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.030423, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '99.92%', 3: '99.86%', 4: '99.72%', 5: '99.70%'},
# Val Loss: 0.145199, Val Acc: 94.74%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '97.58%', 3: '96.09%', 4: '93.21%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_97.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_99.pth
# Epoch 100/1000, Train Loss: 0.031471, Train-Class-Acc: {0: '99.53%', 1: '99.20%', 2: '99.84%', 3: '99.93%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.156794, Val Acc: 94.44%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '97.58%', 3: '96.09%', 4: '93.84%', 5: '91.67%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.030083, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.163582, Val Acc: 94.30%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '98.79%', 3: '96.09%', 4: '90.23%', 5: '92.86%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.030317, Train-Class-Acc: {0: '99.46%', 1: '99.71%', 2: '99.92%', 3: '99.72%', 4: '99.81%', 5: '99.70%'},
# Val Loss: 0.142414, Val Acc: 94.77%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '98.19%', 3: '96.28%', 4: '92.78%', 5: '93.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_76.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_102.pth
# Epoch 103/1000, Train Loss: 0.029145, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.142538, Val Acc: 94.64%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '97.58%', 3: '96.09%', 4: '93.21%', 5: '92.62%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.030894, Train-Class-Acc: {0: '99.53%', 1: '99.64%', 2: '99.67%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.151063, Val Acc: 94.40%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '98.79%', 3: '96.09%', 4: '90.45%', 5: '93.10%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.029650, Train-Class-Acc: {0: '99.61%', 1: '99.42%', 2: '99.92%', 3: '99.86%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.147250, Val Acc: 94.54%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '97.98%', 3: '96.09%', 4: '91.30%', 5: '94.05%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.028637, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.155165, Val Acc: 94.50%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 2: '98.19%', 3: '96.09%', 4: '93.84%', 5: '90.71%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.028445, Train-Class-Acc: {0: '99.69%', 1: '99.34%', 2: '99.84%', 3: '99.93%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.147095, Val Acc: 94.74%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '98.59%', 3: '96.09%', 4: '92.14%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_80.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_107.pth
# Epoch 108/1000, Train Loss: 0.027988, Train-Class-Acc: {0: '99.38%', 1: '99.42%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.146688, Val Acc: 94.50%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 2: '98.79%', 3: '96.09%', 4: '90.87%', 5: '93.33%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.029285, Train-Class-Acc: {0: '99.38%', 1: '99.64%', 2: '99.76%', 3: '99.93%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.150707, Val Acc: 94.37%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '98.59%', 3: '96.09%', 4: '93.63%', 5: '90.24%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.027769, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '99.84%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.150713, Val Acc: 94.60%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '98.79%', 3: '96.28%', 4: '90.02%', 5: '94.05%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.029689, Train-Class-Acc: {0: '99.53%', 1: '99.42%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.154662, Val Acc: 94.50%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '97.78%', 3: '96.09%', 4: '92.57%', 5: '92.86%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.028343, Train-Class-Acc: {0: '99.30%', 1: '99.71%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.162277, Val Acc: 94.06%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '99.40%', 3: '96.28%', 4: '90.02%', 5: '90.24%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.028321, Train-Class-Acc: {0: '99.46%', 1: '99.71%', 2: '99.92%', 3: '99.93%', 4: '99.72%', 5: '99.90%'},
# Val Loss: 0.150824, Val Acc: 94.57%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '97.58%', 3: '96.09%', 4: '93.42%', 5: '92.86%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.026960, Train-Class-Acc: {0: '99.46%', 1: '99.85%', 2: '99.76%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.147350, Val Acc: 94.47%, Val-Class-Acc: {0: '91.65%', 1: '95.30%', 2: '98.59%', 3: '96.09%', 4: '92.14%', 5: '92.38%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.027330, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.59%'},
# Val Loss: 0.148406, Val Acc: 94.84%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '97.78%', 3: '96.09%', 4: '92.78%', 5: '94.52%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_84.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_115.pth
# Epoch 116/1000, Train Loss: 0.028916, Train-Class-Acc: {0: '99.14%', 1: '99.64%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.152276, Val Acc: 94.77%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '97.78%', 3: '96.09%', 4: '92.99%', 5: '94.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_99.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_116.pth
# Epoch 117/1000, Train Loss: 0.027552, Train-Class-Acc: {0: '99.46%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.138457, Val Acc: 94.88%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '98.39%', 3: '96.28%', 4: '93.21%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_107.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_117.pth
# Epoch 118/1000, Train Loss: 0.027490, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '99.92%', 3: '99.86%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.147181, Val Acc: 94.81%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '98.79%', 3: '96.09%', 4: '93.42%', 5: '91.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_102.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_118.pth
# Epoch 119/1000, Train Loss: 0.026169, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%', 3: '99.86%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.149779, Val Acc: 94.71%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '98.39%', 3: '96.09%', 4: '91.51%', 5: '93.81%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.026606, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.143070, Val Acc: 94.71%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '97.78%', 3: '96.09%', 4: '93.21%', 5: '93.33%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.027609, Train-Class-Acc: {0: '99.46%', 1: '99.42%', 2: '99.76%', 3: '99.86%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.168172, Val Acc: 94.03%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '98.19%', 3: '96.09%', 4: '91.51%', 5: '93.57%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.026726, Train-Class-Acc: {0: '99.69%', 1: '99.49%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.141081, Val Acc: 94.60%, Val-Class-Acc: {0: '91.45%', 1: '95.86%', 2: '98.19%', 3: '96.28%', 4: '93.42%', 5: '91.67%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.025895, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.155594, Val Acc: 94.71%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 2: '98.59%', 3: '96.09%', 4: '92.99%', 5: '92.62%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.025983, Train-Class-Acc: {0: '99.61%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '99.72%', 5: '100.00%'},
# Val Loss: 0.142662, Val Acc: 95.08%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '97.78%', 3: '96.09%', 4: '95.75%', 5: '92.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_116.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_124.pth
# Epoch 125/1000, Train Loss: 0.026567, Train-Class-Acc: {0: '99.53%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.147888, Val Acc: 94.60%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '98.39%', 3: '96.09%', 4: '91.72%', 5: '93.10%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.026604, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '99.67%', 3: '99.93%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.132399, Val Acc: 94.60%, Val-Class-Acc: {0: '92.46%', 1: '93.98%', 2: '97.18%', 3: '96.46%', 4: '92.99%', 5: '94.29%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.026875, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '99.86%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.147754, Val Acc: 94.71%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '98.19%', 3: '96.09%', 4: '92.99%', 5: '92.14%'}, LR: 0.000100
# ...
# Epoch 954/1000, Train Loss: 0.011207, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.92%', 3: '99.86%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.150547, Val Acc: 95.72%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '98.79%', 3: '99.63%', 4: '94.48%', 5: '92.62%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.009606, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.146621, Val Acc: 95.83%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 2: '98.99%', 3: '99.44%', 4: '94.06%', 5: '93.33%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.011418, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.156395, Val Acc: 95.55%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 2: '98.19%', 3: '99.63%', 4: '96.60%', 5: '91.43%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.009898, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.151744, Val Acc: 95.55%, Val-Class-Acc: {0: '91.45%', 1: '96.80%', 2: '98.99%', 3: '99.44%', 4: '93.84%', 5: '91.67%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.009631, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.143686, Val Acc: 95.96%, Val-Class-Acc: {0: '91.24%', 1: '97.18%', 2: '98.59%', 3: '99.44%', 4: '94.90%', 5: '93.57%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.009680, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.173023, Val Acc: 95.22%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '99.40%', 3: '99.44%', 4: '94.06%', 5: '90.71%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.009389, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.142385, Val Acc: 95.69%, Val-Class-Acc: {0: '91.65%', 1: '96.24%', 2: '98.59%', 3: '99.63%', 4: '94.69%', 5: '92.38%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.009491, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.145044, Val Acc: 95.55%, Val-Class-Acc: {0: '92.87%', 1: '95.11%', 2: '98.79%', 3: '99.63%', 4: '94.69%', 5: '91.19%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.010247, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.146991, Val Acc: 95.76%, Val-Class-Acc: {0: '91.65%', 1: '96.80%', 2: '98.79%', 3: '99.44%', 4: '94.27%', 5: '92.62%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.009302, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.150293, Val Acc: 95.69%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '98.79%', 3: '99.44%', 4: '94.27%', 5: '93.10%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.009943, Train-Class-Acc: {0: '99.69%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.152228, Val Acc: 95.62%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '98.79%', 3: '99.44%', 4: '94.90%', 5: '91.90%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.009508, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.152050, Val Acc: 95.66%, Val-Class-Acc: {0: '91.85%', 1: '96.62%', 2: '98.59%', 3: '99.07%', 4: '94.69%', 5: '92.14%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.010345, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.145190, Val Acc: 95.76%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '98.59%', 3: '99.44%', 4: '94.06%', 5: '94.29%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.009865, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.164095, Val Acc: 95.25%, Val-Class-Acc: {0: '91.65%', 1: '95.49%', 2: '99.60%', 3: '99.63%', 4: '93.42%', 5: '90.48%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.008549, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.167207, Val Acc: 95.32%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '99.19%', 3: '99.26%', 4: '92.99%', 5: '91.90%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.010528, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.142777, Val Acc: 95.83%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '98.19%', 3: '99.44%', 4: '95.33%', 5: '93.33%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.010395, Train-Class-Acc: {0: '99.69%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.145891, Val Acc: 95.89%, Val-Class-Acc: {0: '91.65%', 1: '96.43%', 2: '98.39%', 3: '99.63%', 4: '97.03%', 5: '91.19%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.009556, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.147323, Val Acc: 95.83%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '98.19%', 3: '99.44%', 4: '95.97%', 5: '92.86%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.009864, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.146425, Val Acc: 95.66%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '98.99%', 3: '99.44%', 4: '93.63%', 5: '93.33%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.009721, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.137557, Val Acc: 95.79%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 2: '98.19%', 3: '99.81%', 4: '93.84%', 5: '94.52%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.009983, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.139103, Val Acc: 95.72%, Val-Class-Acc: {0: '91.85%', 1: '95.49%', 2: '98.59%', 3: '99.44%', 4: '94.27%', 5: '94.05%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.010160, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.145853, Val Acc: 95.69%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '98.59%', 3: '99.63%', 4: '95.12%', 5: '91.90%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.010426, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.92%', 3: '99.86%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.150288, Val Acc: 95.55%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '98.79%', 3: '99.44%', 4: '94.27%', 5: '91.67%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.009637, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.146727, Val Acc: 95.55%, Val-Class-Acc: {0: '91.65%', 1: '96.05%', 2: '98.99%', 3: '99.81%', 4: '93.63%', 5: '92.14%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.009538, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.86%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.141426, Val Acc: 96.00%, Val-Class-Acc: {0: '91.24%', 1: '96.80%', 2: '98.19%', 3: '99.81%', 4: '95.75%', 5: '93.33%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.009778, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.155989, Val Acc: 95.72%, Val-Class-Acc: {0: '91.24%', 1: '97.37%', 2: '98.79%', 3: '99.44%', 4: '94.90%', 5: '91.43%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.011155, Train-Class-Acc: {0: '99.61%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.72%', 5: '100.00%'},
# Val Loss: 0.159147, Val Acc: 95.39%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '98.99%', 3: '99.44%', 4: '92.99%', 5: '92.86%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.010312, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.158061, Val Acc: 95.59%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '98.79%', 3: '99.63%', 4: '94.69%', 5: '91.43%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.010456, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.181902, Val Acc: 94.98%, Val-Class-Acc: {0: '87.37%', 1: '98.50%', 2: '99.40%', 3: '99.44%', 4: '93.21%', 5: '90.48%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.010021, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.138029, Val Acc: 95.86%, Val-Class-Acc: {0: '91.65%', 1: '96.24%', 2: '98.39%', 3: '99.63%', 4: '95.12%', 5: '93.33%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.010050, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.151025, Val Acc: 95.76%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '98.59%', 3: '99.26%', 4: '94.06%', 5: '94.05%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.009927, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.131950, Val Acc: 95.83%, Val-Class-Acc: {0: '91.85%', 1: '95.30%', 2: '98.19%', 3: '99.81%', 4: '95.33%', 5: '93.81%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.010267, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.134836, Val Acc: 95.79%, Val-Class-Acc: {0: '91.85%', 1: '96.05%', 2: '98.59%', 3: '99.63%', 4: '94.06%', 5: '93.81%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.009437, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.154751, Val Acc: 95.62%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '98.59%', 3: '99.44%', 4: '94.90%', 5: '92.14%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.009941, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.134931, Val Acc: 95.79%, Val-Class-Acc: {0: '91.65%', 1: '95.86%', 2: '98.59%', 3: '99.81%', 4: '94.06%', 5: '94.05%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.009687, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.144324, Val Acc: 95.69%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '98.79%', 3: '99.63%', 4: '94.06%', 5: '93.33%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.009051, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.156708, Val Acc: 95.62%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 2: '98.19%', 3: '99.63%', 4: '96.39%', 5: '91.19%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.009481, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.149804, Val Acc: 95.83%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 2: '98.59%', 3: '99.63%', 4: '94.90%', 5: '92.62%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.010049, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.159302, Val Acc: 95.49%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '98.59%', 3: '99.26%', 4: '94.90%', 5: '91.43%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.010251, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.155269, Val Acc: 95.62%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '98.79%', 3: '99.63%', 4: '94.69%', 5: '91.43%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.009859, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.149681, Val Acc: 95.76%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '98.99%', 3: '99.81%', 4: '94.06%', 5: '93.10%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.010348, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.141342, Val Acc: 95.79%, Val-Class-Acc: {0: '91.85%', 1: '95.86%', 2: '98.59%', 3: '99.63%', 4: '95.33%', 5: '92.62%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.009783, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.147416, Val Acc: 95.72%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '98.19%', 3: '99.63%', 4: '96.60%', 5: '91.19%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.010500, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '99.86%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.142251, Val Acc: 95.69%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '98.99%', 3: '99.81%', 4: '93.21%', 5: '93.33%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.010150, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.136901, Val Acc: 95.72%, Val-Class-Acc: {0: '91.45%', 1: '95.49%', 2: '98.79%', 3: '99.81%', 4: '94.06%', 5: '94.05%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.009405, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.154922, Val Acc: 95.45%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '98.39%', 3: '99.44%', 4: '94.90%', 5: '91.67%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.010735, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.148199, Val Acc: 95.66%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 2: '98.59%', 3: '99.63%', 4: '94.48%', 5: '92.86%'}, LR: 0.000100
#
# ⏳ Total training time: 272.42 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_best.pth (Val Accuracy: 96.27%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 841, Train Loss: 0.010832, Train-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.142553, Val Acc: 96.27%, Val-Acc: {0: '90.63%', 1: '97.56%', 2: '97.18%', 3: '99.81%', 4: '98.30%', 5: '93.33%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_841.pth
# Epoch 878, Train Loss: 0.009274, Train-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.137218, Val Acc: 96.17%, Val-Acc: {0: '91.24%', 1: '97.18%', 2: '97.98%', 3: '99.81%', 4: '96.60%', 5: '93.33%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_878.pth
# Epoch 842, Train Loss: 0.010768, Train-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.139538, Val Acc: 96.17%, Val-Acc: {0: '91.24%', 1: '96.99%', 2: '97.98%', 3: '99.63%', 4: '96.60%', 5: '93.81%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_842.pth
# Epoch 951, Train Loss: 0.009697, Train-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.132425, Val Acc: 96.06%, Val-Acc: {0: '92.06%', 1: '95.86%', 2: '98.19%', 3: '99.81%', 4: '95.97%', 5: '93.81%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_951.pth
# Epoch 940, Train Loss: 0.009456, Train-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.137423, Val Acc: 96.03%, Val-Acc: {0: '91.65%', 1: '96.62%', 2: '98.59%', 3: '99.63%', 4: '96.39%', 5: '92.38%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4/HAR_MLP_epoch_940.pth
# ---
# ### Period 4
# + ##### Model: HAR_MLP_v1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v1/Period_4'*
# + ##### Best Epoch: 841
# #### __Val Accuracy: 96.27%__
# #### __Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '97.18%', 3: '99.81%', 4: '98.30%', 5: '93.33%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v1(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=6, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ## __HAR_MLP_v2 Training__

# %% [markdown]
# ---
# ### Period 1
# + ##### Total training time: 86.52 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1'*
# + ##### Best Epoch: 351
# #### __Val Accuracy: 95.21%__
# #### __Val-Class-Acc: {0: '92.87%', 1: '97.37%'}__

# %%
# ================================
# 📌 Period 1 Configuration
# ================================
period = 1

# Load processed dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]   # use test set for validation

# Auto-select the best CUDA device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 0.0  # EWC disabled for Period 1
ewc_state     = None

# Model saving path
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_1")
os.makedirs(model_saving_folder, exist_ok=True)

# Initialize model, criterion, optimizer
model     = HAR_MLP_v2(input_size=input_size, hidden_size=hidden_size, output_size=output_size, dropout=dropout).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train the model
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================

# Unique class summary
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Clean up memory to prepare for next period
del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 37218 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
# Epoch 1/1000, Train Loss: 0.779738, Train-Class-Acc: {0: '32.35%', 1: '85.37%'},
# Val Loss: 0.823068, Val Acc: 55.52%, Val-Class-Acc: {0: '7.54%', 1: '99.81%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.549599, Train-Class-Acc: {0: '56.45%', 1: '87.92%'},
# Val Loss: 0.473766, Val Acc: 75.27%, Val-Class-Acc: {0: '55.60%', 1: '93.42%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.443803, Train-Class-Acc: {0: '69.60%', 1: '88.14%'},
# Val Loss: 0.366771, Val Acc: 84.46%, Val-Class-Acc: {0: '78.82%', 1: '89.66%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.372504, Train-Class-Acc: {0: '77.45%', 1: '88.50%'},
# Val Loss: 0.325826, Val Acc: 85.92%, Val-Class-Acc: {0: '78.82%', 1: '92.48%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.329409, Train-Class-Acc: {0: '81.57%', 1: '89.08%'},
# Val Loss: 0.292739, Val Acc: 88.27%, Val-Class-Acc: {0: '84.93%', 1: '91.35%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.286960, Train-Class-Acc: {0: '85.85%', 1: '90.54%'},
# Val Loss: 0.284181, Val Acc: 89.54%, Val-Class-Acc: {0: '94.70%', 1: '84.77%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.269580, Train-Class-Acc: {0: '86.39%', 1: '91.19%'},
# Val Loss: 0.267311, Val Acc: 89.35%, Val-Class-Acc: {0: '83.91%', 1: '94.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.254925, Train-Class-Acc: {0: '88.80%', 1: '91.27%'},
# Val Loss: 0.251849, Val Acc: 89.74%, Val-Class-Acc: {0: '85.95%', 1: '93.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.224390, Train-Class-Acc: {0: '89.97%', 1: '91.56%'},
# Val Loss: 0.247805, Val Acc: 90.62%, Val-Class-Acc: {0: '95.52%', 1: '86.09%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.211235, Train-Class-Acc: {0: '90.75%', 1: '92.21%'},
# Val Loss: 0.220453, Val Acc: 91.40%, Val-Class-Acc: {0: '89.41%', 1: '93.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.194505, Train-Class-Acc: {0: '91.37%', 1: '93.16%'},
# Val Loss: 0.216585, Val Acc: 90.81%, Val-Class-Acc: {0: '88.19%', 1: '93.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.180034, Train-Class-Acc: {0: '92.22%', 1: '94.10%'},
# Val Loss: 0.205453, Val Acc: 92.38%, Val-Class-Acc: {0: '92.06%', 1: '92.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.163325, Train-Class-Acc: {0: '92.77%', 1: '94.91%'},
# Val Loss: 0.210042, Val Acc: 91.69%, Val-Class-Acc: {0: '87.37%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.154402, Train-Class-Acc: {0: '94.40%', 1: '94.69%'},
# Val Loss: 0.208836, Val Acc: 91.98%, Val-Class-Acc: {0: '87.58%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.145076, Train-Class-Acc: {0: '94.71%', 1: '94.10%'},
# Val Loss: 0.221502, Val Acc: 91.50%, Val-Class-Acc: {0: '85.74%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.135393, Train-Class-Acc: {0: '94.87%', 1: '94.91%'},
# Val Loss: 0.188266, Val Acc: 92.67%, Val-Class-Acc: {0: '93.08%', 1: '92.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.134444, Train-Class-Acc: {0: '94.79%', 1: '95.49%'},
# Val Loss: 0.206807, Val Acc: 92.38%, Val-Class-Acc: {0: '88.59%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.126743, Train-Class-Acc: {0: '95.72%', 1: '95.12%'},
# Val Loss: 0.187162, Val Acc: 92.86%, Val-Class-Acc: {0: '90.63%', 1: '94.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.118055, Train-Class-Acc: {0: '95.72%', 1: '95.78%'},
# Val Loss: 0.229695, Val Acc: 91.50%, Val-Class-Acc: {0: '84.93%', 1: '97.56%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.115121, Train-Class-Acc: {0: '95.72%', 1: '96.29%'},
# Val Loss: 0.204718, Val Acc: 92.57%, Val-Class-Acc: {0: '87.78%', 1: '96.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.101687, Train-Class-Acc: {0: '96.19%', 1: '96.51%'},
# Val Loss: 0.240918, Val Acc: 91.50%, Val-Class-Acc: {0: '83.91%', 1: '98.50%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.103384, Train-Class-Acc: {0: '95.96%', 1: '96.14%'},
# Val Loss: 0.182862, Val Acc: 93.16%, Val-Class-Acc: {0: '94.50%', 1: '91.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.101181, Train-Class-Acc: {0: '96.50%', 1: '97.09%'},
# Val Loss: 0.221446, Val Acc: 91.89%, Val-Class-Acc: {0: '86.15%', 1: '97.18%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.095391, Train-Class-Acc: {0: '96.58%', 1: '96.51%'},
# Val Loss: 0.197554, Val Acc: 93.06%, Val-Class-Acc: {0: '95.52%', 1: '90.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.094366, Train-Class-Acc: {0: '97.12%', 1: '96.36%'},
# Val Loss: 0.283062, Val Acc: 89.74%, Val-Class-Acc: {0: '79.43%', 1: '99.25%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.083717, Train-Class-Acc: {0: '97.43%', 1: '97.53%'},
# Val Loss: 0.278710, Val Acc: 90.03%, Val-Class-Acc: {0: '80.04%', 1: '99.25%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.075888, Train-Class-Acc: {0: '97.74%', 1: '97.38%'},
# Val Loss: 0.184024, Val Acc: 93.45%, Val-Class-Acc: {0: '90.22%', 1: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.077802, Train-Class-Acc: {0: '98.13%', 1: '97.23%'},
# Val Loss: 0.246401, Val Acc: 91.10%, Val-Class-Acc: {0: '82.89%', 1: '98.68%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.073525, Train-Class-Acc: {0: '97.82%', 1: '97.74%'},
# Val Loss: 0.183788, Val Acc: 93.74%, Val-Class-Acc: {0: '91.24%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.074410, Train-Class-Acc: {0: '97.74%', 1: '98.33%'},
# Val Loss: 0.179212, Val Acc: 93.94%, Val-Class-Acc: {0: '92.46%', 1: '95.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.067940, Train-Class-Acc: {0: '97.67%', 1: '97.53%'},
# Val Loss: 0.189486, Val Acc: 94.04%, Val-Class-Acc: {0: '91.65%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.063287, Train-Class-Acc: {0: '98.06%', 1: '98.11%'},
# Val Loss: 0.202320, Val Acc: 93.06%, Val-Class-Acc: {0: '87.98%', 1: '97.74%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.064167, Train-Class-Acc: {0: '98.06%', 1: '97.82%'},
# Val Loss: 0.196317, Val Acc: 93.45%, Val-Class-Acc: {0: '88.59%', 1: '97.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.059501, Train-Class-Acc: {0: '98.13%', 1: '98.25%'},
# Val Loss: 0.173612, Val Acc: 94.13%, Val-Class-Acc: {0: '92.87%', 1: '95.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.058401, Train-Class-Acc: {0: '98.52%', 1: '97.74%'},
# Val Loss: 0.181921, Val Acc: 94.13%, Val-Class-Acc: {0: '94.09%', 1: '94.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.054685, Train-Class-Acc: {0: '98.68%', 1: '98.62%'},
# Val Loss: 0.222515, Val Acc: 92.38%, Val-Class-Acc: {0: '86.15%', 1: '98.12%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.061555, Train-Class-Acc: {0: '98.37%', 1: '97.74%'},
# Val Loss: 0.198241, Val Acc: 93.16%, Val-Class-Acc: {0: '88.80%', 1: '97.18%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.049079, Train-Class-Acc: {0: '98.83%', 1: '98.54%'},
# Val Loss: 0.189360, Val Acc: 93.45%, Val-Class-Acc: {0: '94.30%', 1: '92.67%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.051225, Train-Class-Acc: {0: '98.83%', 1: '98.40%'},
# Val Loss: 0.250195, Val Acc: 92.18%, Val-Class-Acc: {0: '84.73%', 1: '99.06%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.047885, Train-Class-Acc: {0: '98.76%', 1: '98.47%'},
# Val Loss: 0.185653, Val Acc: 94.04%, Val-Class-Acc: {0: '91.24%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.053404, Train-Class-Acc: {0: '98.44%', 1: '97.96%'},
# Val Loss: 0.210212, Val Acc: 93.26%, Val-Class-Acc: {0: '88.59%', 1: '97.56%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.043115, Train-Class-Acc: {0: '98.99%', 1: '98.33%'},
# Val Loss: 0.260909, Val Acc: 92.28%, Val-Class-Acc: {0: '84.73%', 1: '99.25%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.041888, Train-Class-Acc: {0: '99.22%', 1: '98.76%'},
# Val Loss: 0.180743, Val Acc: 93.65%, Val-Class-Acc: {0: '94.50%', 1: '92.86%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.043251, Train-Class-Acc: {0: '98.83%', 1: '99.13%'},
# Val Loss: 0.186500, Val Acc: 93.94%, Val-Class-Acc: {0: '91.24%', 1: '96.43%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.041818, Train-Class-Acc: {0: '98.68%', 1: '98.47%'},
# Val Loss: 0.185158, Val Acc: 94.13%, Val-Class-Acc: {0: '92.46%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.043344, Train-Class-Acc: {0: '98.44%', 1: '98.98%'},
# Val Loss: 0.232831, Val Acc: 91.98%, Val-Class-Acc: {0: '96.33%', 1: '87.97%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.038799, Train-Class-Acc: {0: '99.22%', 1: '98.69%'},
# Val Loss: 0.214140, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.035433, Train-Class-Acc: {0: '99.14%', 1: '98.98%'},
# Val Loss: 0.200549, Val Acc: 93.84%, Val-Class-Acc: {0: '90.02%', 1: '97.37%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.033443, Train-Class-Acc: {0: '99.22%', 1: '99.05%'},
# Val Loss: 0.217414, Val Acc: 93.65%, Val-Class-Acc: {0: '88.39%', 1: '98.50%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.034826, Train-Class-Acc: {0: '98.91%', 1: '98.91%'},
# Val Loss: 0.180862, Val Acc: 94.43%, Val-Class-Acc: {0: '92.87%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_50.pth
# Epoch 51/1000, Train Loss: 0.035485, Train-Class-Acc: {0: '98.99%', 1: '98.91%'},
# Val Loss: 0.187311, Val Acc: 94.13%, Val-Class-Acc: {0: '92.87%', 1: '95.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.032290, Train-Class-Acc: {0: '99.14%', 1: '98.98%'},
# Val Loss: 0.279198, Val Acc: 92.18%, Val-Class-Acc: {0: '84.52%', 1: '99.25%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.033681, Train-Class-Acc: {0: '99.22%', 1: '98.69%'},
# Val Loss: 0.209846, Val Acc: 93.74%, Val-Class-Acc: {0: '89.41%', 1: '97.74%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.029760, Train-Class-Acc: {0: '99.30%', 1: '99.13%'},
# Val Loss: 0.189202, Val Acc: 93.74%, Val-Class-Acc: {0: '94.70%', 1: '92.86%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.028093, Train-Class-Acc: {0: '98.99%', 1: '99.42%'},
# Val Loss: 0.185553, Val Acc: 93.84%, Val-Class-Acc: {0: '92.87%', 1: '94.74%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.027084, Train-Class-Acc: {0: '99.07%', 1: '99.34%'},
# Val Loss: 0.569438, Val Acc: 84.65%, Val-Class-Acc: {0: '68.43%', 1: '99.62%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.036855, Train-Class-Acc: {0: '99.22%', 1: '98.91%'},
# Val Loss: 0.300831, Val Acc: 91.98%, Val-Class-Acc: {0: '84.11%', 1: '99.25%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.030397, Train-Class-Acc: {0: '99.14%', 1: '98.98%'},
# Val Loss: 0.221125, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.028379, Train-Class-Acc: {0: '99.38%', 1: '99.34%'},
# Val Loss: 0.201974, Val Acc: 92.57%, Val-Class-Acc: {0: '95.32%', 1: '90.04%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.026153, Train-Class-Acc: {0: '99.22%', 1: '99.42%'},
# Val Loss: 0.224231, Val Acc: 93.94%, Val-Class-Acc: {0: '88.80%', 1: '98.68%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.025082, Train-Class-Acc: {0: '99.38%', 1: '99.42%'},
# Val Loss: 0.189147, Val Acc: 94.13%, Val-Class-Acc: {0: '93.28%', 1: '94.92%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.023526, Train-Class-Acc: {0: '99.61%', 1: '99.27%'},
# Val Loss: 0.406106, Val Acc: 88.86%, Val-Class-Acc: {0: '77.19%', 1: '99.62%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.022410, Train-Class-Acc: {0: '99.46%', 1: '99.56%'},
# Val Loss: 0.215753, Val Acc: 93.84%, Val-Class-Acc: {0: '90.22%', 1: '97.18%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.023851, Train-Class-Acc: {0: '99.69%', 1: '98.98%'},
# Val Loss: 0.261775, Val Acc: 93.35%, Val-Class-Acc: {0: '86.97%', 1: '99.25%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.020499, Train-Class-Acc: {0: '99.46%', 1: '99.78%'},
# Val Loss: 0.183306, Val Acc: 94.62%, Val-Class-Acc: {0: '93.48%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_65.pth
# Epoch 66/1000, Train Loss: 0.022776, Train-Class-Acc: {0: '99.69%', 1: '99.42%'},
# Val Loss: 0.210006, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.021508, Train-Class-Acc: {0: '99.14%', 1: '99.42%'},
# Val Loss: 0.495793, Val Acc: 87.59%, Val-Class-Acc: {0: '74.34%', 1: '99.81%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.022084, Train-Class-Acc: {0: '99.46%', 1: '99.34%'},
# Val Loss: 0.195767, Val Acc: 94.53%, Val-Class-Acc: {0: '93.28%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_68.pth
# Epoch 69/1000, Train Loss: 0.023671, Train-Class-Acc: {0: '99.14%', 1: '99.56%'},
# Val Loss: 0.206994, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_69.pth
# Epoch 70/1000, Train Loss: 0.022562, Train-Class-Acc: {0: '99.69%', 1: '99.20%'},
# Val Loss: 0.326187, Val Acc: 91.59%, Val-Class-Acc: {0: '83.10%', 1: '99.44%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.017638, Train-Class-Acc: {0: '99.61%', 1: '99.56%'},
# Val Loss: 0.315872, Val Acc: 91.98%, Val-Class-Acc: {0: '83.91%', 1: '99.44%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.017121, Train-Class-Acc: {0: '99.69%', 1: '99.64%'},
# Val Loss: 0.182740, Val Acc: 94.53%, Val-Class-Acc: {0: '94.09%', 1: '94.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_69.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.016743, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.794039, Val Acc: 81.52%, Val-Class-Acc: {0: '61.71%', 1: '99.81%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.022026, Train-Class-Acc: {0: '99.69%', 1: '99.27%'},
# Val Loss: 0.397750, Val Acc: 89.74%, Val-Class-Acc: {0: '79.23%', 1: '99.44%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.015140, Train-Class-Acc: {0: '99.46%', 1: '99.93%'},
# Val Loss: 0.212329, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.017154, Train-Class-Acc: {0: '99.84%', 1: '99.42%'},
# Val Loss: 0.320291, Val Acc: 92.08%, Val-Class-Acc: {0: '83.91%', 1: '99.62%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.018783, Train-Class-Acc: {0: '99.61%', 1: '99.56%'},
# Val Loss: 0.376505, Val Acc: 90.71%, Val-Class-Acc: {0: '81.06%', 1: '99.62%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.015906, Train-Class-Acc: {0: '99.53%', 1: '99.56%'},
# Val Loss: 0.250564, Val Acc: 94.04%, Val-Class-Acc: {0: '88.39%', 1: '99.25%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.015918, Train-Class-Acc: {0: '99.38%', 1: '99.71%'},
# Val Loss: 0.286789, Val Acc: 93.16%, Val-Class-Acc: {0: '86.35%', 1: '99.44%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.012983, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.213581, Val Acc: 94.33%, Val-Class-Acc: {0: '91.45%', 1: '96.99%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.016896, Train-Class-Acc: {0: '99.77%', 1: '99.56%'},
# Val Loss: 0.220995, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.018398, Train-Class-Acc: {0: '99.22%', 1: '99.56%'},
# Val Loss: 0.239366, Val Acc: 94.53%, Val-Class-Acc: {0: '90.22%', 1: '98.50%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_50.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_82.pth
# Epoch 83/1000, Train Loss: 0.012240, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.214027, Val Acc: 94.72%, Val-Class-Acc: {0: '91.85%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_68.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.017712, Train-Class-Acc: {0: '99.92%', 1: '99.13%'},
# Val Loss: 0.205434, Val Acc: 93.84%, Val-Class-Acc: {0: '94.70%', 1: '93.05%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.015610, Train-Class-Acc: {0: '99.77%', 1: '99.27%'},
# Val Loss: 0.259330, Val Acc: 93.84%, Val-Class-Acc: {0: '88.80%', 1: '98.50%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.012299, Train-Class-Acc: {0: '99.69%', 1: '99.71%'},
# Val Loss: 0.233850, Val Acc: 94.23%, Val-Class-Acc: {0: '90.43%', 1: '97.74%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.015713, Train-Class-Acc: {0: '99.61%', 1: '99.56%'},
# Val Loss: 0.289743, Val Acc: 92.96%, Val-Class-Acc: {0: '86.15%', 1: '99.25%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.016234, Train-Class-Acc: {0: '99.61%', 1: '99.56%'},
# Val Loss: 0.274682, Val Acc: 93.45%, Val-Class-Acc: {0: '87.58%', 1: '98.87%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.018873, Train-Class-Acc: {0: '99.46%', 1: '99.56%'},
# Val Loss: 0.313514, Val Acc: 92.57%, Val-Class-Acc: {0: '84.93%', 1: '99.62%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.013243, Train-Class-Acc: {0: '99.69%', 1: '99.78%'},
# Val Loss: 0.246927, Val Acc: 94.04%, Val-Class-Acc: {0: '90.02%', 1: '97.74%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.011412, Train-Class-Acc: {0: '99.77%', 1: '99.71%'},
# Val Loss: 0.254205, Val Acc: 94.33%, Val-Class-Acc: {0: '89.41%', 1: '98.87%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.012560, Train-Class-Acc: {0: '99.53%', 1: '99.71%'},
# Val Loss: 0.199437, Val Acc: 94.04%, Val-Class-Acc: {0: '91.24%', 1: '96.62%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.010970, Train-Class-Acc: {0: '99.69%', 1: '99.78%'},
# Val Loss: 0.449266, Val Acc: 89.64%, Val-Class-Acc: {0: '79.02%', 1: '99.44%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.013896, Train-Class-Acc: {0: '99.84%', 1: '99.64%'},
# Val Loss: 0.211123, Val Acc: 94.82%, Val-Class-Acc: {0: '92.06%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_94.pth
# Epoch 95/1000, Train Loss: 0.013901, Train-Class-Acc: {0: '99.53%', 1: '99.42%'},
# Val Loss: 0.231925, Val Acc: 94.04%, Val-Class-Acc: {0: '90.22%', 1: '97.56%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.008794, Train-Class-Acc: {0: '99.84%', 1: '99.85%'},
# Val Loss: 0.232848, Val Acc: 94.43%, Val-Class-Acc: {0: '89.82%', 1: '98.68%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.012060, Train-Class-Acc: {0: '99.61%', 1: '99.71%'},
# Val Loss: 0.346886, Val Acc: 91.79%, Val-Class-Acc: {0: '83.50%', 1: '99.44%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.008380, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.209928, Val Acc: 94.23%, Val-Class-Acc: {0: '94.70%', 1: '93.80%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.010100, Train-Class-Acc: {0: '99.77%', 1: '99.71%'},
# Val Loss: 0.244371, Val Acc: 94.43%, Val-Class-Acc: {0: '89.61%', 1: '98.87%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.010022, Train-Class-Acc: {0: '99.61%', 1: '99.78%'},
# Val Loss: 0.196217, Val Acc: 94.82%, Val-Class-Acc: {0: '93.69%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_100.pth
# Epoch 101/1000, Train Loss: 0.012106, Train-Class-Acc: {0: '99.77%', 1: '99.64%'},
# Val Loss: 0.276999, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.010451, Train-Class-Acc: {0: '99.84%', 1: '99.85%'},
# Val Loss: 0.238117, Val Acc: 92.77%, Val-Class-Acc: {0: '96.13%', 1: '89.66%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.008443, Train-Class-Acc: {0: '99.69%', 1: '99.71%'},
# Val Loss: 0.240053, Val Acc: 94.53%, Val-Class-Acc: {0: '90.63%', 1: '98.12%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.010549, Train-Class-Acc: {0: '99.69%', 1: '99.56%'},
# Val Loss: 0.455113, Val Acc: 89.44%, Val-Class-Acc: {0: '78.41%', 1: '99.62%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.007257, Train-Class-Acc: {0: '100.00%', 1: '99.78%'},
# Val Loss: 0.223962, Val Acc: 94.72%, Val-Class-Acc: {0: '91.65%', 1: '97.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_82.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_105.pth
# Epoch 106/1000, Train Loss: 0.009943, Train-Class-Acc: {0: '99.69%', 1: '99.85%'},
# Val Loss: 0.398635, Val Acc: 91.98%, Val-Class-Acc: {0: '83.71%', 1: '99.62%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.008129, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.319093, Val Acc: 90.32%, Val-Class-Acc: {0: '96.74%', 1: '84.40%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.009011, Train-Class-Acc: {0: '99.84%', 1: '99.71%'},
# Val Loss: 0.380462, Val Acc: 91.69%, Val-Class-Acc: {0: '83.10%', 1: '99.62%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.010193, Train-Class-Acc: {0: '99.69%', 1: '99.85%'},
# Val Loss: 0.389266, Val Acc: 91.89%, Val-Class-Acc: {0: '83.71%', 1: '99.44%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.007862, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.265378, Val Acc: 94.33%, Val-Class-Acc: {0: '89.41%', 1: '98.87%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.008547, Train-Class-Acc: {0: '99.92%', 1: '99.64%'},
# Val Loss: 0.546150, Val Acc: 83.58%, Val-Class-Acc: {0: '97.96%', 1: '70.30%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.009569, Train-Class-Acc: {0: '99.84%', 1: '99.78%'},
# Val Loss: 0.307706, Val Acc: 93.55%, Val-Class-Acc: {0: '87.98%', 1: '98.68%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.010152, Train-Class-Acc: {0: '99.38%', 1: '99.71%'},
# Val Loss: 0.264015, Val Acc: 92.38%, Val-Class-Acc: {0: '96.33%', 1: '88.72%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.009318, Train-Class-Acc: {0: '99.77%', 1: '99.64%'},
# Val Loss: 0.238679, Val Acc: 94.33%, Val-Class-Acc: {0: '89.41%', 1: '98.87%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.012343, Train-Class-Acc: {0: '99.53%', 1: '99.71%'},
# Val Loss: 0.355574, Val Acc: 92.28%, Val-Class-Acc: {0: '84.52%', 1: '99.44%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.007903, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.214676, Val Acc: 94.33%, Val-Class-Acc: {0: '93.08%', 1: '95.49%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.008662, Train-Class-Acc: {0: '99.61%', 1: '99.85%'},
# Val Loss: 0.235980, Val Acc: 92.77%, Val-Class-Acc: {0: '95.32%', 1: '90.41%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.007910, Train-Class-Acc: {0: '99.84%', 1: '99.71%'},
# Val Loss: 0.219338, Val Acc: 93.84%, Val-Class-Acc: {0: '94.70%', 1: '93.05%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.007053, Train-Class-Acc: {0: '99.84%', 1: '99.85%'},
# Val Loss: 0.435636, Val Acc: 90.71%, Val-Class-Acc: {0: '81.06%', 1: '99.62%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.005046, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.287786, Val Acc: 93.94%, Val-Class-Acc: {0: '88.39%', 1: '99.06%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.005284, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.237070, Val Acc: 94.82%, Val-Class-Acc: {0: '91.24%', 1: '98.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_65.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_121.pth
# Epoch 122/1000, Train Loss: 0.011953, Train-Class-Acc: {0: '99.77%', 1: '99.56%'},
# Val Loss: 0.324932, Val Acc: 93.55%, Val-Class-Acc: {0: '87.37%', 1: '99.25%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.008775, Train-Class-Acc: {0: '100.00%', 1: '99.56%'},
# Val Loss: 0.510312, Val Acc: 89.64%, Val-Class-Acc: {0: '78.82%', 1: '99.62%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.006938, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.236055, Val Acc: 94.53%, Val-Class-Acc: {0: '94.50%', 1: '94.55%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.006324, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.246560, Val Acc: 93.45%, Val-Class-Acc: {0: '95.11%', 1: '91.92%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.009888, Train-Class-Acc: {0: '99.77%', 1: '99.71%'},
# Val Loss: 0.448817, Val Acc: 91.30%, Val-Class-Acc: {0: '82.48%', 1: '99.44%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.005529, Train-Class-Acc: {0: '99.77%', 1: '99.93%'},
# Val Loss: 0.251035, Val Acc: 93.65%, Val-Class-Acc: {0: '94.50%', 1: '92.86%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.007698, Train-Class-Acc: {0: '99.61%', 1: '99.85%'},
# Val Loss: 0.280425, Val Acc: 92.47%, Val-Class-Acc: {0: '95.52%', 1: '89.66%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.007434, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.685136, Val Acc: 86.90%, Val-Class-Acc: {0: '73.12%', 1: '99.62%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.005747, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.296656, Val Acc: 93.55%, Val-Class-Acc: {0: '87.58%', 1: '99.06%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.004297, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.264634, Val Acc: 93.16%, Val-Class-Acc: {0: '95.72%', 1: '90.79%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.006334, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.257918, Val Acc: 94.92%, Val-Class-Acc: {0: '91.24%', 1: '98.31%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_132.pth
# Epoch 133/1000, Train Loss: 0.004184, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.501857, Val Acc: 90.03%, Val-Class-Acc: {0: '79.63%', 1: '99.62%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.005906, Train-Class-Acc: {0: '99.77%', 1: '99.85%'},
# Val Loss: 0.236746, Val Acc: 94.53%, Val-Class-Acc: {0: '93.08%', 1: '95.86%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.007110, Train-Class-Acc: {0: '99.61%', 1: '99.85%'},
# Val Loss: 0.363398, Val Acc: 92.86%, Val-Class-Acc: {0: '85.95%', 1: '99.25%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.005425, Train-Class-Acc: {0: '99.84%', 1: '99.85%'},
# Val Loss: 0.308188, Val Acc: 93.65%, Val-Class-Acc: {0: '87.98%', 1: '98.87%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.004523, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.472962, Val Acc: 90.52%, Val-Class-Acc: {0: '80.86%', 1: '99.44%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.006791, Train-Class-Acc: {0: '99.84%', 1: '99.71%'},
# Val Loss: 0.243478, Val Acc: 94.53%, Val-Class-Acc: {0: '93.48%', 1: '95.49%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.003930, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.269171, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.007010, Train-Class-Acc: {0: '99.84%', 1: '99.78%'},
# Val Loss: 0.555203, Val Acc: 89.44%, Val-Class-Acc: {0: '78.41%', 1: '99.62%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.006407, Train-Class-Acc: {0: '99.84%', 1: '99.85%'},
# Val Loss: 0.274527, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.004588, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.299636, Val Acc: 94.04%, Val-Class-Acc: {0: '88.80%', 1: '98.87%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.004774, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.289434, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.004594, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.287625, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '97.18%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.004741, Train-Class-Acc: {0: '100.00%', 1: '99.78%'},
# Val Loss: 0.729892, Val Acc: 85.53%, Val-Class-Acc: {0: '70.06%', 1: '99.81%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.003186, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.248957, Val Acc: 94.82%, Val-Class-Acc: {0: '93.28%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_105.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_146.pth
# Epoch 147/1000, Train Loss: 0.002601, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.267792, Val Acc: 94.72%, Val-Class-Acc: {0: '91.04%', 1: '98.12%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.003753, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.338339, Val Acc: 93.26%, Val-Class-Acc: {0: '87.37%', 1: '98.68%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.002783, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.261182, Val Acc: 94.72%, Val-Class-Acc: {0: '93.08%', 1: '96.24%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.003621, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.517814, Val Acc: 89.83%, Val-Class-Acc: {0: '79.23%', 1: '99.62%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.003820, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.324355, Val Acc: 94.23%, Val-Class-Acc: {0: '89.61%', 1: '98.50%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.005053, Train-Class-Acc: {0: '100.00%', 1: '99.78%'},
# Val Loss: 0.467988, Val Acc: 91.01%, Val-Class-Acc: {0: '81.87%', 1: '99.44%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.004465, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.305316, Val Acc: 94.13%, Val-Class-Acc: {0: '90.22%', 1: '97.74%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.004356, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.342018, Val Acc: 93.16%, Val-Class-Acc: {0: '86.56%', 1: '99.25%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.004482, Train-Class-Acc: {0: '99.77%', 1: '99.93%'},
# Val Loss: 0.275711, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.004919, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.459943, Val Acc: 91.69%, Val-Class-Acc: {0: '83.50%', 1: '99.25%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.004144, Train-Class-Acc: {0: '99.77%', 1: '99.93%'},
# Val Loss: 0.334608, Val Acc: 93.84%, Val-Class-Acc: {0: '89.00%', 1: '98.31%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.003285, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.280615, Val Acc: 94.62%, Val-Class-Acc: {0: '93.48%', 1: '95.68%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.003767, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.447730, Val Acc: 91.89%, Val-Class-Acc: {0: '83.71%', 1: '99.44%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.004389, Train-Class-Acc: {0: '100.00%', 1: '99.78%'},
# Val Loss: 0.796228, Val Acc: 80.84%, Val-Class-Acc: {0: '97.76%', 1: '65.23%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.003704, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.319371, Val Acc: 94.13%, Val-Class-Acc: {0: '89.41%', 1: '98.50%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.002254, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.285477, Val Acc: 94.53%, Val-Class-Acc: {0: '91.65%', 1: '97.18%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.002688, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.368406, Val Acc: 93.84%, Val-Class-Acc: {0: '88.19%', 1: '99.06%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.005051, Train-Class-Acc: {0: '99.77%', 1: '99.93%'},
# Val Loss: 0.864610, Val Acc: 85.83%, Val-Class-Acc: {0: '70.67%', 1: '99.81%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.006048, Train-Class-Acc: {0: '99.77%', 1: '99.64%'},
# Val Loss: 0.289695, Val Acc: 94.53%, Val-Class-Acc: {0: '91.65%', 1: '97.18%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.006349, Train-Class-Acc: {0: '99.69%', 1: '100.00%'},
# Val Loss: 1.174567, Val Acc: 82.60%, Val-Class-Acc: {0: '63.95%', 1: '99.81%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.003635, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.256754, Val Acc: 94.72%, Val-Class-Acc: {0: '92.46%', 1: '96.80%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.004552, Train-Class-Acc: {0: '99.84%', 1: '99.78%'},
# Val Loss: 0.488093, Val Acc: 91.59%, Val-Class-Acc: {0: '82.89%', 1: '99.62%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.006235, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.325022, Val Acc: 94.04%, Val-Class-Acc: {0: '89.00%', 1: '98.68%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.003014, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.270214, Val Acc: 94.82%, Val-Class-Acc: {0: '92.06%', 1: '97.37%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.003049, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.287532, Val Acc: 94.43%, Val-Class-Acc: {0: '92.67%', 1: '96.05%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.003518, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.294784, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.002439, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.309139, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.006551, Train-Class-Acc: {0: '99.84%', 1: '99.64%'},
# Val Loss: 0.875034, Val Acc: 86.31%, Val-Class-Acc: {0: '71.69%', 1: '99.81%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.004315, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.349769, Val Acc: 93.74%, Val-Class-Acc: {0: '88.19%', 1: '98.87%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.003050, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.351622, Val Acc: 94.04%, Val-Class-Acc: {0: '89.21%', 1: '98.50%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.003597, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.304316, Val Acc: 94.04%, Val-Class-Acc: {0: '93.89%', 1: '94.17%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.004499, Train-Class-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.495342, Val Acc: 91.10%, Val-Class-Acc: {0: '82.08%', 1: '99.44%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.005058, Train-Class-Acc: {0: '99.92%', 1: '99.78%'},
# Val Loss: 0.633989, Val Acc: 89.25%, Val-Class-Acc: {0: '77.80%', 1: '99.81%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.001863, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.311335, Val Acc: 94.04%, Val-Class-Acc: {0: '93.89%', 1: '94.17%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.003613, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.311593, Val Acc: 93.45%, Val-Class-Acc: {0: '94.30%', 1: '92.67%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.001868, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.373635, Val Acc: 94.13%, Val-Class-Acc: {0: '90.22%', 1: '97.74%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.003059, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.364112, Val Acc: 94.04%, Val-Class-Acc: {0: '89.00%', 1: '98.68%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.004056, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.320420, Val Acc: 92.57%, Val-Class-Acc: {0: '95.93%', 1: '89.47%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.003812, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.386709, Val Acc: 93.55%, Val-Class-Acc: {0: '87.98%', 1: '98.68%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.002670, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.322365, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.004472, Train-Class-Acc: {0: '99.77%', 1: '99.93%'},
# Val Loss: 0.401415, Val Acc: 91.40%, Val-Class-Acc: {0: '96.54%', 1: '86.65%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.007414, Train-Class-Acc: {0: '99.61%', 1: '99.85%'},
# Val Loss: 0.568044, Val Acc: 91.10%, Val-Class-Acc: {0: '81.67%', 1: '99.81%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.002456, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.343752, Val Acc: 94.23%, Val-Class-Acc: {0: '90.43%', 1: '97.74%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.002772, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.321485, Val Acc: 94.43%, Val-Class-Acc: {0: '91.85%', 1: '96.80%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.001778, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.298852, Val Acc: 94.53%, Val-Class-Acc: {0: '93.48%', 1: '95.49%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.002423, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.405473, Val Acc: 93.35%, Val-Class-Acc: {0: '87.78%', 1: '98.50%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.002562, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.312218, Val Acc: 94.53%, Val-Class-Acc: {0: '91.65%', 1: '97.18%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.002084, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.338773, Val Acc: 94.82%, Val-Class-Acc: {0: '91.45%', 1: '97.93%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.002196, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.400344, Val Acc: 93.55%, Val-Class-Acc: {0: '87.78%', 1: '98.87%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.002067, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.374364, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.003330, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.334092, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.002655, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.375296, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.001741, Train-Class-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.322943, Val Acc: 94.53%, Val-Class-Acc: {0: '91.24%', 1: '97.56%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.002396, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.455781, Val Acc: 92.67%, Val-Class-Acc: {0: '85.34%', 1: '99.44%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.002135, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.324654, Val Acc: 93.35%, Val-Class-Acc: {0: '94.30%', 1: '92.48%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.002462, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.557860, Val Acc: 90.62%, Val-Class-Acc: {0: '80.86%', 1: '99.62%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.002403, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.368226, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.002415, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.374406, Val Acc: 93.84%, Val-Class-Acc: {0: '89.41%', 1: '97.93%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.003206, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.309734, Val Acc: 94.62%, Val-Class-Acc: {0: '93.48%', 1: '95.68%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.003362, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.718834, Val Acc: 89.44%, Val-Class-Acc: {0: '78.82%', 1: '99.25%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.002249, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.315558, Val Acc: 95.11%, Val-Class-Acc: {0: '92.87%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_94.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_207.pth
# Epoch 208/1000, Train Loss: 0.002692, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.323932, Val Acc: 94.43%, Val-Class-Acc: {0: '93.08%', 1: '95.68%'}, LR: 0.000100
# Epoch 209/1000, Train Loss: 0.002779, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.338036, Val Acc: 94.82%, Val-Class-Acc: {0: '91.65%', 1: '97.74%'}, LR: 0.000100
# Epoch 210/1000, Train Loss: 0.001851, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.403558, Val Acc: 93.65%, Val-Class-Acc: {0: '87.98%', 1: '98.87%'}, LR: 0.000100
# Epoch 211/1000, Train Loss: 0.001397, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.316637, Val Acc: 94.82%, Val-Class-Acc: {0: '92.26%', 1: '97.18%'}, LR: 0.000100
# Epoch 212/1000, Train Loss: 0.003033, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.345531, Val Acc: 93.55%, Val-Class-Acc: {0: '94.70%', 1: '92.48%'}, LR: 0.000100
# Epoch 213/1000, Train Loss: 0.001272, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.533532, Val Acc: 91.69%, Val-Class-Acc: {0: '83.30%', 1: '99.44%'}, LR: 0.000100
# Epoch 214/1000, Train Loss: 0.001328, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.331699, Val Acc: 95.01%, Val-Class-Acc: {0: '92.67%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_100.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_214.pth
# Epoch 215/1000, Train Loss: 0.004148, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.763701, Val Acc: 88.17%, Val-Class-Acc: {0: '75.56%', 1: '99.81%'}, LR: 0.000100
# Epoch 216/1000, Train Loss: 0.002892, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.501087, Val Acc: 91.59%, Val-Class-Acc: {0: '83.30%', 1: '99.25%'}, LR: 0.000100
# Epoch 217/1000, Train Loss: 0.003647, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.427353, Val Acc: 92.38%, Val-Class-Acc: {0: '85.13%', 1: '99.06%'}, LR: 0.000100
# Epoch 218/1000, Train Loss: 0.001856, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.315851, Val Acc: 94.43%, Val-Class-Acc: {0: '92.46%', 1: '96.24%'}, LR: 0.000100
# Epoch 219/1000, Train Loss: 0.001640, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.352293, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 220/1000, Train Loss: 0.001450, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.342221, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# ...
# Val Loss: 1.053220, Val Acc: 89.54%, Val-Class-Acc: {0: '78.82%', 1: '99.44%'}, LR: 0.000100
# Epoch 925/1000, Train Loss: 0.000164, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.713082, Val Acc: 93.65%, Val-Class-Acc: {0: '89.21%', 1: '97.74%'}, LR: 0.000100
# Epoch 926/1000, Train Loss: 0.006926, Train-Class-Acc: {0: '99.84%', 1: '99.56%'},
# Val Loss: 1.292744, Val Acc: 83.19%, Val-Class-Acc: {0: '96.13%', 1: '71.24%'}, LR: 0.000100
# Epoch 927/1000, Train Loss: 0.000530, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.642437, Val Acc: 94.04%, Val-Class-Acc: {0: '90.02%', 1: '97.74%'}, LR: 0.000100
# Epoch 928/1000, Train Loss: 0.001362, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.766071, Val Acc: 92.47%, Val-Class-Acc: {0: '85.54%', 1: '98.87%'}, LR: 0.000100
# Epoch 929/1000, Train Loss: 0.000092, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.621490, Val Acc: 93.35%, Val-Class-Acc: {0: '87.98%', 1: '98.31%'}, LR: 0.000100
# Epoch 930/1000, Train Loss: 0.000653, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.788742, Val Acc: 91.59%, Val-Class-Acc: {0: '83.71%', 1: '98.87%'}, LR: 0.000100
# Epoch 931/1000, Train Loss: 0.001479, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.737326, Val Acc: 87.19%, Val-Class-Acc: {0: '96.13%', 1: '78.95%'}, LR: 0.000100
# Epoch 932/1000, Train Loss: 0.000863, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.821909, Val Acc: 91.89%, Val-Class-Acc: {0: '83.91%', 1: '99.25%'}, LR: 0.000100
# Epoch 933/1000, Train Loss: 0.000127, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.620457, Val Acc: 93.65%, Val-Class-Acc: {0: '89.21%', 1: '97.74%'}, LR: 0.000100
# Epoch 934/1000, Train Loss: 0.000101, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.637004, Val Acc: 93.84%, Val-Class-Acc: {0: '89.41%', 1: '97.93%'}, LR: 0.000100
# Epoch 935/1000, Train Loss: 0.000117, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.652437, Val Acc: 93.26%, Val-Class-Acc: {0: '88.19%', 1: '97.93%'}, LR: 0.000100
# Epoch 936/1000, Train Loss: 0.000399, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.645832, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.000127, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.642180, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.000718, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.525928, Val Acc: 94.62%, Val-Class-Acc: {0: '92.87%', 1: '96.24%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.001720, Train-Class-Acc: {0: '99.92%', 1: '99.93%'},
# Val Loss: 0.589269, Val Acc: 94.13%, Val-Class-Acc: {0: '91.45%', 1: '96.62%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.000283, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.670908, Val Acc: 93.65%, Val-Class-Acc: {0: '89.41%', 1: '97.56%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.000512, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 1.525917, Val Acc: 87.10%, Val-Class-Acc: {0: '73.32%', 1: '99.81%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.000486, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.636464, Val Acc: 93.65%, Val-Class-Acc: {0: '94.30%', 1: '93.05%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.000237, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.716561, Val Acc: 93.26%, Val-Class-Acc: {0: '88.80%', 1: '97.37%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.000084, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.677739, Val Acc: 93.84%, Val-Class-Acc: {0: '90.22%', 1: '97.18%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.000730, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 1.142858, Val Acc: 89.83%, Val-Class-Acc: {0: '79.63%', 1: '99.25%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.000262, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.793686, Val Acc: 92.77%, Val-Class-Acc: {0: '87.17%', 1: '97.93%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.001552, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.850985, Val Acc: 92.28%, Val-Class-Acc: {0: '84.73%', 1: '99.25%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.000170, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.666492, Val Acc: 93.45%, Val-Class-Acc: {0: '89.61%', 1: '96.99%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.000095, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.659315, Val Acc: 93.65%, Val-Class-Acc: {0: '89.82%', 1: '97.18%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.000188, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.726458, Val Acc: 93.65%, Val-Class-Acc: {0: '88.80%', 1: '98.12%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.000076, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.677443, Val Acc: 93.74%, Val-Class-Acc: {0: '90.22%', 1: '96.99%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.000473, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.598410, Val Acc: 94.04%, Val-Class-Acc: {0: '93.69%', 1: '94.36%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.000204, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.901959, Val Acc: 92.18%, Val-Class-Acc: {0: '84.73%', 1: '99.06%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.000054, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.715380, Val Acc: 93.65%, Val-Class-Acc: {0: '89.41%', 1: '97.56%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.001346, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.613194, Val Acc: 94.23%, Val-Class-Acc: {0: '93.28%', 1: '95.11%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.000336, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.738573, Val Acc: 93.45%, Val-Class-Acc: {0: '88.19%', 1: '98.31%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.002144, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 1.878743, Val Acc: 84.07%, Val-Class-Acc: {0: '66.80%', 1: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.000319, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.734112, Val Acc: 93.84%, Val-Class-Acc: {0: '90.43%', 1: '96.99%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.000899, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.686711, Val Acc: 94.04%, Val-Class-Acc: {0: '91.45%', 1: '96.43%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.000714, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.621749, Val Acc: 94.62%, Val-Class-Acc: {0: '92.06%', 1: '96.99%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.001153, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.861369, Val Acc: 92.47%, Val-Class-Acc: {0: '85.95%', 1: '98.50%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.000785, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 1.172314, Val Acc: 89.15%, Val-Class-Acc: {0: '78.41%', 1: '99.06%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.000719, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.728637, Val Acc: 90.91%, Val-Class-Acc: {0: '96.13%', 1: '86.09%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.000538, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.758136, Val Acc: 93.16%, Val-Class-Acc: {0: '87.78%', 1: '98.12%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.000052, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.702398, Val Acc: 93.55%, Val-Class-Acc: {0: '89.00%', 1: '97.74%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.000215, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.616645, Val Acc: 93.84%, Val-Class-Acc: {0: '90.84%', 1: '96.62%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.000253, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.778784, Val Acc: 92.38%, Val-Class-Acc: {0: '85.95%', 1: '98.31%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.001141, Train-Class-Acc: {0: '99.84%', 1: '100.00%'},
# Val Loss: 0.524839, Val Acc: 93.74%, Val-Class-Acc: {0: '93.69%', 1: '93.80%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.000097, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.646350, Val Acc: 93.45%, Val-Class-Acc: {0: '88.59%', 1: '97.93%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.000254, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.659712, Val Acc: 93.55%, Val-Class-Acc: {0: '88.80%', 1: '97.93%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.000118, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.763761, Val Acc: 92.86%, Val-Class-Acc: {0: '86.76%', 1: '98.50%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.000747, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.614452, Val Acc: 93.74%, Val-Class-Acc: {0: '94.91%', 1: '92.67%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.000106, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.633304, Val Acc: 94.33%, Val-Class-Acc: {0: '91.65%', 1: '96.80%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.000265, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.568217, Val Acc: 94.72%, Val-Class-Acc: {0: '93.48%', 1: '95.86%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.000054, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.655116, Val Acc: 93.74%, Val-Class-Acc: {0: '89.21%', 1: '97.93%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.000199, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.766633, Val Acc: 92.96%, Val-Class-Acc: {0: '87.17%', 1: '98.31%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.000149, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.635762, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.000519, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.838035, Val Acc: 92.47%, Val-Class-Acc: {0: '86.15%', 1: '98.31%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.001364, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.879565, Val Acc: 87.98%, Val-Class-Acc: {0: '95.93%', 1: '80.64%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.000099, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.679797, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.000461, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.607460, Val Acc: 94.33%, Val-Class-Acc: {0: '91.85%', 1: '96.62%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.001948, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.775431, Val Acc: 92.96%, Val-Class-Acc: {0: '86.76%', 1: '98.68%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.000317, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.711922, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.000148, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.684803, Val Acc: 94.04%, Val-Class-Acc: {0: '89.61%', 1: '98.12%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.001262, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.690378, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.000190, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.769828, Val Acc: 92.77%, Val-Class-Acc: {0: '86.76%', 1: '98.31%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.000701, Train-Class-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.547950, Val Acc: 93.45%, Val-Class-Acc: {0: '94.09%', 1: '92.86%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.000111, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.687597, Val Acc: 93.65%, Val-Class-Acc: {0: '89.00%', 1: '97.93%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.000393, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.736596, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.000275, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.648337, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.000124, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.710425, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.000244, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.679069, Val Acc: 94.04%, Val-Class-Acc: {0: '90.22%', 1: '97.56%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.000176, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.665888, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.000049, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.684807, Val Acc: 94.04%, Val-Class-Acc: {0: '89.61%', 1: '98.12%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.000121, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.683069, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.000280, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.797265, Val Acc: 92.67%, Val-Class-Acc: {0: '86.56%', 1: '98.31%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.000316, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.662905, Val Acc: 94.13%, Val-Class-Acc: {0: '90.22%', 1: '97.74%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.000142, Train-Class-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.622582, Val Acc: 94.33%, Val-Class-Acc: {0: '90.63%', 1: '97.74%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.000766, Train-Class-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.910405, Val Acc: 91.10%, Val-Class-Acc: {0: '83.30%', 1: '98.31%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.002201, Train-Class-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.809235, Val Acc: 91.79%, Val-Class-Acc: {0: '84.52%', 1: '98.50%'}, LR: 0.000100
#
# ⏳ Total training time: 86.52 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_best.pth (Val Accuracy: 95.21%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 351, Train Loss: 0.000509, Train-Acc: {0: '100.00%', 1: '100.00%'},
# Val Loss: 0.385031, Val Acc: 95.21%, Val-Acc: {0: '92.87%', 1: '97.37%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_351.pth
# Epoch 349, Train Loss: 0.000997, Train-Acc: {0: '99.92%', 1: '100.00%'},
# Val Loss: 0.405379, Val Acc: 95.21%, Val-Acc: {0: '93.08%', 1: '97.18%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_349.pth
# Epoch 284, Train Loss: 0.002083, Train-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.352384, Val Acc: 95.21%, Val-Acc: {0: '92.67%', 1: '97.56%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_284.pth
# Epoch 298, Train Loss: 0.002484, Train-Acc: {0: '100.00%', 1: '99.85%'},
# Val Loss: 0.387759, Val Acc: 95.11%, Val-Acc: {0: '92.26%', 1: '97.74%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_298.pth
# Epoch 207, Train Loss: 0.002249, Train-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.315558, Val Acc: 95.11%, Val-Acc: {0: '92.87%', 1: '97.18%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1/HAR_MLP_epoch_207.pth
# ---
# ### Period 1
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_1'*
# + ##### Best Epoch: 351
# #### __Val Accuracy: 95.21%__
# #### __Val-Class-Acc: {0: '92.87%', 1: '97.37%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ---
# ### Period 2
# + ##### Total training time: 334.56 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2'*
# + ##### Best Epoch: 646
# #### __Val Accuracy: 97.80%__
# #### __Val-Class-Acc: {0: '94.09%', 1: '95.49%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 2 Configuration
# ================================
period = 2

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_2")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 1 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_1", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher Information Matrix (based on Period 1 training data)
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[1]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[1]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer (new for Period 2)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Memory cleanup
del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 26567 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# /tmp/ipykernel_3491776/2795078744.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.313574, Train-Class-Acc: {0: '79.24%', 1: '89.88%', 2: '95.80%'},
# Val Loss: 0.146322, Val Acc: 97.26%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.097342, Train-Class-Acc: {0: '96.03%', 1: '96.51%', 2: '99.91%'},
# Val Loss: 0.139701, Val Acc: 96.60%, Val-Class-Acc: {0: '84.52%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.068778, Train-Class-Acc: {0: '97.12%', 1: '97.23%', 2: '99.94%'},
# Val Loss: 0.103519, Val Acc: 97.34%, Val-Class-Acc: {0: '92.46%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.047736, Train-Class-Acc: {0: '98.29%', 1: '98.54%', 2: '99.91%'},
# Val Loss: 0.113818, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.042646, Train-Class-Acc: {0: '98.06%', 1: '98.18%', 2: '99.97%'},
# Val Loss: 0.120354, Val Acc: 96.97%, Val-Class-Acc: {0: '87.17%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.035152, Train-Class-Acc: {0: '98.76%', 1: '98.84%', 2: '99.97%'},
# Val Loss: 0.108410, Val Acc: 97.51%, Val-Class-Acc: {0: '90.02%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.031096, Train-Class-Acc: {0: '98.83%', 1: '98.84%', 2: '99.97%'},
# Val Loss: 0.104648, Val Acc: 97.68%, Val-Class-Acc: {0: '91.04%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.029137, Train-Class-Acc: {0: '98.68%', 1: '99.05%', 2: '99.94%'},
# Val Loss: 0.095006, Val Acc: 97.72%, Val-Class-Acc: {0: '92.46%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.022732, Train-Class-Acc: {0: '99.30%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.105826, Val Acc: 97.68%, Val-Class-Acc: {0: '90.84%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.022710, Train-Class-Acc: {0: '99.22%', 1: '99.20%', 2: '99.97%'},
# Val Loss: 0.114374, Val Acc: 97.01%, Val-Class-Acc: {0: '94.50%', 1: '91.54%', 2: '100.00%'}, LR: 0.000100
# Epoch 11/1000, Train Loss: 0.022703, Train-Class-Acc: {0: '98.83%', 1: '99.42%', 2: '99.97%'},
# Val Loss: 0.155858, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 12/1000, Train Loss: 0.019085, Train-Class-Acc: {0: '98.76%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.123101, Val Acc: 97.59%, Val-Class-Acc: {0: '89.61%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.015799, Train-Class-Acc: {0: '99.38%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.111877, Val Acc: 97.72%, Val-Class-Acc: {0: '90.84%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.018103, Train-Class-Acc: {0: '99.14%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.109933, Val Acc: 97.30%, Val-Class-Acc: {0: '92.87%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.016845, Train-Class-Acc: {0: '99.53%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.112409, Val Acc: 97.47%, Val-Class-Acc: {0: '92.87%', 1: '95.11%', 2: '100.00%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.014758, Train-Class-Acc: {0: '99.30%', 1: '99.49%', 2: '99.97%'},
# Val Loss: 0.131645, Val Acc: 97.18%, Val-Class-Acc: {0: '87.78%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.015986, Train-Class-Acc: {0: '99.38%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.201161, Val Acc: 95.31%, Val-Class-Acc: {0: '77.39%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.016229, Train-Class-Acc: {0: '99.14%', 1: '99.27%', 2: '100.00%'},
# Val Loss: 0.110948, Val Acc: 97.43%, Val-Class-Acc: {0: '92.06%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.015599, Train-Class-Acc: {0: '99.46%', 1: '99.20%', 2: '100.00%'},
# Val Loss: 0.135031, Val Acc: 96.06%, Val-Class-Acc: {0: '95.11%', 1: '86.65%', 2: '100.00%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.014277, Train-Class-Acc: {0: '99.53%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.111061, Val Acc: 97.22%, Val-Class-Acc: {0: '93.69%', 1: '93.23%', 2: '100.00%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.012998, Train-Class-Acc: {0: '99.61%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.109458, Val Acc: 97.47%, Val-Class-Acc: {0: '93.28%', 1: '94.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.012807, Train-Class-Acc: {0: '99.77%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.111656, Val Acc: 97.63%, Val-Class-Acc: {0: '92.26%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.011191, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.137050, Val Acc: 97.51%, Val-Class-Acc: {0: '89.21%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.011429, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.126250, Val Acc: 97.59%, Val-Class-Acc: {0: '91.24%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.011461, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '99.97%'},
# Val Loss: 0.189411, Val Acc: 95.81%, Val-Class-Acc: {0: '80.04%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.010165, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.133811, Val Acc: 97.47%, Val-Class-Acc: {0: '89.21%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.008579, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.118089, Val Acc: 97.63%, Val-Class-Acc: {0: '90.84%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.010675, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.128252, Val Acc: 97.47%, Val-Class-Acc: {0: '89.41%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.010454, Train-Class-Acc: {0: '99.69%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.139091, Val Acc: 96.93%, Val-Class-Acc: {0: '86.76%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.010507, Train-Class-Acc: {0: '99.53%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.120801, Val Acc: 97.55%, Val-Class-Acc: {0: '91.45%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.009406, Train-Class-Acc: {0: '99.77%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.123480, Val Acc: 97.80%, Val-Class-Acc: {0: '90.84%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.008669, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.119628, Val Acc: 97.26%, Val-Class-Acc: {0: '94.30%', 1: '92.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.007606, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.173066, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.007852, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.149647, Val Acc: 96.80%, Val-Class-Acc: {0: '85.34%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.008339, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.115867, Val Acc: 97.59%, Val-Class-Acc: {0: '91.65%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.007807, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.182149, Val Acc: 96.51%, Val-Class-Acc: {0: '83.50%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.007086, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.124194, Val Acc: 97.51%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.007239, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.172602, Val Acc: 96.80%, Val-Class-Acc: {0: '86.15%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.006993, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.254228, Val Acc: 95.10%, Val-Class-Acc: {0: '76.78%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.007105, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.131355, Val Acc: 97.55%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.007506, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.116907, Val Acc: 97.39%, Val-Class-Acc: {0: '93.08%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.006771, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.108983, Val Acc: 97.80%, Val-Class-Acc: {0: '92.67%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.005711, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.97%'},
# Val Loss: 0.120488, Val Acc: 97.39%, Val-Class-Acc: {0: '92.67%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.006422, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.150156, Val Acc: 97.14%, Val-Class-Acc: {0: '86.97%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.007751, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.145929, Val Acc: 97.14%, Val-Class-Acc: {0: '87.17%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.007882, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.121620, Val Acc: 97.26%, Val-Class-Acc: {0: '94.70%', 1: '92.48%', 2: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.006225, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.144075, Val Acc: 97.01%, Val-Class-Acc: {0: '95.32%', 1: '90.79%', 2: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.006158, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.120202, Val Acc: 97.51%, Val-Class-Acc: {0: '94.09%', 1: '94.17%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.006182, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '99.97%'},
# Val Loss: 0.262220, Val Acc: 94.94%, Val-Class-Acc: {0: '75.76%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.006335, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.214267, Val Acc: 95.98%, Val-Class-Acc: {0: '80.86%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.005866, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.152530, Val Acc: 97.10%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.006355, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.220236, Val Acc: 96.10%, Val-Class-Acc: {0: '81.26%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.005693, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.106491, Val Acc: 97.72%, Val-Class-Acc: {0: '93.08%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.006613, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.179926, Val Acc: 96.64%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.006194, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.203944, Val Acc: 96.35%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.006394, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.192359, Val Acc: 96.39%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.005936, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.206121, Val Acc: 96.39%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.005724, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.196734, Val Acc: 96.18%, Val-Class-Acc: {0: '82.28%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.006882, Train-Class-Acc: {0: '99.84%', 1: '99.56%', 2: '100.00%'},
# Val Loss: 0.127623, Val Acc: 97.63%, Val-Class-Acc: {0: '90.22%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.004960, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.122689, Val Acc: 97.34%, Val-Class-Acc: {0: '92.87%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.004952, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.130364, Val Acc: 97.59%, Val-Class-Acc: {0: '91.04%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.005651, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.147666, Val Acc: 97.05%, Val-Class-Acc: {0: '87.17%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.004510, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.153044, Val Acc: 97.34%, Val-Class-Acc: {0: '88.59%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.007157, Train-Class-Acc: {0: '99.77%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.277283, Val Acc: 94.61%, Val-Class-Acc: {0: '73.93%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.004977, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.143616, Val Acc: 97.72%, Val-Class-Acc: {0: '91.85%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.005279, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.124276, Val Acc: 97.68%, Val-Class-Acc: {0: '92.26%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.005232, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.133070, Val Acc: 97.55%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.004667, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.259773, Val Acc: 93.11%, Val-Class-Acc: {0: '96.13%', 1: '72.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.006724, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.151637, Val Acc: 95.73%, Val-Class-Acc: {0: '95.93%', 1: '84.40%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.005366, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.224878, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.005156, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.146803, Val Acc: 97.10%, Val-Class-Acc: {0: '94.91%', 1: '91.54%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.005848, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.141320, Val Acc: 97.22%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.005427, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.135152, Val Acc: 97.55%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.010216, Train-Class-Acc: {0: '99.46%', 1: '99.34%', 2: '100.00%'},
# Val Loss: 0.159996, Val Acc: 97.14%, Val-Class-Acc: {0: '88.19%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.005566, Train-Class-Acc: {0: '99.69%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.151133, Val Acc: 97.22%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.004449, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.185043, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.005023, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.301886, Val Acc: 94.85%, Val-Class-Acc: {0: '75.36%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.004707, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.152996, Val Acc: 97.22%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.005133, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.97%'},
# Val Loss: 0.198208, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.005179, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.140448, Val Acc: 97.30%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.004838, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.135793, Val Acc: 97.01%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.005073, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.252151, Val Acc: 95.27%, Val-Class-Acc: {0: '77.19%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.005321, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.127512, Val Acc: 97.72%, Val-Class-Acc: {0: '94.30%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.003696, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.131617, Val Acc: 97.55%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.003790, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.155887, Val Acc: 97.34%, Val-Class-Acc: {0: '88.59%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.003486, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.125246, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.004635, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.124523, Val Acc: 97.43%, Val-Class-Acc: {0: '93.48%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.005755, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.124717, Val Acc: 97.68%, Val-Class-Acc: {0: '91.04%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.005378, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.154728, Val Acc: 97.05%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.004660, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.421957, Val Acc: 93.11%, Val-Class-Acc: {0: '66.19%', 1: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.004633, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.130280, Val Acc: 97.34%, Val-Class-Acc: {0: '92.06%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.004103, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.123928, Val Acc: 97.55%, Val-Class-Acc: {0: '94.30%', 1: '94.17%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.003844, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.196241, Val Acc: 96.51%, Val-Class-Acc: {0: '83.50%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.004040, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.173050, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.003768, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.163141, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.004109, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.129896, Val Acc: 97.59%, Val-Class-Acc: {0: '90.22%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.006852, Train-Class-Acc: {0: '99.77%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.145345, Val Acc: 96.89%, Val-Class-Acc: {0: '93.48%', 1: '91.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.004995, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.141235, Val Acc: 97.63%, Val-Class-Acc: {0: '91.65%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.003384, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.134547, Val Acc: 97.68%, Val-Class-Acc: {0: '91.04%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.003134, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.178477, Val Acc: 96.85%, Val-Class-Acc: {0: '85.54%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.003786, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.158349, Val Acc: 97.18%, Val-Class-Acc: {0: '87.78%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.004409, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.158129, Val Acc: 97.43%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.003469, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.186765, Val Acc: 96.56%, Val-Class-Acc: {0: '84.52%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.004155, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.172562, Val Acc: 96.93%, Val-Class-Acc: {0: '86.56%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.004138, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.132684, Val Acc: 97.63%, Val-Class-Acc: {0: '92.46%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.004581, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.147946, Val Acc: 97.59%, Val-Class-Acc: {0: '91.04%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.003355, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.158935, Val Acc: 97.47%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.003709, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.172788, Val Acc: 96.39%, Val-Class-Acc: {0: '95.32%', 1: '87.97%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.005051, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.152726, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.005806, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.157003, Val Acc: 96.56%, Val-Class-Acc: {0: '95.32%', 1: '88.72%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.005612, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '99.97%'},
# Val Loss: 0.203288, Val Acc: 96.31%, Val-Class-Acc: {0: '82.89%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.006050, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.311790, Val Acc: 94.77%, Val-Class-Acc: {0: '74.54%', 1: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.005597, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.240594, Val Acc: 95.64%, Val-Class-Acc: {0: '79.63%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.004180, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144230, Val Acc: 97.47%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.002785, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.165610, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.002663, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.145812, Val Acc: 97.43%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.003467, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.147175, Val Acc: 97.26%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.004741, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.139124, Val Acc: 97.43%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.004000, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.175993, Val Acc: 97.14%, Val-Class-Acc: {0: '88.39%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.003465, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.231284, Val Acc: 95.77%, Val-Class-Acc: {0: '79.84%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.002632, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.145103, Val Acc: 97.39%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.002667, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.194570, Val Acc: 96.89%, Val-Class-Acc: {0: '85.95%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.003412, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.134485, Val Acc: 97.72%, Val-Class-Acc: {0: '94.50%', 1: '94.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.004584, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.164799, Val Acc: 97.39%, Val-Class-Acc: {0: '88.39%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.003137, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135708, Val Acc: 97.47%, Val-Class-Acc: {0: '92.87%', 1: '95.11%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.004120, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.199814, Val Acc: 96.89%, Val-Class-Acc: {0: '85.54%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.004573, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.209160, Val Acc: 96.39%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.005119, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.148482, Val Acc: 97.43%, Val-Class-Acc: {0: '89.00%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.003477, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.125659, Val Acc: 97.80%, Val-Class-Acc: {0: '93.48%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_129.pth
# Epoch 130/1000, Train Loss: 0.004690, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.130783, Val Acc: 97.30%, Val-Class-Acc: {0: '93.69%', 1: '93.61%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.002821, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.157352, Val Acc: 97.22%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.003177, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.149216, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.002791, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.129979, Val Acc: 97.59%, Val-Class-Acc: {0: '94.09%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.003441, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.187972, Val Acc: 96.80%, Val-Class-Acc: {0: '85.13%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.006290, Train-Class-Acc: {0: '99.61%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.135832, Val Acc: 97.22%, Val-Class-Acc: {0: '92.67%', 1: '94.17%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.004002, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.250752, Val Acc: 96.02%, Val-Class-Acc: {0: '81.06%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.006350, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.295426, Val Acc: 95.15%, Val-Class-Acc: {0: '76.58%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.003317, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.149427, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.003456, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.307322, Val Acc: 94.69%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.004243, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.182654, Val Acc: 96.93%, Val-Class-Acc: {0: '86.56%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.003443, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.257769, Val Acc: 95.64%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.002676, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.162008, Val Acc: 97.34%, Val-Class-Acc: {0: '88.19%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.003151, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.222677, Val Acc: 96.18%, Val-Class-Acc: {0: '82.28%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.003075, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.196920, Val Acc: 96.43%, Val-Class-Acc: {0: '83.71%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.002894, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144610, Val Acc: 97.22%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.002609, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.156458, Val Acc: 97.39%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.003313, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.144115, Val Acc: 97.26%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.002663, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.159624, Val Acc: 97.30%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.002472, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.182794, Val Acc: 96.93%, Val-Class-Acc: {0: '86.15%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.002975, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.200100, Val Acc: 96.72%, Val-Class-Acc: {0: '84.93%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.002400, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.149384, Val Acc: 97.39%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.008798, Train-Class-Acc: {0: '99.46%', 1: '99.49%', 2: '100.00%'},
# Val Loss: 0.438838, Val Acc: 92.12%, Val-Class-Acc: {0: '61.30%', 1: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.005706, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.120410, Val Acc: 97.59%, Val-Class-Acc: {0: '91.85%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.003309, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.204675, Val Acc: 96.35%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.002844, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.144763, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.003629, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.148822, Val Acc: 97.26%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.003086, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.175864, Val Acc: 96.72%, Val-Class-Acc: {0: '84.52%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.002725, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.166972, Val Acc: 96.93%, Val-Class-Acc: {0: '86.56%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.002941, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.152994, Val Acc: 97.26%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.002308, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.158229, Val Acc: 97.26%, Val-Class-Acc: {0: '88.39%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.002566, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.163827, Val Acc: 97.26%, Val-Class-Acc: {0: '88.19%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.003478, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.172662, Val Acc: 97.39%, Val-Class-Acc: {0: '88.80%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.003875, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.123343, Val Acc: 97.55%, Val-Class-Acc: {0: '93.48%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.003968, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.128234, Val Acc: 97.01%, Val-Class-Acc: {0: '95.11%', 1: '90.98%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.005642, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '99.97%'},
# Val Loss: 0.295459, Val Acc: 95.19%, Val-Class-Acc: {0: '76.58%', 1: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.004182, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.146677, Val Acc: 97.51%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.004027, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.249239, Val Acc: 95.64%, Val-Class-Acc: {0: '79.63%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.003815, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.168325, Val Acc: 97.10%, Val-Class-Acc: {0: '86.97%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.003145, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.148693, Val Acc: 97.18%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.002902, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.138070, Val Acc: 97.39%, Val-Class-Acc: {0: '92.67%', 1: '94.92%', 2: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.003427, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.148981, Val Acc: 97.43%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.002853, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.133559, Val Acc: 97.30%, Val-Class-Acc: {0: '92.67%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.003721, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.184656, Val Acc: 96.31%, Val-Class-Acc: {0: '83.91%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.004262, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.153812, Val Acc: 97.22%, Val-Class-Acc: {0: '91.45%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.003780, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.280290, Val Acc: 95.23%, Val-Class-Acc: {0: '77.19%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.003176, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.169725, Val Acc: 97.22%, Val-Class-Acc: {0: '94.09%', 1: '92.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.002611, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.227420, Val Acc: 96.31%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.002521, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.178754, Val Acc: 97.10%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.002482, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.174146, Val Acc: 97.10%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.003337, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.240628, Val Acc: 95.64%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.003011, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.131592, Val Acc: 97.39%, Val-Class-Acc: {0: '94.09%', 1: '93.61%', 2: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.003556, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.160895, Val Acc: 97.14%, Val-Class-Acc: {0: '86.76%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.002634, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.131608, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.003461, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.136837, Val Acc: 97.22%, Val-Class-Acc: {0: '94.91%', 1: '92.11%', 2: '100.00%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.004060, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.175297, Val Acc: 97.10%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.002438, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.154626, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.003130, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.337079, Val Acc: 94.65%, Val-Class-Acc: {0: '74.13%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.010513, Train-Class-Acc: {0: '99.14%', 1: '99.13%', 2: '100.00%'},
# Val Loss: 0.180290, Val Acc: 96.93%, Val-Class-Acc: {0: '86.35%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.005801, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.174648, Val Acc: 96.68%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.003934, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.162924, Val Acc: 97.22%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.005734, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.157093, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.003290, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.160809, Val Acc: 97.34%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.004022, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.148218, Val Acc: 97.39%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.003059, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.190188, Val Acc: 96.85%, Val-Class-Acc: {0: '85.54%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.003278, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.179843, Val Acc: 97.05%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.002559, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.265394, Val Acc: 95.56%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.003600, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.203135, Val Acc: 96.39%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.003057, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.185199, Val Acc: 96.97%, Val-Class-Acc: {0: '86.56%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.003398, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.149092, Val Acc: 97.59%, Val-Class-Acc: {0: '92.87%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.003791, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.135130, Val Acc: 97.55%, Val-Class-Acc: {0: '94.09%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.002528, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.160645, Val Acc: 97.26%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.004975, Train-Class-Acc: {0: '99.61%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.171501, Val Acc: 97.51%, Val-Class-Acc: {0: '89.82%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.002900, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.188136, Val Acc: 96.93%, Val-Class-Acc: {0: '86.56%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.002641, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.154495, Val Acc: 97.39%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.003074, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.308080, Val Acc: 94.94%, Val-Class-Acc: {0: '75.56%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.003142, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.170482, Val Acc: 97.18%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.002842, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.139760, Val Acc: 97.55%, Val-Class-Acc: {0: '93.08%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# Epoch 208/1000, Train Loss: 0.002218, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.166209, Val Acc: 97.22%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 209/1000, Train Loss: 0.002514, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.166212, Val Acc: 97.26%, Val-Class-Acc: {0: '87.98%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 210/1000, Train Loss: 0.002905, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.135964, Val Acc: 97.18%, Val-Class-Acc: {0: '94.70%', 1: '92.11%', 2: '100.00%'}, LR: 0.000100
# Epoch 211/1000, Train Loss: 0.004740, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.173285, Val Acc: 97.14%, Val-Class-Acc: {0: '90.63%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 212/1000, Train Loss: 0.003314, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.144358, Val Acc: 97.43%, Val-Class-Acc: {0: '91.85%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 213/1000, Train Loss: 0.002785, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.142500, Val Acc: 97.47%, Val-Class-Acc: {0: '92.06%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 214/1000, Train Loss: 0.003029, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.145056, Val Acc: 97.34%, Val-Class-Acc: {0: '95.32%', 1: '92.29%', 2: '100.00%'}, LR: 0.000100
# Epoch 215/1000, Train Loss: 0.002627, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.250663, Val Acc: 95.98%, Val-Class-Acc: {0: '80.86%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 216/1000, Train Loss: 0.002582, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# ...
# Val Loss: 0.144732, Val Acc: 97.34%, Val-Class-Acc: {0: '91.24%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 936/1000, Train Loss: 0.001966, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.161767, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.002414, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.181557, Val Acc: 95.64%, Val-Class-Acc: {0: '94.70%', 1: '85.15%', 2: '100.00%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.002796, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.213655, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.002158, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.169162, Val Acc: 96.97%, Val-Class-Acc: {0: '87.58%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.002289, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.149773, Val Acc: 97.47%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.001908, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.157426, Val Acc: 97.34%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.002099, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.172127, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.001924, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.155273, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.001934, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.145425, Val Acc: 97.34%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.002031, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.170914, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.002011, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.166573, Val Acc: 97.22%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.001760, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.159857, Val Acc: 97.34%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.001863, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.141616, Val Acc: 97.51%, Val-Class-Acc: {0: '91.85%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.002136, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.233216, Val Acc: 96.27%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.001784, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.154697, Val Acc: 97.55%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.001971, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.143205, Val Acc: 97.59%, Val-Class-Acc: {0: '94.30%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.007209, Train-Class-Acc: {0: '99.53%', 1: '99.64%', 2: '100.00%'},
# Val Loss: 0.134245, Val Acc: 97.34%, Val-Class-Acc: {0: '94.50%', 1: '93.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.003086, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.164988, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.002419, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.174422, Val Acc: 97.14%, Val-Class-Acc: {0: '88.39%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.001948, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.156149, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.002917, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.181063, Val Acc: 96.56%, Val-Class-Acc: {0: '85.74%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.002414, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.159104, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.001793, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.152206, Val Acc: 97.30%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.001877, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.139016, Val Acc: 97.47%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.001847, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.158370, Val Acc: 97.18%, Val-Class-Acc: {0: '89.00%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.001790, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.165500, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.001827, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.153392, Val Acc: 97.47%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.001674, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.159243, Val Acc: 97.18%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.001966, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.156442, Val Acc: 97.01%, Val-Class-Acc: {0: '87.37%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.001932, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.140722, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.002704, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.252208, Val Acc: 95.73%, Val-Class-Acc: {0: '80.45%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.001737, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.150158, Val Acc: 97.30%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.001830, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.155527, Val Acc: 97.05%, Val-Class-Acc: {0: '87.98%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.001901, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.97%'},
# Val Loss: 0.137268, Val Acc: 97.47%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.002784, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.149111, Val Acc: 97.26%, Val-Class-Acc: {0: '92.46%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.002040, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.154235, Val Acc: 97.22%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.002324, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.152703, Val Acc: 97.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.002067, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.288137, Val Acc: 95.48%, Val-Class-Acc: {0: '78.41%', 1: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.004628, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%'},
# Val Loss: 0.486321, Val Acc: 92.66%, Val-Class-Acc: {0: '63.95%', 1: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.003373, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.223588, Val Acc: 96.18%, Val-Class-Acc: {0: '82.69%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.004291, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.157714, Val Acc: 97.05%, Val-Class-Acc: {0: '89.82%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.002093, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.140412, Val Acc: 97.22%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.002033, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.132042, Val Acc: 97.43%, Val-Class-Acc: {0: '93.28%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.002041, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.149200, Val Acc: 97.18%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.001762, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.151465, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.001876, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.159914, Val Acc: 97.22%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.001778, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.151087, Val Acc: 97.30%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.001994, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.127435, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.002373, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.200078, Val Acc: 96.60%, Val-Class-Acc: {0: '84.93%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.001810, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.146321, Val Acc: 97.26%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.001704, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.170875, Val Acc: 97.10%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.002202, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.167144, Val Acc: 96.93%, Val-Class-Acc: {0: '86.76%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.001981, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.178287, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.002474, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.150657, Val Acc: 97.14%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.001957, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.178058, Val Acc: 96.80%, Val-Class-Acc: {0: '85.74%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.002074, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.129000, Val Acc: 97.51%, Val-Class-Acc: {0: '91.85%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.001798, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.133346, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.001688, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.129760, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.001990, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.122496, Val Acc: 97.59%, Val-Class-Acc: {0: '94.09%', 1: '94.55%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.002566, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.150819, Val Acc: 97.18%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.002827, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.422803, Val Acc: 93.24%, Val-Class-Acc: {0: '67.21%', 1: '99.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.003381, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%'},
# Val Loss: 0.153858, Val Acc: 97.39%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.002373, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.148048, Val Acc: 97.39%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.001860, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%'},
# Val Loss: 0.146050, Val Acc: 97.30%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.002142, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.169714, Val Acc: 97.05%, Val-Class-Acc: {0: '87.17%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 334.56 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_best.pth (Val Accuracy: 97.80%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 646, Train Loss: 0.002638, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.131659, Val Acc: 97.80%, Val-Acc: {0: '94.09%', 1: '95.49%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_646.pth
# Epoch 411, Train Loss: 0.003569, Train-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.137064, Val Acc: 97.80%, Val-Acc: {0: '93.69%', 1: '95.86%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_411.pth
# Epoch 129, Train Loss: 0.003477, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%'},
# Val Loss: 0.125659, Val Acc: 97.80%, Val-Acc: {0: '93.48%', 1: '96.05%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_129.pth
# Epoch 42, Train Loss: 0.006771, Train-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%'},
# Val Loss: 0.108983, Val Acc: 97.80%, Val-Acc: {0: '92.67%', 1: '96.80%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_42.pth
# Epoch 31, Train Loss: 0.009406, Train-Acc: {0: '99.77%', 1: '99.42%', 2: '100.00%'},
# Val Loss: 0.123480, Val Acc: 97.80%, Val-Acc: {0: '90.84%', 1: '98.50%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2/HAR_MLP_epoch_31.pth
# ---
# ### Period 2
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_2'*
# + ##### Best Epoch: 646
# #### __Val Accuracy: 97.80%__
# #### __Val-Class-Acc: {0: '94.09%', 1: '95.49%', 2: '100.00%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=3, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3
# + ##### Total training time: 387.41 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3'*
# + ##### Best Epoch: 949
# #### __Val Accuracy: 98.37%__
# #### __Val-Class-Acc: {0: '94.50%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}__

# %%
# ================================
# 📌 Period 3 Configuration
# ================================
period = 3

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_3")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 2 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_2", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 2 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[2]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[2]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 18 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_4114800/1376862386.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# Epoch 1/1000, Train Loss: 0.385065, Train-Class-Acc: {0: '53.73%', 1: '95.20%', 2: '98.72%', 3: '93.18%'},
# Val Loss: 0.173175, Val Acc: 96.78%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 2: '100.00%', 3: '93.67%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.100426, Train-Class-Acc: {0: '94.01%', 1: '98.84%', 2: '100.00%', 3: '99.08%'},
# Val Loss: 0.158755, Val Acc: 94.74%, Val-Class-Acc: {0: '74.34%', 1: '99.25%', 2: '100.00%', 3: '95.34%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.050937, Train-Class-Acc: {0: '97.51%', 1: '99.13%', 2: '99.97%', 3: '99.50%'},
# Val Loss: 0.109620, Val Acc: 96.44%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.029245, Train-Class-Acc: {0: '98.76%', 1: '99.64%', 2: '99.94%', 3: '99.72%'},
# Val Loss: 0.078626, Val Acc: 97.49%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.025508, Train-Class-Acc: {0: '98.99%', 1: '99.49%', 2: '100.00%', 3: '99.50%'},
# Val Loss: 0.076832, Val Acc: 97.83%, Val-Class-Acc: {0: '89.82%', 1: '98.31%', 2: '100.00%', 3: '99.07%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.018099, Train-Class-Acc: {0: '99.46%', 1: '99.64%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.080137, Val Acc: 97.90%, Val-Class-Acc: {0: '89.21%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.015882, Train-Class-Acc: {0: '99.14%', 1: '99.49%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.085023, Val Acc: 97.56%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.012585, Train-Class-Acc: {0: '99.38%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.083529, Val Acc: 97.79%, Val-Class-Acc: {0: '89.21%', 1: '98.50%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.011120, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072884, Val Acc: 97.83%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.011891, Train-Class-Acc: {0: '99.38%', 1: '99.71%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.090572, Val Acc: 97.42%, Val-Class-Acc: {0: '85.74%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 11/1000, Train Loss: 0.009780, Train-Class-Acc: {0: '99.46%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.072995, Val Acc: 97.93%, Val-Class-Acc: {0: '94.50%', 1: '93.61%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.009382, Train-Class-Acc: {0: '99.46%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.087578, Val Acc: 97.73%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 13/1000, Train Loss: 0.007549, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.072114, Val Acc: 97.96%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.006857, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.075464, Val Acc: 98.10%, Val-Class-Acc: {0: '91.65%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.006916, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.082173, Val Acc: 97.62%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.006191, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.077194, Val Acc: 98.00%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.005365, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.095463, Val Acc: 97.52%, Val-Class-Acc: {0: '86.76%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.006731, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.079405, Val Acc: 97.83%, Val-Class-Acc: {0: '95.52%', 1: '92.11%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.006031, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.078159, Val Acc: 98.17%, Val-Class-Acc: {0: '92.26%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.005741, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.146779, Val Acc: 96.47%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.006452, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.084485, Val Acc: 97.62%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.004868, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.081626, Val Acc: 98.07%, Val-Class-Acc: {0: '95.11%', 1: '93.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.004776, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.076548, Val Acc: 98.27%, Val-Class-Acc: {0: '93.28%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.004876, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.082438, Val Acc: 98.17%, Val-Class-Acc: {0: '91.24%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.004082, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083241, Val Acc: 98.07%, Val-Class-Acc: {0: '91.45%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.004649, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.158340, Val Acc: 96.64%, Val-Class-Acc: {0: '80.45%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.004215, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.081829, Val Acc: 98.03%, Val-Class-Acc: {0: '92.87%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.004140, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.97%', 3: '99.93%'},
# Val Loss: 0.098506, Val Acc: 97.49%, Val-Class-Acc: {0: '86.97%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.003869, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.086435, Val Acc: 98.07%, Val-Class-Acc: {0: '91.04%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.003557, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.085934, Val Acc: 98.03%, Val-Class-Acc: {0: '90.84%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.003630, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.078408, Val Acc: 98.34%, Val-Class-Acc: {0: '94.50%', 1: '95.86%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.003936, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.098057, Val Acc: 97.59%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.005098, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.080287, Val Acc: 97.73%, Val-Class-Acc: {0: '94.09%', 1: '92.86%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.003291, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.091676, Val Acc: 98.00%, Val-Class-Acc: {0: '91.45%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.003170, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.087476, Val Acc: 98.10%, Val-Class-Acc: {0: '91.65%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.003221, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102772, Val Acc: 97.73%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.003804, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.079881, Val Acc: 98.27%, Val-Class-Acc: {0: '94.50%', 1: '95.49%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.002822, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.086811, Val Acc: 98.00%, Val-Class-Acc: {0: '94.09%', 1: '94.36%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.004602, Train-Class-Acc: {0: '99.61%', 1: '99.71%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.111361, Val Acc: 97.86%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.003169, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.134879, Val Acc: 96.64%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.003527, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.224229, Val Acc: 96.03%, Val-Class-Acc: {0: '77.19%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.003158, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.131521, Val Acc: 97.46%, Val-Class-Acc: {0: '85.95%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.002749, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.131649, Val Acc: 97.39%, Val-Class-Acc: {0: '85.54%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.002704, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.088536, Val Acc: 98.07%, Val-Class-Acc: {0: '92.06%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.002900, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.091963, Val Acc: 98.07%, Val-Class-Acc: {0: '94.91%', 1: '93.98%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.003319, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.092596, Val Acc: 98.17%, Val-Class-Acc: {0: '91.24%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.002086, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100846, Val Acc: 97.93%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.003418, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.111080, Val Acc: 97.69%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.003468, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.099250, Val Acc: 97.86%, Val-Class-Acc: {0: '94.50%', 1: '93.23%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.002810, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.104793, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.002849, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.135721, Val Acc: 96.74%, Val-Class-Acc: {0: '96.13%', 1: '85.53%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.002409, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.096037, Val Acc: 98.07%, Val-Class-Acc: {0: '91.45%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.001888, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.092921, Val Acc: 98.10%, Val-Class-Acc: {0: '91.45%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.002203, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113766, Val Acc: 97.83%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.002519, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.093274, Val Acc: 97.86%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.002221, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.112571, Val Acc: 97.69%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.003030, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.096901, Val Acc: 97.86%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.002513, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.111716, Val Acc: 97.73%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.001707, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.096352, Val Acc: 98.13%, Val-Class-Acc: {0: '92.46%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.002105, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115109, Val Acc: 97.56%, Val-Class-Acc: {0: '87.37%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.004039, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.092456, Val Acc: 97.90%, Val-Class-Acc: {0: '92.67%', 1: '95.11%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.002335, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.099264, Val Acc: 98.07%, Val-Class-Acc: {0: '92.06%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.001917, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.124660, Val Acc: 97.62%, Val-Class-Acc: {0: '87.37%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.002377, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.093652, Val Acc: 98.03%, Val-Class-Acc: {0: '93.08%', 1: '95.49%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.001750, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.118674, Val Acc: 97.52%, Val-Class-Acc: {0: '86.76%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.001751, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114801, Val Acc: 97.69%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.001701, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.126099, Val Acc: 97.42%, Val-Class-Acc: {0: '86.15%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.002093, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.108024, Val Acc: 97.86%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.001490, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103894, Val Acc: 98.00%, Val-Class-Acc: {0: '89.82%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.001828, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114774, Val Acc: 97.73%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.001464, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.104050, Val Acc: 97.79%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.001547, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.096560, Val Acc: 98.00%, Val-Class-Acc: {0: '93.28%', 1: '95.11%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.002435, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.216511, Val Acc: 95.52%, Val-Class-Acc: {0: '73.93%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.002093, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.106311, Val Acc: 97.93%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.001720, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103087, Val Acc: 98.03%, Val-Class-Acc: {0: '91.04%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.001676, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.131591, Val Acc: 97.39%, Val-Class-Acc: {0: '85.95%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.002190, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.518892, Val Acc: 90.80%, Val-Class-Acc: {0: '46.03%', 1: '100.00%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.003879, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105032, Val Acc: 97.83%, Val-Class-Acc: {0: '94.30%', 1: '93.23%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.001776, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112683, Val Acc: 97.69%, Val-Class-Acc: {0: '89.00%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.003339, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103358, Val Acc: 98.03%, Val-Class-Acc: {0: '92.87%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.003462, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.147600, Val Acc: 97.29%, Val-Class-Acc: {0: '84.93%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.001912, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110742, Val Acc: 97.83%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.001923, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.099925, Val Acc: 98.03%, Val-Class-Acc: {0: '90.22%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.001559, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.108403, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.001409, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102582, Val Acc: 98.10%, Val-Class-Acc: {0: '91.04%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.002072, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.106266, Val Acc: 97.96%, Val-Class-Acc: {0: '94.70%', 1: '93.61%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.002136, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.096921, Val Acc: 98.13%, Val-Class-Acc: {0: '93.28%', 1: '95.86%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.001506, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.132806, Val Acc: 97.46%, Val-Class-Acc: {0: '86.15%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.001373, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.101331, Val Acc: 97.96%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.001307, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103855, Val Acc: 97.93%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.001519, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113711, Val Acc: 97.76%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.002009, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103090, Val Acc: 97.90%, Val-Class-Acc: {0: '95.72%', 1: '92.29%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.001603, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.083440, Val Acc: 98.13%, Val-Class-Acc: {0: '92.87%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.001258, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.099873, Val Acc: 98.07%, Val-Class-Acc: {0: '90.84%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.001351, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105554, Val Acc: 98.13%, Val-Class-Acc: {0: '91.45%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.001600, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.091111, Val Acc: 98.20%, Val-Class-Acc: {0: '93.28%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_96.pth
# Epoch 97/1000, Train Loss: 0.001185, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.107785, Val Acc: 97.86%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.001612, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.104393, Val Acc: 97.90%, Val-Class-Acc: {0: '89.21%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.001572, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.097542, Val Acc: 98.37%, Val-Class-Acc: {0: '92.87%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_99.pth
# Epoch 100/1000, Train Loss: 0.001336, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113701, Val Acc: 97.86%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.001850, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.119895, Val Acc: 97.90%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.002467, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120268, Val Acc: 97.62%, Val-Class-Acc: {0: '95.72%', 1: '90.79%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.001743, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.097259, Val Acc: 98.17%, Val-Class-Acc: {0: '93.08%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.001863, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.233925, Val Acc: 95.69%, Val-Class-Acc: {0: '74.95%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.001794, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.098933, Val Acc: 98.13%, Val-Class-Acc: {0: '91.65%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.002353, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105174, Val Acc: 97.90%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.001263, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100057, Val Acc: 98.13%, Val-Class-Acc: {0: '92.06%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.001519, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102818, Val Acc: 98.10%, Val-Class-Acc: {0: '91.24%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.002327, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115851, Val Acc: 98.00%, Val-Class-Acc: {0: '92.87%', 1: '95.49%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.004386, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.128326, Val Acc: 97.73%, Val-Class-Acc: {0: '89.21%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.002433, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112000, Val Acc: 97.93%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.001780, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.154181, Val Acc: 97.08%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.001730, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109977, Val Acc: 97.86%, Val-Class-Acc: {0: '95.11%', 1: '92.67%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.002523, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.86%'},
# Val Loss: 0.301945, Val Acc: 95.08%, Val-Class-Acc: {0: '70.88%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.001756, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.107699, Val Acc: 98.00%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.001442, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110716, Val Acc: 98.00%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.001300, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120639, Val Acc: 97.76%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.001292, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.118060, Val Acc: 97.66%, Val-Class-Acc: {0: '89.00%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.001192, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.117470, Val Acc: 97.76%, Val-Class-Acc: {0: '89.21%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.001236, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120463, Val Acc: 97.59%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.001352, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.125126, Val Acc: 97.39%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.001250, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109427, Val Acc: 97.90%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.001237, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.135766, Val Acc: 97.25%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.001351, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100371, Val Acc: 98.10%, Val-Class-Acc: {0: '94.09%', 1: '94.92%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.001208, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.132889, Val Acc: 97.46%, Val-Class-Acc: {0: '86.56%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.001320, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.116493, Val Acc: 97.76%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.001272, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.098968, Val Acc: 98.24%, Val-Class-Acc: {0: '93.28%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_96.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_127.pth
# Epoch 128/1000, Train Loss: 0.001407, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.107548, Val Acc: 98.13%, Val-Class-Acc: {0: '91.24%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.001986, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.125796, Val Acc: 97.49%, Val-Class-Acc: {0: '86.97%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.002811, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.099601, Val Acc: 98.07%, Val-Class-Acc: {0: '93.08%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.002335, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103311, Val Acc: 98.13%, Val-Class-Acc: {0: '92.26%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.002344, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.136779, Val Acc: 97.35%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.002789, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.118835, Val Acc: 97.93%, Val-Class-Acc: {0: '89.61%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.001717, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.137097, Val Acc: 97.73%, Val-Class-Acc: {0: '87.58%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.001324, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102527, Val Acc: 98.07%, Val-Class-Acc: {0: '90.63%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.001677, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.158594, Val Acc: 97.46%, Val-Class-Acc: {0: '86.35%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.001336, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.116352, Val Acc: 97.76%, Val-Class-Acc: {0: '89.21%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.001283, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103373, Val Acc: 98.27%, Val-Class-Acc: {0: '93.48%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_127.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_138.pth
# Epoch 139/1000, Train Loss: 0.001238, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105542, Val Acc: 98.24%, Val-Class-Acc: {0: '94.09%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.001274, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102808, Val Acc: 98.17%, Val-Class-Acc: {0: '91.85%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.001397, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110941, Val Acc: 98.00%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.001201, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.130134, Val Acc: 97.59%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.001094, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120523, Val Acc: 97.90%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.001108, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.108798, Val Acc: 97.96%, Val-Class-Acc: {0: '92.46%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.001118, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.139149, Val Acc: 97.59%, Val-Class-Acc: {0: '87.17%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.001055, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120435, Val Acc: 97.69%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.001413, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109538, Val Acc: 97.96%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.001470, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.094677, Val Acc: 98.03%, Val-Class-Acc: {0: '91.65%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.001297, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109652, Val Acc: 98.13%, Val-Class-Acc: {0: '91.45%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.002462, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100837, Val Acc: 98.10%, Val-Class-Acc: {0: '91.65%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.001967, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.123529, Val Acc: 97.83%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.001630, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.123196, Val Acc: 97.52%, Val-Class-Acc: {0: '86.76%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.002455, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.098059, Val Acc: 98.10%, Val-Class-Acc: {0: '93.89%', 1: '95.11%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.001492, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.147883, Val Acc: 97.05%, Val-Class-Acc: {0: '84.32%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.002991, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.116425, Val Acc: 97.83%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.001809, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114190, Val Acc: 97.79%, Val-Class-Acc: {0: '95.11%', 1: '92.29%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.001173, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114511, Val Acc: 97.96%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.001139, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115185, Val Acc: 97.90%, Val-Class-Acc: {0: '89.41%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.001305, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.122454, Val Acc: 97.62%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.001425, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.174333, Val Acc: 96.95%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.001281, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.145416, Val Acc: 97.35%, Val-Class-Acc: {0: '85.54%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.001188, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114723, Val Acc: 97.90%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.001135, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.103970, Val Acc: 98.00%, Val-Class-Acc: {0: '92.67%', 1: '95.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.001143, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.104731, Val Acc: 98.00%, Val-Class-Acc: {0: '91.85%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.001228, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109404, Val Acc: 97.93%, Val-Class-Acc: {0: '90.22%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.001104, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110617, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.001217, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.123622, Val Acc: 97.73%, Val-Class-Acc: {0: '87.98%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.001155, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102457, Val Acc: 98.03%, Val-Class-Acc: {0: '93.89%', 1: '94.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.001072, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.106928, Val Acc: 98.10%, Val-Class-Acc: {0: '92.46%', 1: '96.43%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.001040, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.101345, Val Acc: 98.24%, Val-Class-Acc: {0: '92.46%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.001653, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.155096, Val Acc: 97.18%, Val-Class-Acc: {0: '84.11%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.001126, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120985, Val Acc: 97.83%, Val-Class-Acc: {0: '88.80%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.002564, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.141803, Val Acc: 97.66%, Val-Class-Acc: {0: '88.19%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.001449, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.108437, Val Acc: 98.00%, Val-Class-Acc: {0: '92.06%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.001305, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112241, Val Acc: 98.10%, Val-Class-Acc: {0: '94.91%', 1: '94.17%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.001423, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.137805, Val Acc: 97.49%, Val-Class-Acc: {0: '86.56%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.001235, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109889, Val Acc: 97.86%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.001529, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.097805, Val Acc: 98.13%, Val-Class-Acc: {0: '92.87%', 1: '96.24%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.001580, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.107006, Val Acc: 98.00%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.001216, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.098807, Val Acc: 98.00%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.001378, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.098224, Val Acc: 98.27%, Val-Class-Acc: {0: '95.11%', 1: '94.92%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.001427, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.134087, Val Acc: 97.52%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.001275, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113346, Val Acc: 97.86%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.001117, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# ...
# Epoch 945/1000, Train Loss: 0.001100, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.183205, Val Acc: 96.54%, Val-Class-Acc: {0: '81.06%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.001011, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.122962, Val Acc: 98.03%, Val-Class-Acc: {0: '90.63%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.000993, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.147396, Val Acc: 97.66%, Val-Class-Acc: {0: '87.78%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.001376, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112218, Val Acc: 97.96%, Val-Class-Acc: {0: '94.91%', 1: '93.42%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.001579, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.095504, Val Acc: 98.37%, Val-Class-Acc: {0: '94.50%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_565.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_949.pth
# Epoch 950/1000, Train Loss: 0.001187, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105224, Val Acc: 97.96%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.001904, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112649, Val Acc: 98.13%, Val-Class-Acc: {0: '94.50%', 1: '94.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.001216, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.126981, Val Acc: 97.83%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.001036, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121723, Val Acc: 97.96%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.000968, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.118465, Val Acc: 97.96%, Val-Class-Acc: {0: '91.24%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.001436, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112559, Val Acc: 98.07%, Val-Class-Acc: {0: '91.85%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.001682, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112899, Val Acc: 98.13%, Val-Class-Acc: {0: '91.65%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.001029, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121182, Val Acc: 97.90%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.001402, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.247837, Val Acc: 95.66%, Val-Class-Acc: {0: '74.75%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.001137, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110114, Val Acc: 98.13%, Val-Class-Acc: {0: '91.85%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.000969, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112488, Val Acc: 98.00%, Val-Class-Acc: {0: '90.22%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.002049, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100817, Val Acc: 98.20%, Val-Class-Acc: {0: '91.45%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.001404, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.122311, Val Acc: 97.96%, Val-Class-Acc: {0: '89.82%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.001917, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.171673, Val Acc: 96.84%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.001301, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113032, Val Acc: 98.03%, Val-Class-Acc: {0: '91.24%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.000990, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.127352, Val Acc: 97.76%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.001102, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114803, Val Acc: 97.76%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.001526, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.133314, Val Acc: 97.49%, Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.001074, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.109360, Val Acc: 98.13%, Val-Class-Acc: {0: '92.26%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.001124, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.118898, Val Acc: 97.83%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.000989, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.125655, Val Acc: 97.69%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.001161, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.102341, Val Acc: 98.20%, Val-Class-Acc: {0: '92.46%', 1: '96.99%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.001441, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.181960, Val Acc: 96.50%, Val-Class-Acc: {0: '80.24%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.001238, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121940, Val Acc: 97.79%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.001002, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121823, Val Acc: 97.96%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.000936, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.116420, Val Acc: 97.93%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.000978, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.147279, Val Acc: 97.25%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.001043, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.135720, Val Acc: 97.62%, Val-Class-Acc: {0: '87.37%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.001221, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121715, Val Acc: 97.76%, Val-Class-Acc: {0: '94.70%', 1: '92.48%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.001588, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.144939, Val Acc: 97.56%, Val-Class-Acc: {0: '87.58%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.001664, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.161521, Val Acc: 96.88%, Val-Class-Acc: {0: '83.50%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.003025, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.134365, Val Acc: 97.59%, Val-Class-Acc: {0: '87.98%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.001293, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.176708, Val Acc: 96.71%, Val-Class-Acc: {0: '81.67%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.001861, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113908, Val Acc: 98.17%, Val-Class-Acc: {0: '92.67%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.001361, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.149720, Val Acc: 97.12%, Val-Class-Acc: {0: '85.13%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.001299, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.116349, Val Acc: 97.86%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.001511, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.131042, Val Acc: 97.52%, Val-Class-Acc: {0: '93.69%', 1: '92.11%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.001204, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.123283, Val Acc: 97.83%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.001691, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.114509, Val Acc: 98.17%, Val-Class-Acc: {0: '93.28%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.002287, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115570, Val Acc: 98.00%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.001618, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113471, Val Acc: 98.07%, Val-Class-Acc: {0: '92.67%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.001221, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115808, Val Acc: 98.03%, Val-Class-Acc: {0: '91.04%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.001064, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.124547, Val Acc: 97.76%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.001234, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113203, Val Acc: 98.07%, Val-Class-Acc: {0: '94.09%', 1: '94.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.001136, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.115201, Val Acc: 98.03%, Val-Class-Acc: {0: '92.46%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.000965, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.120527, Val Acc: 97.96%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.001334, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110643, Val Acc: 97.93%, Val-Class-Acc: {0: '91.24%', 1: '96.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.001043, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.122083, Val Acc: 97.86%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.001040, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.113675, Val Acc: 97.93%, Val-Class-Acc: {0: '91.04%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.000979, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.130763, Val Acc: 97.73%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.000962, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.132384, Val Acc: 97.69%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 387.41 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_best.pth (Val Accuracy: 98.37%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 949, Train Loss: 0.001579, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.095504, Val Acc: 98.37%, Val-Acc: {0: '94.50%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_949.pth
# Epoch 624, Train Loss: 0.001130, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.105982, Val Acc: 98.37%, Val-Acc: {0: '92.46%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_624.pth
# Epoch 617, Train Loss: 0.001189, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.107724, Val Acc: 98.37%, Val-Acc: {0: '92.46%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_617.pth
# Epoch 208, Train Loss: 0.001545, Train-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.100731, Val Acc: 98.37%, Val-Acc: {0: '93.69%', 1: '96.80%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_208.pth
# Epoch 99, Train Loss: 0.001572, Train-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.097542, Val Acc: 98.37%, Val-Acc: {0: '92.87%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3/HAR_MLP_epoch_99.pth
# ---
# ### Period 3
# + ##### Total training time: 387.41 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_3'*
# + ##### Best Epoch: 949
# #### __Val Accuracy: 98.37%__
# #### __Val-Class-Acc: {0: '94.50%', 1: '96.05%', 2: '100.00%', 3: '100.00%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4
# + ##### Total training time: 848.43 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4'*
# + ##### Best Epoch: 352
# #### __Val Accuracy: 97.49%__
# #### __Val-Class-Acc: {0: '93.69%', 1: '96.05%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '98.33%'}__

# %%
# ================================
# 📌 Period 4 Configuration
# ================================
period = 4

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_4")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 3 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_3", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 3 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[3]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[3]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 18 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_4114800/2633862097.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# Epoch 1/1000, Train Loss: 0.751578, Train-Class-Acc: {0: '58.48%', 1: '83.92%', 2: '77.73%', 3: '95.45%', 4: '50.33%', 5: '71.50%'},
# Val Loss: 0.245227, Val Acc: 93.62%, Val-Class-Acc: {0: '79.43%', 1: '99.06%', 2: '97.98%', 3: '100.00%', 4: '94.48%', 5: '89.05%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.160186, Train-Class-Acc: {0: '96.89%', 1: '98.62%', 2: '95.19%', 3: '99.93%', 4: '91.71%', 5: '93.81%'},
# Val Loss: 0.172514, Val Acc: 94.60%, Val-Class-Acc: {0: '93.48%', 1: '95.86%', 2: '99.19%', 3: '100.00%', 4: '90.45%', 5: '86.67%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.105326, Train-Class-Acc: {0: '97.67%', 1: '99.05%', 2: '96.17%', 3: '99.93%', 4: '95.90%', 5: '95.23%'},
# Val Loss: 0.154288, Val Acc: 94.81%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '91.72%', 5: '89.29%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.067717, Train-Class-Acc: {0: '98.76%', 1: '99.42%', 2: '98.53%', 3: '99.79%', 4: '96.27%', 5: '98.88%'},
# Val Loss: 0.127230, Val Acc: 96.27%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 2: '98.59%', 3: '100.00%', 4: '97.45%', 5: '94.29%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.055692, Train-Class-Acc: {0: '98.99%', 1: '99.27%', 2: '98.53%', 3: '100.00%', 4: '97.58%', 5: '97.87%'},
# Val Loss: 0.115250, Val Acc: 96.37%, Val-Class-Acc: {0: '93.48%', 1: '94.74%', 2: '99.40%', 3: '100.00%', 4: '96.18%', 5: '93.81%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.041016, Train-Class-Acc: {0: '99.22%', 1: '99.49%', 2: '98.86%', 3: '99.93%', 4: '98.70%', 5: '98.78%'},
# Val Loss: 0.126701, Val Acc: 96.34%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '99.19%', 3: '100.00%', 4: '98.51%', 5: '96.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.036715, Train-Class-Acc: {0: '99.38%', 1: '99.64%', 2: '98.94%', 3: '100.00%', 4: '98.60%', 5: '98.58%'},
# Val Loss: 0.119369, Val Acc: 96.00%, Val-Class-Acc: {0: '87.98%', 1: '97.37%', 2: '98.59%', 3: '100.00%', 4: '98.30%', 5: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.028921, Train-Class-Acc: {0: '99.38%', 1: '99.56%', 2: '99.67%', 3: '100.00%', 4: '99.16%', 5: '99.59%'},
# Val Loss: 0.146529, Val Acc: 94.74%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '89.17%', 5: '93.57%'}, LR: 0.000100
# Epoch 9/1000, Train Loss: 0.029028, Train-Class-Acc: {0: '99.53%', 1: '99.64%', 2: '99.35%', 3: '100.00%', 4: '98.70%', 5: '99.19%'},
# Val Loss: 0.138480, Val Acc: 95.39%, Val-Class-Acc: {0: '91.65%', 1: '96.80%', 2: '99.80%', 3: '100.00%', 4: '94.06%', 5: '88.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.028602, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '99.10%', 3: '99.86%', 4: '99.25%', 5: '99.29%'},
# Val Loss: 0.130644, Val Acc: 96.10%, Val-Class-Acc: {0: '86.15%', 1: '98.50%', 2: '96.37%', 3: '100.00%', 4: '97.88%', 5: '97.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.023649, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '99.43%', 3: '100.00%', 4: '99.25%', 5: '99.29%'},
# Val Loss: 0.120043, Val Acc: 96.30%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '99.19%', 3: '100.00%', 4: '97.66%', 5: '94.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.024955, Train-Class-Acc: {0: '99.61%', 1: '99.78%', 2: '99.43%', 3: '99.64%', 4: '99.25%', 5: '99.39%'},
# Val Loss: 0.111561, Val Acc: 96.78%, Val-Class-Acc: {0: '93.08%', 1: '95.68%', 2: '99.19%', 3: '100.00%', 4: '95.12%', 5: '97.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.021602, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.59%', 3: '99.93%', 4: '99.25%', 5: '99.39%'},
# Val Loss: 0.103851, Val Acc: 96.81%, Val-Class-Acc: {0: '90.84%', 1: '95.86%', 2: '98.79%', 3: '100.00%', 4: '98.30%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.019924, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '99.51%', 3: '99.93%', 4: '99.63%', 5: '99.39%'},
# Val Loss: 0.127464, Val Acc: 96.10%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '95.97%', 5: '94.76%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.019214, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '99.51%', 3: '99.93%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.131874, Val Acc: 96.03%, Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '99.80%', 3: '100.00%', 4: '92.99%', 5: '97.86%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.016166, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.128584, Val Acc: 96.06%, Val-Class-Acc: {0: '88.39%', 1: '96.99%', 2: '99.19%', 3: '100.00%', 4: '94.90%', 5: '96.43%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.015099, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.67%', 3: '99.93%', 4: '99.81%', 5: '99.59%'},
# Val Loss: 0.155937, Val Acc: 95.01%, Val-Class-Acc: {0: '94.70%', 1: '92.11%', 2: '99.40%', 3: '100.00%', 4: '91.51%', 5: '91.43%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.016439, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '99.35%', 3: '100.00%', 4: '100.00%', 5: '99.49%'},
# Val Loss: 0.122600, Val Acc: 96.30%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '95.97%', 3: '100.00%', 4: '95.75%', 5: '98.33%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.014278, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '99.67%', 3: '100.00%', 4: '99.72%', 5: '99.59%'},
# Val Loss: 0.137145, Val Acc: 96.03%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '98.39%', 3: '100.00%', 4: '97.45%', 5: '96.43%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.014699, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.76%', 3: '99.79%', 4: '99.81%', 5: '99.59%'},
# Val Loss: 0.139331, Val Acc: 95.86%, Val-Class-Acc: {0: '88.39%', 1: '97.74%', 2: '98.99%', 3: '100.00%', 4: '96.82%', 5: '92.14%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.013873, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.76%', 3: '99.93%', 4: '99.63%', 5: '99.70%'},
# Val Loss: 0.130312, Val Acc: 96.17%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 2: '98.99%', 3: '100.00%', 4: '92.99%', 5: '96.67%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.011082, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.147263, Val Acc: 95.83%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '98.79%', 3: '100.00%', 4: '97.66%', 5: '94.05%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.012636, Train-Class-Acc: {0: '99.77%', 1: '100.00%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.59%'},
# Val Loss: 0.197537, Val Acc: 94.33%, Val-Class-Acc: {0: '93.08%', 1: '95.49%', 2: '99.80%', 3: '100.00%', 4: '83.44%', 5: '92.86%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.013431, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '99.51%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.144083, Val Acc: 96.10%, Val-Class-Acc: {0: '86.35%', 1: '98.31%', 2: '98.99%', 3: '100.00%', 4: '95.75%', 5: '96.67%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.012760, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '99.84%', 3: '100.00%', 4: '99.35%', 5: '99.59%'},
# Val Loss: 0.136827, Val Acc: 96.20%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 2: '99.60%', 3: '100.00%', 4: '91.30%', 5: '98.33%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.010662, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '99.84%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.142336, Val Acc: 95.93%, Val-Class-Acc: {0: '95.72%', 1: '92.48%', 2: '99.19%', 3: '100.00%', 4: '93.63%', 5: '94.05%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.010692, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.129749, Val Acc: 96.37%, Val-Class-Acc: {0: '91.85%', 1: '96.62%', 2: '99.80%', 3: '100.00%', 4: '92.57%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.011510, Train-Class-Acc: {0: '99.53%', 1: '99.78%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.130933, Val Acc: 96.13%, Val-Class-Acc: {0: '91.85%', 1: '97.56%', 2: '100.00%', 3: '100.00%', 4: '92.14%', 5: '94.29%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.010784, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.139648, Val Acc: 96.17%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '93.42%', 5: '97.14%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.010580, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.84%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.119931, Val Acc: 96.84%, Val-Class-Acc: {0: '91.45%', 1: '97.18%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '97.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.011258, Train-Class-Acc: {0: '99.77%', 1: '99.64%', 2: '99.92%', 3: '100.00%', 4: '99.63%', 5: '99.90%'},
# Val Loss: 0.151079, Val Acc: 95.69%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '94.76%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.008610, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.122633, Val Acc: 96.61%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 2: '99.60%', 3: '100.00%', 4: '95.54%', 5: '97.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.010985, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.72%', 5: '99.70%'},
# Val Loss: 0.145801, Val Acc: 96.17%, Val-Class-Acc: {0: '93.08%', 1: '96.05%', 2: '99.60%', 3: '100.00%', 4: '97.03%', 5: '90.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.007848, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.203853, Val Acc: 95.18%, Val-Class-Acc: {0: '84.52%', 1: '98.68%', 2: '97.58%', 3: '100.00%', 4: '91.30%', 5: '98.57%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.010023, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.221215, Val Acc: 94.23%, Val-Class-Acc: {0: '74.75%', 1: '98.87%', 2: '99.40%', 3: '100.00%', 4: '95.97%', 5: '95.71%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.011240, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '99.76%', 3: '100.00%', 4: '99.63%', 5: '99.90%'},
# Val Loss: 0.207889, Val Acc: 94.54%, Val-Class-Acc: {0: '76.78%', 1: '98.87%', 2: '99.19%', 3: '100.00%', 4: '95.12%', 5: '96.67%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.008344, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.154093, Val Acc: 95.86%, Val-Class-Acc: {0: '92.46%', 1: '96.43%', 2: '99.60%', 3: '100.00%', 4: '91.93%', 5: '93.81%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.008672, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.76%', 3: '100.00%', 4: '99.81%', 5: '99.70%'},
# Val Loss: 0.184219, Val Acc: 95.32%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '99.40%', 3: '100.00%', 4: '87.90%', 5: '98.57%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.009833, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.67%', 3: '100.00%', 4: '99.72%', 5: '99.70%'},
# Val Loss: 0.167563, Val Acc: 95.49%, Val-Class-Acc: {0: '86.15%', 1: '98.31%', 2: '99.60%', 3: '100.00%', 4: '94.06%', 5: '93.81%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.009087, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.76%', 3: '99.93%', 4: '99.72%', 5: '99.80%'},
# Val Loss: 0.138013, Val Acc: 96.50%, Val-Class-Acc: {0: '92.26%', 1: '95.86%', 2: '98.59%', 3: '100.00%', 4: '96.82%', 5: '95.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.007087, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.154705, Val Acc: 96.27%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '99.40%', 3: '100.00%', 4: '94.69%', 5: '97.38%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.008631, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.63%', 5: '99.90%'},
# Val Loss: 0.147070, Val Acc: 96.54%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '98.79%', 3: '100.00%', 4: '98.09%', 5: '96.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.007826, Train-Class-Acc: {0: '99.69%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.182897, Val Acc: 95.79%, Val-Class-Acc: {0: '85.74%', 1: '97.74%', 2: '97.98%', 3: '99.81%', 4: '94.90%', 5: '98.33%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.009274, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.180459, Val Acc: 95.52%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 2: '99.19%', 3: '99.81%', 4: '93.21%', 5: '93.57%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.007218, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.144680, Val Acc: 96.57%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 2: '98.59%', 3: '100.00%', 4: '95.33%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.007207, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.153673, Val Acc: 95.93%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '97.58%', 3: '100.00%', 4: '95.54%', 5: '94.52%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.006582, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.157036, Val Acc: 96.10%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '94.06%', 5: '97.62%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.008584, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.250641, Val Acc: 94.71%, Val-Class-Acc: {0: '76.99%', 1: '99.62%', 2: '99.60%', 3: '99.81%', 4: '94.69%', 5: '96.90%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.011513, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.67%', 3: '100.00%', 4: '99.91%', 5: '99.70%'},
# Val Loss: 0.178642, Val Acc: 95.79%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '97.98%', 3: '100.00%', 4: '94.27%', 5: '97.86%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.007666, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.145622, Val Acc: 96.50%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 2: '97.78%', 3: '100.00%', 4: '96.18%', 5: '96.43%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.009935, Train-Class-Acc: {0: '99.61%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.159633, Val Acc: 96.27%, Val-Class-Acc: {0: '95.32%', 1: '92.29%', 2: '99.80%', 3: '100.00%', 4: '93.84%', 5: '96.19%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.009391, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.140945, Val Acc: 96.88%, Val-Class-Acc: {0: '94.91%', 1: '93.80%', 2: '98.59%', 3: '100.00%', 4: '96.82%', 5: '97.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_45.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.005822, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.170704, Val Acc: 96.06%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 2: '99.19%', 3: '100.00%', 4: '92.57%', 5: '97.62%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.005952, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.166298, Val Acc: 96.13%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '94.06%', 5: '96.67%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.006481, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.191987, Val Acc: 95.79%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '91.51%', 5: '96.67%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.006626, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.166051, Val Acc: 95.93%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 2: '98.99%', 3: '100.00%', 4: '94.06%', 5: '95.24%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.007091, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.156534, Val Acc: 96.30%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '94.29%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.006296, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.155920, Val Acc: 96.10%, Val-Class-Acc: {0: '91.65%', 1: '96.43%', 2: '99.80%', 3: '100.00%', 4: '92.99%', 5: '95.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.005546, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.174395, Val Acc: 95.89%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '99.80%', 3: '100.00%', 4: '91.30%', 5: '96.19%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.008470, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '99.84%', 3: '100.00%', 4: '99.72%', 5: '99.90%'},
# Val Loss: 0.153610, Val Acc: 96.34%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '99.19%', 3: '100.00%', 4: '93.84%', 5: '98.81%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.007483, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.76%', 3: '100.00%', 4: '99.63%', 5: '99.90%'},
# Val Loss: 0.310149, Val Acc: 93.82%, Val-Class-Acc: {0: '70.67%', 1: '99.81%', 2: '98.99%', 3: '100.00%', 4: '95.12%', 5: '97.86%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.008325, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.142478, Val Acc: 96.61%, Val-Class-Acc: {0: '92.26%', 1: '95.86%', 2: '99.40%', 3: '100.00%', 4: '93.84%', 5: '98.10%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.005515, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.158559, Val Acc: 96.40%, Val-Class-Acc: {0: '93.08%', 1: '95.86%', 2: '99.60%', 3: '100.00%', 4: '91.51%', 5: '98.10%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.007138, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.175221, Val Acc: 95.96%, Val-Class-Acc: {0: '87.78%', 1: '98.50%', 2: '99.80%', 3: '100.00%', 4: '93.21%', 5: '95.71%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.005963, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.156376, Val Acc: 96.57%, Val-Class-Acc: {0: '93.48%', 1: '94.92%', 2: '99.60%', 3: '100.00%', 4: '93.42%', 5: '97.86%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.008077, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.67%', 3: '100.00%', 4: '99.81%', 5: '99.70%'},
# Val Loss: 0.142177, Val Acc: 96.47%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 2: '99.80%', 3: '100.00%', 4: '96.82%', 5: '94.29%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.006238, Train-Class-Acc: {0: '100.00%', 1: '99.78%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.160150, Val Acc: 95.86%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '95.75%', 5: '95.24%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.005906, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.166415, Val Acc: 95.96%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '93.63%', 5: '95.48%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.005833, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.142265, Val Acc: 96.67%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '99.60%', 3: '100.00%', 4: '95.12%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_69.pth
# Epoch 70/1000, Train Loss: 0.008435, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.72%', 5: '99.70%'},
# Val Loss: 0.129256, Val Acc: 97.05%, Val-Class-Acc: {0: '95.52%', 1: '93.42%', 2: '98.59%', 3: '100.00%', 4: '96.60%', 5: '98.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_69.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_70.pth
# Epoch 71/1000, Train Loss: 0.005863, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.181552, Val Acc: 96.03%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%', 3: '100.00%', 4: '90.02%', 5: '97.38%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.007765, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.154619, Val Acc: 96.57%, Val-Class-Acc: {0: '87.78%', 1: '97.18%', 2: '99.80%', 3: '100.00%', 4: '96.18%', 5: '98.33%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.008255, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.157669, Val Acc: 96.20%, Val-Class-Acc: {0: '93.48%', 1: '96.05%', 2: '99.60%', 3: '100.00%', 4: '91.30%', 5: '96.19%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.005769, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.167306, Val Acc: 96.13%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '94.06%', 5: '95.71%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.006147, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.156043, Val Acc: 95.76%, Val-Class-Acc: {0: '92.67%', 1: '95.30%', 2: '99.80%', 3: '100.00%', 4: '91.93%', 5: '94.05%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.005011, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.162611, Val Acc: 96.13%, Val-Class-Acc: {0: '86.97%', 1: '97.93%', 2: '99.80%', 3: '99.81%', 4: '94.69%', 5: '97.14%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.005789, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.153261, Val Acc: 96.57%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '99.60%', 3: '100.00%', 4: '93.42%', 5: '97.86%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.005801, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.182519, Val Acc: 95.49%, Val-Class-Acc: {0: '84.93%', 1: '97.74%', 2: '98.39%', 3: '100.00%', 4: '95.54%', 5: '95.71%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.005791, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.164342, Val Acc: 96.37%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 2: '99.40%', 3: '100.00%', 4: '92.57%', 5: '98.57%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.006562, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.76%', 3: '100.00%', 4: '100.00%', 5: '99.70%'},
# Val Loss: 0.209919, Val Acc: 95.52%, Val-Class-Acc: {0: '81.26%', 1: '98.68%', 2: '99.60%', 3: '99.81%', 4: '94.90%', 5: '98.57%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.009148, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '99.76%', 3: '100.00%', 4: '99.72%', 5: '99.70%'},
# Val Loss: 0.150905, Val Acc: 96.17%, Val-Class-Acc: {0: '87.78%', 1: '98.31%', 2: '98.99%', 3: '100.00%', 4: '93.63%', 5: '97.86%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.005596, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.221895, Val Acc: 95.66%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '99.60%', 3: '100.00%', 4: '90.23%', 5: '97.62%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.006129, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.167101, Val Acc: 96.34%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '99.40%', 3: '100.00%', 4: '95.33%', 5: '97.86%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.005913, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.183260, Val Acc: 96.03%, Val-Class-Acc: {0: '86.56%', 1: '98.31%', 2: '99.19%', 3: '99.81%', 4: '95.12%', 5: '96.67%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.005629, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.148802, Val Acc: 96.57%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 2: '99.19%', 3: '100.00%', 4: '94.69%', 5: '96.90%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.005631, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.170126, Val Acc: 96.06%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 2: '98.59%', 3: '100.00%', 4: '95.33%', 5: '95.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.005116, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.146799, Val Acc: 96.84%, Val-Class-Acc: {0: '92.87%', 1: '96.43%', 2: '99.40%', 3: '100.00%', 4: '94.48%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_87.pth
# Epoch 88/1000, Train Loss: 0.005786, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.147860, Val Acc: 96.64%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 2: '98.79%', 3: '100.00%', 4: '96.60%', 5: '96.43%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.005328, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.193085, Val Acc: 95.89%, Val-Class-Acc: {0: '84.32%', 1: '98.50%', 2: '98.79%', 3: '99.81%', 4: '96.60%', 5: '96.90%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.005367, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.139148, Val Acc: 96.74%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '97.98%', 3: '100.00%', 4: '97.24%', 5: '97.62%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.007231, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.160005, Val Acc: 96.37%, Val-Class-Acc: {0: '94.91%', 1: '91.17%', 2: '98.39%', 3: '100.00%', 4: '96.39%', 5: '97.62%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.005137, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.167685, Val Acc: 96.20%, Val-Class-Acc: {0: '90.02%', 1: '96.43%', 2: '97.98%', 3: '100.00%', 4: '94.48%', 5: '98.10%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.005105, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.179297, Val Acc: 96.13%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '99.80%', 3: '100.00%', 4: '93.42%', 5: '97.14%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.004650, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.182750, Val Acc: 96.17%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '93.21%', 5: '95.95%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.005437, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.145197, Val Acc: 96.40%, Val-Class-Acc: {0: '93.28%', 1: '95.68%', 2: '95.97%', 3: '100.00%', 4: '96.39%', 5: '96.90%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.008420, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.149957, Val Acc: 96.74%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '97.86%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.007958, Train-Class-Acc: {0: '99.69%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.141219, Val Acc: 96.57%, Val-Class-Acc: {0: '93.69%', 1: '93.98%', 2: '98.39%', 3: '100.00%', 4: '96.18%', 5: '97.14%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.005380, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.164941, Val Acc: 96.40%, Val-Class-Acc: {0: '92.67%', 1: '95.68%', 2: '97.38%', 3: '100.00%', 4: '94.48%', 5: '98.10%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.006006, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.201424, Val Acc: 95.62%, Val-Class-Acc: {0: '86.35%', 1: '98.68%', 2: '99.60%', 3: '100.00%', 4: '88.96%', 5: '99.76%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.004235, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.134519, Val Acc: 96.88%, Val-Class-Acc: {0: '92.87%', 1: '95.68%', 2: '98.99%', 3: '100.00%', 4: '96.39%', 5: '97.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_100.pth
# Epoch 101/1000, Train Loss: 0.006997, Train-Class-Acc: {0: '99.84%', 1: '99.64%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.255262, Val Acc: 94.54%, Val-Class-Acc: {0: '76.37%', 1: '98.87%', 2: '96.77%', 3: '100.00%', 4: '96.82%', 5: '98.10%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.005502, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.174637, Val Acc: 96.06%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 2: '100.00%', 3: '100.00%', 4: '92.57%', 5: '96.43%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.004192, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.244228, Val Acc: 94.94%, Val-Class-Acc: {0: '79.02%', 1: '98.68%', 2: '99.19%', 3: '100.00%', 4: '95.12%', 5: '97.14%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.007711, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '99.76%', 3: '99.93%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.250975, Val Acc: 94.06%, Val-Class-Acc: {0: '86.56%', 1: '97.93%', 2: '100.00%', 3: '100.00%', 4: '88.96%', 5: '89.05%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.006257, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.159609, Val Acc: 96.23%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 2: '98.99%', 3: '100.00%', 4: '95.75%', 5: '95.71%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.005722, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.165436, Val Acc: 96.67%, Val-Class-Acc: {0: '90.63%', 1: '98.12%', 2: '99.40%', 3: '100.00%', 4: '93.84%', 5: '97.62%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.004874, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.202736, Val Acc: 95.59%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '99.80%', 3: '100.00%', 4: '96.82%', 5: '96.19%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.006307, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.146154, Val Acc: 96.47%, Val-Class-Acc: {0: '92.87%', 1: '96.80%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '93.10%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.007791, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '99.84%', 3: '99.79%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.221016, Val Acc: 95.05%, Val-Class-Acc: {0: '80.65%', 1: '98.87%', 2: '100.00%', 3: '100.00%', 4: '94.90%', 5: '95.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.006259, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.130679, Val Acc: 96.98%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 2: '99.19%', 3: '100.00%', 4: '96.60%', 5: '97.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_110.pth
# Epoch 111/1000, Train Loss: 0.004423, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.149165, Val Acc: 96.78%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 2: '98.59%', 3: '100.00%', 4: '96.18%', 5: '97.38%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.005408, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.192942, Val Acc: 96.00%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '99.80%', 3: '99.63%', 4: '92.36%', 5: '98.33%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.006716, Train-Class-Acc: {0: '99.77%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.193906, Val Acc: 95.49%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '99.19%', 3: '99.63%', 4: '94.48%', 5: '96.19%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.005083, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.129264, Val Acc: 97.12%, Val-Class-Acc: {0: '93.48%', 1: '96.05%', 2: '98.39%', 3: '100.00%', 4: '98.30%', 5: '96.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_87.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_114.pth
# Epoch 115/1000, Train Loss: 0.004446, Train-Class-Acc: {0: '100.00%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.164089, Val Acc: 96.54%, Val-Class-Acc: {0: '94.09%', 1: '94.92%', 2: '100.00%', 3: '100.00%', 4: '91.93%', 5: '98.10%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.004572, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.84%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.179252, Val Acc: 96.74%, Val-Class-Acc: {0: '92.67%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '91.51%', 5: '98.81%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.004606, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.185866, Val Acc: 96.10%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '99.60%', 3: '99.44%', 4: '92.14%', 5: '98.10%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.004091, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.178217, Val Acc: 96.23%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%', 3: '99.26%', 4: '95.54%', 5: '97.62%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.004745, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.157630, Val Acc: 96.71%, Val-Class-Acc: {0: '91.85%', 1: '96.43%', 2: '100.00%', 3: '99.63%', 4: '93.42%', 5: '98.81%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.008479, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '99.76%', 3: '100.00%', 4: '99.63%', 5: '100.00%'},
# Val Loss: 0.248430, Val Acc: 93.99%, Val-Class-Acc: {0: '96.54%', 1: '77.63%', 2: '99.40%', 3: '100.00%', 4: '94.69%', 5: '96.90%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.007808, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.80%'},
# Val Loss: 0.178844, Val Acc: 96.34%, Val-Class-Acc: {0: '88.59%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '95.54%', 5: '95.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.006182, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.166056, Val Acc: 96.37%, Val-Class-Acc: {0: '86.97%', 1: '98.12%', 2: '99.19%', 3: '100.00%', 4: '95.75%', 5: '97.86%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.005178, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.168404, Val Acc: 96.64%, Val-Class-Acc: {0: '91.04%', 1: '97.56%', 2: '99.80%', 3: '100.00%', 4: '93.63%', 5: '97.38%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.004531, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.236886, Val Acc: 94.91%, Val-Class-Acc: {0: '78.62%', 1: '98.87%', 2: '98.99%', 3: '99.63%', 4: '94.27%', 5: '98.81%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.006717, Train-Class-Acc: {0: '99.84%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '100.00%'},
# Val Loss: 0.136688, Val Acc: 96.78%, Val-Class-Acc: {0: '92.87%', 1: '96.24%', 2: '98.79%', 3: '100.00%', 4: '95.97%', 5: '96.43%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.003915, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.159381, Val Acc: 96.78%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 2: '99.19%', 3: '100.00%', 4: '95.33%', 5: '98.57%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.005487, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.193832, Val Acc: 95.96%, Val-Class-Acc: {0: '85.95%', 1: '98.50%', 2: '100.00%', 3: '100.00%', 4: '92.78%', 5: '98.10%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.004388, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.174916, Val Acc: 96.17%, Val-Class-Acc: {0: '89.82%', 1: '97.93%', 2: '99.40%', 3: '100.00%', 4: '94.69%', 5: '94.29%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.005058, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.176024, Val Acc: 96.44%, Val-Class-Acc: {0: '87.17%', 1: '98.12%', 2: '99.60%', 3: '99.81%', 4: '97.45%', 5: '95.95%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.004804, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.153507, Val Acc: 96.34%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 2: '98.79%', 3: '99.81%', 4: '96.18%', 5: '95.24%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.006764, Train-Class-Acc: {0: '99.69%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.147875, Val Acc: 96.54%, Val-Class-Acc: {0: '95.52%', 1: '90.79%', 2: '99.60%', 3: '100.00%', 4: '96.18%', 5: '97.38%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.005571, Train-Class-Acc: {0: '99.92%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.156065, Val Acc: 96.71%, Val-Class-Acc: {0: '91.45%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '94.48%', 5: '96.67%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.004510, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.183625, Val Acc: 96.00%, Val-Class-Acc: {0: '85.54%', 1: '98.68%', 2: '98.99%', 3: '100.00%', 4: '94.90%', 5: '97.38%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.004144, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.157430, Val Acc: 96.64%, Val-Class-Acc: {0: '91.04%', 1: '97.56%', 2: '98.79%', 3: '100.00%', 4: '94.27%', 5: '97.86%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.005275, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.145662, Val Acc: 96.44%, Val-Class-Acc: {0: '91.24%', 1: '97.18%', 2: '99.40%', 3: '100.00%', 4: '95.12%', 5: '95.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.005106, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.171425, Val Acc: 96.00%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 2: '99.40%', 3: '100.00%', 4: '94.27%', 5: '94.76%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.004315, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.180631, Val Acc: 95.62%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 2: '98.99%', 3: '100.00%', 4: '96.18%', 5: '92.14%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.004267, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.160347, Val Acc: 96.44%, Val-Class-Acc: {0: '91.24%', 1: '97.74%', 2: '96.37%', 3: '100.00%', 4: '95.33%', 5: '97.62%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.006554, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'},
# Val Loss: 0.156625, Val Acc: 96.13%, Val-Class-Acc: {0: '91.65%', 1: '97.37%', 2: '98.39%', 3: '100.00%', 4: '94.27%', 5: '94.29%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.004143, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.154318, Val Acc: 96.47%, Val-Class-Acc: {0: '91.45%', 1: '97.37%', 2: '98.99%', 3: '99.81%', 4: '94.48%', 5: '96.19%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.007049, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.161537, Val Acc: 96.03%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '99.19%', 3: '99.81%', 4: '97.24%', 5: '91.67%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.008970, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.59%', 3: '100.00%', 4: '99.72%', 5: '99.90%'},
# Val Loss: 0.226706, Val Acc: 94.91%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '87.90%', 5: '98.33%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.005653, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.158726, Val Acc: 96.54%, Val-Class-Acc: {0: '91.65%', 1: '97.56%', 2: '99.19%', 3: '100.00%', 4: '94.27%', 5: '95.95%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.005063, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.157487, Val Acc: 96.64%, Val-Class-Acc: {0: '90.43%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '93.84%', 5: '97.86%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.005863, Train-Class-Acc: {0: '99.77%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.90%'},
# Val Loss: 0.183796, Val Acc: 95.72%, Val-Class-Acc: {0: '86.76%', 1: '98.31%', 2: '98.19%', 3: '100.00%', 4: '97.88%', 5: '92.14%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.005827, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.188311, Val Acc: 95.55%, Val-Class-Acc: {0: '87.17%', 1: '98.31%', 2: '97.18%', 3: '99.63%', 4: '94.27%', 5: '96.19%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.005233, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.135693, Val Acc: 96.98%, Val-Class-Acc: {0: '92.87%', 1: '97.37%', 2: '99.19%', 3: '100.00%', 4: '96.18%', 5: '95.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_52.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_147.pth
# Epoch 148/1000, Train Loss: 0.005613, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.151730, Val Acc: 96.37%, Val-Class-Acc: {0: '93.08%', 1: '96.05%', 2: '99.40%', 3: '99.44%', 4: '93.63%', 5: '96.19%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.004836, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# ...
# Val Loss: 0.150627, Val Acc: 96.67%, Val-Class-Acc: {0: '93.08%', 1: '95.30%', 2: '100.00%', 3: '99.81%', 4: '93.21%', 5: '98.57%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.004257, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.198541, Val Acc: 95.28%, Val-Class-Acc: {0: '86.35%', 1: '97.56%', 2: '98.19%', 3: '99.44%', 4: '94.69%', 5: '94.76%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.004822, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.189579, Val Acc: 95.66%, Val-Class-Acc: {0: '95.93%', 1: '85.90%', 2: '100.00%', 3: '99.44%', 4: '95.33%', 5: '98.10%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.003746, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.269164, Val Acc: 94.20%, Val-Class-Acc: {0: '86.56%', 1: '97.93%', 2: '100.00%', 3: '97.02%', 4: '87.05%', 5: '95.95%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.003808, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.194091, Val Acc: 95.49%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 2: '98.99%', 3: '97.95%', 4: '92.14%', 5: '96.19%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.003614, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.178455, Val Acc: 96.00%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 2: '99.80%', 3: '98.51%', 4: '92.36%', 5: '98.57%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.003264, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.188819, Val Acc: 96.03%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 2: '98.79%', 3: '98.14%', 4: '93.21%', 5: '98.57%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.003215, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.179177, Val Acc: 95.93%, Val-Class-Acc: {0: '86.76%', 1: '97.74%', 2: '98.99%', 3: '98.51%', 4: '95.33%', 5: '98.10%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.002907, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.155365, Val Acc: 96.64%, Val-Class-Acc: {0: '92.67%', 1: '95.49%', 2: '99.19%', 3: '97.95%', 4: '96.18%', 5: '98.57%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.003182, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.191662, Val Acc: 95.79%, Val-Class-Acc: {0: '89.41%', 1: '96.99%', 2: '98.99%', 3: '96.83%', 4: '94.27%', 5: '98.33%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.004904, Train-Class-Acc: {0: '99.77%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.337718, Val Acc: 93.08%, Val-Class-Acc: {0: '71.69%', 1: '99.06%', 2: '99.40%', 3: '96.28%', 4: '94.69%', 5: '97.14%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.003757, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.156354, Val Acc: 96.64%, Val-Class-Acc: {0: '91.85%', 1: '96.43%', 2: '99.19%', 3: '97.95%', 4: '97.03%', 5: '97.38%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.003484, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.177351, Val Acc: 96.17%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '98.59%', 3: '97.58%', 4: '96.82%', 5: '98.10%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.004083, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.304953, Val Acc: 92.87%, Val-Class-Acc: {0: '96.95%', 1: '73.12%', 2: '99.19%', 3: '97.58%', 4: '94.27%', 5: '98.10%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.003945, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.172411, Val Acc: 96.27%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 2: '99.19%', 3: '97.21%', 4: '96.18%', 5: '98.33%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.003419, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.169897, Val Acc: 96.23%, Val-Class-Acc: {0: '93.89%', 1: '94.74%', 2: '99.19%', 3: '96.65%', 4: '95.97%', 5: '97.14%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.006663, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.172304, Val Acc: 96.67%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 2: '98.59%', 3: '97.58%', 4: '97.66%', 5: '98.10%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.003666, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.143646, Val Acc: 96.71%, Val-Class-Acc: {0: '92.67%', 1: '95.86%', 2: '98.79%', 3: '97.95%', 4: '97.24%', 5: '97.86%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.002968, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.155545, Val Acc: 96.54%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '98.99%', 3: '98.14%', 4: '97.24%', 5: '99.05%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.002841, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.139289, Val Acc: 96.78%, Val-Class-Acc: {0: '93.28%', 1: '96.05%', 2: '99.60%', 3: '97.77%', 4: '95.75%', 5: '98.33%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.003101, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.168150, Val Acc: 96.50%, Val-Class-Acc: {0: '91.45%', 1: '97.56%', 2: '100.00%', 3: '97.95%', 4: '94.06%', 5: '97.86%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.004070, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.173445, Val Acc: 96.00%, Val-Class-Acc: {0: '95.72%', 1: '90.60%', 2: '100.00%', 3: '98.70%', 4: '92.36%', 5: '99.05%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.004008, Train-Class-Acc: {0: '99.92%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.210853, Val Acc: 95.45%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '98.99%', 3: '96.46%', 4: '94.06%', 5: '98.57%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.002998, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.166981, Val Acc: 96.23%, Val-Class-Acc: {0: '91.04%', 1: '96.99%', 2: '98.99%', 3: '97.21%', 4: '95.75%', 5: '97.38%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.002865, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.160646, Val Acc: 96.57%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 2: '98.99%', 3: '97.39%', 4: '96.82%', 5: '98.81%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.003725, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.141754, Val Acc: 96.95%, Val-Class-Acc: {0: '91.24%', 1: '96.80%', 2: '98.79%', 3: '98.88%', 4: '97.24%', 5: '98.81%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.003778, Train-Class-Acc: {0: '99.84%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.218419, Val Acc: 95.05%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '98.99%', 3: '98.14%', 4: '94.06%', 5: '96.90%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.003363, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.163166, Val Acc: 96.34%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 2: '99.80%', 3: '97.95%', 4: '93.84%', 5: '98.81%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.003268, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.150924, Val Acc: 96.71%, Val-Class-Acc: {0: '93.28%', 1: '94.74%', 2: '99.40%', 3: '98.51%', 4: '96.39%', 5: '98.10%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.003515, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.158737, Val Acc: 96.44%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 2: '99.40%', 3: '98.14%', 4: '94.48%', 5: '98.57%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.004020, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.150977, Val Acc: 96.54%, Val-Class-Acc: {0: '92.06%', 1: '96.80%', 2: '100.00%', 3: '97.95%', 4: '94.48%', 5: '97.86%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.004191, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.135767, Val Acc: 96.34%, Val-Class-Acc: {0: '94.30%', 1: '92.29%', 2: '99.80%', 3: '99.63%', 4: '94.06%', 5: '98.10%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.005433, Train-Class-Acc: {0: '99.77%', 1: '99.78%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.80%'},
# Val Loss: 0.166935, Val Acc: 96.47%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '99.40%', 3: '98.70%', 4: '97.03%', 5: '98.10%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.005024, Train-Class-Acc: {0: '99.84%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.194642, Val Acc: 95.42%, Val-Class-Acc: {0: '89.21%', 1: '96.62%', 2: '100.00%', 3: '97.58%', 4: '91.72%', 5: '97.14%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.003193, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.179705, Val Acc: 95.76%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '98.99%', 3: '97.02%', 4: '94.69%', 5: '97.86%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.004731, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.228203, Val Acc: 94.74%, Val-Class-Acc: {0: '86.76%', 1: '97.18%', 2: '99.80%', 3: '96.65%', 4: '89.38%', 5: '98.57%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.003100, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.177935, Val Acc: 95.86%, Val-Class-Acc: {0: '89.00%', 1: '97.37%', 2: '99.40%', 3: '97.02%', 4: '94.69%', 5: '97.62%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.003336, Train-Class-Acc: {0: '100.00%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.206521, Val Acc: 95.72%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 2: '99.19%', 3: '97.95%', 4: '90.23%', 5: '98.81%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.003967, Train-Class-Acc: {0: '99.84%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.187977, Val Acc: 95.32%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '98.79%', 3: '96.46%', 4: '94.69%', 5: '97.14%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.003546, Train-Class-Acc: {0: '99.92%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.343639, Val Acc: 93.79%, Val-Class-Acc: {0: '74.34%', 1: '99.06%', 2: '99.19%', 3: '96.46%', 4: '94.90%', 5: '98.81%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.003194, Train-Class-Acc: {0: '99.92%', 1: '100.00%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.194425, Val Acc: 95.45%, Val-Class-Acc: {0: '95.93%', 1: '90.04%', 2: '99.19%', 3: '98.32%', 4: '92.36%', 5: '97.14%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.004042, Train-Class-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.169977, Val Acc: 96.17%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 2: '99.40%', 3: '95.72%', 4: '95.97%', 5: '98.57%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.003314, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.223695, Val Acc: 95.28%, Val-Class-Acc: {0: '83.71%', 1: '98.87%', 2: '99.60%', 3: '96.65%', 4: '93.84%', 5: '99.05%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.002838, Train-Class-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.165950, Val Acc: 96.20%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 2: '99.19%', 3: '98.14%', 4: '94.06%', 5: '99.29%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.006217, Train-Class-Acc: {0: '99.69%', 1: '99.64%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.217332, Val Acc: 95.49%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%', 3: '96.83%', 4: '95.33%', 5: '99.05%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.005242, Train-Class-Acc: {0: '99.84%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'},
# Val Loss: 0.180376, Val Acc: 95.62%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 2: '100.00%', 3: '98.88%', 4: '94.69%', 5: '90.71%'}, LR: 0.000100
#
# ⏳ Total training time: 848.43 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_best.pth (Val Accuracy: 97.49%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 352, Train Loss: 0.004546, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.121811, Val Acc: 97.49%, Val-Acc: {0: '93.69%', 1: '96.05%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '98.33%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_352.pth
# Epoch 201, Train Loss: 0.003763, Train-Acc: {0: '99.92%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.126153, Val Acc: 97.25%, Val-Acc: {0: '93.08%', 1: '95.86%', 2: '99.80%', 3: '100.00%', 4: '95.75%', 5: '99.05%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_201.pth
# Epoch 832, Train Loss: 0.004379, Train-Acc: {0: '99.92%', 1: '99.78%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.133679, Val Acc: 97.22%, Val-Acc: {0: '93.48%', 1: '95.11%', 2: '99.80%', 3: '99.44%', 4: '96.39%', 5: '99.29%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_832.pth
# Epoch 698, Train Loss: 0.003743, Train-Acc: {0: '100.00%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.129643, Val Acc: 97.22%, Val-Acc: {0: '92.46%', 1: '95.86%', 2: '99.60%', 3: '99.44%', 4: '98.09%', 5: '97.86%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_698.pth
# Epoch 472, Train Loss: 0.003284, Train-Acc: {0: '100.00%', 1: '99.93%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.138945, Val Acc: 97.18%, Val-Acc: {0: '90.63%', 1: '97.37%', 2: '99.40%', 3: '99.44%', 4: '98.30%', 5: '97.86%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4/HAR_MLP_epoch_472.pth
# ---
# ### Period 4
# + ##### Total training time: 848.43 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/EWC_CIL_v2/Period_4'*
# + ##### Best Epoch: 352
# #### __Val Accuracy: 97.49%__
# #### __Val-Class-Acc: {0: '93.69%', 1: '96.05%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '98.33%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=6, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ##  __Compute FWT & Model Size__

# %% [markdown]
# ### Period 1

# %%
# ================================
# 📌 Period 1 Configuration
# ================================
period = 1

# Load processed dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]   # use test set for validation

# Auto-select the best CUDA device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
lambda_ewc    = 0.0  # EWC disabled for Period 1
ewc_state     = None

# Model saving path
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "TT", "EWC_CIL_v2", "Period_1")
os.makedirs(model_saving_folder, exist_ok=True)

# Initialize model, criterion, optimizer
model     = HAR_MLP_v2(input_size=input_size, hidden_size=hidden_size, output_size=output_size, dropout=dropout).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

print_model_info(model)
# Train the model
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================

# Unique class summary
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Clean up memory to prepare for next period
del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 765 MiB
#     - Device Name    : NVIDIA RTX A6000
# - Total Parameters: 89218
# - Model Size (float32): 0.34 MB
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
# Epoch 1/1, Train Loss: 0.820664, Train-Class-Acc: {0: '61.90%', 1: '43.89%'},
# Val Loss: 0.523949, Val Acc: 75.37%, Val-Class-Acc: {0: '60.69%', 1: '88.91%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1/HAR_MLP_epoch_1.pth
#
# ⏳ Total training time: 0.65 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1/HAR_MLP_best.pth (Val Accuracy: 75.37%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.820664, Train-Acc: {0: '61.90%', 1: '43.89%'},
# Val Loss: 0.523949, Val Acc: 75.37%, Val-Acc: {0: '60.69%', 1: '88.91%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1/HAR_MLP_epoch_1.pth
# ---
# ### Period 1
# + ##### Total training time: 0.65 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_1'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 75.37%__
# #### __Val-Class-Acc: {0: '60.69%', 1: '88.91%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ### Period 2

# %%
# ================================
# 📌 FWT - Period 2 (HAR EWC)
# ================================
period = 2

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
dropout = 0.2
device = auto_select_cuda_device()
output_size_prev = 2  # Period 1: Sitting, Standing → label 0, 1

# === 載入 Period 1 的最佳模型 ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "EWC_CIL_v2", "Period_1", "HAR_MLP_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)

# === Previous Model ===
previous_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
previous_model.load_state_dict(checkpoint["model_state_dict"], strict=False)
previous_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init Model ===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === 資料與 FWT ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1]

fwt, acc_prev, acc_init = compute_fwt_har(previous_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 2:")
print(f"- FWT (EWC HAR Period 2, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5118 MiB
#     - Device Name    : NVIDIA RTX A6000
# 📋 Total samples for known classes [0, 1]: 1023
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 1023
# - Correct (PrevModel): 939 / 1023 → Acc = 0.9179
# - Correct (InitModel): 491 / 1023 → Acc = 0.4800
# - FWT = Acc_prev - Acc_init = 0.4379
#
# ### Period 2:
# - FWT (EWC HAR Period 2, old classes [0, 1]): 43.79%
# - Accuracy by previous model: 91.79%
# - Accuracy by init model:     48.00%
# /tmp/ipykernel_1865198/758516492.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# /tmp/ipykernel_1865198/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1865198/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)

# %%
# ================================
# 📌 Period 2 Configuration
# ================================
period = 2

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "TT", "EWC_CIL_v2", "Period_2")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 1 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_1", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher Information Matrix (based on Period 1 training data)
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[1]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[1]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer (new for Period 2)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
print_model_info(model)
# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

# Memory cleanup
del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 1018 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_792860/98783376.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# - Total Parameters: 89347
# - Model Size (float32): 0.34 MB
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# Epoch 1/1, Train Loss: 0.547917, Train-Class-Acc: {0: '84.84%', 1: '82.31%', 2: '74.76%'},
# Val Loss: 0.223783, Val Acc: 95.77%, Val-Class-Acc: {0: '81.67%', 1: '98.31%', 2: '99.78%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2/HAR_MLP_epoch_1.pth
#
# ⏳ Total training time: 0.45 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2/HAR_MLP_best.pth (Val Accuracy: 95.77%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.547917, Train-Acc: {0: '84.84%', 1: '82.31%', 2: '74.76%'},
# Val Loss: 0.223783, Val Acc: 95.77%, Val-Acc: {0: '81.67%', 1: '98.31%', 2: '99.78%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2/HAR_MLP_epoch_1.pth
# ---
# ### Period 2
# + ##### Total training time: 0.45 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_2'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 95.77%__
# #### __Val-Class-Acc: {0: '81.67%', 1: '98.31%', 2: '99.78%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=3, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ### Period 3

# %%
# ================================
# 📌 FWT - Period 3 (HAR EWC)
# ================================
period = 3

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
dropout = 0.2
device = auto_select_cuda_device()
output_size_prev = 3  # Period 2: Sitting, Standing, Walking → 0, 1, 2

# === 載入 Period 2 的最佳模型 ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "EWC_CIL_v2", "Period_2", "HAR_MLP_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)

previous_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
previous_model.load_state_dict(checkpoint["model_state_dict"], strict=False)
previous_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init Model ===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === 資料與 FWT ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1, 2]

fwt, acc_prev, acc_init = compute_fwt_har(previous_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 3:")
print(f"- FWT (EWC HAR Period 3, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5118 MiB
#     - Device Name    : NVIDIA RTX A6000
# 📋 Total samples for known classes [0, 1, 2]: 2410
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 2410
# - Correct (PrevModel): 2339 / 2410 → Acc = 0.9705
# - Correct (InitModel): 622 / 2410 → Acc = 0.2581
# - FWT = Acc_prev - Acc_init = 0.7124
#
# ### Period 3:
# - FWT (EWC HAR Period 3, old classes [0, 1, 2]): 71.24%
# - Accuracy by previous model: 97.05%
# - Accuracy by init model:     25.81%
# /tmp/ipykernel_1865198/3286973532.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# /tmp/ipykernel_1865198/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1865198/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)

# %%
# ================================
# 📌 Period 3 Configuration
# ================================
period = 3

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "TT", "EWC_CIL_v2", "Period_3")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 2 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_2", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 2 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[2]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[2]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
print_model_info(model)
# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 1132 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_792860/984836093.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# - Total Parameters: 89476
# - Model Size (float32): 0.34 MB
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# Epoch 1/1, Train Loss: 0.697774, Train-Class-Acc: {0: '65.55%', 1: '74.09%', 2: '74.12%', 3: '74.91%'},
# Val Loss: 0.174004, Val Acc: 96.20%, Val-Class-Acc: {0: '92.06%', 1: '92.48%', 2: '100.00%', 3: '93.85%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3/HAR_MLP_epoch_1.pth
#
# ⏳ Total training time: 0.65 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3/HAR_MLP_best.pth (Val Accuracy: 96.20%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.697774, Train-Acc: {0: '65.55%', 1: '74.09%', 2: '74.12%', 3: '74.91%'},
# Val Loss: 0.174004, Val Acc: 96.20%, Val-Acc: {0: '92.06%', 1: '92.48%', 2: '100.00%', 3: '93.85%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3/HAR_MLP_epoch_1.pth
# ---
# ### Period 3
# + ##### Total training time: 0.65 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_3'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 96.20%__
# #### __Val-Class-Acc: {0: '92.06%', 1: '92.48%', 2: '100.00%', 3: '93.85%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ### Period 4

# %%
# ================================
# 📌 FWT - Period 4 (HAR EWC)
# ================================
period = 4

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
dropout = 0.2
device = auto_select_cuda_device()
output_size_prev = 4  # Period 3: Sitting, Standing, Walking, Laying → 0, 1, 2, 3

# === 載入 Period 3 的最佳模型 ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "EWC_CIL_v2", "Period_3", "HAR_MLP_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)

previous_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
previous_model.load_state_dict(checkpoint["model_state_dict"], strict=False)
previous_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init Model ===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === FWT 計算 ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1, 3]  # 同樣排除拆分後不穩定語意的類別

fwt, acc_prev, acc_init = compute_fwt_har(previous_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 4:")
print(f"- FWT (EWC HAR Period 4, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5118 MiB
#     - Device Name    : NVIDIA RTX A6000
# 📋 Total samples for known classes [0, 1, 3]: 1560
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 1560
# - Correct (PrevModel): 1492 / 1560 → Acc = 0.9564
# - Correct (InitModel): 465 / 1560 → Acc = 0.2981
# - FWT = Acc_prev - Acc_init = 0.6583
#
# ### Period 4:
# - FWT (EWC HAR Period 4, old classes [0, 1, 3]): 65.83%
# - Accuracy by previous model: 95.64%
# - Accuracy by init model:     29.81%
# /tmp/ipykernel_1865198/3530869363.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# /tmp/ipykernel_1865198/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1865198/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)

# %%
# ================================
# 📌 Period 4 Configuration
# ================================
period = 4

# Load dataset
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Set model and training config
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
lambda_ewc    = 1.0

# Model saving directory
model_name = "HAR_MLP"
model_saving_folder = os.path.join("Class_Incremental_CL", "HAR_CIL", "TT", "EWC_CIL_v2", "Period_4")
os.makedirs(model_saving_folder, exist_ok=True)

# Load best model from Period 3 (ignore output layer shape mismatch)
prev_path = os.path.join("Class_Incremental_CL", "HAR_CIL", "Trained_models", "EWC_CIL_v2", "Period_3", f"{model_name}_best.pth")
prev_checkpoint = torch.load(prev_path, map_location=device)
model = HAR_MLP_v2(input_size, hidden_size, output_size, dropout).to(device)

# Filter mismatched keys (especially fc2) during load
state_dict = prev_checkpoint["model_state_dict"]
model_dict = model.state_dict()
filtered_dict = {k: v for k, v in state_dict.items() if k in model_dict and model_dict[k].shape == v.shape}
model.load_state_dict(filtered_dict, strict=False)

# Compute Fisher from Period 3 training data
criterion = nn.CrossEntropyLoss()
train_loader = DataLoader(
    TensorDataset(
        torch.tensor(period_datasets[3]["train"][0], dtype=torch.float32),
        torch.tensor(period_datasets[3]["train"][1], dtype=torch.long)
    ),
    batch_size=batch_size, shuffle=True
)
fisher_dict, params_dict = EWC.compute_fisher_and_params(model, train_loader, criterion, device=device)
ewc_state = EWC(fisher_dict, params_dict)

# Optimizer for this period
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
print_model_info(model)
# Train with EWC
train_with_ewc(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    scheduler=None,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    ewc=ewc_state,
    lambda_ewc=lambda_ewc,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, train_loader, prev_checkpoint, state_dict, model_dict, filtered_dict
del fisher_dict, params_dict, ewc_state, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 1138 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_792860/3431978897.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prev_checkpoint = torch.load(prev_path, map_location=device)
# - Total Parameters: 89734
# - Model Size (float32): 0.34 MB
#
# 🚀 'train_with_ewc' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# Epoch 1/1, Train Loss: 0.750827, Train-Class-Acc: {0: '85.38%', 1: '95.85%', 2: '78.06%', 3: '83.72%', 4: '34.39%', 5: '71.70%'},
# Val Loss: 0.314743, Val Acc: 92.09%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '99.19%', 3: '95.34%', 4: '90.23%', 5: '80.48%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4/HAR_MLP_epoch_1.pth
#
# ⏳ Total training time: 0.43 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4/HAR_MLP_best.pth (Val Accuracy: 92.09%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4/HAR_MLP_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.750827, Train-Acc: {0: '85.38%', 1: '95.85%', 2: '78.06%', 3: '83.72%', 4: '34.39%', 5: '71.70%'},
# Val Loss: 0.314743, Val Acc: 92.09%, Val-Acc: {0: '86.97%', 1: '97.74%', 2: '99.19%', 3: '95.34%', 4: '90.23%', 5: '80.48%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4/HAR_MLP_epoch_1.pth
# ---
# ### Period 4
# + ##### Total training time: 0.43 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/EWC_CIL_v2/Period_4'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 92.09%__
# #### __Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '99.19%', 3: '95.34%', 4: '90.23%', 5: '80.48%'}__
#
# ✅ Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=6, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ---

# %% [markdown]
# ## 📊 Summary:

# %% [markdown]
# ### ✔️ HAR - EWC: Validation Summary
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                    |
# |--------|-------------------|---------------------|-------------------------------------------------------------------------|
# | 1      | 149.07            | **95.31%**          | {0: 95.32%, 1: 95.30%}                                                 |
# | 2      | 334.56            | **97.80%**          | {0: 94.09%, 1: 95.49%, 2: 100.00%}                                     |
# | 3      | 387.41            | **98.37%**          | {0: 94.50%, 1: 96.05%, 2: 100.00%, 3: 100.00%}                         |
# | 4      | 848.43            | **97.49%**          | {0: 93.69%, 1: 96.05%, 2: 99.40%, 3: 100.00%, 4: 97.45%, 5: 98.33%}    |

# %% [markdown]
# ### 🧠 Continual Learning Metrics
#
# | Period | AA_old (%) | AA_new (%) | BWT (%) | FWT (%) | FWT Classes     | Prev. Model Acc | Init Model Acc |
# |--------|------------|------------|---------|---------|------------------|------------------|-----------------|
# | 2      | 94.79%     | 100.00%    | -0.33%  | 43.79%  | [0, 1]           | 91.79%           | 48.00%          |
# | 3      | 96.85%     | 100.00%    | +0.32%  | 71.24%  | [0, 1, 2]        | 97.05%           | 25.81%          |
# | 4      | 97.29%     | 97.89%     | -0.35%  | 65.83%  | [0, 1, 3]        | 95.64%           | 29.81%          |

# %% [markdown]
# ### 📦 Model Size per Period
#
# | Period | Output Size | Total Params | Δ Params vs Prev | Δ % vs Prev | Model Size (float32) |
# |--------|-------------|--------------|------------------|-------------|-----------------------|
# | 1      | 2           | 89,218       | —                | —           | 0.34 MB               |
# | 2      | 3           | 89,347       | +129             | +0.14%      | 0.34 MB               |
# | 3      | 4           | 89,476       | +129             | +0.14%      | 0.34 MB               |
# | 4      | 6           | 89,734       | +258             | +0.29%      | 0.34 MB               |
#
# **📈 Model Growth Rate (MGR) = (89,734 - 89,218) / (89,218 × 3) ≈ +0.19%**
#
# **📈 Max trainable ratio = 100%**
