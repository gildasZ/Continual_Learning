# %% [markdown]
# ## __Check first before starting__

# %%
import os

# Change the working directory to the project root
# Working_directory = os.path.normpath("C:/Users/james/OneDrive/文件/Continual_Learning")
Working_directory = os.path.normpath("/mnt/mydisk/Continual_Learning_JL/Continual_Learning/")
os.chdir(Working_directory)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /mnt/mydisk/Continual_Learning_JL/Continual_Learning

# %% [markdown]
# ## __All imports__

# %%
# Operating system and file management
import os
import shutil
import contextlib
import traceback
import gc
import glob, copy
from collections import defaultdict
import subprocess
import time
import re, pickle

# Jupyter notebook widgets and display
import ipywidgets as widgets
from IPython.display import display

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Plotting and visualization
import matplotlib.pyplot as plt
from mpl_interactions import zoom_factory, panhandler

# Machine learning and preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pickle
from ta import trend, momentum, volatility, volume

# Mathematical and scientific computing
import math
from scipy.ndimage import gaussian_filter1d

# Type hinting
from typing import Callable, Tuple

# Deep learning with PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## __Dataset Setup & Preprocessing__

# %% [markdown]
# ### 📥 Step 1 — Set dataset path and load features & labels
# We will load the 561-dimensional features and original activity labels for both training and testing.

# %%
# Set working directory manually before running this cell if needed
BASE_DIR = "Class_Incremental_CL/HAR_CIL/har_dataset"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
TEST_DIR = os.path.join(BASE_DIR, "test")

# 活動對應（原始標籤）
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# Load feature and label data
X_train = np.loadtxt(os.path.join(TRAIN_DIR, "X_train.txt"))
y_train = np.loadtxt(os.path.join(TRAIN_DIR, "y_train.txt")).astype(int)
X_test = np.loadtxt(os.path.join(TEST_DIR, "X_test.txt"))
y_test = np.loadtxt(os.path.join(TEST_DIR, "y_test.txt")).astype(int)

print("Train shape:", X_train.shape, y_train.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (7352, 561) (7352,)
# Test shape: (2947, 561) (2947,)

# %% [markdown]
# ### 🧩 Step 2 — Define period label groups and final class remapping
# We will predefine the class mappings for each period to ensure consistency across the experiment.

# %%
# Period-to-original-label mapping
period_label_map = {
    1: [4, 5],           # SITTING, STANDING
    2: [4, 5, 1, 2, 3],  # + WALKING variants (merged)
    3: [4, 5, 1, 2, 3, 6],  # + LAYING
    4: [4, 5, 1, 2, 3, 6]   # same classes, but with walking variants separated
}

# Consistent label remapping across all periods (final label index)
final_class_map = {
    "SITTING": 0,
    "STANDING": 1,
    "WALKING": 2,
    "LAYING": 3,
    "WALKING_UPSTAIRS": 4,
    "WALKING_DOWNSTAIRS": 5
}

# Reverse mapping for readability
label_name_from_id = {v: k for k, v in final_class_map.items()}
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# %% [markdown]
# ### 🧪 Step 3 — Filter and remap datasets for each period
# We will build training and testing splits for each period using consistent class indices.

# %%
def map_label(label, period):
    name = activity_label_map[label]
    if period < 4:
        if name.startswith("WALKING"):
            return final_class_map["WALKING"]
        else:
            return final_class_map[name]
    else:
        return final_class_map[name]

def get_period_dataset(X, y, period):
    allowed_labels = period_label_map[period]
    mask = np.isin(y, allowed_labels)
    Xp = X[mask]
    yp = np.array([map_label(label, period) for label in y[mask]])
    return Xp, yp

# %% [markdown]
# ### 📊 Step 4 — Print artistic class distribution for each period
# We show each period's label map and class statistics to confirm correctness.

# %%
def print_class_distribution(y, var_name: str, label_map: dict) -> None:
    y = np.array(y).flatten()
    unique, counts = np.unique(y, return_counts=True)
    total = counts.sum()
    print(f"\n📦 Class Distribution for {var_name}")
    for i, c in zip(unique, counts):
        print(f"  ├─ Label {i:<2} ({label_map[i]:<20}) → {c:>5} samples ({(c/total)*100:>5.2f}%)")

# %%
period_datasets = {}

for period in range(1, 5):
    Xp_train, yp_train = get_period_dataset(X_train, y_train, period)
    Xp_test, yp_test = get_period_dataset(X_test, y_test, period)

    period_datasets[period] = {
        "train": (Xp_train, yp_train),
        "test": (Xp_test, yp_test)
    }

    print_class_distribution(yp_train, f"Period {period} (Train)", label_name_from_id)
    print_class_distribution(yp_test, f"Period {period} (Test)", label_name_from_id)
# Out:
# 📦 Class Distribution for Period 1 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (48.35%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (51.65%)
#
# 📦 Class Distribution for Period 1 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (48.00%)
#   ├─ Label 1  (STANDING            ) →   532 samples (52.00%)
#
# 📦 Class Distribution for Period 2 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (21.63%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (23.11%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (55.26%)
#
# 📦 Class Distribution for Period 2 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (20.37%)
#   ├─ Label 1  (STANDING            ) →   532 samples (22.07%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (57.55%)
#
# 📦 Class Distribution for Period 3 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (44.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#
# 📦 Class Distribution for Period 3 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (47.06%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#
# 📦 Class Distribution for Period 4 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  1226 samples (16.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →  1073 samples (14.59%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   986 samples (13.41%)
#
# 📦 Class Distribution for Period 4 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →   496 samples (16.83%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →   471 samples (15.98%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   420 samples (14.25%)

# %% [markdown]
# ## __Check GPU, CUDA, Pytorch__

# %% [markdown]
# ### GPU Details

# %%
# !nvidia-smi
# Out:
# Thu Apr 24 23:24:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.15              Driver Version: 570.86.15      CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:2A:00.0 Off |                  Off |
# | 30%   44C    P5             77W /  300W |    4539MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:3D:00.0 Off |                  Off |
# | 30%   50C    P2            145W /  300W |   39939MiB /  49140MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               Off |   00000000:AB:00.0 Off |                  Off |
# | 30%   33C    P5             17W /  300W |    6610MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    0   N/A  N/A         2214128      C   ...onda3/envs/CIL_env/bin/python        366MiB |
# |    0   N/A  N/A         2695839      C   python3                                4018MiB |
# |    1   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    1   N/A  N/A         2695839      C   python3                               38154MiB |
# |    1   N/A  N/A         2802897      C   python                                 1920MiB |
# |    2   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    2   N/A  N/A         2214128      C   ...onda3/envs/CIL_env/bin/python        362MiB |
# |    2   N/A  N/A         2234450      C   ...onda3/envs/CIL_env/bin/python        380MiB |
# |    2   N/A  N/A         2695839      C   python3                                5834MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### CUDA Details

# %%
def check_gpu_config():
    """
    Check GPU availability and display detailed configuration information.
    """
    # Check if GPU is available
    gpu_available = torch.cuda.is_available()
    
    # Print header
    print("=" * 50)
    print("GPU Configuration Check".center(50))
    print("=" * 50)
    
    # Basic GPU availability
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'GPU Available':<25}: {'Yes' if gpu_available else 'No'}")
    
    # If GPU is available, print detailed info
    if gpu_available:
        print("-" * 50)
        print("GPU Details".center(50))
        print("-" * 50)
        
        # Device info
        print(f"{'Device Name':<25}: {torch.cuda.get_device_name(0)}")
        print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")
        print(f"{'Current Device Index':<25}: {torch.cuda.current_device()}")
        
        # Compute capability and CUDA cores
        props = torch.cuda.get_device_properties(0)
        print(f"{'Compute Capability':<25}: {props.major}.{props.minor}")
        print(f"{'Total CUDA Cores':<25}: {props.multi_processor_count * 128}")  # Approx. 128 cores per SM
        
        # Memory info
        total_memory = props.total_memory / (1024 ** 3)  # Convert to GB
        memory_allocated = torch.cuda.memory_allocated(0) / (1024 ** 3)
        memory_reserved = torch.cuda.memory_reserved(0) / (1024 ** 3)
        print(f"{'Total Memory (GB)':<25}: {total_memory:.2f}")
        print(f"{'Allocated Memory (GB)':<25}: {memory_allocated:.2f}")
        print(f"{'Reserved Memory (GB)':<25}: {memory_reserved:.2f}")
    else:
        print("-" * 50)
        print("No GPU detected. Running on CPU.".center(50))
        print("-" * 50)
    
    print("=" * 50)

if __name__ == "__main__":
    check_gpu_config()
# Out:
# ==================================================
#              GPU Configuration Check
# ==================================================
# PyTorch Version          : 2.5.1
# GPU Available            : Yes
# --------------------------------------------------
#                    GPU Details
# --------------------------------------------------
# Device Name              : NVIDIA RTX A6000
# Number of GPUs           : 3
# Current Device Index     : 0
# Compute Capability       : 8.6
# Total CUDA Cores         : 10752
# Total Memory (GB)        : 47.41
# Allocated Memory (GB)    : 0.00
# Reserved Memory (GB)     : 0.00
# ==================================================

# %% [markdown]
# ### PyTorch Details

# %%
def print_torch_config():
    """Print PyTorch and CUDA configuration in a formatted manner."""
    print("=" * 50)
    print("PyTorch Configuration".center(50))
    print("=" * 50)
    
    # Basic PyTorch and CUDA info
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'CUDA Compiled Version':<25}: {torch.version.cuda}")
    print(f"{'CUDA Available':<25}: {'Yes' if torch.cuda.is_available() else 'No'}")
    print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")

    # GPU details if available
    if torch.cuda.is_available():
        print(f"{'GPU Name':<25}: {torch.cuda.get_device_name(0)}")

    print("-" * 50)
    
    # Seed setting
    torch.manual_seed(42)
    print(f"{'Random Seed':<25}: 42 (Seeding successful!)")
    
    print("=" * 50)

if __name__ == "__main__":
    print_torch_config()
# Out:
# ==================================================
#               PyTorch Configuration
# ==================================================
# PyTorch Version          : 2.5.1
# CUDA Compiled Version    : 12.1
# CUDA Available           : Yes
# Number of GPUs           : 3
# GPU Name                 : NVIDIA RTX A6000
# --------------------------------------------------
# Random Seed              : 42 (Seeding successful!)
# ==================================================

# %% [markdown]
# ## __⚙️ GPU Selection — Auto-select the least loaded GPU__
# This code automatically scans available GPUs and selects the one with the lowest current memory usage.

# %%
def auto_select_cuda_device(verbose=True):
    """
    Automatically selects the CUDA GPU with the least memory usage.
    Falls back to CPU if no GPU is available.
    """
    if not torch.cuda.is_available():
        print("🚫 No CUDA GPU available. Using CPU.")
        return torch.device("cpu")

    try:
        # Run nvidia-smi to get memory usage of each GPU
        smi_output = subprocess.check_output(
            ['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader'],
            encoding='utf-8'
        )
        memory_used = [int(x) for x in smi_output.strip().split('\n')]
        best_gpu = int(np.argmin(memory_used))

        if verbose:
            print("🎯 Automatically selected GPU:")
            print(f"    - CUDA Device ID : {best_gpu}")
            print(f"    - Memory Used    : {memory_used[best_gpu]} MiB")
            print(f"    - Device Name    : {torch.cuda.get_device_name(best_gpu)}")
        return torch.device(f"cuda:{best_gpu}")
    except Exception as e:
        print(f"⚠️ Failed to auto-detect GPU. Falling back to cuda:0. ({e})")
        return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Execute and assign
device = auto_select_cuda_device()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 4539 MiB
#     - Device Name    : NVIDIA RTX A6000

# %% [markdown]
# ## __MLP Model__

# %% [markdown]
# ### HAR_MLP_v2

# %%
class HAR_MLP_v2(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, dropout: float = 0.2):
        super(HAR_MLP_v2, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.fc3 = nn.Linear(hidden_size, output_size)
        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.dropout2(x)

        x = self.fc3(x)
        return x

# %% [markdown]
# ## __PNN Module__

# %%
# =============================
# PNN_fc1 Implementation for HAR_MLP_v2 
# =============================
class HAR_PNN_Column_fc1(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, new_output_size: int, dropout: float = 0.2):
        super(HAR_PNN_Column_fc1, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.fc3 = nn.Linear(hidden_size, new_output_size)
        self.lateral_adapter = nn.Linear(hidden_size, hidden_size)

        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor, lateral_features: torch.Tensor) -> torch.Tensor:
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        lateral = self.lateral_adapter(lateral_features)
        x = x + lateral

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.dropout2(x)

        out = self.fc3(x)
        return out


class ProgressiveNeuralNetwork_fc1(nn.Module):
    def __init__(self, base_model: nn.Module, new_column: HAR_PNN_Column_fc1):
        super(ProgressiveNeuralNetwork_fc1, self).__init__()
        self.base_model = base_model
        self.new_column = new_column

        for param in self.base_model.parameters():
            param.requires_grad = False

    def forward_features(self, x: torch.Tensor) -> torch.Tensor:
        # ✅ 遞迴支援 base_model 的 forward_features
        with torch.no_grad():
            if hasattr(self.base_model, "forward_features"):
                return self.base_model.forward_features(x)
            else:
                x = self.base_model.fc1(x)
                x = self.base_model.bn1(x)
                x = self.base_model.relu1(x)
                x = self.base_model.dropout1(x)
                return x

    def get_logits(self, x: torch.Tensor, base_features: torch.Tensor) -> torch.Tensor:
        with torch.no_grad():
            # 遞迴收集所有 base logits
            if isinstance(self.base_model, ProgressiveNeuralNetwork_fc1):
                logits = self.base_model(x)  # ✅ 直接 forward base model（內含其 own logits）
            else:
                x = self.base_model.fc2(base_features)
                x = self.base_model.bn2(x)
                x = self.base_model.relu2(x)
                x = self.base_model.dropout2(x)
                logits = self.base_model.fc3(x)
            return logits

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        base_features = self.forward_features(x)
        base_logits = self.get_logits(x, base_features)
        new_logits = self.new_column(x, lateral_features=base_features)
        return torch.cat([base_logits, new_logits], dim=-1)

# %%
# =============================
# PNN_fc2 Implementation for HAR_MLP_v2
# =============================
class HAR_PNN_Column_fc2(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, new_output_size: int, dropout: float = 0.2):
        super(HAR_PNN_Column_fc2, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.fc3 = nn.Linear(hidden_size, new_output_size)
        self.lateral_adapter = nn.Linear(hidden_size, hidden_size)

        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor, lateral_features: torch.Tensor) -> torch.Tensor:
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.dropout2(x)

        lateral = self.lateral_adapter(lateral_features)
        x = x + lateral

        out = self.fc3(x)
        return out


class ProgressiveNeuralNetwork_fc2(nn.Module):
    def __init__(self, base_model: nn.Module, new_column: HAR_PNN_Column_fc2):
        super(ProgressiveNeuralNetwork_fc2, self).__init__()
        self.base_model = base_model
        self.new_column = new_column

        for param in self.base_model.parameters():
            param.requires_grad = False

    def forward_features(self, x: torch.Tensor) -> torch.Tensor:
        with torch.no_grad():
            # 遞迴下探 base_model 若有 forward_features
            if hasattr(self.base_model, "forward_features"):
                return self.base_model.forward_features(x)
            else:
                x = self.base_model.fc1(x)
                x = self.base_model.bn1(x)
                x = self.base_model.relu1(x)
                x = self.base_model.dropout1(x)

                x = self.base_model.fc2(x)
                x = self.base_model.bn2(x)
                x = self.base_model.relu2(x)
                x = self.base_model.dropout2(x)
                return x

    def get_logits(self, x: torch.Tensor, base_features: torch.Tensor) -> torch.Tensor:
        with torch.no_grad():
            # 遞迴收集所有 base logits
            if isinstance(self.base_model, ProgressiveNeuralNetwork_fc2):
                logits = self.base_model(x)  # ✅ 直接 forward base model（內含其 own logits）
            else:
                logits = self.base_model.fc3(base_features)
            return logits

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        base_features = self.forward_features(x)
        base_logits = self.get_logits(x, base_features)
        new_logits = self.new_column(x, lateral_features=base_features)
        return torch.cat([base_logits, new_logits], dim=-1)

# %% [markdown]
# ## __Training Function with PNN__

# %%
def compute_classwise_accuracy(preds, targets, class_correct, class_total):
    """
    Computes per-class accuracy statistics from raw logits and ground truth.
    """
    preds = torch.argmax(preds, dim=-1)
    correct_mask = (preds == targets)
    for label in torch.unique(targets):
        label = label.item()
        label_mask = (targets == label)
        class_total[label] = class_total.get(label, 0) + label_mask.sum().item()
        class_correct[label] = class_correct.get(label, 0) + (correct_mask & label_mask).sum().item()

# %%
def compute_fwt_har(previous_model, init_model, X_val, y_val, known_classes, batch_size=64):
    """
    FWT computation for HAR-style inputs (tabular MLP, not sequence).
    X_val: shape [N, F]
    y_val: shape [N]
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    previous_model.to(device).eval()
    init_model.to(device).eval()

    # 只選擇 known_classes
    mask = np.isin(y_val, known_classes)
    X_known = X_val[mask]
    y_known = y_val[mask]

    if len(y_known) == 0:
        print(f"⚠️ No validation samples for known classes {known_classes}.")
        return None, None, None

    print(f"📋 Total samples for known classes {known_classes}: {len(y_known)}")

    dataset = TensorDataset(
        torch.tensor(X_known, dtype=torch.float32),
        torch.tensor(y_known, dtype=torch.long)
    )
    loader = DataLoader(dataset, batch_size=batch_size)

    correct_prev, correct_init, total = 0, 0, 0

    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)

            out_prev = previous_model(xb)
            out_init = init_model(xb)

            preds_prev = torch.argmax(out_prev, dim=-1)
            preds_init = torch.argmax(out_init, dim=-1)

            correct_prev += (preds_prev == yb).sum().item()
            correct_init += (preds_init == yb).sum().item()
            total += yb.size(0)

    acc_prev = correct_prev / total
    acc_init = correct_init / total
    fwt_value = acc_prev - acc_init

    print(f"\n### 🔍 FWT Debug Info (HAR):")
    print(f"- Total evaluated samples: {total}")
    print(f"- Correct (PrevModel): {correct_prev} / {total} → Acc = {acc_prev:.4f}")
    print(f"- Correct (InitModel): {correct_init} / {total} → Acc = {acc_init:.4f}")
    print(f"- FWT = Acc_prev - Acc_init = {fwt_value:.4f}")

    return fwt_value, acc_prev, acc_init

# %%
def print_model_info(model):
    total_params = sum(p.numel() for p in model.parameters())
    param_size_bytes = total_params * 4  # 假設 float32，每個參數佔 4 bytes
    param_size_MB = param_size_bytes / (1024**2)

    print(f"- Total Parameters: {total_params}")
    print(f"- Model Size (float32): {param_size_MB:.2f} MB")

# %%
def train_with_pnn(model, output_size, criterion, optimizer,
                   X_train, y_train, X_val, y_val,
                   scheduler=None, num_epochs=10, batch_size=32,
                   model_saving_folder=None, model_name=None,
                   stop_signal_file=None, period=1, device=auto_select_cuda_device()):
    print("\n🚀 'train_with_pnn' started.")
    model_name = model_name or 'pnn_model'
    model_saving_folder = model_saving_folder or './saved_models'

    if model_saving_folder:
        if os.path.exists(model_saving_folder):
            shutil.rmtree(model_saving_folder)
            print(f"✅ Removed existing folder: {model_saving_folder}")
        os.makedirs(model_saving_folder, exist_ok=True)

    model.to(device)

    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    print("\n✅ Data Overview:")
    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")

    start_time = time.time()
    best_results = []

    for epoch in range(num_epochs):
        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\n🛑 Stop signal detected. Exiting training loop.")
            break

        model.train()
        epoch_loss = 0.0
        class_correct, class_total = {}, {}

        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            logits = model(X_batch).view(-1, output_size)
            y_batch = y_batch.view(-1)
            loss = criterion(logits, y_batch)
            compute_classwise_accuracy(logits, y_batch, class_correct, class_total)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * X_batch.size(0)

        train_loss = epoch_loss / len(train_loader.dataset)
        train_acc = {int(c): f"{(class_correct[c] / class_total[c]) * 100:.2f}%" if class_total[c] > 0 else "0.00%" for c in sorted(class_total.keys())}

        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        val_class_correct, val_class_total = {}, {}

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                logits = model(X_batch).view(-1, output_size)
                y_batch = y_batch.view(-1)
                val_loss += criterion(logits, y_batch).item() * X_batch.size(0)
                predictions = torch.argmax(logits, dim=-1)
                val_correct += (predictions == y_batch).sum().item()
                val_total += y_batch.size(0)
                compute_classwise_accuracy(logits, y_batch, val_class_correct, val_class_total)

        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / val_total
        val_acc_cls = {int(c): f"{(val_class_correct[c] / val_class_total[c]) * 100:.2f}%" if val_class_total[c] > 0 else "0.00%" for c in sorted(val_class_total.keys())}

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, Train-Class-Acc: {train_acc}")
        print(f"Val Loss: {val_loss:.6f}, Val Acc: {val_acc * 100:.2f}%, Val-Class-Acc: {val_acc_cls}, LR: {optimizer.param_groups[0]['lr']:.6f}")

        model_path = os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        current = {
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_accuracy': val_acc,
            'train_classwise_accuracy': train_acc,
            'val_classwise_accuracy': val_acc_cls,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'learning_rate': optimizer.param_groups[0]['lr'],
            'model_path': model_path
        }

        if len(best_results) < 5 or val_acc > best_results[-1]['val_accuracy']:
            if len(best_results) == 5:
                to_remove = best_results.pop()
                if os.path.exists(to_remove['model_path']):
                    os.remove(to_remove['model_path'])
                    print(f"🗑 Removed: {to_remove['model_path']}")
            best_results.append(current)
            best_results.sort(key=lambda x: (x['val_accuracy'], x['epoch']), reverse=True)
            torch.save(current, model_path)
            print(f"✅ Saved model: {model_path}")

        if scheduler:
            scheduler.step(val_loss)

    elapsed_time = time.time() - start_time
    print(f"\n⏳ Total training time: {elapsed_time:.2f} seconds")

    if best_results:
        best = best_results[0]
        best_model_path = os.path.join(model_saving_folder, f"{model_name}_best.pth")
        torch.save(best, best_model_path)
        print(f"\n🏆 Best model saved as: {best_model_path} (Val Accuracy: {best['val_accuracy'] * 100:.2f}%)")

    final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
    torch.save(current, final_model_path)
    print(f"\n📌 Final model saved as: {final_model_path}")

    print("\n🎯 Top 5 Best Models:")
    for res in best_results:
        print(f"Epoch {res['epoch']}, Train Loss: {res['train_loss']:.6f}, Train-Acc: {res['train_classwise_accuracy']},\n"
              f"Val Loss: {res['val_loss']:.6f}, Val Acc: {res['val_accuracy']*100:.2f}%, Val-Acc: {res['val_classwise_accuracy']},"
              f" Model Path: {res['model_path']}")

    model_name_str = model.__class__.__name__
    best_model = max(best_results, key=lambda x: x['val_accuracy'])

    best_md_summary = f"""
    ---
### Period {period}
+ ##### Total training time: {elapsed_time:.2f} seconds
+ ##### Model: {model_name_str}
+ ##### Training and saving in *'{model_saving_folder}'*
+ ##### Best Epoch: {best_model['epoch']}
#### __Val Accuracy: {best_model['val_accuracy'] * 100:.2f}%__
#### __Val-Class-Acc: {best_model['val_classwise_accuracy']}__
    """
    print(best_md_summary.strip())

    del X_train, y_train, X_val, y_val, train_loader, val_loader
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 7025 MiB
#     - Device Name    : NVIDIA RTX A6000

# %% [markdown]
# ## __📋 Label Mapping (HAR Activities)__
#
# | Label ID | Activity Name       |
# |----------|---------------------|
# |    0     | SITTING             |
# |    1     | STANDING            |
# |    2     | WALKING             |
# |    3     | LAYING              |
# |    4     | WALKING_UPSTAIRS    |
# |    5     | WALKING_DOWNSTAIRS  |

# %% [markdown]
# ## __Common Parameters__

# %%
batch_size = 32
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'HAR_CIL/stop_training.txt'))

# %% [markdown]
# ## __PNN Baseline Training For PNN_fc1, PNN_fc_2__

# %% [markdown]
# ---
# ### Period 1
# + ##### Total training time: 159.83 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1'*
# + ##### Best Epoch: 866
# #### __Val Accuracy: 95.31%__
# #### __Val-Class-Acc: {0: '93.48%', 1: '96.99%'}__

# %%
# ================================
# 📌 Period 1 Configuration - HAR_MLP_v2 (PNN Baseline)
# ================================
period = 1

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000

# ==== Saving Path ====
model_name = "HAR_MLP_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"Baseline_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# ==== Model (Baseline HAR MLP for PNN) ====
model = HAR_MLP_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout
).to(device)

# ==== Optimizer / Criterion / Scheduler ====
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# ==== Training ====
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 25663 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
# Epoch 1/1000, Train Loss: 0.690389, Train-Class-Acc: {0: '46.58%', 1: '79.77%'}
# Val Loss: 0.474428, Val Acc: 75.95%, Val-Class-Acc: {0: '56.01%', 1: '94.36%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.457192, Train-Class-Acc: {0: '72.63%', 1: '85.30%'}
# Val Loss: 0.381584, Val Acc: 84.16%, Val-Class-Acc: {0: '94.09%', 1: '75.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.375725, Train-Class-Acc: {0: '78.30%', 1: '87.34%'}
# Val Loss: 0.302174, Val Acc: 87.49%, Val-Class-Acc: {0: '81.87%', 1: '92.67%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.312058, Train-Class-Acc: {0: '83.83%', 1: '88.28%'}
# Val Loss: 0.284711, Val Acc: 87.78%, Val-Class-Acc: {0: '82.48%', 1: '92.67%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.287245, Train-Class-Acc: {0: '86.94%', 1: '89.23%'}
# Val Loss: 0.265544, Val Acc: 88.95%, Val-Class-Acc: {0: '80.86%', 1: '96.43%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.240061, Train-Class-Acc: {0: '89.27%', 1: '91.56%'}
# Val Loss: 0.234259, Val Acc: 90.52%, Val-Class-Acc: {0: '85.34%', 1: '95.30%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.228175, Train-Class-Acc: {0: '89.89%', 1: '91.19%'}
# Val Loss: 0.217027, Val Acc: 92.38%, Val-Class-Acc: {0: '89.82%', 1: '94.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.189299, Train-Class-Acc: {0: '92.85%', 1: '93.16%'}
# Val Loss: 0.232242, Val Acc: 91.50%, Val-Class-Acc: {0: '86.97%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.194260, Train-Class-Acc: {0: '92.69%', 1: '92.36%'}
# Val Loss: 0.188581, Val Acc: 93.45%, Val-Class-Acc: {0: '94.30%', 1: '92.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.164915, Train-Class-Acc: {0: '92.69%', 1: '93.96%'}
# Val Loss: 0.191193, Val Acc: 93.65%, Val-Class-Acc: {0: '94.50%', 1: '92.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.157973, Train-Class-Acc: {0: '94.25%', 1: '93.60%'}
# Val Loss: 0.192687, Val Acc: 92.86%, Val-Class-Acc: {0: '91.85%', 1: '93.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.147923, Train-Class-Acc: {0: '94.25%', 1: '94.83%'}
# Val Loss: 0.225472, Val Acc: 90.22%, Val-Class-Acc: {0: '96.13%', 1: '84.77%'}, LR: 0.000100
# Epoch 13/1000, Train Loss: 0.143773, Train-Class-Acc: {0: '94.25%', 1: '94.47%'}
# Val Loss: 0.191254, Val Acc: 93.06%, Val-Class-Acc: {0: '95.11%', 1: '91.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.143536, Train-Class-Acc: {0: '93.93%', 1: '94.10%'}
# Val Loss: 0.219054, Val Acc: 92.18%, Val-Class-Acc: {0: '86.35%', 1: '97.56%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.127010, Train-Class-Acc: {0: '95.80%', 1: '95.12%'}
# Val Loss: 0.190062, Val Acc: 92.77%, Val-Class-Acc: {0: '94.50%', 1: '91.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.119591, Train-Class-Acc: {0: '95.65%', 1: '96.22%'}
# Val Loss: 0.232623, Val Acc: 91.69%, Val-Class-Acc: {0: '85.54%', 1: '97.37%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.120127, Train-Class-Acc: {0: '96.11%', 1: '95.20%'}
# Val Loss: 0.181718, Val Acc: 93.94%, Val-Class-Acc: {0: '91.65%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.106844, Train-Class-Acc: {0: '96.73%', 1: '95.78%'}
# Val Loss: 0.204795, Val Acc: 92.86%, Val-Class-Acc: {0: '88.59%', 1: '96.80%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.099255, Train-Class-Acc: {0: '96.73%', 1: '96.22%'}
# Val Loss: 0.181348, Val Acc: 94.13%, Val-Class-Acc: {0: '93.69%', 1: '94.55%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.095308, Train-Class-Acc: {0: '96.66%', 1: '96.94%'}
# Val Loss: 0.178747, Val Acc: 93.74%, Val-Class-Acc: {0: '94.50%', 1: '93.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.095629, Train-Class-Acc: {0: '96.73%', 1: '96.65%'}
# Val Loss: 0.188341, Val Acc: 93.65%, Val-Class-Acc: {0: '91.24%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.087409, Train-Class-Acc: {0: '97.82%', 1: '96.58%'}
# Val Loss: 0.181433, Val Acc: 93.94%, Val-Class-Acc: {0: '93.28%', 1: '94.55%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.094085, Train-Class-Acc: {0: '97.12%', 1: '95.92%'}
# Val Loss: 0.228665, Val Acc: 92.77%, Val-Class-Acc: {0: '86.56%', 1: '98.50%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.095489, Train-Class-Acc: {0: '96.35%', 1: '96.87%'}
# Val Loss: 0.244815, Val Acc: 92.38%, Val-Class-Acc: {0: '85.74%', 1: '98.50%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.082674, Train-Class-Acc: {0: '97.05%', 1: '97.31%'}
# Val Loss: 0.189010, Val Acc: 92.96%, Val-Class-Acc: {0: '95.32%', 1: '90.79%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.074400, Train-Class-Acc: {0: '97.28%', 1: '97.45%'}
# Val Loss: 0.189418, Val Acc: 93.94%, Val-Class-Acc: {0: '92.26%', 1: '95.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.075755, Train-Class-Acc: {0: '97.82%', 1: '96.94%'}
# Val Loss: 0.188671, Val Acc: 93.35%, Val-Class-Acc: {0: '94.09%', 1: '92.67%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.082658, Train-Class-Acc: {0: '97.28%', 1: '96.94%'}
# Val Loss: 0.176132, Val Acc: 93.94%, Val-Class-Acc: {0: '94.09%', 1: '93.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.077495, Train-Class-Acc: {0: '96.97%', 1: '97.67%'}
# Val Loss: 0.199217, Val Acc: 94.04%, Val-Class-Acc: {0: '91.04%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.068031, Train-Class-Acc: {0: '97.74%', 1: '97.74%'}
# Val Loss: 0.234045, Val Acc: 93.35%, Val-Class-Acc: {0: '88.80%', 1: '97.56%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.066176, Train-Class-Acc: {0: '98.37%', 1: '97.23%'}
# Val Loss: 0.201066, Val Acc: 93.94%, Val-Class-Acc: {0: '91.24%', 1: '96.43%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.065171, Train-Class-Acc: {0: '97.43%', 1: '97.74%'}
# Val Loss: 0.230406, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.068882, Train-Class-Acc: {0: '97.28%', 1: '97.89%'}
# Val Loss: 0.207115, Val Acc: 92.86%, Val-Class-Acc: {0: '95.52%', 1: '90.41%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.059631, Train-Class-Acc: {0: '97.74%', 1: '97.67%'}
# Val Loss: 0.228410, Val Acc: 93.55%, Val-Class-Acc: {0: '89.21%', 1: '97.56%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.056861, Train-Class-Acc: {0: '98.44%', 1: '97.38%'}
# Val Loss: 0.232313, Val Acc: 93.35%, Val-Class-Acc: {0: '88.59%', 1: '97.74%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.059343, Train-Class-Acc: {0: '97.90%', 1: '98.40%'}
# Val Loss: 0.193668, Val Acc: 94.13%, Val-Class-Acc: {0: '92.46%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.054698, Train-Class-Acc: {0: '98.06%', 1: '97.96%'}
# Val Loss: 0.217197, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.053276, Train-Class-Acc: {0: '97.98%', 1: '98.18%'}
# Val Loss: 0.191589, Val Acc: 94.04%, Val-Class-Acc: {0: '93.28%', 1: '94.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.055797, Train-Class-Acc: {0: '98.06%', 1: '98.03%'}
# Val Loss: 0.191674, Val Acc: 93.94%, Val-Class-Acc: {0: '93.89%', 1: '93.98%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.055634, Train-Class-Acc: {0: '97.82%', 1: '98.11%'}
# Val Loss: 0.197378, Val Acc: 94.13%, Val-Class-Acc: {0: '92.67%', 1: '95.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.052022, Train-Class-Acc: {0: '98.37%', 1: '98.84%'}
# Val Loss: 0.286435, Val Acc: 92.18%, Val-Class-Acc: {0: '84.73%', 1: '99.06%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.046193, Train-Class-Acc: {0: '98.76%', 1: '98.47%'}
# Val Loss: 0.222955, Val Acc: 93.55%, Val-Class-Acc: {0: '92.06%', 1: '94.92%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.054080, Train-Class-Acc: {0: '98.44%', 1: '97.74%'}
# Val Loss: 0.434878, Val Acc: 88.47%, Val-Class-Acc: {0: '76.78%', 1: '99.25%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.056961, Train-Class-Acc: {0: '97.28%', 1: '98.54%'}
# Val Loss: 0.220062, Val Acc: 93.74%, Val-Class-Acc: {0: '89.82%', 1: '97.37%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.040680, Train-Class-Acc: {0: '98.99%', 1: '98.47%'}
# Val Loss: 0.199384, Val Acc: 93.84%, Val-Class-Acc: {0: '93.69%', 1: '93.98%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.044660, Train-Class-Acc: {0: '98.99%', 1: '97.82%'}
# Val Loss: 0.231461, Val Acc: 93.84%, Val-Class-Acc: {0: '91.24%', 1: '96.24%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.045756, Train-Class-Acc: {0: '98.44%', 1: '98.18%'}
# Val Loss: 0.305386, Val Acc: 92.67%, Val-Class-Acc: {0: '85.95%', 1: '98.87%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.047655, Train-Class-Acc: {0: '97.90%', 1: '98.47%'}
# Val Loss: 0.218097, Val Acc: 94.23%, Val-Class-Acc: {0: '92.46%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.045888, Train-Class-Acc: {0: '98.13%', 1: '98.69%'}
# Val Loss: 0.304604, Val Acc: 92.67%, Val-Class-Acc: {0: '86.35%', 1: '98.50%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.045272, Train-Class-Acc: {0: '98.76%', 1: '98.54%'}
# Val Loss: 0.237398, Val Acc: 93.94%, Val-Class-Acc: {0: '90.02%', 1: '97.56%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.040781, Train-Class-Acc: {0: '98.83%', 1: '98.11%'}
# Val Loss: 0.217163, Val Acc: 93.74%, Val-Class-Acc: {0: '91.45%', 1: '95.86%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.039692, Train-Class-Acc: {0: '99.07%', 1: '98.62%'}
# Val Loss: 0.228491, Val Acc: 93.84%, Val-Class-Acc: {0: '90.43%', 1: '96.99%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.039938, Train-Class-Acc: {0: '98.37%', 1: '98.91%'}
# Val Loss: 0.196716, Val Acc: 94.72%, Val-Class-Acc: {0: '92.67%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.041118, Train-Class-Acc: {0: '98.68%', 1: '98.54%'}
# Val Loss: 1.101221, Val Acc: 74.00%, Val-Class-Acc: {0: '45.82%', 1: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.041164, Train-Class-Acc: {0: '99.07%', 1: '98.25%'}
# Val Loss: 0.220921, Val Acc: 93.94%, Val-Class-Acc: {0: '91.24%', 1: '96.43%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.039760, Train-Class-Acc: {0: '98.68%', 1: '98.98%'}
# Val Loss: 0.209653, Val Acc: 93.74%, Val-Class-Acc: {0: '92.06%', 1: '95.30%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.033319, Train-Class-Acc: {0: '99.07%', 1: '99.05%'}
# Val Loss: 0.222859, Val Acc: 93.94%, Val-Class-Acc: {0: '93.48%', 1: '94.36%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.027332, Train-Class-Acc: {0: '99.46%', 1: '98.84%'}
# Val Loss: 0.216891, Val Acc: 94.13%, Val-Class-Acc: {0: '92.26%', 1: '95.86%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.035290, Train-Class-Acc: {0: '99.14%', 1: '98.98%'}
# Val Loss: 0.263192, Val Acc: 93.26%, Val-Class-Acc: {0: '89.00%', 1: '97.18%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.034253, Train-Class-Acc: {0: '99.07%', 1: '98.84%'}
# Val Loss: 0.236177, Val Acc: 94.04%, Val-Class-Acc: {0: '92.06%', 1: '95.86%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.026572, Train-Class-Acc: {0: '99.53%', 1: '99.27%'}
# Val Loss: 0.215284, Val Acc: 94.33%, Val-Class-Acc: {0: '93.69%', 1: '94.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.024028, Train-Class-Acc: {0: '99.30%', 1: '99.20%'}
# Val Loss: 0.238197, Val Acc: 94.33%, Val-Class-Acc: {0: '91.45%', 1: '96.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.034589, Train-Class-Acc: {0: '98.68%', 1: '99.05%'}
# Val Loss: 0.224878, Val Acc: 93.74%, Val-Class-Acc: {0: '93.48%', 1: '93.98%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.030835, Train-Class-Acc: {0: '99.22%', 1: '98.76%'}
# Val Loss: 0.219177, Val Acc: 94.43%, Val-Class-Acc: {0: '95.52%', 1: '93.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_64.pth
# Epoch 65/1000, Train Loss: 0.031727, Train-Class-Acc: {0: '99.07%', 1: '99.34%'}
# Val Loss: 0.237112, Val Acc: 93.94%, Val-Class-Acc: {0: '90.43%', 1: '97.18%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.034662, Train-Class-Acc: {0: '99.22%', 1: '98.84%'}
# Val Loss: 0.290901, Val Acc: 93.16%, Val-Class-Acc: {0: '88.19%', 1: '97.74%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.023765, Train-Class-Acc: {0: '99.46%', 1: '99.20%'}
# Val Loss: 0.230526, Val Acc: 94.23%, Val-Class-Acc: {0: '92.06%', 1: '96.24%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.030644, Train-Class-Acc: {0: '99.07%', 1: '98.54%'}
# Val Loss: 0.213518, Val Acc: 94.23%, Val-Class-Acc: {0: '92.87%', 1: '95.49%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.031883, Train-Class-Acc: {0: '99.14%', 1: '99.05%'}
# Val Loss: 0.240147, Val Acc: 94.13%, Val-Class-Acc: {0: '91.24%', 1: '96.80%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.029960, Train-Class-Acc: {0: '99.07%', 1: '98.62%'}
# Val Loss: 0.219792, Val Acc: 94.62%, Val-Class-Acc: {0: '93.08%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_70.pth
# Epoch 71/1000, Train Loss: 0.024115, Train-Class-Acc: {0: '99.30%', 1: '99.42%'}
# Val Loss: 0.250312, Val Acc: 91.98%, Val-Class-Acc: {0: '96.33%', 1: '87.97%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.035797, Train-Class-Acc: {0: '98.13%', 1: '98.84%'}
# Val Loss: 0.228545, Val Acc: 94.72%, Val-Class-Acc: {0: '93.08%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.023749, Train-Class-Acc: {0: '99.30%', 1: '99.56%'}
# Val Loss: 0.312815, Val Acc: 92.47%, Val-Class-Acc: {0: '86.76%', 1: '97.74%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.026845, Train-Class-Acc: {0: '99.22%', 1: '98.84%'}
# Val Loss: 0.368568, Val Acc: 91.69%, Val-Class-Acc: {0: '83.71%', 1: '99.06%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.019879, Train-Class-Acc: {0: '99.07%', 1: '99.78%'}
# Val Loss: 0.289869, Val Acc: 93.65%, Val-Class-Acc: {0: '88.19%', 1: '98.68%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.027135, Train-Class-Acc: {0: '99.30%', 1: '99.27%'}
# Val Loss: 0.272941, Val Acc: 93.65%, Val-Class-Acc: {0: '90.22%', 1: '96.80%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.034559, Train-Class-Acc: {0: '99.46%', 1: '98.69%'}
# Val Loss: 0.291835, Val Acc: 93.35%, Val-Class-Acc: {0: '88.19%', 1: '98.12%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.024423, Train-Class-Acc: {0: '99.14%', 1: '99.27%'}
# Val Loss: 0.391327, Val Acc: 91.69%, Val-Class-Acc: {0: '83.30%', 1: '99.44%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.027103, Train-Class-Acc: {0: '99.30%', 1: '99.20%'}
# Val Loss: 0.264471, Val Acc: 92.57%, Val-Class-Acc: {0: '95.93%', 1: '89.47%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.019011, Train-Class-Acc: {0: '99.30%', 1: '99.64%'}
# Val Loss: 0.220690, Val Acc: 94.33%, Val-Class-Acc: {0: '94.30%', 1: '94.36%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.021917, Train-Class-Acc: {0: '99.61%', 1: '99.34%'}
# Val Loss: 0.258475, Val Acc: 93.74%, Val-Class-Acc: {0: '89.41%', 1: '97.74%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.023707, Train-Class-Acc: {0: '99.30%', 1: '99.27%'}
# Val Loss: 0.252278, Val Acc: 94.33%, Val-Class-Acc: {0: '90.84%', 1: '97.56%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.017795, Train-Class-Acc: {0: '99.38%', 1: '99.71%'}
# Val Loss: 0.369453, Val Acc: 91.79%, Val-Class-Acc: {0: '84.32%', 1: '98.68%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.024690, Train-Class-Acc: {0: '99.46%', 1: '99.27%'}
# Val Loss: 0.258526, Val Acc: 93.84%, Val-Class-Acc: {0: '91.24%', 1: '96.24%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.020671, Train-Class-Acc: {0: '99.38%', 1: '99.42%'}
# Val Loss: 0.224612, Val Acc: 93.84%, Val-Class-Acc: {0: '91.24%', 1: '96.24%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.022607, Train-Class-Acc: {0: '99.53%', 1: '99.05%'}
# Val Loss: 0.290465, Val Acc: 93.74%, Val-Class-Acc: {0: '89.21%', 1: '97.93%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.017905, Train-Class-Acc: {0: '99.38%', 1: '99.27%'}
# Val Loss: 0.287802, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.026670, Train-Class-Acc: {0: '99.46%', 1: '99.27%'}
# Val Loss: 0.221851, Val Acc: 94.53%, Val-Class-Acc: {0: '91.65%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_88.pth
# Epoch 89/1000, Train Loss: 0.029694, Train-Class-Acc: {0: '98.99%', 1: '98.91%'}
# Val Loss: 0.236905, Val Acc: 94.13%, Val-Class-Acc: {0: '92.87%', 1: '95.30%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.024996, Train-Class-Acc: {0: '99.07%', 1: '99.42%'}
# Val Loss: 0.372170, Val Acc: 91.59%, Val-Class-Acc: {0: '83.30%', 1: '99.25%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.024187, Train-Class-Acc: {0: '99.53%', 1: '99.05%'}
# Val Loss: 0.267245, Val Acc: 93.84%, Val-Class-Acc: {0: '89.21%', 1: '98.12%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.020875, Train-Class-Acc: {0: '99.30%', 1: '99.20%'}
# Val Loss: 0.248072, Val Acc: 94.72%, Val-Class-Acc: {0: '92.46%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_64.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_92.pth
# Epoch 93/1000, Train Loss: 0.016372, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.249731, Val Acc: 94.33%, Val-Class-Acc: {0: '90.22%', 1: '98.12%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.022185, Train-Class-Acc: {0: '99.14%', 1: '99.56%'}
# Val Loss: 0.381500, Val Acc: 91.69%, Val-Class-Acc: {0: '83.30%', 1: '99.44%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.019483, Train-Class-Acc: {0: '99.30%', 1: '99.64%'}
# Val Loss: 0.231096, Val Acc: 93.74%, Val-Class-Acc: {0: '93.69%', 1: '93.80%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.017539, Train-Class-Acc: {0: '99.38%', 1: '99.34%'}
# Val Loss: 0.320444, Val Acc: 93.35%, Val-Class-Acc: {0: '87.58%', 1: '98.68%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.018591, Train-Class-Acc: {0: '99.77%', 1: '99.05%'}
# Val Loss: 0.264440, Val Acc: 93.65%, Val-Class-Acc: {0: '90.22%', 1: '96.80%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.022471, Train-Class-Acc: {0: '99.14%', 1: '99.20%'}
# Val Loss: 0.347327, Val Acc: 92.77%, Val-Class-Acc: {0: '86.35%', 1: '98.68%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.022907, Train-Class-Acc: {0: '99.61%', 1: '99.49%'}
# Val Loss: 0.297206, Val Acc: 94.04%, Val-Class-Acc: {0: '89.61%', 1: '98.12%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.021340, Train-Class-Acc: {0: '99.46%', 1: '99.71%'}
# Val Loss: 0.259573, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '97.18%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.020334, Train-Class-Acc: {0: '99.77%', 1: '99.13%'}
# Val Loss: 0.235882, Val Acc: 94.92%, Val-Class-Acc: {0: '92.87%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_88.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_101.pth
# Epoch 102/1000, Train Loss: 0.018565, Train-Class-Acc: {0: '99.30%', 1: '99.64%'}
# Val Loss: 0.253401, Val Acc: 93.45%, Val-Class-Acc: {0: '95.11%', 1: '91.92%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.022336, Train-Class-Acc: {0: '99.14%', 1: '98.91%'}
# Val Loss: 0.303018, Val Acc: 93.84%, Val-Class-Acc: {0: '89.61%', 1: '97.74%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.014235, Train-Class-Acc: {0: '99.38%', 1: '99.78%'}
# Val Loss: 0.243379, Val Acc: 94.33%, Val-Class-Acc: {0: '93.69%', 1: '94.92%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.015710, Train-Class-Acc: {0: '99.61%', 1: '99.42%'}
# Val Loss: 0.306192, Val Acc: 93.74%, Val-Class-Acc: {0: '88.80%', 1: '98.31%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.016246, Train-Class-Acc: {0: '99.53%', 1: '99.64%'}
# Val Loss: 0.301258, Val Acc: 94.04%, Val-Class-Acc: {0: '89.41%', 1: '98.31%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.025666, Train-Class-Acc: {0: '99.14%', 1: '99.27%'}
# Val Loss: 0.238963, Val Acc: 94.04%, Val-Class-Acc: {0: '95.72%', 1: '92.48%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.027486, Train-Class-Acc: {0: '99.22%', 1: '99.20%'}
# Val Loss: 0.269929, Val Acc: 94.43%, Val-Class-Acc: {0: '90.22%', 1: '98.31%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.024085, Train-Class-Acc: {0: '98.44%', 1: '99.49%'}
# Val Loss: 0.244203, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.018392, Train-Class-Acc: {0: '99.46%', 1: '99.34%'}
# Val Loss: 0.426484, Val Acc: 90.71%, Val-Class-Acc: {0: '82.08%', 1: '98.68%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.012124, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.305698, Val Acc: 93.65%, Val-Class-Acc: {0: '88.59%', 1: '98.31%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.019051, Train-Class-Acc: {0: '99.53%', 1: '99.20%'}
# Val Loss: 0.244048, Val Acc: 94.33%, Val-Class-Acc: {0: '92.26%', 1: '96.24%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.011910, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.311725, Val Acc: 93.35%, Val-Class-Acc: {0: '88.39%', 1: '97.93%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.018044, Train-Class-Acc: {0: '99.30%', 1: '99.42%'}
# Val Loss: 0.300018, Val Acc: 93.45%, Val-Class-Acc: {0: '88.19%', 1: '98.31%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.019535, Train-Class-Acc: {0: '99.46%', 1: '99.20%'}
# Val Loss: 0.353524, Val Acc: 92.77%, Val-Class-Acc: {0: '86.76%', 1: '98.31%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.019173, Train-Class-Acc: {0: '99.30%', 1: '99.56%'}
# Val Loss: 0.495118, Val Acc: 89.35%, Val-Class-Acc: {0: '78.21%', 1: '99.62%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.016002, Train-Class-Acc: {0: '99.30%', 1: '99.49%'}
# Val Loss: 0.444132, Val Acc: 91.98%, Val-Class-Acc: {0: '84.73%', 1: '98.68%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.016467, Train-Class-Acc: {0: '99.53%', 1: '99.20%'}
# Val Loss: 0.360706, Val Acc: 92.77%, Val-Class-Acc: {0: '85.95%', 1: '99.06%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.015001, Train-Class-Acc: {0: '99.38%', 1: '99.93%'}
# Val Loss: 0.262267, Val Acc: 94.43%, Val-Class-Acc: {0: '91.85%', 1: '96.80%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.017807, Train-Class-Acc: {0: '99.22%', 1: '99.71%'}
# Val Loss: 0.261547, Val Acc: 94.23%, Val-Class-Acc: {0: '89.61%', 1: '98.50%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.009710, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.265918, Val Acc: 94.62%, Val-Class-Acc: {0: '91.24%', 1: '97.74%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.020615, Train-Class-Acc: {0: '99.46%', 1: '99.34%'}
# Val Loss: 0.229778, Val Acc: 93.74%, Val-Class-Acc: {0: '93.28%', 1: '94.17%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.016480, Train-Class-Acc: {0: '99.53%', 1: '99.20%'}
# Val Loss: 0.252070, Val Acc: 94.92%, Val-Class-Acc: {0: '91.45%', 1: '98.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_70.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_123.pth
# Epoch 124/1000, Train Loss: 0.017116, Train-Class-Acc: {0: '99.84%', 1: '99.27%'}
# Val Loss: 0.347075, Val Acc: 93.74%, Val-Class-Acc: {0: '87.78%', 1: '99.25%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.016840, Train-Class-Acc: {0: '99.53%', 1: '99.42%'}
# Val Loss: 0.233185, Val Acc: 94.62%, Val-Class-Acc: {0: '94.50%', 1: '94.74%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.012977, Train-Class-Acc: {0: '99.38%', 1: '99.85%'}
# Val Loss: 0.265337, Val Acc: 94.43%, Val-Class-Acc: {0: '90.22%', 1: '98.31%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.025764, Train-Class-Acc: {0: '99.46%', 1: '99.42%'}
# Val Loss: 0.243172, Val Acc: 94.62%, Val-Class-Acc: {0: '91.65%', 1: '97.37%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.021822, Train-Class-Acc: {0: '99.38%', 1: '99.42%'}
# Val Loss: 0.232776, Val Acc: 94.82%, Val-Class-Acc: {0: '91.85%', 1: '97.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_128.pth
# Epoch 129/1000, Train Loss: 0.014946, Train-Class-Acc: {0: '99.38%', 1: '99.56%'}
# Val Loss: 0.269830, Val Acc: 94.72%, Val-Class-Acc: {0: '91.04%', 1: '98.12%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.011174, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.305138, Val Acc: 93.74%, Val-Class-Acc: {0: '88.39%', 1: '98.68%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.013816, Train-Class-Acc: {0: '99.92%', 1: '99.34%'}
# Val Loss: 0.263234, Val Acc: 94.92%, Val-Class-Acc: {0: '91.45%', 1: '98.12%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_131.pth
# Epoch 132/1000, Train Loss: 0.018066, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.405345, Val Acc: 91.89%, Val-Class-Acc: {0: '84.32%', 1: '98.87%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.017310, Train-Class-Acc: {0: '99.46%', 1: '99.34%'}
# Val Loss: 0.266292, Val Acc: 93.16%, Val-Class-Acc: {0: '95.93%', 1: '90.60%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.014565, Train-Class-Acc: {0: '99.53%', 1: '99.34%'}
# Val Loss: 0.334102, Val Acc: 92.77%, Val-Class-Acc: {0: '86.35%', 1: '98.68%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.016419, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.241481, Val Acc: 94.82%, Val-Class-Acc: {0: '94.70%', 1: '94.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_92.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_135.pth
# Epoch 136/1000, Train Loss: 0.018819, Train-Class-Acc: {0: '99.61%', 1: '98.98%'}
# Val Loss: 0.353176, Val Acc: 93.16%, Val-Class-Acc: {0: '87.98%', 1: '97.93%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.016589, Train-Class-Acc: {0: '99.53%', 1: '99.42%'}
# Val Loss: 0.287176, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.015491, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.369247, Val Acc: 92.86%, Val-Class-Acc: {0: '86.76%', 1: '98.50%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.014608, Train-Class-Acc: {0: '99.61%', 1: '99.34%'}
# Val Loss: 0.254960, Val Acc: 94.62%, Val-Class-Acc: {0: '93.48%', 1: '95.68%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.013847, Train-Class-Acc: {0: '99.46%', 1: '99.64%'}
# Val Loss: 0.289662, Val Acc: 94.53%, Val-Class-Acc: {0: '91.85%', 1: '96.99%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.010143, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.295984, Val Acc: 94.04%, Val-Class-Acc: {0: '90.84%', 1: '96.99%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.015066, Train-Class-Acc: {0: '99.46%', 1: '99.56%'}
# Val Loss: 0.248934, Val Acc: 94.72%, Val-Class-Acc: {0: '93.28%', 1: '96.05%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.015778, Train-Class-Acc: {0: '99.77%', 1: '99.20%'}
# Val Loss: 0.364312, Val Acc: 93.16%, Val-Class-Acc: {0: '87.17%', 1: '98.68%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.017141, Train-Class-Acc: {0: '99.38%', 1: '99.27%'}
# Val Loss: 0.249508, Val Acc: 95.11%, Val-Class-Acc: {0: '93.28%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_128.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_144.pth
# Epoch 145/1000, Train Loss: 0.017333, Train-Class-Acc: {0: '99.30%', 1: '99.56%'}
# Val Loss: 0.409920, Val Acc: 92.28%, Val-Class-Acc: {0: '85.54%', 1: '98.50%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.020773, Train-Class-Acc: {0: '99.22%', 1: '99.64%'}
# Val Loss: 0.311989, Val Acc: 92.28%, Val-Class-Acc: {0: '95.11%', 1: '89.66%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.018798, Train-Class-Acc: {0: '99.46%', 1: '99.56%'}
# Val Loss: 0.276527, Val Acc: 94.23%, Val-Class-Acc: {0: '91.45%', 1: '96.80%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.012325, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.403888, Val Acc: 92.47%, Val-Class-Acc: {0: '85.74%', 1: '98.68%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.009177, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.313514, Val Acc: 94.04%, Val-Class-Acc: {0: '89.82%', 1: '97.93%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.016840, Train-Class-Acc: {0: '99.46%', 1: '99.64%'}
# Val Loss: 0.276593, Val Acc: 94.13%, Val-Class-Acc: {0: '91.45%', 1: '96.62%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.009086, Train-Class-Acc: {0: '99.92%', 1: '99.64%'}
# Val Loss: 0.320073, Val Acc: 93.94%, Val-Class-Acc: {0: '89.82%', 1: '97.74%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.017097, Train-Class-Acc: {0: '99.30%', 1: '99.34%'}
# Val Loss: 0.283834, Val Acc: 94.13%, Val-Class-Acc: {0: '92.67%', 1: '95.49%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.011431, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.390739, Val Acc: 92.86%, Val-Class-Acc: {0: '86.56%', 1: '98.68%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.010779, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.283907, Val Acc: 93.84%, Val-Class-Acc: {0: '93.89%', 1: '93.80%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.009714, Train-Class-Acc: {0: '99.69%', 1: '99.85%'}
# Val Loss: 0.286819, Val Acc: 94.53%, Val-Class-Acc: {0: '93.28%', 1: '95.68%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.010186, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.301548, Val Acc: 94.43%, Val-Class-Acc: {0: '91.45%', 1: '97.18%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.022104, Train-Class-Acc: {0: '98.99%', 1: '99.56%'}
# Val Loss: 0.335742, Val Acc: 93.94%, Val-Class-Acc: {0: '90.02%', 1: '97.56%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.015547, Train-Class-Acc: {0: '99.77%', 1: '99.34%'}
# Val Loss: 0.346242, Val Acc: 94.04%, Val-Class-Acc: {0: '89.41%', 1: '98.31%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.013940, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.368201, Val Acc: 93.45%, Val-Class-Acc: {0: '87.78%', 1: '98.68%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.013848, Train-Class-Acc: {0: '99.38%', 1: '99.85%'}
# Val Loss: 0.374064, Val Acc: 93.35%, Val-Class-Acc: {0: '87.78%', 1: '98.50%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.010669, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.285259, Val Acc: 93.84%, Val-Class-Acc: {0: '92.87%', 1: '94.74%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.010775, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.357318, Val Acc: 93.16%, Val-Class-Acc: {0: '87.78%', 1: '98.12%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.015627, Train-Class-Acc: {0: '99.61%', 1: '99.42%'}
# Val Loss: 0.357693, Val Acc: 92.57%, Val-Class-Acc: {0: '86.35%', 1: '98.31%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.009759, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.277638, Val Acc: 94.62%, Val-Class-Acc: {0: '93.08%', 1: '96.05%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.015507, Train-Class-Acc: {0: '99.61%', 1: '99.49%'}
# Val Loss: 0.268163, Val Acc: 94.13%, Val-Class-Acc: {0: '93.69%', 1: '94.55%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.008866, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.324431, Val Acc: 94.13%, Val-Class-Acc: {0: '90.84%', 1: '97.18%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.020795, Train-Class-Acc: {0: '99.61%', 1: '99.20%'}
# Val Loss: 0.294183, Val Acc: 94.23%, Val-Class-Acc: {0: '92.26%', 1: '96.05%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.011118, Train-Class-Acc: {0: '99.53%', 1: '99.71%'}
# Val Loss: 0.297203, Val Acc: 94.62%, Val-Class-Acc: {0: '93.08%', 1: '96.05%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.012976, Train-Class-Acc: {0: '99.38%', 1: '99.71%'}
# Val Loss: 0.406115, Val Acc: 92.67%, Val-Class-Acc: {0: '86.56%', 1: '98.31%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.013451, Train-Class-Acc: {0: '99.46%', 1: '99.71%'}
# Val Loss: 0.277615, Val Acc: 94.04%, Val-Class-Acc: {0: '93.69%', 1: '94.36%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.012886, Train-Class-Acc: {0: '99.46%', 1: '99.71%'}
# Val Loss: 0.413046, Val Acc: 93.06%, Val-Class-Acc: {0: '87.37%', 1: '98.31%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.008713, Train-Class-Acc: {0: '99.53%', 1: '99.78%'}
# Val Loss: 0.552250, Val Acc: 84.46%, Val-Class-Acc: {0: '96.54%', 1: '73.31%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.012907, Train-Class-Acc: {0: '99.77%', 1: '99.49%'}
# Val Loss: 0.550625, Val Acc: 90.81%, Val-Class-Acc: {0: '81.47%', 1: '99.44%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.014311, Train-Class-Acc: {0: '99.61%', 1: '99.49%'}
# Val Loss: 0.335891, Val Acc: 94.33%, Val-Class-Acc: {0: '92.67%', 1: '95.86%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.009039, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.339501, Val Acc: 94.04%, Val-Class-Acc: {0: '90.63%', 1: '97.18%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.014416, Train-Class-Acc: {0: '99.30%', 1: '99.85%'}
# Val Loss: 0.333850, Val Acc: 94.43%, Val-Class-Acc: {0: '91.85%', 1: '96.80%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.014675, Train-Class-Acc: {0: '99.77%', 1: '99.42%'}
# Val Loss: 0.333047, Val Acc: 94.13%, Val-Class-Acc: {0: '91.24%', 1: '96.80%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.009747, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.296261, Val Acc: 94.23%, Val-Class-Acc: {0: '92.06%', 1: '96.24%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.016543, Train-Class-Acc: {0: '99.53%', 1: '99.42%'}
# Val Loss: 0.327357, Val Acc: 93.94%, Val-Class-Acc: {0: '90.84%', 1: '96.80%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.007894, Train-Class-Acc: {0: '99.84%', 1: '99.64%'}
# Val Loss: 0.286635, Val Acc: 93.94%, Val-Class-Acc: {0: '93.89%', 1: '93.98%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.012331, Train-Class-Acc: {0: '99.53%', 1: '99.78%'}
# Val Loss: 0.311300, Val Acc: 94.53%, Val-Class-Acc: {0: '92.26%', 1: '96.62%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.012038, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.319284, Val Acc: 94.33%, Val-Class-Acc: {0: '92.26%', 1: '96.24%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.011359, Train-Class-Acc: {0: '99.84%', 1: '99.56%'}
# Val Loss: 0.445085, Val Acc: 91.89%, Val-Class-Acc: {0: '84.52%', 1: '98.68%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.014858, Train-Class-Acc: {0: '99.30%', 1: '99.64%'}
# Val Loss: 0.287044, Val Acc: 94.13%, Val-Class-Acc: {0: '91.65%', 1: '96.43%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.007361, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.346127, Val Acc: 93.94%, Val-Class-Acc: {0: '90.02%', 1: '97.56%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.014763, Train-Class-Acc: {0: '99.61%', 1: '99.34%'}
# Val Loss: 0.418487, Val Acc: 92.77%, Val-Class-Acc: {0: '86.56%', 1: '98.50%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.015987, Train-Class-Acc: {0: '99.38%', 1: '99.56%'}
# Val Loss: 0.324260, Val Acc: 93.94%, Val-Class-Acc: {0: '92.26%', 1: '95.49%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.008471, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.330062, Val Acc: 94.04%, Val-Class-Acc: {0: '90.84%', 1: '96.99%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.011892, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.330993, Val Acc: 94.04%, Val-Class-Acc: {0: '90.22%', 1: '97.56%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.014086, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.291394, Val Acc: 92.96%, Val-Class-Acc: {0: '94.30%', 1: '91.73%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.010650, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.346865, Val Acc: 93.94%, Val-Class-Acc: {0: '89.82%', 1: '97.74%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.008818, Train-Class-Acc: {0: '99.46%', 1: '99.71%'}
# Val Loss: 0.373201, Val Acc: 93.55%, Val-Class-Acc: {0: '88.80%', 1: '97.93%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.006107, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.299079, Val Acc: 94.62%, Val-Class-Acc: {0: '93.28%', 1: '95.86%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.014487, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.451690, Val Acc: 92.08%, Val-Class-Acc: {0: '84.93%', 1: '98.68%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.007256, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.430478, Val Acc: 92.47%, Val-Class-Acc: {0: '85.74%', 1: '98.68%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.012824, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.359896, Val Acc: 94.13%, Val-Class-Acc: {0: '90.84%', 1: '97.18%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.011026, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.423412, Val Acc: 92.77%, Val-Class-Acc: {0: '86.76%', 1: '98.31%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.012002, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.298031, Val Acc: 94.13%, Val-Class-Acc: {0: '93.69%', 1: '94.55%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.014440, Train-Class-Acc: {0: '99.61%', 1: '99.20%'}
# Val Loss: 0.388036, Val Acc: 93.16%, Val-Class-Acc: {0: '88.19%', 1: '97.74%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.011004, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.324959, Val Acc: 94.04%, Val-Class-Acc: {0: '91.04%', 1: '96.80%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.004954, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.320584, Val Acc: 94.23%, Val-Class-Acc: {0: '91.24%', 1: '96.99%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.007316, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.304380, Val Acc: 94.23%, Val-Class-Acc: {0: '93.08%', 1: '95.30%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.007562, Train-Class-Acc: {0: '99.84%', 1: '99.64%'}
# Val Loss: 0.384172, Val Acc: 93.55%, Val-Class-Acc: {0: '89.61%', 1: '97.18%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.007781, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.619166, Val Acc: 89.25%, Val-Class-Acc: {0: '78.62%', 1: '99.06%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.014890, Train-Class-Acc: {0: '99.69%', 1: '99.64%'}
# Val Loss: 0.317063, Val Acc: 94.53%, Val-Class-Acc: {0: '93.28%', 1: '95.68%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.007474, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.492186, Val Acc: 92.08%, Val-Class-Acc: {0: '84.73%', 1: '98.87%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.009366, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.541453, Val Acc: 90.62%, Val-Class-Acc: {0: '81.67%', 1: '98.87%'}, LR: 0.000100
# Epoch 208/1000, Train Loss: 0.010560, Train-Class-Acc: {0: '99.53%', 1: '99.64%'}
# Val Loss: 0.513843, Val Acc: 91.01%, Val-Class-Acc: {0: '82.48%', 1: '98.87%'}, LR: 0.000100
# Epoch 209/1000, Train Loss: 0.007582, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.340248, Val Acc: 94.23%, Val-Class-Acc: {0: '91.45%', 1: '96.80%'}, LR: 0.000100
# Epoch 210/1000, Train Loss: 0.008758, Train-Class-Acc: {0: '99.84%', 1: '99.56%'}
# Val Loss: 0.386794, Val Acc: 93.55%, Val-Class-Acc: {0: '89.21%', 1: '97.56%'}, LR: 0.000100
# Epoch 211/1000, Train Loss: 0.008944, Train-Class-Acc: {0: '99.69%', 1: '99.85%'}
# Val Loss: 0.311198, Val Acc: 94.23%, Val-Class-Acc: {0: '92.87%', 1: '95.49%'}, LR: 0.000100
# Epoch 212/1000, Train Loss: 0.009063, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.567833, Val Acc: 89.44%, Val-Class-Acc: {0: '78.82%', 1: '99.25%'}, LR: 0.000100
# Epoch 213/1000, Train Loss: 0.004380, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.434753, Val Acc: 92.57%, Val-Class-Acc: {0: '85.95%', 1: '98.68%'}, LR: 0.000100
# Epoch 214/1000, Train Loss: 0.009055, Train-Class-Acc: {0: '99.53%', 1: '99.78%'}
# Val Loss: 0.326608, Val Acc: 94.33%, Val-Class-Acc: {0: '91.45%', 1: '96.99%'}, LR: 0.000100
# Epoch 215/1000, Train Loss: 0.009585, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.371991, Val Acc: 94.33%, Val-Class-Acc: {0: '90.84%', 1: '97.56%'}, LR: 0.000100
# Epoch 216/1000, Train Loss: 0.008296, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.367290, Val Acc: 93.84%, Val-Class-Acc: {0: '89.82%', 1: '97.56%'}, LR: 0.000100
# Epoch 217/1000, Train Loss: 0.008976, Train-Class-Acc: {0: '99.69%', 1: '99.85%'}
# Val Loss: 0.449370, Val Acc: 92.96%, Val-Class-Acc: {0: '86.97%', 1: '98.50%'}, LR: 0.000100
# Epoch 218/1000, Train Loss: 0.012621, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.454393, Val Acc: 92.96%, Val-Class-Acc: {0: '87.37%', 1: '98.12%'}, LR: 0.000100
# Epoch 219/1000, Train Loss: 0.008201, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.325391, Val Acc: 94.43%, Val-Class-Acc: {0: '91.65%', 1: '96.99%'}, LR: 0.000100
# Epoch 220/1000, Train Loss: 0.011099, Train-Class-Acc: {0: '99.84%', 1: '99.49%'}
# Val Loss: 0.534748, Val Acc: 90.52%, Val-Class-Acc: {0: '81.67%', 1: '98.68%'}, LR: 0.000100
# Epoch 221/1000, Train Loss: 0.008194, Train-Class-Acc: {0: '99.92%', 1: '99.64%'}
# Val Loss: 0.324853, Val Acc: 94.43%, Val-Class-Acc: {0: '92.87%', 1: '95.86%'}, LR: 0.000100
# Epoch 222/1000, Train Loss: 0.008361, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.577908, Val Acc: 90.71%, Val-Class-Acc: {0: '81.87%', 1: '98.87%'}, LR: 0.000100
# Epoch 223/1000, Train Loss: 0.011967, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.617692, Val Acc: 89.35%, Val-Class-Acc: {0: '78.82%', 1: '99.06%'}, LR: 0.000100
# Epoch 224/1000, Train Loss: 0.007287, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.329747, Val Acc: 93.35%, Val-Class-Acc: {0: '93.48%', 1: '93.23%'}, LR: 0.000100
# Epoch 225/1000, Train Loss: 0.006901, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.330722, Val Acc: 93.45%, Val-Class-Acc: {0: '93.48%', 1: '93.42%'}, LR: 0.000100
# Epoch 226/1000, Train Loss: 0.011345, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.418626, Val Acc: 93.65%, Val-Class-Acc: {0: '89.00%', 1: '97.93%'}, LR: 0.000100
# Epoch 227/1000, Train Loss: 0.012909, Train-Class-Acc: {0: '99.53%', 1: '99.93%'}
# ...
# Val Loss: 0.694158, Val Acc: 88.95%, Val-Class-Acc: {0: '77.39%', 1: '99.62%'}, LR: 0.000100
# Epoch 925/1000, Train Loss: 0.004247, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.339576, Val Acc: 94.33%, Val-Class-Acc: {0: '94.50%', 1: '94.17%'}, LR: 0.000100
# Epoch 926/1000, Train Loss: 0.002811, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.385668, Val Acc: 93.94%, Val-Class-Acc: {0: '90.02%', 1: '97.56%'}, LR: 0.000100
# Epoch 927/1000, Train Loss: 0.003353, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.393188, Val Acc: 93.84%, Val-Class-Acc: {0: '90.02%', 1: '97.37%'}, LR: 0.000100
# Epoch 928/1000, Train Loss: 0.004063, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.351135, Val Acc: 93.74%, Val-Class-Acc: {0: '91.85%', 1: '95.49%'}, LR: 0.000100
# Epoch 929/1000, Train Loss: 0.003011, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.431282, Val Acc: 93.65%, Val-Class-Acc: {0: '89.41%', 1: '97.56%'}, LR: 0.000100
# Epoch 930/1000, Train Loss: 0.003860, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.534173, Val Acc: 91.69%, Val-Class-Acc: {0: '84.11%', 1: '98.68%'}, LR: 0.000100
# Epoch 931/1000, Train Loss: 0.007892, Train-Class-Acc: {0: '99.69%', 1: '99.85%'}
# Val Loss: 0.333278, Val Acc: 94.43%, Val-Class-Acc: {0: '94.70%', 1: '94.17%'}, LR: 0.000100
# Epoch 932/1000, Train Loss: 0.005548, Train-Class-Acc: {0: '99.84%', 1: '99.71%'}
# Val Loss: 0.352758, Val Acc: 94.62%, Val-Class-Acc: {0: '93.28%', 1: '95.86%'}, LR: 0.000100
# Epoch 933/1000, Train Loss: 0.008403, Train-Class-Acc: {0: '99.84%', 1: '99.49%'}
# Val Loss: 0.364267, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '97.18%'}, LR: 0.000100
# Epoch 934/1000, Train Loss: 0.003906, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.383899, Val Acc: 94.13%, Val-Class-Acc: {0: '90.84%', 1: '97.18%'}, LR: 0.000100
# Epoch 935/1000, Train Loss: 0.006356, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.397606, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 936/1000, Train Loss: 0.003803, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.392648, Val Acc: 94.92%, Val-Class-Acc: {0: '92.46%', 1: '97.18%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.009161, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.430271, Val Acc: 93.84%, Val-Class-Acc: {0: '89.00%', 1: '98.31%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.003857, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.364436, Val Acc: 94.62%, Val-Class-Acc: {0: '93.08%', 1: '96.05%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.004876, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.411390, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.003814, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.392409, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.005301, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.361569, Val Acc: 94.43%, Val-Class-Acc: {0: '91.65%', 1: '96.99%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.006809, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.376630, Val Acc: 94.72%, Val-Class-Acc: {0: '91.45%', 1: '97.74%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.003849, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.392661, Val Acc: 93.94%, Val-Class-Acc: {0: '90.02%', 1: '97.56%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.005587, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.387748, Val Acc: 94.04%, Val-Class-Acc: {0: '89.61%', 1: '98.12%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.003296, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.336403, Val Acc: 95.01%, Val-Class-Acc: {0: '93.48%', 1: '96.43%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.003292, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.395624, Val Acc: 93.94%, Val-Class-Acc: {0: '89.41%', 1: '98.12%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.005673, Train-Class-Acc: {0: '99.92%', 1: '99.56%'}
# Val Loss: 0.392795, Val Acc: 94.23%, Val-Class-Acc: {0: '89.61%', 1: '98.50%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.002215, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.367017, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.012630, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.412942, Val Acc: 93.84%, Val-Class-Acc: {0: '88.80%', 1: '98.50%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.003040, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.335458, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.006025, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.338261, Val Acc: 93.74%, Val-Class-Acc: {0: '95.11%', 1: '92.48%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.003438, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.365938, Val Acc: 93.65%, Val-Class-Acc: {0: '88.39%', 1: '98.50%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.006325, Train-Class-Acc: {0: '99.69%', 1: '100.00%'}
# Val Loss: 0.386044, Val Acc: 93.45%, Val-Class-Acc: {0: '87.98%', 1: '98.50%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.003918, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.349459, Val Acc: 94.04%, Val-Class-Acc: {0: '90.02%', 1: '97.74%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.004152, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.328160, Val Acc: 94.43%, Val-Class-Acc: {0: '91.24%', 1: '97.37%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.005571, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.305928, Val Acc: 94.04%, Val-Class-Acc: {0: '94.50%', 1: '93.61%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.006497, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.458744, Val Acc: 92.28%, Val-Class-Acc: {0: '84.93%', 1: '99.06%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.004570, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.358726, Val Acc: 93.65%, Val-Class-Acc: {0: '95.32%', 1: '92.11%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.012374, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.368247, Val Acc: 94.43%, Val-Class-Acc: {0: '93.48%', 1: '95.30%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.003732, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.353617, Val Acc: 94.62%, Val-Class-Acc: {0: '92.06%', 1: '96.99%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.004392, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.343198, Val Acc: 94.23%, Val-Class-Acc: {0: '93.69%', 1: '94.74%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.004107, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.929322, Val Acc: 85.73%, Val-Class-Acc: {0: '70.88%', 1: '99.44%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.008258, Train-Class-Acc: {0: '99.46%', 1: '100.00%'}
# Val Loss: 0.485384, Val Acc: 91.98%, Val-Class-Acc: {0: '84.52%', 1: '98.87%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.007745, Train-Class-Acc: {0: '99.53%', 1: '99.85%'}
# Val Loss: 0.345911, Val Acc: 94.53%, Val-Class-Acc: {0: '92.06%', 1: '96.80%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.006447, Train-Class-Acc: {0: '100.00%', 1: '99.64%'}
# Val Loss: 0.375069, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.005831, Train-Class-Acc: {0: '99.53%', 1: '99.93%'}
# Val Loss: 0.362254, Val Acc: 94.13%, Val-Class-Acc: {0: '89.41%', 1: '98.50%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.004208, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.394566, Val Acc: 93.65%, Val-Class-Acc: {0: '88.39%', 1: '98.50%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.004530, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.346776, Val Acc: 94.23%, Val-Class-Acc: {0: '90.43%', 1: '97.74%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.003073, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.413606, Val Acc: 93.55%, Val-Class-Acc: {0: '88.19%', 1: '98.50%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.002445, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.347331, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.001451, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.341573, Val Acc: 94.62%, Val-Class-Acc: {0: '91.45%', 1: '97.56%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.006711, Train-Class-Acc: {0: '99.92%', 1: '99.64%'}
# Val Loss: 0.401787, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.003369, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.356054, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.004469, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.337104, Val Acc: 94.53%, Val-Class-Acc: {0: '91.85%', 1: '96.99%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.002728, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.360452, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.002292, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.333651, Val Acc: 94.43%, Val-Class-Acc: {0: '90.63%', 1: '97.93%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.002373, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.463377, Val Acc: 92.57%, Val-Class-Acc: {0: '85.54%', 1: '99.06%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.001904, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.331271, Val Acc: 94.82%, Val-Class-Acc: {0: '91.85%', 1: '97.56%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.001940, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.334836, Val Acc: 94.53%, Val-Class-Acc: {0: '90.63%', 1: '98.12%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.001483, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.378076, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.002224, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.339336, Val Acc: 94.82%, Val-Class-Acc: {0: '91.45%', 1: '97.93%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.002498, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.401949, Val Acc: 93.55%, Val-Class-Acc: {0: '87.98%', 1: '98.68%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.002551, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.362412, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.002524, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.324704, Val Acc: 94.62%, Val-Class-Acc: {0: '92.46%', 1: '96.62%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.002885, Train-Class-Acc: {0: '99.77%', 1: '100.00%'}
# Val Loss: 0.394372, Val Acc: 94.62%, Val-Class-Acc: {0: '91.24%', 1: '97.74%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.001666, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.382820, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.002565, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.391742, Val Acc: 94.72%, Val-Class-Acc: {0: '91.04%', 1: '98.12%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.001123, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.417046, Val Acc: 94.23%, Val-Class-Acc: {0: '90.02%', 1: '98.12%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.003380, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.662303, Val Acc: 89.54%, Val-Class-Acc: {0: '78.82%', 1: '99.44%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.002423, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.416197, Val Acc: 93.84%, Val-Class-Acc: {0: '89.21%', 1: '98.12%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.004065, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.330756, Val Acc: 94.92%, Val-Class-Acc: {0: '92.67%', 1: '96.99%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.001442, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.379773, Val Acc: 94.23%, Val-Class-Acc: {0: '91.04%', 1: '97.18%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.004858, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.419396, Val Acc: 93.26%, Val-Class-Acc: {0: '87.98%', 1: '98.12%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.001995, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.335073, Val Acc: 94.62%, Val-Class-Acc: {0: '92.06%', 1: '96.99%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.002119, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.330848, Val Acc: 94.62%, Val-Class-Acc: {0: '92.67%', 1: '96.43%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.003006, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.386695, Val Acc: 93.84%, Val-Class-Acc: {0: '89.21%', 1: '98.12%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.002946, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.427638, Val Acc: 93.35%, Val-Class-Acc: {0: '87.37%', 1: '98.87%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.003507, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.376677, Val Acc: 94.43%, Val-Class-Acc: {0: '91.45%', 1: '97.18%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.004274, Train-Class-Acc: {0: '99.77%', 1: '100.00%'}
# Val Loss: 0.362753, Val Acc: 94.62%, Val-Class-Acc: {0: '92.26%', 1: '96.80%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.001515, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.453096, Val Acc: 92.96%, Val-Class-Acc: {0: '87.17%', 1: '98.31%'}, LR: 0.000100
#
# ⏳ Total training time: 159.83 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_best.pth (Val Accuracy: 95.31%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 866, Train Loss: 0.004625, Train-Acc: {0: '99.69%', 1: '99.85%'},
# Val Loss: 0.348087, Val Acc: 95.31%, Val-Acc: {0: '93.48%', 1: '96.99%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_866.pth
# Epoch 852, Train Loss: 0.002846, Train-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.335841, Val Acc: 95.21%, Val-Acc: {0: '94.50%', 1: '95.86%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_852.pth
# Epoch 827, Train Loss: 0.002248, Train-Acc: {0: '99.84%', 1: '99.93%'},
# Val Loss: 0.395612, Val Acc: 95.21%, Val-Acc: {0: '93.48%', 1: '96.80%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_827.pth
# Epoch 723, Train Loss: 0.002297, Train-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.347481, Val Acc: 95.11%, Val-Acc: {0: '91.85%', 1: '98.12%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_723.pth
# Epoch 144, Train Loss: 0.017141, Train-Acc: {0: '99.38%', 1: '99.27%'},
# Val Loss: 0.249508, Val Acc: 95.11%, Val-Acc: {0: '93.28%', 1: '96.80%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_144.pth
# ---
# ### Period 1
# + ##### Total training time: 159.83 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/Baseline_1'*
# + ##### Best Epoch: 866
# #### __Val Accuracy: 95.31%__
# #### __Val-Class-Acc: {0: '93.48%', 1: '96.99%'}__
#
# ✅ Period 1 Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ## __~~~ PNN_fc1 ~~~__

# %% [markdown]
# ---
# ### Period 2
# + ##### Total training time: 408.46 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2'*
# + ##### Best Epoch: 636
# #### __Val Accuracy: 96.93%__
# #### __Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 2 Configuration - Progressive Neural Network (PNN_fc1)
# ================================
period = 2

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 1  # 新增 1 個類別
output_size = len(set(y_train))  # 到目前為止所有類別數

# === Load frozen Period 1 model ===
frozen_model = HAR_MLP_v2(input_size, hidden_size, output_size - new_output_size, dropout)
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"Baseline_{period-1}", "HAR_MLP_PNN_v2_best.pth"
)
frozen_checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(frozen_checkpoint['model_state_dict'])
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create new PNN column ===
new_column = HAR_PNN_Column_fc1(input_size=input_size, hidden_size=hidden_size, new_output_size=new_output_size)

# === Wrap into ProgressiveNeuralNetwork ===
model = ProgressiveNeuralNetwork_fc1(base_model=frozen_model, new_column=new_column).to(device)

# === Define optimizer, loss, etc. ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC1_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, frozen_model, new_column, frozen_checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 4906 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# /tmp/ipykernel_2803466/2098380930.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   frozen_checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 1.150666, Train-Class-Acc: {0: '90.67%', 1: '98.62%', 2: '46.27%'}
# Val Loss: 0.600781, Val Acc: 80.91%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '74.48%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.487802, Train-Class-Acc: {0: '92.30%', 1: '98.62%', 2: '75.31%'}
# Val Loss: 0.304398, Val Acc: 90.50%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 2: '89.04%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.327222, Train-Class-Acc: {0: '91.29%', 1: '98.33%', 2: '83.81%'}
# Val Loss: 0.309093, Val Acc: 90.83%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '91.64%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.222632, Train-Class-Acc: {0: '92.53%', 1: '98.69%', 2: '89.07%'}
# Val Loss: 0.257100, Val Acc: 92.82%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '94.59%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.174782, Train-Class-Acc: {0: '91.60%', 1: '98.40%', 2: '92.88%'}
# Val Loss: 0.180935, Val Acc: 95.48%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '97.98%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.149599, Train-Class-Acc: {0: '91.52%', 1: '98.62%', 2: '95.40%'}
# Val Loss: 0.182224, Val Acc: 95.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '98.27%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.128911, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '96.23%'}
# Val Loss: 0.182847, Val Acc: 95.68%, Val-Class-Acc: {0: '82.48%', 1: '98.68%', 2: '99.21%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.101513, Train-Class-Acc: {0: '91.45%', 1: '98.40%', 2: '97.29%'}
# Val Loss: 0.186162, Val Acc: 95.68%, Val-Class-Acc: {0: '81.87%', 1: '98.68%', 2: '99.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.096132, Train-Class-Acc: {0: '91.99%', 1: '98.54%', 2: '97.96%'}
# Val Loss: 0.161957, Val Acc: 96.27%, Val-Class-Acc: {0: '83.91%', 1: '98.12%', 2: '99.93%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.084285, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '98.57%'}
# Val Loss: 0.152644, Val Acc: 96.47%, Val-Class-Acc: {0: '86.35%', 1: '97.74%', 2: '99.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.080248, Train-Class-Acc: {0: '91.37%', 1: '98.40%', 2: '99.00%'}
# Val Loss: 0.189496, Val Acc: 95.68%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '99.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.076922, Train-Class-Acc: {0: '91.68%', 1: '99.05%', 2: '99.18%'}
# Val Loss: 0.194823, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.089407, Train-Class-Acc: {0: '89.58%', 1: '98.40%', 2: '99.27%'}
# Val Loss: 0.180043, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.068108, Train-Class-Acc: {0: '93.47%', 1: '98.69%', 2: '99.30%'}
# Val Loss: 0.198518, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.071774, Train-Class-Acc: {0: '91.52%', 1: '98.91%', 2: '99.42%'}
# Val Loss: 0.180140, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.072724, Train-Class-Acc: {0: '90.98%', 1: '98.91%', 2: '99.67%'}
# Val Loss: 0.169250, Val Acc: 96.27%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.074059, Train-Class-Acc: {0: '91.37%', 1: '98.62%', 2: '99.60%'}
# Val Loss: 0.148989, Val Acc: 96.80%, Val-Class-Acc: {0: '86.15%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.063140, Train-Class-Acc: {0: '92.38%', 1: '98.98%', 2: '99.63%'}
# Val Loss: 0.179213, Val Acc: 95.89%, Val-Class-Acc: {0: '81.06%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.073936, Train-Class-Acc: {0: '90.90%', 1: '98.76%', 2: '99.79%'}
# Val Loss: 0.155131, Val Acc: 96.27%, Val-Class-Acc: {0: '83.30%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.070797, Train-Class-Acc: {0: '91.21%', 1: '98.54%', 2: '99.88%'}
# Val Loss: 0.148153, Val Acc: 96.60%, Val-Class-Acc: {0: '85.54%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.083428, Train-Class-Acc: {0: '90.98%', 1: '98.47%', 2: '99.91%'}
# Val Loss: 0.146792, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.062309, Train-Class-Acc: {0: '91.14%', 1: '99.13%', 2: '99.85%'}
# Val Loss: 0.147538, Val Acc: 96.60%, Val-Class-Acc: {0: '85.54%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.065157, Train-Class-Acc: {0: '90.90%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.144392, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.053391, Train-Class-Acc: {0: '93.16%', 1: '98.69%', 2: '99.91%'}
# Val Loss: 0.140706, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.063376, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '99.91%'}
# Val Loss: 0.164361, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.074476, Train-Class-Acc: {0: '90.51%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.159865, Val Acc: 96.27%, Val-Class-Acc: {0: '83.50%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.063945, Train-Class-Acc: {0: '91.68%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.145120, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.066231, Train-Class-Acc: {0: '92.22%', 1: '98.91%', 2: '99.94%'}
# Val Loss: 0.160237, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.071086, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '99.94%'}
# Val Loss: 0.180721, Val Acc: 95.85%, Val-Class-Acc: {0: '80.86%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.059084, Train-Class-Acc: {0: '92.30%', 1: '98.54%', 2: '99.97%'}
# Val Loss: 0.143278, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.068884, Train-Class-Acc: {0: '90.67%', 1: '98.69%', 2: '99.94%'}
# Val Loss: 0.171930, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.060454, Train-Class-Acc: {0: '93.31%', 1: '98.98%', 2: '99.97%'}
# Val Loss: 0.134353, Val Acc: 96.85%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.066594, Train-Class-Acc: {0: '91.37%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.153739, Val Acc: 96.39%, Val-Class-Acc: {0: '84.32%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.067423, Train-Class-Acc: {0: '90.67%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.160126, Val Acc: 96.39%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.066444, Train-Class-Acc: {0: '91.84%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.142938, Val Acc: 96.64%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.069217, Train-Class-Acc: {0: '91.45%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.177346, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.066612, Train-Class-Acc: {0: '91.45%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.155323, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.071480, Train-Class-Acc: {0: '90.59%', 1: '98.62%', 2: '99.91%'}
# Val Loss: 0.164929, Val Acc: 96.35%, Val-Class-Acc: {0: '83.30%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.066300, Train-Class-Acc: {0: '91.45%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.188549, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.064542, Train-Class-Acc: {0: '92.15%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.154621, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.074160, Train-Class-Acc: {0: '91.21%', 1: '97.96%', 2: '99.94%'}
# Val Loss: 0.163807, Val Acc: 95.98%, Val-Class-Acc: {0: '81.87%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.063898, Train-Class-Acc: {0: '91.91%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.148113, Val Acc: 96.60%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.064892, Train-Class-Acc: {0: '91.06%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.153684, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.067383, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.186952, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.073017, Train-Class-Acc: {0: '90.90%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.174570, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.076717, Train-Class-Acc: {0: '90.59%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.160382, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.052800, Train-Class-Acc: {0: '92.53%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.153046, Val Acc: 96.51%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.069912, Train-Class-Acc: {0: '90.67%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.181250, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.068927, Train-Class-Acc: {0: '90.05%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.177597, Val Acc: 96.02%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.058885, Train-Class-Acc: {0: '92.22%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.155976, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.066612, Train-Class-Acc: {0: '90.82%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.157332, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.061765, Train-Class-Acc: {0: '91.52%', 1: '98.84%', 2: '99.94%'}
# Val Loss: 0.159024, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.061871, Train-Class-Acc: {0: '92.15%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.171022, Val Acc: 95.89%, Val-Class-Acc: {0: '81.06%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.071781, Train-Class-Acc: {0: '91.68%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.169972, Val Acc: 96.14%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.062228, Train-Class-Acc: {0: '91.60%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.186495, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.058104, Train-Class-Acc: {0: '91.37%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.166909, Val Acc: 96.22%, Val-Class-Acc: {0: '83.10%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.060236, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.148882, Val Acc: 96.72%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.062042, Train-Class-Acc: {0: '91.76%', 1: '98.76%', 2: '99.94%'}
# Val Loss: 0.199210, Val Acc: 95.52%, Val-Class-Acc: {0: '79.02%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.063883, Train-Class-Acc: {0: '91.45%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.146624, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.057704, Train-Class-Acc: {0: '92.38%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.155556, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.060263, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.149335, Val Acc: 96.68%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.070860, Train-Class-Acc: {0: '90.98%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.158841, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.068449, Train-Class-Acc: {0: '91.45%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.160600, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.064619, Train-Class-Acc: {0: '91.76%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.152694, Val Acc: 96.60%, Val-Class-Acc: {0: '84.93%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.065672, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.151634, Val Acc: 96.56%, Val-Class-Acc: {0: '84.73%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.068411, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.161015, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.066826, Train-Class-Acc: {0: '91.68%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.192911, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.063743, Train-Class-Acc: {0: '91.14%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.141612, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.068989, Train-Class-Acc: {0: '91.60%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.167383, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.064341, Train-Class-Acc: {0: '91.06%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.146334, Val Acc: 96.68%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.064144, Train-Class-Acc: {0: '90.98%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.143973, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.062605, Train-Class-Acc: {0: '91.91%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.156587, Val Acc: 96.31%, Val-Class-Acc: {0: '83.50%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.068114, Train-Class-Acc: {0: '92.38%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.170055, Val Acc: 96.10%, Val-Class-Acc: {0: '81.87%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.070428, Train-Class-Acc: {0: '90.51%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.164076, Val Acc: 96.10%, Val-Class-Acc: {0: '82.28%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.059083, Train-Class-Acc: {0: '91.52%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.141202, Val Acc: 96.72%, Val-Class-Acc: {0: '86.35%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.067446, Train-Class-Acc: {0: '92.30%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.160411, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.065229, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.155394, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.053812, Train-Class-Acc: {0: '92.38%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.152789, Val Acc: 96.64%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.060451, Train-Class-Acc: {0: '92.07%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.142379, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.061464, Train-Class-Acc: {0: '91.29%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.173964, Val Acc: 96.06%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.078547, Train-Class-Acc: {0: '90.67%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.163781, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.063430, Train-Class-Acc: {0: '92.46%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.181524, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.062923, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.159810, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.066019, Train-Class-Acc: {0: '91.91%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.169605, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.056811, Train-Class-Acc: {0: '92.53%', 1: '98.98%', 2: '99.97%'}
# Val Loss: 0.154884, Val Acc: 96.60%, Val-Class-Acc: {0: '84.93%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.057429, Train-Class-Acc: {0: '91.60%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.165868, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.062978, Train-Class-Acc: {0: '90.82%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.156432, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.059768, Train-Class-Acc: {0: '91.06%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.139352, Val Acc: 96.76%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_88.pth
# Epoch 89/1000, Train Loss: 0.069208, Train-Class-Acc: {0: '90.82%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.145130, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.063378, Train-Class-Acc: {0: '91.37%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.146733, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.063706, Train-Class-Acc: {0: '91.99%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.165779, Val Acc: 96.43%, Val-Class-Acc: {0: '83.71%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.072650, Train-Class-Acc: {0: '90.75%', 1: '97.82%', 2: '100.00%'}
# Val Loss: 0.150646, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.062482, Train-Class-Acc: {0: '92.30%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.158882, Val Acc: 96.10%, Val-Class-Acc: {0: '82.28%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.057439, Train-Class-Acc: {0: '91.99%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.177081, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.056351, Train-Class-Acc: {0: '91.99%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.170687, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.067052, Train-Class-Acc: {0: '91.37%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.166145, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.066125, Train-Class-Acc: {0: '91.91%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.150266, Val Acc: 96.64%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.064978, Train-Class-Acc: {0: '91.14%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.185548, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.059787, Train-Class-Acc: {0: '91.99%', 1: '98.62%', 2: '99.94%'}
# Val Loss: 0.163628, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '99.93%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.059679, Train-Class-Acc: {0: '91.37%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.141766, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_100.pth
# Epoch 101/1000, Train Loss: 0.067986, Train-Class-Acc: {0: '91.45%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.182629, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.069609, Train-Class-Acc: {0: '91.60%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.177922, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.064583, Train-Class-Acc: {0: '90.82%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.170113, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.064438, Train-Class-Acc: {0: '91.45%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.167383, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.068308, Train-Class-Acc: {0: '91.84%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.161373, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.061292, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.195647, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.069683, Train-Class-Acc: {0: '91.21%', 1: '98.84%', 2: '99.85%'}
# Val Loss: 0.156794, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.063229, Train-Class-Acc: {0: '92.61%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.180891, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.057782, Train-Class-Acc: {0: '92.69%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.158020, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.061583, Train-Class-Acc: {0: '91.99%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.179044, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.063602, Train-Class-Acc: {0: '91.99%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.158044, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.070790, Train-Class-Acc: {0: '91.21%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.159882, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.058600, Train-Class-Acc: {0: '92.85%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.162456, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.072371, Train-Class-Acc: {0: '90.75%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.178335, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.054002, Train-Class-Acc: {0: '93.16%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.146480, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.077306, Train-Class-Acc: {0: '89.97%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.157707, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.061129, Train-Class-Acc: {0: '91.45%', 1: '98.91%', 2: '99.85%'}
# Val Loss: 0.146652, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.058726, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.153535, Val Acc: 96.60%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.063952, Train-Class-Acc: {0: '91.91%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.162533, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.065407, Train-Class-Acc: {0: '92.07%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.146539, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.068481, Train-Class-Acc: {0: '91.37%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.159304, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.061455, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.148193, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.059938, Train-Class-Acc: {0: '91.52%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.143956, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.069314, Train-Class-Acc: {0: '92.30%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.165167, Val Acc: 96.14%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.071580, Train-Class-Acc: {0: '91.37%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.189076, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.060552, Train-Class-Acc: {0: '91.45%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.168009, Val Acc: 96.18%, Val-Class-Acc: {0: '82.69%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.057377, Train-Class-Acc: {0: '91.84%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.189863, Val Acc: 95.77%, Val-Class-Acc: {0: '80.24%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.063301, Train-Class-Acc: {0: '91.37%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.145018, Val Acc: 96.76%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.064670, Train-Class-Acc: {0: '92.07%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.138521, Val Acc: 96.64%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.066347, Train-Class-Acc: {0: '90.98%', 1: '99.20%', 2: '99.94%'}
# Val Loss: 0.153286, Val Acc: 96.51%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.060279, Train-Class-Acc: {0: '91.91%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.174147, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.066381, Train-Class-Acc: {0: '92.15%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.159429, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.057042, Train-Class-Acc: {0: '92.53%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.163739, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.064429, Train-Class-Acc: {0: '91.76%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.162546, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.070083, Train-Class-Acc: {0: '90.98%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.188141, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.069590, Train-Class-Acc: {0: '92.15%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.152805, Val Acc: 96.39%, Val-Class-Acc: {0: '84.32%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.068626, Train-Class-Acc: {0: '89.66%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.175003, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.068046, Train-Class-Acc: {0: '91.45%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.171430, Val Acc: 96.14%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.064709, Train-Class-Acc: {0: '91.68%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.155545, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.067872, Train-Class-Acc: {0: '90.90%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.178851, Val Acc: 95.85%, Val-Class-Acc: {0: '80.65%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.057235, Train-Class-Acc: {0: '92.15%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.159709, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.074388, Train-Class-Acc: {0: '90.67%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.152793, Val Acc: 96.47%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.063498, Train-Class-Acc: {0: '90.90%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.149922, Val Acc: 96.68%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.068187, Train-Class-Acc: {0: '90.75%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.178125, Val Acc: 96.06%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.063774, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.157215, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.059210, Train-Class-Acc: {0: '92.53%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.187533, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.058217, Train-Class-Acc: {0: '92.46%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.170200, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.069331, Train-Class-Acc: {0: '91.45%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.148795, Val Acc: 96.60%, Val-Class-Acc: {0: '85.34%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.058344, Train-Class-Acc: {0: '91.60%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.169729, Val Acc: 96.06%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.063844, Train-Class-Acc: {0: '90.90%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.183651, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.061670, Train-Class-Acc: {0: '91.45%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.168647, Val Acc: 96.18%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.071552, Train-Class-Acc: {0: '91.60%', 1: '98.03%', 2: '100.00%'}
# Val Loss: 0.164949, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.059977, Train-Class-Acc: {0: '92.92%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.133170, Val Acc: 96.85%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_153.pth
# Epoch 154/1000, Train Loss: 0.065318, Train-Class-Acc: {0: '91.84%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.141934, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.059954, Train-Class-Acc: {0: '92.69%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.154147, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.060871, Train-Class-Acc: {0: '91.99%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.161340, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.066494, Train-Class-Acc: {0: '91.45%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.190504, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.065248, Train-Class-Acc: {0: '91.37%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.168807, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.061801, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.174706, Val Acc: 96.18%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.061015, Train-Class-Acc: {0: '91.99%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.159721, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.069381, Train-Class-Acc: {0: '92.15%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.161351, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.062955, Train-Class-Acc: {0: '91.52%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.155387, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.057326, Train-Class-Acc: {0: '93.08%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.149810, Val Acc: 96.64%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.064685, Train-Class-Acc: {0: '90.98%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.144896, Val Acc: 96.60%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.064364, Train-Class-Acc: {0: '91.29%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.157197, Val Acc: 96.22%, Val-Class-Acc: {0: '83.10%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.068034, Train-Class-Acc: {0: '91.45%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.196575, Val Acc: 95.60%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.075293, Train-Class-Acc: {0: '90.51%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.167954, Val Acc: 96.14%, Val-Class-Acc: {0: '82.69%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.061849, Train-Class-Acc: {0: '91.91%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.165626, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.060173, Train-Class-Acc: {0: '92.38%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.175925, Val Acc: 96.02%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.059313, Train-Class-Acc: {0: '92.22%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.147081, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.071273, Train-Class-Acc: {0: '91.45%', 1: '98.11%', 2: '99.97%'}
# Val Loss: 0.170328, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.053673, Train-Class-Acc: {0: '93.39%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.177455, Val Acc: 95.93%, Val-Class-Acc: {0: '81.26%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.069081, Train-Class-Acc: {0: '91.60%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.138613, Val Acc: 96.76%, Val-Class-Acc: {0: '86.56%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.055548, Train-Class-Acc: {0: '93.23%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.171376, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.070541, Train-Class-Acc: {0: '90.90%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.170450, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.059139, Train-Class-Acc: {0: '91.06%', 1: '99.34%', 2: '100.00%'}
# Val Loss: 0.146035, Val Acc: 96.68%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.068020, Train-Class-Acc: {0: '90.98%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.174658, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.068040, Train-Class-Acc: {0: '91.29%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.171775, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.059174, Train-Class-Acc: {0: '91.76%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.180681, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.066285, Train-Class-Acc: {0: '91.06%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.153466, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.058929, Train-Class-Acc: {0: '91.99%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.176731, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.063767, Train-Class-Acc: {0: '92.30%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.152818, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.058522, Train-Class-Acc: {0: '91.60%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.188780, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.070707, Train-Class-Acc: {0: '90.82%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.170266, Val Acc: 96.27%, Val-Class-Acc: {0: '83.30%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.063163, Train-Class-Acc: {0: '91.52%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.145362, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.062715, Train-Class-Acc: {0: '91.37%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.162426, Val Acc: 96.31%, Val-Class-Acc: {0: '83.50%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.058694, Train-Class-Acc: {0: '92.77%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.166229, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.061721, Train-Class-Acc: {0: '92.07%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.162512, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.062373, Train-Class-Acc: {0: '91.76%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.167012, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.064274, Train-Class-Acc: {0: '92.15%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.176443, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.063606, Train-Class-Acc: {0: '91.76%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.163896, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '99.93%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.067248, Train-Class-Acc: {0: '91.29%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.165756, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.058300, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.163046, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.070072, Train-Class-Acc: {0: '91.52%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.154994, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.060224, Train-Class-Acc: {0: '92.22%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.136873, Val Acc: 96.80%, Val-Class-Acc: {0: '86.56%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_88.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_195.pth
# Epoch 196/1000, Train Loss: 0.067180, Train-Class-Acc: {0: '91.45%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.151235, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.060761, Train-Class-Acc: {0: '92.61%', 1: '98.11%', 2: '100.00%'}
# Val Loss: 0.154446, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.071709, Train-Class-Acc: {0: '91.52%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.169183, Val Acc: 96.14%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.064712, Train-Class-Acc: {0: '91.45%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.150009, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.064197, Train-Class-Acc: {0: '91.84%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.160169, Val Acc: 96.18%, Val-Class-Acc: {0: '82.69%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.056756, Train-Class-Acc: {0: '92.15%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.162666, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# ...
# Epoch 939/1000, Train Loss: 0.064698, Train-Class-Acc: {0: '90.90%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.167469, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.073591, Train-Class-Acc: {0: '91.52%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.160145, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.081044, Train-Class-Acc: {0: '89.42%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.149181, Val Acc: 96.56%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.057515, Train-Class-Acc: {0: '92.22%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.194650, Val Acc: 95.60%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.065726, Train-Class-Acc: {0: '91.60%', 1: '98.03%', 2: '100.00%'}
# Val Loss: 0.181186, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.067427, Train-Class-Acc: {0: '91.99%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.168815, Val Acc: 96.18%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '99.93%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.071333, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.158990, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '99.93%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.075511, Train-Class-Acc: {0: '90.90%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.166455, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '99.93%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.059262, Train-Class-Acc: {0: '92.69%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.149005, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.055563, Train-Class-Acc: {0: '91.84%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.144849, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.069417, Train-Class-Acc: {0: '91.84%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.163065, Val Acc: 96.18%, Val-Class-Acc: {0: '82.69%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.062945, Train-Class-Acc: {0: '91.14%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.166362, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.054678, Train-Class-Acc: {0: '92.85%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.141755, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.050035, Train-Class-Acc: {0: '93.55%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.151622, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.059415, Train-Class-Acc: {0: '92.92%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.170955, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.067041, Train-Class-Acc: {0: '92.61%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.151012, Val Acc: 96.64%, Val-Class-Acc: {0: '84.93%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.055206, Train-Class-Acc: {0: '93.62%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.158654, Val Acc: 96.31%, Val-Class-Acc: {0: '83.50%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.055784, Train-Class-Acc: {0: '92.07%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.149936, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.072984, Train-Class-Acc: {0: '90.05%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.161868, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.067786, Train-Class-Acc: {0: '90.90%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.161708, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.058324, Train-Class-Acc: {0: '91.76%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.143859, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.058638, Train-Class-Acc: {0: '93.23%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.169719, Val Acc: 96.02%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '99.93%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.056998, Train-Class-Acc: {0: '92.30%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.150264, Val Acc: 96.60%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.064038, Train-Class-Acc: {0: '91.52%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.160375, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.057623, Train-Class-Acc: {0: '91.84%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.145989, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.065308, Train-Class-Acc: {0: '91.68%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.146454, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.066305, Train-Class-Acc: {0: '91.52%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.154249, Val Acc: 96.51%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.056730, Train-Class-Acc: {0: '91.84%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.164315, Val Acc: 96.47%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.062091, Train-Class-Acc: {0: '92.61%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.149838, Val Acc: 96.56%, Val-Class-Acc: {0: '84.73%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.069453, Train-Class-Acc: {0: '91.45%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.141217, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.058895, Train-Class-Acc: {0: '92.53%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.156175, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.061538, Train-Class-Acc: {0: '91.68%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.144041, Val Acc: 96.64%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.059449, Train-Class-Acc: {0: '92.69%', 1: '99.34%', 2: '100.00%'}
# Val Loss: 0.159825, Val Acc: 96.47%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.066010, Train-Class-Acc: {0: '91.52%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.156864, Val Acc: 96.51%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.066647, Train-Class-Acc: {0: '90.44%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.195097, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.070107, Train-Class-Acc: {0: '91.21%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.171667, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.068165, Train-Class-Acc: {0: '90.90%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.150890, Val Acc: 96.51%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.064669, Train-Class-Acc: {0: '91.14%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.144572, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.061019, Train-Class-Acc: {0: '92.07%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.161554, Val Acc: 96.47%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.062995, Train-Class-Acc: {0: '92.22%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.153086, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.060919, Train-Class-Acc: {0: '91.37%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.170811, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.066166, Train-Class-Acc: {0: '91.91%', 1: '98.69%', 2: '99.94%'}
# Val Loss: 0.139267, Val Acc: 96.72%, Val-Class-Acc: {0: '86.56%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.066733, Train-Class-Acc: {0: '90.59%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.148295, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.065823, Train-Class-Acc: {0: '90.28%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.157947, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.060344, Train-Class-Acc: {0: '92.38%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.153892, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.066783, Train-Class-Acc: {0: '90.05%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.153476, Val Acc: 96.51%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.066689, Train-Class-Acc: {0: '91.68%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.140354, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.064157, Train-Class-Acc: {0: '91.68%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.177145, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.065561, Train-Class-Acc: {0: '91.68%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.159943, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.062138, Train-Class-Acc: {0: '92.15%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.156114, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.058067, Train-Class-Acc: {0: '91.76%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.161916, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.058147, Train-Class-Acc: {0: '92.38%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.151940, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.056034, Train-Class-Acc: {0: '92.61%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.170799, Val Acc: 96.02%, Val-Class-Acc: {0: '81.67%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.052178, Train-Class-Acc: {0: '92.07%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.167934, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.063054, Train-Class-Acc: {0: '90.75%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.170507, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.067060, Train-Class-Acc: {0: '90.82%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.147278, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.064340, Train-Class-Acc: {0: '92.30%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.196060, Val Acc: 95.64%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.065618, Train-Class-Acc: {0: '91.52%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.186184, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.059015, Train-Class-Acc: {0: '92.61%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.160504, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.063730, Train-Class-Acc: {0: '91.99%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.145389, Val Acc: 96.56%, Val-Class-Acc: {0: '85.13%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.065067, Train-Class-Acc: {0: '92.07%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.197647, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.061364, Train-Class-Acc: {0: '91.06%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.150783, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 408.46 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_best.pth (Val Accuracy: 96.93%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 636, Train Loss: 0.057483, Train-Acc: {0: '92.38%', 1: '98.84%', 2: '100.00%'},
# Val Loss: 0.131670, Val Acc: 96.93%, Val-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_636.pth
# Epoch 420, Train Loss: 0.075517, Train-Acc: {0: '92.22%', 1: '98.54%', 2: '100.00%'},
# Val Loss: 0.130085, Val Acc: 96.93%, Val-Acc: {0: '87.58%', 1: '97.56%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_420.pth
# Epoch 237, Train Loss: 0.063268, Train-Acc: {0: '91.37%', 1: '98.69%', 2: '100.00%'},
# Val Loss: 0.136747, Val Acc: 96.89%, Val-Acc: {0: '86.97%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_237.pth
# Epoch 416, Train Loss: 0.077197, Train-Acc: {0: '90.98%', 1: '98.76%', 2: '100.00%'},
# Val Loss: 0.135201, Val Acc: 96.85%, Val-Acc: {0: '87.17%', 1: '97.56%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_416.pth
# Epoch 248, Train Loss: 0.062944, Train-Acc: {0: '92.46%', 1: '98.62%', 2: '100.00%'},
# Val Loss: 0.142790, Val Acc: 96.85%, Val-Acc: {0: '86.35%', 1: '98.31%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2/HAR_PNN_v2_epoch_248.pth
# ---
# ### Period 2
# + ##### Total training time: 408.46 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_2'*
# + ##### Best Epoch: 636
# #### __Val Accuracy: 96.93%__
# #### __Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}__
#
# ✅ Period 2 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc1(
#   (base_model): HAR_MLP_v2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (new_column): HAR_PNN_Column_fc1(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3
# + ##### Total training time: 712.79 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3'*
# + ##### Best Epoch: 536
# #### __Val Accuracy: 97.46%__
# #### __Val-Class-Acc: {0: '87.78%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}__

# %%
# ================================
# 📌 Period 3 Configuration - Progressive Neural Network (PNN_fc1)
# ================================
period = 3

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 1  # 新增一個類別
output_size = len(set(y_train))  # 目前總類別數（含舊+新）
print(output_size)
# === 還原 Period 2 架構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, output_size - 2, dropout)
prev_column = HAR_PNN_Column_fc1(input_size, hidden_size, new_output_size=1)

frozen_model = ProgressiveNeuralNetwork_fc1(base_model=base_model, new_column=prev_column)

# === 載入 Period 2 的 model state_dict ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC1_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create Period 3 New Column ===
new_column = HAR_PNN_Column_fc1(input_size, hidden_size, new_output_size=new_output_size)

# === Combine into new PNN wrapper ===
model = ProgressiveNeuralNetwork_fc1(base_model=frozen_model, new_column=new_column).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC1_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, base_model, prev_column, new_column, frozen_model, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 4815 MiB
#     - Device Name    : NVIDIA RTX A6000
# 4
# ProgressiveNeuralNetwork_fc1(
#   (base_model): ProgressiveNeuralNetwork_fc1(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc1(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc1(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_2803466/988963645.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.252808, Train-Class-Acc: {0: '88.72%', 1: '98.98%', 2: '100.00%', 3: '72.21%'}
# Val Loss: 0.258338, Val Acc: 94.91%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '89.20%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.109029, Train-Class-Acc: {0: '89.50%', 1: '99.27%', 2: '100.00%', 3: '93.82%'}
# Val Loss: 0.194260, Val Acc: 95.79%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '93.30%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.079023, Train-Class-Acc: {0: '89.58%', 1: '99.42%', 2: '100.00%', 3: '96.94%'}
# Val Loss: 0.151489, Val Acc: 96.40%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%', 3: '95.34%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.076109, Train-Class-Acc: {0: '87.95%', 1: '99.27%', 2: '100.00%', 3: '98.01%'}
# Val Loss: 0.196585, Val Acc: 95.39%, Val-Class-Acc: {0: '76.99%', 1: '99.25%', 2: '100.00%', 3: '96.46%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.071978, Train-Class-Acc: {0: '89.11%', 1: '99.20%', 2: '100.00%', 3: '98.37%'}
# Val Loss: 0.146689, Val Acc: 96.64%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '100.00%', 3: '96.65%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.062425, Train-Class-Acc: {0: '90.51%', 1: '99.13%', 2: '100.00%', 3: '99.08%'}
# Val Loss: 0.157080, Val Acc: 96.54%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '98.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.061957, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '100.00%', 3: '99.00%'}
# Val Loss: 0.126432, Val Acc: 97.05%, Val-Class-Acc: {0: '85.13%', 1: '98.12%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.065477, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '99.15%'}
# Val Loss: 0.147792, Val Acc: 96.78%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.059867, Train-Class-Acc: {0: '90.36%', 1: '99.49%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.162591, Val Acc: 96.40%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '98.32%'}, LR: 0.000100
# Epoch 10/1000, Train Loss: 0.066685, Train-Class-Acc: {0: '89.66%', 1: '99.34%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.148817, Val Acc: 96.88%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.063757, Train-Class-Acc: {0: '89.19%', 1: '99.05%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.132218, Val Acc: 97.12%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.052476, Train-Class-Acc: {0: '91.84%', 1: '99.20%', 2: '100.00%', 3: '99.08%'}
# Val Loss: 0.125504, Val Acc: 97.32%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.057723, Train-Class-Acc: {0: '90.59%', 1: '99.71%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.175139, Val Acc: 96.23%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 14/1000, Train Loss: 0.054263, Train-Class-Acc: {0: '91.14%', 1: '99.42%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.162915, Val Acc: 96.54%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.052715, Train-Class-Acc: {0: '91.52%', 1: '99.49%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.156559, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.057688, Train-Class-Acc: {0: '90.75%', 1: '99.49%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.145310, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.048620, Train-Class-Acc: {0: '91.60%', 1: '99.64%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.126274, Val Acc: 97.29%, Val-Class-Acc: {0: '86.35%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.065522, Train-Class-Acc: {0: '90.20%', 1: '99.56%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.192035, Val Acc: 95.83%, Val-Class-Acc: {0: '76.17%', 1: '99.25%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.057388, Train-Class-Acc: {0: '90.90%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.161722, Val Acc: 96.54%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.059928, Train-Class-Acc: {0: '89.89%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.172416, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.050723, Train-Class-Acc: {0: '91.68%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.146468, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.055773, Train-Class-Acc: {0: '91.91%', 1: '98.98%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.148739, Val Acc: 96.91%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.048433, Train-Class-Acc: {0: '91.68%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.152399, Val Acc: 96.64%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.060031, Train-Class-Acc: {0: '90.05%', 1: '99.27%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.198569, Val Acc: 95.83%, Val-Class-Acc: {0: '75.36%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.051017, Train-Class-Acc: {0: '90.05%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.165737, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.053756, Train-Class-Acc: {0: '90.12%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.161654, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.055093, Train-Class-Acc: {0: '90.82%', 1: '99.42%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.186650, Val Acc: 95.96%, Val-Class-Acc: {0: '76.99%', 1: '99.44%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.052261, Train-Class-Acc: {0: '90.67%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148810, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.051990, Train-Class-Acc: {0: '90.82%', 1: '98.91%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.205359, Val Acc: 95.72%, Val-Class-Acc: {0: '75.15%', 1: '99.44%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.053942, Train-Class-Acc: {0: '91.21%', 1: '99.27%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.182487, Val Acc: 96.10%, Val-Class-Acc: {0: '77.39%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.049616, Train-Class-Acc: {0: '90.90%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.157884, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.058789, Train-Class-Acc: {0: '89.42%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.127575, Val Acc: 97.29%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.051289, Train-Class-Acc: {0: '90.67%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.167285, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.063431, Train-Class-Acc: {0: '89.74%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.156767, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.053972, Train-Class-Acc: {0: '91.21%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.166382, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.057018, Train-Class-Acc: {0: '89.89%', 1: '99.27%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.132551, Val Acc: 97.12%, Val-Class-Acc: {0: '84.73%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.054787, Train-Class-Acc: {0: '90.75%', 1: '99.49%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.151719, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.055692, Train-Class-Acc: {0: '89.97%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.162598, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.057480, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.152255, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.054641, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.136401, Val Acc: 97.18%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.063828, Train-Class-Acc: {0: '89.50%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.186222, Val Acc: 96.03%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '98.32%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.048687, Train-Class-Acc: {0: '91.37%', 1: '99.34%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.151617, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.058760, Train-Class-Acc: {0: '91.06%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.139255, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.046255, Train-Class-Acc: {0: '91.37%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.130584, Val Acc: 97.12%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.049363, Train-Class-Acc: {0: '91.52%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.119647, Val Acc: 97.32%, Val-Class-Acc: {0: '86.35%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_45.pth
# Epoch 46/1000, Train Loss: 0.055076, Train-Class-Acc: {0: '89.97%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.131788, Val Acc: 97.05%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.058599, Train-Class-Acc: {0: '90.36%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.162020, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.056452, Train-Class-Acc: {0: '90.44%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149431, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.051274, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.139694, Val Acc: 97.05%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.059831, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.168710, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.054165, Train-Class-Acc: {0: '89.89%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.192436, Val Acc: 95.79%, Val-Class-Acc: {0: '75.36%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.050776, Train-Class-Acc: {0: '91.29%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.175550, Val Acc: 96.47%, Val-Class-Acc: {0: '79.43%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.056830, Train-Class-Acc: {0: '90.98%', 1: '99.56%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.168146, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.060807, Train-Class-Acc: {0: '90.36%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.209144, Val Acc: 95.52%, Val-Class-Acc: {0: '73.73%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.052291, Train-Class-Acc: {0: '90.90%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.143569, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.057879, Train-Class-Acc: {0: '90.12%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.143213, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.050009, Train-Class-Acc: {0: '92.30%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.144061, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.063805, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.159991, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.051624, Train-Class-Acc: {0: '91.21%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.193660, Val Acc: 96.03%, Val-Class-Acc: {0: '76.99%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.058421, Train-Class-Acc: {0: '90.20%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.161220, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.059211, Train-Class-Acc: {0: '90.67%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.145564, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.050634, Train-Class-Acc: {0: '90.82%', 1: '99.71%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.172386, Val Acc: 96.44%, Val-Class-Acc: {0: '79.23%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.050716, Train-Class-Acc: {0: '90.90%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.160692, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.051645, Train-Class-Acc: {0: '92.22%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.134871, Val Acc: 97.05%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.060542, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.206207, Val Acc: 95.66%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.055968, Train-Class-Acc: {0: '89.74%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.168220, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.059254, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.150548, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.052730, Train-Class-Acc: {0: '91.76%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148325, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.053996, Train-Class-Acc: {0: '90.12%', 1: '99.71%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.139010, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.054743, Train-Class-Acc: {0: '90.44%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.161254, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.047720, Train-Class-Acc: {0: '92.22%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.160454, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.052643, Train-Class-Acc: {0: '91.14%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.145545, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.052647, Train-Class-Acc: {0: '91.76%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.140204, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.059673, Train-Class-Acc: {0: '90.20%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.129111, Val Acc: 97.15%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.051754, Train-Class-Acc: {0: '90.82%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142497, Val Acc: 96.98%, Val-Class-Acc: {0: '82.89%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.053466, Train-Class-Acc: {0: '91.21%', 1: '99.49%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.135628, Val Acc: 97.12%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.059708, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.187321, Val Acc: 95.96%, Val-Class-Acc: {0: '76.37%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.047997, Train-Class-Acc: {0: '91.29%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.164460, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.057350, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.183231, Val Acc: 96.06%, Val-Class-Acc: {0: '76.99%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.053935, Train-Class-Acc: {0: '90.98%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.157515, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.049110, Train-Class-Acc: {0: '91.52%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.137145, Val Acc: 97.08%, Val-Class-Acc: {0: '83.30%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.054078, Train-Class-Acc: {0: '89.89%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.200488, Val Acc: 95.79%, Val-Class-Acc: {0: '75.36%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.051987, Train-Class-Acc: {0: '90.90%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158555, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.064224, Train-Class-Acc: {0: '89.66%', 1: '99.20%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.208427, Val Acc: 95.45%, Val-Class-Acc: {0: '73.12%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.057129, Train-Class-Acc: {0: '90.51%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.154941, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.052760, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.152523, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.052517, Train-Class-Acc: {0: '91.60%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135042, Val Acc: 97.15%, Val-Class-Acc: {0: '83.71%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.061430, Train-Class-Acc: {0: '90.75%', 1: '98.91%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.152585, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.058791, Train-Class-Acc: {0: '90.05%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.153626, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.052581, Train-Class-Acc: {0: '91.99%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.163234, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.054905, Train-Class-Acc: {0: '89.97%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.157962, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.060626, Train-Class-Acc: {0: '90.75%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145071, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.058004, Train-Class-Acc: {0: '89.97%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.147412, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.054420, Train-Class-Acc: {0: '90.05%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.197731, Val Acc: 95.96%, Val-Class-Acc: {0: '76.37%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.051052, Train-Class-Acc: {0: '91.84%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.206905, Val Acc: 95.62%, Val-Class-Acc: {0: '74.13%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.056975, Train-Class-Acc: {0: '90.36%', 1: '99.13%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.189677, Val Acc: 96.10%, Val-Class-Acc: {0: '77.19%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.054943, Train-Class-Acc: {0: '91.37%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.195156, Val Acc: 95.79%, Val-Class-Acc: {0: '75.15%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.052085, Train-Class-Acc: {0: '91.37%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.144954, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.055777, Train-Class-Acc: {0: '89.89%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.164837, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.062494, Train-Class-Acc: {0: '89.58%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149974, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.050007, Train-Class-Acc: {0: '90.90%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.193493, Val Acc: 96.00%, Val-Class-Acc: {0: '76.58%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.057444, Train-Class-Acc: {0: '89.66%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158195, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.050703, Train-Class-Acc: {0: '91.52%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.134056, Val Acc: 97.12%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.059313, Train-Class-Acc: {0: '89.74%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.194340, Val Acc: 95.89%, Val-Class-Acc: {0: '75.97%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.049202, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.140517, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.047922, Train-Class-Acc: {0: '91.37%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.157134, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.049864, Train-Class-Acc: {0: '90.98%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.169710, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.048956, Train-Class-Acc: {0: '91.29%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.193717, Val Acc: 95.83%, Val-Class-Acc: {0: '75.56%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.048854, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.154782, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.054627, Train-Class-Acc: {0: '90.90%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.132363, Val Acc: 97.08%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.049531, Train-Class-Acc: {0: '90.51%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135793, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.048872, Train-Class-Acc: {0: '91.91%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.120262, Val Acc: 97.25%, Val-Class-Acc: {0: '86.15%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_112.pth
# Epoch 113/1000, Train Loss: 0.048766, Train-Class-Acc: {0: '92.30%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.172921, Val Acc: 96.23%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.055310, Train-Class-Acc: {0: '91.21%', 1: '99.20%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.144080, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.057180, Train-Class-Acc: {0: '89.58%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.158436, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.054296, Train-Class-Acc: {0: '90.44%', 1: '99.49%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.164840, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.058944, Train-Class-Acc: {0: '90.20%', 1: '99.56%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.185491, Val Acc: 96.10%, Val-Class-Acc: {0: '76.99%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.052563, Train-Class-Acc: {0: '91.06%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146194, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.048550, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162702, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.053985, Train-Class-Acc: {0: '90.90%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.149228, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.048678, Train-Class-Acc: {0: '91.52%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.137422, Val Acc: 97.15%, Val-Class-Acc: {0: '83.71%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.058965, Train-Class-Acc: {0: '90.12%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.151282, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.056193, Train-Class-Acc: {0: '90.51%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.156821, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.053762, Train-Class-Acc: {0: '91.06%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142844, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.052888, Train-Class-Acc: {0: '91.84%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.179323, Val Acc: 96.10%, Val-Class-Acc: {0: '77.39%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.051889, Train-Class-Acc: {0: '90.98%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.164154, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.058525, Train-Class-Acc: {0: '89.81%', 1: '99.64%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.156425, Val Acc: 96.84%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.051293, Train-Class-Acc: {0: '91.60%', 1: '99.05%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.163222, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.055732, Train-Class-Acc: {0: '89.89%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158331, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.050388, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.173377, Val Acc: 96.27%, Val-Class-Acc: {0: '78.21%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.057820, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.169669, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.050642, Train-Class-Acc: {0: '91.21%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.182867, Val Acc: 96.00%, Val-Class-Acc: {0: '76.58%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.054550, Train-Class-Acc: {0: '90.59%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.130309, Val Acc: 97.18%, Val-Class-Acc: {0: '84.73%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.058543, Train-Class-Acc: {0: '90.59%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.153130, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.051194, Train-Class-Acc: {0: '90.98%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.174031, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.052130, Train-Class-Acc: {0: '91.45%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.132361, Val Acc: 97.15%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.055132, Train-Class-Acc: {0: '90.44%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146602, Val Acc: 96.91%, Val-Class-Acc: {0: '82.48%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.052096, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.175064, Val Acc: 96.27%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.050001, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.152298, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.051411, Train-Class-Acc: {0: '90.67%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.178938, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.057149, Train-Class-Acc: {0: '89.81%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.153864, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.046081, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.164637, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.055427, Train-Class-Acc: {0: '90.59%', 1: '99.42%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.138051, Val Acc: 97.08%, Val-Class-Acc: {0: '83.30%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.052817, Train-Class-Acc: {0: '90.75%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145294, Val Acc: 97.05%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.051973, Train-Class-Acc: {0: '91.14%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.114975, Val Acc: 97.25%, Val-Class-Acc: {0: '86.15%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.051371, Train-Class-Acc: {0: '91.06%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.176787, Val Acc: 96.17%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.052570, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.150858, Val Acc: 96.81%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.055390, Train-Class-Acc: {0: '89.89%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.177040, Val Acc: 96.27%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.050728, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.198636, Val Acc: 95.96%, Val-Class-Acc: {0: '76.17%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.058697, Train-Class-Acc: {0: '89.74%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.185436, Val Acc: 96.17%, Val-Class-Acc: {0: '77.60%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.048973, Train-Class-Acc: {0: '92.22%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.214305, Val Acc: 95.72%, Val-Class-Acc: {0: '74.95%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.053350, Train-Class-Acc: {0: '90.51%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145366, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.047545, Train-Class-Acc: {0: '91.52%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.119937, Val Acc: 97.15%, Val-Class-Acc: {0: '85.13%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.054389, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.166822, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.054841, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.174728, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.049626, Train-Class-Acc: {0: '91.21%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138171, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.053844, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135063, Val Acc: 97.01%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.059219, Train-Class-Acc: {0: '90.20%', 1: '98.98%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.152079, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.055719, Train-Class-Acc: {0: '89.97%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.155582, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.053052, Train-Class-Acc: {0: '90.51%', 1: '99.13%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.161868, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.057424, Train-Class-Acc: {0: '90.44%', 1: '99.49%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.152380, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.045231, Train-Class-Acc: {0: '91.68%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.192441, Val Acc: 96.10%, Val-Class-Acc: {0: '76.99%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.052089, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.159824, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.055948, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.127712, Val Acc: 97.25%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.058696, Train-Class-Acc: {0: '88.88%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.130876, Val Acc: 97.18%, Val-Class-Acc: {0: '84.52%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.053868, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.173386, Val Acc: 96.37%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.059954, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.171063, Val Acc: 96.17%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.055434, Train-Class-Acc: {0: '90.12%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146861, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.057561, Train-Class-Acc: {0: '90.28%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148942, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.057785, Train-Class-Acc: {0: '90.28%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.161405, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.058159, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '99.94%', 3: '100.00%'}
# Val Loss: 0.130271, Val Acc: 97.22%, Val-Class-Acc: {0: '84.52%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.055460, Train-Class-Acc: {0: '90.20%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.160901, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.053365, Train-Class-Acc: {0: '91.45%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.154496, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.058411, Train-Class-Acc: {0: '90.98%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.150713, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.058372, Train-Class-Acc: {0: '89.89%', 1: '99.34%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.152713, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.055636, Train-Class-Acc: {0: '90.82%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145303, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.059466, Train-Class-Acc: {0: '89.66%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.127676, Val Acc: 97.32%, Val-Class-Acc: {0: '85.34%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_112.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_177.pth
# Epoch 178/1000, Train Loss: 0.054460, Train-Class-Acc: {0: '90.44%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.183818, Val Acc: 96.03%, Val-Class-Acc: {0: '76.58%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# ...
# Val Loss: 0.117650, Val Acc: 97.29%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.048804, Train-Class-Acc: {0: '92.07%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162212, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.057844, Train-Class-Acc: {0: '90.12%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.164149, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.054054, Train-Class-Acc: {0: '90.75%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.143393, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.048627, Train-Class-Acc: {0: '90.90%', 1: '99.34%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.156923, Val Acc: 96.78%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.054134, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165132, Val Acc: 96.47%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.054150, Train-Class-Acc: {0: '90.59%', 1: '99.42%', 2: '99.94%', 3: '100.00%'}
# Val Loss: 0.157677, Val Acc: 96.57%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.058579, Train-Class-Acc: {0: '90.28%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.161745, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.059031, Train-Class-Acc: {0: '90.98%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148834, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.056522, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.144014, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.050911, Train-Class-Acc: {0: '91.76%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148003, Val Acc: 96.91%, Val-Class-Acc: {0: '82.48%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.065349, Train-Class-Acc: {0: '89.58%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.194873, Val Acc: 95.93%, Val-Class-Acc: {0: '76.37%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.050851, Train-Class-Acc: {0: '90.28%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.167870, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.064217, Train-Class-Acc: {0: '90.59%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145921, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.050213, Train-Class-Acc: {0: '90.67%', 1: '99.56%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.148341, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.052677, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165534, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.052749, Train-Class-Acc: {0: '90.90%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.167702, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.060374, Train-Class-Acc: {0: '90.82%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.167508, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.053312, Train-Class-Acc: {0: '90.59%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.169844, Val Acc: 96.27%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.058657, Train-Class-Acc: {0: '90.28%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165006, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.049963, Train-Class-Acc: {0: '91.14%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.149499, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.056390, Train-Class-Acc: {0: '90.98%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.156657, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.054895, Train-Class-Acc: {0: '91.06%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.168752, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.057153, Train-Class-Acc: {0: '90.28%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.138352, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.051303, Train-Class-Acc: {0: '91.14%', 1: '99.27%', 2: '99.97%', 3: '100.00%'}
# Val Loss: 0.151307, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.056036, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.122776, Val Acc: 97.35%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.056984, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148566, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.054773, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138556, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.056965, Train-Class-Acc: {0: '89.89%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.184110, Val Acc: 96.06%, Val-Class-Acc: {0: '77.19%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.058391, Train-Class-Acc: {0: '91.14%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.154229, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.045818, Train-Class-Acc: {0: '91.76%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.144507, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.056447, Train-Class-Acc: {0: '90.12%', 1: '98.84%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158484, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.050388, Train-Class-Acc: {0: '89.89%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.154964, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.056326, Train-Class-Acc: {0: '90.20%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.154960, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.054848, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146680, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.055081, Train-Class-Acc: {0: '88.88%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.172107, Val Acc: 96.37%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.051475, Train-Class-Acc: {0: '91.45%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.175919, Val Acc: 95.93%, Val-Class-Acc: {0: '76.37%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.048531, Train-Class-Acc: {0: '90.82%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.137759, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.050878, Train-Class-Acc: {0: '91.14%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.133083, Val Acc: 97.18%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.052713, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.196770, Val Acc: 95.72%, Val-Class-Acc: {0: '74.95%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.054731, Train-Class-Acc: {0: '90.59%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.129754, Val Acc: 97.15%, Val-Class-Acc: {0: '84.93%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.049464, Train-Class-Acc: {0: '90.90%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.163054, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.051828, Train-Class-Acc: {0: '90.59%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.156329, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.051851, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.170816, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.055665, Train-Class-Acc: {0: '90.28%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.125499, Val Acc: 97.29%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.055806, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.170559, Val Acc: 96.37%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.057529, Train-Class-Acc: {0: '90.20%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.157185, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.059991, Train-Class-Acc: {0: '90.59%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.188063, Val Acc: 96.13%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.050338, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.131797, Val Acc: 97.12%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.061289, Train-Class-Acc: {0: '89.58%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135881, Val Acc: 96.98%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.043370, Train-Class-Acc: {0: '92.30%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138563, Val Acc: 97.12%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 712.79 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_best.pth (Val Accuracy: 97.46%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 536, Train Loss: 0.055512, Train-Acc: {0: '90.90%', 1: '99.34%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.108252, Val Acc: 97.46%, Val-Acc: {0: '87.78%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_536.pth
# Epoch 431, Train Loss: 0.049638, Train-Acc: {0: '91.21%', 1: '99.64%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110179, Val Acc: 97.42%, Val-Acc: {0: '87.17%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_431.pth
# Epoch 253, Train Loss: 0.047170, Train-Acc: {0: '92.22%', 1: '99.27%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.124253, Val Acc: 97.42%, Val-Acc: {0: '85.95%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_253.pth
# Epoch 331, Train Loss: 0.058281, Train-Acc: {0: '90.98%', 1: '99.13%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.121818, Val Acc: 97.35%, Val-Acc: {0: '86.56%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_331.pth
# Epoch 310, Train Loss: 0.052050, Train-Acc: {0: '91.37%', 1: '99.42%', 2: '99.97%', 3: '100.00%'},
# Val Loss: 0.128533, Val Acc: 97.35%, Val-Acc: {0: '85.13%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3/HAR_PNN_v2_epoch_310.pth
# ---
# ### Period 3
# + ##### Total training time: 712.79 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_3'*
# + ##### Best Epoch: 536
# #### __Val Accuracy: 97.46%__
# #### __Val-Class-Acc: {0: '87.78%', 1: '97.18%', 2: '100.00%', 3: '100.00%'}__
#
# ✅ Period 3 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc1(
#   (base_model): ProgressiveNeuralNetwork_fc1(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc1(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc1(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4
# + ##### Total training time: 868.30 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4'*
# + ##### Best Epoch: 780
# #### __Val Accuracy: 96.47%__
# #### __Val-Class-Acc: {0: '86.76%', 1: '97.56%', 2: '99.80%', 3: '100.00%', 4: '95.75%', 5: '98.81%'}__

# %%
# ================================
# 📌 Period 4 Configuration - Progressive Neural Network (PNN_fc1)
# ================================
period = 4

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 2  # 新增兩個類別（拆分 WALKING 類）
output_size = len(set(y_train))  # 到目前為止總類別數（應為 5）

# === Step 1: 還原 Period 2 的基礎 MLP + Column 結構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, 2, dropout)  # output: 2
prev_column_2 = HAR_PNN_Column_fc1(input_size, hidden_size, new_output_size=1)  # output: 1
frozen_step1 = ProgressiveNeuralNetwork_fc1(base_model=base_model, new_column=prev_column_2)

# === Step 2: 再加上 Period 3 的 Column ===
prev_column_3 = HAR_PNN_Column_fc1(input_size, hidden_size, new_output_size=1)  # Period 3 新增類別
frozen_step2 = ProgressiveNeuralNetwork_fc1(base_model=frozen_step1, new_column=prev_column_3)

# === 載入 Period 3 模型的 state_dict（已經是 Step2 完整結構）===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC1_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_step2.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_step2.to(device)
frozen_step2.eval()
for param in frozen_step2.parameters():
    param.requires_grad = False

# === Step 3: 加上 Period 4 的 Column 並包成新模型 ===
new_column_4 = HAR_PNN_Column_fc1(input_size, hidden_size, new_output_size=new_output_size)
model = ProgressiveNeuralNetwork_fc1(base_model=frozen_step2, new_column=new_column_4).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC1_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
del base_model, prev_column_2, prev_column_3, new_column_4, frozen_step1, frozen_step2, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 4843 MiB
#     - Device Name    : NVIDIA RTX A6000
# ProgressiveNeuralNetwork_fc1(
#   (base_model): ProgressiveNeuralNetwork_fc1(
#     (base_model): ProgressiveNeuralNetwork_fc1(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc1(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc1(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc1(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_2803466/913096177.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 5.589476, Train-Class-Acc: {0: '89.27%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '0.00%'}
# Val Loss: 4.929336, Val Acc: 67.15%, Val-Class-Acc: {0: '87.17%', 1: '97.37%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '0.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 3.519128, Train-Class-Acc: {0: '87.64%', 1: '98.84%', 2: '100.00%', 3: '100.00%', 4: '2.42%', 5: '1.52%'}
# Val Loss: 3.225756, Val Acc: 66.00%, Val-Class-Acc: {0: '78.00%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '0.21%', 5: '0.24%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 2.183600, Train-Class-Acc: {0: '89.35%', 1: '99.27%', 2: '99.92%', 3: '100.00%', 4: '17.99%', 5: '16.02%'}
# Val Loss: 1.965656, Val Acc: 73.33%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%', 3: '100.00%', 4: '10.40%', 5: '32.38%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 1.352836, Train-Class-Acc: {0: '89.66%', 1: '98.62%', 2: '99.51%', 3: '99.93%', 4: '34.95%', 5: '33.87%'}
# Val Loss: 1.721054, Val Acc: 73.06%, Val-Class-Acc: {0: '80.86%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '25.90%', 5: '17.62%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.888502, Train-Class-Acc: {0: '89.42%', 1: '99.71%', 2: '99.35%', 3: '100.00%', 4: '52.66%', 5: '49.70%'}
# Val Loss: 1.343990, Val Acc: 76.76%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '35.67%', 5: '32.86%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.583108, Train-Class-Acc: {0: '89.97%', 1: '99.42%', 2: '99.10%', 3: '99.93%', 4: '65.14%', 5: '63.59%'}
# Val Loss: 0.884630, Val Acc: 82.59%, Val-Class-Acc: {0: '86.76%', 1: '97.18%', 2: '100.00%', 3: '100.00%', 4: '55.20%', 5: '47.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.417740, Train-Class-Acc: {0: '90.51%', 1: '98.76%', 2: '99.02%', 3: '100.00%', 4: '72.41%', 5: '73.12%'}
# Val Loss: 0.385743, Val Acc: 91.35%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '80.47%', 5: '83.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.299546, Train-Class-Acc: {0: '92.61%', 1: '99.05%', 2: '98.29%', 3: '99.86%', 4: '78.29%', 5: '79.21%'}
# Val Loss: 0.458509, Val Acc: 88.90%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '69.64%', 5: '77.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.256797, Train-Class-Acc: {0: '90.44%', 1: '99.27%', 2: '97.72%', 3: '100.00%', 4: '82.29%', 5: '86.41%'}
# Val Loss: 0.342390, Val Acc: 92.13%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '85.77%', 5: '87.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.215778, Train-Class-Acc: {0: '89.66%', 1: '98.69%', 2: '98.37%', 3: '99.93%', 4: '87.70%', 5: '87.02%'}
# Val Loss: 0.276593, Val Acc: 93.01%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '85.35%', 5: '91.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.167256, Train-Class-Acc: {0: '90.98%', 1: '99.13%', 2: '98.69%', 3: '99.93%', 4: '90.68%', 5: '90.16%'}
# Val Loss: 0.353973, Val Acc: 90.94%, Val-Class-Acc: {0: '75.56%', 1: '99.62%', 2: '99.60%', 3: '100.00%', 4: '81.32%', 5: '86.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.154989, Train-Class-Acc: {0: '90.67%', 1: '99.56%', 2: '98.21%', 3: '100.00%', 4: '91.80%', 5: '92.09%'}
# Val Loss: 0.319261, Val Acc: 92.06%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '85.14%', 5: '88.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.134019, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '98.21%', 3: '99.93%', 4: '91.80%', 5: '94.93%'}
# Val Loss: 0.284073, Val Acc: 93.18%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '87.05%', 5: '92.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.124707, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '98.12%', 3: '99.93%', 4: '93.76%', 5: '94.32%'}
# Val Loss: 0.265645, Val Acc: 93.69%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '91.72%', 5: '91.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.106083, Train-Class-Acc: {0: '90.59%', 1: '99.13%', 2: '98.29%', 3: '100.00%', 4: '95.25%', 5: '96.15%'}
# Val Loss: 0.249615, Val Acc: 94.13%, Val-Class-Acc: {0: '85.95%', 1: '98.68%', 2: '99.60%', 3: '100.00%', 4: '88.75%', 5: '90.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.104076, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '98.12%', 3: '99.93%', 4: '94.78%', 5: '96.55%'}
# Val Loss: 0.260656, Val Acc: 93.86%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '90.87%', 5: '91.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.104208, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '98.78%', 3: '99.93%', 4: '96.46%', 5: '96.15%'}
# Val Loss: 0.285901, Val Acc: 93.04%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '99.80%', 3: '100.00%', 4: '85.77%', 5: '88.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.102608, Train-Class-Acc: {0: '90.98%', 1: '99.49%', 2: '98.37%', 3: '100.00%', 4: '96.55%', 5: '95.64%'}
# Val Loss: 0.270706, Val Acc: 93.55%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.08%', 5: '90.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.100828, Train-Class-Acc: {0: '90.05%', 1: '99.20%', 2: '98.45%', 3: '100.00%', 4: '96.37%', 5: '96.86%'}
# Val Loss: 0.207713, Val Acc: 95.08%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '99.40%', 3: '100.00%', 4: '90.02%', 5: '95.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.093608, Train-Class-Acc: {0: '90.28%', 1: '99.05%', 2: '98.45%', 3: '100.00%', 4: '97.39%', 5: '98.07%'}
# Val Loss: 0.193040, Val Acc: 95.55%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '99.60%', 3: '100.00%', 4: '92.57%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.078220, Train-Class-Acc: {0: '90.75%', 1: '99.34%', 2: '99.02%', 3: '99.93%', 4: '97.67%', 5: '97.57%'}
# Val Loss: 0.262185, Val Acc: 93.99%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '88.32%', 5: '96.19%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.087555, Train-Class-Acc: {0: '91.21%', 1: '99.34%', 2: '97.80%', 3: '99.93%', 4: '96.74%', 5: '98.07%'}
# Val Loss: 0.290404, Val Acc: 93.52%, Val-Class-Acc: {0: '72.71%', 1: '99.44%', 2: '100.00%', 3: '100.00%', 4: '92.57%', 5: '95.48%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.068087, Train-Class-Acc: {0: '92.15%', 1: '99.42%', 2: '98.69%', 3: '100.00%', 4: '97.20%', 5: '97.57%'}
# Val Loss: 0.224958, Val Acc: 94.67%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '89.17%', 5: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.074128, Train-Class-Acc: {0: '92.22%', 1: '99.49%', 2: '98.69%', 3: '99.86%', 4: '97.67%', 5: '97.67%'}
# Val Loss: 0.247627, Val Acc: 94.57%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '88.75%', 5: '98.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.080620, Train-Class-Acc: {0: '90.36%', 1: '99.13%', 2: '98.86%', 3: '99.93%', 4: '98.04%', 5: '97.67%'}
# Val Loss: 0.256680, Val Acc: 94.13%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '88.96%', 5: '94.05%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.079351, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '98.53%', 3: '100.00%', 4: '97.67%', 5: '98.58%'}
# Val Loss: 0.212179, Val Acc: 94.98%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '91.51%', 5: '93.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.078257, Train-Class-Acc: {0: '90.05%', 1: '98.76%', 2: '99.43%', 3: '100.00%', 4: '98.88%', 5: '98.88%'}
# Val Loss: 0.261685, Val Acc: 93.79%, Val-Class-Acc: {0: '75.15%', 1: '99.62%', 2: '98.79%', 3: '100.00%', 4: '94.06%', 5: '94.05%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.060968, Train-Class-Acc: {0: '90.67%', 1: '99.05%', 2: '99.51%', 3: '99.93%', 4: '98.51%', 5: '99.09%'}
# Val Loss: 0.198528, Val Acc: 95.28%, Val-Class-Acc: {0: '84.93%', 1: '98.50%', 2: '98.79%', 3: '100.00%', 4: '92.99%', 5: '95.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.076093, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '99.18%', 3: '99.86%', 4: '98.60%', 5: '97.87%'}
# Val Loss: 0.217496, Val Acc: 95.01%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '90.02%', 5: '98.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.075006, Train-Class-Acc: {0: '89.19%', 1: '99.20%', 2: '99.02%', 3: '99.93%', 4: '99.07%', 5: '99.19%'}
# Val Loss: 0.255372, Val Acc: 94.30%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '91.72%', 5: '94.29%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.073997, Train-Class-Acc: {0: '90.28%', 1: '99.05%', 2: '98.86%', 3: '99.86%', 4: '99.07%', 5: '97.97%'}
# Val Loss: 0.286165, Val Acc: 93.76%, Val-Class-Acc: {0: '73.12%', 1: '99.62%', 2: '99.19%', 3: '100.00%', 4: '92.78%', 5: '97.14%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.067777, Train-Class-Acc: {0: '90.59%', 1: '99.20%', 2: '99.43%', 3: '99.86%', 4: '98.32%', 5: '98.38%'}
# Val Loss: 0.235586, Val Acc: 94.50%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '97.18%', 3: '100.00%', 4: '92.99%', 5: '94.76%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.073811, Train-Class-Acc: {0: '90.98%', 1: '99.27%', 2: '99.18%', 3: '99.93%', 4: '98.79%', 5: '98.99%'}
# Val Loss: 0.257397, Val Acc: 93.89%, Val-Class-Acc: {0: '75.56%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.69%', 5: '93.57%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.064187, Train-Class-Acc: {0: '91.68%', 1: '99.49%', 2: '99.92%', 3: '100.00%', 4: '98.70%', 5: '98.99%'}
# Val Loss: 0.198068, Val Acc: 95.55%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.48%', 5: '97.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.062529, Train-Class-Acc: {0: '91.60%', 1: '99.05%', 2: '99.35%', 3: '100.00%', 4: '99.07%', 5: '99.39%'}
# Val Loss: 0.231301, Val Acc: 94.64%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '91.72%', 5: '96.19%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.076445, Train-Class-Acc: {0: '89.04%', 1: '99.13%', 2: '99.43%', 3: '100.00%', 4: '98.60%', 5: '98.58%'}
# Val Loss: 0.282528, Val Acc: 93.62%, Val-Class-Acc: {0: '76.58%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '88.96%', 5: '96.67%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.063311, Train-Class-Acc: {0: '90.82%', 1: '98.91%', 2: '99.51%', 3: '99.93%', 4: '99.16%', 5: '99.19%'}
# Val Loss: 0.243170, Val Acc: 94.40%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '96.77%', 3: '100.00%', 4: '92.99%', 5: '96.67%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.078293, Train-Class-Acc: {0: '89.89%', 1: '99.05%', 2: '99.10%', 3: '100.00%', 4: '98.97%', 5: '98.58%'}
# Val Loss: 0.228628, Val Acc: 94.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '92.14%', 5: '95.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.061734, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '99.43%', 3: '100.00%', 4: '98.97%', 5: '99.29%'}
# Val Loss: 0.192552, Val Acc: 95.32%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '98.59%', 3: '100.00%', 4: '94.06%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.068421, Train-Class-Acc: {0: '90.67%', 1: '99.56%', 2: '99.10%', 3: '99.93%', 4: '99.16%', 5: '99.29%'}
# Val Loss: 0.246536, Val Acc: 94.77%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '92.78%', 5: '96.90%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.061047, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '99.51%', 3: '100.00%', 4: '98.88%', 5: '98.88%'}
# Val Loss: 0.206002, Val Acc: 95.28%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '96.60%', 5: '97.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_41.pth
# Epoch 42/1000, Train Loss: 0.067926, Train-Class-Acc: {0: '89.89%', 1: '99.13%', 2: '99.43%', 3: '99.93%', 4: '99.35%', 5: '99.49%'}
# Val Loss: 0.351164, Val Acc: 92.81%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '82.59%', 5: '92.86%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.066201, Train-Class-Acc: {0: '90.90%', 1: '99.42%', 2: '99.10%', 3: '100.00%', 4: '98.97%', 5: '98.88%'}
# Val Loss: 0.263869, Val Acc: 94.71%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%', 3: '100.00%', 4: '87.69%', 5: '95.71%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.069935, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '99.76%', 3: '99.93%', 4: '98.97%', 5: '99.39%'}
# Val Loss: 0.197194, Val Acc: 95.59%, Val-Class-Acc: {0: '83.71%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '95.33%', 5: '95.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_44.pth
# Epoch 45/1000, Train Loss: 0.073716, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '99.35%', 3: '100.00%', 4: '98.88%', 5: '99.09%'}
# Val Loss: 0.238970, Val Acc: 94.74%, Val-Class-Acc: {0: '78.82%', 1: '99.62%', 2: '99.60%', 3: '100.00%', 4: '94.90%', 5: '94.52%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.071122, Train-Class-Acc: {0: '90.36%', 1: '99.49%', 2: '99.35%', 3: '99.86%', 4: '99.53%', 5: '98.78%'}
# Val Loss: 0.195014, Val Acc: 95.25%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '99.19%', 3: '100.00%', 4: '89.81%', 5: '97.86%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.068777, Train-Class-Acc: {0: '89.89%', 1: '99.42%', 2: '99.18%', 3: '99.93%', 4: '99.35%', 5: '99.39%'}
# Val Loss: 0.215295, Val Acc: 95.08%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.54%', 5: '97.62%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.058068, Train-Class-Acc: {0: '90.67%', 1: '99.71%', 2: '99.59%', 3: '100.00%', 4: '99.16%', 5: '99.39%'}
# Val Loss: 0.225493, Val Acc: 94.84%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '92.99%', 5: '95.48%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.057825, Train-Class-Acc: {0: '91.37%', 1: '99.27%', 2: '99.67%', 3: '99.93%', 4: '99.07%', 5: '99.59%'}
# Val Loss: 0.262189, Val Acc: 93.69%, Val-Class-Acc: {0: '76.58%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '90.23%', 5: '95.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.067910, Train-Class-Acc: {0: '90.20%', 1: '99.71%', 2: '99.35%', 3: '99.93%', 4: '99.44%', 5: '98.88%'}
# Val Loss: 0.240196, Val Acc: 94.54%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '91.72%', 5: '96.19%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.058344, Train-Class-Acc: {0: '91.84%', 1: '98.98%', 2: '99.59%', 3: '100.00%', 4: '99.44%', 5: '99.19%'}
# Val Loss: 0.197363, Val Acc: 95.49%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '99.60%', 3: '100.00%', 4: '93.21%', 5: '95.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.060379, Train-Class-Acc: {0: '91.29%', 1: '99.27%', 2: '99.51%', 3: '99.93%', 4: '99.16%', 5: '99.29%'}
# Val Loss: 0.298138, Val Acc: 93.52%, Val-Class-Acc: {0: '73.52%', 1: '99.62%', 2: '99.60%', 3: '100.00%', 4: '90.66%', 5: '96.90%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.063394, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '99.59%', 3: '99.86%', 4: '99.63%', 5: '99.39%'}
# Val Loss: 0.225802, Val Acc: 94.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '94.06%', 5: '94.76%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.063634, Train-Class-Acc: {0: '90.12%', 1: '99.56%', 2: '99.27%', 3: '100.00%', 4: '99.25%', 5: '99.29%'}
# Val Loss: 0.241776, Val Acc: 94.30%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '94.27%', 5: '89.76%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.055101, Train-Class-Acc: {0: '90.98%', 1: '98.98%', 2: '99.84%', 3: '100.00%', 4: '99.35%', 5: '99.59%'}
# Val Loss: 0.216865, Val Acc: 95.08%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '96.60%', 5: '96.43%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.064367, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '99.18%', 3: '100.00%', 4: '99.07%', 5: '99.70%'}
# Val Loss: 0.248778, Val Acc: 94.16%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '92.99%', 5: '93.10%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.062226, Train-Class-Acc: {0: '91.52%', 1: '99.49%', 2: '99.51%', 3: '99.86%', 4: '98.97%', 5: '99.59%'}
# Val Loss: 0.251472, Val Acc: 94.37%, Val-Class-Acc: {0: '76.58%', 1: '99.62%', 2: '99.19%', 3: '100.00%', 4: '94.06%', 5: '95.95%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.070271, Train-Class-Acc: {0: '89.66%', 1: '99.42%', 2: '99.43%', 3: '99.86%', 4: '99.35%', 5: '99.19%'}
# Val Loss: 0.202360, Val Acc: 95.18%, Val-Class-Acc: {0: '85.34%', 1: '98.12%', 2: '99.40%', 3: '100.00%', 4: '92.78%', 5: '94.52%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.058527, Train-Class-Acc: {0: '91.45%', 1: '99.34%', 2: '99.59%', 3: '100.00%', 4: '99.72%', 5: '99.70%'}
# Val Loss: 0.260515, Val Acc: 94.06%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '91.08%', 5: '90.48%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.063975, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '99.35%', 3: '99.93%', 4: '99.25%', 5: '99.39%'}
# Val Loss: 0.272534, Val Acc: 93.79%, Val-Class-Acc: {0: '75.97%', 1: '99.62%', 2: '99.40%', 3: '100.00%', 4: '91.30%', 5: '95.48%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.061644, Train-Class-Acc: {0: '91.14%', 1: '99.42%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.205290, Val Acc: 95.18%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '91.72%', 5: '96.67%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.056146, Train-Class-Acc: {0: '90.20%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '99.63%', 5: '99.80%'}
# Val Loss: 0.192654, Val Acc: 95.55%, Val-Class-Acc: {0: '84.11%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '93.21%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.067719, Train-Class-Acc: {0: '88.96%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '99.72%', 5: '99.70%'}
# Val Loss: 0.216856, Val Acc: 95.28%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '95.75%', 5: '96.43%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.058529, Train-Class-Acc: {0: '90.59%', 1: '99.34%', 2: '99.92%', 3: '100.00%', 4: '99.63%', 5: '99.29%'}
# Val Loss: 0.232934, Val Acc: 94.60%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '94.27%', 5: '93.81%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.064680, Train-Class-Acc: {0: '90.51%', 1: '99.20%', 2: '99.67%', 3: '99.79%', 4: '99.35%', 5: '99.59%'}
# Val Loss: 0.225865, Val Acc: 94.94%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '94.90%', 5: '93.10%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.072623, Train-Class-Acc: {0: '89.89%', 1: '99.64%', 2: '99.51%', 3: '100.00%', 4: '99.35%', 5: '99.80%'}
# Val Loss: 0.210369, Val Acc: 95.49%, Val-Class-Acc: {0: '84.93%', 1: '98.68%', 2: '100.00%', 3: '100.00%', 4: '92.36%', 5: '96.19%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.063365, Train-Class-Acc: {0: '90.36%', 1: '99.42%', 2: '99.84%', 3: '99.86%', 4: '99.53%', 5: '99.49%'}
# Val Loss: 0.280947, Val Acc: 94.10%, Val-Class-Acc: {0: '77.19%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '89.60%', 5: '97.38%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.069020, Train-Class-Acc: {0: '89.50%', 1: '99.49%', 2: '99.43%', 3: '100.00%', 4: '99.07%', 5: '99.49%'}
# Val Loss: 0.208573, Val Acc: 95.32%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.97%', 5: '96.19%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.057837, Train-Class-Acc: {0: '90.67%', 1: '99.49%', 2: '99.51%', 3: '99.93%', 4: '99.25%', 5: '99.70%'}
# Val Loss: 0.223620, Val Acc: 94.81%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '91.51%', 5: '95.71%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.067949, Train-Class-Acc: {0: '89.81%', 1: '99.49%', 2: '99.76%', 3: '99.93%', 4: '99.07%', 5: '99.09%'}
# Val Loss: 0.251856, Val Acc: 94.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '91.08%', 5: '96.67%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.054216, Train-Class-Acc: {0: '91.68%', 1: '99.49%', 2: '99.76%', 3: '99.93%', 4: '99.44%', 5: '99.39%'}
# Val Loss: 0.229598, Val Acc: 94.94%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '94.48%', 5: '96.43%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.056934, Train-Class-Acc: {0: '91.29%', 1: '99.05%', 2: '99.76%', 3: '100.00%', 4: '99.35%', 5: '99.80%'}
# Val Loss: 0.189293, Val Acc: 95.59%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '99.40%', 3: '100.00%', 4: '94.06%', 5: '95.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.063636, Train-Class-Acc: {0: '89.74%', 1: '99.49%', 2: '99.76%', 3: '99.93%', 4: '99.35%', 5: '99.49%'}
# Val Loss: 0.195270, Val Acc: 95.66%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '97.98%', 3: '100.00%', 4: '96.18%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_73.pth
# Epoch 74/1000, Train Loss: 0.059476, Train-Class-Acc: {0: '90.05%', 1: '99.78%', 2: '99.59%', 3: '99.93%', 4: '99.53%', 5: '99.29%'}
# Val Loss: 0.214022, Val Acc: 95.08%, Val-Class-Acc: {0: '82.89%', 1: '99.06%', 2: '99.80%', 3: '100.00%', 4: '92.36%', 5: '95.48%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.064076, Train-Class-Acc: {0: '90.44%', 1: '99.49%', 2: '99.51%', 3: '99.93%', 4: '99.53%', 5: '99.39%'}
# Val Loss: 0.219858, Val Acc: 95.35%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '90.66%', 5: '99.05%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.048163, Train-Class-Acc: {0: '91.45%', 1: '99.64%', 2: '99.92%', 3: '100.00%', 4: '99.44%', 5: '99.90%'}
# Val Loss: 0.217719, Val Acc: 95.22%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '97.03%', 5: '93.10%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.061419, Train-Class-Acc: {0: '90.28%', 1: '99.27%', 2: '99.51%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.252341, Val Acc: 94.54%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '90.66%', 5: '92.38%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.068062, Train-Class-Acc: {0: '89.81%', 1: '99.42%', 2: '99.43%', 3: '100.00%', 4: '99.53%', 5: '99.49%'}
# Val Loss: 0.260206, Val Acc: 94.74%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%', 3: '100.00%', 4: '87.26%', 5: '96.19%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.056610, Train-Class-Acc: {0: '90.82%', 1: '99.49%', 2: '99.76%', 3: '99.93%', 4: '99.53%', 5: '99.59%'}
# Val Loss: 0.222564, Val Acc: 95.25%, Val-Class-Acc: {0: '83.10%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '91.93%', 5: '96.67%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.051328, Train-Class-Acc: {0: '90.51%', 1: '99.49%', 2: '99.84%', 3: '100.00%', 4: '99.72%', 5: '99.80%'}
# Val Loss: 0.283794, Val Acc: 94.03%, Val-Class-Acc: {0: '72.91%', 1: '99.62%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '95.71%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.057564, Train-Class-Acc: {0: '91.37%', 1: '99.64%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.49%'}
# Val Loss: 0.230180, Val Acc: 95.25%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.99%', 5: '96.67%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.066172, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '99.67%', 3: '99.86%', 4: '99.63%', 5: '99.59%'}
# Val Loss: 0.212130, Val Acc: 95.35%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '92.14%', 5: '95.71%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.059720, Train-Class-Acc: {0: '91.14%', 1: '99.34%', 2: '99.35%', 3: '100.00%', 4: '99.72%', 5: '99.59%'}
# Val Loss: 0.218092, Val Acc: 94.98%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '95.97%', 5: '93.81%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.060203, Train-Class-Acc: {0: '90.28%', 1: '99.56%', 2: '99.84%', 3: '100.00%', 4: '99.35%', 5: '99.49%'}
# Val Loss: 0.321247, Val Acc: 93.15%, Val-Class-Acc: {0: '74.95%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '92.99%', 5: '89.52%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.053211, Train-Class-Acc: {0: '91.68%', 1: '99.34%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.285432, Val Acc: 94.06%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '99.80%', 3: '100.00%', 4: '93.63%', 5: '96.19%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.058564, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '99.76%', 3: '100.00%', 4: '99.53%', 5: '99.49%'}
# Val Loss: 0.244697, Val Acc: 94.60%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%', 3: '100.00%', 4: '92.78%', 5: '90.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.059003, Train-Class-Acc: {0: '90.98%', 1: '99.56%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.59%'}
# Val Loss: 0.218220, Val Acc: 95.18%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '94.48%', 5: '97.62%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.067111, Train-Class-Acc: {0: '90.05%', 1: '99.05%', 2: '99.35%', 3: '100.00%', 4: '99.35%', 5: '99.39%'}
# Val Loss: 0.205574, Val Acc: 95.18%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '95.75%', 5: '93.81%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.068459, Train-Class-Acc: {0: '90.44%', 1: '99.27%', 2: '99.35%', 3: '99.93%', 4: '99.07%', 5: '99.29%'}
# Val Loss: 0.304300, Val Acc: 93.38%, Val-Class-Acc: {0: '74.34%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '90.66%', 5: '95.71%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.055420, Train-Class-Acc: {0: '90.98%', 1: '99.71%', 2: '99.84%', 3: '99.93%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.196617, Val Acc: 95.69%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '98.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_90.pth
# Epoch 91/1000, Train Loss: 0.058958, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.196480, Val Acc: 95.52%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '96.18%', 5: '96.19%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.053086, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '99.84%', 3: '99.93%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.191219, Val Acc: 95.76%, Val-Class-Acc: {0: '84.52%', 1: '98.50%', 2: '99.80%', 3: '100.00%', 4: '94.48%', 5: '96.67%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_92.pth
# Epoch 93/1000, Train Loss: 0.059542, Train-Class-Acc: {0: '90.98%', 1: '99.49%', 2: '99.67%', 3: '100.00%', 4: '99.25%', 5: '99.59%'}
# Val Loss: 0.234307, Val Acc: 95.11%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%', 3: '100.00%', 4: '90.66%', 5: '95.48%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.060586, Train-Class-Acc: {0: '90.44%', 1: '99.13%', 2: '99.51%', 3: '99.93%', 4: '99.44%', 5: '99.70%'}
# Val Loss: 0.250186, Val Acc: 94.71%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '93.63%', 5: '95.48%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.057772, Train-Class-Acc: {0: '89.97%', 1: '99.34%', 2: '99.92%', 3: '100.00%', 4: '99.63%', 5: '99.90%'}
# Val Loss: 0.272201, Val Acc: 94.03%, Val-Class-Acc: {0: '73.73%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '94.69%', 5: '95.24%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.048301, Train-Class-Acc: {0: '91.60%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '99.72%', 5: '99.70%'}
# Val Loss: 0.233083, Val Acc: 94.84%, Val-Class-Acc: {0: '78.21%', 1: '99.44%', 2: '99.40%', 3: '100.00%', 4: '94.48%', 5: '96.90%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.066978, Train-Class-Acc: {0: '89.50%', 1: '98.98%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.264867, Val Acc: 94.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '93.21%', 5: '95.24%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.063560, Train-Class-Acc: {0: '90.36%', 1: '98.91%', 2: '99.92%', 3: '99.93%', 4: '99.72%', 5: '100.00%'}
# Val Loss: 0.182769, Val Acc: 95.83%, Val-Class-Acc: {0: '84.11%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '94.90%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_44.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_98.pth
# Epoch 99/1000, Train Loss: 0.053530, Train-Class-Acc: {0: '90.51%', 1: '99.20%', 2: '99.92%', 3: '100.00%', 4: '99.63%', 5: '99.80%'}
# Val Loss: 0.173532, Val Acc: 96.06%, Val-Class-Acc: {0: '84.11%', 1: '99.06%', 2: '99.19%', 3: '100.00%', 4: '95.12%', 5: '98.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_72.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_99.pth
# Epoch 100/1000, Train Loss: 0.053887, Train-Class-Acc: {0: '91.60%', 1: '99.42%', 2: '99.76%', 3: '99.93%', 4: '99.72%', 5: '100.00%'}
# Val Loss: 0.216347, Val Acc: 95.42%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '94.48%', 5: '97.14%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.051854, Train-Class-Acc: {0: '90.98%', 1: '99.71%', 2: '99.84%', 3: '100.00%', 4: '99.63%', 5: '99.49%'}
# Val Loss: 0.274997, Val Acc: 94.06%, Val-Class-Acc: {0: '73.73%', 1: '99.62%', 2: '99.19%', 3: '100.00%', 4: '96.60%', 5: '94.29%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.053253, Train-Class-Acc: {0: '90.67%', 1: '99.05%', 2: '100.00%', 3: '100.00%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.241162, Val Acc: 94.44%, Val-Class-Acc: {0: '76.58%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '94.90%', 5: '95.48%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.049959, Train-Class-Acc: {0: '91.45%', 1: '99.13%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.258409, Val Acc: 94.40%, Val-Class-Acc: {0: '74.54%', 1: '99.62%', 2: '99.19%', 3: '100.00%', 4: '94.90%', 5: '97.62%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.060627, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.191766, Val Acc: 95.59%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '99.60%', 3: '100.00%', 4: '94.06%', 5: '96.67%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.053662, Train-Class-Acc: {0: '92.15%', 1: '99.13%', 2: '99.76%', 3: '99.86%', 4: '99.81%', 5: '99.59%'}
# Val Loss: 0.272385, Val Acc: 94.03%, Val-Class-Acc: {0: '75.76%', 1: '99.44%', 2: '99.60%', 3: '100.00%', 4: '93.42%', 5: '95.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.065401, Train-Class-Acc: {0: '90.82%', 1: '99.13%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.80%'}
# Val Loss: 0.190955, Val Acc: 95.79%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '99.19%', 3: '100.00%', 4: '96.18%', 5: '95.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_73.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_106.pth
# Epoch 107/1000, Train Loss: 0.056060, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '99.92%', 3: '100.00%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.176872, Val Acc: 95.86%, Val-Class-Acc: {0: '85.13%', 1: '97.93%', 2: '99.40%', 3: '100.00%', 4: '94.06%', 5: '98.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_90.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_107.pth
# Epoch 108/1000, Train Loss: 0.057642, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.200604, Val Acc: 95.66%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '94.48%', 5: '98.57%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.056095, Train-Class-Acc: {0: '92.15%', 1: '99.05%', 2: '99.67%', 3: '100.00%', 4: '99.63%', 5: '99.59%'}
# Val Loss: 0.201065, Val Acc: 95.59%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.90%', 5: '97.38%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.061382, Train-Class-Acc: {0: '90.90%', 1: '99.34%', 2: '99.43%', 3: '99.93%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.206267, Val Acc: 95.49%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '94.69%', 5: '97.62%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.057977, Train-Class-Acc: {0: '90.36%', 1: '98.98%', 2: '99.67%', 3: '99.93%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.212003, Val Acc: 95.52%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '94.90%', 5: '98.57%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.049332, Train-Class-Acc: {0: '91.29%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.223886, Val Acc: 95.01%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '92.57%', 5: '97.38%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.059739, Train-Class-Acc: {0: '90.20%', 1: '99.64%', 2: '99.84%', 3: '99.93%', 4: '99.91%', 5: '99.59%'}
# Val Loss: 0.267858, Val Acc: 94.20%, Val-Class-Acc: {0: '73.52%', 1: '99.44%', 2: '97.58%', 3: '100.00%', 4: '95.54%', 5: '98.81%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.057500, Train-Class-Acc: {0: '89.74%', 1: '99.49%', 2: '99.76%', 3: '100.00%', 4: '99.81%', 5: '100.00%'}
# Val Loss: 0.202620, Val Acc: 95.35%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '99.40%', 3: '100.00%', 4: '95.75%', 5: '93.57%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.065321, Train-Class-Acc: {0: '89.89%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '100.00%', 5: '99.80%'}
# Val Loss: 0.169735, Val Acc: 96.30%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '98.99%', 3: '100.00%', 4: '95.54%', 5: '97.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_92.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_115.pth
# Epoch 116/1000, Train Loss: 0.066729, Train-Class-Acc: {0: '90.36%', 1: '99.13%', 2: '99.67%', 3: '100.00%', 4: '99.72%', 5: '99.90%'}
# Val Loss: 0.189113, Val Acc: 95.76%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '99.40%', 3: '100.00%', 4: '94.06%', 5: '96.90%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.055314, Train-Class-Acc: {0: '90.82%', 1: '99.56%', 2: '100.00%', 3: '99.93%', 4: '99.72%', 5: '99.80%'}
# Val Loss: 0.185993, Val Acc: 95.83%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.97%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_106.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_117.pth
# Epoch 118/1000, Train Loss: 0.062529, Train-Class-Acc: {0: '89.66%', 1: '98.91%', 2: '99.84%', 3: '99.93%', 4: '99.72%', 5: '99.90%'}
# Val Loss: 0.266024, Val Acc: 94.60%, Val-Class-Acc: {0: '77.60%', 1: '99.44%', 2: '100.00%', 3: '100.00%', 4: '92.99%', 5: '96.90%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.053351, Train-Class-Acc: {0: '90.90%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.231939, Val Acc: 94.88%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '91.08%', 5: '95.71%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.055018, Train-Class-Acc: {0: '91.06%', 1: '99.13%', 2: '99.76%', 3: '100.00%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.256752, Val Acc: 94.91%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.72%', 5: '96.90%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.062371, Train-Class-Acc: {0: '89.66%', 1: '99.27%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '99.59%'}
# Val Loss: 0.313039, Val Acc: 93.86%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '87.05%', 5: '97.14%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.058910, Train-Class-Acc: {0: '91.21%', 1: '99.27%', 2: '99.67%', 3: '99.93%', 4: '99.72%', 5: '99.49%'}
# Val Loss: 0.214683, Val Acc: 95.69%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%', 3: '100.00%', 4: '91.93%', 5: '98.33%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.057744, Train-Class-Acc: {0: '91.37%', 1: '99.64%', 2: '99.76%', 3: '99.86%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.248314, Val Acc: 95.08%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%', 3: '100.00%', 4: '88.75%', 5: '97.14%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.062939, Train-Class-Acc: {0: '90.51%', 1: '98.98%', 2: '99.59%', 3: '100.00%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.289624, Val Acc: 93.76%, Val-Class-Acc: {0: '73.12%', 1: '99.44%', 2: '99.60%', 3: '100.00%', 4: '92.57%', 5: '97.14%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.054563, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.70%'}
# Val Loss: 0.256761, Val Acc: 94.40%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.08%', 5: '97.14%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.050502, Train-Class-Acc: {0: '91.21%', 1: '99.42%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.230528, Val Acc: 95.11%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.78%', 5: '98.57%'}, LR: 0.000100
# ...
# Val Loss: 0.228964, Val Acc: 95.76%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '98.79%', 3: '100.00%', 4: '96.39%', 5: '95.24%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.055188, Train-Class-Acc: {0: '90.59%', 1: '99.20%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.306787, Val Acc: 93.96%, Val-Class-Acc: {0: '76.17%', 1: '99.44%', 2: '95.97%', 3: '100.00%', 4: '95.12%', 5: '96.43%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.051350, Train-Class-Acc: {0: '91.99%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.344767, Val Acc: 93.01%, Val-Class-Acc: {0: '73.12%', 1: '99.62%', 2: '98.39%', 3: '100.00%', 4: '91.93%', 5: '93.81%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.054911, Train-Class-Acc: {0: '90.59%', 1: '99.49%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.179756, Val Acc: 95.86%, Val-Class-Acc: {0: '85.95%', 1: '97.56%', 2: '99.40%', 3: '100.00%', 4: '95.75%', 5: '95.95%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.054271, Train-Class-Acc: {0: '91.06%', 1: '99.64%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '99.80%'}
# Val Loss: 0.232421, Val Acc: 95.22%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.93%', 5: '99.05%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.062713, Train-Class-Acc: {0: '90.28%', 1: '99.13%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '99.80%'}
# Val Loss: 0.254977, Val Acc: 95.08%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.51%', 5: '95.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.051734, Train-Class-Acc: {0: '90.82%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.243151, Val Acc: 95.05%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '94.48%', 5: '96.67%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.051226, Train-Class-Acc: {0: '91.06%', 1: '99.42%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.223075, Val Acc: 95.42%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.54%', 5: '97.62%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.047709, Train-Class-Acc: {0: '91.60%', 1: '99.56%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.271226, Val Acc: 94.30%, Val-Class-Acc: {0: '74.95%', 1: '99.44%', 2: '98.19%', 3: '100.00%', 4: '95.97%', 5: '96.67%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.063220, Train-Class-Acc: {0: '89.97%', 1: '99.49%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.245202, Val Acc: 95.11%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '88.54%', 5: '98.33%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.058649, Train-Class-Acc: {0: '90.44%', 1: '99.27%', 2: '100.00%', 3: '99.93%', 4: '99.81%', 5: '100.00%'}
# Val Loss: 0.274297, Val Acc: 94.67%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '96.77%', 3: '100.00%', 4: '95.75%', 5: '95.24%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.050391, Train-Class-Acc: {0: '91.68%', 1: '99.05%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.216251, Val Acc: 95.45%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '98.79%', 3: '100.00%', 4: '92.99%', 5: '98.10%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.049410, Train-Class-Acc: {0: '91.29%', 1: '98.91%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.247569, Val Acc: 94.64%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.27%', 5: '95.95%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.061458, Train-Class-Acc: {0: '89.42%', 1: '99.05%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.219911, Val Acc: 95.39%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.69%', 5: '96.19%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.058704, Train-Class-Acc: {0: '90.44%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.230742, Val Acc: 95.66%, Val-Class-Acc: {0: '84.93%', 1: '98.68%', 2: '99.80%', 3: '100.00%', 4: '92.78%', 5: '97.14%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.064020, Train-Class-Acc: {0: '90.20%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.216889, Val Acc: 95.59%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '93.84%', 5: '97.86%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.051912, Train-Class-Acc: {0: '91.06%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.280818, Val Acc: 94.74%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '91.72%', 5: '96.43%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.052115, Train-Class-Acc: {0: '91.29%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.209686, Val Acc: 95.69%, Val-Class-Acc: {0: '85.13%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '94.27%', 5: '96.19%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.052856, Train-Class-Acc: {0: '91.21%', 1: '99.49%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.213720, Val Acc: 95.62%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.97%', 5: '97.62%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.055259, Train-Class-Acc: {0: '90.98%', 1: '99.64%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.210326, Val Acc: 95.52%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '96.18%', 5: '97.86%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.059958, Train-Class-Acc: {0: '89.81%', 1: '99.56%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.279357, Val Acc: 94.37%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '93.63%', 5: '89.05%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.049730, Train-Class-Acc: {0: '91.76%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.173800, Val Acc: 96.30%, Val-Class-Acc: {0: '85.34%', 1: '98.68%', 2: '99.60%', 3: '100.00%', 4: '96.18%', 5: '97.62%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.048500, Train-Class-Acc: {0: '91.60%', 1: '99.49%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.182867, Val Acc: 96.23%, Val-Class-Acc: {0: '84.52%', 1: '98.68%', 2: '99.19%', 3: '100.00%', 4: '97.45%', 5: '97.14%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.057667, Train-Class-Acc: {0: '90.28%', 1: '99.20%', 2: '99.76%', 3: '99.93%', 4: '100.00%', 5: '99.70%'}
# Val Loss: 0.218067, Val Acc: 95.52%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.97%', 5: '98.57%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.061870, Train-Class-Acc: {0: '89.89%', 1: '99.64%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.186982, Val Acc: 95.83%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%', 3: '100.00%', 4: '94.27%', 5: '97.14%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.057928, Train-Class-Acc: {0: '90.36%', 1: '99.49%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.289591, Val Acc: 94.13%, Val-Class-Acc: {0: '73.12%', 1: '99.44%', 2: '100.00%', 3: '100.00%', 4: '93.63%', 5: '98.10%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.059180, Train-Class-Acc: {0: '89.81%', 1: '99.20%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.191524, Val Acc: 95.83%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '95.33%', 5: '98.57%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.055005, Train-Class-Acc: {0: '91.29%', 1: '99.05%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.193888, Val Acc: 95.89%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '98.30%', 5: '96.19%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.053427, Train-Class-Acc: {0: '90.98%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.206074, Val Acc: 95.66%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.75%', 5: '97.86%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.051278, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.235740, Val Acc: 95.32%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '98.09%', 5: '97.14%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.048057, Train-Class-Acc: {0: '90.75%', 1: '99.85%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.216306, Val Acc: 95.52%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '95.97%', 5: '98.10%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.056777, Train-Class-Acc: {0: '90.12%', 1: '98.98%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.235461, Val Acc: 95.32%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.78%', 5: '97.38%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.055499, Train-Class-Acc: {0: '90.59%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.229980, Val Acc: 95.25%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '95.33%', 5: '98.33%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.058741, Train-Class-Acc: {0: '90.12%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.197788, Val Acc: 96.03%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '97.03%', 5: '98.81%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.060014, Train-Class-Acc: {0: '89.97%', 1: '99.42%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.210909, Val Acc: 95.25%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '94.06%', 5: '99.76%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.054310, Train-Class-Acc: {0: '90.44%', 1: '99.56%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.308937, Val Acc: 93.65%, Val-Class-Acc: {0: '71.08%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '92.36%', 5: '98.33%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.051906, Train-Class-Acc: {0: '90.67%', 1: '99.71%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.249067, Val Acc: 95.18%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%', 3: '100.00%', 4: '91.08%', 5: '97.86%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.058959, Train-Class-Acc: {0: '90.44%', 1: '99.56%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.311743, Val Acc: 94.13%, Val-Class-Acc: {0: '75.36%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '91.30%', 5: '97.86%'}, LR: 0.000100
#
# ⏳ Total training time: 868.30 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_best.pth (Val Accuracy: 96.47%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 780, Train Loss: 0.052266, Train-Acc: {0: '91.29%', 1: '99.49%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.166074, Val Acc: 96.47%, Val-Acc: {0: '86.76%', 1: '97.56%', 2: '99.80%', 3: '100.00%', 4: '95.75%', 5: '98.81%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_780.pth
# Epoch 619, Train Loss: 0.049519, Train-Acc: {0: '91.45%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.176626, Val Acc: 96.47%, Val-Acc: {0: '85.95%', 1: '98.87%', 2: '100.00%', 3: '100.00%', 4: '95.12%', 5: '98.57%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_619.pth
# Epoch 786, Train Loss: 0.053421, Train-Acc: {0: '92.15%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'},
# Val Loss: 0.183104, Val Acc: 96.44%, Val-Acc: {0: '88.80%', 1: '96.99%', 2: '100.00%', 3: '100.00%', 4: '94.90%', 5: '97.62%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_786.pth
# Epoch 337, Train Loss: 0.054497, Train-Acc: {0: '90.98%', 1: '99.42%', 2: '99.84%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.169602, Val Acc: 96.40%, Val-Acc: {0: '83.50%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '97.45%', 5: '98.10%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_337.pth
# Epoch 677, Train Loss: 0.062465, Train-Acc: {0: '90.12%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.166575, Val Acc: 96.37%, Val-Acc: {0: '87.17%', 1: '97.74%', 2: '99.60%', 3: '100.00%', 4: '94.90%', 5: '98.57%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4/HAR_PNN_v2_epoch_677.pth
# ---
# ### Period 4
# + ##### Total training time: 868.30 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc1
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC1_Period_4'*
# + ##### Best Epoch: 780
# #### __Val Accuracy: 96.47%__
# #### __Val-Class-Acc: {0: '86.76%', 1: '97.56%', 2: '99.80%', 3: '100.00%', 4: '95.75%', 5: '98.81%'}__
#
# ✅ Period 4 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc1(
#   (base_model): ProgressiveNeuralNetwork_fc1(
#     (base_model): ProgressiveNeuralNetwork_fc1(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc1(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc1(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc1(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ## __~~~ PNN_fc2 ~~~__

# %% [markdown]
# ---
# ### Period 2
# + ##### Total training time: 480.26 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2'*
# + ##### Best Epoch: 145
# #### __Val Accuracy: 96.93%__
# #### __Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 2 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 2

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 1  # 新增 1 個類別
output_size = len(set(y_train))  # 到目前為止所有類別數

# === Load frozen Period 1 model ===
frozen_model = HAR_MLP_v2(input_size, hidden_size, output_size - new_output_size, dropout)
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"Baseline_{period-1}", "HAR_MLP_PNN_v2_best.pth"
)
frozen_checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(frozen_checkpoint['model_state_dict'])
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create new PNN column ===
new_column = HAR_PNN_Column_fc2(input_size=input_size, hidden_size=hidden_size, new_output_size=new_output_size)

# === Wrap into ProgressiveNeuralNetwork ===
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_model, new_column=new_column).to(device)

# === Define optimizer, loss, etc. ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, frozen_model, new_column, frozen_checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5303 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# /tmp/ipykernel_2803466/3489795576.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   frozen_checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.380569, Train-Class-Acc: {0: '89.42%', 1: '97.67%', 2: '82.98%'}
# Val Loss: 0.221704, Val Acc: 94.94%, Val-Class-Acc: {0: '79.43%', 1: '98.87%', 2: '98.92%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.094197, Train-Class-Acc: {0: '90.44%', 1: '97.96%', 2: '98.93%'}
# Val Loss: 0.158848, Val Acc: 96.47%, Val-Class-Acc: {0: '85.13%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.090061, Train-Class-Acc: {0: '90.12%', 1: '98.54%', 2: '99.60%'}
# Val Loss: 0.154991, Val Acc: 96.68%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.070391, Train-Class-Acc: {0: '91.45%', 1: '98.69%', 2: '99.73%'}
# Val Loss: 0.180983, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.066995, Train-Class-Acc: {0: '92.22%', 1: '98.47%', 2: '99.94%'}
# Val Loss: 0.183949, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.060083, Train-Class-Acc: {0: '91.68%', 1: '98.40%', 2: '99.91%'}
# Val Loss: 0.159542, Val Acc: 96.31%, Val-Class-Acc: {0: '83.71%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.074978, Train-Class-Acc: {0: '91.37%', 1: '98.33%', 2: '99.88%'}
# Val Loss: 0.167226, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.069322, Train-Class-Acc: {0: '91.76%', 1: '98.98%', 2: '99.82%'}
# Val Loss: 0.146932, Val Acc: 96.60%, Val-Class-Acc: {0: '85.74%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.074777, Train-Class-Acc: {0: '91.06%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.165508, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.069843, Train-Class-Acc: {0: '91.37%', 1: '98.76%', 2: '99.94%'}
# Val Loss: 0.158276, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.066408, Train-Class-Acc: {0: '90.28%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.161727, Val Acc: 96.27%, Val-Class-Acc: {0: '83.50%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 12/1000, Train Loss: 0.059192, Train-Class-Acc: {0: '91.76%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.159262, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 13/1000, Train Loss: 0.070758, Train-Class-Acc: {0: '90.98%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.151208, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.060787, Train-Class-Acc: {0: '91.76%', 1: '98.98%', 2: '99.94%'}
# Val Loss: 0.151140, Val Acc: 96.64%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.056688, Train-Class-Acc: {0: '93.39%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.149713, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.071408, Train-Class-Acc: {0: '91.37%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.148938, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.056421, Train-Class-Acc: {0: '91.60%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.184165, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.064445, Train-Class-Acc: {0: '91.76%', 1: '98.62%', 2: '99.94%'}
# Val Loss: 0.180985, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.069274, Train-Class-Acc: {0: '90.75%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.137835, Val Acc: 96.76%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.061841, Train-Class-Acc: {0: '91.84%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.163466, Val Acc: 96.39%, Val-Class-Acc: {0: '83.50%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.061931, Train-Class-Acc: {0: '92.30%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.153171, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.058833, Train-Class-Acc: {0: '91.29%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.140063, Val Acc: 96.80%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.063227, Train-Class-Acc: {0: '91.29%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.163618, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.057053, Train-Class-Acc: {0: '93.23%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.180893, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.068961, Train-Class-Acc: {0: '90.90%', 1: '98.91%', 2: '99.97%'}
# Val Loss: 0.149547, Val Acc: 96.51%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.054137, Train-Class-Acc: {0: '92.77%', 1: '98.98%', 2: '99.97%'}
# Val Loss: 0.144156, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.066630, Train-Class-Acc: {0: '91.37%', 1: '98.40%', 2: '99.97%'}
# Val Loss: 0.164954, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.064359, Train-Class-Acc: {0: '91.29%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.175578, Val Acc: 96.10%, Val-Class-Acc: {0: '81.87%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.057771, Train-Class-Acc: {0: '91.99%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.171473, Val Acc: 96.06%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.065345, Train-Class-Acc: {0: '91.14%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.145311, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.071435, Train-Class-Acc: {0: '91.06%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.174805, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.060045, Train-Class-Acc: {0: '92.07%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.190101, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.059259, Train-Class-Acc: {0: '91.99%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.190032, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.068456, Train-Class-Acc: {0: '91.76%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.163197, Val Acc: 96.14%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.063486, Train-Class-Acc: {0: '91.91%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.188357, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.058765, Train-Class-Acc: {0: '92.77%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.203941, Val Acc: 95.44%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.064531, Train-Class-Acc: {0: '90.75%', 1: '99.27%', 2: '99.97%'}
# Val Loss: 0.167531, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.054775, Train-Class-Acc: {0: '92.77%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.148419, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.066857, Train-Class-Acc: {0: '92.30%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.176245, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.060139, Train-Class-Acc: {0: '91.76%', 1: '98.91%', 2: '99.97%'}
# Val Loss: 0.138313, Val Acc: 96.85%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.056951, Train-Class-Acc: {0: '92.77%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.147408, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.054835, Train-Class-Acc: {0: '91.99%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.157923, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.053182, Train-Class-Acc: {0: '92.77%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.171356, Val Acc: 95.89%, Val-Class-Acc: {0: '80.86%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.060152, Train-Class-Acc: {0: '91.76%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.180514, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.065070, Train-Class-Acc: {0: '90.90%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.169877, Val Acc: 96.10%, Val-Class-Acc: {0: '81.87%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.062163, Train-Class-Acc: {0: '91.99%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.172807, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.066260, Train-Class-Acc: {0: '91.52%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.133323, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.057053, Train-Class-Acc: {0: '92.46%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.149875, Val Acc: 96.60%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.052687, Train-Class-Acc: {0: '92.38%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.146977, Val Acc: 96.56%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.058073, Train-Class-Acc: {0: '91.52%', 1: '99.13%', 2: '99.97%'}
# Val Loss: 0.171192, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.057833, Train-Class-Acc: {0: '92.30%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.149261, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.068599, Train-Class-Acc: {0: '91.45%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.159520, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.064586, Train-Class-Acc: {0: '92.15%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.144376, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_53.pth
# Epoch 54/1000, Train Loss: 0.062491, Train-Class-Acc: {0: '92.61%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.147730, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.057167, Train-Class-Acc: {0: '92.30%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.150150, Val Acc: 96.72%, Val-Class-Acc: {0: '85.34%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.059879, Train-Class-Acc: {0: '91.99%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.160614, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.064230, Train-Class-Acc: {0: '92.30%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.175704, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.078849, Train-Class-Acc: {0: '90.75%', 1: '98.03%', 2: '100.00%'}
# Val Loss: 0.149523, Val Acc: 96.56%, Val-Class-Acc: {0: '85.13%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.064939, Train-Class-Acc: {0: '92.22%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.177488, Val Acc: 96.02%, Val-Class-Acc: {0: '81.67%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.067012, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.158828, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.065036, Train-Class-Acc: {0: '91.76%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.159325, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.060740, Train-Class-Acc: {0: '91.29%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.162034, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.056381, Train-Class-Acc: {0: '92.53%', 1: '99.34%', 2: '100.00%'}
# Val Loss: 0.180693, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.068705, Train-Class-Acc: {0: '91.14%', 1: '99.34%', 2: '100.00%'}
# Val Loss: 0.155351, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.061764, Train-Class-Acc: {0: '91.68%', 1: '99.13%', 2: '99.97%'}
# Val Loss: 0.154477, Val Acc: 96.43%, Val-Class-Acc: {0: '84.73%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.068666, Train-Class-Acc: {0: '92.30%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.170593, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.065250, Train-Class-Acc: {0: '92.22%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.161402, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.070876, Train-Class-Acc: {0: '91.06%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.135545, Val Acc: 96.72%, Val-Class-Acc: {0: '86.76%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.065610, Train-Class-Acc: {0: '91.60%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.167034, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.061768, Train-Class-Acc: {0: '90.98%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.191863, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.072738, Train-Class-Acc: {0: '90.12%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.186350, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.059730, Train-Class-Acc: {0: '91.91%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.160999, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.065794, Train-Class-Acc: {0: '90.90%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.150987, Val Acc: 96.60%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.069230, Train-Class-Acc: {0: '91.21%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.157501, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.060134, Train-Class-Acc: {0: '93.16%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.146020, Val Acc: 96.60%, Val-Class-Acc: {0: '85.74%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.062894, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.126926, Val Acc: 96.85%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_53.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_76.pth
# Epoch 77/1000, Train Loss: 0.071498, Train-Class-Acc: {0: '89.89%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.167847, Val Acc: 96.35%, Val-Class-Acc: {0: '83.10%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.074590, Train-Class-Acc: {0: '90.75%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.183174, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.056657, Train-Class-Acc: {0: '92.69%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.164571, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.062501, Train-Class-Acc: {0: '91.91%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.174292, Val Acc: 96.18%, Val-Class-Acc: {0: '82.28%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.057390, Train-Class-Acc: {0: '91.91%', 1: '99.34%', 2: '100.00%'}
# Val Loss: 0.159280, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.069840, Train-Class-Acc: {0: '91.84%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.154871, Val Acc: 96.56%, Val-Class-Acc: {0: '85.34%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.056607, Train-Class-Acc: {0: '93.16%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.175675, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.059845, Train-Class-Acc: {0: '92.30%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.169945, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.070153, Train-Class-Acc: {0: '90.75%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.184812, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.063864, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.145047, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.058961, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.188484, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.069219, Train-Class-Acc: {0: '91.60%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.162884, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.061808, Train-Class-Acc: {0: '91.52%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.162625, Val Acc: 96.31%, Val-Class-Acc: {0: '83.50%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.062484, Train-Class-Acc: {0: '91.29%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.189360, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.064070, Train-Class-Acc: {0: '91.37%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.179574, Val Acc: 95.89%, Val-Class-Acc: {0: '80.86%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.071269, Train-Class-Acc: {0: '91.21%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.170702, Val Acc: 96.27%, Val-Class-Acc: {0: '82.89%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.063526, Train-Class-Acc: {0: '91.99%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.159900, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.065980, Train-Class-Acc: {0: '91.52%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.172469, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.068397, Train-Class-Acc: {0: '91.21%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.134211, Val Acc: 96.80%, Val-Class-Acc: {0: '86.56%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_95.pth
# Epoch 96/1000, Train Loss: 0.052883, Train-Class-Acc: {0: '93.23%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.184366, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.061762, Train-Class-Acc: {0: '91.29%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.171692, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.058313, Train-Class-Acc: {0: '92.46%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.180886, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.070723, Train-Class-Acc: {0: '90.90%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.169062, Val Acc: 96.22%, Val-Class-Acc: {0: '82.48%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.063273, Train-Class-Acc: {0: '91.84%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.160980, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.069566, Train-Class-Acc: {0: '91.68%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.174191, Val Acc: 96.02%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.061353, Train-Class-Acc: {0: '92.07%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.174319, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.067560, Train-Class-Acc: {0: '91.14%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.175389, Val Acc: 95.93%, Val-Class-Acc: {0: '81.26%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.061063, Train-Class-Acc: {0: '91.84%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.167205, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.067129, Train-Class-Acc: {0: '91.21%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.200060, Val Acc: 95.56%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.056957, Train-Class-Acc: {0: '91.76%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.136199, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.065857, Train-Class-Acc: {0: '91.60%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.146577, Val Acc: 96.64%, Val-Class-Acc: {0: '85.74%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.061394, Train-Class-Acc: {0: '92.77%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.152409, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.065895, Train-Class-Acc: {0: '91.29%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.187267, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.062831, Train-Class-Acc: {0: '92.15%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.154186, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.064158, Train-Class-Acc: {0: '92.30%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.156072, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.067226, Train-Class-Acc: {0: '91.45%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.176445, Val Acc: 96.10%, Val-Class-Acc: {0: '81.87%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.061223, Train-Class-Acc: {0: '91.45%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.164495, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.065836, Train-Class-Acc: {0: '90.98%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.144650, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.060867, Train-Class-Acc: {0: '92.15%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.140898, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.056619, Train-Class-Acc: {0: '92.85%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.168042, Val Acc: 96.14%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.070808, Train-Class-Acc: {0: '90.75%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.160330, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.062232, Train-Class-Acc: {0: '92.07%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.178319, Val Acc: 95.85%, Val-Class-Acc: {0: '80.65%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.054809, Train-Class-Acc: {0: '92.61%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.145689, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.067182, Train-Class-Acc: {0: '91.84%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.164335, Val Acc: 96.18%, Val-Class-Acc: {0: '82.28%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.060368, Train-Class-Acc: {0: '92.53%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.183795, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.060973, Train-Class-Acc: {0: '91.14%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.164087, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.062509, Train-Class-Acc: {0: '92.53%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.160637, Val Acc: 96.35%, Val-Class-Acc: {0: '83.10%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.066787, Train-Class-Acc: {0: '91.91%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.146109, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.069170, Train-Class-Acc: {0: '90.75%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.188618, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.058540, Train-Class-Acc: {0: '91.84%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.144372, Val Acc: 96.47%, Val-Class-Acc: {0: '84.93%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.069099, Train-Class-Acc: {0: '91.45%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.153694, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.071639, Train-Class-Acc: {0: '90.59%', 1: '98.54%', 2: '99.97%'}
# Val Loss: 0.169857, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.067169, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.148416, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.068047, Train-Class-Acc: {0: '90.75%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.160235, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.063508, Train-Class-Acc: {0: '91.06%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.180441, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.061330, Train-Class-Acc: {0: '91.99%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.153246, Val Acc: 96.47%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.061927, Train-Class-Acc: {0: '91.37%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.179986, Val Acc: 95.89%, Val-Class-Acc: {0: '81.06%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.062975, Train-Class-Acc: {0: '92.61%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.178643, Val Acc: 95.85%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.060438, Train-Class-Acc: {0: '91.76%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.163189, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.061216, Train-Class-Acc: {0: '92.22%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.144510, Val Acc: 96.72%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.060917, Train-Class-Acc: {0: '91.29%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.172219, Val Acc: 96.18%, Val-Class-Acc: {0: '82.28%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.057300, Train-Class-Acc: {0: '92.07%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.185514, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.064477, Train-Class-Acc: {0: '91.37%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.131382, Val Acc: 96.89%, Val-Class-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_139.pth
# Epoch 140/1000, Train Loss: 0.065571, Train-Class-Acc: {0: '91.84%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.138773, Val Acc: 96.68%, Val-Class-Acc: {0: '85.95%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.062189, Train-Class-Acc: {0: '91.52%', 1: '98.11%', 2: '100.00%'}
# Val Loss: 0.155587, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.056656, Train-Class-Acc: {0: '92.77%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.155716, Val Acc: 96.47%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.063958, Train-Class-Acc: {0: '92.69%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.170483, Val Acc: 96.02%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.069732, Train-Class-Acc: {0: '90.82%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.176420, Val Acc: 96.02%, Val-Class-Acc: {0: '81.67%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.056206, Train-Class-Acc: {0: '92.38%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.135199, Val Acc: 96.93%, Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_145.pth
# Epoch 146/1000, Train Loss: 0.066101, Train-Class-Acc: {0: '91.45%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.147748, Val Acc: 96.68%, Val-Class-Acc: {0: '85.95%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.056165, Train-Class-Acc: {0: '91.52%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.178936, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.065353, Train-Class-Acc: {0: '91.14%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.160362, Val Acc: 96.31%, Val-Class-Acc: {0: '83.30%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.059613, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.167097, Val Acc: 96.10%, Val-Class-Acc: {0: '82.48%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.070089, Train-Class-Acc: {0: '90.98%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.163559, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.065101, Train-Class-Acc: {0: '91.76%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.178155, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.056160, Train-Class-Acc: {0: '92.15%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.150343, Val Acc: 96.56%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.057781, Train-Class-Acc: {0: '91.52%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.186314, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.060275, Train-Class-Acc: {0: '92.22%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.152486, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.064369, Train-Class-Acc: {0: '92.07%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.176106, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.067641, Train-Class-Acc: {0: '91.21%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.163659, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.053186, Train-Class-Acc: {0: '92.77%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.161090, Val Acc: 96.27%, Val-Class-Acc: {0: '83.30%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.062211, Train-Class-Acc: {0: '92.07%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.195080, Val Acc: 95.56%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.054351, Train-Class-Acc: {0: '91.76%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.175098, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.060978, Train-Class-Acc: {0: '91.68%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.139356, Val Acc: 96.80%, Val-Class-Acc: {0: '86.56%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.059269, Train-Class-Acc: {0: '91.76%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.153818, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.066002, Train-Class-Acc: {0: '91.84%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.184344, Val Acc: 95.81%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.064552, Train-Class-Acc: {0: '91.45%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.146364, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.062511, Train-Class-Acc: {0: '92.30%', 1: '98.76%', 2: '99.97%'}
# Val Loss: 0.159698, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.060878, Train-Class-Acc: {0: '91.52%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.173840, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.053594, Train-Class-Acc: {0: '92.46%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.142447, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.064714, Train-Class-Acc: {0: '90.98%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.164811, Val Acc: 96.22%, Val-Class-Acc: {0: '82.69%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.066467, Train-Class-Acc: {0: '90.75%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.175818, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.053463, Train-Class-Acc: {0: '93.31%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.165506, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.063865, Train-Class-Acc: {0: '91.29%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.173418, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.048871, Train-Class-Acc: {0: '92.46%', 1: '99.20%', 2: '100.00%'}
# Val Loss: 0.158879, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.058616, Train-Class-Acc: {0: '92.15%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.171414, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.075161, Train-Class-Acc: {0: '90.98%', 1: '97.89%', 2: '100.00%'}
# Val Loss: 0.180279, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.062516, Train-Class-Acc: {0: '92.46%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.152157, Val Acc: 96.35%, Val-Class-Acc: {0: '83.91%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.058359, Train-Class-Acc: {0: '91.60%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.193999, Val Acc: 95.64%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.061964, Train-Class-Acc: {0: '92.92%', 1: '98.69%', 2: '99.97%'}
# Val Loss: 0.137530, Val Acc: 96.80%, Val-Class-Acc: {0: '86.76%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.060071, Train-Class-Acc: {0: '92.46%', 1: '98.25%', 2: '99.97%'}
# Val Loss: 0.145194, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.074615, Train-Class-Acc: {0: '91.14%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.152551, Val Acc: 96.39%, Val-Class-Acc: {0: '84.11%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.063366, Train-Class-Acc: {0: '92.07%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.186505, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.070543, Train-Class-Acc: {0: '91.29%', 1: '99.05%', 2: '99.97%'}
# Val Loss: 0.169339, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.073218, Train-Class-Acc: {0: '90.51%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.146707, Val Acc: 96.64%, Val-Class-Acc: {0: '84.93%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.054962, Train-Class-Acc: {0: '92.07%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.162829, Val Acc: 96.22%, Val-Class-Acc: {0: '83.10%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.073135, Train-Class-Acc: {0: '90.98%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.138487, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.056515, Train-Class-Acc: {0: '92.53%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.171667, Val Acc: 96.22%, Val-Class-Acc: {0: '82.48%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.062115, Train-Class-Acc: {0: '90.90%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.182535, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.062514, Train-Class-Acc: {0: '91.84%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.154336, Val Acc: 96.56%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.062855, Train-Class-Acc: {0: '92.15%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.161004, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.055954, Train-Class-Acc: {0: '92.92%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.150753, Val Acc: 96.47%, Val-Class-Acc: {0: '84.52%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.058465, Train-Class-Acc: {0: '91.76%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.166283, Val Acc: 96.14%, Val-Class-Acc: {0: '82.48%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.056204, Train-Class-Acc: {0: '92.30%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.147970, Val Acc: 96.72%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.063466, Train-Class-Acc: {0: '91.52%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.190778, Val Acc: 95.68%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.068900, Train-Class-Acc: {0: '90.67%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.146473, Val Acc: 96.72%, Val-Class-Acc: {0: '85.74%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.064426, Train-Class-Acc: {0: '91.21%', 1: '99.42%', 2: '100.00%'}
# Val Loss: 0.174202, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.062987, Train-Class-Acc: {0: '91.29%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.157130, Val Acc: 96.39%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.057105, Train-Class-Acc: {0: '91.60%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.180014, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.059920, Train-Class-Acc: {0: '91.99%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.170373, Val Acc: 96.14%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.060334, Train-Class-Acc: {0: '92.30%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.171244, Val Acc: 96.10%, Val-Class-Acc: {0: '82.08%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.065054, Train-Class-Acc: {0: '90.75%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.179401, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.066363, Train-Class-Acc: {0: '90.98%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.165765, Val Acc: 96.27%, Val-Class-Acc: {0: '83.10%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 200/1000, Train Loss: 0.062981, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.157855, Val Acc: 96.47%, Val-Class-Acc: {0: '84.32%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.064821, Train-Class-Acc: {0: '92.07%', 1: '98.91%', 2: '99.97%'}
# Val Loss: 0.173843, Val Acc: 96.06%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.060139, Train-Class-Acc: {0: '91.76%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.158370, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.064489, Train-Class-Acc: {0: '91.14%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.141188, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.072133, Train-Class-Acc: {0: '90.98%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.169524, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.063678, Train-Class-Acc: {0: '91.68%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.157092, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.059543, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.147542, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.063960, Train-Class-Acc: {0: '91.91%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.164607, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# ...
# Epoch 939/1000, Train Loss: 0.055641, Train-Class-Acc: {0: '93.16%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.152712, Val Acc: 96.35%, Val-Class-Acc: {0: '84.11%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.060064, Train-Class-Acc: {0: '91.84%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.150152, Val Acc: 96.68%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.063116, Train-Class-Acc: {0: '92.85%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.189768, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.062031, Train-Class-Acc: {0: '92.15%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.199285, Val Acc: 95.60%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.070551, Train-Class-Acc: {0: '90.75%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.136749, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.056534, Train-Class-Acc: {0: '92.69%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.163935, Val Acc: 96.27%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.057511, Train-Class-Acc: {0: '92.22%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.165376, Val Acc: 96.27%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.063284, Train-Class-Acc: {0: '92.15%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.166428, Val Acc: 96.02%, Val-Class-Acc: {0: '81.67%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.070862, Train-Class-Acc: {0: '91.76%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.164309, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.064533, Train-Class-Acc: {0: '92.38%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.150773, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.057520, Train-Class-Acc: {0: '92.22%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.179861, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.066026, Train-Class-Acc: {0: '91.52%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.147359, Val Acc: 96.56%, Val-Class-Acc: {0: '84.93%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.066710, Train-Class-Acc: {0: '92.15%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.162731, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.069903, Train-Class-Acc: {0: '91.06%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.169469, Val Acc: 96.31%, Val-Class-Acc: {0: '83.10%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.063852, Train-Class-Acc: {0: '91.76%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.169050, Val Acc: 96.06%, Val-Class-Acc: {0: '81.87%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.058252, Train-Class-Acc: {0: '92.15%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.148358, Val Acc: 96.51%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.056835, Train-Class-Acc: {0: '91.68%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.171721, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.054828, Train-Class-Acc: {0: '91.76%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.165319, Val Acc: 96.10%, Val-Class-Acc: {0: '81.87%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.064933, Train-Class-Acc: {0: '92.15%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.175494, Val Acc: 96.02%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.059181, Train-Class-Acc: {0: '92.46%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.151320, Val Acc: 96.39%, Val-Class-Acc: {0: '84.32%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.063908, Train-Class-Acc: {0: '91.45%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.149064, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.072914, Train-Class-Acc: {0: '90.44%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.157976, Val Acc: 96.39%, Val-Class-Acc: {0: '83.91%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.061041, Train-Class-Acc: {0: '91.68%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.160539, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.051079, Train-Class-Acc: {0: '92.69%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.146727, Val Acc: 96.64%, Val-Class-Acc: {0: '85.54%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.054875, Train-Class-Acc: {0: '93.16%', 1: '99.13%', 2: '100.00%'}
# Val Loss: 0.168410, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.051098, Train-Class-Acc: {0: '93.39%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.177584, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.068243, Train-Class-Acc: {0: '91.60%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.171523, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.065947, Train-Class-Acc: {0: '91.76%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.162746, Val Acc: 96.27%, Val-Class-Acc: {0: '83.30%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.058953, Train-Class-Acc: {0: '92.15%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.175411, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.067122, Train-Class-Acc: {0: '90.12%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.147645, Val Acc: 96.68%, Val-Class-Acc: {0: '85.95%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.061783, Train-Class-Acc: {0: '92.15%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.180956, Val Acc: 95.93%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.064476, Train-Class-Acc: {0: '91.84%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.175706, Val Acc: 95.89%, Val-Class-Acc: {0: '80.86%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.067556, Train-Class-Acc: {0: '91.37%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.151873, Val Acc: 96.43%, Val-Class-Acc: {0: '84.32%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.064483, Train-Class-Acc: {0: '91.06%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.172959, Val Acc: 96.06%, Val-Class-Acc: {0: '81.67%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.060828, Train-Class-Acc: {0: '91.84%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.177217, Val Acc: 96.02%, Val-Class-Acc: {0: '81.47%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.066566, Train-Class-Acc: {0: '91.06%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.171537, Val Acc: 96.14%, Val-Class-Acc: {0: '82.08%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.069294, Train-Class-Acc: {0: '90.51%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.154805, Val Acc: 96.60%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.058438, Train-Class-Acc: {0: '93.23%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.171442, Val Acc: 95.93%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.056700, Train-Class-Acc: {0: '93.16%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.153601, Val Acc: 96.47%, Val-Class-Acc: {0: '84.32%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.062821, Train-Class-Acc: {0: '91.29%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.184826, Val Acc: 95.89%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.068845, Train-Class-Acc: {0: '91.68%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.172839, Val Acc: 96.10%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.057533, Train-Class-Acc: {0: '93.16%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.159088, Val Acc: 96.35%, Val-Class-Acc: {0: '83.50%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.066610, Train-Class-Acc: {0: '91.14%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.159338, Val Acc: 96.31%, Val-Class-Acc: {0: '83.50%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.055716, Train-Class-Acc: {0: '92.46%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.154416, Val Acc: 96.43%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.065170, Train-Class-Acc: {0: '91.37%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.142070, Val Acc: 96.68%, Val-Class-Acc: {0: '85.74%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.064008, Train-Class-Acc: {0: '91.68%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.171580, Val Acc: 95.98%, Val-Class-Acc: {0: '81.26%', 1: '99.06%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.063355, Train-Class-Acc: {0: '91.84%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.169398, Val Acc: 95.98%, Val-Class-Acc: {0: '81.47%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.055288, Train-Class-Acc: {0: '92.92%', 1: '98.91%', 2: '99.97%'}
# Val Loss: 0.140059, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.064775, Train-Class-Acc: {0: '92.38%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.156691, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.056308, Train-Class-Acc: {0: '92.46%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.185498, Val Acc: 95.77%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.060646, Train-Class-Acc: {0: '92.07%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.159554, Val Acc: 96.43%, Val-Class-Acc: {0: '84.11%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.060074, Train-Class-Acc: {0: '92.07%', 1: '98.98%', 2: '100.00%'}
# Val Loss: 0.192353, Val Acc: 95.73%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.059155, Train-Class-Acc: {0: '92.38%', 1: '98.84%', 2: '100.00%'}
# Val Loss: 0.147710, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.057647, Train-Class-Acc: {0: '91.84%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.169993, Val Acc: 96.14%, Val-Class-Acc: {0: '82.28%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.057781, Train-Class-Acc: {0: '92.61%', 1: '99.05%', 2: '100.00%'}
# Val Loss: 0.140460, Val Acc: 96.72%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.062448, Train-Class-Acc: {0: '92.22%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.137763, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.063013, Train-Class-Acc: {0: '91.68%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.178868, Val Acc: 95.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.056917, Train-Class-Acc: {0: '91.52%', 1: '99.49%', 2: '100.00%'}
# Val Loss: 0.155713, Val Acc: 96.56%, Val-Class-Acc: {0: '84.73%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.074218, Train-Class-Acc: {0: '90.05%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.146926, Val Acc: 96.60%, Val-Class-Acc: {0: '85.34%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.061215, Train-Class-Acc: {0: '91.76%', 1: '99.27%', 2: '100.00%'}
# Val Loss: 0.155500, Val Acc: 96.22%, Val-Class-Acc: {0: '82.89%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.063232, Train-Class-Acc: {0: '91.84%', 1: '98.62%', 2: '100.00%'}
# Val Loss: 0.155541, Val Acc: 96.35%, Val-Class-Acc: {0: '83.71%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.065022, Train-Class-Acc: {0: '91.06%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.167179, Val Acc: 96.18%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 480.26 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_best.pth (Val Accuracy: 96.93%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 145, Train Loss: 0.056206, Train-Acc: {0: '92.38%', 1: '98.91%', 2: '100.00%'},
# Val Loss: 0.135199, Val Acc: 96.93%, Val-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_145.pth
# Epoch 735, Train Loss: 0.064606, Train-Acc: {0: '91.06%', 1: '98.54%', 2: '100.00%'},
# Val Loss: 0.130954, Val Acc: 96.89%, Val-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_735.pth
# Epoch 589, Train Loss: 0.055462, Train-Acc: {0: '93.47%', 1: '98.69%', 2: '100.00%'},
# Val Loss: 0.132146, Val Acc: 96.89%, Val-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_589.pth
# Epoch 443, Train Loss: 0.069908, Train-Acc: {0: '91.60%', 1: '98.25%', 2: '100.00%'},
# Val Loss: 0.133338, Val Acc: 96.89%, Val-Acc: {0: '86.97%', 1: '97.93%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_443.pth
# Epoch 139, Train Loss: 0.064477, Train-Acc: {0: '91.37%', 1: '98.84%', 2: '100.00%'},
# Val Loss: 0.131382, Val Acc: 96.89%, Val-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_139.pth
# ---
# ### Period 2
# + ##### Total training time: 480.26 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_2'*
# + ##### Best Epoch: 145
# #### __Val Accuracy: 96.93%__
# #### __Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}__
#
# ✅ Period 2 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): HAR_MLP_v2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3
# + ##### Total training time: 729.13 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3'*
# + ##### Best Epoch: 121
# #### __Val Accuracy: 97.56%__
# #### __Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}__

# %%
# ================================
# 📌 Period 3 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 3

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 1  # 新增一個類別
output_size = len(set(y_train))  # 目前總類別數（含舊+新）

# === 還原 Period 2 架構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, output_size - 2, dropout)
prev_column = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)

frozen_model = ProgressiveNeuralNetwork_fc2(base_model=base_model, new_column=prev_column)

# === 載入 Period 2 的 model state_dict ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create Period 3 New Column ===
new_column = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=new_output_size)

# === Combine into new PNN wrapper ===
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_model, new_column=new_column).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, base_model, prev_column, new_column, frozen_model, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5305 MiB
#     - Device Name    : NVIDIA RTX A6000
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_2803466/4077336448.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 0.210756, Train-Class-Acc: {0: '84.21%', 1: '98.69%', 2: '100.00%', 3: '78.89%'}
# Val Loss: 0.310711, Val Acc: 93.82%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '100.00%', 3: '87.34%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.094583, Train-Class-Acc: {0: '88.10%', 1: '99.27%', 2: '100.00%', 3: '96.02%'}
# Val Loss: 0.200956, Val Acc: 95.62%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '94.41%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.079032, Train-Class-Acc: {0: '89.27%', 1: '99.34%', 2: '100.00%', 3: '98.72%'}
# Val Loss: 0.183715, Val Acc: 95.86%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '95.34%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.072219, Train-Class-Acc: {0: '88.72%', 1: '99.27%', 2: '100.00%', 3: '98.37%'}
# Val Loss: 0.145237, Val Acc: 96.57%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '100.00%', 3: '96.09%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.057658, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.186367, Val Acc: 95.62%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '94.97%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.063895, Train-Class-Acc: {0: '89.81%', 1: '99.34%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.160951, Val Acc: 96.23%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.068702, Train-Class-Acc: {0: '90.20%', 1: '98.98%', 2: '100.00%', 3: '99.00%'}
# Val Loss: 0.186449, Val Acc: 95.79%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '100.00%', 3: '97.58%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.062674, Train-Class-Acc: {0: '90.20%', 1: '99.05%', 2: '100.00%', 3: '99.08%'}
# Val Loss: 0.178580, Val Acc: 96.13%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '95.72%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.063167, Train-Class-Acc: {0: '89.66%', 1: '99.20%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.130486, Val Acc: 96.91%, Val-Class-Acc: {0: '84.93%', 1: '98.12%', 2: '100.00%', 3: '98.70%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.058248, Train-Class-Acc: {0: '90.75%', 1: '99.56%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.137047, Val Acc: 96.81%, Val-Class-Acc: {0: '83.30%', 1: '99.25%', 2: '100.00%', 3: '98.51%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.052234, Train-Class-Acc: {0: '90.98%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.165242, Val Acc: 96.10%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '95.53%'}, LR: 0.000100
# Epoch 12/1000, Train Loss: 0.055340, Train-Class-Acc: {0: '91.21%', 1: '99.49%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.162456, Val Acc: 96.47%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.050613, Train-Class-Acc: {0: '90.98%', 1: '99.71%', 2: '100.00%', 3: '99.43%'}
# Val Loss: 0.132098, Val Acc: 97.01%, Val-Class-Acc: {0: '85.34%', 1: '98.50%', 2: '100.00%', 3: '98.51%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.064870, Train-Class-Acc: {0: '89.81%', 1: '99.27%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.210052, Val Acc: 95.35%, Val-Class-Acc: {0: '73.73%', 1: '99.62%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.059987, Train-Class-Acc: {0: '89.35%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.147251, Val Acc: 96.61%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.052980, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.142296, Val Acc: 96.84%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '99.07%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.056628, Train-Class-Acc: {0: '90.20%', 1: '99.49%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.179663, Val Acc: 96.13%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '100.00%', 3: '99.07%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.051901, Train-Class-Acc: {0: '90.98%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.164321, Val Acc: 96.54%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 19/1000, Train Loss: 0.052517, Train-Class-Acc: {0: '91.21%', 1: '99.64%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.166760, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.62%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.057225, Train-Class-Acc: {0: '91.68%', 1: '99.34%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.178694, Val Acc: 96.20%, Val-Class-Acc: {0: '77.80%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.055337, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.178979, Val Acc: 96.17%, Val-Class-Acc: {0: '77.60%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.056064, Train-Class-Acc: {0: '90.90%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.185256, Val Acc: 95.93%, Val-Class-Acc: {0: '76.17%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.058549, Train-Class-Acc: {0: '90.90%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.154814, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.057907, Train-Class-Acc: {0: '90.20%', 1: '99.78%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.178004, Val Acc: 96.06%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.052416, Train-Class-Acc: {0: '91.06%', 1: '98.98%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.146146, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.061010, Train-Class-Acc: {0: '88.57%', 1: '99.05%', 2: '99.97%', 3: '99.93%'}
# Val Loss: 0.177550, Val Acc: 96.03%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '100.00%', 3: '99.26%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.055000, Train-Class-Acc: {0: '91.21%', 1: '99.34%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.157767, Val Acc: 96.47%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '98.70%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.057127, Train-Class-Acc: {0: '90.90%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.124858, Val Acc: 97.32%, Val-Class-Acc: {0: '85.34%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.049457, Train-Class-Acc: {0: '90.67%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.143587, Val Acc: 97.12%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.059515, Train-Class-Acc: {0: '90.05%', 1: '99.64%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.182204, Val Acc: 96.10%, Val-Class-Acc: {0: '77.39%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.052678, Train-Class-Acc: {0: '91.06%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.186391, Val Acc: 95.93%, Val-Class-Acc: {0: '75.97%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.041647, Train-Class-Acc: {0: '92.69%', 1: '99.71%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.173816, Val Acc: 96.37%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.055823, Train-Class-Acc: {0: '90.59%', 1: '98.84%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.167166, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.055412, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.209824, Val Acc: 95.55%, Val-Class-Acc: {0: '74.13%', 1: '99.62%', 2: '100.00%', 3: '99.63%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.055069, Train-Class-Acc: {0: '90.05%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.195034, Val Acc: 95.83%, Val-Class-Acc: {0: '75.56%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.052743, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.163164, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.055063, Train-Class-Acc: {0: '90.20%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.172796, Val Acc: 96.20%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.059088, Train-Class-Acc: {0: '89.04%', 1: '99.20%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.120210, Val Acc: 97.32%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.053650, Train-Class-Acc: {0: '91.37%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.117862, Val Acc: 97.35%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.061599, Train-Class-Acc: {0: '89.66%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142238, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.058927, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.180055, Val Acc: 96.20%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.059612, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.132428, Val Acc: 97.15%, Val-Class-Acc: {0: '84.73%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.051294, Train-Class-Acc: {0: '90.36%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.141077, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.057714, Train-Class-Acc: {0: '89.66%', 1: '99.34%', 2: '99.97%', 3: '99.93%'}
# Val Loss: 0.158668, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.056620, Train-Class-Acc: {0: '90.12%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.176426, Val Acc: 96.13%, Val-Class-Acc: {0: '77.39%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.048776, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.145253, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.051669, Train-Class-Acc: {0: '92.30%', 1: '99.56%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.165116, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.057550, Train-Class-Acc: {0: '90.59%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158344, Val Acc: 96.74%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.062048, Train-Class-Acc: {0: '88.80%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.123025, Val Acc: 97.29%, Val-Class-Acc: {0: '85.13%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.058543, Train-Class-Acc: {0: '89.66%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.160280, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.061578, Train-Class-Acc: {0: '90.12%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.132884, Val Acc: 97.25%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_51.pth
# Epoch 52/1000, Train Loss: 0.065031, Train-Class-Acc: {0: '88.65%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.160391, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.049312, Train-Class-Acc: {0: '91.60%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.153389, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.058132, Train-Class-Acc: {0: '90.05%', 1: '99.05%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.132345, Val Acc: 97.12%, Val-Class-Acc: {0: '84.11%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.060109, Train-Class-Acc: {0: '89.89%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.159066, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.062671, Train-Class-Acc: {0: '89.50%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.134827, Val Acc: 97.08%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.059522, Train-Class-Acc: {0: '89.50%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.139599, Val Acc: 97.12%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.049315, Train-Class-Acc: {0: '91.45%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.151767, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.059742, Train-Class-Acc: {0: '89.42%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.131019, Val Acc: 97.18%, Val-Class-Acc: {0: '84.32%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.054972, Train-Class-Acc: {0: '90.51%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146357, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.046563, Train-Class-Acc: {0: '92.07%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.189047, Val Acc: 96.10%, Val-Class-Acc: {0: '77.19%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.052674, Train-Class-Acc: {0: '90.59%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.165696, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.053761, Train-Class-Acc: {0: '90.90%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.169007, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.055324, Train-Class-Acc: {0: '90.82%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165254, Val Acc: 96.23%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.061459, Train-Class-Acc: {0: '89.81%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.128768, Val Acc: 97.22%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.055955, Train-Class-Acc: {0: '90.75%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.129955, Val Acc: 97.12%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.056722, Train-Class-Acc: {0: '91.06%', 1: '99.20%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.149053, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.060316, Train-Class-Acc: {0: '89.89%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.157768, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.047711, Train-Class-Acc: {0: '90.59%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.141405, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.058270, Train-Class-Acc: {0: '90.75%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.165086, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.058999, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162087, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.057658, Train-Class-Acc: {0: '90.28%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.137828, Val Acc: 97.15%, Val-Class-Acc: {0: '83.71%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.055429, Train-Class-Acc: {0: '89.97%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.120946, Val Acc: 97.32%, Val-Class-Acc: {0: '86.15%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_51.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_73.pth
# Epoch 74/1000, Train Loss: 0.051777, Train-Class-Acc: {0: '90.59%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.150846, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.052459, Train-Class-Acc: {0: '90.75%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138774, Val Acc: 97.18%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.057682, Train-Class-Acc: {0: '91.06%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.194382, Val Acc: 96.03%, Val-Class-Acc: {0: '76.78%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.051249, Train-Class-Acc: {0: '92.07%', 1: '99.42%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.157733, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.047976, Train-Class-Acc: {0: '91.45%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.142487, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.054172, Train-Class-Acc: {0: '91.21%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.167464, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.063167, Train-Class-Acc: {0: '89.97%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.163730, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.045416, Train-Class-Acc: {0: '91.91%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.158800, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.058195, Train-Class-Acc: {0: '90.36%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.140969, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.056405, Train-Class-Acc: {0: '91.06%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.197984, Val Acc: 95.66%, Val-Class-Acc: {0: '74.34%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.051616, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.211563, Val Acc: 95.66%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.053551, Train-Class-Acc: {0: '90.98%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.161082, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.064217, Train-Class-Acc: {0: '89.35%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.175615, Val Acc: 96.06%, Val-Class-Acc: {0: '77.19%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.068036, Train-Class-Acc: {0: '89.04%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148180, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.061234, Train-Class-Acc: {0: '90.05%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165838, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.052874, Train-Class-Acc: {0: '91.60%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.164930, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.047212, Train-Class-Acc: {0: '91.14%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.126126, Val Acc: 97.22%, Val-Class-Acc: {0: '84.52%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.046596, Train-Class-Acc: {0: '91.84%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.155641, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.046986, Train-Class-Acc: {0: '91.99%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.141123, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.054061, Train-Class-Acc: {0: '91.37%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162670, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.050821, Train-Class-Acc: {0: '91.06%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.122834, Val Acc: 97.29%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.059542, Train-Class-Acc: {0: '90.51%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.179470, Val Acc: 96.20%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.053288, Train-Class-Acc: {0: '90.20%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.168704, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.060507, Train-Class-Acc: {0: '90.28%', 1: '98.84%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158937, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.055111, Train-Class-Acc: {0: '90.51%', 1: '99.20%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.163529, Val Acc: 96.44%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '98.88%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.052377, Train-Class-Acc: {0: '91.52%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.138773, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.056214, Train-Class-Acc: {0: '90.90%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149027, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.047865, Train-Class-Acc: {0: '91.37%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.141764, Val Acc: 96.95%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.057982, Train-Class-Acc: {0: '90.59%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.147380, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.053602, Train-Class-Acc: {0: '91.45%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.133343, Val Acc: 97.18%, Val-Class-Acc: {0: '84.32%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.050273, Train-Class-Acc: {0: '91.45%', 1: '99.27%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.159011, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.053818, Train-Class-Acc: {0: '90.75%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.124857, Val Acc: 97.25%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.061135, Train-Class-Acc: {0: '90.90%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.137504, Val Acc: 97.05%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.061030, Train-Class-Acc: {0: '89.97%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.140264, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.053948, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.163750, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.054381, Train-Class-Acc: {0: '89.58%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.170268, Val Acc: 96.17%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.057464, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.132754, Val Acc: 97.15%, Val-Class-Acc: {0: '83.71%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.050106, Train-Class-Acc: {0: '91.84%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.147497, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.053260, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.144996, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.053914, Train-Class-Acc: {0: '90.44%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.157462, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.055604, Train-Class-Acc: {0: '90.28%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.129107, Val Acc: 97.15%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.060398, Train-Class-Acc: {0: '90.28%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162295, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.052842, Train-Class-Acc: {0: '90.98%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142841, Val Acc: 96.95%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.060337, Train-Class-Acc: {0: '89.89%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.199017, Val Acc: 95.83%, Val-Class-Acc: {0: '75.56%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.050319, Train-Class-Acc: {0: '91.06%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.142465, Val Acc: 96.67%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '99.07%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.060007, Train-Class-Acc: {0: '90.51%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.124408, Val Acc: 97.35%, Val-Class-Acc: {0: '85.54%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_119.pth
# Epoch 120/1000, Train Loss: 0.056464, Train-Class-Acc: {0: '91.14%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.162089, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.051743, Train-Class-Acc: {0: '90.59%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.102279, Val Acc: 97.56%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_121.pth
# Epoch 122/1000, Train Loss: 0.060529, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.131971, Val Acc: 97.08%, Val-Class-Acc: {0: '83.71%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.067834, Train-Class-Acc: {0: '88.49%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.150754, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.053186, Train-Class-Acc: {0: '89.89%', 1: '99.49%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.147438, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.058489, Train-Class-Acc: {0: '90.28%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.159125, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.051790, Train-Class-Acc: {0: '91.14%', 1: '99.27%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.164663, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.054148, Train-Class-Acc: {0: '91.84%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.166716, Val Acc: 96.34%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.053407, Train-Class-Acc: {0: '90.98%', 1: '98.91%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.154080, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.049504, Train-Class-Acc: {0: '90.90%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.156039, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.054002, Train-Class-Acc: {0: '90.75%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.140685, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.051713, Train-Class-Acc: {0: '91.21%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.168253, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.054289, Train-Class-Acc: {0: '89.74%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.170202, Val Acc: 96.47%, Val-Class-Acc: {0: '79.43%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.053472, Train-Class-Acc: {0: '91.29%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.207746, Val Acc: 94.33%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%', 3: '83.05%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.052145, Train-Class-Acc: {0: '91.21%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.135250, Val Acc: 97.01%, Val-Class-Acc: {0: '83.30%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.047892, Train-Class-Acc: {0: '91.99%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.168771, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.055704, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.164667, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.056708, Train-Class-Acc: {0: '90.51%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.156549, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.060023, Train-Class-Acc: {0: '88.96%', 1: '99.13%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.187664, Val Acc: 96.03%, Val-Class-Acc: {0: '76.78%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.058060, Train-Class-Acc: {0: '90.20%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.154019, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.055152, Train-Class-Acc: {0: '90.59%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.188435, Val Acc: 96.13%, Val-Class-Acc: {0: '77.39%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.058100, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.143828, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.051019, Train-Class-Acc: {0: '90.05%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.128092, Val Acc: 97.29%, Val-Class-Acc: {0: '84.52%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.054429, Train-Class-Acc: {0: '90.36%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.179087, Val Acc: 96.23%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.052472, Train-Class-Acc: {0: '90.75%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.160759, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.056010, Train-Class-Acc: {0: '91.06%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.165704, Val Acc: 96.61%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.053269, Train-Class-Acc: {0: '91.52%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.171357, Val Acc: 96.30%, Val-Class-Acc: {0: '78.41%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.059966, Train-Class-Acc: {0: '90.12%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.171222, Val Acc: 96.40%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.050117, Train-Class-Acc: {0: '91.84%', 1: '99.56%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.182617, Val Acc: 96.17%, Val-Class-Acc: {0: '77.60%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.056642, Train-Class-Acc: {0: '89.58%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.158752, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.057785, Train-Class-Acc: {0: '89.42%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.117509, Val Acc: 97.25%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.056965, Train-Class-Acc: {0: '90.51%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.166549, Val Acc: 96.47%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.055056, Train-Class-Acc: {0: '91.45%', 1: '99.56%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.189652, Val Acc: 95.93%, Val-Class-Acc: {0: '76.17%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.057396, Train-Class-Acc: {0: '90.12%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.126679, Val Acc: 97.22%, Val-Class-Acc: {0: '84.93%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.055170, Train-Class-Acc: {0: '90.51%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135737, Val Acc: 97.08%, Val-Class-Acc: {0: '83.30%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.046141, Train-Class-Acc: {0: '91.60%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165039, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.056325, Train-Class-Acc: {0: '90.90%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148840, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.060169, Train-Class-Acc: {0: '89.89%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165447, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.051653, Train-Class-Acc: {0: '91.29%', 1: '99.49%', 2: '99.97%', 3: '99.93%'}
# Val Loss: 0.161679, Val Acc: 96.57%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.056252, Train-Class-Acc: {0: '90.82%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.147132, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.062816, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.137876, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.053745, Train-Class-Acc: {0: '90.36%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138250, Val Acc: 97.12%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.060175, Train-Class-Acc: {0: '90.20%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.150123, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.056873, Train-Class-Acc: {0: '89.81%', 1: '99.42%', 2: '99.97%', 3: '99.93%'}
# Val Loss: 0.181289, Val Acc: 96.20%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.053135, Train-Class-Acc: {0: '90.98%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149952, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.052156, Train-Class-Acc: {0: '89.89%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.175902, Val Acc: 96.27%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.056039, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145008, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.054295, Train-Class-Acc: {0: '90.67%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.174130, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.055985, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.188734, Val Acc: 96.10%, Val-Class-Acc: {0: '76.99%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.060240, Train-Class-Acc: {0: '90.05%', 1: '99.34%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.148861, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.048180, Train-Class-Acc: {0: '90.44%', 1: '99.64%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.139835, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.056835, Train-Class-Acc: {0: '90.05%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.136265, Val Acc: 97.05%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.052578, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.139336, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# ...
# Val Loss: 0.178084, Val Acc: 96.23%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.057357, Train-Class-Acc: {0: '90.44%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.153160, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.050269, Train-Class-Acc: {0: '91.21%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.128070, Val Acc: 97.18%, Val-Class-Acc: {0: '85.13%', 1: '98.31%', 2: '100.00%', 3: '99.81%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.047953, Train-Class-Acc: {0: '91.91%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.148550, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.051003, Train-Class-Acc: {0: '91.68%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.152449, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.057573, Train-Class-Acc: {0: '90.59%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.160850, Val Acc: 96.44%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.051736, Train-Class-Acc: {0: '90.90%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.124469, Val Acc: 97.22%, Val-Class-Acc: {0: '84.52%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.061742, Train-Class-Acc: {0: '89.74%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.133495, Val Acc: 97.05%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.051915, Train-Class-Acc: {0: '91.29%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.135757, Val Acc: 96.88%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.050436, Train-Class-Acc: {0: '90.75%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.129408, Val Acc: 97.08%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.057410, Train-Class-Acc: {0: '90.90%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.203596, Val Acc: 95.89%, Val-Class-Acc: {0: '75.76%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.058488, Train-Class-Acc: {0: '90.28%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.115721, Val Acc: 97.32%, Val-Class-Acc: {0: '86.76%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.046564, Train-Class-Acc: {0: '91.84%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.173537, Val Acc: 96.27%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.057336, Train-Class-Acc: {0: '90.05%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149910, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.054272, Train-Class-Acc: {0: '90.51%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142172, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.058421, Train-Class-Acc: {0: '90.75%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.146914, Val Acc: 97.05%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.055143, Train-Class-Acc: {0: '90.12%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138184, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.051041, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.165341, Val Acc: 96.50%, Val-Class-Acc: {0: '79.84%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.055409, Train-Class-Acc: {0: '90.44%', 1: '98.98%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.155934, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.052407, Train-Class-Acc: {0: '89.66%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.155199, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.058512, Train-Class-Acc: {0: '88.96%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.201373, Val Acc: 95.66%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.051609, Train-Class-Acc: {0: '90.82%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.118517, Val Acc: 97.35%, Val-Class-Acc: {0: '85.74%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.060265, Train-Class-Acc: {0: '90.36%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.136463, Val Acc: 97.08%, Val-Class-Acc: {0: '83.30%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.049145, Train-Class-Acc: {0: '91.14%', 1: '99.56%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.118598, Val Acc: 97.29%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.050301, Train-Class-Acc: {0: '90.59%', 1: '99.05%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.149802, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.058903, Train-Class-Acc: {0: '89.66%', 1: '99.64%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.138008, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.054961, Train-Class-Acc: {0: '89.66%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.205045, Val Acc: 95.59%, Val-Class-Acc: {0: '73.93%', 1: '99.62%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.057272, Train-Class-Acc: {0: '90.82%', 1: '99.71%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.155068, Val Acc: 96.71%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.063222, Train-Class-Acc: {0: '89.89%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.156777, Val Acc: 96.64%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.054308, Train-Class-Acc: {0: '91.52%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.174063, Val Acc: 96.13%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.052422, Train-Class-Acc: {0: '91.37%', 1: '99.34%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.156650, Val Acc: 96.67%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.060216, Train-Class-Acc: {0: '90.05%', 1: '98.76%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.147394, Val Acc: 96.71%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '99.44%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.052737, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.185047, Val Acc: 96.00%, Val-Class-Acc: {0: '76.58%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.054955, Train-Class-Acc: {0: '90.67%', 1: '99.49%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148211, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.057306, Train-Class-Acc: {0: '89.66%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.139262, Val Acc: 97.12%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.044660, Train-Class-Acc: {0: '91.68%', 1: '99.78%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.133898, Val Acc: 97.22%, Val-Class-Acc: {0: '84.73%', 1: '98.68%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.056354, Train-Class-Acc: {0: '90.98%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.142924, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.055514, Train-Class-Acc: {0: '91.14%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.129791, Val Acc: 97.25%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.053615, Train-Class-Acc: {0: '90.90%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.141914, Val Acc: 97.01%, Val-Class-Acc: {0: '82.89%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.058266, Train-Class-Acc: {0: '90.20%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.126385, Val Acc: 97.25%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.051921, Train-Class-Acc: {0: '89.89%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.145367, Val Acc: 96.81%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.053224, Train-Class-Acc: {0: '90.98%', 1: '99.27%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.167059, Val Acc: 96.30%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.055298, Train-Class-Acc: {0: '91.06%', 1: '98.84%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.147033, Val Acc: 96.84%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.059574, Train-Class-Acc: {0: '90.36%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.128040, Val Acc: 97.08%, Val-Class-Acc: {0: '85.34%', 1: '97.37%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.059317, Train-Class-Acc: {0: '90.82%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.143321, Val Acc: 96.98%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.050603, Train-Class-Acc: {0: '90.82%', 1: '99.42%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.147720, Val Acc: 96.78%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.051385, Train-Class-Acc: {0: '90.67%', 1: '99.20%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.115077, Val Acc: 97.25%, Val-Class-Acc: {0: '85.95%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.066883, Train-Class-Acc: {0: '89.74%', 1: '98.91%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.148755, Val Acc: 96.91%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.049609, Train-Class-Acc: {0: '90.82%', 1: '99.42%', 2: '100.00%', 3: '99.93%'}
# Val Loss: 0.127610, Val Acc: 97.12%, Val-Class-Acc: {0: '83.91%', 1: '98.87%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.051895, Train-Class-Acc: {0: '91.37%', 1: '99.13%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.191667, Val Acc: 96.06%, Val-Class-Acc: {0: '76.99%', 1: '99.44%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.056553, Train-Class-Acc: {0: '90.82%', 1: '99.20%', 2: '100.00%', 3: '100.00%'}
# Val Loss: 0.161696, Val Acc: 96.54%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '100.00%', 3: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 729.13 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_best.pth (Val Accuracy: 97.56%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 121, Train Loss: 0.051743, Train-Acc: {0: '90.59%', 1: '99.56%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.102279, Val Acc: 97.56%, Val-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_121.pth
# Epoch 661, Train Loss: 0.054715, Train-Acc: {0: '90.98%', 1: '99.42%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.109525, Val Acc: 97.46%, Val-Acc: {0: '86.97%', 1: '97.93%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_661.pth
# Epoch 544, Train Loss: 0.057139, Train-Acc: {0: '90.82%', 1: '99.34%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.112049, Val Acc: 97.46%, Val-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_544.pth
# Epoch 257, Train Loss: 0.056032, Train-Acc: {0: '90.51%', 1: '99.34%', 2: '100.00%', 3: '99.93%'},
# Val Loss: 0.107730, Val Acc: 97.46%, Val-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_257.pth
# Epoch 236, Train Loss: 0.054320, Train-Acc: {0: '90.28%', 1: '99.05%', 2: '100.00%', 3: '100.00%'},
# Val Loss: 0.110940, Val Acc: 97.46%, Val-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%', 3: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_236.pth
# ---
# ### Period 3
# + ##### Total training time: 729.13 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_3'*
# + ##### Best Epoch: 121
# #### __Val Accuracy: 97.56%__
# #### __Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%', 3: '100.00%'}__
#
# ✅ Period 3 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4
# + ##### Total training time: 893.29 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4'*
# + ##### Best Epoch: 555
# #### __Val Accuracy: 97.01%__
# #### __Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '98.51%', 5: '97.62%'}__

# %%
# ================================
# 📌 Period 4 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 4

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000
new_output_size = 2  # 新增兩個類別（拆分 WALKING 類）
output_size = len(set(y_train))  # 到目前為止總類別數（應為 5）

# === Step 1: 還原 Period 2 的基礎 MLP + Column 結構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, 2, dropout)  # output: 2
prev_column_2 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)  # output: 1
frozen_step1 = ProgressiveNeuralNetwork_fc2(base_model=base_model, new_column=prev_column_2)

# === Step 2: 再加上 Period 3 的 Column ===
prev_column_3 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)  # Period 3 新增類別
frozen_step2 = ProgressiveNeuralNetwork_fc2(base_model=frozen_step1, new_column=prev_column_3)

# === 載入 Period 3 模型的 state_dict（已經是 Step2 完整結構）===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_step2.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_step2.to(device)
frozen_step2.eval()
for param in frozen_step2.parameters():
    param.requires_grad = False

# === Step 3: 加上 Period 4 的 Column 並包成新模型 ===
new_column_4 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=new_output_size)
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_step2, new_column=new_column_4).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
del base_model, prev_column_2, prev_column_3, new_column_4, frozen_step1, frozen_step2, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5317 MiB
#     - Device Name    : NVIDIA RTX A6000
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): ProgressiveNeuralNetwork_fc2(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_2803466/2956673141.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 4.910972, Train-Class-Acc: {0: '81.96%', 1: '92.65%', 2: '99.92%', 3: '100.00%', 4: '1.21%', 5: '2.03%'}
# Val Loss: 2.820312, Val Acc: 65.05%, Val-Class-Acc: {0: '76.78%', 1: '94.92%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '0.48%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 1.320140, Train-Class-Acc: {0: '74.42%', 1: '86.83%', 2: '92.41%', 3: '99.86%', 4: '36.25%', 5: '43.20%'}
# Val Loss: 0.615264, Val Acc: 83.00%, Val-Class-Acc: {0: '79.84%', 1: '97.37%', 2: '98.79%', 3: '99.63%', 4: '53.29%', 5: '61.90%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.610914, Train-Class-Acc: {0: '85.07%', 1: '92.87%', 2: '85.48%', 3: '99.79%', 4: '68.22%', 5: '70.08%'}
# Val Loss: 0.426050, Val Acc: 88.60%, Val-Class-Acc: {0: '76.17%', 1: '99.06%', 2: '97.58%', 3: '100.00%', 4: '77.92%', 5: '76.67%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.424237, Train-Class-Acc: {0: '86.24%', 1: '95.78%', 2: '86.05%', 3: '99.72%', 4: '78.29%', 5: '80.63%'}
# Val Loss: 0.340841, Val Acc: 90.09%, Val-Class-Acc: {0: '82.28%', 1: '98.68%', 2: '99.40%', 3: '100.00%', 4: '81.95%', 5: '73.81%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.325318, Train-Class-Acc: {0: '88.57%', 1: '97.38%', 2: '88.09%', 3: '99.79%', 4: '83.32%', 5: '84.38%'}
# Val Loss: 0.249185, Val Acc: 93.55%, Val-Class-Acc: {0: '82.08%', 1: '98.68%', 2: '97.78%', 3: '100.00%', 4: '93.21%', 5: '87.62%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.260366, Train-Class-Acc: {0: '88.02%', 1: '97.67%', 2: '91.03%', 3: '99.64%', 4: '88.26%', 5: '87.02%'}
# Val Loss: 0.255268, Val Acc: 93.04%, Val-Class-Acc: {0: '86.56%', 1: '96.80%', 2: '98.59%', 3: '100.00%', 4: '90.23%', 5: '83.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.247092, Train-Class-Acc: {0: '89.19%', 1: '97.96%', 2: '90.86%', 3: '100.00%', 4: '86.86%', 5: '90.67%'}
# Val Loss: 0.227998, Val Acc: 94.33%, Val-Class-Acc: {0: '79.43%', 1: '99.06%', 2: '97.98%', 3: '100.00%', 4: '96.18%', 5: '92.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.203142, Train-Class-Acc: {0: '88.72%', 1: '98.33%', 2: '93.88%', 3: '99.79%', 4: '89.28%', 5: '90.97%'}
# Val Loss: 0.302101, Val Acc: 91.99%, Val-Class-Acc: {0: '77.19%', 1: '99.44%', 2: '99.40%', 3: '100.00%', 4: '90.87%', 5: '82.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.181963, Train-Class-Acc: {0: '89.97%', 1: '98.84%', 2: '93.88%', 3: '99.86%', 4: '91.99%', 5: '93.20%'}
# Val Loss: 0.181575, Val Acc: 95.18%, Val-Class-Acc: {0: '86.35%', 1: '97.56%', 2: '98.79%', 3: '100.00%', 4: '94.90%', 5: '92.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.177138, Train-Class-Acc: {0: '89.19%', 1: '98.33%', 2: '94.45%', 3: '99.86%', 4: '92.54%', 5: '93.00%'}
# Val Loss: 0.237632, Val Acc: 93.93%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '92.57%', 5: '90.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.172762, Train-Class-Acc: {0: '89.04%', 1: '98.84%', 2: '94.94%', 3: '99.93%', 4: '92.36%', 5: '93.10%'}
# Val Loss: 0.282898, Val Acc: 93.32%, Val-Class-Acc: {0: '74.75%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '94.48%', 5: '90.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.141421, Train-Class-Acc: {0: '90.20%', 1: '98.62%', 2: '95.92%', 3: '99.64%', 4: '94.32%', 5: '94.73%'}
# Val Loss: 0.219164, Val Acc: 94.47%, Val-Class-Acc: {0: '85.74%', 1: '98.50%', 2: '99.40%', 3: '100.00%', 4: '89.38%', 5: '92.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.147596, Train-Class-Acc: {0: '91.21%', 1: '98.76%', 2: '95.92%', 3: '99.86%', 4: '94.78%', 5: '93.91%'}
# Val Loss: 0.237229, Val Acc: 94.57%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.33%', 5: '94.52%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.133351, Train-Class-Acc: {0: '90.67%', 1: '99.05%', 2: '95.92%', 3: '99.86%', 4: '94.32%', 5: '95.13%'}
# Val Loss: 0.222682, Val Acc: 94.94%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.48%', 5: '95.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.116036, Train-Class-Acc: {0: '90.67%', 1: '98.98%', 2: '96.98%', 3: '99.79%', 4: '95.71%', 5: '95.13%'}
# Val Loss: 0.255430, Val Acc: 93.62%, Val-Class-Acc: {0: '72.91%', 1: '99.44%', 2: '98.39%', 3: '100.00%', 4: '94.06%', 5: '96.19%'}, LR: 0.000100
# Epoch 16/1000, Train Loss: 0.114053, Train-Class-Acc: {0: '90.36%', 1: '98.98%', 2: '97.47%', 3: '99.86%', 4: '96.83%', 5: '96.04%'}
# Val Loss: 0.267058, Val Acc: 93.69%, Val-Class-Acc: {0: '76.78%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '92.78%', 5: '92.62%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.110806, Train-Class-Acc: {0: '91.37%', 1: '99.42%', 2: '96.49%', 3: '100.00%', 4: '95.34%', 5: '96.15%'}
# Val Loss: 0.237255, Val Acc: 94.64%, Val-Class-Acc: {0: '77.39%', 1: '99.25%', 2: '98.39%', 3: '100.00%', 4: '98.09%', 5: '93.81%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.098460, Train-Class-Acc: {0: '91.52%', 1: '98.91%', 2: '97.31%', 3: '99.79%', 4: '97.39%', 5: '96.86%'}
# Val Loss: 0.189222, Val Acc: 95.39%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 2: '99.19%', 3: '100.00%', 4: '90.45%', 5: '97.38%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.104741, Train-Class-Acc: {0: '90.75%', 1: '99.20%', 2: '97.47%', 3: '99.86%', 4: '96.74%', 5: '96.86%'}
# Val Loss: 0.217770, Val Acc: 94.81%, Val-Class-Acc: {0: '83.91%', 1: '99.06%', 2: '99.60%', 3: '100.00%', 4: '95.97%', 5: '88.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.090980, Train-Class-Acc: {0: '90.82%', 1: '98.91%', 2: '97.96%', 3: '100.00%', 4: '97.58%', 5: '97.87%'}
# Val Loss: 0.191422, Val Acc: 95.45%, Val-Class-Acc: {0: '81.06%', 1: '99.06%', 2: '98.39%', 3: '100.00%', 4: '98.09%', 5: '95.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.105693, Train-Class-Acc: {0: '89.66%', 1: '98.84%', 2: '98.45%', 3: '100.00%', 4: '96.74%', 5: '97.87%'}
# Val Loss: 0.262798, Val Acc: 93.86%, Val-Class-Acc: {0: '78.62%', 1: '99.44%', 2: '99.60%', 3: '100.00%', 4: '91.72%', 5: '92.38%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.095372, Train-Class-Acc: {0: '90.59%', 1: '99.27%', 2: '97.80%', 3: '99.86%', 4: '97.48%', 5: '98.17%'}
# Val Loss: 0.233723, Val Acc: 94.77%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '96.82%', 5: '94.52%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.092199, Train-Class-Acc: {0: '90.44%', 1: '98.62%', 2: '98.29%', 3: '100.00%', 4: '97.67%', 5: '98.17%'}
# Val Loss: 0.241035, Val Acc: 94.64%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '91.30%', 5: '94.29%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.103003, Train-Class-Acc: {0: '90.82%', 1: '98.76%', 2: '98.04%', 3: '99.93%', 4: '97.86%', 5: '96.96%'}
# Val Loss: 0.200693, Val Acc: 95.18%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '98.39%', 3: '100.00%', 4: '97.03%', 5: '94.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.081821, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '98.78%', 3: '99.93%', 4: '98.04%', 5: '98.17%'}
# Val Loss: 0.215556, Val Acc: 95.22%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '95.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.099904, Train-Class-Acc: {0: '89.58%', 1: '99.20%', 2: '98.04%', 3: '99.79%', 4: '97.76%', 5: '97.46%'}
# Val Loss: 0.257219, Val Acc: 94.30%, Val-Class-Acc: {0: '77.60%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '93.21%', 5: '94.76%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.096477, Train-Class-Acc: {0: '90.36%', 1: '99.27%', 2: '98.45%', 3: '99.93%', 4: '98.60%', 5: '97.87%'}
# Val Loss: 0.244701, Val Acc: 94.64%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '93.21%', 5: '94.05%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.090467, Train-Class-Acc: {0: '90.12%', 1: '98.76%', 2: '98.04%', 3: '99.93%', 4: '97.76%', 5: '98.78%'}
# Val Loss: 0.206550, Val Acc: 95.15%, Val-Class-Acc: {0: '82.48%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '96.39%', 5: '92.38%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.077576, Train-Class-Acc: {0: '90.20%', 1: '99.05%', 2: '98.78%', 3: '99.86%', 4: '98.23%', 5: '98.88%'}
# Val Loss: 0.228743, Val Acc: 94.71%, Val-Class-Acc: {0: '78.21%', 1: '99.25%', 2: '98.39%', 3: '100.00%', 4: '97.03%', 5: '94.52%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.076441, Train-Class-Acc: {0: '90.51%', 1: '99.34%', 2: '98.86%', 3: '99.93%', 4: '98.14%', 5: '98.88%'}
# Val Loss: 0.215380, Val Acc: 94.98%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '96.82%', 5: '95.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.090551, Train-Class-Acc: {0: '89.04%', 1: '98.76%', 2: '98.37%', 3: '99.93%', 4: '97.67%', 5: '98.07%'}
# Val Loss: 0.193163, Val Acc: 95.62%, Val-Class-Acc: {0: '84.93%', 1: '98.12%', 2: '99.60%', 3: '100.00%', 4: '95.54%', 5: '94.76%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.083157, Train-Class-Acc: {0: '90.05%', 1: '98.76%', 2: '98.86%', 3: '99.86%', 4: '97.95%', 5: '98.58%'}
# Val Loss: 0.243980, Val Acc: 94.37%, Val-Class-Acc: {0: '75.76%', 1: '99.44%', 2: '98.59%', 3: '100.00%', 4: '97.03%', 5: '94.52%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.090569, Train-Class-Acc: {0: '90.51%', 1: '99.05%', 2: '98.29%', 3: '99.72%', 4: '98.32%', 5: '98.48%'}
# Val Loss: 0.352216, Val Acc: 92.40%, Val-Class-Acc: {0: '67.62%', 1: '99.62%', 2: '100.00%', 3: '100.00%', 4: '95.54%', 5: '90.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.072940, Train-Class-Acc: {0: '91.29%', 1: '99.27%', 2: '99.27%', 3: '100.00%', 4: '98.70%', 5: '98.58%'}
# Val Loss: 0.263830, Val Acc: 94.27%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.78%', 5: '93.10%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.068213, Train-Class-Acc: {0: '90.75%', 1: '98.84%', 2: '99.35%', 3: '99.93%', 4: '99.07%', 5: '98.68%'}
# Val Loss: 0.224697, Val Acc: 94.84%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '93.63%', 5: '95.48%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.081173, Train-Class-Acc: {0: '90.82%', 1: '98.91%', 2: '98.78%', 3: '100.00%', 4: '98.60%', 5: '99.09%'}
# Val Loss: 0.218765, Val Acc: 94.77%, Val-Class-Acc: {0: '77.39%', 1: '99.44%', 2: '98.79%', 3: '100.00%', 4: '96.60%', 5: '95.71%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.072026, Train-Class-Acc: {0: '90.98%', 1: '98.98%', 2: '99.43%', 3: '100.00%', 4: '98.60%', 5: '98.88%'}
# Val Loss: 0.210362, Val Acc: 95.18%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '98.09%', 5: '93.81%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.070994, Train-Class-Acc: {0: '92.15%', 1: '99.34%', 2: '99.02%', 3: '99.86%', 4: '98.70%', 5: '98.48%'}
# Val Loss: 0.281526, Val Acc: 93.93%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '88.96%', 5: '96.19%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.075024, Train-Class-Acc: {0: '90.90%', 1: '99.05%', 2: '98.94%', 3: '99.64%', 4: '98.42%', 5: '98.88%'}
# Val Loss: 0.264103, Val Acc: 93.82%, Val-Class-Acc: {0: '74.75%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '95.33%', 5: '93.10%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.076635, Train-Class-Acc: {0: '90.05%', 1: '99.27%', 2: '99.18%', 3: '99.86%', 4: '98.79%', 5: '99.39%'}
# Val Loss: 0.238015, Val Acc: 94.91%, Val-Class-Acc: {0: '83.71%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '92.14%', 5: '93.33%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.067467, Train-Class-Acc: {0: '91.37%', 1: '98.69%', 2: '99.10%', 3: '99.93%', 4: '98.88%', 5: '98.78%'}
# Val Loss: 0.169471, Val Acc: 95.96%, Val-Class-Acc: {0: '84.32%', 1: '98.87%', 2: '98.19%', 3: '100.00%', 4: '96.39%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_41.pth
# Epoch 42/1000, Train Loss: 0.064158, Train-Class-Acc: {0: '91.37%', 1: '99.13%', 2: '99.35%', 3: '99.93%', 4: '98.79%', 5: '98.78%'}
# Val Loss: 0.186001, Val Acc: 96.00%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.076976, Train-Class-Acc: {0: '90.75%', 1: '99.13%', 2: '99.02%', 3: '99.79%', 4: '98.70%', 5: '99.39%'}
# Val Loss: 0.237913, Val Acc: 94.81%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 2: '99.60%', 3: '100.00%', 4: '91.93%', 5: '92.38%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.075884, Train-Class-Acc: {0: '90.28%', 1: '99.27%', 2: '99.18%', 3: '99.86%', 4: '98.51%', 5: '98.78%'}
# Val Loss: 0.216066, Val Acc: 94.98%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '97.78%', 3: '100.00%', 4: '97.24%', 5: '93.33%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.077260, Train-Class-Acc: {0: '89.58%', 1: '99.13%', 2: '99.02%', 3: '99.86%', 4: '99.25%', 5: '98.88%'}
# Val Loss: 0.252872, Val Acc: 94.54%, Val-Class-Acc: {0: '76.78%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '95.54%', 5: '95.24%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.065991, Train-Class-Acc: {0: '90.51%', 1: '99.27%', 2: '99.35%', 3: '100.00%', 4: '99.07%', 5: '99.39%'}
# Val Loss: 0.206378, Val Acc: 95.49%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '95.54%', 5: '95.48%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.067055, Train-Class-Acc: {0: '91.14%', 1: '99.42%', 2: '99.51%', 3: '99.93%', 4: '99.25%', 5: '99.09%'}
# Val Loss: 0.216366, Val Acc: 95.01%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.75%', 5: '95.71%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.069778, Train-Class-Acc: {0: '91.21%', 1: '99.20%', 2: '99.43%', 3: '100.00%', 4: '99.25%', 5: '99.19%'}
# Val Loss: 0.193667, Val Acc: 95.69%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '99.40%', 3: '100.00%', 4: '95.75%', 5: '95.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.067039, Train-Class-Acc: {0: '90.98%', 1: '99.34%', 2: '99.27%', 3: '99.93%', 4: '99.53%', 5: '98.99%'}
# Val Loss: 0.240320, Val Acc: 94.84%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.57%', 5: '95.71%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.068556, Train-Class-Acc: {0: '91.60%', 1: '99.20%', 2: '99.10%', 3: '99.93%', 4: '98.79%', 5: '98.99%'}
# Val Loss: 0.275378, Val Acc: 93.82%, Val-Class-Acc: {0: '75.76%', 1: '99.44%', 2: '99.60%', 3: '100.00%', 4: '96.18%', 5: '90.48%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.063262, Train-Class-Acc: {0: '90.82%', 1: '99.56%', 2: '99.27%', 3: '99.93%', 4: '99.25%', 5: '99.39%'}
# Val Loss: 0.216656, Val Acc: 95.45%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '94.06%', 5: '99.05%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.072645, Train-Class-Acc: {0: '90.20%', 1: '99.42%', 2: '99.18%', 3: '100.00%', 4: '98.97%', 5: '99.19%'}
# Val Loss: 0.256448, Val Acc: 94.27%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '94.27%', 5: '92.14%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.066699, Train-Class-Acc: {0: '90.75%', 1: '99.49%', 2: '99.27%', 3: '100.00%', 4: '99.07%', 5: '99.19%'}
# Val Loss: 0.251454, Val Acc: 94.91%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '91.93%', 5: '93.81%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.074176, Train-Class-Acc: {0: '91.06%', 1: '98.91%', 2: '99.02%', 3: '100.00%', 4: '98.97%', 5: '98.78%'}
# Val Loss: 0.218192, Val Acc: 95.35%, Val-Class-Acc: {0: '79.02%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '96.82%', 5: '96.90%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.068872, Train-Class-Acc: {0: '91.14%', 1: '99.20%', 2: '99.43%', 3: '100.00%', 4: '99.44%', 5: '99.19%'}
# Val Loss: 0.237047, Val Acc: 94.91%, Val-Class-Acc: {0: '81.47%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '93.42%', 5: '94.29%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.060967, Train-Class-Acc: {0: '91.06%', 1: '99.49%', 2: '99.10%', 3: '99.93%', 4: '99.25%', 5: '99.39%'}
# Val Loss: 0.220453, Val Acc: 95.55%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '95.54%', 5: '95.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.058199, Train-Class-Acc: {0: '91.29%', 1: '98.69%', 2: '99.51%', 3: '99.93%', 4: '99.35%', 5: '99.39%'}
# Val Loss: 0.223559, Val Acc: 95.08%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.12%', 5: '93.57%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.074443, Train-Class-Acc: {0: '88.88%', 1: '99.42%', 2: '99.59%', 3: '100.00%', 4: '98.79%', 5: '98.99%'}
# Val Loss: 0.243183, Val Acc: 94.67%, Val-Class-Acc: {0: '76.17%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '95.33%', 5: '97.62%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.052980, Train-Class-Acc: {0: '91.45%', 1: '99.13%', 2: '99.84%', 3: '100.00%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.212330, Val Acc: 95.22%, Val-Class-Acc: {0: '78.82%', 1: '99.44%', 2: '98.99%', 3: '100.00%', 4: '96.18%', 5: '97.38%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.055537, Train-Class-Acc: {0: '91.14%', 1: '99.34%', 2: '99.59%', 3: '100.00%', 4: '99.53%', 5: '99.70%'}
# Val Loss: 0.182006, Val Acc: 95.76%, Val-Class-Acc: {0: '84.11%', 1: '99.06%', 2: '99.19%', 3: '100.00%', 4: '97.03%', 5: '94.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_60.pth
# Epoch 61/1000, Train Loss: 0.062149, Train-Class-Acc: {0: '90.20%', 1: '98.98%', 2: '99.59%', 3: '100.00%', 4: '99.25%', 5: '99.39%'}
# Val Loss: 0.189766, Val Acc: 95.79%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '94.90%', 5: '97.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.064699, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '99.44%', 5: '99.49%'}
# Val Loss: 0.256190, Val Acc: 94.47%, Val-Class-Acc: {0: '75.76%', 1: '99.62%', 2: '99.80%', 3: '100.00%', 4: '94.27%', 5: '96.67%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.065810, Train-Class-Acc: {0: '89.97%', 1: '99.64%', 2: '99.51%', 3: '100.00%', 4: '99.72%', 5: '99.80%'}
# Val Loss: 0.265896, Val Acc: 94.67%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.99%', 5: '96.19%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.058624, Train-Class-Acc: {0: '90.44%', 1: '99.34%', 2: '99.67%', 3: '99.93%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.191333, Val Acc: 95.59%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '98.30%', 5: '96.90%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.065855, Train-Class-Acc: {0: '90.51%', 1: '99.56%', 2: '99.51%', 3: '100.00%', 4: '99.44%', 5: '98.88%'}
# Val Loss: 0.251213, Val Acc: 94.40%, Val-Class-Acc: {0: '76.58%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '94.90%', 5: '94.76%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.066180, Train-Class-Acc: {0: '90.12%', 1: '99.42%', 2: '99.67%', 3: '99.86%', 4: '99.44%', 5: '99.59%'}
# Val Loss: 0.215241, Val Acc: 95.22%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '96.18%', 5: '92.62%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.067817, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '99.51%', 3: '100.00%', 4: '99.25%', 5: '99.19%'}
# Val Loss: 0.203634, Val Acc: 95.42%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '99.40%', 3: '100.00%', 4: '96.82%', 5: '93.57%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.059036, Train-Class-Acc: {0: '91.21%', 1: '99.13%', 2: '99.84%', 3: '100.00%', 4: '99.44%', 5: '99.49%'}
# Val Loss: 0.319409, Val Acc: 93.32%, Val-Class-Acc: {0: '68.84%', 1: '99.62%', 2: '97.98%', 3: '100.00%', 4: '96.60%', 5: '96.19%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.063175, Train-Class-Acc: {0: '91.52%', 1: '98.98%', 2: '99.27%', 3: '99.93%', 4: '99.16%', 5: '99.59%'}
# Val Loss: 0.264351, Val Acc: 94.06%, Val-Class-Acc: {0: '76.37%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.69%', 5: '93.81%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.069317, Train-Class-Acc: {0: '89.74%', 1: '98.69%', 2: '99.76%', 3: '99.93%', 4: '99.72%', 5: '99.90%'}
# Val Loss: 0.218377, Val Acc: 95.22%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '98.39%', 3: '100.00%', 4: '95.75%', 5: '96.67%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.055682, Train-Class-Acc: {0: '91.21%', 1: '99.49%', 2: '99.59%', 3: '99.93%', 4: '99.63%', 5: '99.49%'}
# Val Loss: 0.205005, Val Acc: 95.72%, Val-Class-Acc: {0: '82.69%', 1: '99.06%', 2: '98.59%', 3: '100.00%', 4: '96.39%', 5: '97.14%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_71.pth
# Epoch 72/1000, Train Loss: 0.068203, Train-Class-Acc: {0: '90.90%', 1: '99.42%', 2: '99.59%', 3: '99.86%', 4: '99.16%', 5: '99.49%'}
# Val Loss: 0.198273, Val Acc: 95.69%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '97.03%', 5: '95.95%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.057307, Train-Class-Acc: {0: '90.98%', 1: '99.49%', 2: '99.67%', 3: '100.00%', 4: '99.63%', 5: '99.59%'}
# Val Loss: 0.245425, Val Acc: 94.77%, Val-Class-Acc: {0: '76.17%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '97.45%', 5: '95.71%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.052534, Train-Class-Acc: {0: '91.76%', 1: '99.49%', 2: '99.43%', 3: '99.93%', 4: '99.53%', 5: '99.49%'}
# Val Loss: 0.219179, Val Acc: 95.01%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '97.66%', 5: '95.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.057698, Train-Class-Acc: {0: '91.06%', 1: '99.05%', 2: '99.67%', 3: '99.93%', 4: '99.44%', 5: '99.70%'}
# Val Loss: 0.221640, Val Acc: 95.59%, Val-Class-Acc: {0: '79.43%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '96.82%', 5: '98.33%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.061098, Train-Class-Acc: {0: '90.28%', 1: '98.98%', 2: '99.43%', 3: '100.00%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.282249, Val Acc: 93.93%, Val-Class-Acc: {0: '71.49%', 1: '99.62%', 2: '99.40%', 3: '100.00%', 4: '97.66%', 5: '94.52%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.065904, Train-Class-Acc: {0: '89.66%', 1: '99.27%', 2: '99.59%', 3: '99.86%', 4: '99.63%', 5: '99.29%'}
# Val Loss: 0.295100, Val Acc: 94.06%, Val-Class-Acc: {0: '70.88%', 1: '99.62%', 2: '98.79%', 3: '100.00%', 4: '97.03%', 5: '97.62%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.063849, Train-Class-Acc: {0: '90.44%', 1: '99.56%', 2: '99.51%', 3: '99.86%', 4: '99.72%', 5: '99.59%'}
# Val Loss: 0.217893, Val Acc: 95.28%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '97.66%', 5: '93.81%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.054538, Train-Class-Acc: {0: '90.36%', 1: '99.56%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.80%'}
# Val Loss: 0.182466, Val Acc: 96.20%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '97.66%', 5: '98.33%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_71.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_79.pth
# Epoch 80/1000, Train Loss: 0.055761, Train-Class-Acc: {0: '91.60%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '99.72%', 5: '99.59%'}
# Val Loss: 0.236131, Val Acc: 94.60%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '89.76%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.064647, Train-Class-Acc: {0: '90.36%', 1: '99.42%', 2: '99.67%', 3: '99.93%', 4: '99.63%', 5: '99.49%'}
# Val Loss: 0.186870, Val Acc: 95.96%, Val-Class-Acc: {0: '86.15%', 1: '98.12%', 2: '99.40%', 3: '100.00%', 4: '97.24%', 5: '94.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_60.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.053496, Train-Class-Acc: {0: '91.99%', 1: '99.13%', 2: '99.67%', 3: '99.86%', 4: '99.53%', 5: '99.39%'}
# Val Loss: 0.231302, Val Acc: 95.25%, Val-Class-Acc: {0: '81.67%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '92.36%', 5: '99.05%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.064064, Train-Class-Acc: {0: '90.05%', 1: '99.27%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.191386, Val Acc: 95.83%, Val-Class-Acc: {0: '85.54%', 1: '98.50%', 2: '97.78%', 3: '100.00%', 4: '97.45%', 5: '95.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.062631, Train-Class-Acc: {0: '90.51%', 1: '99.42%', 2: '99.67%', 3: '99.93%', 4: '99.44%', 5: '99.59%'}
# Val Loss: 0.217102, Val Acc: 95.39%, Val-Class-Acc: {0: '82.89%', 1: '99.06%', 2: '96.17%', 3: '100.00%', 4: '97.45%', 5: '96.19%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.071270, Train-Class-Acc: {0: '89.97%', 1: '99.13%', 2: '99.59%', 3: '99.86%', 4: '99.25%', 5: '99.59%'}
# Val Loss: 0.222493, Val Acc: 95.35%, Val-Class-Acc: {0: '80.86%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '94.48%', 5: '98.10%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.059151, Train-Class-Acc: {0: '90.51%', 1: '99.20%', 2: '99.84%', 3: '99.86%', 4: '99.72%', 5: '99.80%'}
# Val Loss: 0.211145, Val Acc: 95.39%, Val-Class-Acc: {0: '80.24%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '98.73%', 5: '93.81%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.060849, Train-Class-Acc: {0: '90.67%', 1: '99.42%', 2: '99.76%', 3: '99.93%', 4: '99.63%', 5: '99.59%'}
# Val Loss: 0.166953, Val Acc: 96.20%, Val-Class-Acc: {0: '86.15%', 1: '97.37%', 2: '99.19%', 3: '100.00%', 4: '96.18%', 5: '98.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_87.pth
# Epoch 88/1000, Train Loss: 0.058486, Train-Class-Acc: {0: '90.44%', 1: '99.20%', 2: '99.67%', 3: '100.00%', 4: '99.63%', 5: '99.80%'}
# Val Loss: 0.215595, Val Acc: 95.49%, Val-Class-Acc: {0: '79.02%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '97.45%', 5: '97.38%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.069105, Train-Class-Acc: {0: '90.12%', 1: '99.20%', 2: '99.76%', 3: '99.79%', 4: '99.91%', 5: '99.70%'}
# Val Loss: 0.254126, Val Acc: 94.44%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '97.45%', 5: '91.90%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.067364, Train-Class-Acc: {0: '90.59%', 1: '99.20%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.59%'}
# Val Loss: 0.213665, Val Acc: 95.45%, Val-Class-Acc: {0: '81.26%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '97.45%', 5: '95.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.059768, Train-Class-Acc: {0: '90.59%', 1: '98.98%', 2: '99.76%', 3: '99.86%', 4: '99.35%', 5: '99.59%'}
# Val Loss: 0.320959, Val Acc: 93.69%, Val-Class-Acc: {0: '74.54%', 1: '99.44%', 2: '99.80%', 3: '100.00%', 4: '92.78%', 5: '94.52%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.065555, Train-Class-Acc: {0: '90.28%', 1: '99.13%', 2: '99.67%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.282255, Val Acc: 93.86%, Val-Class-Acc: {0: '74.13%', 1: '99.44%', 2: '99.80%', 3: '100.00%', 4: '96.82%', 5: '91.67%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.067705, Train-Class-Acc: {0: '90.12%', 1: '98.76%', 2: '99.76%', 3: '100.00%', 4: '99.53%', 5: '99.59%'}
# Val Loss: 0.257645, Val Acc: 94.67%, Val-Class-Acc: {0: '77.19%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '96.60%', 5: '96.19%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.066219, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '99.76%', 3: '99.93%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.231354, Val Acc: 95.59%, Val-Class-Acc: {0: '82.28%', 1: '99.25%', 2: '96.98%', 3: '100.00%', 4: '96.39%', 5: '98.33%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.060551, Train-Class-Acc: {0: '90.82%', 1: '99.05%', 2: '99.59%', 3: '99.93%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.229736, Val Acc: 95.39%, Val-Class-Acc: {0: '82.08%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.90%', 5: '96.19%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.055475, Train-Class-Acc: {0: '91.37%', 1: '99.20%', 2: '99.76%', 3: '100.00%', 4: '99.35%', 5: '99.59%'}
# Val Loss: 0.256867, Val Acc: 94.71%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '96.82%', 5: '94.52%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.062365, Train-Class-Acc: {0: '91.37%', 1: '98.98%', 2: '99.51%', 3: '99.93%', 4: '99.35%', 5: '99.70%'}
# Val Loss: 0.268765, Val Acc: 94.20%, Val-Class-Acc: {0: '74.95%', 1: '99.62%', 2: '98.39%', 3: '100.00%', 4: '97.88%', 5: '93.33%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.057056, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '99.92%', 3: '99.93%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.183157, Val Acc: 95.93%, Val-Class-Acc: {0: '86.56%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '97.66%', 5: '93.33%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.056940, Train-Class-Acc: {0: '91.68%', 1: '99.27%', 2: '99.51%', 3: '100.00%', 4: '99.81%', 5: '99.80%'}
# Val Loss: 0.275716, Val Acc: 94.64%, Val-Class-Acc: {0: '74.13%', 1: '99.62%', 2: '99.80%', 3: '100.00%', 4: '95.97%', 5: '97.86%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.059147, Train-Class-Acc: {0: '91.45%', 1: '99.20%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.264245, Val Acc: 94.64%, Val-Class-Acc: {0: '76.37%', 1: '99.62%', 2: '99.19%', 3: '100.00%', 4: '97.03%', 5: '94.76%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.059657, Train-Class-Acc: {0: '90.82%', 1: '98.84%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.243557, Val Acc: 94.88%, Val-Class-Acc: {0: '75.15%', 1: '99.62%', 2: '97.98%', 3: '100.00%', 4: '98.09%', 5: '98.10%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.048304, Train-Class-Acc: {0: '91.29%', 1: '99.64%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.279141, Val Acc: 94.44%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.97%', 5: '91.90%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.066525, Train-Class-Acc: {0: '90.12%', 1: '99.34%', 2: '99.67%', 3: '100.00%', 4: '99.53%', 5: '99.39%'}
# Val Loss: 0.214681, Val Acc: 95.45%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '96.39%', 5: '94.52%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.060227, Train-Class-Acc: {0: '90.51%', 1: '99.13%', 2: '99.76%', 3: '99.93%', 4: '99.72%', 5: '99.90%'}
# Val Loss: 0.189442, Val Acc: 95.96%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '97.45%', 5: '96.43%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.055098, Train-Class-Acc: {0: '91.52%', 1: '99.05%', 2: '99.84%', 3: '100.00%', 4: '99.72%', 5: '99.80%'}
# Val Loss: 0.186651, Val Acc: 96.20%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '98.59%', 3: '100.00%', 4: '97.88%', 5: '98.57%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_41.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_105.pth
# Epoch 106/1000, Train Loss: 0.058998, Train-Class-Acc: {0: '91.06%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.191093, Val Acc: 96.10%, Val-Class-Acc: {0: '86.76%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '96.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_106.pth
# Epoch 107/1000, Train Loss: 0.062884, Train-Class-Acc: {0: '89.35%', 1: '99.05%', 2: '99.76%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.242528, Val Acc: 95.55%, Val-Class-Acc: {0: '83.10%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '94.48%', 5: '95.95%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.065827, Train-Class-Acc: {0: '90.20%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '99.70%'}
# Val Loss: 0.243777, Val Acc: 95.18%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '97.38%', 3: '100.00%', 4: '98.09%', 5: '95.48%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.064575, Train-Class-Acc: {0: '90.28%', 1: '98.84%', 2: '99.59%', 3: '99.93%', 4: '99.44%', 5: '99.49%'}
# Val Loss: 0.216734, Val Acc: 95.49%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '98.79%', 3: '100.00%', 4: '96.39%', 5: '94.52%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.054873, Train-Class-Acc: {0: '90.98%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.265294, Val Acc: 94.84%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '94.06%', 5: '97.38%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.057354, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '99.44%', 5: '99.70%'}
# Val Loss: 0.236839, Val Acc: 95.45%, Val-Class-Acc: {0: '81.87%', 1: '99.25%', 2: '96.77%', 3: '100.00%', 4: '96.60%', 5: '97.86%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.050254, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '99.92%', 3: '99.93%', 4: '99.91%', 5: '99.70%'}
# Val Loss: 0.247420, Val Acc: 94.88%, Val-Class-Acc: {0: '76.17%', 1: '99.44%', 2: '97.58%', 3: '100.00%', 4: '97.66%', 5: '98.10%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.060520, Train-Class-Acc: {0: '90.12%', 1: '99.34%', 2: '99.76%', 3: '100.00%', 4: '99.63%', 5: '99.59%'}
# Val Loss: 0.199918, Val Acc: 95.69%, Val-Class-Acc: {0: '84.32%', 1: '98.87%', 2: '97.78%', 3: '100.00%', 4: '95.54%', 5: '97.14%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.052273, Train-Class-Acc: {0: '91.45%', 1: '99.56%', 2: '99.76%', 3: '100.00%', 4: '99.53%', 5: '99.90%'}
# Val Loss: 0.218077, Val Acc: 95.69%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '99.80%', 3: '100.00%', 4: '93.42%', 5: '96.67%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.053151, Train-Class-Acc: {0: '90.20%', 1: '99.05%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.59%'}
# Val Loss: 0.209024, Val Acc: 96.06%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '98.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_115.pth
# Epoch 116/1000, Train Loss: 0.063037, Train-Class-Acc: {0: '90.36%', 1: '99.20%', 2: '99.84%', 3: '100.00%', 4: '99.53%', 5: '99.49%'}
# Val Loss: 0.259134, Val Acc: 95.22%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '100.00%', 3: '100.00%', 4: '92.14%', 5: '95.71%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.059185, Train-Class-Acc: {0: '90.59%', 1: '99.42%', 2: '99.76%', 3: '99.93%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.242871, Val Acc: 94.91%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '97.45%', 5: '94.29%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.060453, Train-Class-Acc: {0: '90.59%', 1: '99.49%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.194034, Val Acc: 96.00%, Val-Class-Acc: {0: '83.91%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '97.45%', 5: '95.24%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.057478, Train-Class-Acc: {0: '91.29%', 1: '98.98%', 2: '99.92%', 3: '100.00%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.224963, Val Acc: 95.55%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '97.03%', 5: '97.86%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.067026, Train-Class-Acc: {0: '90.59%', 1: '99.20%', 2: '99.67%', 3: '99.93%', 4: '99.72%', 5: '99.49%'}
# Val Loss: 0.198867, Val Acc: 96.00%, Val-Class-Acc: {0: '83.30%', 1: '99.06%', 2: '97.78%', 3: '100.00%', 4: '97.24%', 5: '98.33%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.052524, Train-Class-Acc: {0: '91.68%', 1: '99.27%', 2: '99.59%', 3: '100.00%', 4: '99.53%', 5: '99.70%'}
# Val Loss: 0.206118, Val Acc: 95.89%, Val-Class-Acc: {0: '86.15%', 1: '97.74%', 2: '99.40%', 3: '100.00%', 4: '94.48%', 5: '97.14%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.061708, Train-Class-Acc: {0: '90.75%', 1: '99.42%', 2: '99.67%', 3: '99.86%', 4: '99.63%', 5: '99.80%'}
# Val Loss: 0.201501, Val Acc: 95.96%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '97.03%', 5: '98.57%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.060019, Train-Class-Acc: {0: '90.98%', 1: '99.20%', 2: '99.92%', 3: '99.86%', 4: '99.63%', 5: '99.90%'}
# Val Loss: 0.209749, Val Acc: 95.66%, Val-Class-Acc: {0: '80.65%', 1: '99.25%', 2: '99.19%', 3: '100.00%', 4: '97.03%', 5: '97.38%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.078791, Train-Class-Acc: {0: '89.89%', 1: '99.27%', 2: '99.59%', 3: '100.00%', 4: '99.53%', 5: '99.09%'}
# Val Loss: 0.279953, Val Acc: 95.28%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '92.99%', 5: '98.81%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.056783, Train-Class-Acc: {0: '91.29%', 1: '99.64%', 2: '99.67%', 3: '100.00%', 4: '99.35%', 5: '99.59%'}
# Val Loss: 0.254584, Val Acc: 95.05%, Val-Class-Acc: {0: '78.00%', 1: '99.25%', 2: '99.40%', 3: '100.00%', 4: '96.60%', 5: '96.43%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.056266, Train-Class-Acc: {0: '91.68%', 1: '98.91%', 2: '99.51%', 3: '99.93%', 4: '99.81%', 5: '99.90%'}
# Val Loss: 0.233190, Val Acc: 95.45%, Val-Class-Acc: {0: '84.32%', 1: '99.06%', 2: '99.60%', 3: '100.00%', 4: '95.12%', 5: '93.57%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.053398, Train-Class-Acc: {0: '90.67%', 1: '98.91%', 2: '100.00%', 3: '100.00%', 4: '99.81%', 5: '99.80%'}
# Val Loss: 0.234702, Val Acc: 95.25%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '97.45%', 5: '95.48%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.057797, Train-Class-Acc: {0: '90.51%', 1: '99.34%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.70%'}
# Val Loss: 0.256003, Val Acc: 94.91%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '96.17%', 3: '100.00%', 4: '95.97%', 5: '97.62%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.068322, Train-Class-Acc: {0: '90.05%', 1: '99.13%', 2: '99.51%', 3: '100.00%', 4: '99.53%', 5: '99.80%'}
# Val Loss: 0.286316, Val Acc: 94.84%, Val-Class-Acc: {0: '80.04%', 1: '99.25%', 2: '98.79%', 3: '100.00%', 4: '94.06%', 5: '96.19%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.065588, Train-Class-Acc: {0: '90.44%', 1: '99.05%', 2: '99.51%', 3: '99.93%', 4: '99.44%', 5: '99.59%'}
# Val Loss: 0.235917, Val Acc: 95.72%, Val-Class-Acc: {0: '83.71%', 1: '98.68%', 2: '98.99%', 3: '100.00%', 4: '94.06%', 5: '98.57%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.047670, Train-Class-Acc: {0: '92.15%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.63%', 5: '99.70%'}
# Val Loss: 0.233301, Val Acc: 95.35%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '95.54%', 5: '97.62%'}, LR: 0.000100
# ...
# Val Loss: 0.270019, Val Acc: 95.01%, Val-Class-Acc: {0: '77.80%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '96.82%', 5: '95.71%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.057538, Train-Class-Acc: {0: '90.44%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '99.80%'}
# Val Loss: 0.324919, Val Acc: 94.71%, Val-Class-Acc: {0: '78.82%', 1: '99.25%', 2: '100.00%', 3: '100.00%', 4: '91.08%', 5: '98.57%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.053978, Train-Class-Acc: {0: '89.74%', 1: '99.71%', 2: '99.92%', 3: '100.00%', 4: '99.72%', 5: '100.00%'}
# Val Loss: 0.382704, Val Acc: 93.59%, Val-Class-Acc: {0: '73.93%', 1: '99.62%', 2: '99.60%', 3: '100.00%', 4: '94.48%', 5: '92.62%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.051619, Train-Class-Acc: {0: '90.98%', 1: '99.56%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.264919, Val Acc: 95.49%, Val-Class-Acc: {0: '82.48%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '94.48%', 5: '96.43%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.057403, Train-Class-Acc: {0: '90.75%', 1: '99.05%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.264342, Val Acc: 95.55%, Val-Class-Acc: {0: '86.56%', 1: '97.56%', 2: '95.97%', 3: '100.00%', 4: '96.60%', 5: '96.19%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.056793, Train-Class-Acc: {0: '90.28%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.305366, Val Acc: 94.98%, Val-Class-Acc: {0: '80.45%', 1: '99.25%', 2: '96.57%', 3: '100.00%', 4: '95.75%', 5: '97.38%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.054901, Train-Class-Acc: {0: '91.14%', 1: '99.42%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.362175, Val Acc: 94.44%, Val-Class-Acc: {0: '77.80%', 1: '99.44%', 2: '95.97%', 3: '100.00%', 4: '96.39%', 5: '96.43%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.056518, Train-Class-Acc: {0: '89.74%', 1: '99.64%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.334062, Val Acc: 94.84%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '95.77%', 3: '100.00%', 4: '96.18%', 5: '97.14%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.057716, Train-Class-Acc: {0: '90.44%', 1: '98.84%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.326841, Val Acc: 94.20%, Val-Class-Acc: {0: '75.76%', 1: '99.62%', 2: '96.98%', 3: '100.00%', 4: '95.75%', 5: '96.43%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.056801, Train-Class-Acc: {0: '90.82%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.361899, Val Acc: 94.13%, Val-Class-Acc: {0: '74.75%', 1: '99.62%', 2: '96.77%', 3: '100.00%', 4: '96.18%', 5: '96.90%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.047526, Train-Class-Acc: {0: '91.14%', 1: '99.71%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.314933, Val Acc: 94.98%, Val-Class-Acc: {0: '81.06%', 1: '99.25%', 2: '97.18%', 3: '100.00%', 4: '95.33%', 5: '96.43%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.055462, Train-Class-Acc: {0: '90.28%', 1: '99.34%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.235326, Val Acc: 95.49%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '99.80%', 3: '100.00%', 4: '95.33%', 5: '95.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.055017, Train-Class-Acc: {0: '91.37%', 1: '98.84%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.70%'}
# Val Loss: 0.249695, Val Acc: 95.93%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '99.80%', 3: '100.00%', 4: '93.42%', 5: '97.86%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.049814, Train-Class-Acc: {0: '91.14%', 1: '99.20%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.228013, Val Acc: 95.45%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '99.60%', 3: '100.00%', 4: '95.33%', 5: '97.86%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.054584, Train-Class-Acc: {0: '90.12%', 1: '99.05%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.311509, Val Acc: 93.99%, Val-Class-Acc: {0: '74.13%', 1: '99.62%', 2: '99.40%', 3: '100.00%', 4: '95.75%', 5: '94.05%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.048761, Train-Class-Acc: {0: '91.14%', 1: '99.20%', 2: '99.92%', 3: '99.93%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.488450, Val Acc: 93.96%, Val-Class-Acc: {0: '81.87%', 1: '99.44%', 2: '100.00%', 3: '100.00%', 4: '87.26%', 5: '93.81%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.053935, Train-Class-Acc: {0: '90.59%', 1: '99.27%', 2: '99.84%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.347304, Val Acc: 93.82%, Val-Class-Acc: {0: '74.34%', 1: '99.44%', 2: '99.19%', 3: '100.00%', 4: '95.75%', 5: '93.10%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.055285, Train-Class-Acc: {0: '91.21%', 1: '99.20%', 2: '99.84%', 3: '100.00%', 4: '99.72%', 5: '100.00%'}
# Val Loss: 0.262257, Val Acc: 95.25%, Val-Class-Acc: {0: '84.93%', 1: '97.93%', 2: '98.39%', 3: '100.00%', 4: '95.97%', 5: '93.33%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.050338, Train-Class-Acc: {0: '91.99%', 1: '99.34%', 2: '100.00%', 3: '99.93%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.313501, Val Acc: 94.37%, Val-Class-Acc: {0: '78.62%', 1: '99.25%', 2: '98.19%', 3: '100.00%', 4: '95.97%', 5: '93.10%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.056236, Train-Class-Acc: {0: '89.58%', 1: '98.98%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.294066, Val Acc: 94.60%, Val-Class-Acc: {0: '76.37%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '95.12%', 5: '97.38%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.052174, Train-Class-Acc: {0: '90.67%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '99.72%', 5: '99.70%'}
# Val Loss: 0.244293, Val Acc: 95.76%, Val-Class-Acc: {0: '82.48%', 1: '99.06%', 2: '98.39%', 3: '100.00%', 4: '96.18%', 5: '98.10%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.059582, Train-Class-Acc: {0: '89.04%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.254007, Val Acc: 95.86%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '98.99%', 3: '100.00%', 4: '95.97%', 5: '97.86%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.050857, Train-Class-Acc: {0: '91.68%', 1: '99.42%', 2: '99.92%', 3: '100.00%', 4: '99.81%', 5: '100.00%'}
# Val Loss: 0.286357, Val Acc: 94.20%, Val-Class-Acc: {0: '73.32%', 1: '99.62%', 2: '99.40%', 3: '100.00%', 4: '96.82%', 5: '95.24%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.056845, Train-Class-Acc: {0: '89.81%', 1: '99.13%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.215592, Val Acc: 95.52%, Val-Class-Acc: {0: '85.74%', 1: '97.56%', 2: '99.60%', 3: '100.00%', 4: '97.03%', 5: '92.14%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.056776, Train-Class-Acc: {0: '90.28%', 1: '99.42%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.298752, Val Acc: 94.84%, Val-Class-Acc: {0: '79.63%', 1: '99.25%', 2: '97.18%', 3: '100.00%', 4: '96.18%', 5: '96.19%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.053297, Train-Class-Acc: {0: '92.30%', 1: '98.98%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '99.90%'}
# Val Loss: 0.302983, Val Acc: 95.01%, Val-Class-Acc: {0: '79.23%', 1: '99.25%', 2: '97.18%', 3: '100.00%', 4: '96.18%', 5: '97.86%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.057482, Train-Class-Acc: {0: '90.67%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.273155, Val Acc: 95.59%, Val-Class-Acc: {0: '83.50%', 1: '99.25%', 2: '97.18%', 3: '100.00%', 4: '96.18%', 5: '96.90%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.054105, Train-Class-Acc: {0: '90.67%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.263974, Val Acc: 95.69%, Val-Class-Acc: {0: '84.52%', 1: '98.87%', 2: '97.18%', 3: '100.00%', 4: '96.18%', 5: '96.90%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.052750, Train-Class-Acc: {0: '91.06%', 1: '99.56%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.245447, Val Acc: 95.89%, Val-Class-Acc: {0: '85.34%', 1: '98.87%', 2: '97.58%', 3: '100.00%', 4: '96.18%', 5: '96.90%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.048742, Train-Class-Acc: {0: '91.91%', 1: '99.34%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.248203, Val Acc: 95.83%, Val-Class-Acc: {0: '84.32%', 1: '98.68%', 2: '97.18%', 3: '100.00%', 4: '97.24%', 5: '97.14%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.059762, Train-Class-Acc: {0: '89.19%', 1: '99.56%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.223369, Val Acc: 96.13%, Val-Class-Acc: {0: '84.32%', 1: '98.50%', 2: '97.58%', 3: '100.00%', 4: '97.24%', 5: '99.05%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.049791, Train-Class-Acc: {0: '91.68%', 1: '99.34%', 2: '99.92%', 3: '100.00%', 4: '99.91%', 5: '99.90%'}
# Val Loss: 0.235011, Val Acc: 95.83%, Val-Class-Acc: {0: '82.69%', 1: '99.25%', 2: '98.59%', 3: '100.00%', 4: '96.39%', 5: '97.62%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.055500, Train-Class-Acc: {0: '91.21%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '99.91%', 5: '100.00%'}
# Val Loss: 0.244400, Val Acc: 95.28%, Val-Class-Acc: {0: '83.50%', 1: '99.06%', 2: '98.59%', 3: '100.00%', 4: '97.45%', 5: '91.90%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.053620, Train-Class-Acc: {0: '90.75%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.309944, Val Acc: 94.33%, Val-Class-Acc: {0: '75.56%', 1: '99.44%', 2: '96.98%', 3: '100.00%', 4: '96.60%', 5: '96.90%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.065968, Train-Class-Acc: {0: '88.88%', 1: '99.42%', 2: '99.84%', 3: '100.00%', 4: '99.81%', 5: '100.00%'}
# Val Loss: 0.248893, Val Acc: 95.42%, Val-Class-Acc: {0: '84.11%', 1: '98.87%', 2: '98.39%', 3: '100.00%', 4: '96.18%', 5: '94.05%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.054272, Train-Class-Acc: {0: '90.98%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.245208, Val Acc: 95.32%, Val-Class-Acc: {0: '82.08%', 1: '98.68%', 2: '98.19%', 3: '100.00%', 4: '96.18%', 5: '96.19%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.058338, Train-Class-Acc: {0: '89.89%', 1: '99.20%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.317615, Val Acc: 93.76%, Val-Class-Acc: {0: '74.34%', 1: '99.44%', 2: '97.98%', 3: '100.00%', 4: '96.60%', 5: '93.10%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.059049, Train-Class-Acc: {0: '90.59%', 1: '98.69%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'}
# Val Loss: 0.238240, Val Acc: 95.62%, Val-Class-Acc: {0: '84.52%', 1: '99.06%', 2: '97.58%', 3: '100.00%', 4: '97.03%', 5: '94.76%'}, LR: 0.000100
#
# ⏳ Total training time: 893.29 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_best.pth (Val Accuracy: 97.01%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 555, Train Loss: 0.049187, Train-Acc: {0: '90.90%', 1: '99.71%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.151406, Val Acc: 97.01%, Val-Acc: {0: '88.59%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '98.51%', 5: '97.62%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_555.pth
# Epoch 714, Train Loss: 0.051938, Train-Acc: {0: '90.20%', 1: '99.13%', 2: '99.92%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.149842, Val Acc: 96.88%, Val-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%', 3: '100.00%', 4: '97.24%', 5: '99.76%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_714.pth
# Epoch 707, Train Loss: 0.056342, Train-Acc: {0: '89.81%', 1: '99.42%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '100.00%'},
# Val Loss: 0.143541, Val Acc: 96.88%, Val-Acc: {0: '89.00%', 1: '96.99%', 2: '98.99%', 3: '100.00%', 4: '98.51%', 5: '97.62%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_707.pth
# Epoch 716, Train Loss: 0.050815, Train-Acc: {0: '91.45%', 1: '99.27%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.150564, Val Acc: 96.84%, Val-Acc: {0: '86.15%', 1: '98.12%', 2: '99.19%', 3: '100.00%', 4: '98.94%', 5: '98.57%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_716.pth
# Epoch 521, Train Loss: 0.050859, Train-Acc: {0: '91.06%', 1: '99.05%', 2: '100.00%', 3: '100.00%', 4: '100.00%', 5: '99.90%'},
# Val Loss: 0.183098, Val Acc: 96.74%, Val-Acc: {0: '86.76%', 1: '98.12%', 2: '98.99%', 3: '100.00%', 4: '97.24%', 5: '99.29%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_521.pth
# ---
# ### Period 4
# + ##### Total training time: 893.29 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/PNN_CIL_v2/PNN_FC2_Period_4'*
# + ##### Best Epoch: 555
# #### __Val Accuracy: 97.01%__
# #### __Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '99.80%', 3: '100.00%', 4: '98.51%', 5: '97.62%'}__
#
# ✅ Period 4 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): ProgressiveNeuralNetwork_fc2(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ##  __Compute FWT & Model Size__

# %% [markdown]
# ### Period 1

# %%
# ================================
# 📌 Period 1 Configuration - HAR_MLP_v2 (PNN Baseline)
# ================================
period = 1

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1

# ==== Saving Path ====
model_name = "HAR_MLP_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "TT",
    "PNN_CIL_v2", f"Baseline_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# ==== Model (Baseline HAR MLP for PNN) ====
model = HAR_MLP_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout
).to(device)

# ==== Optimizer / Criterion / Scheduler ====
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

print_model_info(model)

# ==== Training ====
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 391 MiB
#     - Device Name    : NVIDIA RTX A6000
# - Total Parameters: 89218
# - Model Size (float32): 0.34 MB
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
# Epoch 1/1, Train Loss: 0.738479, Train-Class-Acc: {0: '63.69%', 1: '53.35%'}
# Val Loss: 0.533027, Val Acc: 72.92%, Val-Class-Acc: {0: '46.44%', 1: '97.37%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_1.pth
#
# ⏳ Total training time: 0.47 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_best.pth (Val Accuracy: 72.92%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.738479, Train-Acc: {0: '63.69%', 1: '53.35%'},
# Val Loss: 0.533027, Val Acc: 72.92%, Val-Acc: {0: '46.44%', 1: '97.37%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1/HAR_MLP_PNN_v2_epoch_1.pth
# ---
# ### Period 1
# + ##### Total training time: 0.47 seconds
# + ##### Model: HAR_MLP_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/Baseline_1'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 72.92%__
# #### __Val-Class-Acc: {0: '46.44%', 1: '97.37%'}__
#
# ✅ Period 1 Training Complete. Final model architecture:
# HAR_MLP_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ### Period 2

# %%
# ================================
# 📌 FWT - Period 2 (HAR PNN LoRA)
# ================================
period = 2

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
output_size_prev = 2  # Period 1 類別：SITTING (0), STANDING (1)
dropout = 0.2
device = auto_select_cuda_device()

# === 載入 Period 1 模型作為 frozen base ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", "Baseline_1", "HAR_MLP_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)

previous_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
previous_model.load_state_dict(checkpoint["model_state_dict"])
previous_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init Model（相同結構，但未訓練）===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === 準備資料 ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1]  # Period 1 穩定類別：SITTING, STANDING

# === ✅ 計算 FWT ===
fwt, acc_prev, acc_init = compute_fwt_har(previous_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 2:")
print(f"- FWT (PNN HAR Period 2, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5118 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_1853981/1064505577.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# 📋 Total samples for known classes [0, 1]: 1023
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 1023
# - Correct (PrevModel): 951 / 1023 → Acc = 0.9296
# - Correct (InitModel): 465 / 1023 → Acc = 0.4545
# - FWT = Acc_prev - Acc_init = 0.4751
#
# ### Period 2:
# - FWT (PNN HAR Period 2, old classes [0, 1]): 47.51%
# - Accuracy by previous model: 92.96%
# - Accuracy by init model:     45.45%
# /tmp/ipykernel_1853981/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1853981/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)

# %%
# ================================
# 📌 Period 2 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 2

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
new_output_size = 1  # 新增 1 個類別
output_size = len(set(y_train))  # 到目前為止所有類別數

# === Load frozen Period 1 model ===
frozen_model = HAR_MLP_v2(input_size, hidden_size, output_size - new_output_size, dropout)
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"Baseline_{period-1}", "HAR_MLP_PNN_v2_best.pth"
)
frozen_checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(frozen_checkpoint['model_state_dict'])
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create new PNN column ===
new_column = HAR_PNN_Column_fc2(input_size=input_size, hidden_size=hidden_size, new_output_size=new_output_size)

# === Wrap into ProgressiveNeuralNetwork ===
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_model, new_column=new_column).to(device)

# === Define optimizer, loss, etc. ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "TT",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)


print_model_info(model)

# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, frozen_model, new_column, frozen_checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 0
#     - Memory Used    : 651 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_781994/3163962344.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   frozen_checkpoint = torch.load(prev_model_path, map_location=device)
# - Total Parameters: 194819
# - Model Size (float32): 0.74 MB
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
# Epoch 1/1, Train Loss: 0.497424, Train-Class-Acc: {0: '89.74%', 1: '97.67%', 2: '78.48%'}
# Val Loss: 0.191339, Val Acc: 95.81%, Val-Class-Acc: {0: '81.67%', 1: '98.31%', 2: '99.86%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_1.pth
#
# ⏳ Total training time: 0.84 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_best.pth (Val Accuracy: 95.81%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.497424, Train-Acc: {0: '89.74%', 1: '97.67%', 2: '78.48%'},
# Val Loss: 0.191339, Val Acc: 95.81%, Val-Acc: {0: '81.67%', 1: '98.31%', 2: '99.86%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2/HAR_PNN_v2_epoch_1.pth
# ---
# ### Period 2
# + ##### Total training time: 0.84 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_2'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 95.81%__
# #### __Val-Class-Acc: {0: '81.67%', 1: '98.31%', 2: '99.86%'}__
#
# ✅ Period 2 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): HAR_MLP_v2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ### Period 3

# %%
# ================================
# 📌 FWT - Period 3 (HAR PNN)
# ================================
period = 3

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
dropout = 0.2
device = auto_select_cuda_device()
output_size_prev = 3  # Period 2: SITTING, STANDING, WALKING → label 0,1,2

# === 還原 Period 2 架構並載入模型 ===
base_model = HAR_MLP_v2(input_size, hidden_size, 2, dropout)
prev_column = HAR_PNN_Column_fc2(input_size, hidden_size, 1)
prev_model = ProgressiveNeuralNetwork_fc2(base_model, prev_column).to(device)

prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", "PNN_FC2_Period_2", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
prev_model.load_state_dict(checkpoint["model_state_dict"])
prev_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init model ===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === 資料與 FWT ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1, 2]  # SITTING, STANDING, WALKING

fwt, acc_prev, acc_init = compute_fwt_har(prev_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 3:")
print(f"- FWT (PNN HAR Period 3, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5120 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_1853981/3353869866.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# /tmp/ipykernel_1853981/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1853981/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)
# 📋 Total samples for known classes [0, 1, 2]: 2410
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 2410
# - Correct (PrevModel): 2318 / 2410 → Acc = 0.9618
# - Correct (InitModel): 582 / 2410 → Acc = 0.2415
# - FWT = Acc_prev - Acc_init = 0.7203
#
# ### Period 3:
# - FWT (PNN HAR Period 3, old classes [0, 1, 2]): 72.03%
# - Accuracy by previous model: 96.18%
# - Accuracy by init model:     24.15%

# %%
# ================================
# 📌 Period 3 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 3

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
new_output_size = 1  # 新增一個類別
output_size = len(set(y_train))  # 目前總類別數（含舊+新）

# === 還原 Period 2 架構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, output_size - 2, dropout)
prev_column = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)

frozen_model = ProgressiveNeuralNetwork_fc2(base_model=base_model, new_column=prev_column)

# === 載入 Period 2 的 model state_dict ===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_model.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_model.to(device)
frozen_model.eval()
for param in frozen_model.parameters():
    param.requires_grad = False

# === Create Period 3 New Column ===
new_column = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=new_output_size)

# === Combine into new PNN wrapper ===
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_model, new_column=new_column).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "TT",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

print_model_info(model)
# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, base_model, prev_column, new_column, frozen_model, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 763 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_781994/4016017670.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# - Total Parameters: 300420
# - Model Size (float32): 1.15 MB
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# Epoch 1/1, Train Loss: 0.236484, Train-Class-Acc: {0: '84.68%', 1: '97.67%', 2: '100.00%', 3: '75.41%'}
# Val Loss: 0.248172, Val Acc: 94.84%, Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '90.50%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_1.pth
#
# ⏳ Total training time: 0.75 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_best.pth (Val Accuracy: 94.84%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 0.236484, Train-Acc: {0: '84.68%', 1: '97.67%', 2: '100.00%', 3: '75.41%'},
# Val Loss: 0.248172, Val Acc: 94.84%, Val-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '90.50%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3/HAR_PNN_v2_epoch_1.pth
# ---
# ### Period 3
# + ##### Total training time: 0.75 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_3'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 94.84%__
# #### __Val-Class-Acc: {0: '80.24%', 1: '99.25%', 2: '100.00%', 3: '90.50%'}__
#
# ✅ Period 3 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): HAR_MLP_v2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=2, bias=True)
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=1, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ### Period 4

# %%
# ================================
# 📌 FWT - Period 4 (HAR PNN)
# ================================
period = 4

X_val = period_datasets[period]["test"][0]
y_val = period_datasets[period]["test"][1]

input_size = X_val.shape[1]
hidden_size = 128
dropout = 0.2
device = auto_select_cuda_device()
output_size_prev = 4  # Period 3: {0,1,2,3} = SITTING, STANDING, WALKING, LAYING

# === 重建 Period 3 架構並載入 ===
base_model = HAR_MLP_v2(input_size, hidden_size, 2, dropout)
prev_column_2 = HAR_PNN_Column_fc2(input_size, hidden_size, 1)
frozen_step1 = ProgressiveNeuralNetwork_fc2(base_model, prev_column_2)

prev_column_3 = HAR_PNN_Column_fc2(input_size, hidden_size, 1)
prev_model = ProgressiveNeuralNetwork_fc2(frozen_step1, prev_column_3).to(device)

prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", "PNN_FC2_Period_3", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
prev_model.load_state_dict(checkpoint["model_state_dict"])
prev_model.output_size = output_size_prev
del checkpoint
gc.collect()

# === Init model ===
init_model = HAR_MLP_v2(input_size, hidden_size, output_size_prev, dropout).to(device)
init_model.output_size = output_size_prev

# === 資料與 FWT ===
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)
known_classes = [0, 1, 3]  # Period 4 穩定類別（排除 WALKING 類拆分後不穩定語意）

fwt, acc_prev, acc_init = compute_fwt_har(prev_model, init_model, X_val_tensor, y_val_tensor, known_classes)

print(f"\n### Period 4:")
print(f"- FWT (PNN HAR Period 4, old classes {known_classes}): {fwt * 100:.2f}%")
print(f"- Accuracy by previous model: {acc_prev * 100:.2f}%")
print(f"- Accuracy by init model:     {acc_init * 100:.2f}%")
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 5120 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_1853981/2821685562.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# 📋 Total samples for known classes [0, 1, 3]: 1560
#
# ### 🔍 FWT Debug Info (HAR):
# - Total evaluated samples: 1560
# - Correct (PrevModel): 1458 / 1560 → Acc = 0.9346
# - Correct (InitModel): 489 / 1560 → Acc = 0.3135
# - FWT = Acc_prev - Acc_init = 0.6212
#
# ### Period 4:
# - FWT (PNN HAR Period 4, old classes [0, 1, 3]): 62.12%
# - Accuracy by previous model: 93.46%
# - Accuracy by init model:     31.35%
# /tmp/ipykernel_1853981/3765843572.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(X_known, dtype=torch.float32),
# /tmp/ipykernel_1853981/3765843572.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(y_known, dtype=torch.long)

# %%
# ================================
# 📌 Period 4 Configuration - Progressive Neural Network (PNN_fc2)
# ================================
period = 4

# === Load dataset for this period ===
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# === Device ===
device = auto_select_cuda_device()

# === Training Hyperparameters ===
input_size    = X_train.shape[1]
hidden_size   = 128
dropout       = 0.2
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1
new_output_size = 2  # 新增兩個類別（拆分 WALKING 類）
output_size = len(set(y_train))  # 到目前為止總類別數（應為 5）

# === Step 1: 還原 Period 2 的基礎 MLP + Column 結構 ===
base_model = HAR_MLP_v2(input_size, hidden_size, 2, dropout)  # output: 2
prev_column_2 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)  # output: 1
frozen_step1 = ProgressiveNeuralNetwork_fc2(base_model=base_model, new_column=prev_column_2)

# === Step 2: 再加上 Period 3 的 Column ===
prev_column_3 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=1)  # Period 3 新增類別
frozen_step2 = ProgressiveNeuralNetwork_fc2(base_model=frozen_step1, new_column=prev_column_3)

# === 載入 Period 3 模型的 state_dict（已經是 Step2 完整結構）===
prev_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period-1}", "HAR_PNN_v2_best.pth"
)
checkpoint = torch.load(prev_model_path, map_location=device)
frozen_step2.load_state_dict(checkpoint['model_state_dict'], strict=True)
frozen_step2.to(device)
frozen_step2.eval()
for param in frozen_step2.parameters():
    param.requires_grad = False

# === Step 3: 加上 Period 4 的 Column 並包成新模型 ===
new_column_4 = HAR_PNN_Column_fc2(input_size, hidden_size, new_output_size=new_output_size)
model = ProgressiveNeuralNetwork_fc2(base_model=frozen_step2, new_column=new_column_4).to(device)
print(model)

# === Optimizer / Loss / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.new_column.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Saving Path ===
model_name = "HAR_PNN_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "TT",
    "PNN_CIL_v2", f"PNN_FC2_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

print_model_info(model)
# === Training ===
train_with_pnn(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period,
    device=device
)

# === Summary & Cleanup ===
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
del base_model, prev_column_2, prev_column_3, new_column_4, frozen_step1, frozen_step2, checkpoint
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 1
#     - Memory Used    : 765 MiB
#     - Device Name    : NVIDIA RTX A6000
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): ProgressiveNeuralNetwork_fc2(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# - Total Parameters: 406150
# - Model Size (float32): 1.55 MB
#
# 🚀 'train_with_pnn' started.
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
# /tmp/ipykernel_781994/3291222569.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(prev_model_path, map_location=device)
# Epoch 1/1, Train Loss: 4.623844, Train-Class-Acc: {0: '79.24%', 1: '91.99%', 2: '99.18%', 3: '100.00%', 4: '0.75%', 5: '5.58%'}
# Val Loss: 2.147958, Val Acc: 67.66%, Val-Class-Acc: {0: '79.23%', 1: '93.80%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '17.38%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_1.pth
#
# ⏳ Total training time: 1.38 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_best.pth (Val Accuracy: 67.66%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 1, Train Loss: 4.623844, Train-Acc: {0: '79.24%', 1: '91.99%', 2: '99.18%', 3: '100.00%', 4: '0.75%', 5: '5.58%'},
# Val Loss: 2.147958, Val Acc: 67.66%, Val-Acc: {0: '79.23%', 1: '93.80%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '17.38%'}, Model Path: Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4/HAR_PNN_v2_epoch_1.pth
# ---
# ### Period 4
# + ##### Total training time: 1.38 seconds
# + ##### Model: ProgressiveNeuralNetwork_fc2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/TT/PNN_CIL_v2/PNN_FC2_Period_4'*
# + ##### Best Epoch: 1
# #### __Val Accuracy: 67.66%__
# #### __Val-Class-Acc: {0: '79.23%', 1: '93.80%', 2: '100.00%', 3: '100.00%', 4: '0.00%', 5: '17.38%'}__
#
# ✅ Period 4 Training Complete. Final model architecture:
# ProgressiveNeuralNetwork_fc2(
#   (base_model): ProgressiveNeuralNetwork_fc2(
#     (base_model): ProgressiveNeuralNetwork_fc2(
#       (base_model): HAR_MLP_v2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=2, bias=True)
#       )
#       (new_column): HAR_PNN_Column_fc2(
#         (fc1): Linear(in_features=561, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (fc3): Linear(in_features=128, out_features=1, bias=True)
#         (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (new_column): HAR_PNN_Column_fc2(
#       (fc1): Linear(in_features=561, out_features=128, bias=True)
#       (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (fc2): Linear(in_features=128, out_features=128, bias=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (fc3): Linear(in_features=128, out_features=1, bias=True)
#       (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (new_column): HAR_PNN_Column_fc2(
#     (fc1): Linear(in_features=561, out_features=128, bias=True)
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=128, out_features=2, bias=True)
#     (lateral_adapter): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ---
# ## 📊 Comprehensive Test Results:
# ### HAR - PNN_FC1 (ProgressiveNeuralNetwork_fc1)
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                     |
# |--------|-------------------|---------------------|--------------------------------------------------------------------------|
# | 1      | 159.83            | **95.31%**          | {0: 93.48%, 1: 96.99%}                                                  |
# | 2      | 408.46            | **96.93%**          | {0: 87.17%, 1: 97.93%, 2: 100.00%}                                      |
# | 3      | 712.79            | **97.46%**          | {0: 87.78%, 1: 97.18%, 2: 100.00%, 3: 100.00%}                          |
# | 4      | 868.30            | **96.47%**          | {0: 86.76%, 1: 97.56%, 2: 99.80%, 3: 100.00%, 4: 95.75%, 5: 98.81%}     |
#
# ### ✔️ HAR - PNN_FC2 (ProgressiveNeuralNetwork_fc2)
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                     |
# |--------|-------------------|---------------------|--------------------------------------------------------------------------|
# | 1      | 159.83            | **95.31%**          | {0: 93.48%, 1: 96.99%}                                                  |
# | 2      | 480.26            | **96.93%**          | {0: 87.17%, 1: 97.93%, 2: 100.00%}                                      |
# | 3      | 729.13            | **97.56%**          | {0: 87.78%, 1: 97.74%, 2: 100.00%, 3: 100.00%}                          |
# | 4      | 893.29            | **97.01%**          | {0: 88.59%, 1: 97.37%, 2: 99.80%, 3: 100.00%, 4: 98.51%, 5: 97.62%}     |
#
# ---

# %% [markdown]
# ## 📊 Summary:

# %% [markdown]
# ### ✔️ HAR - PNN: Validation Summary
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                     |
# |--------|-------------------|---------------------|--------------------------------------------------------------------------|
# | 1      | 149.07            | **95.31%**          | {0: 95.32%, 1: 95.30%}                                                 |
# | 2      | 480.26            | **96.93%**          | {0: 87.17%, 1: 97.93%, 2: 100.00%}                                      |
# | 3      | 729.13            | **97.56%**          | {0: 87.78%, 1: 97.74%, 2: 100.00%, 3: 100.00%}                          |
# | 4      | 893.29            | **97.01%**          | {0: 88.59%, 1: 97.37%, 2: 99.80%, 3: 100.00%, 4: 98.51%, 5: 97.62%}     |

# %% [markdown]
# ### 🧠 Continual Learning Metrics
#
# | Period | AA_old (%) | AA_new (%) | BWT (%) | FWT (%) | FWT Classes     | Prev. Model Acc | Init Model Acc |
# |--------|------------|------------|---------|---------|------------------|------------------|-----------------|
# | 2      | 92.55%     | 100.00%    | -2.68%  | 47.51%  | [0, 1]           | 92.96%           | 45.45%          |
# | 3      | 95.17%     | 100.00%    | +0.14%  | 72.03%  | [0, 1, 2]        | 96.18%           | 24.15%          |
# | 4      | 96.44%     | 98.07%     | +0.06%  | 62.12%  | [0, 1, 3]        | 93.46%           | 31.35%          |

# %% [markdown]
# ### 📦 Model Size per Period
#
# | Period | Output Size | Total Params | Δ Params vs Prev | Δ % vs Prev | Model Size (float32) |
# |--------|-------------|--------------|------------------|-------------|-----------------------|
# | 1      | 2           | 89,218       | —                | —           | 0.34 MB               |
# | 2      | 3           | 194,819      | +105,601         | +118.34%    | 0.74 MB               |
# | 3      | 4           | 300,420      | +105,601         | +54.21%     | 1.15 MB               |
# | 4      | 6           | 406,150      | +105,730         | +35.20%     | 1.55 MB               |
#
# **📈 Model Growth Rate (MGR) = (406,150 - 89,218) / (89,218 × 3) ≈ +118.38%**
#
# **📈 Max trainable ratio ≈ 54.20%**
