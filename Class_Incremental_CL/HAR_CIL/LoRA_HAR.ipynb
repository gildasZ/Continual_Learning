# %% [markdown]
# ## __Check first before starting__

# %%
import os

# Change the working directory to the project root
# Working_directory = os.path.normpath("C:/Users/james/OneDrive/文件/Continual_Learning")
Working_directory = os.path.normpath("/mnt/mydisk/Continual_Learning_JL/Continual_Learning/")
os.chdir(Working_directory)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /mnt/mydisk/Continual_Learning_JL/Continual_Learning

# %% [markdown]
# ## __All imports__

# %%
# Operating system and file management
import os
import shutil
import contextlib
import traceback
import gc
import glob, copy
from collections import defaultdict
import subprocess
import time
import re, pickle

# Jupyter notebook widgets and display
import ipywidgets as widgets
from IPython.display import display

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Plotting and visualization
import matplotlib.pyplot as plt
from mpl_interactions import zoom_factory, panhandler

# Machine learning and preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pickle
from ta import trend, momentum, volatility, volume

# Mathematical and scientific computing
import math
from scipy.ndimage import gaussian_filter1d

# Type hinting
from typing import Callable, Tuple

# Deep learning with PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## __Dataset Setup & Preprocessing__

# %% [markdown]
# ### 📥 Step 1 — Set dataset path and load features & labels
# We will load the 561-dimensional features and original activity labels for both training and testing.

# %%
# Set working directory manually before running this cell if needed
BASE_DIR = "Class_Incremental_CL/HAR_CIL/har_dataset"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
TEST_DIR = os.path.join(BASE_DIR, "test")

# 活動對應（原始標籤）
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# Load feature and label data
X_train = np.loadtxt(os.path.join(TRAIN_DIR, "X_train.txt"))
y_train = np.loadtxt(os.path.join(TRAIN_DIR, "y_train.txt")).astype(int)
X_test = np.loadtxt(os.path.join(TEST_DIR, "X_test.txt"))
y_test = np.loadtxt(os.path.join(TEST_DIR, "y_test.txt")).astype(int)

print("Train shape:", X_train.shape, y_train.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (7352, 561) (7352,)
# Test shape: (2947, 561) (2947,)

# %% [markdown]
# ### 🧩 Step 2 — Define period label groups and final class remapping
# We will predefine the class mappings for each period to ensure consistency across the experiment.

# %%
# Period-to-original-label mapping
period_label_map = {
    1: [4, 5],           # SITTING, STANDING
    2: [4, 5, 1, 2, 3],  # + WALKING variants (merged)
    3: [4, 5, 1, 2, 3, 6],  # + LAYING
    4: [4, 5, 1, 2, 3, 6]   # same classes, but with walking variants separated
}

# Consistent label remapping across all periods (final label index)
final_class_map = {
    "SITTING": 0,
    "STANDING": 1,
    "WALKING": 2,
    "LAYING": 3,
    "WALKING_UPSTAIRS": 4,
    "WALKING_DOWNSTAIRS": 5
}

# Reverse mapping for readability
label_name_from_id = {v: k for k, v in final_class_map.items()}
activity_label_map = {
    1: "WALKING",
    2: "WALKING_UPSTAIRS",
    3: "WALKING_DOWNSTAIRS",
    4: "SITTING",
    5: "STANDING",
    6: "LAYING"
}

# %% [markdown]
# ### 🧪 Step 3 — Filter and remap datasets for each period
# We will build training and testing splits for each period using consistent class indices.

# %%
def map_label(label, period):
    name = activity_label_map[label]
    if period < 4:
        if name.startswith("WALKING"):
            return final_class_map["WALKING"]
        else:
            return final_class_map[name]
    else:
        return final_class_map[name]

def get_period_dataset(X, y, period):
    allowed_labels = period_label_map[period]
    mask = np.isin(y, allowed_labels)
    Xp = X[mask]
    yp = np.array([map_label(label, period) for label in y[mask]])
    return Xp, yp

# %% [markdown]
# ### 📊 Step 4 — Print artistic class distribution for each period
# We show each period's label map and class statistics to confirm correctness.

# %%
def print_class_distribution(y, var_name: str, label_map: dict) -> None:
    y = np.array(y).flatten()
    unique, counts = np.unique(y, return_counts=True)
    total = counts.sum()
    print(f"\n📦 Class Distribution for {var_name}")
    for i, c in zip(unique, counts):
        print(f"  ├─ Label {i:<2} ({label_map[i]:<20}) → {c:>5} samples ({(c/total)*100:>5.2f}%)")

# %%
period_datasets = {}

for period in range(1, 5):
    Xp_train, yp_train = get_period_dataset(X_train, y_train, period)
    Xp_test, yp_test = get_period_dataset(X_test, y_test, period)

    period_datasets[period] = {
        "train": (Xp_train, yp_train),
        "test": (Xp_test, yp_test)
    }

    print_class_distribution(yp_train, f"Period {period} (Train)", label_name_from_id)
    print_class_distribution(yp_test, f"Period {period} (Test)", label_name_from_id)
# Out:
# 📦 Class Distribution for Period 1 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (48.35%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (51.65%)
#
# 📦 Class Distribution for Period 1 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (48.00%)
#   ├─ Label 1  (STANDING            ) →   532 samples (52.00%)
#
# 📦 Class Distribution for Period 2 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (21.63%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (23.11%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (55.26%)
#
# 📦 Class Distribution for Period 2 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (20.37%)
#   ├─ Label 1  (STANDING            ) →   532 samples (22.07%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (57.55%)
#
# 📦 Class Distribution for Period 3 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  3285 samples (44.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#
# 📦 Class Distribution for Period 3 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →  1387 samples (47.06%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#
# 📦 Class Distribution for Period 4 (Train)
#   ├─ Label 0  (SITTING             ) →  1286 samples (17.49%)
#   ├─ Label 1  (STANDING            ) →  1374 samples (18.69%)
#   ├─ Label 2  (WALKING             ) →  1226 samples (16.68%)
#   ├─ Label 3  (LAYING              ) →  1407 samples (19.14%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →  1073 samples (14.59%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   986 samples (13.41%)
#
# 📦 Class Distribution for Period 4 (Test)
#   ├─ Label 0  (SITTING             ) →   491 samples (16.66%)
#   ├─ Label 1  (STANDING            ) →   532 samples (18.05%)
#   ├─ Label 2  (WALKING             ) →   496 samples (16.83%)
#   ├─ Label 3  (LAYING              ) →   537 samples (18.22%)
#   ├─ Label 4  (WALKING_UPSTAIRS    ) →   471 samples (15.98%)
#   ├─ Label 5  (WALKING_DOWNSTAIRS  ) →   420 samples (14.25%)

# %% [markdown]
# ## __Check GPU, CUDA, Pytorch__

# %% [markdown]
# ### GPU Details

# %%
# !nvidia-smi
# Out:
# Thu Apr 24 16:04:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.15              Driver Version: 570.86.15      CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:2A:00.0 Off |                  Off |
# | 52%   78C    P2            294W /  300W |   46011MiB /  49140MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:3D:00.0 Off |                  Off |
# | 30%   50C    P2            104W /  300W |   38915MiB /  49140MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               Off |   00000000:AB:00.0 Off |                  Off |
# | 30%   43C    P2             98W /  300W |   21147MiB /  49140MiB |     56%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    0   N/A  N/A         2081354      C   python                                20010MiB |
# |    0   N/A  N/A         2195268      C   python                                13922MiB |
# |    0   N/A  N/A         2214128      C   ...onda3/envs/CIL_env/bin/python        260MiB |
# |    0   N/A  N/A         2222688      C   python                                 7810MiB |
# |    1   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    1   N/A  N/A         2188598      C   python                                23910MiB |
# |    1   N/A  N/A         2195268      C   python                                14750MiB |
# |    2   N/A  N/A            2843      G   /usr/lib/xorg/Xorg                        4MiB |
# |    2   N/A  N/A         2195268      C   python                                20734MiB |
# |    2   N/A  N/A         2214128      C   ...onda3/envs/CIL_env/bin/python        384MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### CUDA Details

# %%
def check_gpu_config():
    """
    Check GPU availability and display detailed configuration information.
    """
    # Check if GPU is available
    gpu_available = torch.cuda.is_available()
    
    # Print header
    print("=" * 50)
    print("GPU Configuration Check".center(50))
    print("=" * 50)
    
    # Basic GPU availability
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'GPU Available':<25}: {'Yes' if gpu_available else 'No'}")
    
    # If GPU is available, print detailed info
    if gpu_available:
        print("-" * 50)
        print("GPU Details".center(50))
        print("-" * 50)
        
        # Device info
        print(f"{'Device Name':<25}: {torch.cuda.get_device_name(0)}")
        print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")
        print(f"{'Current Device Index':<25}: {torch.cuda.current_device()}")
        
        # Compute capability and CUDA cores
        props = torch.cuda.get_device_properties(0)
        print(f"{'Compute Capability':<25}: {props.major}.{props.minor}")
        print(f"{'Total CUDA Cores':<25}: {props.multi_processor_count * 128}")  # Approx. 128 cores per SM
        
        # Memory info
        total_memory = props.total_memory / (1024 ** 3)  # Convert to GB
        memory_allocated = torch.cuda.memory_allocated(0) / (1024 ** 3)
        memory_reserved = torch.cuda.memory_reserved(0) / (1024 ** 3)
        print(f"{'Total Memory (GB)':<25}: {total_memory:.2f}")
        print(f"{'Allocated Memory (GB)':<25}: {memory_allocated:.2f}")
        print(f"{'Reserved Memory (GB)':<25}: {memory_reserved:.2f}")
    else:
        print("-" * 50)
        print("No GPU detected. Running on CPU.".center(50))
        print("-" * 50)
    
    print("=" * 50)

if __name__ == "__main__":
    check_gpu_config()
# Out:
# ==================================================
#              GPU Configuration Check
# ==================================================
# PyTorch Version          : 2.5.1
# GPU Available            : Yes
# --------------------------------------------------
#                    GPU Details
# --------------------------------------------------
# Device Name              : NVIDIA RTX A6000
# Number of GPUs           : 3
# Current Device Index     : 0
# Compute Capability       : 8.6
# Total CUDA Cores         : 10752
# Total Memory (GB)        : 47.41
# Allocated Memory (GB)    : 0.00
# Reserved Memory (GB)     : 0.00
# ==================================================

# %% [markdown]
# ### PyTorch Details

# %%
def print_torch_config():
    """Print PyTorch and CUDA configuration in a formatted manner."""
    print("=" * 50)
    print("PyTorch Configuration".center(50))
    print("=" * 50)
    
    # Basic PyTorch and CUDA info
    print(f"{'PyTorch Version':<25}: {torch.__version__}")
    print(f"{'CUDA Compiled Version':<25}: {torch.version.cuda}")
    print(f"{'CUDA Available':<25}: {'Yes' if torch.cuda.is_available() else 'No'}")
    print(f"{'Number of GPUs':<25}: {torch.cuda.device_count()}")

    # GPU details if available
    if torch.cuda.is_available():
        print(f"{'GPU Name':<25}: {torch.cuda.get_device_name(0)}")

    print("-" * 50)
    
    # Seed setting
    torch.manual_seed(42)
    print(f"{'Random Seed':<25}: 42 (Seeding successful!)")
    
    print("=" * 50)

if __name__ == "__main__":
    print_torch_config()
# Out:
# ==================================================
#               PyTorch Configuration
# ==================================================
# PyTorch Version          : 2.5.1
# CUDA Compiled Version    : 12.1
# CUDA Available           : Yes
# Number of GPUs           : 3
# GPU Name                 : NVIDIA RTX A6000
# --------------------------------------------------
# Random Seed              : 42 (Seeding successful!)
# ==================================================

# %% [markdown]
# ## __⚙️ GPU Selection — Auto-select the least loaded GPU__
# This code automatically scans available GPUs and selects the one with the lowest current memory usage.

# %%
def auto_select_cuda_device(verbose=True):
    """
    Automatically selects the CUDA GPU with the least memory usage.
    Falls back to CPU if no GPU is available.
    """
    if not torch.cuda.is_available():
        print("🚫 No CUDA GPU available. Using CPU.")
        return torch.device("cpu")

    try:
        # Run nvidia-smi to get memory usage of each GPU
        smi_output = subprocess.check_output(
            ['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader'],
            encoding='utf-8'
        )
        memory_used = [int(x) for x in smi_output.strip().split('\n')]
        best_gpu = int(np.argmin(memory_used))

        if verbose:
            print("🎯 Automatically selected GPU:")
            print(f"    - CUDA Device ID : {best_gpu}")
            print(f"    - Memory Used    : {memory_used[best_gpu]} MiB")
            print(f"    - Device Name    : {torch.cuda.get_device_name(best_gpu)}")
        return torch.device(f"cuda:{best_gpu}")
    except Exception as e:
        print(f"⚠️ Failed to auto-detect GPU. Falling back to cuda:0. ({e})")
        return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Execute and assign
device = auto_select_cuda_device()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 21147 MiB
#     - Device Name    : NVIDIA RTX A6000

# %% [markdown]
# ## __MLP Model with LoRA__

# %% [markdown]
# ### HAR_MLP_LoRA_v2

# %%
class LoRA(nn.Module):
    def __init__(self, linear_layer: nn.Linear, rank: int):
        super(LoRA, self).__init__()
        self.linear = linear_layer
        self.rank = rank

        in_features, out_features = linear_layer.weight.shape
        self.A = nn.Parameter(torch.zeros(in_features, rank))
        self.B = nn.Parameter(torch.zeros(rank, out_features))

        nn.init.normal_(self.A, mean=0, std=1)
        nn.init.zeros_(self.B)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        lora_delta = self.A @ self.B
        adapted_weight = self.linear.weight + lora_delta
        return F.linear(x, adapted_weight, self.linear.bias)

    def parameters(self, recurse=True):
        return [self.A, self.B]

class HAR_MLP_LoRA_v2(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, output_size: int, dropout: float = 0.2, lora_rank: int = 8):
        super(HAR_MLP_LoRA_v2, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.fc3 = nn.Linear(hidden_size, output_size)

        self.lora_rank = lora_rank
        self.lora_adapter = None  # 延遲初始化

        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def init_lora(self):
        """從 Period 2 開始呼叫一次，初始化並固定使用這個 LoRA"""
        if self.lora_adapter is None:
            self.lora_adapter = LoRA(self.fc2, self.lora_rank).to(next(self.parameters()).device)
            print("✅ Initialized LoRA adapter for fc2")

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.dropout1(x)

        if self.lora_adapter:
            lora_delta = self.lora_adapter.A @ self.lora_adapter.B
            adapted_weight = self.fc2.weight + lora_delta
            x = F.linear(x, adapted_weight, self.fc2.bias)
        else:
            x = self.fc2(x)

        x = self.bn2(x)
        x = self.relu2(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

    def get_trainable_parameters(self):
        params = []
        names = []

        if self.lora_adapter:
            lora_params = list(self.lora_adapter.parameters())
            params += lora_params
            names += ['lora_adapter.' + name for name, _ in self.lora_adapter.named_parameters()]

        fc3_params = list(self.fc3.parameters())
        params += fc3_params
        names += ['fc3.' + name for name, _ in self.fc3.named_parameters()]

        # # ✅ 加入 fc1 的參數
        # fc1_params = list(self.fc1.parameters())
        # params += fc1_params
        # names += ['fc1.' + name for name, _ in self.fc1.named_parameters()]

        print(f"🧠 Trainable parameters: {len(params)} total")
        for name in names:
            print(f"  ✅ {name}")
        return params

# %% [markdown]
# ## __Training Function with LoRA__

# %%
def compute_classwise_accuracy(preds, targets, class_correct, class_total):
    """
    Computes per-class accuracy statistics from raw logits and ground truth.
    """
    preds = torch.argmax(preds, dim=-1)
    correct_mask = (preds == targets)
    for label in torch.unique(targets):
        label = label.item()
        label_mask = (targets == label)
        class_total[label] = class_total.get(label, 0) + label_mask.sum().item()
        class_correct[label] = class_correct.get(label, 0) + (correct_mask & label_mask).sum().item()

# %%
def train_with_standard_lora(model, output_size, criterion, optimizer,
                             X_train, y_train, X_val, y_val,
                             num_epochs, batch_size,
                             model_saving_folder, model_name,
                             stop_signal_file=None, scheduler=None,
                             period=None):
    print(f"\n🚀 'train_with_standard_lora' started for Period {period}\n")

    model_name = model_name or 'standard_lora_model'
    model_saving_folder = model_saving_folder or './saved_models'
    if os.path.exists(model_saving_folder):
        shutil.rmtree(model_saving_folder)
        print(f"✅ Removed existing folder: {model_saving_folder}")
    os.makedirs(model_saving_folder, exist_ok=True)

    device = auto_select_cuda_device()
    model.to(device)

    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val = torch.tensor(y_val, dtype=torch.long).to(device)

    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    print("\n✅ Data Overview:")
    print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")

    # === Parameter Overview ===
    print("\n🔧 Model Parameter Overview:")
    for name, param in model.named_parameters():
        status = "✅ trainable" if param.requires_grad else "❌ frozen"
        print(f"{name:<50} | {status:<12} | shape={list(param.shape)}")

    print("\n🧠 Optimizer Parameter Overview:")
    for group in optimizer.param_groups:
        for param in group['params']:
            for name, p in model.named_parameters():
                if p is param:
                    print(f"{name:<50} | ✅ from optimizer | shape={list(p.shape)}")

    print("\n" + "=" * 80 + "\n")

    start_time = time.time()
    best_results = []

    for epoch in range(num_epochs):
        if stop_signal_file and os.path.exists(stop_signal_file):
            print("\n🛑 Stop signal detected. Exiting training loop.")
            break

        model.train()
        epoch_loss = 0.0
        class_correct, class_total = {}, {}

        for xb, yb in train_loader:
            optimizer.zero_grad()
            logits = model(xb).view(-1, output_size)
            yb_flat = yb.view(-1)
            loss = criterion(logits, yb_flat)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * xb.size(0)
            compute_classwise_accuracy(logits, yb_flat, class_correct, class_total)

        train_loss = epoch_loss / len(train_loader.dataset)
        train_acc = {int(k): f"{(class_correct[k] / class_total[k]) * 100:.2f}%" if class_total[k] > 0 else "0.00%" for k in class_total}

        # === Validation ===
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        val_class_correct, val_class_total = {}, {}

        with torch.no_grad():
            for xb, yb in val_loader:
                outputs = model(xb).view(-1, output_size)
                yb_flat = yb.view(-1)
                val_loss += criterion(outputs, yb_flat).item() * xb.size(0)
                preds = torch.argmax(outputs, dim=1)
                val_correct += (preds == yb_flat).sum().item()
                val_total += yb_flat.size(0)
                compute_classwise_accuracy(outputs, yb_flat, val_class_correct, val_class_total)

        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / val_total
        val_acc_cls = {int(k): f"{(val_class_correct[k]/val_class_total[k])*100:.2f}%" if val_class_total[k]>0 else "0.00%" for k in val_class_total}

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, Train-Class-Acc: {train_acc}")
        print(f"Val Loss: {val_loss:.6f}, Val Acc: {val_acc*100:.2f}%, Val-Class-Acc: {val_acc_cls}, LR: {optimizer.param_groups[0]['lr']:.6f}")

        # === Save checkpoint ===
        model_path = os.path.join(model_saving_folder, f"{model_name}_epoch_{epoch+1}.pth")
        current = {
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_accuracy': val_acc,
            'train_classwise_accuracy': train_acc,
            'val_classwise_accuracy': val_acc_cls,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'learning_rate': optimizer.param_groups[0]['lr'],
            'model_path': model_path,
        }

        if len(best_results) < 5 or val_acc > best_results[-1]['val_accuracy']:
            if len(best_results) == 5:
                to_remove = best_results.pop()
                if os.path.exists(to_remove['model_path']):
                    os.remove(to_remove['model_path'])
                    print(f"🗑 Removed: {to_remove['model_path']}")
            best_results.append(current)
            best_results.sort(key=lambda x: (x['val_accuracy'], x['epoch']), reverse=True)
            torch.save(current, model_path)
            print(f"✅ Saved model: {model_path}")

        if scheduler: scheduler.step(val_loss)

    elapsed_time = time.time() - start_time
    print(f"\n⏳ Total training time: {elapsed_time:.2f} seconds")

    if best_results:
        best = best_results[0]
        best_model_path = os.path.join(model_saving_folder, f"{model_name}_best.pth")
        torch.save(best, best_model_path)
        print(f"\n🏆 Best model saved as: {best_model_path} (Val Accuracy: {best['val_accuracy'] * 100:.2f}%)")

    final_model_path = os.path.join(model_saving_folder, f"{model_name}_final.pth")
    torch.save(current, final_model_path)
    print(f"\n📌 Final model saved as: {final_model_path}")

    print("\n🎯 Top 5 Best Models:")
    for res in best_results:
        print(f"Epoch {res['epoch']}, Train Loss: {res['train_loss']:.6f}, Train-Acc: {res['train_classwise_accuracy']},\n"
              f"Val Loss: {res['val_loss']:.6f}, Val Acc: {res['val_accuracy']*100:.2f}%, Val-Acc: {res['val_classwise_accuracy']}, Model Path: {res['model_path']}")

    match = re.search(r'Period_(\d+)', model_saving_folder)
    period_label = match.group(1) if match else str(period)
    model_name_str = model.__class__.__name__
    best_model = max(best_results, key=lambda x: x['val_accuracy'])

    best_md_summary = f"""
    ---
### Period {period_label}
+ ##### Total training time: {elapsed_time:.2f} seconds
+ ##### Model: {model_name_str}
+ ##### Training and saving in *'{model_saving_folder}'*
+ ##### Best Epoch: {best_model['epoch']}
#### __Val Accuracy: {best_model['val_accuracy'] * 100:.2f}%__
#### __Val-Class-Acc: {best_model['val_classwise_accuracy']}__
    """
    print(best_md_summary.strip())

    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# ## __📋 Label Mapping (HAR Activities)__
#
# | Label ID | Activity Name       |
# |----------|---------------------|
# |    0     | SITTING             |
# |    1     | STANDING            |
# |    2     | WALKING             |
# |    3     | LAYING              |
# |    4     | WALKING_UPSTAIRS    |
# |    5     | WALKING_DOWNSTAIRS  |

# %% [markdown]
# ## __Common Parameters__

# %%
batch_size = 32
stop_signal_file = os.path.normpath(os.path.join('Class_Incremental_CL', 'HAR_CIL/stop_training.txt'))

# %% [markdown]
# ---
# ### Period 1
# + ##### Total training time: 561.36 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1'*
# + ##### Best Epoch: 973
# #### __Val Accuracy: 95.41%__
# #### __Val-Class-Acc: {0: '93.28%', 1: '97.37%'}__

# %%
# ================================
# 📌 Period 1 Configuration - HAR_MLP_v2 (Standard LoRA baseline)
# ================================
period = 1

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Device
device = auto_select_cuda_device()

# Model and training hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
lora_r        = 4
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000

# ==== Saving Path ====
model_name = "HAR_MLP_LoRA_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# ==== Model (No LoRA in Period 1) ====
model = HAR_MLP_LoRA_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout
).to(device)

# ==== Optimizer / Criterion / Scheduler ====
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# ==== Training ====
train_with_standard_lora(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 21147 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# 🚀 'train_with_standard_lora' started for Period 1
#
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 21414 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# ✅ Data Overview:
# X_train: torch.Size([2660, 561]), y_train: torch.Size([2660])
# X_val: torch.Size([1023, 561]), y_val: torch.Size([1023])
#
# 🔧 Model Parameter Overview:
# fc1.weight                                         | ✅ trainable  | shape=[128, 561]
# fc1.bias                                           | ✅ trainable  | shape=[128]
# bn1.weight                                         | ✅ trainable  | shape=[128]
# bn1.bias                                           | ✅ trainable  | shape=[128]
# fc2.weight                                         | ✅ trainable  | shape=[128, 128]
# fc2.bias                                           | ✅ trainable  | shape=[128]
# bn2.weight                                         | ✅ trainable  | shape=[128]
# bn2.bias                                           | ✅ trainable  | shape=[128]
# fc3.weight                                         | ✅ trainable  | shape=[2, 128]
# fc3.bias                                           | ✅ trainable  | shape=[2]
#
# 🧠 Optimizer Parameter Overview:
# fc1.weight                                         | ✅ from optimizer | shape=[128, 561]
# fc1.bias                                           | ✅ from optimizer | shape=[128]
# bn1.weight                                         | ✅ from optimizer | shape=[128]
# bn1.bias                                           | ✅ from optimizer | shape=[128]
# fc2.weight                                         | ✅ from optimizer | shape=[128, 128]
# fc2.bias                                           | ✅ from optimizer | shape=[128]
# bn2.weight                                         | ✅ from optimizer | shape=[128]
# bn2.bias                                           | ✅ from optimizer | shape=[128]
# fc3.weight                                         | ✅ from optimizer | shape=[2, 128]
# fc3.bias                                           | ✅ from optimizer | shape=[2]
#
# ================================================================================
#
# Epoch 1/1000, Train Loss: 0.738479, Train-Class-Acc: {0: '63.69%', 1: '53.35%'}
# Val Loss: 0.533027, Val Acc: 72.92%, Val-Class-Acc: {0: '46.44%', 1: '97.37%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.481248, Train-Class-Acc: {0: '74.73%', 1: '76.93%'}
# Val Loss: 0.350414, Val Acc: 84.95%, Val-Class-Acc: {0: '91.24%', 1: '79.14%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.398643, Train-Class-Acc: {0: '80.02%', 1: '82.46%'}
# Val Loss: 0.317090, Val Acc: 85.83%, Val-Class-Acc: {0: '76.58%', 1: '94.36%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.335251, Train-Class-Acc: {0: '82.97%', 1: '87.70%'}
# Val Loss: 0.271577, Val Acc: 90.22%, Val-Class-Acc: {0: '93.08%', 1: '87.59%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.289950, Train-Class-Acc: {0: '86.39%', 1: '88.94%'}
# Val Loss: 0.246961, Val Acc: 91.59%, Val-Class-Acc: {0: '89.21%', 1: '93.80%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.250690, Train-Class-Acc: {0: '87.64%', 1: '91.63%'}
# Val Loss: 0.238426, Val Acc: 91.50%, Val-Class-Acc: {0: '92.26%', 1: '90.79%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.229537, Train-Class-Acc: {0: '89.50%', 1: '91.99%'}
# Val Loss: 0.227349, Val Acc: 91.20%, Val-Class-Acc: {0: '91.85%', 1: '90.60%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.214816, Train-Class-Acc: {0: '90.51%', 1: '91.63%'}
# Val Loss: 0.221171, Val Acc: 91.98%, Val-Class-Acc: {0: '89.41%', 1: '94.36%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.193242, Train-Class-Acc: {0: '92.69%', 1: '92.58%'}
# Val Loss: 0.247617, Val Acc: 91.01%, Val-Class-Acc: {0: '84.32%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.179088, Train-Class-Acc: {0: '92.77%', 1: '93.60%'}
# Val Loss: 0.200770, Val Acc: 93.45%, Val-Class-Acc: {0: '92.06%', 1: '94.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.168376, Train-Class-Acc: {0: '93.70%', 1: '93.45%'}
# Val Loss: 0.262021, Val Acc: 91.10%, Val-Class-Acc: {0: '83.91%', 1: '97.74%'}, LR: 0.000100
# Epoch 12/1000, Train Loss: 0.159995, Train-Class-Acc: {0: '93.16%', 1: '93.74%'}
# Val Loss: 0.198418, Val Acc: 93.35%, Val-Class-Acc: {0: '92.46%', 1: '94.17%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.139943, Train-Class-Acc: {0: '94.71%', 1: '94.61%'}
# Val Loss: 0.201686, Val Acc: 92.67%, Val-Class-Acc: {0: '89.00%', 1: '96.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.143340, Train-Class-Acc: {0: '94.79%', 1: '94.03%'}
# Val Loss: 0.202202, Val Acc: 93.06%, Val-Class-Acc: {0: '90.22%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.131195, Train-Class-Acc: {0: '94.56%', 1: '95.27%'}
# Val Loss: 0.211520, Val Acc: 92.96%, Val-Class-Acc: {0: '88.80%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.120604, Train-Class-Acc: {0: '95.72%', 1: '95.34%'}
# Val Loss: 0.291760, Val Acc: 90.32%, Val-Class-Acc: {0: '81.26%', 1: '98.68%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.121637, Train-Class-Acc: {0: '95.65%', 1: '95.78%'}
# Val Loss: 0.244589, Val Acc: 92.38%, Val-Class-Acc: {0: '85.95%', 1: '98.31%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.096556, Train-Class-Acc: {0: '96.97%', 1: '96.51%'}
# Val Loss: 0.202606, Val Acc: 93.06%, Val-Class-Acc: {0: '89.21%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.105599, Train-Class-Acc: {0: '95.57%', 1: '96.14%'}
# Val Loss: 0.204432, Val Acc: 93.06%, Val-Class-Acc: {0: '94.70%', 1: '91.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.111902, Train-Class-Acc: {0: '95.65%', 1: '95.92%'}
# Val Loss: 0.201307, Val Acc: 92.86%, Val-Class-Acc: {0: '93.48%', 1: '92.29%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.091454, Train-Class-Acc: {0: '97.43%', 1: '96.65%'}
# Val Loss: 0.212899, Val Acc: 93.06%, Val-Class-Acc: {0: '88.80%', 1: '96.99%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.089354, Train-Class-Acc: {0: '97.12%', 1: '96.65%'}
# Val Loss: 0.226751, Val Acc: 92.18%, Val-Class-Acc: {0: '86.76%', 1: '97.18%'}, LR: 0.000100
# Epoch 23/1000, Train Loss: 0.092405, Train-Class-Acc: {0: '96.66%', 1: '97.09%'}
# Val Loss: 0.197275, Val Acc: 93.06%, Val-Class-Acc: {0: '94.70%', 1: '91.54%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.089687, Train-Class-Acc: {0: '96.73%', 1: '96.65%'}
# Val Loss: 0.185487, Val Acc: 94.23%, Val-Class-Acc: {0: '92.06%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.087677, Train-Class-Acc: {0: '97.28%', 1: '96.94%'}
# Val Loss: 0.188880, Val Acc: 93.94%, Val-Class-Acc: {0: '93.08%', 1: '94.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.085125, Train-Class-Acc: {0: '97.43%', 1: '96.80%'}
# Val Loss: 0.253893, Val Acc: 92.08%, Val-Class-Acc: {0: '85.54%', 1: '98.12%'}, LR: 0.000100
# Epoch 27/1000, Train Loss: 0.076863, Train-Class-Acc: {0: '97.36%', 1: '97.31%'}
# Val Loss: 0.245859, Val Acc: 92.18%, Val-Class-Acc: {0: '85.95%', 1: '97.93%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.073589, Train-Class-Acc: {0: '97.59%', 1: '96.80%'}
# Val Loss: 0.213795, Val Acc: 93.16%, Val-Class-Acc: {0: '88.19%', 1: '97.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.071134, Train-Class-Acc: {0: '97.67%', 1: '97.67%'}
# Val Loss: 0.194125, Val Acc: 93.55%, Val-Class-Acc: {0: '90.02%', 1: '96.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.071453, Train-Class-Acc: {0: '97.51%', 1: '97.09%'}
# Val Loss: 0.248541, Val Acc: 91.69%, Val-Class-Acc: {0: '84.93%', 1: '97.93%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.068727, Train-Class-Acc: {0: '97.74%', 1: '97.60%'}
# Val Loss: 0.328405, Val Acc: 88.86%, Val-Class-Acc: {0: '77.80%', 1: '99.06%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.063748, Train-Class-Acc: {0: '98.37%', 1: '97.53%'}
# Val Loss: 0.182485, Val Acc: 94.33%, Val-Class-Acc: {0: '92.87%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.066087, Train-Class-Acc: {0: '97.36%', 1: '97.38%'}
# Val Loss: 0.273955, Val Acc: 91.20%, Val-Class-Acc: {0: '83.71%', 1: '98.12%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.058115, Train-Class-Acc: {0: '98.44%', 1: '97.74%'}
# Val Loss: 0.239274, Val Acc: 92.38%, Val-Class-Acc: {0: '86.97%', 1: '97.37%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.050679, Train-Class-Acc: {0: '98.60%', 1: '98.40%'}
# Val Loss: 0.199143, Val Acc: 93.74%, Val-Class-Acc: {0: '90.02%', 1: '97.18%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.055326, Train-Class-Acc: {0: '98.13%', 1: '98.18%'}
# Val Loss: 0.272281, Val Acc: 92.18%, Val-Class-Acc: {0: '85.13%', 1: '98.68%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.056517, Train-Class-Acc: {0: '97.98%', 1: '98.11%'}
# Val Loss: 0.364166, Val Acc: 88.76%, Val-Class-Acc: {0: '77.60%', 1: '99.06%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.051348, Train-Class-Acc: {0: '98.06%', 1: '98.84%'}
# Val Loss: 0.264614, Val Acc: 92.57%, Val-Class-Acc: {0: '86.15%', 1: '98.50%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.052772, Train-Class-Acc: {0: '98.13%', 1: '98.11%'}
# Val Loss: 0.324519, Val Acc: 90.71%, Val-Class-Acc: {0: '82.28%', 1: '98.50%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.054899, Train-Class-Acc: {0: '97.74%', 1: '98.11%'}
# Val Loss: 0.405562, Val Acc: 88.27%, Val-Class-Acc: {0: '76.58%', 1: '99.06%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.051243, Train-Class-Acc: {0: '98.83%', 1: '97.45%'}
# Val Loss: 0.232535, Val Acc: 91.98%, Val-Class-Acc: {0: '95.72%', 1: '88.53%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.045202, Train-Class-Acc: {0: '98.68%', 1: '98.76%'}
# Val Loss: 0.252799, Val Acc: 92.67%, Val-Class-Acc: {0: '86.76%', 1: '98.12%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.039260, Train-Class-Acc: {0: '99.07%', 1: '98.40%'}
# Val Loss: 0.174736, Val Acc: 94.72%, Val-Class-Acc: {0: '93.48%', 1: '95.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.051019, Train-Class-Acc: {0: '98.52%', 1: '98.18%'}
# Val Loss: 0.224285, Val Acc: 93.06%, Val-Class-Acc: {0: '88.59%', 1: '97.18%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.043983, Train-Class-Acc: {0: '98.60%', 1: '98.47%'}
# Val Loss: 0.361827, Val Acc: 89.93%, Val-Class-Acc: {0: '79.63%', 1: '99.44%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.042837, Train-Class-Acc: {0: '98.76%', 1: '98.33%'}
# Val Loss: 0.254644, Val Acc: 92.67%, Val-Class-Acc: {0: '86.15%', 1: '98.68%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.044524, Train-Class-Acc: {0: '98.44%', 1: '98.91%'}
# Val Loss: 0.468558, Val Acc: 87.59%, Val-Class-Acc: {0: '74.34%', 1: '99.81%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.034877, Train-Class-Acc: {0: '98.68%', 1: '98.84%'}
# Val Loss: 0.285798, Val Acc: 91.79%, Val-Class-Acc: {0: '84.32%', 1: '98.68%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.041410, Train-Class-Acc: {0: '98.52%', 1: '98.62%'}
# Val Loss: 0.284117, Val Acc: 92.08%, Val-Class-Acc: {0: '84.73%', 1: '98.87%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.045131, Train-Class-Acc: {0: '98.76%', 1: '98.47%'}
# Val Loss: 0.231854, Val Acc: 93.35%, Val-Class-Acc: {0: '88.19%', 1: '98.12%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.041872, Train-Class-Acc: {0: '98.52%', 1: '98.47%'}
# Val Loss: 0.519893, Val Acc: 86.31%, Val-Class-Acc: {0: '71.69%', 1: '99.81%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.027786, Train-Class-Acc: {0: '99.46%', 1: '99.27%'}
# Val Loss: 0.199296, Val Acc: 94.53%, Val-Class-Acc: {0: '92.26%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.038121, Train-Class-Acc: {0: '98.99%', 1: '98.98%'}
# Val Loss: 0.350202, Val Acc: 91.69%, Val-Class-Acc: {0: '83.50%', 1: '99.25%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.031389, Train-Class-Acc: {0: '99.30%', 1: '98.98%'}
# Val Loss: 0.224060, Val Acc: 93.74%, Val-Class-Acc: {0: '91.85%', 1: '95.49%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.024641, Train-Class-Acc: {0: '98.83%', 1: '99.34%'}
# Val Loss: 0.214531, Val Acc: 94.23%, Val-Class-Acc: {0: '91.65%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_55.pth
# Epoch 56/1000, Train Loss: 0.039312, Train-Class-Acc: {0: '98.68%', 1: '98.47%'}
# Val Loss: 0.212578, Val Acc: 94.43%, Val-Class-Acc: {0: '92.46%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_56.pth
# Epoch 57/1000, Train Loss: 0.035596, Train-Class-Acc: {0: '98.60%', 1: '98.69%'}
# Val Loss: 0.233369, Val Acc: 94.43%, Val-Class-Acc: {0: '92.06%', 1: '96.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_55.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_57.pth
# Epoch 58/1000, Train Loss: 0.028097, Train-Class-Acc: {0: '98.99%', 1: '98.98%'}
# Val Loss: 0.263713, Val Acc: 93.55%, Val-Class-Acc: {0: '88.59%', 1: '98.12%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.025981, Train-Class-Acc: {0: '99.07%', 1: '99.34%'}
# Val Loss: 0.217409, Val Acc: 94.13%, Val-Class-Acc: {0: '92.26%', 1: '95.86%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.024307, Train-Class-Acc: {0: '99.46%', 1: '99.20%'}
# Val Loss: 0.252515, Val Acc: 93.84%, Val-Class-Acc: {0: '89.00%', 1: '98.31%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.035083, Train-Class-Acc: {0: '98.83%', 1: '99.13%'}
# Val Loss: 0.214116, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.027212, Train-Class-Acc: {0: '98.91%', 1: '99.05%'}
# Val Loss: 0.218796, Val Acc: 94.62%, Val-Class-Acc: {0: '91.65%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_56.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.030905, Train-Class-Acc: {0: '98.91%', 1: '98.91%'}
# Val Loss: 0.240453, Val Acc: 94.33%, Val-Class-Acc: {0: '90.22%', 1: '98.12%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.030965, Train-Class-Acc: {0: '99.22%', 1: '98.62%'}
# Val Loss: 0.361136, Val Acc: 91.69%, Val-Class-Acc: {0: '84.11%', 1: '98.68%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.032745, Train-Class-Acc: {0: '99.22%', 1: '98.98%'}
# Val Loss: 0.263665, Val Acc: 93.16%, Val-Class-Acc: {0: '87.58%', 1: '98.31%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.024354, Train-Class-Acc: {0: '99.38%', 1: '99.27%'}
# Val Loss: 0.216594, Val Acc: 94.72%, Val-Class-Acc: {0: '91.45%', 1: '97.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_57.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_66.pth
# Epoch 67/1000, Train Loss: 0.025122, Train-Class-Acc: {0: '99.22%', 1: '99.13%'}
# Val Loss: 0.245904, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.021625, Train-Class-Acc: {0: '99.61%', 1: '99.27%'}
# Val Loss: 0.235223, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.026621, Train-Class-Acc: {0: '99.30%', 1: '98.84%'}
# Val Loss: 0.227521, Val Acc: 92.67%, Val-Class-Acc: {0: '95.52%', 1: '90.04%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.029037, Train-Class-Acc: {0: '98.76%', 1: '99.05%'}
# Val Loss: 0.237837, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.025900, Train-Class-Acc: {0: '98.99%', 1: '99.42%'}
# Val Loss: 0.234023, Val Acc: 94.53%, Val-Class-Acc: {0: '92.67%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_61.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_71.pth
# Epoch 72/1000, Train Loss: 0.022229, Train-Class-Acc: {0: '99.46%', 1: '99.27%'}
# Val Loss: 0.486290, Val Acc: 89.64%, Val-Class-Acc: {0: '79.43%', 1: '99.06%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.018146, Train-Class-Acc: {0: '99.53%', 1: '99.42%'}
# Val Loss: 0.232533, Val Acc: 92.96%, Val-Class-Acc: {0: '94.09%', 1: '91.92%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.019690, Train-Class-Acc: {0: '99.46%', 1: '99.20%'}
# Val Loss: 0.300949, Val Acc: 93.35%, Val-Class-Acc: {0: '87.78%', 1: '98.50%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.021399, Train-Class-Acc: {0: '99.38%', 1: '99.34%'}
# Val Loss: 0.250714, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.019675, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.220122, Val Acc: 93.84%, Val-Class-Acc: {0: '94.30%', 1: '93.42%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.028308, Train-Class-Acc: {0: '98.52%', 1: '99.42%'}
# Val Loss: 0.409202, Val Acc: 91.40%, Val-Class-Acc: {0: '83.50%', 1: '98.68%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.021881, Train-Class-Acc: {0: '99.30%', 1: '99.05%'}
# Val Loss: 0.375211, Val Acc: 91.59%, Val-Class-Acc: {0: '83.91%', 1: '98.68%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.021631, Train-Class-Acc: {0: '99.46%', 1: '99.49%'}
# Val Loss: 0.435109, Val Acc: 90.52%, Val-Class-Acc: {0: '81.26%', 1: '99.06%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.020850, Train-Class-Acc: {0: '99.61%', 1: '98.98%'}
# Val Loss: 0.371425, Val Acc: 91.59%, Val-Class-Acc: {0: '83.91%', 1: '98.68%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.026037, Train-Class-Acc: {0: '98.99%', 1: '99.13%'}
# Val Loss: 0.239879, Val Acc: 94.72%, Val-Class-Acc: {0: '91.65%', 1: '97.56%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_52.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_81.pth
# Epoch 82/1000, Train Loss: 0.021027, Train-Class-Acc: {0: '99.14%', 1: '99.42%'}
# Val Loss: 0.287864, Val Acc: 93.16%, Val-Class-Acc: {0: '87.78%', 1: '98.12%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.017180, Train-Class-Acc: {0: '99.61%', 1: '99.42%'}
# Val Loss: 0.641304, Val Acc: 86.61%, Val-Class-Acc: {0: '72.51%', 1: '99.62%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.016922, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.200392, Val Acc: 94.43%, Val-Class-Acc: {0: '93.69%', 1: '95.11%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.017946, Train-Class-Acc: {0: '99.46%', 1: '99.42%'}
# Val Loss: 0.233449, Val Acc: 94.23%, Val-Class-Acc: {0: '92.06%', 1: '96.24%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.017606, Train-Class-Acc: {0: '99.38%', 1: '99.56%'}
# Val Loss: 0.238210, Val Acc: 94.33%, Val-Class-Acc: {0: '91.04%', 1: '97.37%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.016616, Train-Class-Acc: {0: '99.38%', 1: '99.78%'}
# Val Loss: 0.223757, Val Acc: 94.04%, Val-Class-Acc: {0: '94.09%', 1: '93.98%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.021892, Train-Class-Acc: {0: '99.30%', 1: '99.20%'}
# Val Loss: 0.267173, Val Acc: 94.33%, Val-Class-Acc: {0: '91.65%', 1: '96.80%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.022810, Train-Class-Acc: {0: '99.53%', 1: '99.20%'}
# Val Loss: 0.382290, Val Acc: 92.28%, Val-Class-Acc: {0: '84.93%', 1: '99.06%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.021872, Train-Class-Acc: {0: '99.30%', 1: '99.20%'}
# Val Loss: 0.339336, Val Acc: 92.57%, Val-Class-Acc: {0: '85.74%', 1: '98.87%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.016713, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.232448, Val Acc: 94.43%, Val-Class-Acc: {0: '92.67%', 1: '96.05%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.019628, Train-Class-Acc: {0: '99.53%', 1: '99.49%'}
# Val Loss: 0.328303, Val Acc: 93.16%, Val-Class-Acc: {0: '87.78%', 1: '98.12%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.017636, Train-Class-Acc: {0: '99.53%', 1: '99.49%'}
# Val Loss: 0.328393, Val Acc: 93.35%, Val-Class-Acc: {0: '87.58%', 1: '98.68%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.015020, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.350094, Val Acc: 92.77%, Val-Class-Acc: {0: '85.95%', 1: '99.06%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.013709, Train-Class-Acc: {0: '99.77%', 1: '99.49%'}
# Val Loss: 0.581407, Val Acc: 87.68%, Val-Class-Acc: {0: '74.54%', 1: '99.81%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.015457, Train-Class-Acc: {0: '99.61%', 1: '99.27%'}
# Val Loss: 0.245677, Val Acc: 94.53%, Val-Class-Acc: {0: '92.67%', 1: '96.24%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.018892, Train-Class-Acc: {0: '99.61%', 1: '99.27%'}
# Val Loss: 0.403140, Val Acc: 92.38%, Val-Class-Acc: {0: '85.74%', 1: '98.50%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.015811, Train-Class-Acc: {0: '99.61%', 1: '99.49%'}
# Val Loss: 0.318716, Val Acc: 93.16%, Val-Class-Acc: {0: '87.17%', 1: '98.68%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.025639, Train-Class-Acc: {0: '99.07%', 1: '98.98%'}
# Val Loss: 0.406609, Val Acc: 87.59%, Val-Class-Acc: {0: '97.56%', 1: '78.38%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.016036, Train-Class-Acc: {0: '99.69%', 1: '99.64%'}
# Val Loss: 0.483201, Val Acc: 90.52%, Val-Class-Acc: {0: '80.86%', 1: '99.44%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.014689, Train-Class-Acc: {0: '99.61%', 1: '99.49%'}
# Val Loss: 0.250225, Val Acc: 94.13%, Val-Class-Acc: {0: '90.63%', 1: '97.37%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.024147, Train-Class-Acc: {0: '99.38%', 1: '99.13%'}
# Val Loss: 0.217132, Val Acc: 94.43%, Val-Class-Acc: {0: '91.85%', 1: '96.80%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.017354, Train-Class-Acc: {0: '99.53%', 1: '99.34%'}
# Val Loss: 0.244412, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.015695, Train-Class-Acc: {0: '99.61%', 1: '99.34%'}
# Val Loss: 0.348818, Val Acc: 92.67%, Val-Class-Acc: {0: '86.15%', 1: '98.68%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.015500, Train-Class-Acc: {0: '99.61%', 1: '99.42%'}
# Val Loss: 0.271643, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.018979, Train-Class-Acc: {0: '99.46%', 1: '99.20%'}
# Val Loss: 0.229382, Val Acc: 94.62%, Val-Class-Acc: {0: '92.87%', 1: '96.24%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_71.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_106.pth
# Epoch 107/1000, Train Loss: 0.011069, Train-Class-Acc: {0: '99.53%', 1: '99.71%'}
# Val Loss: 0.284073, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.013654, Train-Class-Acc: {0: '99.92%', 1: '99.34%'}
# Val Loss: 0.244157, Val Acc: 94.82%, Val-Class-Acc: {0: '92.46%', 1: '96.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_108.pth
# Epoch 109/1000, Train Loss: 0.012002, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.263081, Val Acc: 94.43%, Val-Class-Acc: {0: '92.06%', 1: '96.62%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.023683, Train-Class-Acc: {0: '99.07%', 1: '99.34%'}
# Val Loss: 0.254367, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.014649, Train-Class-Acc: {0: '99.77%', 1: '99.49%'}
# Val Loss: 0.276872, Val Acc: 94.82%, Val-Class-Acc: {0: '92.46%', 1: '96.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_106.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_111.pth
# Epoch 112/1000, Train Loss: 0.013012, Train-Class-Acc: {0: '99.77%', 1: '99.64%'}
# Val Loss: 0.410439, Val Acc: 91.50%, Val-Class-Acc: {0: '83.71%', 1: '98.68%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.014026, Train-Class-Acc: {0: '99.22%', 1: '99.78%'}
# Val Loss: 0.313186, Val Acc: 93.94%, Val-Class-Acc: {0: '89.00%', 1: '98.50%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.026464, Train-Class-Acc: {0: '99.30%', 1: '98.84%'}
# Val Loss: 0.296090, Val Acc: 92.18%, Val-Class-Acc: {0: '95.93%', 1: '88.72%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.022379, Train-Class-Acc: {0: '99.07%', 1: '99.34%'}
# Val Loss: 0.343891, Val Acc: 94.23%, Val-Class-Acc: {0: '89.82%', 1: '98.31%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.017573, Train-Class-Acc: {0: '99.53%', 1: '99.34%'}
# Val Loss: 0.279207, Val Acc: 94.43%, Val-Class-Acc: {0: '91.65%', 1: '96.99%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.012114, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.530541, Val Acc: 88.95%, Val-Class-Acc: {0: '78.00%', 1: '99.06%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.013558, Train-Class-Acc: {0: '99.46%', 1: '99.56%'}
# Val Loss: 0.260086, Val Acc: 94.53%, Val-Class-Acc: {0: '92.67%', 1: '96.24%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.019942, Train-Class-Acc: {0: '99.38%', 1: '99.20%'}
# Val Loss: 0.312085, Val Acc: 94.23%, Val-Class-Acc: {0: '90.84%', 1: '97.37%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.015136, Train-Class-Acc: {0: '99.53%', 1: '99.71%'}
# Val Loss: 0.347782, Val Acc: 93.26%, Val-Class-Acc: {0: '87.58%', 1: '98.50%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.016279, Train-Class-Acc: {0: '99.46%', 1: '99.34%'}
# Val Loss: 0.485396, Val Acc: 90.91%, Val-Class-Acc: {0: '82.28%', 1: '98.87%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.014552, Train-Class-Acc: {0: '99.30%', 1: '99.85%'}
# Val Loss: 0.240128, Val Acc: 94.43%, Val-Class-Acc: {0: '92.87%', 1: '95.86%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.010055, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.385102, Val Acc: 92.38%, Val-Class-Acc: {0: '85.34%', 1: '98.87%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.017322, Train-Class-Acc: {0: '99.46%', 1: '99.56%'}
# Val Loss: 0.416238, Val Acc: 92.18%, Val-Class-Acc: {0: '84.73%', 1: '99.06%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.015642, Train-Class-Acc: {0: '99.53%', 1: '99.27%'}
# Val Loss: 0.287147, Val Acc: 94.33%, Val-Class-Acc: {0: '91.65%', 1: '96.80%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.011719, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.261979, Val Acc: 94.33%, Val-Class-Acc: {0: '92.06%', 1: '96.43%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.012232, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.286233, Val Acc: 94.13%, Val-Class-Acc: {0: '90.63%', 1: '97.37%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.014131, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.646704, Val Acc: 88.56%, Val-Class-Acc: {0: '76.58%', 1: '99.62%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.011548, Train-Class-Acc: {0: '99.61%', 1: '99.93%'}
# Val Loss: 0.252029, Val Acc: 94.62%, Val-Class-Acc: {0: '92.67%', 1: '96.43%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.014710, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.865318, Val Acc: 84.56%, Val-Class-Acc: {0: '67.82%', 1: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.011689, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.386441, Val Acc: 91.98%, Val-Class-Acc: {0: '84.73%', 1: '98.68%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.013122, Train-Class-Acc: {0: '99.38%', 1: '99.64%'}
# Val Loss: 0.293579, Val Acc: 94.13%, Val-Class-Acc: {0: '90.02%', 1: '97.93%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.016073, Train-Class-Acc: {0: '99.69%', 1: '99.64%'}
# Val Loss: 0.295692, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.013545, Train-Class-Acc: {0: '99.77%', 1: '99.42%'}
# Val Loss: 0.326360, Val Acc: 93.55%, Val-Class-Acc: {0: '88.80%', 1: '97.93%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.012818, Train-Class-Acc: {0: '99.53%', 1: '99.49%'}
# Val Loss: 0.652133, Val Acc: 87.88%, Val-Class-Acc: {0: '74.95%', 1: '99.81%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.014800, Train-Class-Acc: {0: '99.46%', 1: '99.34%'}
# Val Loss: 0.550123, Val Acc: 89.15%, Val-Class-Acc: {0: '78.00%', 1: '99.44%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.010131, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.263248, Val Acc: 94.13%, Val-Class-Acc: {0: '93.08%', 1: '95.11%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.010317, Train-Class-Acc: {0: '99.61%', 1: '99.56%'}
# Val Loss: 0.408272, Val Acc: 92.38%, Val-Class-Acc: {0: '85.13%', 1: '99.06%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.017464, Train-Class-Acc: {0: '99.07%', 1: '99.78%'}
# Val Loss: 0.264732, Val Acc: 94.62%, Val-Class-Acc: {0: '91.04%', 1: '97.93%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.009491, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.363864, Val Acc: 93.35%, Val-Class-Acc: {0: '87.58%', 1: '98.68%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.017148, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.308462, Val Acc: 94.33%, Val-Class-Acc: {0: '90.84%', 1: '97.56%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.008052, Train-Class-Acc: {0: '99.92%', 1: '99.64%'}
# Val Loss: 0.317233, Val Acc: 93.94%, Val-Class-Acc: {0: '89.82%', 1: '97.74%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.011305, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.418591, Val Acc: 89.64%, Val-Class-Acc: {0: '96.95%', 1: '82.89%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.023092, Train-Class-Acc: {0: '99.38%', 1: '99.27%'}
# Val Loss: 0.535206, Val Acc: 90.42%, Val-Class-Acc: {0: '80.86%', 1: '99.25%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.015372, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.736082, Val Acc: 87.49%, Val-Class-Acc: {0: '74.54%', 1: '99.44%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.016607, Train-Class-Acc: {0: '99.38%', 1: '99.56%'}
# Val Loss: 0.294648, Val Acc: 93.06%, Val-Class-Acc: {0: '93.69%', 1: '92.48%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.013410, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.341915, Val Acc: 94.13%, Val-Class-Acc: {0: '90.63%', 1: '97.37%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.017857, Train-Class-Acc: {0: '99.46%', 1: '99.42%'}
# Val Loss: 0.358720, Val Acc: 93.45%, Val-Class-Acc: {0: '87.98%', 1: '98.50%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.014053, Train-Class-Acc: {0: '99.69%', 1: '99.49%'}
# Val Loss: 0.358192, Val Acc: 93.26%, Val-Class-Acc: {0: '86.97%', 1: '99.06%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.009856, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.269331, Val Acc: 94.82%, Val-Class-Acc: {0: '92.06%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_150.pth
# Epoch 151/1000, Train Loss: 0.012922, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.277956, Val Acc: 94.53%, Val-Class-Acc: {0: '91.45%', 1: '97.37%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.015497, Train-Class-Acc: {0: '99.69%', 1: '99.34%'}
# Val Loss: 0.256383, Val Acc: 94.92%, Val-Class-Acc: {0: '92.26%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_66.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_152.pth
# Epoch 153/1000, Train Loss: 0.020381, Train-Class-Acc: {0: '99.14%', 1: '99.49%'}
# Val Loss: 0.257536, Val Acc: 94.33%, Val-Class-Acc: {0: '91.24%', 1: '97.18%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.014840, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.293647, Val Acc: 94.13%, Val-Class-Acc: {0: '90.43%', 1: '97.56%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.010011, Train-Class-Acc: {0: '99.69%', 1: '100.00%'}
# Val Loss: 0.394198, Val Acc: 92.47%, Val-Class-Acc: {0: '85.54%', 1: '98.87%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.013208, Train-Class-Acc: {0: '99.53%', 1: '99.34%'}
# Val Loss: 0.273994, Val Acc: 94.23%, Val-Class-Acc: {0: '91.24%', 1: '96.99%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.013398, Train-Class-Acc: {0: '99.46%', 1: '99.71%'}
# Val Loss: 0.290402, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.006416, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.329533, Val Acc: 93.65%, Val-Class-Acc: {0: '89.00%', 1: '97.93%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.021311, Train-Class-Acc: {0: '99.38%', 1: '99.34%'}
# Val Loss: 0.659234, Val Acc: 88.07%, Val-Class-Acc: {0: '75.97%', 1: '99.25%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.016874, Train-Class-Acc: {0: '99.53%', 1: '99.42%'}
# Val Loss: 0.352621, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.012595, Train-Class-Acc: {0: '99.61%', 1: '99.78%'}
# Val Loss: 0.392722, Val Acc: 92.86%, Val-Class-Acc: {0: '86.35%', 1: '98.87%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.013971, Train-Class-Acc: {0: '99.69%', 1: '99.71%'}
# Val Loss: 0.380821, Val Acc: 92.96%, Val-Class-Acc: {0: '87.17%', 1: '98.31%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.017021, Train-Class-Acc: {0: '99.30%', 1: '99.85%'}
# Val Loss: 0.305252, Val Acc: 93.74%, Val-Class-Acc: {0: '90.63%', 1: '96.62%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.010836, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.303725, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.015418, Train-Class-Acc: {0: '99.30%', 1: '99.64%'}
# Val Loss: 0.653050, Val Acc: 87.59%, Val-Class-Acc: {0: '74.54%', 1: '99.62%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.010219, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.260418, Val Acc: 93.45%, Val-Class-Acc: {0: '94.09%', 1: '92.86%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.009246, Train-Class-Acc: {0: '99.53%', 1: '99.85%'}
# Val Loss: 0.290406, Val Acc: 94.33%, Val-Class-Acc: {0: '91.45%', 1: '96.99%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.009954, Train-Class-Acc: {0: '99.84%', 1: '99.56%'}
# Val Loss: 0.244350, Val Acc: 94.04%, Val-Class-Acc: {0: '93.08%', 1: '94.92%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.011993, Train-Class-Acc: {0: '99.53%', 1: '99.71%'}
# Val Loss: 0.294881, Val Acc: 94.23%, Val-Class-Acc: {0: '91.45%', 1: '96.80%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.014383, Train-Class-Acc: {0: '99.46%', 1: '99.56%'}
# Val Loss: 0.280887, Val Acc: 93.16%, Val-Class-Acc: {0: '95.52%', 1: '90.98%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.014714, Train-Class-Acc: {0: '99.69%', 1: '99.49%'}
# Val Loss: 0.340799, Val Acc: 93.74%, Val-Class-Acc: {0: '88.39%', 1: '98.68%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.009661, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.303038, Val Acc: 93.94%, Val-Class-Acc: {0: '89.82%', 1: '97.74%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.008067, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.299407, Val Acc: 93.55%, Val-Class-Acc: {0: '91.65%', 1: '95.30%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.007756, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.294168, Val Acc: 93.94%, Val-Class-Acc: {0: '90.22%', 1: '97.37%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.006740, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.296384, Val Acc: 93.65%, Val-Class-Acc: {0: '89.00%', 1: '97.93%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.009993, Train-Class-Acc: {0: '99.77%', 1: '99.78%'}
# Val Loss: 0.289336, Val Acc: 94.53%, Val-Class-Acc: {0: '90.84%', 1: '97.93%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.014310, Train-Class-Acc: {0: '99.46%', 1: '99.64%'}
# Val Loss: 0.341985, Val Acc: 93.06%, Val-Class-Acc: {0: '87.17%', 1: '98.50%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.006479, Train-Class-Acc: {0: '100.00%', 1: '99.71%'}
# Val Loss: 0.318896, Val Acc: 93.74%, Val-Class-Acc: {0: '89.21%', 1: '97.93%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.011141, Train-Class-Acc: {0: '99.61%', 1: '99.71%'}
# Val Loss: 0.287570, Val Acc: 94.43%, Val-Class-Acc: {0: '91.04%', 1: '97.56%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.005429, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.290245, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.009640, Train-Class-Acc: {0: '99.61%', 1: '99.78%'}
# Val Loss: 0.263831, Val Acc: 94.82%, Val-Class-Acc: {0: '93.08%', 1: '96.43%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_81.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_181.pth
# Epoch 182/1000, Train Loss: 0.009637, Train-Class-Acc: {0: '99.69%', 1: '99.56%'}
# Val Loss: 0.333972, Val Acc: 93.45%, Val-Class-Acc: {0: '87.78%', 1: '98.68%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.006483, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.339379, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.007733, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.316005, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.009447, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.287116, Val Acc: 94.43%, Val-Class-Acc: {0: '91.65%', 1: '96.99%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.013318, Train-Class-Acc: {0: '99.53%', 1: '99.56%'}
# Val Loss: 0.259092, Val Acc: 94.62%, Val-Class-Acc: {0: '93.69%', 1: '95.49%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.006160, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.260270, Val Acc: 94.53%, Val-Class-Acc: {0: '92.06%', 1: '96.80%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.009358, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.272224, Val Acc: 94.53%, Val-Class-Acc: {0: '93.69%', 1: '95.30%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.011281, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.399679, Val Acc: 92.47%, Val-Class-Acc: {0: '85.13%', 1: '99.25%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.010591, Train-Class-Acc: {0: '100.00%', 1: '99.56%'}
# Val Loss: 0.327238, Val Acc: 93.74%, Val-Class-Acc: {0: '88.80%', 1: '98.31%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.007168, Train-Class-Acc: {0: '99.61%', 1: '100.00%'}
# Val Loss: 0.266716, Val Acc: 94.82%, Val-Class-Acc: {0: '92.46%', 1: '96.99%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.012119, Train-Class-Acc: {0: '99.30%', 1: '99.85%'}
# Val Loss: 0.223691, Val Acc: 94.82%, Val-Class-Acc: {0: '93.08%', 1: '96.43%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.014614, Train-Class-Acc: {0: '100.00%', 1: '99.27%'}
# Val Loss: 0.368225, Val Acc: 89.64%, Val-Class-Acc: {0: '97.96%', 1: '81.95%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.012553, Train-Class-Acc: {0: '99.61%', 1: '99.64%'}
# Val Loss: 0.286181, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 195/1000, Train Loss: 0.010285, Train-Class-Acc: {0: '99.77%', 1: '99.56%'}
# Val Loss: 0.225305, Val Acc: 94.53%, Val-Class-Acc: {0: '93.89%', 1: '95.11%'}, LR: 0.000100
# Epoch 196/1000, Train Loss: 0.015905, Train-Class-Acc: {0: '99.69%', 1: '99.42%'}
# Val Loss: 0.321171, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 197/1000, Train Loss: 0.012858, Train-Class-Acc: {0: '99.30%', 1: '99.78%'}
# Val Loss: 0.371128, Val Acc: 93.26%, Val-Class-Acc: {0: '87.37%', 1: '98.68%'}, LR: 0.000100
# Epoch 198/1000, Train Loss: 0.007364, Train-Class-Acc: {0: '99.69%', 1: '99.93%'}
# Val Loss: 0.283522, Val Acc: 94.72%, Val-Class-Acc: {0: '92.06%', 1: '97.18%'}, LR: 0.000100
# Epoch 199/1000, Train Loss: 0.009035, Train-Class-Acc: {0: '99.69%', 1: '99.49%'}
# Val Loss: 0.264296, Val Acc: 94.92%, Val-Class-Acc: {0: '94.09%', 1: '95.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_108.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_199.pth
# Epoch 200/1000, Train Loss: 0.007362, Train-Class-Acc: {0: '99.84%', 1: '99.56%'}
# Val Loss: 0.409404, Val Acc: 92.28%, Val-Class-Acc: {0: '84.93%', 1: '99.06%'}, LR: 0.000100
# Epoch 201/1000, Train Loss: 0.005629, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.401888, Val Acc: 92.67%, Val-Class-Acc: {0: '85.74%', 1: '99.06%'}, LR: 0.000100
# Epoch 202/1000, Train Loss: 0.007476, Train-Class-Acc: {0: '99.69%', 1: '99.93%'}
# Val Loss: 0.247078, Val Acc: 94.82%, Val-Class-Acc: {0: '93.89%', 1: '95.68%'}, LR: 0.000100
# Epoch 203/1000, Train Loss: 0.012606, Train-Class-Acc: {0: '99.46%', 1: '99.64%'}
# Val Loss: 0.325244, Val Acc: 94.33%, Val-Class-Acc: {0: '90.02%', 1: '98.31%'}, LR: 0.000100
# Epoch 204/1000, Train Loss: 0.007092, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.370135, Val Acc: 94.23%, Val-Class-Acc: {0: '89.82%', 1: '98.31%'}, LR: 0.000100
# Epoch 205/1000, Train Loss: 0.008947, Train-Class-Acc: {0: '99.77%', 1: '99.71%'}
# Val Loss: 0.274476, Val Acc: 93.84%, Val-Class-Acc: {0: '94.50%', 1: '93.23%'}, LR: 0.000100
# Epoch 206/1000, Train Loss: 0.008888, Train-Class-Acc: {0: '99.53%', 1: '99.78%'}
# Val Loss: 0.289952, Val Acc: 94.62%, Val-Class-Acc: {0: '92.87%', 1: '96.24%'}, LR: 0.000100
# Epoch 207/1000, Train Loss: 0.005376, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.297443, Val Acc: 94.43%, Val-Class-Acc: {0: '93.69%', 1: '95.11%'}, LR: 0.000100
# Epoch 208/1000, Train Loss: 0.008794, Train-Class-Acc: {0: '99.69%', 1: '99.71%'}
# Val Loss: 0.310508, Val Acc: 94.72%, Val-Class-Acc: {0: '91.04%', 1: '98.12%'}, LR: 0.000100
# Epoch 209/1000, Train Loss: 0.005887, Train-Class-Acc: {0: '99.69%', 1: '100.00%'}
# Val Loss: 0.264326, Val Acc: 95.01%, Val-Class-Acc: {0: '92.06%', 1: '97.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_111.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_209.pth
# Epoch 210/1000, Train Loss: 0.006177, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.330098, Val Acc: 94.43%, Val-Class-Acc: {0: '90.02%', 1: '98.50%'}, LR: 0.000100
# Epoch 211/1000, Train Loss: 0.007841, Train-Class-Acc: {0: '99.61%', 1: '99.85%'}
# Val Loss: 0.301758, Val Acc: 95.41%, Val-Class-Acc: {0: '92.06%', 1: '98.50%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_150.pth
# ...
# Epoch 926/1000, Train Loss: 0.002529, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.403242, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 927/1000, Train Loss: 0.002317, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.334794, Val Acc: 94.82%, Val-Class-Acc: {0: '92.46%', 1: '96.99%'}, LR: 0.000100
# Epoch 928/1000, Train Loss: 0.003149, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.471695, Val Acc: 92.18%, Val-Class-Acc: {0: '85.13%', 1: '98.68%'}, LR: 0.000100
# Epoch 929/1000, Train Loss: 0.002427, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.315807, Val Acc: 95.01%, Val-Class-Acc: {0: '93.28%', 1: '96.62%'}, LR: 0.000100
# Epoch 930/1000, Train Loss: 0.009613, Train-Class-Acc: {0: '99.77%', 1: '100.00%'}
# Val Loss: 0.727554, Val Acc: 89.44%, Val-Class-Acc: {0: '78.82%', 1: '99.25%'}, LR: 0.000100
# Epoch 931/1000, Train Loss: 0.005863, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.360324, Val Acc: 94.92%, Val-Class-Acc: {0: '94.30%', 1: '95.49%'}, LR: 0.000100
# Epoch 932/1000, Train Loss: 0.001738, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.413379, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 933/1000, Train Loss: 0.004833, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.371340, Val Acc: 94.72%, Val-Class-Acc: {0: '92.06%', 1: '97.18%'}, LR: 0.000100
# Epoch 934/1000, Train Loss: 0.004170, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.350930, Val Acc: 94.53%, Val-Class-Acc: {0: '92.06%', 1: '96.80%'}, LR: 0.000100
# Epoch 935/1000, Train Loss: 0.003598, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.388680, Val Acc: 93.74%, Val-Class-Acc: {0: '89.61%', 1: '97.56%'}, LR: 0.000100
# Epoch 936/1000, Train Loss: 0.003808, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.421161, Val Acc: 93.55%, Val-Class-Acc: {0: '88.59%', 1: '98.12%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.004247, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.412987, Val Acc: 93.55%, Val-Class-Acc: {0: '88.59%', 1: '98.12%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.002700, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.365138, Val Acc: 94.33%, Val-Class-Acc: {0: '90.43%', 1: '97.93%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.009855, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.465354, Val Acc: 93.06%, Val-Class-Acc: {0: '87.17%', 1: '98.50%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.003338, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.364443, Val Acc: 94.53%, Val-Class-Acc: {0: '91.85%', 1: '96.99%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.006996, Train-Class-Acc: {0: '99.61%', 1: '99.78%'}
# Val Loss: 0.338005, Val Acc: 94.23%, Val-Class-Acc: {0: '93.69%', 1: '94.74%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.003970, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.362093, Val Acc: 94.53%, Val-Class-Acc: {0: '92.06%', 1: '96.80%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.002932, Train-Class-Acc: {0: '99.92%', 1: '100.00%'}
# Val Loss: 0.875863, Val Acc: 86.22%, Val-Class-Acc: {0: '71.89%', 1: '99.44%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.003913, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.358975, Val Acc: 94.62%, Val-Class-Acc: {0: '91.04%', 1: '97.93%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.003283, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.379226, Val Acc: 94.13%, Val-Class-Acc: {0: '89.82%', 1: '98.12%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.011972, Train-Class-Acc: {0: '99.38%', 1: '100.00%'}
# Val Loss: 0.317071, Val Acc: 94.92%, Val-Class-Acc: {0: '93.48%', 1: '96.24%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.006518, Train-Class-Acc: {0: '99.77%', 1: '99.85%'}
# Val Loss: 0.323999, Val Acc: 95.01%, Val-Class-Acc: {0: '93.28%', 1: '96.62%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.008686, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.441950, Val Acc: 93.26%, Val-Class-Acc: {0: '87.78%', 1: '98.31%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.003044, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.399379, Val Acc: 93.35%, Val-Class-Acc: {0: '88.39%', 1: '97.93%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.002454, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.372560, Val Acc: 94.43%, Val-Class-Acc: {0: '90.84%', 1: '97.74%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.004920, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.366156, Val Acc: 94.72%, Val-Class-Acc: {0: '92.67%', 1: '96.62%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.003203, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.355652, Val Acc: 94.62%, Val-Class-Acc: {0: '91.85%', 1: '97.18%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.003261, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.387433, Val Acc: 94.04%, Val-Class-Acc: {0: '90.02%', 1: '97.74%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.003838, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.414456, Val Acc: 92.67%, Val-Class-Acc: {0: '86.76%', 1: '98.12%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.007222, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.366704, Val Acc: 93.94%, Val-Class-Acc: {0: '91.04%', 1: '96.62%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.007147, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.436678, Val Acc: 93.06%, Val-Class-Acc: {0: '87.78%', 1: '97.93%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.004350, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.351207, Val Acc: 94.13%, Val-Class-Acc: {0: '92.46%', 1: '95.68%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.006214, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.374859, Val Acc: 93.94%, Val-Class-Acc: {0: '89.61%', 1: '97.93%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.004481, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.419917, Val Acc: 93.45%, Val-Class-Acc: {0: '88.39%', 1: '98.12%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.005806, Train-Class-Acc: {0: '99.69%', 1: '100.00%'}
# Val Loss: 0.330992, Val Acc: 94.13%, Val-Class-Acc: {0: '94.30%', 1: '93.98%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.003249, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.354147, Val Acc: 94.82%, Val-Class-Acc: {0: '91.85%', 1: '97.56%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.006285, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.466384, Val Acc: 93.06%, Val-Class-Acc: {0: '86.35%', 1: '99.25%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.004331, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.359640, Val Acc: 94.13%, Val-Class-Acc: {0: '89.21%', 1: '98.68%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.002820, Train-Class-Acc: {0: '99.84%', 1: '100.00%'}
# Val Loss: 0.399568, Val Acc: 94.33%, Val-Class-Acc: {0: '89.82%', 1: '98.50%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.003224, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.387661, Val Acc: 94.43%, Val-Class-Acc: {0: '90.22%', 1: '98.31%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.003160, Train-Class-Acc: {0: '100.00%', 1: '99.71%'}
# Val Loss: 0.364201, Val Acc: 94.53%, Val-Class-Acc: {0: '90.22%', 1: '98.50%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.002042, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.330838, Val Acc: 94.92%, Val-Class-Acc: {0: '92.06%', 1: '97.56%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.002081, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.390107, Val Acc: 93.74%, Val-Class-Acc: {0: '89.00%', 1: '98.12%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.005472, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.528840, Val Acc: 91.98%, Val-Class-Acc: {0: '84.11%', 1: '99.25%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.003237, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.374102, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.005273, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.364411, Val Acc: 94.92%, Val-Class-Acc: {0: '91.65%', 1: '97.93%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.002518, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.373639, Val Acc: 94.62%, Val-Class-Acc: {0: '92.06%', 1: '96.99%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.006110, Train-Class-Acc: {0: '99.69%', 1: '99.78%'}
# Val Loss: 0.322263, Val Acc: 95.41%, Val-Class-Acc: {0: '93.28%', 1: '97.37%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_807.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_973.pth
# Epoch 974/1000, Train Loss: 0.002902, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.349350, Val Acc: 94.62%, Val-Class-Acc: {0: '91.45%', 1: '97.56%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.007396, Train-Class-Acc: {0: '99.92%', 1: '99.64%'}
# Val Loss: 0.585425, Val Acc: 90.52%, Val-Class-Acc: {0: '80.86%', 1: '99.44%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.005839, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.348530, Val Acc: 95.01%, Val-Class-Acc: {0: '93.28%', 1: '96.62%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.004239, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.349776, Val Acc: 94.62%, Val-Class-Acc: {0: '92.06%', 1: '96.99%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.002886, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.314275, Val Acc: 95.11%, Val-Class-Acc: {0: '94.09%', 1: '96.05%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.005557, Train-Class-Acc: {0: '99.84%', 1: '99.93%'}
# Val Loss: 0.321598, Val Acc: 94.62%, Val-Class-Acc: {0: '94.50%', 1: '94.74%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.002042, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.373407, Val Acc: 94.53%, Val-Class-Acc: {0: '90.84%', 1: '97.93%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.004054, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.336605, Val Acc: 94.72%, Val-Class-Acc: {0: '91.85%', 1: '97.37%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.003781, Train-Class-Acc: {0: '99.69%', 1: '99.93%'}
# Val Loss: 0.415825, Val Acc: 94.43%, Val-Class-Acc: {0: '90.22%', 1: '98.31%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.001321, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.352360, Val Acc: 94.92%, Val-Class-Acc: {0: '92.46%', 1: '97.18%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.005913, Train-Class-Acc: {0: '100.00%', 1: '99.85%'}
# Val Loss: 0.368964, Val Acc: 94.62%, Val-Class-Acc: {0: '91.45%', 1: '97.56%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.005546, Train-Class-Acc: {0: '100.00%', 1: '99.78%'}
# Val Loss: 0.437305, Val Acc: 93.45%, Val-Class-Acc: {0: '88.19%', 1: '98.31%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.006980, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.311895, Val Acc: 95.01%, Val-Class-Acc: {0: '93.69%', 1: '96.24%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.005172, Train-Class-Acc: {0: '99.92%', 1: '99.78%'}
# Val Loss: 0.338921, Val Acc: 95.01%, Val-Class-Acc: {0: '92.46%', 1: '97.37%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.004519, Train-Class-Acc: {0: '99.61%', 1: '100.00%'}
# Val Loss: 0.316085, Val Acc: 95.01%, Val-Class-Acc: {0: '92.87%', 1: '96.99%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.002638, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.355853, Val Acc: 94.13%, Val-Class-Acc: {0: '90.22%', 1: '97.74%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.004582, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.303217, Val Acc: 94.43%, Val-Class-Acc: {0: '92.87%', 1: '95.86%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.005062, Train-Class-Acc: {0: '99.84%', 1: '99.78%'}
# Val Loss: 0.403739, Val Acc: 93.55%, Val-Class-Acc: {0: '87.98%', 1: '98.68%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.002595, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.407896, Val Acc: 93.74%, Val-Class-Acc: {0: '88.59%', 1: '98.50%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.005177, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.347382, Val Acc: 94.23%, Val-Class-Acc: {0: '90.22%', 1: '97.93%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.003512, Train-Class-Acc: {0: '99.92%', 1: '99.85%'}
# Val Loss: 0.369851, Val Acc: 94.13%, Val-Class-Acc: {0: '89.61%', 1: '98.31%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.004428, Train-Class-Acc: {0: '99.77%', 1: '99.93%'}
# Val Loss: 0.373629, Val Acc: 93.94%, Val-Class-Acc: {0: '89.21%', 1: '98.31%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.001982, Train-Class-Acc: {0: '100.00%', 1: '99.93%'}
# Val Loss: 0.349271, Val Acc: 94.33%, Val-Class-Acc: {0: '90.22%', 1: '98.12%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.003009, Train-Class-Acc: {0: '99.92%', 1: '99.93%'}
# Val Loss: 0.318678, Val Acc: 95.11%, Val-Class-Acc: {0: '92.46%', 1: '97.56%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.001927, Train-Class-Acc: {0: '100.00%', 1: '100.00%'}
# Val Loss: 0.393818, Val Acc: 94.04%, Val-Class-Acc: {0: '89.41%', 1: '98.31%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.004997, Train-Class-Acc: {0: '99.84%', 1: '99.85%'}
# Val Loss: 0.547079, Val Acc: 90.91%, Val-Class-Acc: {0: '82.48%', 1: '98.68%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.006740, Train-Class-Acc: {0: '99.92%', 1: '99.71%'}
# Val Loss: 0.415298, Val Acc: 93.55%, Val-Class-Acc: {0: '88.59%', 1: '98.12%'}, LR: 0.000100
#
# ⏳ Total training time: 561.36 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_best.pth (Val Accuracy: 95.41%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 973, Train Loss: 0.006110, Train-Acc: {0: '99.69%', 1: '99.78%'},
# Val Loss: 0.322263, Val Acc: 95.41%, Val-Acc: {0: '93.28%', 1: '97.37%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_973.pth
# Epoch 211, Train Loss: 0.007841, Train-Acc: {0: '99.61%', 1: '99.85%'},
# Val Loss: 0.301758, Val Acc: 95.41%, Val-Acc: {0: '92.06%', 1: '98.50%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_211.pth
# Epoch 896, Train Loss: 0.002194, Train-Acc: {0: '100.00%', 1: '99.93%'},
# Val Loss: 0.324048, Val Acc: 95.31%, Val-Acc: {0: '93.28%', 1: '97.18%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_896.pth
# Epoch 889, Train Loss: 0.002812, Train-Acc: {0: '99.77%', 1: '100.00%'},
# Val Loss: 0.292213, Val Acc: 95.31%, Val-Acc: {0: '93.69%', 1: '96.80%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_889.pth
# Epoch 885, Train Loss: 0.002953, Train-Acc: {0: '99.92%', 1: '99.85%'},
# Val Loss: 0.314130, Val Acc: 95.31%, Val-Acc: {0: '93.48%', 1: '96.99%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1/HAR_MLP_LoRA_v2_epoch_885.pth
# ---
# ### Period 1
# + ##### Total training time: 561.36 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_1'*
# + ##### Best Epoch: 973
# #### __Val Accuracy: 95.41%__
# #### __Val-Class-Acc: {0: '93.28%', 1: '97.37%'}__
#
# ✅ Period 1 Training Complete. Final model architecture:
# HAR_MLP_LoRA_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=2, bias=True)
# )
# 📊 Class Summary → unique_classes = [0 1], num_classes = 2

# %% [markdown]
# ---
# ### Period 2
# + ##### Total training time: 690.63 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2'*
# + ##### Best Epoch: 332
# #### __Val Accuracy: 97.59%__
# #### __Val-Class-Acc: {0: '91.45%', 1: '96.99%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 2 Configuration - HAR_MLP_LoRA_v2 (Standard LoRA)
# ================================
period = 2

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Model hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
lora_r        = 4
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000

# Model saving path
model_name = "HAR_MLP_LoRA_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Load previous model (Period 1) ===
previous_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period - 1}", f"{model_name}_best.pth"
)
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# === Initialize new model (HAR_MLP_LoRA_v2) ===
model = HAR_MLP_LoRA_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

# === Load weights (exclude fc3 & lora_adapter) ===
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc3") and not k.startswith("lora_adapter")
}, strict=False)

# === Initialize LoRA (首次啟用) ===
model.init_lora()

# === Optimizer / Criterion / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.get_trainable_parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Training ===
train_with_standard_lora(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, checkpoint, previous_state_dict
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 27821 MiB
#     - Device Name    : NVIDIA RTX A6000
# /tmp/ipykernel_2234450/3126426129.py:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# ✅ Initialized LoRA adapter for fc2
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc3.weight
#   ✅ fc3.bias
#
# 🚀 'train_with_standard_lora' started for Period 2
#
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 27823 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# ✅ Data Overview:
# X_train: torch.Size([5945, 561]), y_train: torch.Size([5945])
# X_val: torch.Size([2410, 561]), y_val: torch.Size([2410])
#
# 🔧 Model Parameter Overview:
# fc1.weight                                         | ✅ trainable  | shape=[128, 561]
# fc1.bias                                           | ✅ trainable  | shape=[128]
# bn1.weight                                         | ✅ trainable  | shape=[128]
# bn1.bias                                           | ✅ trainable  | shape=[128]
# fc2.weight                                         | ✅ trainable  | shape=[128, 128]
# fc2.bias                                           | ✅ trainable  | shape=[128]
# bn2.weight                                         | ✅ trainable  | shape=[128]
# bn2.bias                                           | ✅ trainable  | shape=[128]
# fc3.weight                                         | ✅ trainable  | shape=[3, 128]
# fc3.bias                                           | ✅ trainable  | shape=[3]
# lora_adapter.A                                     | ✅ trainable  | shape=[128, 4]
# lora_adapter.B                                     | ✅ trainable  | shape=[4, 128]
#
# 🧠 Optimizer Parameter Overview:
# lora_adapter.A                                     | ✅ from optimizer | shape=[128, 4]
# lora_adapter.B                                     | ✅ from optimizer | shape=[4, 128]
# fc3.weight                                         | ✅ from optimizer | shape=[3, 128]
# fc3.bias                                           | ✅ from optimizer | shape=[3]
#
# ================================================================================
#
# Epoch 1/1000, Train Loss: 0.861429, Train-Class-Acc: {0: '37.40%', 1: '56.84%', 2: '71.45%'}
# Val Loss: 0.435099, Val Acc: 91.45%, Val-Class-Acc: {0: '73.12%', 1: '87.78%', 2: '99.35%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.404525, Train-Class-Acc: {0: '74.81%', 1: '77.66%', 2: '96.86%'}
# Val Loss: 0.277298, Val Acc: 94.85%, Val-Class-Acc: {0: '80.65%', 1: '94.92%', 2: '99.86%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.263816, Train-Class-Acc: {0: '86.47%', 1: '85.37%', 2: '99.21%'}
# Val Loss: 0.200280, Val Acc: 96.56%, Val-Class-Acc: {0: '88.19%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.198649, Train-Class-Acc: {0: '88.88%', 1: '90.39%', 2: '99.39%'}
# Val Loss: 0.163811, Val Acc: 96.64%, Val-Class-Acc: {0: '88.39%', 1: '95.49%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.153519, Train-Class-Acc: {0: '92.92%', 1: '92.29%', 2: '99.57%'}
# Val Loss: 0.133584, Val Acc: 96.89%, Val-Class-Acc: {0: '89.41%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.132679, Train-Class-Acc: {0: '92.38%', 1: '92.50%', 2: '99.73%'}
# Val Loss: 0.119972, Val Acc: 96.93%, Val-Class-Acc: {0: '88.19%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.113869, Train-Class-Acc: {0: '93.70%', 1: '94.10%', 2: '99.73%'}
# Val Loss: 0.104059, Val Acc: 97.01%, Val-Class-Acc: {0: '91.45%', 1: '94.36%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.102881, Train-Class-Acc: {0: '94.01%', 1: '94.76%', 2: '99.73%'}
# Val Loss: 0.100627, Val Acc: 97.22%, Val-Class-Acc: {0: '90.63%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.097814, Train-Class-Acc: {0: '94.87%', 1: '95.20%', 2: '99.85%'}
# Val Loss: 0.104305, Val Acc: 96.60%, Val-Class-Acc: {0: '86.15%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 10/1000, Train Loss: 0.082902, Train-Class-Acc: {0: '95.02%', 1: '94.18%', 2: '99.94%'}
# Val Loss: 0.101045, Val Acc: 96.72%, Val-Class-Acc: {0: '86.56%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.078799, Train-Class-Acc: {0: '94.40%', 1: '95.71%', 2: '99.82%'}
# Val Loss: 0.088442, Val Acc: 97.30%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.076856, Train-Class-Acc: {0: '95.33%', 1: '95.63%', 2: '99.88%'}
# Val Loss: 0.089153, Val Acc: 97.05%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.072332, Train-Class-Acc: {0: '95.26%', 1: '95.41%', 2: '99.85%'}
# Val Loss: 0.087564, Val Acc: 97.18%, Val-Class-Acc: {0: '90.02%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.065630, Train-Class-Acc: {0: '95.88%', 1: '95.41%', 2: '99.94%'}
# Val Loss: 0.094460, Val Acc: 96.89%, Val-Class-Acc: {0: '87.58%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 15/1000, Train Loss: 0.066564, Train-Class-Acc: {0: '95.96%', 1: '96.14%', 2: '99.85%'}
# Val Loss: 0.088023, Val Acc: 97.05%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.057383, Train-Class-Acc: {0: '96.27%', 1: '95.92%', 2: '99.88%'}
# Val Loss: 0.090154, Val Acc: 97.01%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 17/1000, Train Loss: 0.062913, Train-Class-Acc: {0: '95.96%', 1: '95.56%', 2: '99.48%'}
# Val Loss: 0.087426, Val Acc: 97.05%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.054382, Train-Class-Acc: {0: '96.73%', 1: '96.43%', 2: '99.97%'}
# Val Loss: 0.085373, Val Acc: 97.26%, Val-Class-Acc: {0: '90.02%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.051097, Train-Class-Acc: {0: '96.50%', 1: '96.87%', 2: '99.85%'}
# Val Loss: 0.089288, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 20/1000, Train Loss: 0.054197, Train-Class-Acc: {0: '95.96%', 1: '96.29%', 2: '99.97%'}
# Val Loss: 0.085951, Val Acc: 97.22%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.056791, Train-Class-Acc: {0: '95.41%', 1: '96.22%', 2: '99.82%'}
# Val Loss: 0.093499, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.049453, Train-Class-Acc: {0: '96.27%', 1: '96.14%', 2: '99.97%'}
# Val Loss: 0.087544, Val Acc: 97.22%, Val-Class-Acc: {0: '90.43%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.052404, Train-Class-Acc: {0: '95.41%', 1: '96.36%', 2: '99.82%'}
# Val Loss: 0.090514, Val Acc: 96.93%, Val-Class-Acc: {0: '87.98%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 24/1000, Train Loss: 0.048517, Train-Class-Acc: {0: '96.73%', 1: '96.14%', 2: '99.76%'}
# Val Loss: 0.107721, Val Acc: 96.64%, Val-Class-Acc: {0: '85.13%', 1: '98.50%', 2: '100.00%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.045194, Train-Class-Acc: {0: '96.66%', 1: '97.09%', 2: '99.88%'}
# Val Loss: 0.089208, Val Acc: 97.14%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 26/1000, Train Loss: 0.041464, Train-Class-Acc: {0: '97.74%', 1: '96.94%', 2: '99.97%'}
# Val Loss: 0.090294, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.042690, Train-Class-Acc: {0: '96.66%', 1: '97.38%', 2: '99.82%'}
# Val Loss: 0.083845, Val Acc: 97.22%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.045361, Train-Class-Acc: {0: '96.97%', 1: '96.51%', 2: '99.70%'}
# Val Loss: 0.088013, Val Acc: 97.34%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.041061, Train-Class-Acc: {0: '97.20%', 1: '96.94%', 2: '99.94%'}
# Val Loss: 0.093189, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.042470, Train-Class-Acc: {0: '96.97%', 1: '96.94%', 2: '99.82%'}
# Val Loss: 0.091991, Val Acc: 97.05%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.043236, Train-Class-Acc: {0: '96.58%', 1: '96.14%', 2: '99.97%'}
# Val Loss: 0.097566, Val Acc: 96.89%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 32/1000, Train Loss: 0.043422, Train-Class-Acc: {0: '96.03%', 1: '97.02%', 2: '99.91%'}
# Val Loss: 0.086964, Val Acc: 97.22%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.042168, Train-Class-Acc: {0: '96.73%', 1: '96.94%', 2: '99.79%'}
# Val Loss: 0.091031, Val Acc: 97.18%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.039509, Train-Class-Acc: {0: '97.12%', 1: '96.72%', 2: '99.94%'}
# Val Loss: 0.101463, Val Acc: 96.80%, Val-Class-Acc: {0: '86.76%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.038489, Train-Class-Acc: {0: '97.74%', 1: '97.16%', 2: '99.94%'}
# Val Loss: 0.087185, Val Acc: 97.26%, Val-Class-Acc: {0: '91.65%', 1: '95.30%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_35.pth
# Epoch 36/1000, Train Loss: 0.037049, Train-Class-Acc: {0: '97.51%', 1: '96.87%', 2: '99.94%'}
# Val Loss: 0.089536, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.036361, Train-Class-Acc: {0: '97.20%', 1: '97.23%', 2: '99.91%'}
# Val Loss: 0.092887, Val Acc: 97.30%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_37.pth
# Epoch 38/1000, Train Loss: 0.039713, Train-Class-Acc: {0: '97.36%', 1: '96.94%', 2: '99.91%'}
# Val Loss: 0.093377, Val Acc: 97.34%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_35.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.039179, Train-Class-Acc: {0: '96.73%', 1: '96.94%', 2: '99.91%'}
# Val Loss: 0.102582, Val Acc: 96.80%, Val-Class-Acc: {0: '86.76%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.032506, Train-Class-Acc: {0: '97.51%', 1: '97.53%', 2: '99.88%'}
# Val Loss: 0.094882, Val Acc: 97.26%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.033807, Train-Class-Acc: {0: '97.67%', 1: '96.87%', 2: '99.97%'}
# Val Loss: 0.100586, Val Acc: 96.85%, Val-Class-Acc: {0: '87.37%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.033072, Train-Class-Acc: {0: '97.51%', 1: '97.53%', 2: '99.94%'}
# Val Loss: 0.104179, Val Acc: 96.89%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.035597, Train-Class-Acc: {0: '97.43%', 1: '97.53%', 2: '99.88%'}
# Val Loss: 0.102931, Val Acc: 96.85%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 44/1000, Train Loss: 0.042463, Train-Class-Acc: {0: '96.50%', 1: '97.02%', 2: '99.79%'}
# Val Loss: 0.099860, Val Acc: 96.80%, Val-Class-Acc: {0: '88.39%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.035718, Train-Class-Acc: {0: '97.05%', 1: '97.89%', 2: '99.85%'}
# Val Loss: 0.093558, Val Acc: 97.18%, Val-Class-Acc: {0: '90.22%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.032388, Train-Class-Acc: {0: '97.59%', 1: '96.58%', 2: '99.97%'}
# Val Loss: 0.100214, Val Acc: 96.97%, Val-Class-Acc: {0: '87.98%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 47/1000, Train Loss: 0.035331, Train-Class-Acc: {0: '97.43%', 1: '97.16%', 2: '99.79%'}
# Val Loss: 0.098012, Val Acc: 96.93%, Val-Class-Acc: {0: '88.19%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 48/1000, Train Loss: 0.029421, Train-Class-Acc: {0: '98.06%', 1: '97.82%', 2: '99.91%'}
# Val Loss: 0.101516, Val Acc: 97.01%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.034280, Train-Class-Acc: {0: '97.28%', 1: '97.53%', 2: '99.94%'}
# Val Loss: 0.120209, Val Acc: 96.80%, Val-Class-Acc: {0: '85.54%', 1: '98.87%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.035858, Train-Class-Acc: {0: '97.51%', 1: '97.38%', 2: '99.82%'}
# Val Loss: 0.101897, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.042766, Train-Class-Acc: {0: '96.81%', 1: '96.07%', 2: '99.94%'}
# Val Loss: 0.101519, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.038387, Train-Class-Acc: {0: '96.50%', 1: '96.72%', 2: '99.85%'}
# Val Loss: 0.098463, Val Acc: 97.18%, Val-Class-Acc: {0: '90.22%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 53/1000, Train Loss: 0.031046, Train-Class-Acc: {0: '97.28%', 1: '97.60%', 2: '99.97%'}
# Val Loss: 0.111346, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.034017, Train-Class-Acc: {0: '96.97%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.099775, Val Acc: 97.18%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.035663, Train-Class-Acc: {0: '97.05%', 1: '97.31%', 2: '99.85%'}
# Val Loss: 0.097154, Val Acc: 97.26%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.027293, Train-Class-Acc: {0: '98.21%', 1: '97.67%', 2: '100.00%'}
# Val Loss: 0.099141, Val Acc: 97.22%, Val-Class-Acc: {0: '90.84%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.034423, Train-Class-Acc: {0: '97.90%', 1: '97.53%', 2: '99.82%'}
# Val Loss: 0.103225, Val Acc: 96.97%, Val-Class-Acc: {0: '88.59%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.034882, Train-Class-Acc: {0: '97.82%', 1: '97.38%', 2: '99.79%'}
# Val Loss: 0.103302, Val Acc: 97.10%, Val-Class-Acc: {0: '89.61%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.033528, Train-Class-Acc: {0: '97.74%', 1: '97.23%', 2: '99.88%'}
# Val Loss: 0.110446, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.036785, Train-Class-Acc: {0: '97.05%', 1: '97.67%', 2: '99.85%'}
# Val Loss: 0.098735, Val Acc: 97.39%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_60.pth
# Epoch 61/1000, Train Loss: 0.028553, Train-Class-Acc: {0: '97.43%', 1: '97.67%', 2: '99.94%'}
# Val Loss: 0.118506, Val Acc: 96.72%, Val-Class-Acc: {0: '86.35%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.035617, Train-Class-Acc: {0: '96.89%', 1: '97.60%', 2: '99.82%'}
# Val Loss: 0.105493, Val Acc: 97.01%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.031183, Train-Class-Acc: {0: '97.59%', 1: '97.31%', 2: '99.82%'}
# Val Loss: 0.103846, Val Acc: 97.14%, Val-Class-Acc: {0: '89.61%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.033538, Train-Class-Acc: {0: '96.58%', 1: '97.02%', 2: '99.97%'}
# Val Loss: 0.112192, Val Acc: 96.89%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.033302, Train-Class-Acc: {0: '96.97%', 1: '97.23%', 2: '99.97%'}
# Val Loss: 0.103842, Val Acc: 97.10%, Val-Class-Acc: {0: '89.41%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.038231, Train-Class-Acc: {0: '96.89%', 1: '97.60%', 2: '99.85%'}
# Val Loss: 0.104564, Val Acc: 97.14%, Val-Class-Acc: {0: '89.41%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.033129, Train-Class-Acc: {0: '97.20%', 1: '96.65%', 2: '99.94%'}
# Val Loss: 0.106953, Val Acc: 97.05%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.029575, Train-Class-Acc: {0: '97.82%', 1: '97.89%', 2: '99.94%'}
# Val Loss: 0.126417, Val Acc: 96.64%, Val-Class-Acc: {0: '85.34%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.028918, Train-Class-Acc: {0: '97.67%', 1: '97.67%', 2: '99.94%'}
# Val Loss: 0.099856, Val Acc: 97.18%, Val-Class-Acc: {0: '90.63%', 1: '95.86%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.037279, Train-Class-Acc: {0: '96.97%', 1: '97.45%', 2: '99.85%'}
# Val Loss: 0.115743, Val Acc: 96.85%, Val-Class-Acc: {0: '87.37%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.032922, Train-Class-Acc: {0: '97.67%', 1: '97.23%', 2: '100.00%'}
# Val Loss: 0.118839, Val Acc: 96.85%, Val-Class-Acc: {0: '86.76%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.033651, Train-Class-Acc: {0: '97.05%', 1: '97.38%', 2: '99.88%'}
# Val Loss: 0.098914, Val Acc: 97.39%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_72.pth
# Epoch 73/1000, Train Loss: 0.028184, Train-Class-Acc: {0: '97.59%', 1: '97.82%', 2: '99.97%'}
# Val Loss: 0.107929, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.031637, Train-Class-Acc: {0: '97.36%', 1: '97.60%', 2: '99.97%'}
# Val Loss: 0.102582, Val Acc: 97.10%, Val-Class-Acc: {0: '90.43%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.027326, Train-Class-Acc: {0: '98.13%', 1: '98.18%', 2: '99.85%'}
# Val Loss: 0.112680, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.029610, Train-Class-Acc: {0: '97.43%', 1: '97.60%', 2: '99.94%'}
# Val Loss: 0.112415, Val Acc: 96.85%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.031770, Train-Class-Acc: {0: '97.74%', 1: '97.53%', 2: '99.97%'}
# Val Loss: 0.111309, Val Acc: 96.85%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.025594, Train-Class-Acc: {0: '98.06%', 1: '98.25%', 2: '99.97%'}
# Val Loss: 0.112667, Val Acc: 96.93%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.033910, Train-Class-Acc: {0: '97.12%', 1: '97.89%', 2: '99.88%'}
# Val Loss: 0.113241, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.034939, Train-Class-Acc: {0: '97.74%', 1: '97.23%', 2: '99.97%'}
# Val Loss: 0.106915, Val Acc: 97.10%, Val-Class-Acc: {0: '89.21%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.025848, Train-Class-Acc: {0: '98.29%', 1: '97.53%', 2: '99.88%'}
# Val Loss: 0.113899, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.028060, Train-Class-Acc: {0: '97.98%', 1: '97.60%', 2: '100.00%'}
# Val Loss: 0.109280, Val Acc: 97.14%, Val-Class-Acc: {0: '89.41%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.031664, Train-Class-Acc: {0: '97.12%', 1: '97.82%', 2: '99.88%'}
# Val Loss: 0.117268, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.032024, Train-Class-Acc: {0: '98.29%', 1: '97.09%', 2: '99.97%'}
# Val Loss: 0.119778, Val Acc: 97.05%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.032380, Train-Class-Acc: {0: '97.67%', 1: '97.74%', 2: '99.94%'}
# Val Loss: 0.128893, Val Acc: 96.68%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.031486, Train-Class-Acc: {0: '97.43%', 1: '97.16%', 2: '99.94%'}
# Val Loss: 0.107404, Val Acc: 97.01%, Val-Class-Acc: {0: '89.41%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.032285, Train-Class-Acc: {0: '97.12%', 1: '97.74%', 2: '99.91%'}
# Val Loss: 0.111891, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.026429, Train-Class-Acc: {0: '97.67%', 1: '97.74%', 2: '99.85%'}
# Val Loss: 0.112618, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.029046, Train-Class-Acc: {0: '98.06%', 1: '98.03%', 2: '99.85%'}
# Val Loss: 0.114916, Val Acc: 97.01%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.029108, Train-Class-Acc: {0: '97.67%', 1: '98.03%', 2: '99.82%'}
# Val Loss: 0.111714, Val Acc: 97.14%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.031239, Train-Class-Acc: {0: '97.43%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.103762, Val Acc: 97.34%, Val-Class-Acc: {0: '91.65%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_37.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_91.pth
# Epoch 92/1000, Train Loss: 0.026397, Train-Class-Acc: {0: '97.74%', 1: '97.82%', 2: '99.97%'}
# Val Loss: 0.125178, Val Acc: 96.89%, Val-Class-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.028308, Train-Class-Acc: {0: '98.52%', 1: '97.60%', 2: '99.97%'}
# Val Loss: 0.126011, Val Acc: 96.97%, Val-Class-Acc: {0: '86.56%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.026593, Train-Class-Acc: {0: '97.67%', 1: '98.69%', 2: '99.88%'}
# Val Loss: 0.117398, Val Acc: 96.93%, Val-Class-Acc: {0: '87.98%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.028631, Train-Class-Acc: {0: '97.36%', 1: '97.74%', 2: '99.94%'}
# Val Loss: 0.115836, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.024475, Train-Class-Acc: {0: '98.37%', 1: '98.25%', 2: '99.94%'}
# Val Loss: 0.107243, Val Acc: 97.10%, Val-Class-Acc: {0: '89.61%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.024836, Train-Class-Acc: {0: '98.52%', 1: '98.03%', 2: '99.88%'}
# Val Loss: 0.124739, Val Acc: 96.85%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.030275, Train-Class-Acc: {0: '97.67%', 1: '97.38%', 2: '99.94%'}
# Val Loss: 0.117547, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.023585, Train-Class-Acc: {0: '98.37%', 1: '97.89%', 2: '99.91%'}
# Val Loss: 0.121827, Val Acc: 97.10%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.029930, Train-Class-Acc: {0: '97.67%', 1: '97.45%', 2: '99.85%'}
# Val Loss: 0.128671, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.024486, Train-Class-Acc: {0: '97.98%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.115378, Val Acc: 97.01%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.024347, Train-Class-Acc: {0: '98.44%', 1: '97.89%', 2: '99.97%'}
# Val Loss: 0.105343, Val Acc: 97.26%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.029571, Train-Class-Acc: {0: '97.90%', 1: '97.89%', 2: '99.91%'}
# Val Loss: 0.112311, Val Acc: 97.22%, Val-Class-Acc: {0: '90.22%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.027790, Train-Class-Acc: {0: '97.98%', 1: '97.60%', 2: '99.91%'}
# Val Loss: 0.118646, Val Acc: 96.97%, Val-Class-Acc: {0: '87.98%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.029515, Train-Class-Acc: {0: '96.97%', 1: '97.96%', 2: '99.97%'}
# Val Loss: 0.118678, Val Acc: 97.01%, Val-Class-Acc: {0: '88.80%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.030979, Train-Class-Acc: {0: '97.82%', 1: '97.67%', 2: '99.91%'}
# Val Loss: 0.127970, Val Acc: 96.89%, Val-Class-Acc: {0: '86.97%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.029128, Train-Class-Acc: {0: '97.43%', 1: '97.74%', 2: '99.97%'}
# Val Loss: 0.108332, Val Acc: 97.43%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_107.pth
# Epoch 108/1000, Train Loss: 0.023384, Train-Class-Acc: {0: '98.52%', 1: '98.11%', 2: '99.94%'}
# Val Loss: 0.132191, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.027355, Train-Class-Acc: {0: '97.98%', 1: '98.18%', 2: '99.94%'}
# Val Loss: 0.119127, Val Acc: 97.14%, Val-Class-Acc: {0: '89.00%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.029026, Train-Class-Acc: {0: '97.51%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.119836, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.028365, Train-Class-Acc: {0: '98.21%', 1: '97.31%', 2: '99.97%'}
# Val Loss: 0.108603, Val Acc: 97.26%, Val-Class-Acc: {0: '90.02%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.032425, Train-Class-Acc: {0: '97.51%', 1: '97.96%', 2: '99.88%'}
# Val Loss: 0.121047, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '99.93%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.031135, Train-Class-Acc: {0: '97.51%', 1: '97.67%', 2: '99.94%'}
# Val Loss: 0.117357, Val Acc: 96.97%, Val-Class-Acc: {0: '88.19%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.027406, Train-Class-Acc: {0: '98.60%', 1: '97.67%', 2: '99.94%'}
# Val Loss: 0.115664, Val Acc: 97.14%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.025450, Train-Class-Acc: {0: '97.98%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.112167, Val Acc: 97.14%, Val-Class-Acc: {0: '89.61%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.028590, Train-Class-Acc: {0: '97.59%', 1: '97.82%', 2: '99.97%'}
# Val Loss: 0.110553, Val Acc: 97.39%, Val-Class-Acc: {0: '91.85%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_38.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_116.pth
# Epoch 117/1000, Train Loss: 0.031921, Train-Class-Acc: {0: '97.74%', 1: '97.60%', 2: '99.88%'}
# Val Loss: 0.113653, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.032694, Train-Class-Acc: {0: '97.98%', 1: '97.09%', 2: '100.00%'}
# Val Loss: 0.114379, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.025563, Train-Class-Acc: {0: '97.67%', 1: '98.47%', 2: '99.91%'}
# Val Loss: 0.126845, Val Acc: 96.93%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.029255, Train-Class-Acc: {0: '97.67%', 1: '97.89%', 2: '99.88%'}
# Val Loss: 0.124674, Val Acc: 97.10%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.023116, Train-Class-Acc: {0: '98.68%', 1: '97.89%', 2: '99.94%'}
# Val Loss: 0.119498, Val Acc: 97.10%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.023567, Train-Class-Acc: {0: '98.21%', 1: '98.69%', 2: '99.94%'}
# Val Loss: 0.115345, Val Acc: 97.05%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.024757, Train-Class-Acc: {0: '97.98%', 1: '97.96%', 2: '100.00%'}
# Val Loss: 0.122458, Val Acc: 96.93%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.027225, Train-Class-Acc: {0: '97.82%', 1: '98.18%', 2: '99.91%'}
# Val Loss: 0.109807, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.021918, Train-Class-Acc: {0: '97.98%', 1: '98.40%', 2: '99.91%'}
# Val Loss: 0.119469, Val Acc: 97.18%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.023930, Train-Class-Acc: {0: '97.74%', 1: '98.03%', 2: '100.00%'}
# Val Loss: 0.111553, Val Acc: 97.18%, Val-Class-Acc: {0: '90.02%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.027152, Train-Class-Acc: {0: '97.43%', 1: '97.82%', 2: '100.00%'}
# Val Loss: 0.110314, Val Acc: 97.22%, Val-Class-Acc: {0: '90.63%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.022003, Train-Class-Acc: {0: '97.90%', 1: '98.11%', 2: '99.91%'}
# Val Loss: 0.116021, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.031233, Train-Class-Acc: {0: '97.28%', 1: '97.67%', 2: '99.94%'}
# Val Loss: 0.122235, Val Acc: 97.10%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.022462, Train-Class-Acc: {0: '98.13%', 1: '98.33%', 2: '99.94%'}
# Val Loss: 0.121266, Val Acc: 97.18%, Val-Class-Acc: {0: '89.41%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.029632, Train-Class-Acc: {0: '97.67%', 1: '97.82%', 2: '99.91%'}
# Val Loss: 0.124837, Val Acc: 97.10%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.024323, Train-Class-Acc: {0: '98.21%', 1: '97.74%', 2: '99.97%'}
# Val Loss: 0.117520, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.023487, Train-Class-Acc: {0: '98.60%', 1: '97.82%', 2: '99.97%'}
# Val Loss: 0.126509, Val Acc: 96.97%, Val-Class-Acc: {0: '87.98%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.022507, Train-Class-Acc: {0: '98.06%', 1: '98.54%', 2: '99.82%'}
# Val Loss: 0.120742, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.029392, Train-Class-Acc: {0: '97.90%', 1: '97.31%', 2: '99.91%'}
# Val Loss: 0.114856, Val Acc: 97.26%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.026643, Train-Class-Acc: {0: '97.90%', 1: '98.25%', 2: '99.88%'}
# Val Loss: 0.120625, Val Acc: 97.18%, Val-Class-Acc: {0: '89.00%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.025793, Train-Class-Acc: {0: '98.44%', 1: '97.53%', 2: '99.97%'}
# Val Loss: 0.132072, Val Acc: 96.80%, Val-Class-Acc: {0: '86.97%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.029431, Train-Class-Acc: {0: '98.06%', 1: '97.74%', 2: '99.94%'}
# Val Loss: 0.112774, Val Acc: 97.22%, Val-Class-Acc: {0: '90.02%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.027158, Train-Class-Acc: {0: '97.12%', 1: '97.67%', 2: '99.91%'}
# Val Loss: 0.118338, Val Acc: 97.05%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.023844, Train-Class-Acc: {0: '98.13%', 1: '98.03%', 2: '99.97%'}
# Val Loss: 0.120333, Val Acc: 97.05%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.033324, Train-Class-Acc: {0: '97.36%', 1: '97.38%', 2: '99.97%'}
# Val Loss: 0.110174, Val Acc: 97.30%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.031227, Train-Class-Acc: {0: '97.98%', 1: '97.31%', 2: '99.94%'}
# Val Loss: 0.123097, Val Acc: 97.10%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.029310, Train-Class-Acc: {0: '97.82%', 1: '97.38%', 2: '99.94%'}
# Val Loss: 0.115118, Val Acc: 97.26%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.032217, Train-Class-Acc: {0: '97.67%', 1: '97.16%', 2: '99.94%'}
# Val Loss: 0.120239, Val Acc: 97.14%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.025900, Train-Class-Acc: {0: '98.13%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.119707, Val Acc: 97.18%, Val-Class-Acc: {0: '89.00%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.027242, Train-Class-Acc: {0: '97.98%', 1: '98.11%', 2: '99.94%'}
# Val Loss: 0.115356, Val Acc: 97.34%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.024566, Train-Class-Acc: {0: '98.44%', 1: '97.96%', 2: '99.88%'}
# Val Loss: 0.121734, Val Acc: 97.14%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.030159, Train-Class-Acc: {0: '98.06%', 1: '97.74%', 2: '99.76%'}
# Val Loss: 0.122981, Val Acc: 96.97%, Val-Class-Acc: {0: '88.39%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.019999, Train-Class-Acc: {0: '98.44%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.120245, Val Acc: 97.10%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.024578, Train-Class-Acc: {0: '97.51%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.117592, Val Acc: 97.18%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.023011, Train-Class-Acc: {0: '98.29%', 1: '98.40%', 2: '99.94%'}
# Val Loss: 0.128288, Val Acc: 97.10%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.027907, Train-Class-Acc: {0: '98.13%', 1: '97.53%', 2: '99.94%'}
# Val Loss: 0.123350, Val Acc: 97.18%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.026327, Train-Class-Acc: {0: '97.98%', 1: '98.18%', 2: '99.91%'}
# Val Loss: 0.125120, Val Acc: 97.14%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.026732, Train-Class-Acc: {0: '97.98%', 1: '97.82%', 2: '99.91%'}
# Val Loss: 0.118197, Val Acc: 97.26%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.024909, Train-Class-Acc: {0: '98.13%', 1: '98.03%', 2: '99.82%'}
# Val Loss: 0.114567, Val Acc: 97.22%, Val-Class-Acc: {0: '91.04%', 1: '95.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.023080, Train-Class-Acc: {0: '98.44%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.133664, Val Acc: 96.89%, Val-Class-Acc: {0: '87.17%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.023482, Train-Class-Acc: {0: '98.21%', 1: '98.47%', 2: '99.94%'}
# Val Loss: 0.144200, Val Acc: 96.85%, Val-Class-Acc: {0: '85.95%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.024549, Train-Class-Acc: {0: '98.21%', 1: '98.47%', 2: '99.91%'}
# Val Loss: 0.115259, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.024974, Train-Class-Acc: {0: '98.21%', 1: '97.74%', 2: '99.91%'}
# Val Loss: 0.119274, Val Acc: 97.05%, Val-Class-Acc: {0: '89.82%', 1: '96.05%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.022053, Train-Class-Acc: {0: '98.29%', 1: '98.25%', 2: '99.97%'}
# Val Loss: 0.133974, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.024020, Train-Class-Acc: {0: '98.06%', 1: '98.40%', 2: '99.94%'}
# Val Loss: 0.129837, Val Acc: 97.10%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.030359, Train-Class-Acc: {0: '97.82%', 1: '97.38%', 2: '100.00%'}
# Val Loss: 0.148364, Val Acc: 96.51%, Val-Class-Acc: {0: '84.93%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.026770, Train-Class-Acc: {0: '97.90%', 1: '97.74%', 2: '99.91%'}
# Val Loss: 0.136711, Val Acc: 96.76%, Val-Class-Acc: {0: '86.56%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.023140, Train-Class-Acc: {0: '98.37%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.126496, Val Acc: 97.10%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.026344, Train-Class-Acc: {0: '97.67%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.143327, Val Acc: 96.93%, Val-Class-Acc: {0: '86.76%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.025372, Train-Class-Acc: {0: '97.43%', 1: '98.25%', 2: '99.91%'}
# Val Loss: 0.129663, Val Acc: 96.97%, Val-Class-Acc: {0: '87.98%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.021206, Train-Class-Acc: {0: '98.37%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.126660, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.025355, Train-Class-Acc: {0: '97.74%', 1: '98.18%', 2: '99.94%'}
# Val Loss: 0.123685, Val Acc: 97.22%, Val-Class-Acc: {0: '89.21%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.026826, Train-Class-Acc: {0: '97.59%', 1: '97.74%', 2: '99.94%'}
# Val Loss: 0.122588, Val Acc: 97.01%, Val-Class-Acc: {0: '89.41%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 170/1000, Train Loss: 0.027210, Train-Class-Acc: {0: '97.51%', 1: '98.18%', 2: '99.91%'}
# Val Loss: 0.123030, Val Acc: 97.22%, Val-Class-Acc: {0: '90.02%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 171/1000, Train Loss: 0.024053, Train-Class-Acc: {0: '98.37%', 1: '97.96%', 2: '99.85%'}
# Val Loss: 0.119590, Val Acc: 97.05%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 172/1000, Train Loss: 0.022484, Train-Class-Acc: {0: '97.82%', 1: '98.33%', 2: '99.94%'}
# Val Loss: 0.127314, Val Acc: 97.14%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 173/1000, Train Loss: 0.024963, Train-Class-Acc: {0: '97.74%', 1: '97.89%', 2: '99.94%'}
# Val Loss: 0.130074, Val Acc: 96.97%, Val-Class-Acc: {0: '88.19%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 174/1000, Train Loss: 0.023028, Train-Class-Acc: {0: '98.52%', 1: '97.96%', 2: '99.97%'}
# Val Loss: 0.130857, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 175/1000, Train Loss: 0.021360, Train-Class-Acc: {0: '97.67%', 1: '98.40%', 2: '99.97%'}
# Val Loss: 0.134606, Val Acc: 96.93%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 176/1000, Train Loss: 0.024750, Train-Class-Acc: {0: '97.98%', 1: '98.25%', 2: '99.88%'}
# Val Loss: 0.128350, Val Acc: 97.10%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 177/1000, Train Loss: 0.028638, Train-Class-Acc: {0: '98.29%', 1: '97.74%', 2: '99.85%'}
# Val Loss: 0.126569, Val Acc: 97.05%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 178/1000, Train Loss: 0.025318, Train-Class-Acc: {0: '97.82%', 1: '98.03%', 2: '99.97%'}
# Val Loss: 0.122689, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 179/1000, Train Loss: 0.024354, Train-Class-Acc: {0: '97.82%', 1: '98.25%', 2: '99.88%'}
# Val Loss: 0.133823, Val Acc: 97.14%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 180/1000, Train Loss: 0.023859, Train-Class-Acc: {0: '98.21%', 1: '97.74%', 2: '99.91%'}
# Val Loss: 0.131581, Val Acc: 97.05%, Val-Class-Acc: {0: '88.19%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 181/1000, Train Loss: 0.026807, Train-Class-Acc: {0: '98.13%', 1: '98.18%', 2: '99.94%'}
# Val Loss: 0.124711, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 182/1000, Train Loss: 0.023709, Train-Class-Acc: {0: '97.74%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.121419, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 183/1000, Train Loss: 0.021724, Train-Class-Acc: {0: '98.29%', 1: '97.96%', 2: '99.97%'}
# Val Loss: 0.121628, Val Acc: 97.26%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 184/1000, Train Loss: 0.025860, Train-Class-Acc: {0: '98.13%', 1: '98.03%', 2: '99.94%'}
# Val Loss: 0.138968, Val Acc: 97.10%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 185/1000, Train Loss: 0.027802, Train-Class-Acc: {0: '97.98%', 1: '97.74%', 2: '99.85%'}
# Val Loss: 0.140345, Val Acc: 96.76%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 186/1000, Train Loss: 0.024386, Train-Class-Acc: {0: '97.82%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.133266, Val Acc: 96.80%, Val-Class-Acc: {0: '87.17%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 187/1000, Train Loss: 0.023987, Train-Class-Acc: {0: '98.37%', 1: '98.25%', 2: '99.97%'}
# Val Loss: 0.136115, Val Acc: 96.85%, Val-Class-Acc: {0: '86.97%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 188/1000, Train Loss: 0.022901, Train-Class-Acc: {0: '98.21%', 1: '97.96%', 2: '99.97%'}
# Val Loss: 0.132242, Val Acc: 97.01%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 189/1000, Train Loss: 0.027995, Train-Class-Acc: {0: '98.37%', 1: '97.82%', 2: '100.00%'}
# Val Loss: 0.124388, Val Acc: 97.05%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 190/1000, Train Loss: 0.025413, Train-Class-Acc: {0: '98.13%', 1: '97.89%', 2: '99.88%'}
# Val Loss: 0.125636, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 191/1000, Train Loss: 0.026101, Train-Class-Acc: {0: '98.44%', 1: '98.11%', 2: '99.85%'}
# Val Loss: 0.131114, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 192/1000, Train Loss: 0.020519, Train-Class-Acc: {0: '98.76%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.123236, Val Acc: 97.22%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 193/1000, Train Loss: 0.026373, Train-Class-Acc: {0: '97.51%', 1: '97.38%', 2: '99.97%'}
# Val Loss: 0.133420, Val Acc: 96.93%, Val-Class-Acc: {0: '87.58%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 194/1000, Train Loss: 0.032705, Train-Class-Acc: {0: '97.43%', 1: '97.60%', 2: '99.94%'}
# Val Loss: 0.135221, Val Acc: 96.97%, Val-Class-Acc: {0: '87.78%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# ...
# Epoch 936/1000, Train Loss: 0.017989, Train-Class-Acc: {0: '98.68%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.167640, Val Acc: 96.89%, Val-Class-Acc: {0: '87.58%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 937/1000, Train Loss: 0.020194, Train-Class-Acc: {0: '97.90%', 1: '98.47%', 2: '99.91%'}
# Val Loss: 0.156753, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 938/1000, Train Loss: 0.020979, Train-Class-Acc: {0: '98.29%', 1: '98.47%', 2: '99.94%'}
# Val Loss: 0.161784, Val Acc: 96.80%, Val-Class-Acc: {0: '87.58%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 939/1000, Train Loss: 0.020983, Train-Class-Acc: {0: '98.76%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.147940, Val Acc: 97.01%, Val-Class-Acc: {0: '88.80%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 940/1000, Train Loss: 0.025420, Train-Class-Acc: {0: '97.98%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.177531, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 941/1000, Train Loss: 0.017996, Train-Class-Acc: {0: '98.37%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.158728, Val Acc: 97.26%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 942/1000, Train Loss: 0.021888, Train-Class-Acc: {0: '98.76%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.163162, Val Acc: 96.93%, Val-Class-Acc: {0: '87.58%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 943/1000, Train Loss: 0.017380, Train-Class-Acc: {0: '98.37%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.159071, Val Acc: 96.93%, Val-Class-Acc: {0: '87.78%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 944/1000, Train Loss: 0.018944, Train-Class-Acc: {0: '98.29%', 1: '98.91%', 2: '100.00%'}
# Val Loss: 0.155883, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.019316, Train-Class-Acc: {0: '98.52%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.156611, Val Acc: 97.26%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.019843, Train-Class-Acc: {0: '98.29%', 1: '98.33%', 2: '99.97%'}
# Val Loss: 0.154507, Val Acc: 96.97%, Val-Class-Acc: {0: '88.19%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.022907, Train-Class-Acc: {0: '98.21%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.159459, Val Acc: 96.85%, Val-Class-Acc: {0: '87.17%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.019224, Train-Class-Acc: {0: '98.29%', 1: '98.69%', 2: '100.00%'}
# Val Loss: 0.141252, Val Acc: 97.34%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.021034, Train-Class-Acc: {0: '98.99%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.146385, Val Acc: 97.26%, Val-Class-Acc: {0: '90.02%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.022016, Train-Class-Acc: {0: '98.21%', 1: '98.54%', 2: '99.97%'}
# Val Loss: 0.164532, Val Acc: 96.93%, Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.020676, Train-Class-Acc: {0: '98.13%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.155959, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.019736, Train-Class-Acc: {0: '98.29%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.150011, Val Acc: 97.22%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.018805, Train-Class-Acc: {0: '98.76%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.174149, Val Acc: 96.72%, Val-Class-Acc: {0: '86.35%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.020106, Train-Class-Acc: {0: '98.06%', 1: '98.25%', 2: '99.94%'}
# Val Loss: 0.160694, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.024922, Train-Class-Acc: {0: '98.52%', 1: '98.03%', 2: '99.94%'}
# Val Loss: 0.154976, Val Acc: 97.26%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.018427, Train-Class-Acc: {0: '98.68%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.151137, Val Acc: 97.18%, Val-Class-Acc: {0: '89.41%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.021048, Train-Class-Acc: {0: '98.44%', 1: '98.25%', 2: '99.94%'}
# Val Loss: 0.165640, Val Acc: 96.93%, Val-Class-Acc: {0: '87.37%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.024562, Train-Class-Acc: {0: '98.13%', 1: '98.11%', 2: '100.00%'}
# Val Loss: 0.153628, Val Acc: 97.05%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.019787, Train-Class-Acc: {0: '98.29%', 1: '98.18%', 2: '99.94%'}
# Val Loss: 0.175797, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.017893, Train-Class-Acc: {0: '98.99%', 1: '98.76%', 2: '100.00%'}
# Val Loss: 0.169701, Val Acc: 96.80%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.022047, Train-Class-Acc: {0: '97.90%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.155303, Val Acc: 97.14%, Val-Class-Acc: {0: '89.61%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.021729, Train-Class-Acc: {0: '98.37%', 1: '98.03%', 2: '99.94%'}
# Val Loss: 0.161151, Val Acc: 97.10%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.015283, Train-Class-Acc: {0: '98.60%', 1: '98.84%', 2: '99.97%'}
# Val Loss: 0.170603, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.023400, Train-Class-Acc: {0: '98.37%', 1: '98.54%', 2: '99.88%'}
# Val Loss: 0.164470, Val Acc: 96.93%, Val-Class-Acc: {0: '87.17%', 1: '97.93%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.021289, Train-Class-Acc: {0: '98.37%', 1: '98.25%', 2: '99.91%'}
# Val Loss: 0.177032, Val Acc: 96.72%, Val-Class-Acc: {0: '85.95%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.021988, Train-Class-Acc: {0: '98.60%', 1: '98.25%', 2: '99.88%'}
# Val Loss: 0.163239, Val Acc: 97.01%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.021350, Train-Class-Acc: {0: '97.90%', 1: '98.54%', 2: '99.85%'}
# Val Loss: 0.159949, Val Acc: 97.14%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.025638, Train-Class-Acc: {0: '97.90%', 1: '98.03%', 2: '99.97%'}
# Val Loss: 0.153533, Val Acc: 97.05%, Val-Class-Acc: {0: '88.59%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.021429, Train-Class-Acc: {0: '98.29%', 1: '98.18%', 2: '99.97%'}
# Val Loss: 0.149516, Val Acc: 97.26%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.022852, Train-Class-Acc: {0: '98.44%', 1: '98.47%', 2: '100.00%'}
# Val Loss: 0.161370, Val Acc: 97.01%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.017712, Train-Class-Acc: {0: '98.21%', 1: '98.76%', 2: '99.91%'}
# Val Loss: 0.183914, Val Acc: 96.76%, Val-Class-Acc: {0: '85.54%', 1: '98.68%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.020019, Train-Class-Acc: {0: '98.13%', 1: '98.62%', 2: '99.97%'}
# Val Loss: 0.149613, Val Acc: 97.18%, Val-Class-Acc: {0: '89.82%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.021492, Train-Class-Acc: {0: '98.29%', 1: '98.40%', 2: '99.91%'}
# Val Loss: 0.151428, Val Acc: 97.26%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.022091, Train-Class-Acc: {0: '98.21%', 1: '98.11%', 2: '99.97%'}
# Val Loss: 0.180632, Val Acc: 96.76%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.019519, Train-Class-Acc: {0: '98.76%', 1: '98.40%', 2: '99.94%'}
# Val Loss: 0.157012, Val Acc: 96.97%, Val-Class-Acc: {0: '88.59%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.023628, Train-Class-Acc: {0: '98.52%', 1: '98.03%', 2: '99.91%'}
# Val Loss: 0.150453, Val Acc: 97.10%, Val-Class-Acc: {0: '89.21%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.018669, Train-Class-Acc: {0: '98.83%', 1: '98.33%', 2: '99.91%'}
# Val Loss: 0.171830, Val Acc: 97.10%, Val-Class-Acc: {0: '89.00%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.025886, Train-Class-Acc: {0: '97.67%', 1: '97.82%', 2: '100.00%'}
# Val Loss: 0.156626, Val Acc: 97.05%, Val-Class-Acc: {0: '88.39%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.022100, Train-Class-Acc: {0: '98.13%', 1: '98.03%', 2: '99.97%'}
# Val Loss: 0.159124, Val Acc: 96.89%, Val-Class-Acc: {0: '87.78%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.016999, Train-Class-Acc: {0: '98.91%', 1: '98.33%', 2: '100.00%'}
# Val Loss: 0.177743, Val Acc: 96.80%, Val-Class-Acc: {0: '86.15%', 1: '98.31%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.019644, Train-Class-Acc: {0: '97.67%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.140431, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.021804, Train-Class-Acc: {0: '97.98%', 1: '98.40%', 2: '100.00%'}
# Val Loss: 0.148935, Val Acc: 97.47%, Val-Class-Acc: {0: '91.45%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.022752, Train-Class-Acc: {0: '98.52%', 1: '97.82%', 2: '99.94%'}
# Val Loss: 0.171612, Val Acc: 96.85%, Val-Class-Acc: {0: '86.56%', 1: '98.12%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.018674, Train-Class-Acc: {0: '98.68%', 1: '98.54%', 2: '99.91%'}
# Val Loss: 0.156136, Val Acc: 96.89%, Val-Class-Acc: {0: '87.98%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.020703, Train-Class-Acc: {0: '98.13%', 1: '98.47%', 2: '99.97%'}
# Val Loss: 0.156986, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.018788, Train-Class-Acc: {0: '98.60%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.160672, Val Acc: 96.89%, Val-Class-Acc: {0: '87.37%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.019344, Train-Class-Acc: {0: '98.68%', 1: '98.40%', 2: '99.97%'}
# Val Loss: 0.151692, Val Acc: 97.39%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.021740, Train-Class-Acc: {0: '98.21%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.161552, Val Acc: 96.97%, Val-Class-Acc: {0: '88.19%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.020944, Train-Class-Acc: {0: '98.52%', 1: '98.11%', 2: '99.97%'}
# Val Loss: 0.146398, Val Acc: 97.26%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.017889, Train-Class-Acc: {0: '98.29%', 1: '98.54%', 2: '99.94%'}
# Val Loss: 0.162939, Val Acc: 97.01%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.018306, Train-Class-Acc: {0: '98.76%', 1: '98.40%', 2: '99.97%'}
# Val Loss: 0.159079, Val Acc: 97.14%, Val-Class-Acc: {0: '89.21%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.020560, Train-Class-Acc: {0: '98.44%', 1: '98.25%', 2: '100.00%'}
# Val Loss: 0.161837, Val Acc: 96.93%, Val-Class-Acc: {0: '87.98%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.022590, Train-Class-Acc: {0: '98.06%', 1: '98.33%', 2: '99.97%'}
# Val Loss: 0.172149, Val Acc: 97.01%, Val-Class-Acc: {0: '88.19%', 1: '97.37%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.023565, Train-Class-Acc: {0: '98.06%', 1: '97.82%', 2: '100.00%'}
# Val Loss: 0.163369, Val Acc: 97.01%, Val-Class-Acc: {0: '87.98%', 1: '97.56%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.023069, Train-Class-Acc: {0: '97.90%', 1: '98.25%', 2: '99.94%'}
# Val Loss: 0.156271, Val Acc: 96.80%, Val-Class-Acc: {0: '87.58%', 1: '96.99%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.022144, Train-Class-Acc: {0: '98.06%', 1: '98.54%', 2: '100.00%'}
# Val Loss: 0.153162, Val Acc: 97.10%, Val-Class-Acc: {0: '89.61%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.018760, Train-Class-Acc: {0: '98.21%', 1: '98.03%', 2: '99.94%'}
# Val Loss: 0.151645, Val Acc: 97.10%, Val-Class-Acc: {0: '89.41%', 1: '96.62%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.020917, Train-Class-Acc: {0: '98.06%', 1: '98.03%', 2: '99.97%'}
# Val Loss: 0.164113, Val Acc: 96.85%, Val-Class-Acc: {0: '87.98%', 1: '96.80%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.020967, Train-Class-Acc: {0: '98.60%', 1: '98.18%', 2: '100.00%'}
# Val Loss: 0.157990, Val Acc: 97.10%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.019189, Train-Class-Acc: {0: '98.21%', 1: '98.62%', 2: '99.91%'}
# Val Loss: 0.155128, Val Acc: 97.43%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 690.63 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_best.pth (Val Accuracy: 97.59%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 332, Train Loss: 0.018894, Train-Acc: {0: '98.60%', 1: '98.84%', 2: '99.88%'},
# Val Loss: 0.132862, Val Acc: 97.59%, Val-Acc: {0: '91.45%', 1: '96.99%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_332.pth
# Epoch 718, Train Loss: 0.020670, Train-Acc: {0: '98.21%', 1: '98.33%', 2: '99.91%'},
# Val Loss: 0.145619, Val Acc: 97.55%, Val-Acc: {0: '91.65%', 1: '96.62%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_718.pth
# Epoch 661, Train Loss: 0.020615, Train-Acc: {0: '98.21%', 1: '98.69%', 2: '99.91%'},
# Val Loss: 0.136590, Val Acc: 97.55%, Val-Acc: {0: '91.85%', 1: '96.43%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_661.pth
# Epoch 490, Train Loss: 0.023154, Train-Acc: {0: '98.13%', 1: '98.54%', 2: '99.88%'},
# Val Loss: 0.136082, Val Acc: 97.55%, Val-Acc: {0: '91.85%', 1: '96.43%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_490.pth
# Epoch 655, Train Loss: 0.021331, Train-Acc: {0: '98.37%', 1: '98.18%', 2: '99.97%'},
# Val Loss: 0.142842, Val Acc: 97.51%, Val-Acc: {0: '91.65%', 1: '96.43%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2/HAR_MLP_LoRA_v2_epoch_655.pth
# ---
# ### Period 2
# + ##### Total training time: 690.63 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_2'*
# + ##### Best Epoch: 332
# #### __Val Accuracy: 97.59%__
# #### __Val-Class-Acc: {0: '91.45%', 1: '96.99%', 2: '100.00%'}__
#
# ✅ Period 2 Training Complete. Final model architecture:
# HAR_MLP_LoRA_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=3, bias=True)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2], num_classes = 3

# %% [markdown]
# ---
# ### Period 3
# + ##### Total training time: 423.39 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3'*
# + ##### Best Epoch: 47
# #### __Val Accuracy: 98.07%__
# #### __Val-Class-Acc: {0: '91.24%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}__

# %%
# ================================
# 📌 Period 3 Configuration - HAR_MLP_LoRA_v2 (Standard LoRA)
# ================================
period = 3

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Model hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
lora_r        = 4
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000

# Model saving path
model_name = "HAR_MLP_LoRA_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Load previous model (Period 2) ===
previous_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period - 1}", f"{model_name}_best.pth"
)
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# === Initialize new model ===
model = HAR_MLP_LoRA_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

# === Init LoRA FIRST ===
model.init_lora()

# === Load weights (exclude fc3 & lora_adapter) ===
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc3")
    # if not k.startswith("fc3") and not k.startswith("lora_adapter")
}, strict=False)

# === Optimizer / Criterion / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.get_trainable_parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Training ===
train_with_standard_lora(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, checkpoint, previous_state_dict
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 777 MiB
#     - Device Name    : NVIDIA RTX A6000
# ✅ Initialized LoRA adapter for fc2
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc3.weight
#   ✅ fc3.bias
#
# 🚀 'train_with_standard_lora' started for Period 3
#
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 777 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
#
# 🔧 Model Parameter Overview:
# fc1.weight                                         | ✅ trainable  | shape=[128, 561]
# fc1.bias                                           | ✅ trainable  | shape=[128]
# bn1.weight                                         | ✅ trainable  | shape=[128]
# bn1.bias                                           | ✅ trainable  | shape=[128]
# fc2.weight                                         | ✅ trainable  | shape=[128, 128]
# fc2.bias                                           | ✅ trainable  | shape=[128]
# bn2.weight                                         | ✅ trainable  | shape=[128]
# bn2.bias                                           | ✅ trainable  | shape=[128]
# fc3.weight                                         | ✅ trainable  | shape=[4, 128]
# fc3.bias                                           | ✅ trainable  | shape=[4]
# lora_adapter.A                                     | ✅ trainable  | shape=[128, 4]
# lora_adapter.B                                     | ✅ trainable  | shape=[4, 128]
#
# 🧠 Optimizer Parameter Overview:
# lora_adapter.A                                     | ✅ from optimizer | shape=[128, 4]
# lora_adapter.B                                     | ✅ from optimizer | shape=[4, 128]
# fc3.weight                                         | ✅ from optimizer | shape=[4, 128]
# fc3.bias                                           | ✅ from optimizer | shape=[4]
#
# ================================================================================
# /tmp/ipykernel_2234450/891328497.py:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 1.057294, Train-Class-Acc: {0: '13.61%', 1: '90.03%', 2: '74.22%', 3: '14.50%'}
# Val Loss: 0.669932, Val Acc: 77.54%, Val-Class-Acc: {0: '34.22%', 1: '99.25%', 3: '37.80%', 2: '99.93%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 0.615037, Train-Class-Acc: {0: '57.08%', 1: '96.00%', 2: '97.35%', 3: '35.25%'}
# Val Loss: 0.466911, Val Acc: 92.03%, Val-Class-Acc: {0: '82.08%', 1: '98.31%', 3: '74.30%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.415672, Train-Class-Acc: {0: '78.77%', 1: '96.36%', 2: '99.42%', 3: '69.86%'}
# Val Loss: 0.311271, Val Acc: 95.69%, Val-Class-Acc: {0: '87.58%', 1: '97.93%', 3: '89.76%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.277457, Train-Class-Acc: {0: '85.07%', 1: '96.00%', 2: '99.70%', 3: '90.26%'}
# Val Loss: 0.210530, Val Acc: 96.44%, Val-Class-Acc: {0: '87.37%', 1: '98.12%', 3: '93.85%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.197873, Train-Class-Acc: {0: '90.36%', 1: '96.65%', 2: '99.70%', 3: '95.31%'}
# Val Loss: 0.160211, Val Acc: 96.71%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 3: '94.60%', 2: '100.00%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.153671, Train-Class-Acc: {0: '92.30%', 1: '96.80%', 2: '99.85%', 3: '96.80%'}
# Val Loss: 0.133839, Val Acc: 96.74%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 3: '95.34%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.122937, Train-Class-Acc: {0: '92.85%', 1: '97.67%', 2: '99.79%', 3: '97.23%'}
# Val Loss: 0.124590, Val Acc: 96.54%, Val-Class-Acc: {0: '86.35%', 1: '97.93%', 3: '95.53%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.111659, Train-Class-Acc: {0: '92.69%', 1: '96.65%', 2: '99.79%', 3: '97.23%'}
# Val Loss: 0.105769, Val Acc: 96.95%, Val-Class-Acc: {0: '87.37%', 1: '97.93%', 3: '96.83%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.095476, Train-Class-Acc: {0: '94.09%', 1: '97.02%', 2: '99.85%', 3: '98.08%'}
# Val Loss: 0.095919, Val Acc: 97.35%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 3: '97.39%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.086100, Train-Class-Acc: {0: '94.40%', 1: '97.31%', 2: '99.94%', 3: '97.37%'}
# Val Loss: 0.087787, Val Acc: 97.56%, Val-Class-Acc: {0: '91.45%', 1: '97.18%', 3: '97.21%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.075039, Train-Class-Acc: {0: '95.33%', 1: '97.38%', 2: '99.85%', 3: '98.58%'}
# Val Loss: 0.082441, Val Acc: 97.83%, Val-Class-Acc: {0: '91.85%', 1: '96.43%', 3: '99.07%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.071269, Train-Class-Acc: {0: '95.33%', 1: '96.29%', 2: '99.79%', 3: '98.37%'}
# Val Loss: 0.083427, Val Acc: 97.35%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 3: '97.77%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.066643, Train-Class-Acc: {0: '94.95%', 1: '97.23%', 2: '99.76%', 3: '98.79%'}
# Val Loss: 0.095381, Val Acc: 96.95%, Val-Class-Acc: {0: '86.35%', 1: '98.50%', 3: '97.21%', 2: '100.00%'}, LR: 0.000100
# Epoch 14/1000, Train Loss: 0.061409, Train-Class-Acc: {0: '94.87%', 1: '96.94%', 2: '99.97%', 3: '99.08%'}
# Val Loss: 0.077798, Val Acc: 97.86%, Val-Class-Acc: {0: '91.85%', 1: '96.80%', 3: '98.88%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.054705, Train-Class-Acc: {0: '96.66%', 1: '97.09%', 2: '99.91%', 3: '98.79%'}
# Val Loss: 0.079909, Val Acc: 97.59%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '98.51%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.053089, Train-Class-Acc: {0: '96.27%', 1: '97.67%', 2: '100.00%', 3: '98.93%'}
# Val Loss: 0.079838, Val Acc: 97.69%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '99.07%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.054786, Train-Class-Acc: {0: '96.03%', 1: '96.65%', 2: '99.94%', 3: '98.72%'}
# Val Loss: 0.084361, Val Acc: 97.42%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 3: '98.51%', 2: '100.00%'}, LR: 0.000100
# Epoch 18/1000, Train Loss: 0.053217, Train-Class-Acc: {0: '95.80%', 1: '96.87%', 2: '99.94%', 3: '99.08%'}
# Val Loss: 0.076395, Val Acc: 97.79%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 3: '99.26%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.053740, Train-Class-Acc: {0: '95.18%', 1: '96.72%', 2: '99.85%', 3: '99.00%'}
# Val Loss: 0.081002, Val Acc: 97.69%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 3: '99.07%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.050405, Train-Class-Acc: {0: '96.50%', 1: '97.31%', 2: '99.85%', 3: '98.51%'}
# Val Loss: 0.085537, Val Acc: 97.46%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 3: '99.26%', 2: '100.00%'}, LR: 0.000100
# Epoch 21/1000, Train Loss: 0.044852, Train-Class-Acc: {0: '96.58%', 1: '97.96%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.084089, Val Acc: 97.56%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 3: '99.26%', 2: '100.00%'}, LR: 0.000100
# Epoch 22/1000, Train Loss: 0.046909, Train-Class-Acc: {0: '96.19%', 1: '96.72%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.077647, Val Acc: 97.96%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.042968, Train-Class-Acc: {0: '96.42%', 1: '97.74%', 2: '99.94%', 3: '98.86%'}
# Val Loss: 0.082967, Val Acc: 97.79%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.043375, Train-Class-Acc: {0: '96.66%', 1: '97.96%', 2: '99.91%', 3: '99.00%'}
# Val Loss: 0.087920, Val Acc: 97.46%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 3: '99.07%', 2: '100.00%'}, LR: 0.000100
# Epoch 25/1000, Train Loss: 0.043020, Train-Class-Acc: {0: '97.12%', 1: '97.23%', 2: '99.79%', 3: '99.15%'}
# Val Loss: 0.078136, Val Acc: 97.93%, Val-Class-Acc: {0: '90.84%', 1: '97.37%', 3: '99.63%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.037161, Train-Class-Acc: {0: '97.05%', 1: '97.60%', 2: '99.91%', 3: '99.00%'}
# Val Loss: 0.077784, Val Acc: 97.96%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.042503, Train-Class-Acc: {0: '95.88%', 1: '97.74%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.085644, Val Acc: 97.69%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 3: '99.44%', 2: '100.00%'}, LR: 0.000100
# Epoch 28/1000, Train Loss: 0.041953, Train-Class-Acc: {0: '96.97%', 1: '97.31%', 2: '99.88%', 3: '98.86%'}
# Val Loss: 0.086816, Val Acc: 97.56%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 29/1000, Train Loss: 0.041243, Train-Class-Acc: {0: '96.42%', 1: '97.74%', 2: '99.94%', 3: '98.93%'}
# Val Loss: 0.087361, Val Acc: 97.69%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 30/1000, Train Loss: 0.040306, Train-Class-Acc: {0: '96.66%', 1: '96.94%', 2: '99.91%', 3: '99.29%'}
# Val Loss: 0.091494, Val Acc: 97.49%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 31/1000, Train Loss: 0.039688, Train-Class-Acc: {0: '96.58%', 1: '97.31%', 2: '99.94%', 3: '98.86%'}
# Val Loss: 0.079476, Val Acc: 97.96%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.037210, Train-Class-Acc: {0: '96.66%', 1: '97.74%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.084499, Val Acc: 97.66%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 33/1000, Train Loss: 0.038411, Train-Class-Acc: {0: '96.89%', 1: '97.67%', 2: '99.94%', 3: '98.86%'}
# Val Loss: 0.081605, Val Acc: 97.79%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 34/1000, Train Loss: 0.038384, Train-Class-Acc: {0: '96.97%', 1: '97.45%', 2: '99.94%', 3: '99.22%'}
# Val Loss: 0.083381, Val Acc: 97.93%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 3: '99.63%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_34.pth
# Epoch 35/1000, Train Loss: 0.036255, Train-Class-Acc: {0: '96.27%', 1: '97.38%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.086434, Val Acc: 97.62%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.034489, Train-Class-Acc: {0: '97.12%', 1: '97.60%', 2: '99.97%', 3: '98.86%'}
# Val Loss: 0.081616, Val Acc: 97.93%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 37/1000, Train Loss: 0.030939, Train-Class-Acc: {0: '97.98%', 1: '97.74%', 2: '99.94%', 3: '99.22%'}
# Val Loss: 0.085929, Val Acc: 97.93%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.039183, Train-Class-Acc: {0: '95.88%', 1: '97.53%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.083676, Val Acc: 98.00%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_38.pth
# Epoch 39/1000, Train Loss: 0.039098, Train-Class-Acc: {0: '96.66%', 1: '96.87%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.089400, Val Acc: 97.76%, Val-Class-Acc: {0: '89.21%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 40/1000, Train Loss: 0.033886, Train-Class-Acc: {0: '97.12%', 1: '97.82%', 2: '99.94%', 3: '98.93%'}
# Val Loss: 0.083238, Val Acc: 97.96%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_34.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_40.pth
# Epoch 41/1000, Train Loss: 0.036683, Train-Class-Acc: {0: '96.42%', 1: '97.45%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.093257, Val Acc: 97.62%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.035915, Train-Class-Acc: {0: '96.73%', 1: '97.31%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.085765, Val Acc: 97.90%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 43/1000, Train Loss: 0.031808, Train-Class-Acc: {0: '97.28%', 1: '97.82%', 2: '99.97%', 3: '98.86%'}
# Val Loss: 0.083610, Val Acc: 98.00%, Val-Class-Acc: {0: '91.45%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.034500, Train-Class-Acc: {0: '97.28%', 1: '97.60%', 2: '99.97%', 3: '99.29%'}
# Val Loss: 0.092761, Val Acc: 97.73%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.033240, Train-Class-Acc: {0: '96.19%', 1: '97.53%', 2: '99.94%', 3: '99.15%'}
# Val Loss: 0.090964, Val Acc: 97.86%, Val-Class-Acc: {0: '89.00%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.032944, Train-Class-Acc: {0: '96.81%', 1: '98.11%', 2: '99.85%', 3: '99.36%'}
# Val Loss: 0.085158, Val Acc: 98.00%, Val-Class-Acc: {0: '91.04%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.030965, Train-Class-Acc: {0: '96.66%', 1: '98.11%', 2: '99.91%', 3: '99.22%'}
# Val Loss: 0.085096, Val Acc: 98.07%, Val-Class-Acc: {0: '91.24%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.031279, Train-Class-Acc: {0: '97.67%', 1: '97.45%', 2: '99.94%', 3: '99.08%'}
# Val Loss: 0.097138, Val Acc: 97.73%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 49/1000, Train Loss: 0.027795, Train-Class-Acc: {0: '97.67%', 1: '97.74%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.088368, Val Acc: 97.86%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 50/1000, Train Loss: 0.033319, Train-Class-Acc: {0: '97.43%', 1: '97.96%', 2: '99.94%', 3: '98.86%'}
# Val Loss: 0.088586, Val Acc: 97.90%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.038760, Train-Class-Acc: {0: '96.03%', 1: '97.53%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.093548, Val Acc: 97.66%, Val-Class-Acc: {0: '88.19%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.029986, Train-Class-Acc: {0: '96.89%', 1: '98.47%', 2: '100.00%', 3: '99.08%'}
# Val Loss: 0.085085, Val Acc: 98.00%, Val-Class-Acc: {0: '91.65%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_40.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.031974, Train-Class-Acc: {0: '97.05%', 1: '97.23%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.089488, Val Acc: 97.93%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.033067, Train-Class-Acc: {0: '96.58%', 1: '98.33%', 2: '99.88%', 3: '98.72%'}
# Val Loss: 0.096493, Val Acc: 97.73%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.027112, Train-Class-Acc: {0: '97.82%', 1: '97.23%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.092934, Val Acc: 97.96%, Val-Class-Acc: {0: '90.43%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.030790, Train-Class-Acc: {0: '97.20%', 1: '97.60%', 2: '99.94%', 3: '99.64%'}
# Val Loss: 0.088943, Val Acc: 98.00%, Val-Class-Acc: {0: '91.24%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.031553, Train-Class-Acc: {0: '97.05%', 1: '97.82%', 2: '99.94%', 3: '99.50%'}
# Val Loss: 0.089775, Val Acc: 97.96%, Val-Class-Acc: {0: '90.63%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.026296, Train-Class-Acc: {0: '96.89%', 1: '98.25%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.091192, Val Acc: 97.93%, Val-Class-Acc: {0: '90.02%', 1: '97.93%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.030940, Train-Class-Acc: {0: '97.36%', 1: '97.74%', 2: '99.91%', 3: '99.15%'}
# Val Loss: 0.114148, Val Acc: 97.22%, Val-Class-Acc: {0: '84.73%', 1: '98.87%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.034890, Train-Class-Acc: {0: '96.89%', 1: '97.53%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.101448, Val Acc: 97.52%, Val-Class-Acc: {0: '87.17%', 1: '98.31%', 3: '99.81%', 2: '100.00%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.032448, Train-Class-Acc: {0: '97.20%', 1: '97.45%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.088194, Val Acc: 97.90%, Val-Class-Acc: {0: '91.24%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 62/1000, Train Loss: 0.029287, Train-Class-Acc: {0: '97.43%', 1: '97.82%', 2: '99.88%', 3: '99.36%'}
# Val Loss: 0.101904, Val Acc: 97.39%, Val-Class-Acc: {0: '86.35%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 63/1000, Train Loss: 0.029853, Train-Class-Acc: {0: '97.36%', 1: '97.82%', 2: '99.88%', 3: '98.93%'}
# Val Loss: 0.091338, Val Acc: 97.86%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.031048, Train-Class-Acc: {0: '96.97%', 1: '97.60%', 2: '99.91%', 3: '99.43%'}
# Val Loss: 0.093079, Val Acc: 97.90%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.033587, Train-Class-Acc: {0: '97.05%', 1: '97.38%', 2: '99.76%', 3: '99.22%'}
# Val Loss: 0.091412, Val Acc: 97.86%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.027053, Train-Class-Acc: {0: '97.20%', 1: '98.62%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.094765, Val Acc: 97.86%, Val-Class-Acc: {0: '89.00%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.028489, Train-Class-Acc: {0: '97.59%', 1: '98.33%', 2: '99.91%', 3: '99.15%'}
# Val Loss: 0.090719, Val Acc: 97.96%, Val-Class-Acc: {0: '91.45%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.033632, Train-Class-Acc: {0: '96.81%', 1: '97.96%', 2: '99.94%', 3: '99.22%'}
# Val Loss: 0.095168, Val Acc: 97.86%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.027654, Train-Class-Acc: {0: '97.28%', 1: '98.40%', 2: '99.91%', 3: '99.43%'}
# Val Loss: 0.107052, Val Acc: 97.66%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.027787, Train-Class-Acc: {0: '97.36%', 1: '98.18%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.094040, Val Acc: 97.86%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.028820, Train-Class-Acc: {0: '97.59%', 1: '97.74%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.100165, Val Acc: 97.83%, Val-Class-Acc: {0: '89.00%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.032204, Train-Class-Acc: {0: '96.50%', 1: '98.40%', 2: '99.85%', 3: '99.36%'}
# Val Loss: 0.095266, Val Acc: 97.93%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.033049, Train-Class-Acc: {0: '97.05%', 1: '97.09%', 2: '99.91%', 3: '99.43%'}
# Val Loss: 0.101136, Val Acc: 97.76%, Val-Class-Acc: {0: '88.19%', 1: '98.50%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.032217, Train-Class-Acc: {0: '97.05%', 1: '98.11%', 2: '99.88%', 3: '99.22%'}
# Val Loss: 0.107548, Val Acc: 97.52%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.031747, Train-Class-Acc: {0: '97.36%', 1: '97.96%', 2: '99.88%', 3: '98.93%'}
# Val Loss: 0.101354, Val Acc: 97.86%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.026891, Train-Class-Acc: {0: '97.51%', 1: '98.11%', 2: '99.97%', 3: '99.79%'}
# Val Loss: 0.096997, Val Acc: 97.86%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.027352, Train-Class-Acc: {0: '96.73%', 1: '97.96%', 2: '99.88%', 3: '99.43%'}
# Val Loss: 0.102575, Val Acc: 97.69%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.022431, Train-Class-Acc: {0: '98.13%', 1: '98.62%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.099001, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.028546, Train-Class-Acc: {0: '97.20%', 1: '97.96%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.094346, Val Acc: 97.83%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.029166, Train-Class-Acc: {0: '97.36%', 1: '97.74%', 2: '99.94%', 3: '99.15%'}
# Val Loss: 0.105910, Val Acc: 97.73%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.026427, Train-Class-Acc: {0: '97.36%', 1: '98.54%', 2: '99.70%', 3: '99.43%'}
# Val Loss: 0.096576, Val Acc: 98.00%, Val-Class-Acc: {0: '90.63%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.032056, Train-Class-Acc: {0: '96.66%', 1: '97.96%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.095888, Val Acc: 97.86%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.035940, Train-Class-Acc: {0: '97.20%', 1: '97.23%', 2: '99.91%', 3: '99.15%'}
# Val Loss: 0.105886, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 84/1000, Train Loss: 0.026373, Train-Class-Acc: {0: '97.20%', 1: '98.03%', 2: '99.97%', 3: '99.64%'}
# Val Loss: 0.096949, Val Acc: 97.93%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 85/1000, Train Loss: 0.027909, Train-Class-Acc: {0: '97.74%', 1: '97.96%', 2: '99.91%', 3: '98.93%'}
# Val Loss: 0.108225, Val Acc: 97.66%, Val-Class-Acc: {0: '87.78%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.026027, Train-Class-Acc: {0: '97.20%', 1: '98.11%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.101638, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 87/1000, Train Loss: 0.029078, Train-Class-Acc: {0: '96.81%', 1: '97.89%', 2: '99.91%', 3: '99.22%'}
# Val Loss: 0.105374, Val Acc: 97.52%, Val-Class-Acc: {0: '86.76%', 1: '98.50%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.029324, Train-Class-Acc: {0: '97.36%', 1: '97.60%', 2: '99.94%', 3: '99.57%'}
# Val Loss: 0.098999, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.025644, Train-Class-Acc: {0: '97.59%', 1: '98.18%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.099286, Val Acc: 97.93%, Val-Class-Acc: {0: '91.24%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.030074, Train-Class-Acc: {0: '97.28%', 1: '97.82%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.105638, Val Acc: 97.79%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.029521, Train-Class-Acc: {0: '97.28%', 1: '98.18%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.104862, Val Acc: 97.76%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.028964, Train-Class-Acc: {0: '97.43%', 1: '98.11%', 2: '99.94%', 3: '98.93%'}
# Val Loss: 0.110042, Val Acc: 97.62%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.030779, Train-Class-Acc: {0: '96.66%', 1: '98.18%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.104880, Val Acc: 97.90%, Val-Class-Acc: {0: '89.61%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.026922, Train-Class-Acc: {0: '97.51%', 1: '98.03%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.112367, Val Acc: 97.66%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.025946, Train-Class-Acc: {0: '97.12%', 1: '98.25%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.104061, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.025441, Train-Class-Acc: {0: '97.28%', 1: '97.96%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.096440, Val Acc: 97.96%, Val-Class-Acc: {0: '91.65%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.027571, Train-Class-Acc: {0: '97.12%', 1: '97.67%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.100033, Val Acc: 98.00%, Val-Class-Acc: {0: '92.06%', 1: '96.24%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.029250, Train-Class-Acc: {0: '96.97%', 1: '97.67%', 2: '99.91%', 3: '99.15%'}
# Val Loss: 0.107141, Val Acc: 97.79%, Val-Class-Acc: {0: '89.00%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.027877, Train-Class-Acc: {0: '97.28%', 1: '98.11%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.099205, Val Acc: 97.83%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.026656, Train-Class-Acc: {0: '97.36%', 1: '97.89%', 2: '99.91%', 3: '99.57%'}
# Val Loss: 0.113435, Val Acc: 97.49%, Val-Class-Acc: {0: '86.76%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 101/1000, Train Loss: 0.030901, Train-Class-Acc: {0: '96.81%', 1: '97.89%', 2: '99.94%', 3: '99.00%'}
# Val Loss: 0.112199, Val Acc: 97.56%, Val-Class-Acc: {0: '87.78%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.028640, Train-Class-Acc: {0: '97.20%', 1: '97.96%', 2: '99.88%', 3: '99.43%'}
# Val Loss: 0.103532, Val Acc: 97.76%, Val-Class-Acc: {0: '89.61%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.033924, Train-Class-Acc: {0: '97.20%', 1: '97.74%', 2: '99.85%', 3: '99.29%'}
# Val Loss: 0.102391, Val Acc: 97.83%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.026495, Train-Class-Acc: {0: '97.20%', 1: '98.40%', 2: '99.94%', 3: '99.00%'}
# Val Loss: 0.098698, Val Acc: 97.86%, Val-Class-Acc: {0: '90.84%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.025090, Train-Class-Acc: {0: '97.43%', 1: '97.96%', 2: '99.97%', 3: '99.72%'}
# Val Loss: 0.101474, Val Acc: 97.86%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.027353, Train-Class-Acc: {0: '97.74%', 1: '98.03%', 2: '99.97%', 3: '99.29%'}
# Val Loss: 0.104703, Val Acc: 97.86%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.026369, Train-Class-Acc: {0: '97.67%', 1: '97.89%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.106368, Val Acc: 97.83%, Val-Class-Acc: {0: '88.80%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.028430, Train-Class-Acc: {0: '97.67%', 1: '98.18%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.091974, Val Acc: 98.00%, Val-Class-Acc: {0: '92.26%', 1: '96.05%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.026192, Train-Class-Acc: {0: '97.51%', 1: '98.40%', 2: '99.85%', 3: '99.15%'}
# Val Loss: 0.118914, Val Acc: 97.59%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.025112, Train-Class-Acc: {0: '97.67%', 1: '98.33%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.110413, Val Acc: 97.76%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.026252, Train-Class-Acc: {0: '97.36%', 1: '98.03%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.109535, Val Acc: 97.79%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.026926, Train-Class-Acc: {0: '97.43%', 1: '98.18%', 2: '99.94%', 3: '99.15%'}
# Val Loss: 0.107485, Val Acc: 97.86%, Val-Class-Acc: {0: '89.41%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.025780, Train-Class-Acc: {0: '97.51%', 1: '97.89%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.107326, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.027932, Train-Class-Acc: {0: '97.67%', 1: '97.45%', 2: '99.94%', 3: '99.50%'}
# Val Loss: 0.101709, Val Acc: 97.79%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.026660, Train-Class-Acc: {0: '98.06%', 1: '98.18%', 2: '99.94%', 3: '99.15%'}
# Val Loss: 0.114394, Val Acc: 97.69%, Val-Class-Acc: {0: '87.98%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.021264, Train-Class-Acc: {0: '98.13%', 1: '99.05%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.104006, Val Acc: 97.93%, Val-Class-Acc: {0: '90.84%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.028673, Train-Class-Acc: {0: '96.73%', 1: '97.67%', 2: '99.97%', 3: '99.64%'}
# Val Loss: 0.106914, Val Acc: 97.76%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.022735, Train-Class-Acc: {0: '98.13%', 1: '98.62%', 2: '99.88%', 3: '99.64%'}
# Val Loss: 0.112435, Val Acc: 97.73%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.027257, Train-Class-Acc: {0: '97.36%', 1: '98.33%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.109280, Val Acc: 97.76%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.024364, Train-Class-Acc: {0: '97.43%', 1: '98.40%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.109586, Val Acc: 97.79%, Val-Class-Acc: {0: '89.41%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.027893, Train-Class-Acc: {0: '97.28%', 1: '98.11%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.107418, Val Acc: 97.79%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.023898, Train-Class-Acc: {0: '97.59%', 1: '98.03%', 2: '99.97%', 3: '99.15%'}
# Val Loss: 0.110272, Val Acc: 97.66%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.031078, Train-Class-Acc: {0: '96.66%', 1: '98.33%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.109627, Val Acc: 97.69%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 124/1000, Train Loss: 0.029153, Train-Class-Acc: {0: '97.20%', 1: '97.89%', 2: '100.00%', 3: '99.43%'}
# Val Loss: 0.106956, Val Acc: 97.93%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 125/1000, Train Loss: 0.029293, Train-Class-Acc: {0: '96.97%', 1: '97.96%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.109727, Val Acc: 97.79%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 126/1000, Train Loss: 0.024352, Train-Class-Acc: {0: '98.13%', 1: '97.60%', 2: '99.85%', 3: '99.29%'}
# Val Loss: 0.117192, Val Acc: 97.62%, Val-Class-Acc: {0: '87.37%', 1: '98.50%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 127/1000, Train Loss: 0.028984, Train-Class-Acc: {0: '97.36%', 1: '98.03%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.107801, Val Acc: 97.66%, Val-Class-Acc: {0: '89.00%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 128/1000, Train Loss: 0.025178, Train-Class-Acc: {0: '97.36%', 1: '98.11%', 2: '99.94%', 3: '99.57%'}
# Val Loss: 0.104658, Val Acc: 97.83%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 129/1000, Train Loss: 0.023269, Train-Class-Acc: {0: '97.20%', 1: '97.96%', 2: '99.94%', 3: '99.72%'}
# Val Loss: 0.101408, Val Acc: 97.90%, Val-Class-Acc: {0: '91.04%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 130/1000, Train Loss: 0.027747, Train-Class-Acc: {0: '97.43%', 1: '98.11%', 2: '99.88%', 3: '99.29%'}
# Val Loss: 0.116876, Val Acc: 97.62%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 131/1000, Train Loss: 0.028461, Train-Class-Acc: {0: '97.05%', 1: '97.82%', 2: '99.91%', 3: '99.50%'}
# Val Loss: 0.108132, Val Acc: 97.76%, Val-Class-Acc: {0: '89.21%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 132/1000, Train Loss: 0.028626, Train-Class-Acc: {0: '96.97%', 1: '98.03%', 2: '100.00%', 3: '99.43%'}
# Val Loss: 0.106723, Val Acc: 97.90%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 133/1000, Train Loss: 0.029525, Train-Class-Acc: {0: '97.51%', 1: '98.03%', 2: '100.00%', 3: '99.29%'}
# Val Loss: 0.107136, Val Acc: 97.79%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 134/1000, Train Loss: 0.024500, Train-Class-Acc: {0: '97.67%', 1: '98.03%', 2: '99.97%', 3: '99.64%'}
# Val Loss: 0.114996, Val Acc: 97.56%, Val-Class-Acc: {0: '87.17%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 135/1000, Train Loss: 0.025279, Train-Class-Acc: {0: '97.36%', 1: '98.11%', 2: '100.00%', 3: '99.43%'}
# Val Loss: 0.107869, Val Acc: 97.90%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 136/1000, Train Loss: 0.024651, Train-Class-Acc: {0: '97.36%', 1: '98.18%', 2: '99.94%', 3: '99.64%'}
# Val Loss: 0.115540, Val Acc: 97.62%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 137/1000, Train Loss: 0.023745, Train-Class-Acc: {0: '97.67%', 1: '98.76%', 2: '99.91%', 3: '99.50%'}
# Val Loss: 0.110601, Val Acc: 97.79%, Val-Class-Acc: {0: '88.80%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 138/1000, Train Loss: 0.023887, Train-Class-Acc: {0: '97.67%', 1: '98.47%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.105461, Val Acc: 97.79%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 139/1000, Train Loss: 0.028193, Train-Class-Acc: {0: '97.28%', 1: '98.25%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.110530, Val Acc: 97.76%, Val-Class-Acc: {0: '88.39%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 140/1000, Train Loss: 0.023890, Train-Class-Acc: {0: '97.59%', 1: '98.54%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.104777, Val Acc: 97.86%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 141/1000, Train Loss: 0.026064, Train-Class-Acc: {0: '97.67%', 1: '97.74%', 2: '99.91%', 3: '99.64%'}
# Val Loss: 0.113152, Val Acc: 97.76%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 142/1000, Train Loss: 0.027769, Train-Class-Acc: {0: '97.20%', 1: '98.18%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.111260, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 143/1000, Train Loss: 0.017010, Train-Class-Acc: {0: '98.68%', 1: '98.84%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.104956, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 144/1000, Train Loss: 0.027658, Train-Class-Acc: {0: '97.67%', 1: '98.03%', 2: '99.85%', 3: '99.36%'}
# Val Loss: 0.110425, Val Acc: 97.83%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 145/1000, Train Loss: 0.027662, Train-Class-Acc: {0: '97.36%', 1: '98.03%', 2: '99.91%', 3: '98.93%'}
# Val Loss: 0.111829, Val Acc: 97.76%, Val-Class-Acc: {0: '88.39%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 146/1000, Train Loss: 0.024083, Train-Class-Acc: {0: '97.51%', 1: '98.03%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.112170, Val Acc: 97.76%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 147/1000, Train Loss: 0.025589, Train-Class-Acc: {0: '98.21%', 1: '97.67%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.112548, Val Acc: 97.69%, Val-Class-Acc: {0: '88.39%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 148/1000, Train Loss: 0.026194, Train-Class-Acc: {0: '97.05%', 1: '98.03%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.121523, Val Acc: 97.59%, Val-Class-Acc: {0: '87.37%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 149/1000, Train Loss: 0.025632, Train-Class-Acc: {0: '97.98%', 1: '97.89%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.110253, Val Acc: 97.83%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 150/1000, Train Loss: 0.025828, Train-Class-Acc: {0: '96.81%', 1: '98.18%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.110879, Val Acc: 97.79%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 151/1000, Train Loss: 0.025048, Train-Class-Acc: {0: '96.89%', 1: '98.33%', 2: '99.97%', 3: '99.22%'}
# Val Loss: 0.108093, Val Acc: 97.90%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 152/1000, Train Loss: 0.022271, Train-Class-Acc: {0: '98.06%', 1: '98.62%', 2: '99.91%', 3: '99.29%'}
# Val Loss: 0.106261, Val Acc: 97.83%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 153/1000, Train Loss: 0.023337, Train-Class-Acc: {0: '97.59%', 1: '98.11%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.120430, Val Acc: 97.73%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 154/1000, Train Loss: 0.021696, Train-Class-Acc: {0: '98.13%', 1: '98.47%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.110270, Val Acc: 97.79%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 155/1000, Train Loss: 0.023006, Train-Class-Acc: {0: '97.82%', 1: '98.91%', 2: '99.94%', 3: '99.57%'}
# Val Loss: 0.107749, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 156/1000, Train Loss: 0.028245, Train-Class-Acc: {0: '97.90%', 1: '98.47%', 2: '99.94%', 3: '98.79%'}
# Val Loss: 0.126554, Val Acc: 97.52%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 157/1000, Train Loss: 0.025819, Train-Class-Acc: {0: '97.59%', 1: '97.96%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.116263, Val Acc: 97.66%, Val-Class-Acc: {0: '88.19%', 1: '97.93%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 158/1000, Train Loss: 0.027912, Train-Class-Acc: {0: '97.51%', 1: '98.47%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.126862, Val Acc: 97.56%, Val-Class-Acc: {0: '87.17%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 159/1000, Train Loss: 0.023524, Train-Class-Acc: {0: '98.29%', 1: '98.25%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.114061, Val Acc: 97.83%, Val-Class-Acc: {0: '89.41%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 160/1000, Train Loss: 0.022998, Train-Class-Acc: {0: '97.51%', 1: '98.18%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.102504, Val Acc: 97.96%, Val-Class-Acc: {0: '91.65%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 161/1000, Train Loss: 0.028022, Train-Class-Acc: {0: '97.51%', 1: '97.82%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.107698, Val Acc: 97.83%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 162/1000, Train Loss: 0.021402, Train-Class-Acc: {0: '98.21%', 1: '98.18%', 2: '99.97%', 3: '99.36%'}
# Val Loss: 0.113237, Val Acc: 97.76%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 163/1000, Train Loss: 0.023509, Train-Class-Acc: {0: '97.59%', 1: '98.54%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.107202, Val Acc: 97.79%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 164/1000, Train Loss: 0.021639, Train-Class-Acc: {0: '97.98%', 1: '98.62%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.114302, Val Acc: 97.66%, Val-Class-Acc: {0: '88.80%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 165/1000, Train Loss: 0.020831, Train-Class-Acc: {0: '97.98%', 1: '98.47%', 2: '99.97%', 3: '99.29%'}
# Val Loss: 0.109716, Val Acc: 97.69%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 166/1000, Train Loss: 0.024550, Train-Class-Acc: {0: '98.13%', 1: '98.33%', 2: '99.94%', 3: '99.29%'}
# Val Loss: 0.115887, Val Acc: 97.73%, Val-Class-Acc: {0: '88.80%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 167/1000, Train Loss: 0.025043, Train-Class-Acc: {0: '97.59%', 1: '98.47%', 2: '100.00%', 3: '99.22%'}
# Val Loss: 0.112248, Val Acc: 97.76%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 168/1000, Train Loss: 0.024060, Train-Class-Acc: {0: '97.59%', 1: '98.03%', 2: '99.94%', 3: '99.43%'}
# Val Loss: 0.125113, Val Acc: 97.66%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 169/1000, Train Loss: 0.023404, Train-Class-Acc: {0: '97.36%', 1: '98.33%', 2: '99.94%', 3: '99.57%'}
# Val Loss: 0.105603, Val Acc: 97.83%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# ...
# Val Loss: 0.140247, Val Acc: 97.62%, Val-Class-Acc: {0: '88.80%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 945/1000, Train Loss: 0.019054, Train-Class-Acc: {0: '98.21%', 1: '98.33%', 2: '99.97%', 3: '99.72%'}
# Val Loss: 0.142571, Val Acc: 97.52%, Val-Class-Acc: {0: '88.39%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 946/1000, Train Loss: 0.017071, Train-Class-Acc: {0: '98.52%', 1: '99.05%', 2: '100.00%', 3: '99.43%'}
# Val Loss: 0.145370, Val Acc: 97.62%, Val-Class-Acc: {0: '89.21%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 947/1000, Train Loss: 0.024164, Train-Class-Acc: {0: '97.20%', 1: '98.11%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.135925, Val Acc: 97.59%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 948/1000, Train Loss: 0.019343, Train-Class-Acc: {0: '97.90%', 1: '98.54%', 2: '100.00%', 3: '99.29%'}
# Val Loss: 0.137398, Val Acc: 97.62%, Val-Class-Acc: {0: '89.21%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 949/1000, Train Loss: 0.019509, Train-Class-Acc: {0: '98.37%', 1: '98.69%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.140333, Val Acc: 97.42%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 950/1000, Train Loss: 0.017786, Train-Class-Acc: {0: '97.59%', 1: '98.54%', 2: '100.00%', 3: '99.79%'}
# Val Loss: 0.141649, Val Acc: 97.66%, Val-Class-Acc: {0: '89.41%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 951/1000, Train Loss: 0.021226, Train-Class-Acc: {0: '97.98%', 1: '98.54%', 2: '100.00%', 3: '99.72%'}
# Val Loss: 0.146585, Val Acc: 97.46%, Val-Class-Acc: {0: '87.37%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 952/1000, Train Loss: 0.020442, Train-Class-Acc: {0: '97.82%', 1: '98.54%', 2: '99.94%', 3: '99.50%'}
# Val Loss: 0.147892, Val Acc: 97.42%, Val-Class-Acc: {0: '87.17%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 953/1000, Train Loss: 0.024816, Train-Class-Acc: {0: '97.90%', 1: '98.03%', 2: '99.88%', 3: '99.50%'}
# Val Loss: 0.136575, Val Acc: 97.56%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 954/1000, Train Loss: 0.017205, Train-Class-Acc: {0: '98.06%', 1: '99.05%', 2: '100.00%', 3: '99.86%'}
# Val Loss: 0.135309, Val Acc: 97.56%, Val-Class-Acc: {0: '88.39%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 955/1000, Train Loss: 0.018353, Train-Class-Acc: {0: '97.90%', 1: '98.76%', 2: '99.94%', 3: '99.64%'}
# Val Loss: 0.136957, Val Acc: 97.62%, Val-Class-Acc: {0: '89.41%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.018602, Train-Class-Acc: {0: '98.13%', 1: '98.54%', 2: '100.00%', 3: '99.50%'}
# Val Loss: 0.134143, Val Acc: 97.59%, Val-Class-Acc: {0: '89.41%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.020008, Train-Class-Acc: {0: '97.90%', 1: '98.47%', 2: '99.91%', 3: '99.93%'}
# Val Loss: 0.144798, Val Acc: 97.35%, Val-Class-Acc: {0: '87.37%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.023747, Train-Class-Acc: {0: '97.59%', 1: '98.25%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.154062, Val Acc: 97.32%, Val-Class-Acc: {0: '86.56%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.020330, Train-Class-Acc: {0: '98.06%', 1: '98.40%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.134576, Val Acc: 97.73%, Val-Class-Acc: {0: '90.22%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.018148, Train-Class-Acc: {0: '98.37%', 1: '98.69%', 2: '99.94%', 3: '99.50%'}
# Val Loss: 0.136669, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.021980, Train-Class-Acc: {0: '98.06%', 1: '98.40%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.134652, Val Acc: 97.76%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.015917, Train-Class-Acc: {0: '98.99%', 1: '98.91%', 2: '99.88%', 3: '99.64%'}
# Val Loss: 0.139671, Val Acc: 97.59%, Val-Class-Acc: {0: '88.80%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.020689, Train-Class-Acc: {0: '97.59%', 1: '98.40%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.144679, Val Acc: 97.49%, Val-Class-Acc: {0: '88.19%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.019634, Train-Class-Acc: {0: '97.59%', 1: '98.54%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.139488, Val Acc: 97.49%, Val-Class-Acc: {0: '88.59%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.023728, Train-Class-Acc: {0: '97.82%', 1: '98.40%', 2: '99.91%', 3: '99.50%'}
# Val Loss: 0.144241, Val Acc: 97.73%, Val-Class-Acc: {0: '90.02%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.020295, Train-Class-Acc: {0: '98.52%', 2: '99.88%', 3: '99.57%', 1: '98.25%'}
# Val Loss: 0.136759, Val Acc: 97.73%, Val-Class-Acc: {0: '90.22%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.016659, Train-Class-Acc: {0: '98.44%', 1: '98.76%', 2: '99.94%', 3: '99.79%'}
# Val Loss: 0.141751, Val Acc: 97.56%, Val-Class-Acc: {0: '89.21%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.018242, Train-Class-Acc: {0: '98.13%', 1: '98.40%', 2: '99.94%', 3: '99.57%'}
# Val Loss: 0.148424, Val Acc: 97.39%, Val-Class-Acc: {0: '87.58%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.020578, Train-Class-Acc: {0: '98.21%', 1: '98.11%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.157059, Val Acc: 97.39%, Val-Class-Acc: {0: '86.97%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.022997, Train-Class-Acc: {0: '97.82%', 1: '98.40%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.142429, Val Acc: 97.69%, Val-Class-Acc: {0: '89.82%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.019142, Train-Class-Acc: {0: '97.98%', 1: '98.84%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.133412, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.022485, Train-Class-Acc: {0: '97.82%', 1: '98.69%', 2: '99.91%', 3: '99.57%'}
# Val Loss: 0.141052, Val Acc: 97.59%, Val-Class-Acc: {0: '89.00%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.019899, Train-Class-Acc: {0: '98.06%', 1: '98.76%', 2: '99.91%', 3: '99.57%'}
# Val Loss: 0.136993, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.017033, Train-Class-Acc: {0: '97.98%', 1: '98.69%', 2: '100.00%', 3: '99.57%'}
# Val Loss: 0.145080, Val Acc: 97.49%, Val-Class-Acc: {0: '88.80%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.025846, Train-Class-Acc: {0: '97.36%', 1: '98.25%', 2: '99.91%', 3: '99.29%'}
# Val Loss: 0.134839, Val Acc: 97.79%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.019547, Train-Class-Acc: {0: '98.13%', 1: '98.69%', 2: '99.97%', 3: '99.57%'}
# Val Loss: 0.140191, Val Acc: 97.42%, Val-Class-Acc: {0: '87.78%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.018424, Train-Class-Acc: {0: '98.37%', 1: '98.18%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.141854, Val Acc: 97.52%, Val-Class-Acc: {0: '88.80%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.019753, Train-Class-Acc: {0: '98.06%', 1: '99.05%', 2: '99.94%', 3: '99.36%'}
# Val Loss: 0.149507, Val Acc: 97.39%, Val-Class-Acc: {0: '86.97%', 1: '97.56%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.018109, Train-Class-Acc: {0: '98.37%', 1: '98.47%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.138649, Val Acc: 97.56%, Val-Class-Acc: {0: '88.59%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.021291, Train-Class-Acc: {0: '97.74%', 1: '98.40%', 2: '99.91%', 3: '99.79%'}
# Val Loss: 0.130674, Val Acc: 97.69%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.020300, Train-Class-Acc: {0: '98.29%', 1: '98.40%', 2: '99.94%', 3: '99.64%'}
# Val Loss: 0.141820, Val Acc: 97.52%, Val-Class-Acc: {0: '88.39%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.022210, Train-Class-Acc: {0: '97.43%', 1: '98.47%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.135245, Val Acc: 97.69%, Val-Class-Acc: {0: '89.61%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.021632, Train-Class-Acc: {0: '97.90%', 1: '98.47%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.134002, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.018110, Train-Class-Acc: {0: '97.90%', 1: '98.98%', 2: '99.97%', 3: '99.72%'}
# Val Loss: 0.138231, Val Acc: 97.83%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.027584, Train-Class-Acc: {0: '97.74%', 1: '97.96%', 2: '99.85%', 3: '99.57%'}
# Val Loss: 0.133851, Val Acc: 97.69%, Val-Class-Acc: {0: '90.02%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.020760, Train-Class-Acc: {0: '97.82%', 1: '98.18%', 2: '100.00%', 3: '99.29%'}
# Val Loss: 0.160355, Val Acc: 97.56%, Val-Class-Acc: {0: '87.17%', 1: '98.31%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.019549, Train-Class-Acc: {0: '98.29%', 1: '98.40%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.135537, Val Acc: 97.69%, Val-Class-Acc: {0: '90.02%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.021049, Train-Class-Acc: {0: '97.90%', 1: '98.40%', 2: '100.00%', 3: '99.36%'}
# Val Loss: 0.137590, Val Acc: 97.42%, Val-Class-Acc: {0: '87.98%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.021127, Train-Class-Acc: {0: '97.36%', 1: '98.47%', 2: '99.94%', 3: '99.79%'}
# Val Loss: 0.131865, Val Acc: 97.76%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.019829, Train-Class-Acc: {0: '98.06%', 1: '98.76%', 2: '99.88%', 3: '99.29%'}
# Val Loss: 0.149120, Val Acc: 97.35%, Val-Class-Acc: {0: '87.37%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.023309, Train-Class-Acc: {0: '97.67%', 1: '98.47%', 2: '99.88%', 3: '99.64%'}
# Val Loss: 0.132613, Val Acc: 97.73%, Val-Class-Acc: {0: '90.22%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.023684, Train-Class-Acc: {0: '97.59%', 1: '98.18%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.148098, Val Acc: 97.42%, Val-Class-Acc: {0: '87.58%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.024300, Train-Class-Acc: {0: '97.43%', 1: '98.40%', 2: '99.97%', 3: '99.50%'}
# Val Loss: 0.139426, Val Acc: 97.56%, Val-Class-Acc: {0: '89.41%', 1: '96.24%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.023215, Train-Class-Acc: {0: '97.20%', 1: '98.62%', 2: '99.91%', 3: '99.43%'}
# Val Loss: 0.137007, Val Acc: 97.59%, Val-Class-Acc: {0: '89.21%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.019561, Train-Class-Acc: {0: '98.06%', 1: '98.18%', 2: '99.88%', 3: '99.64%'}
# Val Loss: 0.142021, Val Acc: 97.62%, Val-Class-Acc: {0: '89.61%', 1: '96.43%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.019793, Train-Class-Acc: {0: '98.06%', 1: '98.11%', 2: '99.97%', 3: '99.72%'}
# Val Loss: 0.145240, Val Acc: 97.39%, Val-Class-Acc: {0: '87.78%', 1: '96.80%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.024033, Train-Class-Acc: {0: '98.13%', 1: '98.47%', 2: '99.91%', 3: '99.57%'}
# Val Loss: 0.137257, Val Acc: 97.73%, Val-Class-Acc: {0: '90.02%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.023593, Train-Class-Acc: {0: '97.67%', 1: '98.54%', 2: '99.94%', 3: '99.50%'}
# Val Loss: 0.140861, Val Acc: 97.73%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.020581, Train-Class-Acc: {0: '97.98%', 1: '97.89%', 2: '100.00%', 3: '99.64%'}
# Val Loss: 0.144262, Val Acc: 97.35%, Val-Class-Acc: {0: '87.17%', 1: '97.18%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.020920, Train-Class-Acc: {0: '98.13%', 1: '98.40%', 2: '99.97%', 3: '99.43%'}
# Val Loss: 0.147138, Val Acc: 97.49%, Val-Class-Acc: {0: '88.19%', 1: '96.99%', 3: '100.00%', 2: '100.00%'}, LR: 0.000100
#
# ⏳ Total training time: 423.39 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_best.pth (Val Accuracy: 98.07%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 47, Train Loss: 0.030965, Train-Acc: {0: '96.66%', 1: '98.11%', 2: '99.91%', 3: '99.22%'},
# Val Loss: 0.085096, Val Acc: 98.07%, Val-Acc: {0: '91.24%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_47.pth
# Epoch 699, Train Loss: 0.021987, Train-Acc: {0: '97.20%', 1: '98.76%', 2: '99.97%', 3: '99.57%'},
# Val Loss: 0.123730, Val Acc: 98.03%, Val-Acc: {0: '92.46%', 1: '96.05%', 3: '100.00%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_699.pth
# Epoch 693, Train Loss: 0.018654, Train-Acc: {0: '98.21%', 1: '98.47%', 2: '99.97%', 3: '99.64%'},
# Val Loss: 0.126114, Val Acc: 98.03%, Val-Acc: {0: '92.26%', 1: '96.24%', 3: '100.00%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_693.pth
# Epoch 494, Train Loss: 0.020299, Train-Acc: {0: '98.21%', 1: '98.11%', 2: '100.00%', 3: '99.79%'},
# Val Loss: 0.119493, Val Acc: 98.03%, Val-Acc: {0: '92.46%', 1: '96.05%', 3: '100.00%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_494.pth
# Epoch 271, Train Loss: 0.024882, Train-Acc: {0: '97.36%', 1: '98.25%', 2: '99.85%', 3: '99.57%'},
# Val Loss: 0.113923, Val Acc: 98.03%, Val-Acc: {0: '91.85%', 1: '96.62%', 3: '100.00%', 2: '100.00%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3/HAR_MLP_LoRA_v2_epoch_271.pth
# ---
# ### Period 3
# + ##### Total training time: 423.39 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_3'*
# + ##### Best Epoch: 47
# #### __Val Accuracy: 98.07%__
# #### __Val-Class-Acc: {0: '91.24%', 1: '97.37%', 3: '100.00%', 2: '100.00%'}__
#
# ✅ Period 3 Training Complete. Final model architecture:
# HAR_MLP_LoRA_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3], num_classes = 4

# %% [markdown]
# ---
# ### Period 4
# + ##### Total training time: 550.57 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4'*
# + ##### Best Epoch: 86
# #### __Val Accuracy: 93.59%__
# #### __Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '95.77%', 5: '89.52%', 4: '88.32%'}__

# %%
# ================================
# 📌 Period 4 Configuration - HAR_MLP_LoRA_v2 (Standard LoRA)
# ================================
period = 4

# Load dataset for this period
X_train, y_train = period_datasets[period]["train"]
X_val, y_val     = period_datasets[period]["test"]

# Auto-select device
device = auto_select_cuda_device()

# Model hyperparameters
input_size    = X_train.shape[1]
hidden_size   = 128
output_size   = len(set(y_train))
dropout       = 0.2
lora_r        = 4
learning_rate = 0.0001
weight_decay  = 1e-5
num_epochs    = 1000

# Model saving path
model_name = "HAR_MLP_LoRA_v2"
model_saving_folder = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period}"
)
os.makedirs(model_saving_folder, exist_ok=True)

# === Load previous model (Period 3) ===
previous_model_path = os.path.join(
    "Class_Incremental_CL", "HAR_CIL", "Trained_models",
    "Standard_LoRA", f"Rank_{lora_r}_Period_{period - 1}", f"{model_name}_best.pth"
)
checkpoint = torch.load(previous_model_path, map_location=device)
previous_state_dict = checkpoint["model_state_dict"]

# === Initialize new model ===
model = HAR_MLP_LoRA_v2(
    input_size=input_size,
    hidden_size=hidden_size,
    output_size=output_size,
    dropout=dropout,
    lora_rank=lora_r
).to(device)

# === Init LoRA FIRST ===
model.init_lora()

# === Load weights (exclude fc3 & lora_adapter) ===
model.load_state_dict({
    k: v for k, v in previous_state_dict.items()
    if not k.startswith("fc3")
    # if not k.startswith("fc3") and not k.startswith("lora_adapter")
}, strict=False)

# === Optimizer / Criterion / Scheduler ===
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.get_trainable_parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = None

# === Training ===
train_with_standard_lora(
    model=model,
    output_size=output_size,
    criterion=criterion,
    optimizer=optimizer,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    num_epochs=num_epochs,
    batch_size=batch_size,
    model_saving_folder=model_saving_folder,
    model_name=model_name,
    stop_signal_file=stop_signal_file,
    scheduler=scheduler,
    period=period
)

# ================================
# ✅ Summary & Resource Cleanup
# ================================
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)

print(f"\n✅ Period {period} Training Complete. Final model architecture:")
print(model)
print(f"📊 Class Summary → unique_classes = {unique_classes}, num_classes = {num_classes}")

del X_train, y_train, X_val, y_val, model, checkpoint, previous_state_dict
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 16192 MiB
#     - Device Name    : NVIDIA RTX A6000
# ✅ Initialized LoRA adapter for fc2
# 🧠 Trainable parameters: 4 total
#   ✅ lora_adapter.A
#   ✅ lora_adapter.B
#   ✅ lora_adapter.linear.weight
#   ✅ lora_adapter.linear.bias
#   ✅ fc3.weight
#   ✅ fc3.bias
#
# 🚀 'train_with_standard_lora' started for Period 4
#
# ✅ Removed existing folder: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4
# 🎯 Automatically selected GPU:
#     - CUDA Device ID : 2
#     - Memory Used    : 16192 MiB
#     - Device Name    : NVIDIA RTX A6000
#
# ✅ Data Overview:
# X_train: torch.Size([7352, 561]), y_train: torch.Size([7352])
# X_val: torch.Size([2947, 561]), y_val: torch.Size([2947])
#
# 🔧 Model Parameter Overview:
# fc1.weight                                         | ✅ trainable  | shape=[128, 561]
# fc1.bias                                           | ✅ trainable  | shape=[128]
# bn1.weight                                         | ✅ trainable  | shape=[128]
# bn1.bias                                           | ✅ trainable  | shape=[128]
# fc2.weight                                         | ✅ trainable  | shape=[128, 128]
# fc2.bias                                           | ✅ trainable  | shape=[128]
# bn2.weight                                         | ✅ trainable  | shape=[128]
# bn2.bias                                           | ✅ trainable  | shape=[128]
# fc3.weight                                         | ✅ trainable  | shape=[6, 128]
# fc3.bias                                           | ✅ trainable  | shape=[6]
# lora_adapter.A                                     | ✅ trainable  | shape=[128, 4]
# lora_adapter.B                                     | ✅ trainable  | shape=[4, 128]
#
# 🧠 Optimizer Parameter Overview:
# lora_adapter.A                                     | ✅ from optimizer | shape=[128, 4]
# lora_adapter.B                                     | ✅ from optimizer | shape=[4, 128]
# fc3.weight                                         | ✅ from optimizer | shape=[6, 128]
# fc3.bias                                           | ✅ from optimizer | shape=[6]
#
# ================================================================================
# /tmp/ipykernel_2234450/1609825039.py:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(previous_model_path, map_location=device)
# Epoch 1/1000, Train Loss: 1.823440, Train-Class-Acc: {0: '3.50%', 1: '12.30%', 2: '23.49%', 3: '62.54%', 4: '19.20%', 5: '41.48%'}
# Val Loss: 1.372367, Val Acc: 44.25%, Val-Class-Acc: {0: '3.26%', 1: '67.48%', 3: '90.13%', 2: '23.19%', 5: '65.95%', 4: '11.25%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_1.pth
# Epoch 2/1000, Train Loss: 1.186155, Train-Class-Acc: {0: '40.12%', 1: '73.73%', 2: '37.77%', 3: '89.98%', 4: '20.13%', 5: '52.33%'}
# Val Loss: 0.950650, Val Acc: 68.75%, Val-Class-Acc: {0: '78.41%', 1: '99.25%', 3: '92.74%', 2: '37.30%', 5: '72.86%', 4: '26.33%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_2.pth
# Epoch 3/1000, Train Loss: 0.885647, Train-Class-Acc: {0: '82.12%', 1: '95.41%', 2: '43.80%', 3: '93.89%', 4: '26.37%', 5: '52.54%'}
# Val Loss: 0.769990, Val Acc: 73.43%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 3: '94.60%', 2: '50.60%', 5: '70.71%', 4: '34.61%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_3.pth
# Epoch 4/1000, Train Loss: 0.738136, Train-Class-Acc: {0: '92.07%', 1: '96.00%', 2: '46.98%', 3: '96.59%', 4: '30.10%', 5: '54.46%'}
# Val Loss: 0.673311, Val Acc: 77.10%, Val-Class-Acc: {0: '85.95%', 1: '98.31%', 3: '94.41%', 2: '68.75%', 5: '69.29%', 4: '39.92%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_4.pth
# Epoch 5/1000, Train Loss: 0.649409, Train-Class-Acc: {0: '93.93%', 1: '97.02%', 2: '52.61%', 3: '97.94%', 4: '35.60%', 5: '57.10%'}
# Val Loss: 0.601935, Val Acc: 79.23%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 3: '95.90%', 2: '61.49%', 5: '78.81%', 4: '48.41%'}, LR: 0.000100
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_5.pth
# Epoch 6/1000, Train Loss: 0.586856, Train-Class-Acc: {0: '95.72%', 1: '97.16%', 2: '54.32%', 3: '97.58%', 4: '42.78%', 5: '60.04%'}
# Val Loss: 0.554700, Val Acc: 82.12%, Val-Class-Acc: {0: '91.65%', 1: '97.18%', 3: '96.46%', 2: '77.42%', 5: '66.90%', 4: '57.32%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_1.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_6.pth
# Epoch 7/1000, Train Loss: 0.529519, Train-Class-Acc: {0: '95.72%', 1: '97.67%', 2: '56.36%', 3: '98.22%', 4: '49.21%', 5: '63.49%'}
# Val Loss: 0.500518, Val Acc: 83.98%, Val-Class-Acc: {0: '90.22%', 1: '97.74%', 3: '96.65%', 2: '75.40%', 5: '77.38%', 4: '62.42%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_2.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_7.pth
# Epoch 8/1000, Train Loss: 0.504024, Train-Class-Acc: {0: '95.41%', 1: '96.80%', 2: '62.56%', 3: '97.87%', 4: '56.29%', 5: '62.58%'}
# Val Loss: 0.472368, Val Acc: 85.58%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 3: '96.83%', 2: '83.47%', 5: '70.95%', 4: '70.49%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_3.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_8.pth
# Epoch 9/1000, Train Loss: 0.465352, Train-Class-Acc: {0: '95.65%', 1: '97.67%', 2: '64.03%', 3: '98.22%', 4: '60.86%', 5: '65.01%'}
# Val Loss: 0.443803, Val Acc: 86.53%, Val-Class-Acc: {0: '91.45%', 1: '96.62%', 3: '96.83%', 2: '88.31%', 5: '65.71%', 4: '74.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_4.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_9.pth
# Epoch 10/1000, Train Loss: 0.428925, Train-Class-Acc: {0: '96.42%', 1: '96.94%', 2: '66.88%', 3: '98.08%', 4: '64.68%', 5: '68.05%'}
# Val Loss: 0.418191, Val Acc: 87.58%, Val-Class-Acc: {0: '90.63%', 1: '97.93%', 3: '96.65%', 2: '86.29%', 5: '77.62%', 4: '72.61%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_5.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_10.pth
# Epoch 11/1000, Train Loss: 0.401973, Train-Class-Acc: {0: '96.35%', 1: '97.31%', 2: '69.09%', 3: '98.44%', 4: '67.94%', 5: '69.27%'}
# Val Loss: 0.380001, Val Acc: 88.29%, Val-Class-Acc: {0: '91.24%', 1: '96.62%', 3: '97.58%', 2: '87.10%', 5: '78.81%', 4: '74.95%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_6.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_11.pth
# Epoch 12/1000, Train Loss: 0.377013, Train-Class-Acc: {1: '97.74%', 2: '72.35%', 3: '98.29%', 4: '72.41%', 5: '71.40%', 0: '97.28%'}
# Val Loss: 0.361197, Val Acc: 89.04%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 3: '98.32%', 2: '88.31%', 5: '76.67%', 4: '80.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_7.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_12.pth
# Epoch 13/1000, Train Loss: 0.358821, Train-Class-Acc: {0: '96.27%', 1: '96.87%', 2: '75.29%', 3: '98.15%', 4: '75.30%', 5: '72.82%'}
# Val Loss: 0.348847, Val Acc: 89.14%, Val-Class-Acc: {0: '90.02%', 1: '97.74%', 3: '98.14%', 2: '89.92%', 5: '77.38%', 4: '77.92%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_8.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_13.pth
# Epoch 14/1000, Train Loss: 0.336791, Train-Class-Acc: {0: '97.05%', 1: '97.38%', 2: '75.53%', 3: '98.37%', 4: '75.58%', 5: '73.23%'}
# Val Loss: 0.333666, Val Acc: 89.68%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '98.32%', 2: '91.13%', 5: '78.33%', 4: '80.68%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_9.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_14.pth
# Epoch 15/1000, Train Loss: 0.322024, Train-Class-Acc: {0: '96.42%', 1: '97.67%', 2: '76.75%', 3: '99.00%', 4: '80.52%', 5: '73.43%'}
# Val Loss: 0.318433, Val Acc: 90.13%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '98.88%', 2: '91.94%', 5: '78.33%', 4: '81.53%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_10.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_15.pth
# Epoch 16/1000, Train Loss: 0.302560, Train-Class-Acc: {0: '96.66%', 1: '97.45%', 2: '80.02%', 3: '98.72%', 4: '80.06%', 5: '75.05%'}
# Val Loss: 0.303881, Val Acc: 90.30%, Val-Class-Acc: {0: '91.04%', 1: '96.24%', 3: '99.63%', 2: '94.96%', 5: '72.38%', 4: '83.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_11.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_16.pth
# Epoch 17/1000, Train Loss: 0.294946, Train-Class-Acc: {0: '96.89%', 1: '97.53%', 2: '79.93%', 3: '99.15%', 4: '80.80%', 5: '75.96%'}
# Val Loss: 0.290932, Val Acc: 91.41%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '99.81%', 2: '92.14%', 5: '81.43%', 4: '84.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_12.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_17.pth
# Epoch 18/1000, Train Loss: 0.289399, Train-Class-Acc: {0: '97.05%', 1: '97.02%', 2: '81.97%', 3: '98.86%', 4: '80.52%', 5: '76.57%'}
# Val Loss: 0.292695, Val Acc: 90.74%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '98.70%', 2: '93.55%', 5: '82.14%', 4: '79.41%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_13.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_18.pth
# Epoch 19/1000, Train Loss: 0.287139, Train-Class-Acc: {0: '96.19%', 1: '97.31%', 2: '81.32%', 3: '98.51%', 4: '83.69%', 5: '76.67%'}
# Val Loss: 0.280918, Val Acc: 90.91%, Val-Class-Acc: {0: '91.45%', 1: '96.05%', 3: '99.63%', 2: '93.35%', 5: '82.62%', 4: '79.41%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_14.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_19.pth
# Epoch 20/1000, Train Loss: 0.277126, Train-Class-Acc: {0: '96.66%', 1: '97.82%', 2: '83.28%', 3: '98.51%', 4: '81.08%', 5: '76.67%'}
# Val Loss: 0.272230, Val Acc: 91.75%, Val-Class-Acc: {0: '90.43%', 1: '96.99%', 3: '99.81%', 2: '92.94%', 5: '85.00%', 4: '82.80%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_15.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_20.pth
# Epoch 21/1000, Train Loss: 0.270903, Train-Class-Acc: {0: '96.42%', 1: '97.16%', 2: '82.95%', 3: '98.37%', 4: '81.83%', 5: '76.98%'}
# Val Loss: 0.274463, Val Acc: 91.25%, Val-Class-Acc: {0: '89.41%', 1: '97.18%', 3: '99.63%', 2: '94.35%', 5: '78.81%', 4: '84.71%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_16.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_21.pth
# Epoch 22/1000, Train Loss: 0.262644, Train-Class-Acc: {0: '95.80%', 1: '96.87%', 2: '83.28%', 3: '98.51%', 4: '83.60%', 5: '77.99%'}
# Val Loss: 0.263341, Val Acc: 92.23%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 3: '100.00%', 2: '94.35%', 5: '84.76%', 4: '84.08%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_18.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_22.pth
# Epoch 23/1000, Train Loss: 0.263193, Train-Class-Acc: {0: '96.66%', 1: '96.87%', 2: '85.24%', 3: '98.51%', 4: '81.92%', 5: '79.11%'}
# Val Loss: 0.261616, Val Acc: 91.62%, Val-Class-Acc: {0: '91.04%', 1: '96.05%', 3: '99.63%', 2: '91.94%', 5: '89.05%', 4: '80.04%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_19.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_23.pth
# Epoch 24/1000, Train Loss: 0.259574, Train-Class-Acc: {0: '96.27%', 1: '97.09%', 2: '84.67%', 3: '98.58%', 4: '83.32%', 5: '77.18%'}
# Val Loss: 0.253842, Val Acc: 92.64%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 3: '99.81%', 2: '92.54%', 5: '87.62%', 4: '87.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_21.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_24.pth
# Epoch 25/1000, Train Loss: 0.249157, Train-Class-Acc: {0: '96.66%', 1: '97.23%', 2: '84.58%', 3: '98.58%', 4: '82.20%', 5: '81.14%'}
# Val Loss: 0.259530, Val Acc: 91.45%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 3: '99.44%', 2: '94.76%', 5: '82.86%', 4: '81.74%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_17.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_25.pth
# Epoch 26/1000, Train Loss: 0.248807, Train-Class-Acc: {0: '97.12%', 1: '97.31%', 2: '85.24%', 3: '98.93%', 4: '83.97%', 5: '79.82%'}
# Val Loss: 0.255898, Val Acc: 92.06%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 3: '99.44%', 2: '93.55%', 5: '87.14%', 4: '82.59%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_25.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_26.pth
# Epoch 27/1000, Train Loss: 0.246576, Train-Class-Acc: {0: '96.50%', 1: '97.09%', 2: '84.83%', 3: '98.72%', 4: '83.04%', 5: '81.24%'}
# Val Loss: 0.263044, Val Acc: 91.72%, Val-Class-Acc: {0: '89.00%', 1: '97.56%', 3: '99.63%', 2: '95.36%', 5: '87.38%', 4: '78.98%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_23.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_27.pth
# Epoch 28/1000, Train Loss: 0.243271, Train-Class-Acc: {0: '96.19%', 1: '97.09%', 2: '85.40%', 3: '98.93%', 4: '85.55%', 5: '79.82%'}
# Val Loss: 0.255640, Val Acc: 92.06%, Val-Class-Acc: {0: '89.61%', 1: '97.37%', 3: '99.44%', 2: '93.95%', 5: '88.81%', 4: '81.10%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_27.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_28.pth
# Epoch 29/1000, Train Loss: 0.231350, Train-Class-Acc: {0: '96.35%', 1: '98.03%', 2: '85.56%', 3: '98.65%', 4: '85.37%', 5: '80.93%'}
# Val Loss: 0.253636, Val Acc: 92.06%, Val-Class-Acc: {0: '89.21%', 1: '97.74%', 3: '99.44%', 2: '95.16%', 5: '85.00%', 4: '83.23%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_20.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_29.pth
# Epoch 30/1000, Train Loss: 0.230503, Train-Class-Acc: {0: '96.58%', 1: '97.23%', 2: '86.30%', 3: '98.86%', 4: '85.09%', 5: '81.54%'}
# Val Loss: 0.238402, Val Acc: 92.74%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 3: '99.63%', 2: '91.73%', 5: '89.52%', 4: '87.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_26.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_30.pth
# Epoch 31/1000, Train Loss: 0.228092, Train-Class-Acc: {0: '97.20%', 1: '97.82%', 2: '85.48%', 3: '99.15%', 4: '87.23%', 5: '79.31%'}
# Val Loss: 0.245700, Val Acc: 92.94%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 3: '99.63%', 2: '94.76%', 5: '87.86%', 4: '86.62%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_28.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_31.pth
# Epoch 32/1000, Train Loss: 0.233419, Train-Class-Acc: {0: '95.96%', 1: '96.94%', 2: '85.73%', 3: '98.58%', 4: '84.53%', 5: '81.14%'}
# Val Loss: 0.247384, Val Acc: 92.60%, Val-Class-Acc: {0: '90.02%', 1: '96.80%', 3: '99.81%', 2: '92.94%', 5: '90.00%', 4: '84.29%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_29.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_32.pth
# Epoch 33/1000, Train Loss: 0.229100, Train-Class-Acc: {0: '96.42%', 1: '98.11%', 2: '86.05%', 3: '98.86%', 4: '84.90%', 5: '79.51%'}
# Val Loss: 0.245764, Val Acc: 92.84%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 3: '99.44%', 2: '95.16%', 5: '87.38%', 4: '85.99%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_22.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_33.pth
# Epoch 34/1000, Train Loss: 0.227473, Train-Class-Acc: {0: '95.96%', 1: '97.60%', 2: '86.79%', 3: '98.44%', 4: '84.81%', 5: '81.85%'}
# Val Loss: 0.257686, Val Acc: 91.86%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 3: '99.44%', 2: '96.17%', 5: '85.95%', 4: '80.25%'}, LR: 0.000100
# Epoch 35/1000, Train Loss: 0.230615, Train-Class-Acc: {0: '96.35%', 1: '97.23%', 2: '85.81%', 3: '98.79%', 4: '84.44%', 5: '80.53%'}
# Val Loss: 0.246947, Val Acc: 92.57%, Val-Class-Acc: {0: '87.98%', 1: '97.93%', 3: '99.44%', 2: '95.97%', 5: '86.19%', 4: '85.56%'}, LR: 0.000100
# Epoch 36/1000, Train Loss: 0.219277, Train-Class-Acc: {0: '96.50%', 1: '97.45%', 2: '85.81%', 3: '98.58%', 4: '86.30%', 5: '83.57%'}
# Val Loss: 0.235483, Val Acc: 93.11%, Val-Class-Acc: {0: '90.43%', 1: '96.62%', 3: '99.81%', 2: '95.36%', 5: '87.38%', 4: '87.05%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_32.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_36.pth
# Epoch 37/1000, Train Loss: 0.222167, Train-Class-Acc: {0: '96.58%', 1: '97.02%', 2: '88.50%', 3: '98.65%', 4: '87.33%', 5: '80.22%'}
# Val Loss: 0.250224, Val Acc: 92.43%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '99.26%', 2: '96.17%', 5: '85.00%', 4: '85.14%'}, LR: 0.000100
# Epoch 38/1000, Train Loss: 0.215849, Train-Class-Acc: {0: '96.73%', 1: '97.31%', 2: '88.01%', 3: '98.86%', 4: '85.27%', 5: '82.96%'}
# Val Loss: 0.237467, Val Acc: 92.60%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 3: '99.63%', 2: '95.56%', 5: '84.29%', 4: '86.62%'}, LR: 0.000100
# Epoch 39/1000, Train Loss: 0.207609, Train-Class-Acc: {0: '96.19%', 1: '97.38%', 2: '86.38%', 3: '98.65%', 4: '87.60%', 5: '81.95%'}
# Val Loss: 0.240952, Val Acc: 92.77%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 3: '99.44%', 2: '95.36%', 5: '86.43%', 4: '87.47%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_24.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_39.pth
# Epoch 40/1000, Train Loss: 0.214948, Train-Class-Acc: {0: '96.73%', 1: '97.02%', 2: '87.28%', 3: '98.86%', 4: '85.00%', 5: '80.63%'}
# Val Loss: 0.247757, Val Acc: 91.92%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 3: '99.44%', 2: '96.57%', 5: '86.43%', 4: '79.41%'}, LR: 0.000100
# Epoch 41/1000, Train Loss: 0.208306, Train-Class-Acc: {0: '96.66%', 1: '97.53%', 2: '86.87%', 3: '99.08%', 4: '85.65%', 5: '82.25%'}
# Val Loss: 0.243549, Val Acc: 92.50%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '99.44%', 2: '96.37%', 5: '87.62%', 4: '81.74%'}, LR: 0.000100
# Epoch 42/1000, Train Loss: 0.211793, Train-Class-Acc: {0: '96.66%', 1: '97.31%', 2: '86.30%', 3: '98.86%', 4: '87.98%', 5: '82.56%'}
# Val Loss: 0.237664, Val Acc: 93.01%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 3: '99.44%', 2: '95.56%', 5: '86.43%', 4: '87.69%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_30.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_42.pth
# Epoch 43/1000, Train Loss: 0.216225, Train-Class-Acc: {0: '96.42%', 1: '97.89%', 2: '86.62%', 3: '98.79%', 4: '84.44%', 5: '81.95%'}
# Val Loss: 0.233988, Val Acc: 93.08%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 3: '99.44%', 2: '95.77%', 5: '89.05%', 4: '85.35%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_39.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_43.pth
# Epoch 44/1000, Train Loss: 0.211395, Train-Class-Acc: {0: '97.36%', 1: '97.74%', 2: '88.42%', 3: '98.65%', 4: '85.93%', 5: '81.03%'}
# Val Loss: 0.248307, Val Acc: 92.33%, Val-Class-Acc: {0: '90.84%', 1: '96.80%', 3: '99.44%', 2: '96.57%', 5: '83.57%', 4: '84.08%'}, LR: 0.000100
# Epoch 45/1000, Train Loss: 0.210933, Train-Class-Acc: {0: '96.42%', 1: '97.96%', 2: '87.03%', 3: '98.51%', 4: '84.72%', 5: '82.96%'}
# Val Loss: 0.237920, Val Acc: 92.81%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 3: '99.44%', 2: '95.77%', 5: '86.90%', 4: '84.71%'}, LR: 0.000100
# Epoch 46/1000, Train Loss: 0.221044, Train-Class-Acc: {0: '96.27%', 1: '97.89%', 2: '86.38%', 3: '98.79%', 4: '86.39%', 5: '82.25%'}
# Val Loss: 0.240674, Val Acc: 92.87%, Val-Class-Acc: {0: '90.43%', 1: '97.37%', 3: '99.44%', 2: '95.77%', 5: '88.33%', 4: '83.86%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_33.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_46.pth
# Epoch 47/1000, Train Loss: 0.211423, Train-Class-Acc: {0: '96.27%', 1: '97.82%', 2: '87.60%', 3: '98.86%', 4: '87.14%', 5: '81.74%'}
# Val Loss: 0.233990, Val Acc: 93.25%, Val-Class-Acc: {0: '90.02%', 1: '97.56%', 3: '99.44%', 2: '93.75%', 5: '90.95%', 4: '86.20%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_46.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_47.pth
# Epoch 48/1000, Train Loss: 0.214551, Train-Class-Acc: {0: '96.89%', 1: '97.60%', 2: '86.95%', 3: '98.51%', 4: '86.39%', 5: '82.25%'}
# Val Loss: 0.230947, Val Acc: 93.32%, Val-Class-Acc: {0: '88.59%', 1: '97.74%', 3: '99.81%', 2: '95.97%', 5: '86.90%', 4: '88.75%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_31.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_48.pth
# Epoch 49/1000, Train Loss: 0.216650, Train-Class-Acc: {0: '95.96%', 1: '97.38%', 2: '88.01%', 3: '98.65%', 4: '87.33%', 5: '82.35%'}
# Val Loss: 0.235001, Val Acc: 93.15%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 3: '99.63%', 2: '95.56%', 5: '86.43%', 4: '87.47%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_42.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_49.pth
# Epoch 50/1000, Train Loss: 0.208281, Train-Class-Acc: {0: '96.35%', 1: '96.87%', 2: '88.83%', 3: '98.58%', 4: '87.42%', 5: '82.15%'}
# Val Loss: 0.244182, Val Acc: 92.40%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '99.44%', 2: '95.97%', 5: '87.38%', 4: '82.17%'}, LR: 0.000100
# Epoch 51/1000, Train Loss: 0.214004, Train-Class-Acc: {0: '96.19%', 1: '97.96%', 2: '87.60%', 3: '98.08%', 4: '84.90%', 5: '83.06%'}
# Val Loss: 0.242517, Val Acc: 92.98%, Val-Class-Acc: {0: '88.19%', 1: '98.12%', 3: '99.44%', 2: '95.36%', 5: '88.33%', 4: '86.41%'}, LR: 0.000100
# Epoch 52/1000, Train Loss: 0.209359, Train-Class-Acc: {0: '96.35%', 1: '97.16%', 2: '87.60%', 3: '98.93%', 4: '87.79%', 5: '82.96%'}
# Val Loss: 0.236353, Val Acc: 93.42%, Val-Class-Acc: {0: '88.80%', 1: '97.56%', 3: '99.63%', 2: '95.56%', 5: '89.52%', 4: '87.69%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_43.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_52.pth
# Epoch 53/1000, Train Loss: 0.214490, Train-Class-Acc: {0: '96.73%', 1: '97.16%', 2: '86.95%', 3: '98.72%', 4: '86.39%', 5: '80.63%'}
# Val Loss: 0.243328, Val Acc: 92.70%, Val-Class-Acc: {0: '89.61%', 1: '97.56%', 3: '99.44%', 2: '95.56%', 5: '87.14%', 4: '84.71%'}, LR: 0.000100
# Epoch 54/1000, Train Loss: 0.211766, Train-Class-Acc: {0: '96.50%', 1: '97.31%', 2: '86.62%', 3: '98.86%', 4: '86.21%', 5: '82.86%'}
# Val Loss: 0.245017, Val Acc: 92.67%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '99.44%', 2: '95.97%', 5: '87.86%', 4: '84.08%'}, LR: 0.000100
# Epoch 55/1000, Train Loss: 0.203240, Train-Class-Acc: {0: '96.42%', 1: '97.38%', 2: '88.50%', 3: '98.65%', 4: '87.33%', 5: '82.25%'}
# Val Loss: 0.243942, Val Acc: 92.33%, Val-Class-Acc: {0: '89.82%', 1: '96.99%', 3: '99.44%', 2: '96.77%', 5: '84.05%', 4: '84.29%'}, LR: 0.000100
# Epoch 56/1000, Train Loss: 0.198311, Train-Class-Acc: {0: '96.50%', 1: '98.03%', 2: '87.36%', 3: '98.93%', 4: '87.88%', 5: '84.69%'}
# Val Loss: 0.248426, Val Acc: 92.30%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 3: '99.44%', 2: '96.37%', 5: '85.24%', 4: '82.80%'}, LR: 0.000100
# Epoch 57/1000, Train Loss: 0.198908, Train-Class-Acc: {0: '96.81%', 1: '97.31%', 2: '88.74%', 3: '99.15%', 4: '86.30%', 5: '82.76%'}
# Val Loss: 0.235430, Val Acc: 92.94%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 3: '99.44%', 2: '95.56%', 5: '88.57%', 4: '85.14%'}, LR: 0.000100
# Epoch 58/1000, Train Loss: 0.213519, Train-Class-Acc: {0: '96.42%', 1: '97.45%', 2: '86.70%', 3: '98.37%', 4: '86.49%', 5: '83.57%'}
# Val Loss: 0.243181, Val Acc: 92.77%, Val-Class-Acc: {0: '87.98%', 1: '97.74%', 3: '99.63%', 2: '96.37%', 5: '86.90%', 4: '85.77%'}, LR: 0.000100
# Epoch 59/1000, Train Loss: 0.202518, Train-Class-Acc: {0: '96.50%', 1: '98.03%', 2: '89.40%', 3: '98.58%', 4: '85.00%', 5: '82.76%'}
# Val Loss: 0.234649, Val Acc: 92.77%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 3: '99.44%', 2: '95.97%', 5: '87.14%', 4: '84.93%'}, LR: 0.000100
# Epoch 60/1000, Train Loss: 0.201838, Train-Class-Acc: {0: '96.58%', 1: '97.45%', 2: '88.42%', 3: '98.93%', 4: '87.05%', 5: '84.48%'}
# Val Loss: 0.235340, Val Acc: 93.11%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '99.44%', 2: '96.57%', 5: '86.43%', 4: '86.41%'}, LR: 0.000100
# Epoch 61/1000, Train Loss: 0.205366, Train-Class-Acc: {0: '96.73%', 1: '97.82%', 2: '88.83%', 3: '99.00%', 4: '86.21%', 5: '83.47%'}
# Val Loss: 0.231992, Val Acc: 93.59%, Val-Class-Acc: {0: '89.41%', 1: '97.37%', 3: '99.81%', 2: '94.76%', 5: '90.71%', 4: '87.90%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_36.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_61.pth
# Epoch 62/1000, Train Loss: 0.203473, Train-Class-Acc: {0: '95.88%', 1: '97.02%', 2: '90.21%', 3: '98.51%', 4: '87.42%', 5: '83.77%'}
# Val Loss: 0.226963, Val Acc: 93.28%, Val-Class-Acc: {0: '91.85%', 1: '95.86%', 3: '99.63%', 2: '96.77%', 5: '86.67%', 4: '86.84%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_49.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_62.pth
# Epoch 63/1000, Train Loss: 0.198988, Train-Class-Acc: {0: '96.50%', 1: '97.38%', 2: '87.60%', 3: '98.72%', 4: '88.16%', 5: '82.25%'}
# Val Loss: 0.233547, Val Acc: 93.01%, Val-Class-Acc: {0: '88.59%', 1: '97.56%', 3: '99.44%', 2: '96.37%', 5: '86.67%', 4: '87.26%'}, LR: 0.000100
# Epoch 64/1000, Train Loss: 0.203153, Train-Class-Acc: {0: '96.42%', 1: '97.89%', 2: '87.28%', 3: '99.08%', 4: '86.67%', 5: '83.47%'}
# Val Loss: 0.241941, Val Acc: 92.81%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 3: '99.63%', 2: '94.76%', 5: '90.24%', 4: '84.50%'}, LR: 0.000100
# Epoch 65/1000, Train Loss: 0.203048, Train-Class-Acc: {0: '96.42%', 1: '97.82%', 2: '89.07%', 3: '98.86%', 4: '88.63%', 5: '83.37%'}
# Val Loss: 0.244769, Val Acc: 92.30%, Val-Class-Acc: {0: '90.63%', 1: '96.62%', 3: '99.44%', 2: '97.58%', 5: '81.90%', 4: '84.71%'}, LR: 0.000100
# Epoch 66/1000, Train Loss: 0.201349, Train-Class-Acc: {0: '96.97%', 1: '98.40%', 2: '87.77%', 3: '98.86%', 4: '86.58%', 5: '81.64%'}
# Val Loss: 0.254310, Val Acc: 92.33%, Val-Class-Acc: {0: '88.39%', 1: '98.50%', 3: '99.44%', 2: '97.58%', 5: '83.10%', 4: '84.08%'}, LR: 0.000100
# Epoch 67/1000, Train Loss: 0.207976, Train-Class-Acc: {0: '96.35%', 1: '97.60%', 2: '87.19%', 3: '98.79%', 4: '86.21%', 5: '82.15%'}
# Val Loss: 0.232845, Val Acc: 93.15%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 3: '99.63%', 2: '94.96%', 5: '89.05%', 4: '86.41%'}, LR: 0.000100
# Epoch 68/1000, Train Loss: 0.202564, Train-Class-Acc: {0: '96.03%', 1: '97.53%', 2: '88.01%', 3: '98.65%', 4: '86.86%', 5: '83.67%'}
# Val Loss: 0.244337, Val Acc: 92.43%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 3: '99.44%', 2: '96.98%', 5: '85.24%', 4: '82.80%'}, LR: 0.000100
# Epoch 69/1000, Train Loss: 0.193947, Train-Class-Acc: {0: '96.73%', 1: '97.53%', 2: '88.09%', 3: '98.65%', 4: '86.67%', 5: '83.57%'}
# Val Loss: 0.245068, Val Acc: 92.30%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '99.44%', 2: '95.16%', 5: '87.86%', 4: '81.53%'}, LR: 0.000100
# Epoch 70/1000, Train Loss: 0.200841, Train-Class-Acc: {0: '96.42%', 1: '98.03%', 2: '87.68%', 3: '98.15%', 4: '87.79%', 5: '84.48%'}
# Val Loss: 0.251506, Val Acc: 92.06%, Val-Class-Acc: {0: '87.58%', 1: '97.93%', 3: '99.81%', 2: '96.98%', 5: '83.57%', 4: '83.65%'}, LR: 0.000100
# Epoch 71/1000, Train Loss: 0.198824, Train-Class-Acc: {0: '96.35%', 1: '97.31%', 2: '89.80%', 3: '98.44%', 4: '86.95%', 5: '81.95%'}
# Val Loss: 0.251312, Val Acc: 92.06%, Val-Class-Acc: {0: '90.63%', 1: '96.99%', 3: '99.44%', 2: '96.98%', 5: '84.29%', 4: '81.32%'}, LR: 0.000100
# Epoch 72/1000, Train Loss: 0.203078, Train-Class-Acc: {0: '96.50%', 1: '97.96%', 2: '87.44%', 3: '98.37%', 4: '85.93%', 5: '84.58%'}
# Val Loss: 0.248193, Val Acc: 92.33%, Val-Class-Acc: {0: '89.21%', 1: '98.12%', 3: '99.44%', 2: '96.57%', 5: '85.24%', 4: '82.80%'}, LR: 0.000100
# Epoch 73/1000, Train Loss: 0.198903, Train-Class-Acc: {0: '96.73%', 1: '97.74%', 2: '89.31%', 3: '98.93%', 4: '87.51%', 5: '82.66%'}
# Val Loss: 0.251030, Val Acc: 92.09%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '99.63%', 2: '96.77%', 5: '86.67%', 4: '80.47%'}, LR: 0.000100
# Epoch 74/1000, Train Loss: 0.193277, Train-Class-Acc: {0: '97.28%', 1: '97.67%', 2: '89.31%', 3: '99.15%', 4: '87.51%', 5: '82.66%'}
# Val Loss: 0.249116, Val Acc: 92.20%, Val-Class-Acc: {0: '89.21%', 1: '98.31%', 3: '99.44%', 2: '96.98%', 5: '84.29%', 4: '82.17%'}, LR: 0.000100
# Epoch 75/1000, Train Loss: 0.194224, Train-Class-Acc: {0: '96.58%', 1: '97.67%', 2: '89.07%', 3: '99.08%', 4: '86.86%', 5: '85.90%'}
# Val Loss: 0.239881, Val Acc: 92.70%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '99.44%', 2: '96.57%', 5: '86.19%', 4: '84.50%'}, LR: 0.000100
# Epoch 76/1000, Train Loss: 0.188155, Train-Class-Acc: {0: '96.27%', 1: '97.45%', 2: '88.25%', 3: '98.79%', 4: '88.35%', 5: '84.18%'}
# Val Loss: 0.246920, Val Acc: 92.30%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '99.63%', 2: '97.38%', 5: '84.29%', 4: '82.38%'}, LR: 0.000100
# Epoch 77/1000, Train Loss: 0.191502, Train-Class-Acc: {0: '96.42%', 1: '97.45%', 2: '89.15%', 3: '98.37%', 4: '86.21%', 5: '82.76%'}
# Val Loss: 0.243587, Val Acc: 92.30%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '99.44%', 2: '95.77%', 5: '89.05%', 4: '80.89%'}, LR: 0.000100
# Epoch 78/1000, Train Loss: 0.194404, Train-Class-Acc: {0: '97.12%', 1: '97.82%', 2: '87.85%', 3: '98.65%', 4: '87.60%', 5: '83.47%'}
# Val Loss: 0.226744, Val Acc: 93.15%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '99.63%', 2: '96.77%', 5: '87.62%', 4: '85.56%'}, LR: 0.000100
# Epoch 79/1000, Train Loss: 0.196568, Train-Class-Acc: {0: '96.27%', 1: '97.96%', 2: '89.31%', 3: '98.44%', 4: '87.60%', 5: '84.58%'}
# Val Loss: 0.239372, Val Acc: 92.87%, Val-Class-Acc: {0: '87.58%', 1: '98.12%', 3: '99.81%', 2: '95.77%', 5: '88.10%', 4: '85.77%'}, LR: 0.000100
# Epoch 80/1000, Train Loss: 0.200372, Train-Class-Acc: {0: '96.42%', 1: '97.74%', 2: '88.01%', 3: '99.00%', 4: '86.11%', 5: '83.27%'}
# Val Loss: 0.247779, Val Acc: 92.37%, Val-Class-Acc: {0: '87.98%', 1: '98.50%', 3: '99.44%', 2: '96.37%', 5: '86.19%', 4: '83.23%'}, LR: 0.000100
# Epoch 81/1000, Train Loss: 0.189274, Train-Class-Acc: {0: '96.97%', 1: '97.60%', 2: '88.99%', 3: '98.93%', 4: '86.95%', 5: '83.06%'}
# Val Loss: 0.238321, Val Acc: 92.53%, Val-Class-Acc: {0: '90.22%', 1: '96.99%', 3: '99.63%', 2: '95.97%', 5: '88.81%', 4: '81.53%'}, LR: 0.000100
# Epoch 82/1000, Train Loss: 0.201751, Train-Class-Acc: {0: '96.27%', 1: '97.67%', 2: '88.01%', 3: '99.00%', 4: '85.93%', 5: '83.67%'}
# Val Loss: 0.235825, Val Acc: 93.08%, Val-Class-Acc: {0: '89.00%', 1: '97.74%', 3: '99.63%', 2: '95.97%', 5: '87.86%', 4: '86.20%'}, LR: 0.000100
# Epoch 83/1000, Train Loss: 0.187792, Train-Class-Acc: {0: '96.73%', 1: '98.33%', 2: '88.91%', 3: '98.51%', 4: '88.54%', 5: '83.27%'}
# Val Loss: 0.227879, Val Acc: 93.28%, Val-Class-Acc: {0: '90.43%', 1: '96.62%', 3: '99.81%', 2: '96.57%', 5: '87.38%', 4: '86.84%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_47.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_83.pth
# Epoch 84/1000, Train Loss: 0.198730, Train-Class-Acc: {0: '96.19%', 1: '97.89%', 2: '87.77%', 3: '98.65%', 4: '87.33%', 5: '81.64%'}
# Val Loss: 0.236405, Val Acc: 93.42%, Val-Class-Acc: {0: '87.78%', 1: '98.12%', 3: '99.81%', 2: '95.97%', 5: '88.81%', 4: '88.11%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_62.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_84.pth
# Epoch 85/1000, Train Loss: 0.181932, Train-Class-Acc: {0: '97.05%', 1: '98.40%', 2: '89.48%', 3: '98.86%', 4: '88.07%', 5: '84.48%'}
# Val Loss: 0.239245, Val Acc: 92.57%, Val-Class-Acc: {0: '88.39%', 1: '98.12%', 3: '99.81%', 2: '97.18%', 5: '82.38%', 4: '86.62%'}, LR: 0.000100
# Epoch 86/1000, Train Loss: 0.194150, Train-Class-Acc: {0: '96.19%', 1: '97.38%', 2: '88.34%', 3: '98.79%', 4: '87.98%', 5: '85.40%'}
# Val Loss: 0.232892, Val Acc: 93.59%, Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '95.77%', 5: '89.52%', 4: '88.32%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_83.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_86.pth
# Epoch 87/1000, Train Loss: 0.188664, Train-Class-Acc: {0: '96.89%', 1: '97.16%', 2: '89.72%', 3: '98.72%', 4: '87.70%', 5: '83.27%'}
# Val Loss: 0.253099, Val Acc: 92.33%, Val-Class-Acc: {0: '87.17%', 1: '98.50%', 3: '99.63%', 2: '96.77%', 5: '87.62%', 4: '81.95%'}, LR: 0.000100
# Epoch 88/1000, Train Loss: 0.194804, Train-Class-Acc: {0: '95.80%', 1: '97.31%', 2: '88.42%', 3: '98.86%', 4: '87.23%', 5: '84.89%'}
# Val Loss: 0.237518, Val Acc: 92.81%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 3: '99.63%', 2: '97.18%', 5: '84.29%', 4: '86.20%'}, LR: 0.000100
# Epoch 89/1000, Train Loss: 0.191599, Train-Class-Acc: {0: '96.89%', 1: '97.67%', 2: '88.74%', 3: '99.00%', 4: '87.60%', 5: '83.98%'}
# Val Loss: 0.247095, Val Acc: 92.43%, Val-Class-Acc: {0: '89.21%', 1: '98.31%', 3: '99.44%', 2: '96.37%', 5: '87.38%', 4: '81.53%'}, LR: 0.000100
# Epoch 90/1000, Train Loss: 0.193616, Train-Class-Acc: {0: '96.35%', 1: '98.18%', 2: '88.34%', 3: '98.72%', 4: '86.95%', 5: '83.37%'}
# Val Loss: 0.231605, Val Acc: 92.50%, Val-Class-Acc: {0: '91.04%', 1: '96.43%', 3: '99.63%', 2: '97.18%', 5: '82.62%', 4: '85.35%'}, LR: 0.000100
# Epoch 91/1000, Train Loss: 0.192025, Train-Class-Acc: {0: '96.11%', 1: '97.82%', 2: '87.85%', 3: '98.72%', 4: '86.86%', 5: '84.08%'}
# Val Loss: 0.247805, Val Acc: 92.33%, Val-Class-Acc: {0: '90.84%', 1: '97.18%', 3: '99.63%', 2: '96.98%', 5: '87.38%', 4: '79.62%'}, LR: 0.000100
# Epoch 92/1000, Train Loss: 0.189114, Train-Class-Acc: {0: '96.11%', 1: '98.18%', 2: '89.31%', 3: '98.86%', 4: '87.88%', 5: '84.08%'}
# Val Loss: 0.253051, Val Acc: 92.40%, Val-Class-Acc: {0: '86.35%', 1: '98.68%', 3: '99.63%', 2: '96.77%', 5: '87.62%', 4: '83.01%'}, LR: 0.000100
# Epoch 93/1000, Train Loss: 0.187426, Train-Class-Acc: {0: '96.89%', 1: '97.09%', 2: '89.23%', 3: '98.86%', 4: '86.67%', 5: '84.28%'}
# Val Loss: 0.239813, Val Acc: 92.57%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 3: '99.81%', 2: '95.77%', 5: '89.05%', 4: '81.53%'}, LR: 0.000100
# Epoch 94/1000, Train Loss: 0.186278, Train-Class-Acc: {0: '96.19%', 1: '97.38%', 2: '88.42%', 3: '98.72%', 4: '88.91%', 5: '85.40%'}
# Val Loss: 0.238685, Val Acc: 93.15%, Val-Class-Acc: {0: '88.59%', 1: '98.12%', 3: '99.81%', 2: '96.98%', 5: '87.62%', 4: '85.56%'}, LR: 0.000100
# Epoch 95/1000, Train Loss: 0.185839, Train-Class-Acc: {0: '96.27%', 1: '97.53%', 2: '89.48%', 3: '98.79%', 4: '88.72%', 5: '82.66%'}
# Val Loss: 0.235281, Val Acc: 92.98%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 3: '99.81%', 2: '97.18%', 5: '85.95%', 4: '85.35%'}, LR: 0.000100
# Epoch 96/1000, Train Loss: 0.198781, Train-Class-Acc: {0: '95.80%', 1: '97.53%', 2: '88.01%', 3: '98.58%', 4: '85.93%', 5: '84.48%'}
# Val Loss: 0.245373, Val Acc: 92.30%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 3: '99.44%', 2: '97.18%', 5: '85.24%', 4: '81.74%'}, LR: 0.000100
# Epoch 97/1000, Train Loss: 0.191633, Train-Class-Acc: {0: '96.81%', 1: '97.67%', 2: '88.09%', 3: '99.00%', 4: '87.60%', 5: '83.98%'}
# Val Loss: 0.252104, Val Acc: 92.50%, Val-Class-Acc: {0: '86.76%', 1: '98.68%', 3: '99.63%', 2: '96.98%', 5: '85.24%', 4: '85.14%'}, LR: 0.000100
# Epoch 98/1000, Train Loss: 0.183819, Train-Class-Acc: {0: '97.36%', 1: '97.96%', 2: '88.25%', 3: '98.79%', 4: '87.51%', 5: '84.18%'}
# Val Loss: 0.246973, Val Acc: 92.47%, Val-Class-Acc: {0: '90.43%', 1: '97.74%', 3: '99.44%', 2: '95.77%', 5: '88.33%', 4: '80.89%'}, LR: 0.000100
# Epoch 99/1000, Train Loss: 0.187875, Train-Class-Acc: {0: '97.67%', 1: '97.74%', 2: '88.42%', 3: '98.93%', 4: '89.38%', 5: '83.06%'}
# Val Loss: 0.243124, Val Acc: 92.57%, Val-Class-Acc: {0: '89.82%', 1: '97.18%', 3: '99.81%', 2: '96.98%', 5: '85.24%', 4: '83.86%'}, LR: 0.000100
# Epoch 100/1000, Train Loss: 0.187810, Train-Class-Acc: {0: '96.89%', 1: '97.67%', 2: '90.13%', 3: '98.44%', 4: '87.51%', 5: '84.89%'}
# Val Loss: 0.224153, Val Acc: 93.38%, Val-Class-Acc: {0: '90.84%', 1: '96.24%', 3: '99.81%', 2: '95.77%', 5: '87.14%', 4: '88.54%'}, LR: 0.000100
# 🗑 Removed: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_48.pth
# ✅ Saved model: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_100.pth
# Epoch 101/1000, Train Loss: 0.184020, Train-Class-Acc: {0: '96.66%', 1: '97.53%', 2: '89.72%', 3: '98.65%', 4: '88.82%', 5: '84.69%'}
# Val Loss: 0.238048, Val Acc: 92.81%, Val-Class-Acc: {0: '90.63%', 1: '97.18%', 3: '99.81%', 2: '96.37%', 5: '87.62%', 4: '83.01%'}, LR: 0.000100
# Epoch 102/1000, Train Loss: 0.185532, Train-Class-Acc: {0: '96.50%', 1: '97.23%', 2: '88.99%', 3: '98.58%', 4: '89.00%', 5: '85.40%'}
# Val Loss: 0.257301, Val Acc: 91.82%, Val-Class-Acc: {0: '83.91%', 1: '98.68%', 3: '99.44%', 2: '96.17%', 5: '87.86%', 4: '82.59%'}, LR: 0.000100
# Epoch 103/1000, Train Loss: 0.172547, Train-Class-Acc: {0: '97.36%', 1: '97.45%', 2: '90.70%', 4: '88.44%', 5: '84.89%', 3: '98.86%'}
# Val Loss: 0.244571, Val Acc: 92.77%, Val-Class-Acc: {0: '86.97%', 1: '98.50%', 3: '99.81%', 2: '95.56%', 5: '89.05%', 4: '84.71%'}, LR: 0.000100
# Epoch 104/1000, Train Loss: 0.189542, Train-Class-Acc: {0: '96.58%', 1: '98.11%', 2: '88.99%', 3: '98.15%', 4: '88.35%', 5: '82.56%'}
# Val Loss: 0.259081, Val Acc: 91.82%, Val-Class-Acc: {0: '85.54%', 1: '98.68%', 3: '99.63%', 2: '96.17%', 5: '88.33%', 4: '80.25%'}, LR: 0.000100
# Epoch 105/1000, Train Loss: 0.186649, Train-Class-Acc: {0: '96.11%', 1: '97.31%', 2: '90.29%', 3: '98.93%', 4: '88.35%', 5: '85.19%'}
# Val Loss: 0.246442, Val Acc: 92.70%, Val-Class-Acc: {0: '88.39%', 1: '98.50%', 3: '99.44%', 2: '95.77%', 5: '88.33%', 4: '83.65%'}, LR: 0.000100
# Epoch 106/1000, Train Loss: 0.183213, Train-Class-Acc: {0: '96.97%', 1: '98.18%', 2: '90.62%', 3: '98.65%', 4: '87.51%', 5: '84.69%'}
# Val Loss: 0.237124, Val Acc: 92.81%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 3: '99.81%', 2: '95.56%', 5: '87.86%', 4: '85.56%'}, LR: 0.000100
# Epoch 107/1000, Train Loss: 0.193580, Train-Class-Acc: {0: '96.89%', 1: '97.96%', 2: '89.56%', 3: '98.79%', 4: '86.21%', 5: '83.77%'}
# Val Loss: 0.242036, Val Acc: 92.94%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 3: '99.81%', 2: '95.77%', 5: '89.05%', 4: '85.14%'}, LR: 0.000100
# Epoch 108/1000, Train Loss: 0.190835, Train-Class-Acc: {0: '96.89%', 1: '98.11%', 2: '87.85%', 3: '98.86%', 4: '88.26%', 5: '82.45%'}
# Val Loss: 0.237053, Val Acc: 93.01%, Val-Class-Acc: {0: '89.61%', 1: '96.99%', 3: '99.81%', 2: '95.77%', 5: '87.86%', 4: '85.99%'}, LR: 0.000100
# Epoch 109/1000, Train Loss: 0.190278, Train-Class-Acc: {0: '96.35%', 1: '97.67%', 2: '87.77%', 3: '98.44%', 4: '87.14%', 5: '85.50%'}
# Val Loss: 0.232397, Val Acc: 93.21%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '99.63%', 2: '95.56%', 5: '89.76%', 4: '85.14%'}, LR: 0.000100
# Epoch 110/1000, Train Loss: 0.181331, Train-Class-Acc: {0: '96.27%', 1: '97.82%', 2: '89.48%', 3: '99.22%', 4: '87.51%', 5: '84.08%'}
# Val Loss: 0.242162, Val Acc: 92.70%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '99.63%', 2: '97.18%', 5: '85.48%', 4: '84.08%'}, LR: 0.000100
# Epoch 111/1000, Train Loss: 0.184105, Train-Class-Acc: {0: '96.11%', 1: '97.38%', 2: '89.48%', 3: '98.72%', 4: '88.91%', 5: '84.79%'}
# Val Loss: 0.241710, Val Acc: 93.15%, Val-Class-Acc: {0: '86.97%', 1: '98.31%', 3: '99.81%', 2: '95.77%', 5: '87.62%', 4: '88.32%'}, LR: 0.000100
# Epoch 112/1000, Train Loss: 0.186655, Train-Class-Acc: {0: '96.97%', 1: '98.18%', 2: '88.58%', 3: '98.72%', 4: '88.26%', 5: '84.18%'}
# Val Loss: 0.234798, Val Acc: 92.91%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 3: '99.81%', 2: '95.97%', 5: '87.38%', 4: '84.93%'}, LR: 0.000100
# Epoch 113/1000, Train Loss: 0.184050, Train-Class-Acc: {0: '97.28%', 1: '97.31%', 2: '89.89%', 3: '98.93%', 4: '87.70%', 5: '85.40%'}
# Val Loss: 0.248467, Val Acc: 92.67%, Val-Class-Acc: {0: '87.37%', 1: '97.93%', 3: '100.00%', 2: '94.56%', 5: '90.00%', 4: '84.29%'}, LR: 0.000100
# Epoch 114/1000, Train Loss: 0.172057, Train-Class-Acc: {0: '97.36%', 1: '98.18%', 2: '90.46%', 3: '98.65%', 4: '89.47%', 5: '84.79%'}
# Val Loss: 0.243707, Val Acc: 92.84%, Val-Class-Acc: {0: '88.19%', 1: '98.50%', 3: '99.81%', 2: '95.77%', 5: '87.14%', 4: '85.35%'}, LR: 0.000100
# Epoch 115/1000, Train Loss: 0.195675, Train-Class-Acc: {0: '96.50%', 1: '97.96%', 2: '89.15%', 3: '98.37%', 4: '87.79%', 5: '83.67%'}
# Val Loss: 0.246556, Val Acc: 92.60%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '99.81%', 2: '97.18%', 5: '83.81%', 4: '84.71%'}, LR: 0.000100
# Epoch 116/1000, Train Loss: 0.191425, Train-Class-Acc: {0: '96.03%', 1: '97.60%', 2: '89.31%', 3: '98.79%', 4: '87.79%', 5: '83.47%'}
# Val Loss: 0.256275, Val Acc: 92.20%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 3: '99.63%', 2: '96.98%', 5: '85.24%', 4: '81.53%'}, LR: 0.000100
# Epoch 117/1000, Train Loss: 0.185680, Train-Class-Acc: {0: '96.35%', 1: '98.03%', 2: '90.29%', 3: '98.86%', 4: '86.86%', 5: '84.69%'}
# Val Loss: 0.233583, Val Acc: 92.64%, Val-Class-Acc: {0: '90.84%', 1: '96.05%', 3: '99.81%', 2: '96.57%', 5: '86.19%', 4: '84.08%'}, LR: 0.000100
# Epoch 118/1000, Train Loss: 0.179842, Train-Class-Acc: {0: '96.73%', 1: '97.60%', 2: '89.64%', 3: '99.22%', 4: '87.98%', 5: '85.19%'}
# Val Loss: 0.252010, Val Acc: 92.26%, Val-Class-Acc: {0: '90.02%', 1: '97.93%', 3: '99.81%', 2: '95.16%', 5: '88.57%', 4: '79.83%'}, LR: 0.000100
# Epoch 119/1000, Train Loss: 0.190588, Train-Class-Acc: {0: '97.12%', 1: '98.25%', 2: '88.09%', 3: '98.65%', 4: '86.39%', 5: '82.56%'}
# Val Loss: 0.235661, Val Acc: 92.74%, Val-Class-Acc: {0: '90.63%', 1: '96.80%', 3: '99.63%', 2: '95.77%', 5: '87.38%', 4: '84.08%'}, LR: 0.000100
# Epoch 120/1000, Train Loss: 0.185665, Train-Class-Acc: {0: '97.05%', 1: '97.45%', 2: '88.42%', 3: '99.43%', 4: '88.07%', 5: '83.06%'}
# Val Loss: 0.244000, Val Acc: 92.87%, Val-Class-Acc: {0: '88.59%', 1: '97.37%', 3: '100.00%', 2: '95.16%', 5: '89.76%', 4: '84.50%'}, LR: 0.000100
# Epoch 121/1000, Train Loss: 0.181476, Train-Class-Acc: {0: '96.27%', 1: '98.11%', 2: '90.29%', 3: '98.86%', 4: '88.63%', 5: '85.09%'}
# Val Loss: 0.241857, Val Acc: 92.74%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 3: '99.81%', 2: '96.17%', 5: '87.86%', 4: '83.23%'}, LR: 0.000100
# Epoch 122/1000, Train Loss: 0.185684, Train-Class-Acc: {0: '96.66%', 1: '97.53%', 2: '89.80%', 3: '98.86%', 4: '88.26%', 5: '84.18%'}
# Val Loss: 0.255329, Val Acc: 92.09%, Val-Class-Acc: {0: '87.58%', 1: '98.31%', 3: '99.44%', 2: '96.37%', 5: '86.67%', 4: '81.74%'}, LR: 0.000100
# Epoch 123/1000, Train Loss: 0.185795, Train-Class-Acc: {0: '96.50%', 1: '98.40%', 2: '88.83%', 3: '98.93%', 4: '88.63%', 5: '84.38%'}
# Val Loss: 0.244940, Val Acc: 92.64%, Val-Class-Acc: {0: '90.02%', 1: '97.37%', 3: '99.63%', 2: '97.38%', 5: '85.00%', 4: '83.86%'}, LR: 0.000100
# ...
# Val Loss: 0.258918, Val Acc: 92.57%, Val-Class-Acc: {0: '87.78%', 1: '97.93%', 3: '100.00%', 2: '95.77%', 5: '86.43%', 4: '85.14%'}, LR: 0.000100
# Epoch 956/1000, Train Loss: 0.151778, Train-Class-Acc: {0: '97.05%', 1: '98.03%', 2: '90.62%', 3: '99.22%', 4: '90.12%', 5: '87.53%'}
# Val Loss: 0.259733, Val Acc: 92.60%, Val-Class-Acc: {0: '89.21%', 1: '97.18%', 3: '100.00%', 2: '96.77%', 5: '85.48%', 4: '84.50%'}, LR: 0.000100
# Epoch 957/1000, Train Loss: 0.138090, Train-Class-Acc: {0: '96.97%', 1: '98.18%', 2: '92.33%', 3: '99.15%', 4: '92.45%', 5: '88.34%'}
# Val Loss: 0.261909, Val Acc: 92.60%, Val-Class-Acc: {0: '88.39%', 1: '97.74%', 3: '100.00%', 2: '95.97%', 5: '86.19%', 4: '84.93%'}, LR: 0.000100
# Epoch 958/1000, Train Loss: 0.156017, Train-Class-Acc: {0: '96.97%', 1: '97.74%', 2: '90.95%', 3: '99.64%', 4: '90.12%', 5: '86.41%'}
# Val Loss: 0.259258, Val Acc: 92.67%, Val-Class-Acc: {0: '90.02%', 1: '96.99%', 3: '100.00%', 2: '94.96%', 5: '89.52%', 4: '82.59%'}, LR: 0.000100
# Epoch 959/1000, Train Loss: 0.148371, Train-Class-Acc: {0: '98.37%', 1: '97.74%', 2: '91.19%', 3: '99.08%', 4: '90.03%', 5: '87.63%'}
# Val Loss: 0.244982, Val Acc: 93.11%, Val-Class-Acc: {0: '91.24%', 1: '96.24%', 3: '100.00%', 2: '95.16%', 5: '87.86%', 4: '86.20%'}, LR: 0.000100
# Epoch 960/1000, Train Loss: 0.152805, Train-Class-Acc: {0: '97.74%', 1: '97.96%', 2: '92.25%', 3: '99.08%', 4: '88.26%', 5: '86.92%'}
# Val Loss: 0.247625, Val Acc: 92.94%, Val-Class-Acc: {0: '87.58%', 1: '97.56%', 3: '100.00%', 2: '94.35%', 5: '89.29%', 4: '87.05%'}, LR: 0.000100
# Epoch 961/1000, Train Loss: 0.139605, Train-Class-Acc: {0: '97.67%', 1: '98.03%', 2: '91.44%', 3: '99.79%', 4: '89.38%', 5: '87.83%'}
# Val Loss: 0.245655, Val Acc: 92.81%, Val-Class-Acc: {0: '90.22%', 1: '96.43%', 3: '100.00%', 2: '95.16%', 5: '88.10%', 4: '84.93%'}, LR: 0.000100
# Epoch 962/1000, Train Loss: 0.148591, Train-Class-Acc: {0: '96.81%', 1: '98.33%', 2: '90.54%', 3: '99.57%', 4: '90.12%', 5: '87.12%'}
# Val Loss: 0.240244, Val Acc: 92.94%, Val-Class-Acc: {0: '92.06%', 1: '95.30%', 3: '100.00%', 2: '95.77%', 5: '86.19%', 4: '86.20%'}, LR: 0.000100
# Epoch 963/1000, Train Loss: 0.143525, Train-Class-Acc: {0: '97.28%', 1: '98.40%', 2: '92.41%', 3: '99.50%', 4: '90.31%', 5: '86.61%'}
# Val Loss: 0.258205, Val Acc: 92.64%, Val-Class-Acc: {0: '90.63%', 1: '96.24%', 3: '100.00%', 2: '95.77%', 5: '87.62%', 4: '83.44%'}, LR: 0.000100
# Epoch 964/1000, Train Loss: 0.157937, Train-Class-Acc: {0: '96.89%', 1: '97.31%', 2: '90.78%', 3: '99.36%', 4: '90.87%', 5: '86.92%'}
# Val Loss: 0.254232, Val Acc: 92.57%, Val-Class-Acc: {0: '92.06%', 1: '95.49%', 3: '100.00%', 2: '95.36%', 5: '87.86%', 4: '82.59%'}, LR: 0.000100
# Epoch 965/1000, Train Loss: 0.152535, Train-Class-Acc: {0: '98.06%', 1: '97.60%', 2: '91.92%', 3: '99.36%', 4: '89.93%', 5: '85.90%'}
# Val Loss: 0.249762, Val Acc: 92.70%, Val-Class-Acc: {0: '91.45%', 1: '95.68%', 3: '100.00%', 2: '96.17%', 5: '86.67%', 4: '84.08%'}, LR: 0.000100
# Epoch 966/1000, Train Loss: 0.146285, Train-Class-Acc: {0: '96.89%', 1: '98.03%', 2: '91.52%', 3: '99.22%', 4: '90.49%', 5: '87.53%'}
# Val Loss: 0.255976, Val Acc: 92.50%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 3: '100.00%', 2: '96.17%', 5: '86.90%', 4: '82.38%'}, LR: 0.000100
# Epoch 967/1000, Train Loss: 0.157947, Train-Class-Acc: {0: '97.43%', 1: '98.11%', 2: '91.03%', 3: '99.36%', 4: '90.12%', 5: '86.82%'}
# Val Loss: 0.248868, Val Acc: 92.87%, Val-Class-Acc: {0: '89.82%', 1: '97.37%', 3: '100.00%', 2: '95.56%', 5: '86.43%', 4: '85.77%'}, LR: 0.000100
# Epoch 968/1000, Train Loss: 0.144046, Train-Class-Acc: {0: '97.59%', 1: '98.11%', 2: '92.90%', 3: '99.08%', 4: '89.10%', 5: '87.12%'}
# Val Loss: 0.261008, Val Acc: 92.67%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 3: '99.81%', 2: '95.56%', 5: '87.14%', 4: '84.50%'}, LR: 0.000100
# Epoch 969/1000, Train Loss: 0.144503, Train-Class-Acc: {0: '96.89%', 1: '98.18%', 2: '91.84%', 3: '99.36%', 4: '91.24%', 5: '88.34%'}
# Val Loss: 0.251405, Val Acc: 92.64%, Val-Class-Acc: {0: '90.43%', 1: '96.43%', 3: '100.00%', 2: '96.17%', 5: '86.43%', 4: '84.08%'}, LR: 0.000100
# Epoch 970/1000, Train Loss: 0.147400, Train-Class-Acc: {0: '97.20%', 1: '98.47%', 2: '90.95%', 3: '98.93%', 4: '90.21%', 5: '87.02%'}
# Val Loss: 0.260471, Val Acc: 92.84%, Val-Class-Acc: {0: '88.59%', 1: '97.93%', 3: '100.00%', 2: '94.76%', 5: '89.52%', 4: '84.29%'}, LR: 0.000100
# Epoch 971/1000, Train Loss: 0.142524, Train-Class-Acc: {0: '97.12%', 1: '98.03%', 2: '93.07%', 3: '99.64%', 4: '90.68%', 5: '87.02%'}
# Val Loss: 0.241682, Val Acc: 93.04%, Val-Class-Acc: {0: '90.84%', 1: '95.86%', 3: '100.00%', 2: '94.56%', 5: '89.29%', 4: '85.99%'}, LR: 0.000100
# Epoch 972/1000, Train Loss: 0.153740, Train-Class-Acc: {0: '97.05%', 1: '97.82%', 2: '90.86%', 3: '98.93%', 4: '90.31%', 5: '87.63%'}
# Val Loss: 0.270188, Val Acc: 92.26%, Val-Class-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '96.37%', 5: '86.67%', 4: '80.89%'}, LR: 0.000100
# Epoch 973/1000, Train Loss: 0.155080, Train-Class-Acc: {0: '96.97%', 1: '97.60%', 2: '91.60%', 3: '99.15%', 4: '89.93%', 5: '85.50%'}
# Val Loss: 0.256831, Val Acc: 92.67%, Val-Class-Acc: {0: '90.22%', 1: '96.62%', 3: '100.00%', 2: '95.97%', 5: '87.14%', 4: '83.86%'}, LR: 0.000100
# Epoch 974/1000, Train Loss: 0.145977, Train-Class-Acc: {0: '98.06%', 1: '98.33%', 2: '90.29%', 3: '98.93%', 4: '91.61%', 5: '87.22%'}
# Val Loss: 0.263351, Val Acc: 92.64%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 3: '100.00%', 2: '95.36%', 5: '88.81%', 4: '82.59%'}, LR: 0.000100
# Epoch 975/1000, Train Loss: 0.154609, Train-Class-Acc: {0: '96.73%', 1: '97.60%', 2: '90.78%', 3: '99.29%', 4: '88.63%', 5: '86.51%'}
# Val Loss: 0.287345, Val Acc: 92.09%, Val-Class-Acc: {0: '85.54%', 1: '98.31%', 3: '100.00%', 2: '95.36%', 5: '89.05%', 4: '82.17%'}, LR: 0.000100
# Epoch 976/1000, Train Loss: 0.157608, Train-Class-Acc: {0: '97.05%', 1: '98.69%', 2: '91.11%', 3: '98.86%', 4: '89.56%', 5: '86.11%'}
# Val Loss: 0.247236, Val Acc: 92.94%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 3: '100.00%', 2: '94.96%', 5: '89.52%', 4: '84.29%'}, LR: 0.000100
# Epoch 977/1000, Train Loss: 0.156600, Train-Class-Acc: {0: '97.12%', 1: '97.31%', 2: '91.92%', 3: '98.86%', 4: '90.31%', 5: '86.00%'}
# Val Loss: 0.263513, Val Acc: 92.20%, Val-Class-Acc: {0: '90.02%', 1: '96.80%', 3: '100.00%', 2: '95.36%', 5: '88.81%', 4: '80.04%'}, LR: 0.000100
# Epoch 978/1000, Train Loss: 0.155368, Train-Class-Acc: {0: '97.05%', 1: '98.33%', 2: '91.27%', 3: '99.15%', 4: '89.47%', 5: '87.22%'}
# Val Loss: 0.257012, Val Acc: 92.53%, Val-Class-Acc: {0: '88.19%', 1: '97.74%', 3: '100.00%', 2: '96.37%', 5: '86.43%', 4: '84.08%'}, LR: 0.000100
# Epoch 979/1000, Train Loss: 0.142063, Train-Class-Acc: {0: '97.59%', 1: '97.74%', 2: '92.33%', 3: '99.08%', 4: '90.49%', 5: '87.22%'}
# Val Loss: 0.259977, Val Acc: 92.37%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '95.77%', 5: '87.38%', 4: '81.53%'}, LR: 0.000100
# Epoch 980/1000, Train Loss: 0.151422, Train-Class-Acc: {0: '97.20%', 1: '97.38%', 2: '91.60%', 3: '99.15%', 4: '90.21%', 5: '87.42%'}
# Val Loss: 0.246458, Val Acc: 92.98%, Val-Class-Acc: {0: '91.45%', 1: '96.24%', 3: '100.00%', 2: '95.16%', 5: '89.05%', 4: '84.08%'}, LR: 0.000100
# Epoch 981/1000, Train Loss: 0.146746, Train-Class-Acc: {0: '97.51%', 1: '98.47%', 2: '92.33%', 3: '99.36%', 4: '90.03%', 5: '85.90%'}
# Val Loss: 0.248210, Val Acc: 92.60%, Val-Class-Acc: {0: '90.63%', 1: '96.43%', 3: '100.00%', 2: '95.36%', 5: '85.95%', 4: '84.93%'}, LR: 0.000100
# Epoch 982/1000, Train Loss: 0.149485, Train-Class-Acc: {1: '98.11%', 2: '91.76%', 3: '99.50%', 4: '89.93%', 5: '86.21%', 0: '97.36%'}
# Val Loss: 0.262676, Val Acc: 92.53%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '100.00%', 2: '95.77%', 5: '86.90%', 4: '82.59%'}, LR: 0.000100
# Epoch 983/1000, Train Loss: 0.154238, Train-Class-Acc: {0: '97.51%', 1: '98.03%', 2: '90.70%', 3: '98.79%', 4: '90.21%', 5: '86.00%'}
# Val Loss: 0.257264, Val Acc: 92.43%, Val-Class-Acc: {0: '90.84%', 1: '96.43%', 3: '100.00%', 2: '96.57%', 5: '85.71%', 4: '82.59%'}, LR: 0.000100
# Epoch 984/1000, Train Loss: 0.150652, Train-Class-Acc: {0: '97.43%', 1: '98.40%', 2: '90.62%', 3: '99.29%', 4: '90.12%', 5: '86.71%'}
# Val Loss: 0.263225, Val Acc: 92.84%, Val-Class-Acc: {0: '89.82%', 1: '97.74%', 3: '100.00%', 2: '96.17%', 5: '88.10%', 4: '83.01%'}, LR: 0.000100
# Epoch 985/1000, Train Loss: 0.152217, Train-Class-Acc: {0: '97.28%', 1: '98.25%', 2: '91.27%', 3: '98.79%', 4: '91.05%', 5: '86.31%'}
# Val Loss: 0.250557, Val Acc: 92.84%, Val-Class-Acc: {0: '90.22%', 1: '96.80%', 3: '100.00%', 2: '95.97%', 5: '86.67%', 4: '85.14%'}, LR: 0.000100
# Epoch 986/1000, Train Loss: 0.150837, Train-Class-Acc: {0: '97.20%', 2: '90.95%', 3: '99.36%', 4: '89.66%', 5: '87.63%', 1: '98.11%'}
# Val Loss: 0.247936, Val Acc: 92.77%, Val-Class-Acc: {0: '90.22%', 1: '97.18%', 3: '100.00%', 2: '95.77%', 5: '85.95%', 4: '85.14%'}, LR: 0.000100
# Epoch 987/1000, Train Loss: 0.150721, Train-Class-Acc: {0: '97.59%', 1: '98.40%', 2: '91.27%', 3: '99.15%', 4: '90.03%', 5: '85.90%'}
# Val Loss: 0.270392, Val Acc: 92.09%, Val-Class-Acc: {0: '89.61%', 1: '97.74%', 3: '100.00%', 2: '95.77%', 5: '87.86%', 4: '79.19%'}, LR: 0.000100
# Epoch 988/1000, Train Loss: 0.153681, Train-Class-Acc: {0: '97.12%', 1: '98.25%', 2: '90.70%', 3: '99.08%', 4: '90.21%', 5: '87.42%'}
# Val Loss: 0.245248, Val Acc: 92.77%, Val-Class-Acc: {0: '91.65%', 1: '95.49%', 3: '100.00%', 2: '95.77%', 5: '86.43%', 4: '85.14%'}, LR: 0.000100
# Epoch 989/1000, Train Loss: 0.159150, Train-Class-Acc: {0: '96.81%', 1: '98.33%', 2: '91.44%', 3: '98.79%', 4: '89.56%', 5: '86.21%'}
# Val Loss: 0.258294, Val Acc: 92.74%, Val-Class-Acc: {0: '88.80%', 1: '97.93%', 3: '100.00%', 2: '95.36%', 5: '87.38%', 4: '84.71%'}, LR: 0.000100
# Epoch 990/1000, Train Loss: 0.156037, Train-Class-Acc: {0: '96.73%', 1: '97.53%', 2: '90.62%', 3: '99.22%', 4: '90.03%', 5: '87.02%'}
# Val Loss: 0.263167, Val Acc: 92.23%, Val-Class-Acc: {0: '90.63%', 1: '96.05%', 3: '100.00%', 2: '95.56%', 5: '87.14%', 4: '81.74%'}, LR: 0.000100
# Epoch 991/1000, Train Loss: 0.150781, Train-Class-Acc: {0: '97.20%', 1: '97.96%', 2: '92.50%', 3: '99.15%', 4: '90.77%', 5: '87.22%'}
# Val Loss: 0.258043, Val Acc: 92.77%, Val-Class-Acc: {0: '89.82%', 1: '96.80%', 3: '100.00%', 2: '95.36%', 5: '89.76%', 4: '83.01%'}, LR: 0.000100
# Epoch 992/1000, Train Loss: 0.146611, Train-Class-Acc: {0: '97.67%', 1: '98.33%', 2: '91.11%', 3: '99.22%', 4: '90.77%', 5: '87.02%'}
# Val Loss: 0.256535, Val Acc: 92.87%, Val-Class-Acc: {0: '90.22%', 1: '97.37%', 3: '100.00%', 2: '95.97%', 5: '87.62%', 4: '83.86%'}, LR: 0.000100
# Epoch 993/1000, Train Loss: 0.152260, Train-Class-Acc: {0: '97.20%', 1: '97.82%', 2: '91.84%', 3: '98.65%', 4: '89.66%', 5: '86.82%'}
# Val Loss: 0.267202, Val Acc: 92.87%, Val-Class-Acc: {0: '89.21%', 1: '97.93%', 3: '100.00%', 2: '94.56%', 5: '89.52%', 4: '84.08%'}, LR: 0.000100
# Epoch 994/1000, Train Loss: 0.153248, Train-Class-Acc: {0: '97.12%', 1: '98.25%', 2: '91.19%', 3: '99.43%', 4: '88.72%', 5: '86.92%'}
# Val Loss: 0.258183, Val Acc: 92.26%, Val-Class-Acc: {0: '91.65%', 1: '96.24%', 3: '100.00%', 2: '96.77%', 5: '84.05%', 4: '82.17%'}, LR: 0.000100
# Epoch 995/1000, Train Loss: 0.154835, Train-Class-Acc: {0: '96.97%', 1: '97.67%', 2: '91.44%', 3: '99.29%', 4: '89.66%', 5: '88.64%'}
# Val Loss: 0.260570, Val Acc: 92.40%, Val-Class-Acc: {0: '88.39%', 1: '97.56%', 3: '100.00%', 2: '96.57%', 5: '84.52%', 4: '84.71%'}, LR: 0.000100
# Epoch 996/1000, Train Loss: 0.143730, Train-Class-Acc: {0: '97.82%', 1: '98.11%', 2: '92.25%', 3: '99.57%', 4: '91.52%', 5: '86.92%'}
# Val Loss: 0.243303, Val Acc: 92.98%, Val-Class-Acc: {0: '90.43%', 1: '96.80%', 3: '100.00%', 2: '95.77%', 5: '86.43%', 4: '86.20%'}, LR: 0.000100
# Epoch 997/1000, Train Loss: 0.152285, Train-Class-Acc: {0: '97.20%', 1: '97.74%', 2: '91.52%', 3: '99.36%', 4: '90.77%', 5: '87.63%'}
# Val Loss: 0.243857, Val Acc: 93.01%, Val-Class-Acc: {0: '90.43%', 1: '97.18%', 3: '100.00%', 2: '94.35%', 5: '89.52%', 4: '84.71%'}, LR: 0.000100
# Epoch 998/1000, Train Loss: 0.153278, Train-Class-Acc: {0: '97.28%', 1: '98.03%', 2: '90.70%', 3: '99.22%', 4: '89.66%', 5: '88.03%'}
# Val Loss: 0.258966, Val Acc: 92.91%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 3: '100.00%', 2: '94.35%', 5: '91.43%', 4: '82.59%'}, LR: 0.000100
# Epoch 999/1000, Train Loss: 0.147727, Train-Class-Acc: {0: '96.73%', 1: '98.33%', 2: '91.60%', 3: '99.15%', 4: '90.12%', 5: '87.02%'}
# Val Loss: 0.264486, Val Acc: 92.60%, Val-Class-Acc: {0: '88.19%', 1: '98.31%', 3: '100.00%', 2: '96.98%', 5: '84.76%', 4: '84.71%'}, LR: 0.000100
# Epoch 1000/1000, Train Loss: 0.152023, Train-Class-Acc: {0: '97.05%', 1: '98.18%', 2: '91.27%', 3: '98.86%', 4: '89.47%', 5: '87.32%'}
# Val Loss: 0.250635, Val Acc: 92.81%, Val-Class-Acc: {0: '89.82%', 1: '97.56%', 3: '100.00%', 2: '95.56%', 5: '86.19%', 4: '85.35%'}, LR: 0.000100
#
# ⏳ Total training time: 550.57 seconds
#
# 🏆 Best model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_best.pth (Val Accuracy: 93.59%)
#
# 📌 Final model saved as: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_final.pth
#
# 🎯 Top 5 Best Models:
# Epoch 86, Train Loss: 0.194150, Train-Acc: {0: '96.19%', 1: '97.38%', 2: '88.34%', 3: '98.79%', 4: '87.98%', 5: '85.40%'},
# Val Loss: 0.232892, Val Acc: 93.59%, Val-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '95.77%', 5: '89.52%', 4: '88.32%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_86.pth
# Epoch 61, Train Loss: 0.205366, Train-Acc: {0: '96.73%', 1: '97.82%', 2: '88.83%', 3: '99.00%', 4: '86.21%', 5: '83.47%'},
# Val Loss: 0.231992, Val Acc: 93.59%, Val-Acc: {0: '89.41%', 1: '97.37%', 3: '99.81%', 2: '94.76%', 5: '90.71%', 4: '87.90%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_61.pth
# Epoch 247, Train Loss: 0.176026, Train-Acc: {0: '96.03%', 1: '97.31%', 2: '90.05%', 3: '99.08%', 4: '89.38%', 5: '86.41%'},
# Val Loss: 0.241263, Val Acc: 93.45%, Val-Acc: {0: '90.02%', 1: '97.18%', 3: '100.00%', 2: '95.97%', 5: '89.05%', 4: '86.62%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_247.pth
# Epoch 84, Train Loss: 0.198730, Train-Acc: {0: '96.19%', 1: '97.89%', 2: '87.77%', 3: '98.65%', 4: '87.33%', 5: '81.64%'},
# Val Loss: 0.236405, Val Acc: 93.42%, Val-Acc: {0: '87.78%', 1: '98.12%', 3: '99.81%', 2: '95.97%', 5: '88.81%', 4: '88.11%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_84.pth
# Epoch 52, Train Loss: 0.209359, Train-Acc: {0: '96.35%', 1: '97.16%', 2: '87.60%', 3: '98.93%', 4: '87.79%', 5: '82.96%'},
# Val Loss: 0.236353, Val Acc: 93.42%, Val-Acc: {0: '88.80%', 1: '97.56%', 3: '99.63%', 2: '95.56%', 5: '89.52%', 4: '87.69%'}, Model Path: Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4/HAR_MLP_LoRA_v2_epoch_52.pth
# ---
# ### Period 4
# + ##### Total training time: 550.57 seconds
# + ##### Model: HAR_MLP_LoRA_v2
# + ##### Training and saving in *'Class_Incremental_CL/HAR_CIL/Trained_models/Standard_LoRA/Rank_4_Period_4'*
# + ##### Best Epoch: 86
# #### __Val Accuracy: 93.59%__
# #### __Val-Class-Acc: {0: '87.98%', 1: '98.12%', 3: '100.00%', 2: '95.77%', 5: '89.52%', 4: '88.32%'}__
#
# ✅ Period 4 Training Complete. Final model architecture:
# HAR_MLP_LoRA_v2(
#   (fc1): Linear(in_features=561, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=128, out_features=6, bias=True)
#   (lora_adapter): LoRA(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 📊 Class Summary → unique_classes = [0 1 2 3 4 5], num_classes = 6

# %% [markdown]
# ---
#
# ## 📊 Summary: HAR - Standard LoRA (HAR_MLP_LoRA_v2)
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                     |
# |--------|-------------------|---------------------|--------------------------------------------------------------------------|
# | 1      | 561.36            | **95.41%**          | {0: 93.28%, 1: 97.37%}                                                  |
# | 2      | 690.63            | **97.59%**          | {0: 91.45%, 1: 96.99%, 2: 100.00%}                                      |
# | 3      | 423.39            | **98.07%**          | {0: 91.24%, 1: 97.37%, 2: 100.00%, 3: 100.00%}                          |
# | 4      | 550.57            | **93.59%**          | {0: 87.98%, 1: 98.12%, 2: 95.77%, 3: 100.00%, 4: 88.32%, 5: 89.52%}     |
#
# ---

# %% [markdown]
# ### ✔️ HAR - Standard LoRA
#
# | Period | Training Time (s) | Validation Accuracy | Class-wise Accuracy                                                     |
# |--------|-------------------|---------------------|--------------------------------------------------------------------------|
# | 1      | 561.36            | **95.41%**          | {0: 93.28%, 1: 97.37%}                                                  |
# | 2      | 690.63            | **97.59%**          | {0: 91.45%, 1: 96.99%, 2: 100.00%}                                      |
# | 3      | 423.39            | **98.07%**          | {0: 91.24%, 1: 97.37%, 2: 100.00%, 3: 100.00%}                          |
# | 4      | 550.57            | **93.59%**          | {0: 87.98%, 1: 98.12%, 2: 95.77%, 3: 100.00%, 4: 88.32%, 5: 89.52%}     |
